# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

from collections import OrderedDict 

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 100)

# viz
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(12.7,10.27)})

# notebook settings
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable
#torch.manual_seed(123)

from dutils import Experiment
from trainer import fit
import visualization as vis
from tcga_datasets import SiameseDataset
import numpy as np
cuda = torch.cuda.is_available()
print("Cuda is available: {}".format(cuda))

# Models
from tcga_networks import EmbeddingNet, SiameseNet
from losses import ContrastiveLoss
# Out:
# Cuda is available: True

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score as ANMI

# %%
def getTCGA(disease):
    path = "/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP/TCGA/TCGA_{}_counts.tsv.gz"
    files = [path.format(d) for d in disease]
    return files


def readGCP(files, biotype='protein_coding', mean=True):
    """
    Paths to count matrices.
    """
    data_dict = {}
    for f in files:
        key = os.path.basename(f).split("_")[1]
        data = pd.read_csv(f, sep='\t', index_col=0)
        # transcript metadata
        meta = pd.DataFrame([row[:-1] for row in data.index.str.split("|")],
                            columns=['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'GENE', 'BP', 'BIOTYPE'])
        meta = pd.MultiIndex.from_frame(meta)
        data.index = meta
        # subset transcripts
        data = data.xs(key=biotype, level='BIOTYPE')
        data = data.droplevel(['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'BP'])
        # average gene expression of splice variants
        data = data.T
        if mean:
            data = data.groupby(by=data.columns, axis=1).mean()
        data_dict[key] = data
    return data_dict


def uq_norm(df, q=0.75):
    """
    Upper quartile normalization of GEX for samples.
    """
    quantiles = df.quantile(q=q, axis=1)
    norm = df.divide(quantiles, axis=0)
    return norm

# %%
def generate_fsets(data, n, steps=5):
    r = np.linspace(start=1, stop=n, num=steps, dtype='int')
    idx = [np.random.randint(low=1, high=data.shape[1], size=i) for i in r]
    return idx

# %%
def process_data():
    base = "/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP"
    disease = ['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']

    tcga_files = getTCGA(disease)
    tcga_meta = pd.read_csv(os.path.join(base, "TCGA/TCGA_GDC_ID_MAP.tsv"), sep="\t")
    tcga_raw = readGCP(tcga_files, mean=True)
    # combine samples
    tcga_raw = pd.concat(tcga_raw.values())
    # Upper quartile normalization
    tcga_raw = uq_norm(tcga_raw)
    # log norm
    tcga = tcga_raw.transform(np.log1p)
    return tcga, tcga_meta

# %%
import datetime
import pathlib

# %% [markdown]
# ### Setup

# %%
tcga, tcga_meta = process_data()

# %%
n_features = 300
steps = 60
feature_idx = generate_fsets(tcga, n=n_features, steps=steps)

# %%
hierarchy = OrderedDict({'Disease':['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM'],
                         'Sample Type':['Primary Tumor', 'Solid Tissue Normal']})

# %%
# Define experiment
exp = Experiment(meta_data=tcga_meta,
                 hierarchy=hierarchy,
                 index='CGHubAnalysisID',
                 cases='Case ID',
                 min_samples=20)
# Train / Test split
exp.train_test_split(cases='Case ID')
# Return data 
train_data, train_labels = exp.get_data(tcga, subset="train", dtype=np.float32)
test_data, test_labels = exp.get_data(tcga, subset="test", dtype=np.float32)

# %%
# Path
dtime = datetime.datetime.today().strftime("%Y.%m.%d_%H:%M")
exp_dir = "/srv/nas/mk2/projects/pan-cancer/experiments/{}_{}_{}-{}".format(dtime, len(exp.labels_dict), n_features, steps)
pathlib.Path(exp_dir).mkdir(parents=True, exist_ok=False)

# %%
experiments = {'experiment': exp,
               'train':(train_data, train_labels),
               'test': (test_data, test_labels)}
pd.to_pickle(experiments, os.path.join(exp_dir, "experiment_meta_data.pkl"))

# %% [markdown]
# ### Network

# %%
def feature_training(train_data, train_labels, test_data, test_labels, feature_idx, exp_dir, cuda=True):
    # Meta data
    meta_data = {"n_features":[],
                 "model":[],
                 "ANMI":[]}
    # Params
    batch_size = 8
    kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {'num_workers': 10}
    
    # Feature Index
    for batch, feat in enumerate(feature_idx):
        print("Number features: {}\n".format(len(feat)))
        exp_data = {'feature_idx':feat}
        # Define data
        siamese_train_dataset = SiameseDataset(data=train_data.iloc[:,feat],
                                           labels=train_labels,
                                           train=True)
        siamese_test_dataset = SiameseDataset(data=test_data.iloc[:,feat],
                                          labels=test_labels,
                                          train=False)
        # Loaders
        siamese_train_loader = torch.utils.data.DataLoader(siamese_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
        siamese_test_loader = torch.utils.data.DataLoader(siamese_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)
        # Instantiate model
        n_samples, n_features = siamese_train_dataset.train_data.shape
        for i in range(3):
            nmodel = 'model_{}'.format(i)
            print("\t{}".format(nmodel))
            embedding_net = EmbeddingNet(n_features, 2)
            model = SiameseNet(embedding_net)
            if cuda:
                model.cuda()
            # Parameters
            margin = 1.
            loss_fn = ContrastiveLoss(margin)
            lr = 1e-3
            optimizer = optim.Adam(model.parameters(), lr=lr)
            scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
            n_epochs = 10
            log_interval = round(len(siamese_train_dataset)/1/batch_size)
            # Train
            train_loss, val_loss = fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, 
                                       n_epochs, cuda, log_interval)
            # Test Embeddings
            val_embeddings_baseline, val_labels_baseline = vis.extract_embeddings(siamese_test_dataset.test_data, siamese_test_dataset.labels, model)
            # Evaluation
            n_clusters = len(np.unique(test_labels))
            kmeans = KMeans(n_clusters=n_clusters)
            siamese_clusters = kmeans.fit_predict(val_embeddings_baseline)
            anmi = ANMI(siamese_clusters, val_labels_baseline)
            # Store
            meta_data['n_features'].append(len(feat))
            meta_data['model'].append(nmodel)
            meta_data['ANMI'].append(anmi)
            exp_data[nmodel] = {'data': (val_embeddings_baseline, val_labels_baseline),
                                'loss': (train_loss, val_loss),
                                'ANMI': anmi}
        pd.to_pickle(exp_data, os.path.join(exp_dir, "model_{}.pkl".format(len(feat))))
    pd.to_pickle(meta_data, os.path.join(exp_dir, "model_meta_data.pkl"))

# %%
feature_training(train_data, train_labels, test_data, test_labels, feature_idx, exp_dir)
# Out:
# Batch 0
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187258
# Train: [1098/2931 (100%)]	Loss: 0.147975
# Epoch: 1/10. Train set: Average loss: 0.1481
# Epoch: 1/10. Validation set: Average loss: 0.1453
# Train: [0/2931 (0%)]	Loss: 0.067953
# Train: [1098/2931 (100%)]	Loss: 0.138040
# Epoch: 2/10. Train set: Average loss: 0.1378
# Epoch: 2/10. Validation set: Average loss: 0.1450
# Train: [0/2931 (0%)]	Loss: 0.059779
# Train: [1098/2931 (100%)]	Loss: 0.141913
# Epoch: 3/10. Train set: Average loss: 0.1417
# Epoch: 3/10. Validation set: Average loss: 0.1457
# Train: [0/2931 (0%)]	Loss: 0.215458
# Train: [1098/2931 (100%)]	Loss: 0.139657
# Epoch: 4/10. Train set: Average loss: 0.1399
# Epoch: 4/10. Validation set: Average loss: 0.1542
# Train: [0/2931 (0%)]	Loss: 0.129223
# Train: [1098/2931 (100%)]	Loss: 0.140416
# Epoch: 5/10. Train set: Average loss: 0.1404
# Epoch: 5/10. Validation set: Average loss: 0.1535
# Train: [0/2931 (0%)]	Loss: 0.208968
# Train: [1098/2931 (100%)]	Loss: 0.145198
# Epoch: 6/10. Train set: Average loss: 0.1454
# Epoch: 6/10. Validation set: Average loss: 0.1545
# Train: [0/2931 (0%)]	Loss: 0.141262
# Train: [1098/2931 (100%)]	Loss: 0.142927
# Epoch: 7/10. Train set: Average loss: 0.1429
# Epoch: 7/10. Validation set: Average loss: 0.1580
# Train: [0/2931 (0%)]	Loss: 0.163689
# Train: [1098/2931 (100%)]	Loss: 0.140268
# Epoch: 8/10. Train set: Average loss: 0.1403
# Epoch: 8/10. Validation set: Average loss: 0.1500
# Train: [0/2931 (0%)]	Loss: 0.199330
# Train: [1098/2931 (100%)]	Loss: 0.135420
# Epoch: 9/10. Train set: Average loss: 0.1356
# Epoch: 9/10. Validation set: Average loss: 0.1417
# Train: [0/2931 (0%)]	Loss: 0.135909
# Train: [1098/2931 (100%)]	Loss: 0.136691
# Epoch: 10/10. Train set: Average loss: 0.1367
# Epoch: 10/10. Validation set: Average loss: 0.1416
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.184075
# Train: [1098/2931 (100%)]	Loss: 0.138883
# Epoch: 1/10. Train set: Average loss: 0.1390
# Epoch: 1/10. Validation set: Average loss: 0.1453
# Train: [0/2931 (0%)]	Loss: 0.196935
# Train: [1098/2931 (100%)]	Loss: 0.148214
# Epoch: 2/10. Train set: Average loss: 0.1483
# Epoch: 2/10. Validation set: Average loss: 0.1425
# Train: [0/2931 (0%)]	Loss: 0.064455
# Train: [1098/2931 (100%)]	Loss: 0.141974
# Epoch: 3/10. Train set: Average loss: 0.1418
# Epoch: 3/10. Validation set: Average loss: 0.1419
# Train: [0/2931 (0%)]	Loss: 0.105943
# Train: [1098/2931 (100%)]	Loss: 0.143189
# Epoch: 4/10. Train set: Average loss: 0.1431
# Epoch: 4/10. Validation set: Average loss: 0.1517
# Train: [0/2931 (0%)]	Loss: 0.055563
# Train: [1098/2931 (100%)]	Loss: 0.140018
# Epoch: 5/10. Train set: Average loss: 0.1398
# Epoch: 5/10. Validation set: Average loss: 0.1424
# Train: [0/2931 (0%)]	Loss: 0.105056
# Train: [1098/2931 (100%)]	Loss: 0.144264
# Epoch: 6/10. Train set: Average loss: 0.1442
# Epoch: 6/10. Validation set: Average loss: 0.1652
# Train: [0/2931 (0%)]	Loss: 0.128561
# Train: [1098/2931 (100%)]	Loss: 0.139517
# Epoch: 7/10. Train set: Average loss: 0.1395
# Epoch: 7/10. Validation set: Average loss: 0.1424
# Train: [0/2931 (0%)]	Loss: 0.022888
# Train: [1098/2931 (100%)]	Loss: 0.140792
# Epoch: 8/10. Train set: Average loss: 0.1405
# Epoch: 8/10. Validation set: Average loss: 0.1426
# Train: [0/2931 (0%)]	Loss: 0.112125
# Train: [1098/2931 (100%)]	Loss: 0.140308
# Epoch: 9/10. Train set: Average loss: 0.1402
# Epoch: 9/10. Validation set: Average loss: 0.1423
# Train: [0/2931 (0%)]	Loss: 0.105101
# Train: [1098/2931 (100%)]	Loss: 0.136593
# Epoch: 10/10. Train set: Average loss: 0.1365
# Epoch: 10/10. Validation set: Average loss: 0.1414
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.248971
# Train: [1098/2931 (100%)]	Loss: 0.147888
# Epoch: 1/10. Train set: Average loss: 0.1482
# Epoch: 1/10. Validation set: Average loss: 0.1455
# Train: [0/2931 (0%)]	Loss: 0.134827
# Train: [1098/2931 (100%)]	Loss: 0.146713
# Epoch: 2/10. Train set: Average loss: 0.1467
# Epoch: 2/10. Validation set: Average loss: 0.1434
# Train: [0/2931 (0%)]	Loss: 0.114375
# Train: [1098/2931 (100%)]	Loss: 0.141841
# Epoch: 3/10. Train set: Average loss: 0.1418
# Epoch: 3/10. Validation set: Average loss: 0.1525
# Train: [0/2931 (0%)]	Loss: 0.101381
# Train: [1098/2931 (100%)]	Loss: 0.143565
# Epoch: 4/10. Train set: Average loss: 0.1435
# Epoch: 4/10. Validation set: Average loss: 0.1525
# Train: [0/2931 (0%)]	Loss: 0.139164
# Train: [1098/2931 (100%)]	Loss: 0.143485
# Epoch: 5/10. Train set: Average loss: 0.1435
# Epoch: 5/10. Validation set: Average loss: 0.1463
# Train: [0/2931 (0%)]	Loss: 0.159635
# Train: [1098/2931 (100%)]	Loss: 0.139844
# Epoch: 6/10. Train set: Average loss: 0.1399
# Epoch: 6/10. Validation set: Average loss: 0.1457
# Train: [0/2931 (0%)]	Loss: 0.142433
# Train: [1098/2931 (100%)]	Loss: 0.143537
# Epoch: 7/10. Train set: Average loss: 0.1435
# Epoch: 7/10. Validation set: Average loss: 0.1422
# Train: [0/2931 (0%)]	Loss: 0.110157
# Train: [1098/2931 (100%)]	Loss: 0.146157
# Epoch: 8/10. Train set: Average loss: 0.1461
# Epoch: 8/10. Validation set: Average loss: 0.1545
# Train: [0/2931 (0%)]	Loss: 0.119046
# Train: [1098/2931 (100%)]	Loss: 0.138770
# Epoch: 9/10. Train set: Average loss: 0.1387
# Epoch: 9/10. Validation set: Average loss: 0.1426
# Train: [0/2931 (0%)]	Loss: 0.176405
# Train: [1098/2931 (100%)]	Loss: 0.137221
# Epoch: 10/10. Train set: Average loss: 0.1373
# Epoch: 10/10. Validation set: Average loss: 0.1428
# Batch 1
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187333
# Train: [1098/2931 (100%)]	Loss: 0.118327
# Epoch: 1/10. Train set: Average loss: 0.1185
# Epoch: 1/10. Validation set: Average loss: 0.1104
# Train: [0/2931 (0%)]	Loss: 0.103277
# Train: [1098/2931 (100%)]	Loss: 0.105170
# Epoch: 2/10. Train set: Average loss: 0.1052
# Epoch: 2/10. Validation set: Average loss: 0.1076
# Train: [0/2931 (0%)]	Loss: 0.089984
# Train: [1098/2931 (100%)]	Loss: 0.099660
# Epoch: 3/10. Train set: Average loss: 0.0996
# Epoch: 3/10. Validation set: Average loss: 0.0878
# Train: [0/2931 (0%)]	Loss: 0.122477
# Train: [1098/2931 (100%)]	Loss: 0.088979
# Epoch: 4/10. Train set: Average loss: 0.0891
# Epoch: 4/10. Validation set: Average loss: 0.0902
# Train: [0/2931 (0%)]	Loss: 0.037168
# Train: [1098/2931 (100%)]	Loss: 0.081897
# Epoch: 5/10. Train set: Average loss: 0.0818
# Epoch: 5/10. Validation set: Average loss: 0.0844
# Train: [0/2931 (0%)]	Loss: 0.041520
# Train: [1098/2931 (100%)]	Loss: 0.082328
# Epoch: 6/10. Train set: Average loss: 0.0822
# Epoch: 6/10. Validation set: Average loss: 0.0928
# Train: [0/2931 (0%)]	Loss: 0.106967
# Train: [1098/2931 (100%)]	Loss: 0.080812
# Epoch: 7/10. Train set: Average loss: 0.0809
# Epoch: 7/10. Validation set: Average loss: 0.0984
# Train: [0/2931 (0%)]	Loss: 0.102685
# Train: [1098/2931 (100%)]	Loss: 0.081471
# Epoch: 8/10. Train set: Average loss: 0.0815
# Epoch: 8/10. Validation set: Average loss: 0.0891
# Train: [0/2931 (0%)]	Loss: 0.046151
# Train: [1098/2931 (100%)]	Loss: 0.078140
# Epoch: 9/10. Train set: Average loss: 0.0781
# Epoch: 9/10. Validation set: Average loss: 0.0846
# Train: [0/2931 (0%)]	Loss: 0.123712
# Train: [1098/2931 (100%)]	Loss: 0.077208
# Epoch: 10/10. Train set: Average loss: 0.0773
# Epoch: 10/10. Validation set: Average loss: 0.0870
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.062383
# Train: [1098/2931 (100%)]	Loss: 0.130084
# Epoch: 1/10. Train set: Average loss: 0.1299
# Epoch: 1/10. Validation set: Average loss: 0.1238
# Train: [0/2931 (0%)]	Loss: 0.052206
# Train: [1098/2931 (100%)]	Loss: 0.108972
# Epoch: 2/10. Train set: Average loss: 0.1088
# Epoch: 2/10. Validation set: Average loss: 0.1052
# Train: [0/2931 (0%)]	Loss: 0.244223
# Train: [1098/2931 (100%)]	Loss: 0.100277
# Epoch: 3/10. Train set: Average loss: 0.1007
# Epoch: 3/10. Validation set: Average loss: 0.1070
# Train: [0/2931 (0%)]	Loss: 0.056176
# Train: [1098/2931 (100%)]	Loss: 0.091317
# Epoch: 4/10. Train set: Average loss: 0.0912
# Epoch: 4/10. Validation set: Average loss: 0.1039
# Train: [0/2931 (0%)]	Loss: 0.089984
# Train: [1098/2931 (100%)]	Loss: 0.088546
# Epoch: 5/10. Train set: Average loss: 0.0885
# Epoch: 5/10. Validation set: Average loss: 0.0901
# Train: [0/2931 (0%)]	Loss: 0.096517
# Train: [1098/2931 (100%)]	Loss: 0.084678
# Epoch: 6/10. Train set: Average loss: 0.0847
# Epoch: 6/10. Validation set: Average loss: 0.0998
# Train: [0/2931 (0%)]	Loss: 0.103353
# Train: [1098/2931 (100%)]	Loss: 0.090569
# Epoch: 7/10. Train set: Average loss: 0.0906
# Epoch: 7/10. Validation set: Average loss: 0.0938
# Train: [0/2931 (0%)]	Loss: 0.044669
# Train: [1098/2931 (100%)]	Loss: 0.082254
# Epoch: 8/10. Train set: Average loss: 0.0822
# Epoch: 8/10. Validation set: Average loss: 0.0939
# Train: [0/2931 (0%)]	Loss: 0.116061
# Train: [1098/2931 (100%)]	Loss: 0.080574
# Epoch: 9/10. Train set: Average loss: 0.0807
# Epoch: 9/10. Validation set: Average loss: 0.0845
# Train: [0/2931 (0%)]	Loss: 0.068508
# Train: [1098/2931 (100%)]	Loss: 0.078069
# Epoch: 10/10. Train set: Average loss: 0.0780
# Epoch: 10/10. Validation set: Average loss: 0.0828
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.062422
# Train: [1098/2931 (100%)]	Loss: 0.133537
# Epoch: 1/10. Train set: Average loss: 0.1333
# Epoch: 1/10. Validation set: Average loss: 0.1340
# Train: [0/2931 (0%)]	Loss: 0.075743
# Train: [1098/2931 (100%)]	Loss: 0.114792
# Epoch: 2/10. Train set: Average loss: 0.1147
# Epoch: 2/10. Validation set: Average loss: 0.1258
# Train: [0/2931 (0%)]	Loss: 0.079754
# Train: [1098/2931 (100%)]	Loss: 0.097157
# Epoch: 3/10. Train set: Average loss: 0.0971
# Epoch: 3/10. Validation set: Average loss: 0.0989
# Train: [0/2931 (0%)]	Loss: 0.156477
# Train: [1098/2931 (100%)]	Loss: 0.098519
# Epoch: 4/10. Train set: Average loss: 0.0987
# Epoch: 4/10. Validation set: Average loss: 0.0938
# Train: [0/2931 (0%)]	Loss: 0.038335
# Train: [1098/2931 (100%)]	Loss: 0.083855
# Epoch: 5/10. Train set: Average loss: 0.0837
# Epoch: 5/10. Validation set: Average loss: 0.0944
# Train: [0/2931 (0%)]	Loss: 0.127130
# Train: [1098/2931 (100%)]	Loss: 0.090586
# Epoch: 6/10. Train set: Average loss: 0.0907
# Epoch: 6/10. Validation set: Average loss: 0.0920
# Train: [0/2931 (0%)]	Loss: 0.185333
# Train: [1098/2931 (100%)]	Loss: 0.087732
# Epoch: 7/10. Train set: Average loss: 0.0880
# Epoch: 7/10. Validation set: Average loss: 0.0937
# Train: [0/2931 (0%)]	Loss: 0.114735
# Train: [1098/2931 (100%)]	Loss: 0.083432
# Epoch: 8/10. Train set: Average loss: 0.0835
# Epoch: 8/10. Validation set: Average loss: 0.0896
# Train: [0/2931 (0%)]	Loss: 0.057175
# Train: [1098/2931 (100%)]	Loss: 0.079129
# Epoch: 9/10. Train set: Average loss: 0.0791
# Epoch: 9/10. Validation set: Average loss: 0.0864
# Train: [0/2931 (0%)]	Loss: 0.100886
# Train: [1098/2931 (100%)]	Loss: 0.074770
# Epoch: 10/10. Train set: Average loss: 0.0748
# Epoch: 10/10. Validation set: Average loss: 0.0858
# Batch 2
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.311900
# Train: [1098/2931 (100%)]	Loss: 0.119399
# Epoch: 1/10. Train set: Average loss: 0.1199
# Epoch: 1/10. Validation set: Average loss: 0.1245
# Train: [0/2931 (0%)]	Loss: 0.145122
# Train: [1098/2931 (100%)]	Loss: 0.096866
# Epoch: 2/10. Train set: Average loss: 0.0970
# Epoch: 2/10. Validation set: Average loss: 0.1059
# Train: [0/2931 (0%)]	Loss: 0.053972
# Train: [1098/2931 (100%)]	Loss: 0.081094
# Epoch: 3/10. Train set: Average loss: 0.0810
# Epoch: 3/10. Validation set: Average loss: 0.0963
# Train: [0/2931 (0%)]	Loss: 0.072169
# Train: [1098/2931 (100%)]	Loss: 0.081488
# Epoch: 4/10. Train set: Average loss: 0.0815
# Epoch: 4/10. Validation set: Average loss: 0.0897
# Train: [0/2931 (0%)]	Loss: 0.079753
# Train: [1098/2931 (100%)]	Loss: 0.076621
# Epoch: 5/10. Train set: Average loss: 0.0766
# Epoch: 5/10. Validation set: Average loss: 0.0825
# Train: [0/2931 (0%)]	Loss: 0.055671
# Train: [1098/2931 (100%)]	Loss: 0.077621
# Epoch: 6/10. Train set: Average loss: 0.0776
# Epoch: 6/10. Validation set: Average loss: 0.0829
# Train: [0/2931 (0%)]	Loss: 0.123581
# Train: [1098/2931 (100%)]	Loss: 0.073626
# Epoch: 7/10. Train set: Average loss: 0.0738
# Epoch: 7/10. Validation set: Average loss: 0.0817
# Train: [0/2931 (0%)]	Loss: 0.118424
# Train: [1098/2931 (100%)]	Loss: 0.077031
# Epoch: 8/10. Train set: Average loss: 0.0771
# Epoch: 8/10. Validation set: Average loss: 0.0929
# Train: [0/2931 (0%)]	Loss: 0.079147
# Train: [1098/2931 (100%)]	Loss: 0.073677
# Epoch: 9/10. Train set: Average loss: 0.0737
# Epoch: 9/10. Validation set: Average loss: 0.0743
# Train: [0/2931 (0%)]	Loss: 0.056273
# Train: [1098/2931 (100%)]	Loss: 0.065328
# Epoch: 10/10. Train set: Average loss: 0.0653
# Epoch: 10/10. Validation set: Average loss: 0.0719
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.312286
# Train: [1098/2931 (100%)]	Loss: 0.123453
# Epoch: 1/10. Train set: Average loss: 0.1240
# Epoch: 1/10. Validation set: Average loss: 0.0982
# Train: [0/2931 (0%)]	Loss: 0.072041
# Train: [1098/2931 (100%)]	Loss: 0.080034
# Epoch: 2/10. Train set: Average loss: 0.0800
# Epoch: 2/10. Validation set: Average loss: 0.1580
# Train: [0/2931 (0%)]	Loss: 0.328090
# Train: [1098/2931 (100%)]	Loss: 0.095974
# Epoch: 3/10. Train set: Average loss: 0.0966
# Epoch: 3/10. Validation set: Average loss: 0.1161
# Train: [0/2931 (0%)]	Loss: 0.122485
# Train: [1098/2931 (100%)]	Loss: 0.085731
# Epoch: 4/10. Train set: Average loss: 0.0858
# Epoch: 4/10. Validation set: Average loss: 0.0814
# Train: [0/2931 (0%)]	Loss: 0.070550
# Train: [1098/2931 (100%)]	Loss: 0.075770
# Epoch: 5/10. Train set: Average loss: 0.0758
# Epoch: 5/10. Validation set: Average loss: 0.0790
# Train: [0/2931 (0%)]	Loss: 0.084286
# Train: [1098/2931 (100%)]	Loss: 0.080212
# Epoch: 6/10. Train set: Average loss: 0.0802
# Epoch: 6/10. Validation set: Average loss: 0.0791
# Train: [0/2931 (0%)]	Loss: 0.105124
# Train: [1098/2931 (100%)]	Loss: 0.076246
# Epoch: 7/10. Train set: Average loss: 0.0763
# Epoch: 7/10. Validation set: Average loss: 0.0801
# Train: [0/2931 (0%)]	Loss: 0.052107
# Train: [1098/2931 (100%)]	Loss: 0.077588
# Epoch: 8/10. Train set: Average loss: 0.0775
# Epoch: 8/10. Validation set: Average loss: 0.0794
# Train: [0/2931 (0%)]	Loss: 0.071669
# Train: [1098/2931 (100%)]	Loss: 0.069270
# Epoch: 9/10. Train set: Average loss: 0.0693
# Epoch: 9/10. Validation set: Average loss: 0.0741
# Train: [0/2931 (0%)]	Loss: 0.044361
# Train: [1098/2931 (100%)]	Loss: 0.068288
# Epoch: 10/10. Train set: Average loss: 0.0682
# Epoch: 10/10. Validation set: Average loss: 0.0723
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.186930
# Train: [1098/2931 (100%)]	Loss: 0.129054
# Epoch: 1/10. Train set: Average loss: 0.1292
# Epoch: 1/10. Validation set: Average loss: 0.1237
# Train: [0/2931 (0%)]	Loss: 0.121721
# Train: [1098/2931 (100%)]	Loss: 0.093723
# Epoch: 2/10. Train set: Average loss: 0.0938
# Epoch: 2/10. Validation set: Average loss: 0.0937
# Train: [0/2931 (0%)]	Loss: 0.129194
# Train: [1098/2931 (100%)]	Loss: 0.081693
# Epoch: 3/10. Train set: Average loss: 0.0818
# Epoch: 3/10. Validation set: Average loss: 0.1014
# Train: [0/2931 (0%)]	Loss: 0.069341
# Train: [1098/2931 (100%)]	Loss: 0.082905
# Epoch: 4/10. Train set: Average loss: 0.0829
# Epoch: 4/10. Validation set: Average loss: 0.0876
# Train: [0/2931 (0%)]	Loss: 0.049902
# Train: [1098/2931 (100%)]	Loss: 0.079089
# Epoch: 5/10. Train set: Average loss: 0.0790
# Epoch: 5/10. Validation set: Average loss: 0.0859
# Train: [0/2931 (0%)]	Loss: 0.088667
# Train: [1098/2931 (100%)]	Loss: 0.077046
# Epoch: 6/10. Train set: Average loss: 0.0771
# Epoch: 6/10. Validation set: Average loss: 0.0771
# Train: [0/2931 (0%)]	Loss: 0.097203
# Train: [1098/2931 (100%)]	Loss: 0.074039
# Epoch: 7/10. Train set: Average loss: 0.0741
# Epoch: 7/10. Validation set: Average loss: 0.0920
# Train: [0/2931 (0%)]	Loss: 0.160796
# Train: [1098/2931 (100%)]	Loss: 0.077662
# Epoch: 8/10. Train set: Average loss: 0.0779
# Epoch: 8/10. Validation set: Average loss: 0.0959
# Train: [0/2931 (0%)]	Loss: 0.123480
# Train: [1098/2931 (100%)]	Loss: 0.069994
# Epoch: 9/10. Train set: Average loss: 0.0701
# Epoch: 9/10. Validation set: Average loss: 0.0758
# Train: [0/2931 (0%)]	Loss: 0.106697
# Train: [1098/2931 (100%)]	Loss: 0.067045
# Epoch: 10/10. Train set: Average loss: 0.0672
# Epoch: 10/10. Validation set: Average loss: 0.0731
# Batch 3
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187038
# Train: [1098/2931 (100%)]	Loss: 0.097506
# Epoch: 1/10. Train set: Average loss: 0.0978
# Epoch: 1/10. Validation set: Average loss: 0.0788
# Train: [0/2931 (0%)]	Loss: 0.128285
# Train: [1098/2931 (100%)]	Loss: 0.087313
# Epoch: 2/10. Train set: Average loss: 0.0874
# Epoch: 2/10. Validation set: Average loss: 0.0727
# Train: [0/2931 (0%)]	Loss: 0.079250
# Train: [1098/2931 (100%)]	Loss: 0.077251
# Epoch: 3/10. Train set: Average loss: 0.0773
# Epoch: 3/10. Validation set: Average loss: 0.0966
# Train: [0/2931 (0%)]	Loss: 0.111674
# Train: [1098/2931 (100%)]	Loss: 0.070997
# Epoch: 4/10. Train set: Average loss: 0.0711
# Epoch: 4/10. Validation set: Average loss: 0.0684
# Train: [0/2931 (0%)]	Loss: 0.037202
# Train: [1098/2931 (100%)]	Loss: 0.071139
# Epoch: 5/10. Train set: Average loss: 0.0710
# Epoch: 5/10. Validation set: Average loss: 0.0616
# Train: [0/2931 (0%)]	Loss: 0.142682
# Train: [1098/2931 (100%)]	Loss: 0.067155
# Epoch: 6/10. Train set: Average loss: 0.0674
# Epoch: 6/10. Validation set: Average loss: 0.0613
# Train: [0/2931 (0%)]	Loss: 0.123630
# Train: [1098/2931 (100%)]	Loss: 0.066811
# Epoch: 7/10. Train set: Average loss: 0.0670
# Epoch: 7/10. Validation set: Average loss: 0.0611
# Train: [0/2931 (0%)]	Loss: 0.083241
# Train: [1098/2931 (100%)]	Loss: 0.064676
# Epoch: 8/10. Train set: Average loss: 0.0647
# Epoch: 8/10. Validation set: Average loss: 0.0716
# Train: [0/2931 (0%)]	Loss: 0.074729
# Train: [1098/2931 (100%)]	Loss: 0.056470
# Epoch: 9/10. Train set: Average loss: 0.0565
# Epoch: 9/10. Validation set: Average loss: 0.0531
# Train: [0/2931 (0%)]	Loss: 0.030246
# Train: [1098/2931 (100%)]	Loss: 0.053586
# Epoch: 10/10. Train set: Average loss: 0.0535
# Epoch: 10/10. Validation set: Average loss: 0.0526
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.437084
# Train: [1098/2931 (100%)]	Loss: 0.095652
# Epoch: 1/10. Train set: Average loss: 0.0966
# Epoch: 1/10. Validation set: Average loss: 0.0957
# Train: [0/2931 (0%)]	Loss: 0.094295
# Train: [1098/2931 (100%)]	Loss: 0.092866
# Epoch: 2/10. Train set: Average loss: 0.0929
# Epoch: 2/10. Validation set: Average loss: 0.0931
# Train: [0/2931 (0%)]	Loss: 0.123704
# Train: [1098/2931 (100%)]	Loss: 0.075451
# Epoch: 3/10. Train set: Average loss: 0.0756
# Epoch: 3/10. Validation set: Average loss: 0.0717
# Train: [0/2931 (0%)]	Loss: 0.070733
# Train: [1098/2931 (100%)]	Loss: 0.077300
# Epoch: 4/10. Train set: Average loss: 0.0773
# Epoch: 4/10. Validation set: Average loss: 0.0913
# Train: [0/2931 (0%)]	Loss: 0.126224
# Train: [1098/2931 (100%)]	Loss: 0.076335
# Epoch: 5/10. Train set: Average loss: 0.0765
# Epoch: 5/10. Validation set: Average loss: 0.0728
# Train: [0/2931 (0%)]	Loss: 0.089098
# Train: [1098/2931 (100%)]	Loss: 0.070053
# Epoch: 6/10. Train set: Average loss: 0.0701
# Epoch: 6/10. Validation set: Average loss: 0.0661
# Train: [0/2931 (0%)]	Loss: 0.156937
# Train: [1098/2931 (100%)]	Loss: 0.068756
# Epoch: 7/10. Train set: Average loss: 0.0690
# Epoch: 7/10. Validation set: Average loss: 0.0702
# Train: [0/2931 (0%)]	Loss: 0.081993
# Train: [1098/2931 (100%)]	Loss: 0.063912
# Epoch: 8/10. Train set: Average loss: 0.0640
# Epoch: 8/10. Validation set: Average loss: 0.0657
# Train: [0/2931 (0%)]	Loss: 0.153710
# Train: [1098/2931 (100%)]	Loss: 0.057893
# Epoch: 9/10. Train set: Average loss: 0.0582
# Epoch: 9/10. Validation set: Average loss: 0.0574
# Train: [0/2931 (0%)]	Loss: 0.050580
# Train: [1098/2931 (100%)]	Loss: 0.055698
# Epoch: 10/10. Train set: Average loss: 0.0557
# Epoch: 10/10. Validation set: Average loss: 0.0554
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.435787
# Train: [1098/2931 (100%)]	Loss: 0.106545
# Epoch: 1/10. Train set: Average loss: 0.1074
# Epoch: 1/10. Validation set: Average loss: 0.0848
# Train: [0/2931 (0%)]	Loss: 0.047480
# Train: [1098/2931 (100%)]	Loss: 0.077602
# Epoch: 2/10. Train set: Average loss: 0.0775
# Epoch: 2/10. Validation set: Average loss: 0.0776
# Train: [0/2931 (0%)]	Loss: 0.134606
# Train: [1098/2931 (100%)]	Loss: 0.079277
# Epoch: 3/10. Train set: Average loss: 0.0794
# Epoch: 3/10. Validation set: Average loss: 0.0826
# Train: [0/2931 (0%)]	Loss: 0.042393
# Train: [1098/2931 (100%)]	Loss: 0.074895
# Epoch: 4/10. Train set: Average loss: 0.0748
# Epoch: 4/10. Validation set: Average loss: 0.0764
# Train: [0/2931 (0%)]	Loss: 0.027726
# Train: [1098/2931 (100%)]	Loss: 0.075201
# Epoch: 5/10. Train set: Average loss: 0.0751
# Epoch: 5/10. Validation set: Average loss: 0.0735
# Train: [0/2931 (0%)]	Loss: 0.063865
# Train: [1098/2931 (100%)]	Loss: 0.069313
# Epoch: 6/10. Train set: Average loss: 0.0693
# Epoch: 6/10. Validation set: Average loss: 0.0696
# Train: [0/2931 (0%)]	Loss: 0.106785
# Train: [1098/2931 (100%)]	Loss: 0.074879
# Epoch: 7/10. Train set: Average loss: 0.0750
# Epoch: 7/10. Validation set: Average loss: 0.0676
# Train: [0/2931 (0%)]	Loss: 0.101598
# Train: [1098/2931 (100%)]	Loss: 0.066128
# Epoch: 8/10. Train set: Average loss: 0.0662
# Epoch: 8/10. Validation set: Average loss: 0.0646
# Train: [0/2931 (0%)]	Loss: 0.082648
# Train: [1098/2931 (100%)]	Loss: 0.058266
# Epoch: 9/10. Train set: Average loss: 0.0583
# Epoch: 9/10. Validation set: Average loss: 0.0536
# Train: [0/2931 (0%)]	Loss: 0.027965
# Train: [1098/2931 (100%)]	Loss: 0.053438
# Epoch: 10/10. Train set: Average loss: 0.0534
# Epoch: 10/10. Validation set: Average loss: 0.0503
# Batch 4
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.249626
# Train: [1098/2931 (100%)]	Loss: 0.125433
# Epoch: 1/10. Train set: Average loss: 0.1258
# Epoch: 1/10. Validation set: Average loss: 0.1657
# Train: [0/2931 (0%)]	Loss: 0.216009
# Train: [1098/2931 (100%)]	Loss: 0.104192
# Epoch: 2/10. Train set: Average loss: 0.1045
# Epoch: 2/10. Validation set: Average loss: 0.0896
# Train: [0/2931 (0%)]	Loss: 0.082103
# Train: [1098/2931 (100%)]	Loss: 0.101843
# Epoch: 3/10. Train set: Average loss: 0.1018
# Epoch: 3/10. Validation set: Average loss: 0.0944
# Train: [0/2931 (0%)]	Loss: 0.079524
# Train: [1098/2931 (100%)]	Loss: 0.099948
# Epoch: 4/10. Train set: Average loss: 0.0999
# Epoch: 4/10. Validation set: Average loss: 0.1161
# Train: [0/2931 (0%)]	Loss: 0.140057
# Train: [1098/2931 (100%)]	Loss: 0.089119
# Epoch: 5/10. Train set: Average loss: 0.0893
# Epoch: 5/10. Validation set: Average loss: 0.0835
# Train: [0/2931 (0%)]	Loss: 0.138476
# Train: [1098/2931 (100%)]	Loss: 0.080807
# Epoch: 6/10. Train set: Average loss: 0.0810
# Epoch: 6/10. Validation set: Average loss: 0.0822
# Train: [0/2931 (0%)]	Loss: 0.101386
# Train: [1098/2931 (100%)]	Loss: 0.078655
# Epoch: 7/10. Train set: Average loss: 0.0787
# Epoch: 7/10. Validation set: Average loss: 0.0807
# Train: [0/2931 (0%)]	Loss: 0.111559
# Train: [1098/2931 (100%)]	Loss: 0.072651
# Epoch: 8/10. Train set: Average loss: 0.0728
# Epoch: 8/10. Validation set: Average loss: 0.0829
# Train: [0/2931 (0%)]	Loss: 0.043330
# Train: [1098/2931 (100%)]	Loss: 0.069445
# Epoch: 9/10. Train set: Average loss: 0.0694
# Epoch: 9/10. Validation set: Average loss: 0.0733
# Train: [0/2931 (0%)]	Loss: 0.065709
# Train: [1098/2931 (100%)]	Loss: 0.065615
# Epoch: 10/10. Train set: Average loss: 0.0656
# Epoch: 10/10. Validation set: Average loss: 0.0706
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.124793
# Train: [1098/2931 (100%)]	Loss: 0.135937
# Epoch: 1/10. Train set: Average loss: 0.1359
# Epoch: 1/10. Validation set: Average loss: 0.1142
# Train: [0/2931 (0%)]	Loss: 0.085533
# Train: [1098/2931 (100%)]	Loss: 0.102776
# Epoch: 2/10. Train set: Average loss: 0.1027
# Epoch: 2/10. Validation set: Average loss: 0.0891
# Train: [0/2931 (0%)]	Loss: 0.042615
# Train: [1098/2931 (100%)]	Loss: 0.088878
# Epoch: 3/10. Train set: Average loss: 0.0888
# Epoch: 3/10. Validation set: Average loss: 0.0909
# Train: [0/2931 (0%)]	Loss: 0.115828
# Train: [1098/2931 (100%)]	Loss: 0.082265
# Epoch: 4/10. Train set: Average loss: 0.0824
# Epoch: 4/10. Validation set: Average loss: 0.0813
# Train: [0/2931 (0%)]	Loss: 0.060062
# Train: [1098/2931 (100%)]	Loss: 0.085543
# Epoch: 5/10. Train set: Average loss: 0.0855
# Epoch: 5/10. Validation set: Average loss: 0.0858
# Train: [0/2931 (0%)]	Loss: 0.090551
# Train: [1098/2931 (100%)]	Loss: 0.078744
# Epoch: 6/10. Train set: Average loss: 0.0788
# Epoch: 6/10. Validation set: Average loss: 0.0776
# Train: [0/2931 (0%)]	Loss: 0.044100
# Train: [1098/2931 (100%)]	Loss: 0.072163
# Epoch: 7/10. Train set: Average loss: 0.0721
# Epoch: 7/10. Validation set: Average loss: 0.0843
# Train: [0/2931 (0%)]	Loss: 0.050027
# Train: [1098/2931 (100%)]	Loss: 0.072842
# Epoch: 8/10. Train set: Average loss: 0.0728
# Epoch: 8/10. Validation set: Average loss: 0.0735
# Train: [0/2931 (0%)]	Loss: 0.061513
# Train: [1098/2931 (100%)]	Loss: 0.065817
# Epoch: 9/10. Train set: Average loss: 0.0658
# Epoch: 9/10. Validation set: Average loss: 0.0707
# Train: [0/2931 (0%)]	Loss: 0.034600
# Train: [1098/2931 (100%)]	Loss: 0.064226
# Epoch: 10/10. Train set: Average loss: 0.0641
# Epoch: 10/10. Validation set: Average loss: 0.0696
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.187255
# Train: [1098/2931 (100%)]	Loss: 0.118852
# Epoch: 1/10. Train set: Average loss: 0.1190
# Epoch: 1/10. Validation set: Average loss: 0.1184
# Train: [0/2931 (0%)]	Loss: 0.098478
# Train: [1098/2931 (100%)]	Loss: 0.101688
# Epoch: 2/10. Train set: Average loss: 0.1017
# Epoch: 2/10. Validation set: Average loss: 0.0931
# Train: [0/2931 (0%)]	Loss: 0.103568
# Train: [1098/2931 (100%)]	Loss: 0.088379
# Epoch: 3/10. Train set: Average loss: 0.0884
# Epoch: 3/10. Validation set: Average loss: 0.0916
# Train: [0/2931 (0%)]	Loss: 0.056896
# Train: [1098/2931 (100%)]	Loss: 0.081295
# Epoch: 4/10. Train set: Average loss: 0.0812
# Epoch: 4/10. Validation set: Average loss: 0.0902
# Train: [0/2931 (0%)]	Loss: 0.036372
# Train: [1098/2931 (100%)]	Loss: 0.081706
# Epoch: 5/10. Train set: Average loss: 0.0816
# Epoch: 5/10. Validation set: Average loss: 0.0969
# Train: [0/2931 (0%)]	Loss: 0.067337
# Train: [1098/2931 (100%)]	Loss: 0.082856
# Epoch: 6/10. Train set: Average loss: 0.0828
# Epoch: 6/10. Validation set: Average loss: 0.0833
# Train: [0/2931 (0%)]	Loss: 0.108295
# Train: [1098/2931 (100%)]	Loss: 0.069188
# Epoch: 7/10. Train set: Average loss: 0.0693
# Epoch: 7/10. Validation set: Average loss: 0.0955
# Train: [0/2931 (0%)]	Loss: 0.078502
# Train: [1098/2931 (100%)]	Loss: 0.072039
# Epoch: 8/10. Train set: Average loss: 0.0721
# Epoch: 8/10. Validation set: Average loss: 0.0711
# Train: [0/2931 (0%)]	Loss: 0.104273
# Train: [1098/2931 (100%)]	Loss: 0.056340
# Epoch: 9/10. Train set: Average loss: 0.0565
# Epoch: 9/10. Validation set: Average loss: 0.0624
# Train: [0/2931 (0%)]	Loss: 0.051211
# Train: [1098/2931 (100%)]	Loss: 0.052143
# Epoch: 10/10. Train set: Average loss: 0.0521
# Epoch: 10/10. Validation set: Average loss: 0.0620
# Batch 5
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.310502
# Train: [1098/2931 (100%)]	Loss: 0.123999
# Epoch: 1/10. Train set: Average loss: 0.1245
# Epoch: 1/10. Validation set: Average loss: 0.1375
# Train: [0/2931 (0%)]	Loss: 0.108975
# Train: [1098/2931 (100%)]	Loss: 0.110005
# Epoch: 2/10. Train set: Average loss: 0.1100
# Epoch: 2/10. Validation set: Average loss: 0.1087
# Train: [0/2931 (0%)]	Loss: 0.115041
# Train: [1098/2931 (100%)]	Loss: 0.092731
# Epoch: 3/10. Train set: Average loss: 0.0928
# Epoch: 3/10. Validation set: Average loss: 0.1029
# Train: [0/2931 (0%)]	Loss: 0.113619
# Train: [1098/2931 (100%)]	Loss: 0.075069
# Epoch: 4/10. Train set: Average loss: 0.0752
# Epoch: 4/10. Validation set: Average loss: 0.0747
# Train: [0/2931 (0%)]	Loss: 0.081652
# Train: [1098/2931 (100%)]	Loss: 0.066506
# Epoch: 5/10. Train set: Average loss: 0.0665
# Epoch: 5/10. Validation set: Average loss: 0.0750
# Train: [0/2931 (0%)]	Loss: 0.089502
# Train: [1098/2931 (100%)]	Loss: 0.056492
# Epoch: 6/10. Train set: Average loss: 0.0566
# Epoch: 6/10. Validation set: Average loss: 0.0677
# Train: [0/2931 (0%)]	Loss: 0.017408
# Train: [1098/2931 (100%)]	Loss: 0.053741
# Epoch: 7/10. Train set: Average loss: 0.0536
# Epoch: 7/10. Validation set: Average loss: 0.0620
# Train: [0/2931 (0%)]	Loss: 0.087052
# Train: [1098/2931 (100%)]	Loss: 0.044600
# Epoch: 8/10. Train set: Average loss: 0.0447
# Epoch: 8/10. Validation set: Average loss: 0.0559
# Train: [0/2931 (0%)]	Loss: 0.003538
# Train: [1098/2931 (100%)]	Loss: 0.036265
# Epoch: 9/10. Train set: Average loss: 0.0362
# Epoch: 9/10. Validation set: Average loss: 0.0504
# Train: [0/2931 (0%)]	Loss: 0.026817
# Train: [1098/2931 (100%)]	Loss: 0.034012
# Epoch: 10/10. Train set: Average loss: 0.0340
# Epoch: 10/10. Validation set: Average loss: 0.0494
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.186375
# Train: [1098/2931 (100%)]	Loss: 0.108131
# Epoch: 1/10. Train set: Average loss: 0.1083
# Epoch: 1/10. Validation set: Average loss: 0.0965
# Train: [0/2931 (0%)]	Loss: 0.074529
# Train: [1098/2931 (100%)]	Loss: 0.095968
# Epoch: 2/10. Train set: Average loss: 0.0959
# Epoch: 2/10. Validation set: Average loss: 0.0856
# Train: [0/2931 (0%)]	Loss: 0.173591
# Train: [1098/2931 (100%)]	Loss: 0.075967
# Epoch: 3/10. Train set: Average loss: 0.0762
# Epoch: 3/10. Validation set: Average loss: 0.0799
# Train: [0/2931 (0%)]	Loss: 0.097741
# Train: [1098/2931 (100%)]	Loss: 0.071193
# Epoch: 4/10. Train set: Average loss: 0.0713
# Epoch: 4/10. Validation set: Average loss: 0.0696
# Train: [0/2931 (0%)]	Loss: 0.037125
# Train: [1098/2931 (100%)]	Loss: 0.056902
# Epoch: 5/10. Train set: Average loss: 0.0568
# Epoch: 5/10. Validation set: Average loss: 0.0725
# Train: [0/2931 (0%)]	Loss: 0.040999
# Train: [1098/2931 (100%)]	Loss: 0.054853
# Epoch: 6/10. Train set: Average loss: 0.0548
# Epoch: 6/10. Validation set: Average loss: 0.0651
# Train: [0/2931 (0%)]	Loss: 0.054042
# Train: [1098/2931 (100%)]	Loss: 0.045191
# Epoch: 7/10. Train set: Average loss: 0.0452
# Epoch: 7/10. Validation set: Average loss: 0.0623
# Train: [0/2931 (0%)]	Loss: 0.056424
# Train: [1098/2931 (100%)]	Loss: 0.045525
# Epoch: 8/10. Train set: Average loss: 0.0456
# Epoch: 8/10. Validation set: Average loss: 0.0560
# Train: [0/2931 (0%)]	Loss: 0.013404
# Train: [1098/2931 (100%)]	Loss: 0.034598
# Epoch: 9/10. Train set: Average loss: 0.0345
# Epoch: 9/10. Validation set: Average loss: 0.0485
# Train: [0/2931 (0%)]	Loss: 0.056222
# Train: [1098/2931 (100%)]	Loss: 0.032252
# Epoch: 10/10. Train set: Average loss: 0.0323
# Epoch: 10/10. Validation set: Average loss: 0.0483
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.248886
# Train: [1098/2931 (100%)]	Loss: 0.110911
# Epoch: 1/10. Train set: Average loss: 0.1113
# Epoch: 1/10. Validation set: Average loss: 0.0889
# Train: [0/2931 (0%)]	Loss: 0.074674
# Train: [1098/2931 (100%)]	Loss: 0.082593
# Epoch: 2/10. Train set: Average loss: 0.0826
# Epoch: 2/10. Validation set: Average loss: 0.0813
# Train: [0/2931 (0%)]	Loss: 0.080267
# Train: [1098/2931 (100%)]	Loss: 0.071125
# Epoch: 3/10. Train set: Average loss: 0.0711
# Epoch: 3/10. Validation set: Average loss: 0.0694
# Train: [0/2931 (0%)]	Loss: 0.055110
# Train: [1098/2931 (100%)]	Loss: 0.060227
# Epoch: 4/10. Train set: Average loss: 0.0602
# Epoch: 4/10. Validation set: Average loss: 0.0642
# Train: [0/2931 (0%)]	Loss: 0.039236
# Train: [1098/2931 (100%)]	Loss: 0.057467
# Epoch: 5/10. Train set: Average loss: 0.0574
# Epoch: 5/10. Validation set: Average loss: 0.0643
# Train: [0/2931 (0%)]	Loss: 0.022873
# Train: [1098/2931 (100%)]	Loss: 0.054501
# Epoch: 6/10. Train set: Average loss: 0.0544
# Epoch: 6/10. Validation set: Average loss: 0.0618
# Train: [0/2931 (0%)]	Loss: 0.049122
# Train: [1098/2931 (100%)]	Loss: 0.046989
# Epoch: 7/10. Train set: Average loss: 0.0470
# Epoch: 7/10. Validation set: Average loss: 0.0568
# Train: [0/2931 (0%)]	Loss: 0.023682
# Train: [1098/2931 (100%)]	Loss: 0.041823
# Epoch: 8/10. Train set: Average loss: 0.0418
# Epoch: 8/10. Validation set: Average loss: 0.0554
# Train: [0/2931 (0%)]	Loss: 0.022695
# Train: [1098/2931 (100%)]	Loss: 0.037526
# Epoch: 9/10. Train set: Average loss: 0.0375
# Epoch: 9/10. Validation set: Average loss: 0.0458
# Train: [0/2931 (0%)]	Loss: 0.003119
# Train: [1098/2931 (100%)]	Loss: 0.034211
# Epoch: 10/10. Train set: Average loss: 0.0341
# Epoch: 10/10. Validation set: Average loss: 0.0458
# Batch 6
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.312084
# Train: [1098/2931 (100%)]	Loss: 0.102976
# Epoch: 1/10. Train set: Average loss: 0.1035
# Epoch: 1/10. Validation set: Average loss: 0.0992
# Train: [0/2931 (0%)]	Loss: 0.089468
# Train: [1098/2931 (100%)]	Loss: 0.086111
# Epoch: 2/10. Train set: Average loss: 0.0861
# Epoch: 2/10. Validation set: Average loss: 0.0918
# Train: [0/2931 (0%)]	Loss: 0.129983
# Train: [1098/2931 (100%)]	Loss: 0.084429
# Epoch: 3/10. Train set: Average loss: 0.0846
# Epoch: 3/10. Validation set: Average loss: 0.0976
# Train: [0/2931 (0%)]	Loss: 0.041573
# Train: [1098/2931 (100%)]	Loss: 0.081696
# Epoch: 4/10. Train set: Average loss: 0.0816
# Epoch: 4/10. Validation set: Average loss: 0.0914
# Train: [0/2931 (0%)]	Loss: 0.082141
# Train: [1098/2931 (100%)]	Loss: 0.075295
# Epoch: 5/10. Train set: Average loss: 0.0753
# Epoch: 5/10. Validation set: Average loss: 0.0854
# Train: [0/2931 (0%)]	Loss: 0.054721
# Train: [1098/2931 (100%)]	Loss: 0.070679
# Epoch: 6/10. Train set: Average loss: 0.0706
# Epoch: 6/10. Validation set: Average loss: 0.0796
# Train: [0/2931 (0%)]	Loss: 0.112734
# Train: [1098/2931 (100%)]	Loss: 0.069238
# Epoch: 7/10. Train set: Average loss: 0.0694
# Epoch: 7/10. Validation set: Average loss: 0.0764
# Train: [0/2931 (0%)]	Loss: 0.097425
# Train: [1098/2931 (100%)]	Loss: 0.069133
# Epoch: 8/10. Train set: Average loss: 0.0692
# Epoch: 8/10. Validation set: Average loss: 0.0779
# Train: [0/2931 (0%)]	Loss: 0.116619
# Train: [1098/2931 (100%)]	Loss: 0.059469
# Epoch: 9/10. Train set: Average loss: 0.0596
# Epoch: 9/10. Validation set: Average loss: 0.0687
# Train: [0/2931 (0%)]	Loss: 0.041699
# Train: [1098/2931 (100%)]	Loss: 0.058063
# Epoch: 10/10. Train set: Average loss: 0.0580
# Epoch: 10/10. Validation set: Average loss: 0.0678
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.310604
# Train: [1098/2931 (100%)]	Loss: 0.119300
# Epoch: 1/10. Train set: Average loss: 0.1198
# Epoch: 1/10. Validation set: Average loss: 0.1156
# Train: [0/2931 (0%)]	Loss: 0.150718
# Train: [1098/2931 (100%)]	Loss: 0.107967
# Epoch: 2/10. Train set: Average loss: 0.1081
# Epoch: 2/10. Validation set: Average loss: 0.1184
# Train: [0/2931 (0%)]	Loss: 0.106735
# Train: [1098/2931 (100%)]	Loss: 0.106274
# Epoch: 3/10. Train set: Average loss: 0.1063
# Epoch: 3/10. Validation set: Average loss: 0.1142
# Train: [0/2931 (0%)]	Loss: 0.060531
# Train: [1098/2931 (100%)]	Loss: 0.104353
# Epoch: 4/10. Train set: Average loss: 0.1042
# Epoch: 4/10. Validation set: Average loss: 0.1174
# Train: [0/2931 (0%)]	Loss: 0.074862
# Train: [1098/2931 (100%)]	Loss: 0.108393
# Epoch: 5/10. Train set: Average loss: 0.1083
# Epoch: 5/10. Validation set: Average loss: 0.1057
# Train: [0/2931 (0%)]	Loss: 0.143710
# Train: [1098/2931 (100%)]	Loss: 0.086220
# Epoch: 6/10. Train set: Average loss: 0.0864
# Epoch: 6/10. Validation set: Average loss: 0.0904
# Train: [0/2931 (0%)]	Loss: 0.103600
# Train: [1098/2931 (100%)]	Loss: 0.084234
# Epoch: 7/10. Train set: Average loss: 0.0843
# Epoch: 7/10. Validation set: Average loss: 0.0875
# Train: [0/2931 (0%)]	Loss: 0.132978
# Train: [1098/2931 (100%)]	Loss: 0.080704
# Epoch: 8/10. Train set: Average loss: 0.0808
# Epoch: 8/10. Validation set: Average loss: 0.0827
# Train: [0/2931 (0%)]	Loss: 0.086131
# Train: [1098/2931 (100%)]	Loss: 0.070702
# Epoch: 9/10. Train set: Average loss: 0.0707
# Epoch: 9/10. Validation set: Average loss: 0.0784
# Train: [0/2931 (0%)]	Loss: 0.057325
# Train: [1098/2931 (100%)]	Loss: 0.071436
# Epoch: 10/10. Train set: Average loss: 0.0714
# Epoch: 10/10. Validation set: Average loss: 0.0759
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.373750
# Train: [1098/2931 (100%)]	Loss: 0.119274
# Epoch: 1/10. Train set: Average loss: 0.1200
# Epoch: 1/10. Validation set: Average loss: 0.1233
# Train: [0/2931 (0%)]	Loss: 0.074710
# Train: [1098/2931 (100%)]	Loss: 0.097055
# Epoch: 2/10. Train set: Average loss: 0.0970
# Epoch: 2/10. Validation set: Average loss: 0.0975
# Train: [0/2931 (0%)]	Loss: 0.063278
# Train: [1098/2931 (100%)]	Loss: 0.080349
# Epoch: 3/10. Train set: Average loss: 0.0803
# Epoch: 3/10. Validation set: Average loss: 0.0958
# Train: [0/2931 (0%)]	Loss: 0.069992
# Train: [1098/2931 (100%)]	Loss: 0.075295
# Epoch: 4/10. Train set: Average loss: 0.0753
# Epoch: 4/10. Validation set: Average loss: 0.0817
# Train: [0/2931 (0%)]	Loss: 0.117054
# Train: [1098/2931 (100%)]	Loss: 0.075082
# Epoch: 5/10. Train set: Average loss: 0.0752
# Epoch: 5/10. Validation set: Average loss: 0.0807
# Train: [0/2931 (0%)]	Loss: 0.152785
# Train: [1098/2931 (100%)]	Loss: 0.073263
# Epoch: 6/10. Train set: Average loss: 0.0735
# Epoch: 6/10. Validation set: Average loss: 0.0789
# Train: [0/2931 (0%)]	Loss: 0.098122
# Train: [1098/2931 (100%)]	Loss: 0.071297
# Epoch: 7/10. Train set: Average loss: 0.0714
# Epoch: 7/10. Validation set: Average loss: 0.0760
# Train: [0/2931 (0%)]	Loss: 0.025996
# Train: [1098/2931 (100%)]	Loss: 0.068171
# Epoch: 8/10. Train set: Average loss: 0.0681
# Epoch: 8/10. Validation set: Average loss: 0.0927
# Train: [0/2931 (0%)]	Loss: 0.100652
# Train: [1098/2931 (100%)]	Loss: 0.063719
# Epoch: 9/10. Train set: Average loss: 0.0638
# Epoch: 9/10. Validation set: Average loss: 0.0667
# Train: [0/2931 (0%)]	Loss: 0.028783
# Train: [1098/2931 (100%)]	Loss: 0.054513
# Epoch: 10/10. Train set: Average loss: 0.0544
# Epoch: 10/10. Validation set: Average loss: 0.0647
# Batch 7
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.311940
# Train: [1098/2931 (100%)]	Loss: 0.112622
# Epoch: 1/10. Train set: Average loss: 0.1132
# Epoch: 1/10. Validation set: Average loss: 0.0951
# Train: [0/2931 (0%)]	Loss: 0.092594
# Train: [1098/2931 (100%)]	Loss: 0.079531
# Epoch: 2/10. Train set: Average loss: 0.0796
# Epoch: 2/10. Validation set: Average loss: 0.0793
# Train: [0/2931 (0%)]	Loss: 0.058228
# Train: [1098/2931 (100%)]	Loss: 0.073310
# Epoch: 3/10. Train set: Average loss: 0.0733
# Epoch: 3/10. Validation set: Average loss: 0.0949
# Train: [0/2931 (0%)]	Loss: 0.066939
# Train: [1098/2931 (100%)]	Loss: 0.067816
# Epoch: 4/10. Train set: Average loss: 0.0678
# Epoch: 4/10. Validation set: Average loss: 0.0710
# Train: [0/2931 (0%)]	Loss: 0.026615
# Train: [1098/2931 (100%)]	Loss: 0.056130
# Epoch: 5/10. Train set: Average loss: 0.0560
# Epoch: 5/10. Validation set: Average loss: 0.0583
# Train: [0/2931 (0%)]	Loss: 0.097467
# Train: [1098/2931 (100%)]	Loss: 0.054681
# Epoch: 6/10. Train set: Average loss: 0.0548
# Epoch: 6/10. Validation set: Average loss: 0.0555
# Train: [0/2931 (0%)]	Loss: 0.017042
# Train: [1098/2931 (100%)]	Loss: 0.052172
# Epoch: 7/10. Train set: Average loss: 0.0521
# Epoch: 7/10. Validation set: Average loss: 0.0505
# Train: [0/2931 (0%)]	Loss: 0.024594
# Train: [1098/2931 (100%)]	Loss: 0.048338
# Epoch: 8/10. Train set: Average loss: 0.0483
# Epoch: 8/10. Validation set: Average loss: 0.0487
# Train: [0/2931 (0%)]	Loss: 0.009227
# Train: [1098/2931 (100%)]	Loss: 0.039567
# Epoch: 9/10. Train set: Average loss: 0.0395
# Epoch: 9/10. Validation set: Average loss: 0.0371
# Train: [0/2931 (0%)]	Loss: 0.030587
# Train: [1098/2931 (100%)]	Loss: 0.036640
# Epoch: 10/10. Train set: Average loss: 0.0366
# Epoch: 10/10. Validation set: Average loss: 0.0337
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249497
# Train: [1098/2931 (100%)]	Loss: 0.103449
# Epoch: 1/10. Train set: Average loss: 0.1038
# Epoch: 1/10. Validation set: Average loss: 0.0888
# Train: [0/2931 (0%)]	Loss: 0.068712
# Train: [1098/2931 (100%)]	Loss: 0.080209
# Epoch: 2/10. Train set: Average loss: 0.0802
# Epoch: 2/10. Validation set: Average loss: 0.0887
# Train: [0/2931 (0%)]	Loss: 0.059041
# Train: [1098/2931 (100%)]	Loss: 0.078463
# Epoch: 3/10. Train set: Average loss: 0.0784
# Epoch: 3/10. Validation set: Average loss: 0.0813
# Train: [0/2931 (0%)]	Loss: 0.074544
# Train: [1098/2931 (100%)]	Loss: 0.069066
# Epoch: 4/10. Train set: Average loss: 0.0691
# Epoch: 4/10. Validation set: Average loss: 0.0732
# Train: [0/2931 (0%)]	Loss: 0.094176
# Train: [1098/2931 (100%)]	Loss: 0.066530
# Epoch: 5/10. Train set: Average loss: 0.0666
# Epoch: 5/10. Validation set: Average loss: 0.0661
# Train: [0/2931 (0%)]	Loss: 0.065263
# Train: [1098/2931 (100%)]	Loss: 0.063872
# Epoch: 6/10. Train set: Average loss: 0.0639
# Epoch: 6/10. Validation set: Average loss: 0.0655
# Train: [0/2931 (0%)]	Loss: 0.136279
# Train: [1098/2931 (100%)]	Loss: 0.057583
# Epoch: 7/10. Train set: Average loss: 0.0578
# Epoch: 7/10. Validation set: Average loss: 0.0680
# Train: [0/2931 (0%)]	Loss: 0.039450
# Train: [1098/2931 (100%)]	Loss: 0.055738
# Epoch: 8/10. Train set: Average loss: 0.0557
# Epoch: 8/10. Validation set: Average loss: 0.0571
# Train: [0/2931 (0%)]	Loss: 0.061452
# Train: [1098/2931 (100%)]	Loss: 0.047970
# Epoch: 9/10. Train set: Average loss: 0.0480
# Epoch: 9/10. Validation set: Average loss: 0.0476
# Train: [0/2931 (0%)]	Loss: 0.043025
# Train: [1098/2931 (100%)]	Loss: 0.042054
# Epoch: 10/10. Train set: Average loss: 0.0421
# Epoch: 10/10. Validation set: Average loss: 0.0430
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.248885
# Train: [1098/2931 (100%)]	Loss: 0.104286
# Epoch: 1/10. Train set: Average loss: 0.1047
# Epoch: 1/10. Validation set: Average loss: 0.1012
# Train: [0/2931 (0%)]	Loss: 0.140885
# Train: [1098/2931 (100%)]	Loss: 0.096582
# Epoch: 2/10. Train set: Average loss: 0.0967
# Epoch: 2/10. Validation set: Average loss: 0.0814
# Train: [0/2931 (0%)]	Loss: 0.053117
# Train: [1098/2931 (100%)]	Loss: 0.080200
# Epoch: 3/10. Train set: Average loss: 0.0801
# Epoch: 3/10. Validation set: Average loss: 0.0731
# Train: [0/2931 (0%)]	Loss: 0.066088
# Train: [1098/2931 (100%)]	Loss: 0.065784
# Epoch: 4/10. Train set: Average loss: 0.0658
# Epoch: 4/10. Validation set: Average loss: 0.0686
# Train: [0/2931 (0%)]	Loss: 0.099881
# Train: [1098/2931 (100%)]	Loss: 0.062182
# Epoch: 5/10. Train set: Average loss: 0.0623
# Epoch: 5/10. Validation set: Average loss: 0.0624
# Train: [0/2931 (0%)]	Loss: 0.052376
# Train: [1098/2931 (100%)]	Loss: 0.061491
# Epoch: 6/10. Train set: Average loss: 0.0615
# Epoch: 6/10. Validation set: Average loss: 0.0598
# Train: [0/2931 (0%)]	Loss: 0.053548
# Train: [1098/2931 (100%)]	Loss: 0.056901
# Epoch: 7/10. Train set: Average loss: 0.0569
# Epoch: 7/10. Validation set: Average loss: 0.0648
# Train: [0/2931 (0%)]	Loss: 0.075690
# Train: [1098/2931 (100%)]	Loss: 0.053455
# Epoch: 8/10. Train set: Average loss: 0.0535
# Epoch: 8/10. Validation set: Average loss: 0.0524
# Train: [0/2931 (0%)]	Loss: 0.088382
# Train: [1098/2931 (100%)]	Loss: 0.043926
# Epoch: 9/10. Train set: Average loss: 0.0440
# Epoch: 9/10. Validation set: Average loss: 0.0417
# Train: [0/2931 (0%)]	Loss: 0.051418
# Train: [1098/2931 (100%)]	Loss: 0.037405
# Epoch: 10/10. Train set: Average loss: 0.0374
# Epoch: 10/10. Validation set: Average loss: 0.0393
# Batch 8
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.124797
# Train: [1098/2931 (100%)]	Loss: 0.078618
# Epoch: 1/10. Train set: Average loss: 0.0787
# Epoch: 1/10. Validation set: Average loss: 0.0806
# Train: [0/2931 (0%)]	Loss: 0.208234
# Train: [1098/2931 (100%)]	Loss: 0.060161
# Epoch: 2/10. Train set: Average loss: 0.0606
# Epoch: 2/10. Validation set: Average loss: 0.0711
# Train: [0/2931 (0%)]	Loss: 0.095601
# Train: [1098/2931 (100%)]	Loss: 0.053791
# Epoch: 3/10. Train set: Average loss: 0.0539
# Epoch: 3/10. Validation set: Average loss: 0.0856
# Train: [0/2931 (0%)]	Loss: 0.061421
# Train: [1098/2931 (100%)]	Loss: 0.048182
# Epoch: 4/10. Train set: Average loss: 0.0482
# Epoch: 4/10. Validation set: Average loss: 0.0572
# Train: [0/2931 (0%)]	Loss: 0.046049
# Train: [1098/2931 (100%)]	Loss: 0.043225
# Epoch: 5/10. Train set: Average loss: 0.0432
# Epoch: 5/10. Validation set: Average loss: 0.0584
# Train: [0/2931 (0%)]	Loss: 0.028695
# Train: [1098/2931 (100%)]	Loss: 0.046673
# Epoch: 6/10. Train set: Average loss: 0.0466
# Epoch: 6/10. Validation set: Average loss: 0.0543
# Train: [0/2931 (0%)]	Loss: 0.060986
# Train: [1098/2931 (100%)]	Loss: 0.039602
# Epoch: 7/10. Train set: Average loss: 0.0397
# Epoch: 7/10. Validation set: Average loss: 0.0485
# Train: [0/2931 (0%)]	Loss: 0.020335
# Train: [1098/2931 (100%)]	Loss: 0.041317
# Epoch: 8/10. Train set: Average loss: 0.0413
# Epoch: 8/10. Validation set: Average loss: 0.0545
# Train: [0/2931 (0%)]	Loss: 0.152685
# Train: [1098/2931 (100%)]	Loss: 0.033976
# Epoch: 9/10. Train set: Average loss: 0.0343
# Epoch: 9/10. Validation set: Average loss: 0.0424
# Train: [0/2931 (0%)]	Loss: 0.021023
# Train: [1098/2931 (100%)]	Loss: 0.032351
# Epoch: 10/10. Train set: Average loss: 0.0323
# Epoch: 10/10. Validation set: Average loss: 0.0413
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.187028
# Train: [1098/2931 (100%)]	Loss: 0.080925
# Epoch: 1/10. Train set: Average loss: 0.0812
# Epoch: 1/10. Validation set: Average loss: 0.0757
# Train: [0/2931 (0%)]	Loss: 0.038603
# Train: [1098/2931 (100%)]	Loss: 0.051245
# Epoch: 2/10. Train set: Average loss: 0.0512
# Epoch: 2/10. Validation set: Average loss: 0.1187
# Train: [0/2931 (0%)]	Loss: 0.051504
# Train: [1098/2931 (100%)]	Loss: 0.048412
# Epoch: 3/10. Train set: Average loss: 0.0484
# Epoch: 3/10. Validation set: Average loss: 0.1174
# Train: [0/2931 (0%)]	Loss: 0.058969
# Train: [1098/2931 (100%)]	Loss: 0.047357
# Epoch: 4/10. Train set: Average loss: 0.0474
# Epoch: 4/10. Validation set: Average loss: 0.0489
# Train: [0/2931 (0%)]	Loss: 0.080425
# Train: [1098/2931 (100%)]	Loss: 0.043051
# Epoch: 5/10. Train set: Average loss: 0.0432
# Epoch: 5/10. Validation set: Average loss: 0.0608
# Train: [0/2931 (0%)]	Loss: 0.010487
# Train: [1098/2931 (100%)]	Loss: 0.038271
# Epoch: 6/10. Train set: Average loss: 0.0382
# Epoch: 6/10. Validation set: Average loss: 0.0515
# Train: [0/2931 (0%)]	Loss: 0.033148
# Train: [1098/2931 (100%)]	Loss: 0.036975
# Epoch: 7/10. Train set: Average loss: 0.0370
# Epoch: 7/10. Validation set: Average loss: 0.0442
# Train: [0/2931 (0%)]	Loss: 0.033137
# Train: [1098/2931 (100%)]	Loss: 0.037202
# Epoch: 8/10. Train set: Average loss: 0.0372
# Epoch: 8/10. Validation set: Average loss: 0.0468
# Train: [0/2931 (0%)]	Loss: 0.045471
# Train: [1098/2931 (100%)]	Loss: 0.032030
# Epoch: 9/10. Train set: Average loss: 0.0321
# Epoch: 9/10. Validation set: Average loss: 0.0362
# Train: [0/2931 (0%)]	Loss: 0.018947
# Train: [1098/2931 (100%)]	Loss: 0.029012
# Epoch: 10/10. Train set: Average loss: 0.0290
# Epoch: 10/10. Validation set: Average loss: 0.0371
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.373993
# Train: [1098/2931 (100%)]	Loss: 0.082442
# Epoch: 1/10. Train set: Average loss: 0.0832
# Epoch: 1/10. Validation set: Average loss: 0.0670
# Train: [0/2931 (0%)]	Loss: 0.071874
# Train: [1098/2931 (100%)]	Loss: 0.061697
# Epoch: 2/10. Train set: Average loss: 0.0617
# Epoch: 2/10. Validation set: Average loss: 0.0667
# Train: [0/2931 (0%)]	Loss: 0.032524
# Train: [1098/2931 (100%)]	Loss: 0.058937
# Epoch: 3/10. Train set: Average loss: 0.0589
# Epoch: 3/10. Validation set: Average loss: 0.0651
# Train: [0/2931 (0%)]	Loss: 0.011461
# Train: [1098/2931 (100%)]	Loss: 0.056098
# Epoch: 4/10. Train set: Average loss: 0.0560
# Epoch: 4/10. Validation set: Average loss: 0.0667
# Train: [0/2931 (0%)]	Loss: 0.087181
# Train: [1098/2931 (100%)]	Loss: 0.043949
# Epoch: 5/10. Train set: Average loss: 0.0441
# Epoch: 5/10. Validation set: Average loss: 0.0515
# Train: [0/2931 (0%)]	Loss: 0.017729
# Train: [1098/2931 (100%)]	Loss: 0.042642
# Epoch: 6/10. Train set: Average loss: 0.0426
# Epoch: 6/10. Validation set: Average loss: 0.0566
# Train: [0/2931 (0%)]	Loss: 0.031519
# Train: [1098/2931 (100%)]	Loss: 0.039434
# Epoch: 7/10. Train set: Average loss: 0.0394
# Epoch: 7/10. Validation set: Average loss: 0.0590
# Train: [0/2931 (0%)]	Loss: 0.027623
# Train: [1098/2931 (100%)]	Loss: 0.040596
# Epoch: 8/10. Train set: Average loss: 0.0406
# Epoch: 8/10. Validation set: Average loss: 0.0532
# Train: [0/2931 (0%)]	Loss: 0.027259
# Train: [1098/2931 (100%)]	Loss: 0.032253
# Epoch: 9/10. Train set: Average loss: 0.0322
# Epoch: 9/10. Validation set: Average loss: 0.0411
# Train: [0/2931 (0%)]	Loss: 0.044215
# Train: [1098/2931 (100%)]	Loss: 0.026789
# Epoch: 10/10. Train set: Average loss: 0.0268
# Epoch: 10/10. Validation set: Average loss: 0.0386
# Batch 9
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.062365
# Train: [1098/2931 (100%)]	Loss: 0.096097
# Epoch: 1/10. Train set: Average loss: 0.0960
# Epoch: 1/10. Validation set: Average loss: 0.0667
# Train: [0/2931 (0%)]	Loss: 0.065644
# Train: [1098/2931 (100%)]	Loss: 0.077622
# Epoch: 2/10. Train set: Average loss: 0.0776
# Epoch: 2/10. Validation set: Average loss: 0.0683
# Train: [0/2931 (0%)]	Loss: 0.119335
# Train: [1098/2931 (100%)]	Loss: 0.075733
# Epoch: 3/10. Train set: Average loss: 0.0759
# Epoch: 3/10. Validation set: Average loss: 0.0785
# Train: [0/2931 (0%)]	Loss: 0.036304
# Train: [1098/2931 (100%)]	Loss: 0.067002
# Epoch: 4/10. Train set: Average loss: 0.0669
# Epoch: 4/10. Validation set: Average loss: 0.0665
# Train: [0/2931 (0%)]	Loss: 0.032566
# Train: [1098/2931 (100%)]	Loss: 0.056786
# Epoch: 5/10. Train set: Average loss: 0.0567
# Epoch: 5/10. Validation set: Average loss: 0.0574
# Train: [0/2931 (0%)]	Loss: 0.019992
# Train: [1098/2931 (100%)]	Loss: 0.056732
# Epoch: 6/10. Train set: Average loss: 0.0566
# Epoch: 6/10. Validation set: Average loss: 0.0583
# Train: [0/2931 (0%)]	Loss: 0.115160
# Train: [1098/2931 (100%)]	Loss: 0.052895
# Epoch: 7/10. Train set: Average loss: 0.0531
# ...
# Train: [1098/2931 (100%)]	Loss: 0.050121
# Epoch: 3/10. Train set: Average loss: 0.0502
# Epoch: 3/10. Validation set: Average loss: 0.0522
# Train: [0/2931 (0%)]	Loss: 0.007785
# Train: [1098/2931 (100%)]	Loss: 0.043404
# Epoch: 4/10. Train set: Average loss: 0.0433
# Epoch: 4/10. Validation set: Average loss: 0.0487
# Train: [0/2931 (0%)]	Loss: 0.019499
# Train: [1098/2931 (100%)]	Loss: 0.039162
# Epoch: 5/10. Train set: Average loss: 0.0391
# Epoch: 5/10. Validation set: Average loss: 0.0469
# Train: [0/2931 (0%)]	Loss: 0.007082
# Train: [1098/2931 (100%)]	Loss: 0.033531
# Epoch: 6/10. Train set: Average loss: 0.0335
# Epoch: 6/10. Validation set: Average loss: 0.0491
# Train: [0/2931 (0%)]	Loss: 0.173839
# Train: [1098/2931 (100%)]	Loss: 0.033649
# Epoch: 7/10. Train set: Average loss: 0.0340
# Epoch: 7/10. Validation set: Average loss: 0.0465
# Train: [0/2931 (0%)]	Loss: 0.022221
# Train: [1098/2931 (100%)]	Loss: 0.029994
# Epoch: 8/10. Train set: Average loss: 0.0300
# Epoch: 8/10. Validation set: Average loss: 0.0419
# Train: [0/2931 (0%)]	Loss: 0.012109
# Train: [1098/2931 (100%)]	Loss: 0.023290
# Epoch: 9/10. Train set: Average loss: 0.0233
# Epoch: 9/10. Validation set: Average loss: 0.0373
# Train: [0/2931 (0%)]	Loss: 0.004379
# Train: [1098/2931 (100%)]	Loss: 0.022803
# Epoch: 10/10. Train set: Average loss: 0.0228
# Epoch: 10/10. Validation set: Average loss: 0.0361
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.498718
# Train: [1098/2931 (100%)]	Loss: 0.073106
# Epoch: 1/10. Train set: Average loss: 0.0743
# Epoch: 1/10. Validation set: Average loss: 0.0570
# Train: [0/2931 (0%)]	Loss: 0.100781
# Train: [1098/2931 (100%)]	Loss: 0.059207
# Epoch: 2/10. Train set: Average loss: 0.0593
# Epoch: 2/10. Validation set: Average loss: 0.0517
# Train: [0/2931 (0%)]	Loss: 0.084038
# Train: [1098/2931 (100%)]	Loss: 0.047681
# Epoch: 3/10. Train set: Average loss: 0.0478
# Epoch: 3/10. Validation set: Average loss: 0.0495
# Train: [0/2931 (0%)]	Loss: 0.013374
# Train: [1098/2931 (100%)]	Loss: 0.042647
# Epoch: 4/10. Train set: Average loss: 0.0426
# Epoch: 4/10. Validation set: Average loss: 0.0466
# Train: [0/2931 (0%)]	Loss: 0.042876
# Train: [1098/2931 (100%)]	Loss: 0.037102
# Epoch: 5/10. Train set: Average loss: 0.0371
# Epoch: 5/10. Validation set: Average loss: 0.0655
# Train: [0/2931 (0%)]	Loss: 0.025929
# Train: [1098/2931 (100%)]	Loss: 0.032270
# Epoch: 6/10. Train set: Average loss: 0.0323
# Epoch: 6/10. Validation set: Average loss: 0.0379
# Train: [0/2931 (0%)]	Loss: 0.013421
# Train: [1098/2931 (100%)]	Loss: 0.031392
# Epoch: 7/10. Train set: Average loss: 0.0313
# Epoch: 7/10. Validation set: Average loss: 0.0566
# Train: [0/2931 (0%)]	Loss: 0.000007
# Train: [1098/2931 (100%)]	Loss: 0.029175
# Epoch: 8/10. Train set: Average loss: 0.0291
# Epoch: 8/10. Validation set: Average loss: 0.0470
# Train: [0/2931 (0%)]	Loss: 0.015009
# Train: [1098/2931 (100%)]	Loss: 0.021863
# Epoch: 9/10. Train set: Average loss: 0.0218
# Epoch: 9/10. Validation set: Average loss: 0.0363
# Train: [0/2931 (0%)]	Loss: 0.000000
# Train: [1098/2931 (100%)]	Loss: 0.021074
# Epoch: 10/10. Train set: Average loss: 0.0210
# Epoch: 10/10. Validation set: Average loss: 0.0347
# Batch 27
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.062485
# Train: [1098/2931 (100%)]	Loss: 0.089157
# Epoch: 1/10. Train set: Average loss: 0.0891
# Epoch: 1/10. Validation set: Average loss: 0.0856
# Train: [0/2931 (0%)]	Loss: 0.045121
# Train: [1098/2931 (100%)]	Loss: 0.057698
# Epoch: 2/10. Train set: Average loss: 0.0577
# Epoch: 2/10. Validation set: Average loss: 0.0638
# Train: [0/2931 (0%)]	Loss: 0.035170
# Train: [1098/2931 (100%)]	Loss: 0.049063
# Epoch: 3/10. Train set: Average loss: 0.0490
# Epoch: 3/10. Validation set: Average loss: 0.0550
# Train: [0/2931 (0%)]	Loss: 0.036238
# Train: [1098/2931 (100%)]	Loss: 0.044914
# Epoch: 4/10. Train set: Average loss: 0.0449
# Epoch: 4/10. Validation set: Average loss: 0.0525
# Train: [0/2931 (0%)]	Loss: 0.050124
# Train: [1098/2931 (100%)]	Loss: 0.040139
# Epoch: 5/10. Train set: Average loss: 0.0402
# Epoch: 5/10. Validation set: Average loss: 0.0468
# Train: [0/2931 (0%)]	Loss: 0.041060
# Train: [1098/2931 (100%)]	Loss: 0.038014
# Epoch: 6/10. Train set: Average loss: 0.0380
# Epoch: 6/10. Validation set: Average loss: 0.0446
# Train: [0/2931 (0%)]	Loss: 0.034615
# Train: [1098/2931 (100%)]	Loss: 0.050051
# Epoch: 7/10. Train set: Average loss: 0.0500
# Epoch: 7/10. Validation set: Average loss: 0.0571
# Train: [0/2931 (0%)]	Loss: 0.018539
# Train: [1098/2931 (100%)]	Loss: 0.039017
# Epoch: 8/10. Train set: Average loss: 0.0390
# Epoch: 8/10. Validation set: Average loss: 0.0408
# Train: [0/2931 (0%)]	Loss: 0.049737
# Train: [1098/2931 (100%)]	Loss: 0.029913
# Epoch: 9/10. Train set: Average loss: 0.0300
# Epoch: 9/10. Validation set: Average loss: 0.0330
# Train: [0/2931 (0%)]	Loss: 0.062403
# Train: [1098/2931 (100%)]	Loss: 0.026203
# Epoch: 10/10. Train set: Average loss: 0.0263
# Epoch: 10/10. Validation set: Average loss: 0.0308
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.311791
# Train: [1098/2931 (100%)]	Loss: 0.076595
# Epoch: 1/10. Train set: Average loss: 0.0772
# Epoch: 1/10. Validation set: Average loss: 0.0561
# Train: [0/2931 (0%)]	Loss: 0.104909
# Train: [1098/2931 (100%)]	Loss: 0.052447
# Epoch: 2/10. Train set: Average loss: 0.0526
# Epoch: 2/10. Validation set: Average loss: 0.0515
# Train: [0/2931 (0%)]	Loss: 0.090852
# Train: [1098/2931 (100%)]	Loss: 0.048126
# Epoch: 3/10. Train set: Average loss: 0.0482
# Epoch: 3/10. Validation set: Average loss: 0.0873
# Train: [0/2931 (0%)]	Loss: 0.143622
# Train: [1098/2931 (100%)]	Loss: 0.051461
# Epoch: 4/10. Train set: Average loss: 0.0517
# Epoch: 4/10. Validation set: Average loss: 0.0579
# Train: [0/2931 (0%)]	Loss: 0.032376
# Train: [1098/2931 (100%)]	Loss: 0.040963
# Epoch: 5/10. Train set: Average loss: 0.0409
# Epoch: 5/10. Validation set: Average loss: 0.0546
# Train: [0/2931 (0%)]	Loss: 0.068727
# Train: [1098/2931 (100%)]	Loss: 0.039959
# Epoch: 6/10. Train set: Average loss: 0.0400
# Epoch: 6/10. Validation set: Average loss: 0.0428
# Train: [0/2931 (0%)]	Loss: 0.092160
# Train: [1098/2931 (100%)]	Loss: 0.037749
# Epoch: 7/10. Train set: Average loss: 0.0379
# Epoch: 7/10. Validation set: Average loss: 0.0394
# Train: [0/2931 (0%)]	Loss: 0.041007
# Train: [1098/2931 (100%)]	Loss: 0.034707
# Epoch: 8/10. Train set: Average loss: 0.0347
# Epoch: 8/10. Validation set: Average loss: 0.0398
# Train: [0/2931 (0%)]	Loss: 0.056372
# Train: [1098/2931 (100%)]	Loss: 0.023593
# Epoch: 9/10. Train set: Average loss: 0.0237
# Epoch: 9/10. Validation set: Average loss: 0.0306
# Train: [0/2931 (0%)]	Loss: 0.026583
# Train: [1098/2931 (100%)]	Loss: 0.024299
# Epoch: 10/10. Train set: Average loss: 0.0243
# Epoch: 10/10. Validation set: Average loss: 0.0300
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.187068
# Train: [1098/2931 (100%)]	Loss: 0.079149
# Epoch: 1/10. Train set: Average loss: 0.0794
# Epoch: 1/10. Validation set: Average loss: 0.0580
# Train: [0/2931 (0%)]	Loss: 0.111150
# Train: [1098/2931 (100%)]	Loss: 0.054150
# Epoch: 2/10. Train set: Average loss: 0.0543
# Epoch: 2/10. Validation set: Average loss: 0.0761
# Train: [0/2931 (0%)]	Loss: 0.098701
# Train: [1098/2931 (100%)]	Loss: 0.047153
# Epoch: 3/10. Train set: Average loss: 0.0473
# Epoch: 3/10. Validation set: Average loss: 0.0496
# Train: [0/2931 (0%)]	Loss: 0.086555
# Train: [1098/2931 (100%)]	Loss: 0.045664
# Epoch: 4/10. Train set: Average loss: 0.0458
# Epoch: 4/10. Validation set: Average loss: 0.0534
# Train: [0/2931 (0%)]	Loss: 0.049166
# Train: [1098/2931 (100%)]	Loss: 0.057371
# Epoch: 5/10. Train set: Average loss: 0.0573
# Epoch: 5/10. Validation set: Average loss: 0.0733
# Train: [0/2931 (0%)]	Loss: 0.100012
# Train: [1098/2931 (100%)]	Loss: 0.046775
# Epoch: 6/10. Train set: Average loss: 0.0469
# Epoch: 6/10. Validation set: Average loss: 0.0582
# Train: [0/2931 (0%)]	Loss: 0.048813
# Train: [1098/2931 (100%)]	Loss: 0.039717
# Epoch: 7/10. Train set: Average loss: 0.0397
# Epoch: 7/10. Validation set: Average loss: 0.0455
# Train: [0/2931 (0%)]	Loss: 0.044651
# Train: [1098/2931 (100%)]	Loss: 0.035156
# Epoch: 8/10. Train set: Average loss: 0.0352
# Epoch: 8/10. Validation set: Average loss: 0.0384
# Train: [0/2931 (0%)]	Loss: 0.026513
# Train: [1098/2931 (100%)]	Loss: 0.029567
# Epoch: 9/10. Train set: Average loss: 0.0296
# Epoch: 9/10. Validation set: Average loss: 0.0312
# Train: [0/2931 (0%)]	Loss: 0.038538
# Train: [1098/2931 (100%)]	Loss: 0.026399
# Epoch: 10/10. Train set: Average loss: 0.0264
# Epoch: 10/10. Validation set: Average loss: 0.0297
# Batch 28
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.124895
# Train: [1098/2931 (100%)]	Loss: 0.083036
# Epoch: 1/10. Train set: Average loss: 0.0832
# Epoch: 1/10. Validation set: Average loss: 0.0540
# Train: [0/2931 (0%)]	Loss: 0.067037
# Train: [1098/2931 (100%)]	Loss: 0.053642
# Epoch: 2/10. Train set: Average loss: 0.0537
# Epoch: 2/10. Validation set: Average loss: 0.0459
# Train: [0/2931 (0%)]	Loss: 0.086495
# Train: [1098/2931 (100%)]	Loss: 0.045186
# Epoch: 3/10. Train set: Average loss: 0.0453
# Epoch: 3/10. Validation set: Average loss: 0.0427
# Train: [0/2931 (0%)]	Loss: 0.038694
# Train: [1098/2931 (100%)]	Loss: 0.041297
# Epoch: 4/10. Train set: Average loss: 0.0413
# Epoch: 4/10. Validation set: Average loss: 0.0401
# Train: [0/2931 (0%)]	Loss: 0.056463
# Train: [1098/2931 (100%)]	Loss: 0.039930
# Epoch: 5/10. Train set: Average loss: 0.0400
# Epoch: 5/10. Validation set: Average loss: 0.0419
# Train: [0/2931 (0%)]	Loss: 0.011689
# Train: [1098/2931 (100%)]	Loss: 0.040413
# Epoch: 6/10. Train set: Average loss: 0.0403
# Epoch: 6/10. Validation set: Average loss: 0.0396
# Train: [0/2931 (0%)]	Loss: 0.027312
# Train: [1098/2931 (100%)]	Loss: 0.034792
# Epoch: 7/10. Train set: Average loss: 0.0348
# Epoch: 7/10. Validation set: Average loss: 0.0361
# Train: [0/2931 (0%)]	Loss: 0.070100
# Train: [1098/2931 (100%)]	Loss: 0.033998
# Epoch: 8/10. Train set: Average loss: 0.0341
# Epoch: 8/10. Validation set: Average loss: 0.0340
# Train: [0/2931 (0%)]	Loss: 0.072938
# Train: [1098/2931 (100%)]	Loss: 0.027596
# Epoch: 9/10. Train set: Average loss: 0.0277
# Epoch: 9/10. Validation set: Average loss: 0.0293
# Train: [0/2931 (0%)]	Loss: 0.023580
# Train: [1098/2931 (100%)]	Loss: 0.024018
# Epoch: 10/10. Train set: Average loss: 0.0240
# Epoch: 10/10. Validation set: Average loss: 0.0268
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.248445
# Train: [1098/2931 (100%)]	Loss: 0.070714
# Epoch: 1/10. Train set: Average loss: 0.0712
# Epoch: 1/10. Validation set: Average loss: 0.0474
# Train: [0/2931 (0%)]	Loss: 0.077282
# Train: [1098/2931 (100%)]	Loss: 0.050194
# Epoch: 2/10. Train set: Average loss: 0.0503
# Epoch: 2/10. Validation set: Average loss: 0.0437
# Train: [0/2931 (0%)]	Loss: 0.069352
# Train: [1098/2931 (100%)]	Loss: 0.045259
# Epoch: 3/10. Train set: Average loss: 0.0453
# Epoch: 3/10. Validation set: Average loss: 0.0505
# Train: [0/2931 (0%)]	Loss: 0.025970
# Train: [1098/2931 (100%)]	Loss: 0.044737
# Epoch: 4/10. Train set: Average loss: 0.0447
# Epoch: 4/10. Validation set: Average loss: 0.0461
# Train: [0/2931 (0%)]	Loss: 0.052934
# Train: [1098/2931 (100%)]	Loss: 0.039772
# Epoch: 5/10. Train set: Average loss: 0.0398
# Epoch: 5/10. Validation set: Average loss: 0.0406
# Train: [0/2931 (0%)]	Loss: 0.052110
# Train: [1098/2931 (100%)]	Loss: 0.037374
# Epoch: 6/10. Train set: Average loss: 0.0374
# Epoch: 6/10. Validation set: Average loss: 0.0346
# Train: [0/2931 (0%)]	Loss: 0.027587
# Train: [1098/2931 (100%)]	Loss: 0.030504
# Epoch: 7/10. Train set: Average loss: 0.0305
# Epoch: 7/10. Validation set: Average loss: 0.0371
# Train: [0/2931 (0%)]	Loss: 0.052943
# Train: [1098/2931 (100%)]	Loss: 0.043082
# Epoch: 8/10. Train set: Average loss: 0.0431
# Epoch: 8/10. Validation set: Average loss: 0.0380
# Train: [0/2931 (0%)]	Loss: 0.014110
# Train: [1098/2931 (100%)]	Loss: 0.033471
# Epoch: 9/10. Train set: Average loss: 0.0334
# Epoch: 9/10. Validation set: Average loss: 0.0327
# Train: [0/2931 (0%)]	Loss: 0.066128
# Train: [1098/2931 (100%)]	Loss: 0.028840
# Epoch: 10/10. Train set: Average loss: 0.0289
# Epoch: 10/10. Validation set: Average loss: 0.0316
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.187094
# Train: [1098/2931 (100%)]	Loss: 0.071651
# Epoch: 1/10. Train set: Average loss: 0.0720
# Epoch: 1/10. Validation set: Average loss: 0.0497
# Train: [0/2931 (0%)]	Loss: 0.077388
# Train: [1098/2931 (100%)]	Loss: 0.051663
# Epoch: 2/10. Train set: Average loss: 0.0517
# Epoch: 2/10. Validation set: Average loss: 0.0543
# Train: [0/2931 (0%)]	Loss: 0.044081
# Train: [1098/2931 (100%)]	Loss: 0.048454
# Epoch: 3/10. Train set: Average loss: 0.0484
# Epoch: 3/10. Validation set: Average loss: 0.0473
# Train: [0/2931 (0%)]	Loss: 0.012570
# Train: [1098/2931 (100%)]	Loss: 0.046006
# Epoch: 4/10. Train set: Average loss: 0.0459
# Epoch: 4/10. Validation set: Average loss: 0.0576
# Train: [0/2931 (0%)]	Loss: 0.063786
# Train: [1098/2931 (100%)]	Loss: 0.043370
# Epoch: 5/10. Train set: Average loss: 0.0434
# Epoch: 5/10. Validation set: Average loss: 0.0476
# Train: [0/2931 (0%)]	Loss: 0.051204
# Train: [1098/2931 (100%)]	Loss: 0.036653
# Epoch: 6/10. Train set: Average loss: 0.0367
# Epoch: 6/10. Validation set: Average loss: 0.0400
# Train: [0/2931 (0%)]	Loss: 0.054781
# Train: [1098/2931 (100%)]	Loss: 0.038609
# Epoch: 7/10. Train set: Average loss: 0.0387
# Epoch: 7/10. Validation set: Average loss: 0.0387
# Train: [0/2931 (0%)]	Loss: 0.069445
# Train: [1098/2931 (100%)]	Loss: 0.034875
# Epoch: 8/10. Train set: Average loss: 0.0350
# Epoch: 8/10. Validation set: Average loss: 0.0538
# Train: [0/2931 (0%)]	Loss: 0.051197
# Train: [1098/2931 (100%)]	Loss: 0.029767
# Epoch: 9/10. Train set: Average loss: 0.0298
# Epoch: 9/10. Validation set: Average loss: 0.0325
# Train: [0/2931 (0%)]	Loss: 0.035188
# Train: [1098/2931 (100%)]	Loss: 0.025826
# Epoch: 10/10. Train set: Average loss: 0.0259
# Epoch: 10/10. Validation set: Average loss: 0.0298
# Batch 29
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.249535
# Train: [1098/2931 (100%)]	Loss: 0.072079
# Epoch: 1/10. Train set: Average loss: 0.0726
# Epoch: 1/10. Validation set: Average loss: 0.0865
# Train: [0/2931 (0%)]	Loss: 0.088869
# Train: [1098/2931 (100%)]	Loss: 0.053672
# Epoch: 2/10. Train set: Average loss: 0.0538
# Epoch: 2/10. Validation set: Average loss: 0.0583
# Train: [0/2931 (0%)]	Loss: 0.049663
# Train: [1098/2931 (100%)]	Loss: 0.048871
# Epoch: 3/10. Train set: Average loss: 0.0489
# Epoch: 3/10. Validation set: Average loss: 0.0496
# Train: [0/2931 (0%)]	Loss: 0.040734
# Train: [1098/2931 (100%)]	Loss: 0.042287
# Epoch: 4/10. Train set: Average loss: 0.0423
# Epoch: 4/10. Validation set: Average loss: 0.0539
# Train: [0/2931 (0%)]	Loss: 0.039148
# Train: [1098/2931 (100%)]	Loss: 0.041419
# Epoch: 5/10. Train set: Average loss: 0.0414
# Epoch: 5/10. Validation set: Average loss: 0.0567
# Train: [0/2931 (0%)]	Loss: 0.008542
# Train: [1098/2931 (100%)]	Loss: 0.045922
# Epoch: 6/10. Train set: Average loss: 0.0458
# Epoch: 6/10. Validation set: Average loss: 0.0446
# Train: [0/2931 (0%)]	Loss: 0.043932
# Train: [1098/2931 (100%)]	Loss: 0.041945
# Epoch: 7/10. Train set: Average loss: 0.0420
# Epoch: 7/10. Validation set: Average loss: 0.0596
# Train: [0/2931 (0%)]	Loss: 0.045916
# Train: [1098/2931 (100%)]	Loss: 0.044287
# Epoch: 8/10. Train set: Average loss: 0.0443
# Epoch: 8/10. Validation set: Average loss: 0.0706
# Train: [0/2931 (0%)]	Loss: 0.076000
# Train: [1098/2931 (100%)]	Loss: 0.035903
# Epoch: 9/10. Train set: Average loss: 0.0360
# Epoch: 9/10. Validation set: Average loss: 0.0400
# Train: [0/2931 (0%)]	Loss: 0.024643
# Train: [1098/2931 (100%)]	Loss: 0.030043
# Epoch: 10/10. Train set: Average loss: 0.0300
# Epoch: 10/10. Validation set: Average loss: 0.0384
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.311695
# Train: [1098/2931 (100%)]	Loss: 0.071924
# Epoch: 1/10. Train set: Average loss: 0.0726
# Epoch: 1/10. Validation set: Average loss: 0.0671
# Train: [0/2931 (0%)]	Loss: 0.072036
# Train: [1098/2931 (100%)]	Loss: 0.057376
# Epoch: 2/10. Train set: Average loss: 0.0574
# Epoch: 2/10. Validation set: Average loss: 0.0580
# Train: [0/2931 (0%)]	Loss: 0.076798
# Train: [1098/2931 (100%)]	Loss: 0.047374
# Epoch: 3/10. Train set: Average loss: 0.0475
# Epoch: 3/10. Validation set: Average loss: 0.0524
# Train: [0/2931 (0%)]	Loss: 0.031841
# Train: [1098/2931 (100%)]	Loss: 0.046677
# Epoch: 4/10. Train set: Average loss: 0.0466
# Epoch: 4/10. Validation set: Average loss: 0.0510
# Train: [0/2931 (0%)]	Loss: 0.107419
# Train: [1098/2931 (100%)]	Loss: 0.044934

# %%
exp_dir
# Out:
# '/srv/nas/mk2/projects/pan-cancer/experiments/2020.03.24_10:57_11_300-60'
