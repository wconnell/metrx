# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("..")

import datetime
import pathlib

from collections import OrderedDict 

import numpy as np
import pandas as pd

# %%
# Pytorch
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable

# Custom
from dutils import Experiment
from trainer import fit
import visualization as vis
from tcga_datasets import SiameseDataset

# Models
from tcga_networks import EmbeddingNet, SiameseNet
from losses import ContrastiveLoss

# Metrics
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score as ANMI

# %%
def getTCGA(disease):
    path = "/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP/TCGA/TCGA_{}_counts.tsv.gz"
    files = [path.format(d) for d in disease]
    return files


def readGCP(files, biotype='protein_coding', mean=True):
    """
    Paths to count matrices.
    """
    data_dict = {}
    for f in files:
        key = os.path.basename(f).split("_")[1]
        data = pd.read_csv(f, sep='\t', index_col=0)
        # transcript metadata
        meta = pd.DataFrame([row[:-1] for row in data.index.str.split("|")],
                            columns=['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'GENE', 'BP', 'BIOTYPE'])
        meta = pd.MultiIndex.from_frame(meta)
        data.index = meta
        # subset transcripts
        data = data.xs(key=biotype, level='BIOTYPE')
        data = data.droplevel(['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'BP'])
        # average gene expression of splice variants
        data = data.T
        if mean:
            data = data.groupby(by=data.columns, axis=1).mean()
        data_dict[key] = data
    return data_dict


def uq_norm(df, q=0.75):
    """
    Upper quartile normalization of GEX for samples.
    """
    quantiles = df.quantile(q=q, axis=1)
    norm = df.divide(quantiles, axis=0)
    return norm


def process_TCGA(disease=['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']):
    base="/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP"
    # get files
    tcga_files = getTCGA(disease)
    # read meta/data
    tcga_meta = pd.read_csv(os.path.join(base, "TCGA/TCGA_GDC_ID_MAP.tsv"), sep="\t")
    tcga_raw = readGCP(tcga_files, mean=True)
    # combine samples
    tcga_raw = pd.concat(tcga_raw.values())
    # Upper quartile normalization
    tcga_raw = uq_norm(tcga_raw)
    # log norm
    tcga = tcga_raw.transform(np.log1p)
    return tcga, tcga_meta

# %%
def generate_fsets(data, n_features, steps=5):
    r = np.linspace(start=1, stop=n_features, num=steps, dtype='int')
    idx = [np.random.choice(data.shape[1], size=i, replace=False) for i in r]
    return idx

# %%
def feature_training(train_data, train_labels, test_data, test_labels, feature_idx, embedding, exp_dir, cuda=True):
    # Meta data
    meta_data = {"n_features":[],
                 "model":[],
                 "ANMI":[]}
    # Params
    batch_size = 8
    kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {'num_workers': 10}
    
    # Feature Index
    for batch, feat in enumerate(feature_idx):
        print("Number features: {}\n".format(len(feat)))
        exp_data = {'feature_idx':feat}
        # Define data
        siamese_train_dataset = SiameseDataset(data=train_data.iloc[:,feat],
                                           labels=train_labels,
                                           train=True)
        siamese_test_dataset = SiameseDataset(data=test_data.iloc[:,feat],
                                          labels=test_labels,
                                          train=False)
        # Loaders
        siamese_train_loader = torch.utils.data.DataLoader(siamese_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
        siamese_test_loader = torch.utils.data.DataLoader(siamese_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)
        # Instantiate model
        n_samples, n_features = siamese_train_dataset.train_data.shape
        for i in range(3):
            nmodel = 'model_{}'.format(i)
            print("\t{}".format(nmodel))
            embedding_net = EmbeddingNet(n_features, embedding)
            model = SiameseNet(embedding_net)
            if cuda:
                model.cuda()
            # Parameters
            margin = 1.
            loss_fn = ContrastiveLoss(margin)
            lr = 1e-3
            optimizer = optim.Adam(model.parameters(), lr=lr)
            scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
            n_epochs = 10
            log_interval = round(len(siamese_train_dataset)/1/batch_size)
            # Train
            train_loss, val_loss = fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, 
                                       n_epochs, cuda, log_interval)
            # Test Embeddings
            val_embeddings_baseline, val_labels_baseline = vis.extract_embeddings(siamese_test_dataset.test_data, siamese_test_dataset.labels, model)
            # Evaluation
            n_clusters = len(np.unique(test_labels))
            kmeans = KMeans(n_clusters=n_clusters)
            siamese_clusters = kmeans.fit_predict(val_embeddings_baseline)
            anmi = ANMI(siamese_clusters, val_labels_baseline)
            # Store
            meta_data['n_features'].append(len(feat))
            meta_data['model'].append(nmodel)
            meta_data['ANMI'].append(anmi)
            exp_data[nmodel] = {'data': (val_embeddings_baseline, val_labels_baseline),
                                'loss': (train_loss, val_loss),
                                'ANMI': anmi}
        pd.to_pickle(exp_data, os.path.join(exp_dir, "model_{}.pkl".format(len(feat))))
    pd.to_pickle(meta_data, os.path.join(exp_dir, "model_meta_data.pkl"))

# %%
def main(disease, sample_type, **kwargs):
    # GPUs
    os.environ["CUDA_VISIBLE_DEVICES"] = kwargs['device']
    cuda = torch.cuda.is_available()
    print("Cuda is available: {}".format(cuda))
    
    # Read / write / process
    tcga, tcga_meta = process_TCGA(disease)
    # Feature design
    feature_idx = generate_fsets(tcga, n_features=kwargs['n_features'], steps=kwargs['steps'])
    # Experiment design
    hierarchy = OrderedDict({'Disease':disease,
                             'Sample Type':sample_type})
    # Define experiment
    exp = Experiment(meta_data=tcga_meta,
                     hierarchy=hierarchy,
                     index='CGHubAnalysisID',
                     cases='Case ID',
                     min_samples=20)
    # Train / Test split
    exp.train_test_split(cases='Case ID')
    # Return data 
    train_data, train_labels = exp.get_data(tcga, subset="train", dtype=np.float32)
    test_data, test_labels = exp.get_data(tcga, subset="test", dtype=np.float32)
    
    # Path *fix*
    dtime = datetime.datetime.today().strftime("%Y.%m.%d_%H:%M")
    exp_dir = "/srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/{}_{}_{}_{}_{}-{}".format(dtime,
                                                                                                  kwargs['note'],
                                                                                                  len(exp.labels_dict),
                                                                                                  kwargs['embedding'],
                                                                                                  kwargs['n_features'], 
                                                                                                  kwargs['steps'])
    pathlib.Path(exp_dir).mkdir(parents=True, exist_ok=False)
    print('Saving to: \n{}'.format(exp_dir))
    
    # Meta data
    experiments = {'experiment': exp,
                   'train':(train_data, train_labels),
                   'test': (test_data, test_labels)}
    pd.to_pickle(experiments, os.path.join(exp_dir, "experiment_meta_data.pkl"))
    
    # Training
    feature_training(train_data, train_labels, test_data, test_labels, feature_idx, kwargs['embedding'], exp_dir)

# %% [markdown]
# ### Setup

# %%
base="/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP"
# read meta/data
tcga_meta = pd.read_csv(os.path.join(base, "TCGA/TCGA_GDC_ID_MAP.tsv"), sep="\t")
# select disease
disease = tcga_meta[tcga_meta['Sample Type']=='Solid Tissue Normal']['Disease'].value_counts()
disease = list(disease[disease>=20].index)
disease
# Out:
# ['BRCA',
#  'KIRC',
#  'LUAD',
#  'THCA',
#  'PRAD',
#  'LIHC',
#  'LUSC',
#  'HNSC',
#  'COAD',
#  'UCEC',
#  'STAD',
#  'KIRP',
#  'KICH']

# %%
sample_type = ['Primary Tumor', 'Solid Tissue Normal']
params = {"device":"6",
          "note":"true",
          "n_features":150,
          "steps":50,
          "embedding":2}

# %%
main(disease=disease, sample_type=sample_type, **params)
# Out:
# Cuda is available: True
# Saving to:
# /srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/2020.03.30_09:13_true_26_2_150-50
# Number features: 1
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.248370
# Epoch: 1/10. Train set: Average loss: 0.1629
# Epoch: 1/10. Validation set: Average loss: 0.1611
# Train: [0/5622 (0%)]	Loss: 0.164451
# Epoch: 2/10. Train set: Average loss: 0.1567
# Epoch: 2/10. Validation set: Average loss: 0.1464
# Train: [0/5622 (0%)]	Loss: 0.188929
# Epoch: 3/10. Train set: Average loss: 0.1464
# Epoch: 3/10. Validation set: Average loss: 0.1754
# Train: [0/5622 (0%)]	Loss: 0.203978
# Epoch: 4/10. Train set: Average loss: 0.1470
# Epoch: 4/10. Validation set: Average loss: 0.1436
# Train: [0/5622 (0%)]	Loss: 0.100227
# Epoch: 5/10. Train set: Average loss: 0.1458
# Epoch: 5/10. Validation set: Average loss: 0.1757
# Train: [0/5622 (0%)]	Loss: 0.144208
# Epoch: 6/10. Train set: Average loss: 0.1509
# Epoch: 6/10. Validation set: Average loss: 0.1454
# Train: [0/5622 (0%)]	Loss: 0.161298
# Epoch: 7/10. Train set: Average loss: 0.1500
# Epoch: 7/10. Validation set: Average loss: 0.1510
# Train: [0/5622 (0%)]	Loss: 0.179478
# Epoch: 8/10. Train set: Average loss: 0.1479
# Epoch: 8/10. Validation set: Average loss: 0.1474
# Train: [0/5622 (0%)]	Loss: 0.193625
# Epoch: 9/10. Train set: Average loss: 0.1499
# Epoch: 9/10. Validation set: Average loss: 0.1443
# Train: [0/5622 (0%)]	Loss: 0.160863
# Epoch: 10/10. Train set: Average loss: 0.1429
# Epoch: 10/10. Validation set: Average loss: 0.1441
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.311398
# Epoch: 1/10. Train set: Average loss: 0.1585
# Epoch: 1/10. Validation set: Average loss: 0.1561
# Train: [0/5622 (0%)]	Loss: 0.229260
# Epoch: 2/10. Train set: Average loss: 0.1505
# Epoch: 2/10. Validation set: Average loss: 0.1443
# Train: [0/5622 (0%)]	Loss: 0.193340
# Epoch: 3/10. Train set: Average loss: 0.1486
# Epoch: 3/10. Validation set: Average loss: 0.1513
# Train: [0/5622 (0%)]	Loss: 0.178097
# Epoch: 4/10. Train set: Average loss: 0.1612
# Epoch: 4/10. Validation set: Average loss: 0.1780
# Train: [0/5622 (0%)]	Loss: 0.234940
# Epoch: 5/10. Train set: Average loss: 0.1515
# Epoch: 5/10. Validation set: Average loss: 0.1440
# Train: [0/5622 (0%)]	Loss: 0.100840
# Epoch: 6/10. Train set: Average loss: 0.1472
# Epoch: 6/10. Validation set: Average loss: 0.1554
# Train: [0/5622 (0%)]	Loss: 0.140623
# Epoch: 7/10. Train set: Average loss: 0.1462
# Epoch: 7/10. Validation set: Average loss: 0.1521
# Train: [0/5622 (0%)]	Loss: 0.154912
# Epoch: 8/10. Train set: Average loss: 0.1462
# Epoch: 8/10. Validation set: Average loss: 0.1453
# Train: [0/5622 (0%)]	Loss: 0.073336
# Epoch: 9/10. Train set: Average loss: 0.1429
# Epoch: 9/10. Validation set: Average loss: 0.1444
# Train: [0/5622 (0%)]	Loss: 0.144377
# Epoch: 10/10. Train set: Average loss: 0.1443
# Epoch: 10/10. Validation set: Average loss: 0.1443
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.187057
# Epoch: 1/10. Train set: Average loss: 0.1596
# Epoch: 1/10. Validation set: Average loss: 0.1748
# Train: [0/5622 (0%)]	Loss: 0.185471
# Epoch: 2/10. Train set: Average loss: 0.1545
# Epoch: 2/10. Validation set: Average loss: 0.1447
# Train: [0/5622 (0%)]	Loss: 0.188718
# Epoch: 3/10. Train set: Average loss: 0.1494
# Epoch: 3/10. Validation set: Average loss: 0.1473
# Train: [0/5622 (0%)]	Loss: 0.179206
# Epoch: 4/10. Train set: Average loss: 0.1448
# Epoch: 4/10. Validation set: Average loss: 0.1523
# Train: [0/5622 (0%)]	Loss: 0.244062
# Epoch: 5/10. Train set: Average loss: 0.1470
# Epoch: 5/10. Validation set: Average loss: 0.1489
# Train: [0/5622 (0%)]	Loss: 0.106865
# Epoch: 6/10. Train set: Average loss: 0.1490
# Epoch: 6/10. Validation set: Average loss: 0.1463
# Train: [0/5622 (0%)]	Loss: 0.200171
# Epoch: 7/10. Train set: Average loss: 0.1496
# Epoch: 7/10. Validation set: Average loss: 0.1469
# Train: [0/5622 (0%)]	Loss: 0.179206
# Epoch: 8/10. Train set: Average loss: 0.1453
# Epoch: 8/10. Validation set: Average loss: 0.1480
# Train: [0/5622 (0%)]	Loss: 0.136734
# Epoch: 9/10. Train set: Average loss: 0.1448
# Epoch: 9/10. Validation set: Average loss: 0.1428
# Train: [0/5622 (0%)]	Loss: 0.131566
# Epoch: 10/10. Train set: Average loss: 0.1422
# Epoch: 10/10. Validation set: Average loss: 0.1426
# Number features: 4
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.124317
# Epoch: 1/10. Train set: Average loss: 0.1474
# Epoch: 1/10. Validation set: Average loss: 0.1314
# Train: [0/5622 (0%)]	Loss: 0.229555
# Epoch: 2/10. Train set: Average loss: 0.1350
# Epoch: 2/10. Validation set: Average loss: 0.1462
# Train: [0/5622 (0%)]	Loss: 0.100752
# Epoch: 3/10. Train set: Average loss: 0.1304
# Epoch: 3/10. Validation set: Average loss: 0.1231
# Train: [0/5622 (0%)]	Loss: 0.193215
# Epoch: 4/10. Train set: Average loss: 0.1215
# Epoch: 4/10. Validation set: Average loss: 0.1235
# Train: [0/5622 (0%)]	Loss: 0.184509
# Epoch: 5/10. Train set: Average loss: 0.1207
# Epoch: 5/10. Validation set: Average loss: 0.1333
# Train: [0/5622 (0%)]	Loss: 0.155677
# Epoch: 6/10. Train set: Average loss: 0.1198
# Epoch: 6/10. Validation set: Average loss: 0.1264
# Train: [0/5622 (0%)]	Loss: 0.081494
# Epoch: 7/10. Train set: Average loss: 0.1211
# Epoch: 7/10. Validation set: Average loss: 0.1188
# Train: [0/5622 (0%)]	Loss: 0.076128
# Epoch: 8/10. Train set: Average loss: 0.1181
# Epoch: 8/10. Validation set: Average loss: 0.1180
# Train: [0/5622 (0%)]	Loss: 0.117997
# Epoch: 9/10. Train set: Average loss: 0.1113
# Epoch: 9/10. Validation set: Average loss: 0.1178
# Train: [0/5622 (0%)]	Loss: 0.060864
# Epoch: 10/10. Train set: Average loss: 0.1133
# Epoch: 10/10. Validation set: Average loss: 0.1170
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.186184
# Epoch: 1/10. Train set: Average loss: 0.1335
# Epoch: 1/10. Validation set: Average loss: 0.1242
# Train: [0/5622 (0%)]	Loss: 0.179401
# Epoch: 2/10. Train set: Average loss: 0.1265
# Epoch: 2/10. Validation set: Average loss: 0.1190
# Train: [0/5622 (0%)]	Loss: 0.179662
# Epoch: 3/10. Train set: Average loss: 0.1189
# Epoch: 3/10. Validation set: Average loss: 0.1260
# Train: [0/5622 (0%)]	Loss: 0.119423
# Epoch: 4/10. Train set: Average loss: 0.1188
# Epoch: 4/10. Validation set: Average loss: 0.1180
# Train: [0/5622 (0%)]	Loss: 0.072398
# Epoch: 5/10. Train set: Average loss: 0.1179
# Epoch: 5/10. Validation set: Average loss: 0.1196
# Train: [0/5622 (0%)]	Loss: 0.070240
# Epoch: 6/10. Train set: Average loss: 0.1202
# Epoch: 6/10. Validation set: Average loss: 0.1218
# Train: [0/5622 (0%)]	Loss: 0.062017
# Epoch: 7/10. Train set: Average loss: 0.1179
# Epoch: 7/10. Validation set: Average loss: 0.1197
# Train: [0/5622 (0%)]	Loss: 0.120286
# Epoch: 8/10. Train set: Average loss: 0.1231
# Epoch: 8/10. Validation set: Average loss: 0.1218
# Train: [0/5622 (0%)]	Loss: 0.179010
# Epoch: 9/10. Train set: Average loss: 0.1169
# Epoch: 9/10. Validation set: Average loss: 0.1177
# Train: [0/5622 (0%)]	Loss: 0.083419
# Epoch: 10/10. Train set: Average loss: 0.1150
# Epoch: 10/10. Validation set: Average loss: 0.1180
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.186999
# Epoch: 1/10. Train set: Average loss: 0.1396
# Epoch: 1/10. Validation set: Average loss: 0.1370
# Train: [0/5622 (0%)]	Loss: 0.146840
# Epoch: 2/10. Train set: Average loss: 0.1312
# Epoch: 2/10. Validation set: Average loss: 0.1320
# Train: [0/5622 (0%)]	Loss: 0.130542
# Epoch: 3/10. Train set: Average loss: 0.1265
# Epoch: 3/10. Validation set: Average loss: 0.1179
# Train: [0/5622 (0%)]	Loss: 0.137778
# Epoch: 4/10. Train set: Average loss: 0.1186
# Epoch: 4/10. Validation set: Average loss: 0.1183
# Train: [0/5622 (0%)]	Loss: 0.047106
# Epoch: 5/10. Train set: Average loss: 0.1276
# Epoch: 5/10. Validation set: Average loss: 0.1218
# Train: [0/5622 (0%)]	Loss: 0.032699
# Epoch: 6/10. Train set: Average loss: 0.1244
# Epoch: 6/10. Validation set: Average loss: 0.1193
# Train: [0/5622 (0%)]	Loss: 0.033998
# Epoch: 7/10. Train set: Average loss: 0.1189
# Epoch: 7/10. Validation set: Average loss: 0.1257
# Train: [0/5622 (0%)]	Loss: 0.062071
# Epoch: 8/10. Train set: Average loss: 0.1180
# Epoch: 8/10. Validation set: Average loss: 0.1181
# Train: [0/5622 (0%)]	Loss: 0.131307
# Epoch: 9/10. Train set: Average loss: 0.1130
# Epoch: 9/10. Validation set: Average loss: 0.1175
# Train: [0/5622 (0%)]	Loss: 0.097443
# Epoch: 10/10. Train set: Average loss: 0.1162
# Epoch: 10/10. Validation set: Average loss: 0.1161
# Number features: 7
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.249842
# Epoch: 1/10. Train set: Average loss: 0.1276
# Epoch: 1/10. Validation set: Average loss: 0.1567
# Train: [0/5622 (0%)]	Loss: 0.077423
# Epoch: 2/10. Train set: Average loss: 0.1077
# Epoch: 2/10. Validation set: Average loss: 0.1491
# Train: [0/5622 (0%)]	Loss: 0.280943
# Epoch: 3/10. Train set: Average loss: 0.1007
# Epoch: 3/10. Validation set: Average loss: 0.1009
# Train: [0/5622 (0%)]	Loss: 0.216704
# Epoch: 4/10. Train set: Average loss: 0.1027
# Epoch: 4/10. Validation set: Average loss: 0.1011
# Train: [0/5622 (0%)]	Loss: 0.105552
# Epoch: 5/10. Train set: Average loss: 0.0975
# Epoch: 5/10. Validation set: Average loss: 0.1146
# Train: [0/5622 (0%)]	Loss: 0.091025
# Epoch: 6/10. Train set: Average loss: 0.0978
# Epoch: 6/10. Validation set: Average loss: 0.1125
# Train: [0/5622 (0%)]	Loss: 0.052312
# Epoch: 7/10. Train set: Average loss: 0.1015
# Epoch: 7/10. Validation set: Average loss: 0.0984
# Train: [0/5622 (0%)]	Loss: 0.036021
# Epoch: 8/10. Train set: Average loss: 0.1009
# Epoch: 8/10. Validation set: Average loss: 0.1129
# Train: [0/5622 (0%)]	Loss: 0.059555
# Epoch: 9/10. Train set: Average loss: 0.0970
# Epoch: 9/10. Validation set: Average loss: 0.0927
# Train: [0/5622 (0%)]	Loss: 0.053348
# Epoch: 10/10. Train set: Average loss: 0.0925
# Epoch: 10/10. Validation set: Average loss: 0.0920
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.124808
# Epoch: 1/10. Train set: Average loss: 0.1147
# Epoch: 1/10. Validation set: Average loss: 0.1178
# Train: [0/5622 (0%)]	Loss: 0.111775
# Epoch: 2/10. Train set: Average loss: 0.1093
# Epoch: 2/10. Validation set: Average loss: 0.1101
# Train: [0/5622 (0%)]	Loss: 0.069431
# Epoch: 3/10. Train set: Average loss: 0.1061
# Epoch: 3/10. Validation set: Average loss: 0.1257
# Train: [0/5622 (0%)]	Loss: 0.199332
# Epoch: 4/10. Train set: Average loss: 0.1020
# Epoch: 4/10. Validation set: Average loss: 0.1536
# Train: [0/5622 (0%)]	Loss: 0.054819
# Epoch: 5/10. Train set: Average loss: 0.1024
# Epoch: 5/10. Validation set: Average loss: 0.0967
# Train: [0/5622 (0%)]	Loss: 0.097637
# Epoch: 6/10. Train set: Average loss: 0.0995
# Epoch: 6/10. Validation set: Average loss: 0.0988
# Train: [0/5622 (0%)]	Loss: 0.053627
# Epoch: 7/10. Train set: Average loss: 0.0966
# Epoch: 7/10. Validation set: Average loss: 0.0930
# Train: [0/5622 (0%)]	Loss: 0.089136
# Epoch: 8/10. Train set: Average loss: 0.0928
# Epoch: 8/10. Validation set: Average loss: 0.0983
# Train: [0/5622 (0%)]	Loss: 0.045128
# Epoch: 9/10. Train set: Average loss: 0.0937
# Epoch: 9/10. Validation set: Average loss: 0.0932
# Train: [0/5622 (0%)]	Loss: 0.121771
# Epoch: 10/10. Train set: Average loss: 0.0908
# Epoch: 10/10. Validation set: Average loss: 0.0910
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.374267
# Epoch: 1/10. Train set: Average loss: 0.1164
# Epoch: 1/10. Validation set: Average loss: 0.1005
# Train: [0/5622 (0%)]	Loss: 0.073864
# Epoch: 2/10. Train set: Average loss: 0.1130
# Epoch: 2/10. Validation set: Average loss: 0.1140
# Train: [0/5622 (0%)]	Loss: 0.188095
# Epoch: 3/10. Train set: Average loss: 0.1047
# Epoch: 3/10. Validation set: Average loss: 0.0987
# Train: [0/5622 (0%)]	Loss: 0.058890
# Epoch: 4/10. Train set: Average loss: 0.1005
# Epoch: 4/10. Validation set: Average loss: 0.0928
# Train: [0/5622 (0%)]	Loss: 0.123305
# Epoch: 5/10. Train set: Average loss: 0.0960
# Epoch: 5/10. Validation set: Average loss: 0.1013
# Train: [0/5622 (0%)]	Loss: 0.160358
# Epoch: 6/10. Train set: Average loss: 0.1025
# Epoch: 6/10. Validation set: Average loss: 0.0905
# Train: [0/5622 (0%)]	Loss: 0.146720
# Epoch: 7/10. Train set: Average loss: 0.0953
# Epoch: 7/10. Validation set: Average loss: 0.0960
# Train: [0/5622 (0%)]	Loss: 0.178196
# Epoch: 8/10. Train set: Average loss: 0.0938
# Epoch: 8/10. Validation set: Average loss: 0.0965
# Train: [0/5622 (0%)]	Loss: 0.102652
# Epoch: 9/10. Train set: Average loss: 0.0943
# Epoch: 9/10. Validation set: Average loss: 0.0919
# Train: [0/5622 (0%)]	Loss: 0.084274
# Epoch: 10/10. Train set: Average loss: 0.0903
# Epoch: 10/10. Validation set: Average loss: 0.0892
# Number features: 10
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.249540
# Epoch: 1/10. Train set: Average loss: 0.1064
# Epoch: 1/10. Validation set: Average loss: 0.0932
# Train: [0/5622 (0%)]	Loss: 0.146161
# Epoch: 2/10. Train set: Average loss: 0.0943
# Epoch: 2/10. Validation set: Average loss: 0.0914
# Train: [0/5622 (0%)]	Loss: 0.101019
# Epoch: 3/10. Train set: Average loss: 0.0905
# Epoch: 3/10. Validation set: Average loss: 0.0904
# Train: [0/5622 (0%)]	Loss: 0.124466
# Epoch: 4/10. Train set: Average loss: 0.0894
# Epoch: 4/10. Validation set: Average loss: 0.0932
# Train: [0/5622 (0%)]	Loss: 0.095678
# Epoch: 5/10. Train set: Average loss: 0.0861
# Epoch: 5/10. Validation set: Average loss: 0.0965
# Train: [0/5622 (0%)]	Loss: 0.149918
# Epoch: 6/10. Train set: Average loss: 0.0886
# Epoch: 6/10. Validation set: Average loss: 0.0919
# Train: [0/5622 (0%)]	Loss: 0.103604
# Epoch: 7/10. Train set: Average loss: 0.0841
# Epoch: 7/10. Validation set: Average loss: 0.0845
# Train: [0/5622 (0%)]	Loss: 0.063998
# Epoch: 8/10. Train set: Average loss: 0.0816
# Epoch: 8/10. Validation set: Average loss: 0.0920
# Train: [0/5622 (0%)]	Loss: 0.054213
# Epoch: 9/10. Train set: Average loss: 0.0790
# Epoch: 9/10. Validation set: Average loss: 0.0828
# Train: [0/5622 (0%)]	Loss: 0.052753
# Epoch: 10/10. Train set: Average loss: 0.0779
# Epoch: 10/10. Validation set: Average loss: 0.0824
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.187340
# Epoch: 1/10. Train set: Average loss: 0.1215
# Epoch: 1/10. Validation set: Average loss: 0.1179
# Train: [0/5622 (0%)]	Loss: 0.079790
# Epoch: 2/10. Train set: Average loss: 0.0942
# Epoch: 2/10. Validation set: Average loss: 0.0866
# Train: [0/5622 (0%)]	Loss: 0.132141
# Epoch: 3/10. Train set: Average loss: 0.0885
# Epoch: 3/10. Validation set: Average loss: 0.0947
# Train: [0/5622 (0%)]	Loss: 0.131898
# Epoch: 4/10. Train set: Average loss: 0.0875
# Epoch: 4/10. Validation set: Average loss: 0.0907
# Train: [0/5622 (0%)]	Loss: 0.145132
# Epoch: 5/10. Train set: Average loss: 0.0863
# Epoch: 5/10. Validation set: Average loss: 0.0882
# Train: [0/5622 (0%)]	Loss: 0.087318
# Epoch: 6/10. Train set: Average loss: 0.0871
# Epoch: 6/10. Validation set: Average loss: 0.0897
# Train: [0/5622 (0%)]	Loss: 0.102547
# Epoch: 7/10. Train set: Average loss: 0.0908
# Epoch: 7/10. Validation set: Average loss: 0.0868
# Train: [0/5622 (0%)]	Loss: 0.098753
# Epoch: 8/10. Train set: Average loss: 0.0825
# Epoch: 8/10. Validation set: Average loss: 0.0850
# Train: [0/5622 (0%)]	Loss: 0.148006
# Epoch: 9/10. Train set: Average loss: 0.0820
# Epoch: 9/10. Validation set: Average loss: 0.0822
# Train: [0/5622 (0%)]	Loss: 0.071804
# Epoch: 10/10. Train set: Average loss: 0.0790
# Epoch: 10/10. Validation set: Average loss: 0.0812
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.248925
# Epoch: 1/10. Train set: Average loss: 0.1090
# Epoch: 1/10. Validation set: Average loss: 0.0921
# Train: [0/5622 (0%)]	Loss: 0.139188
# Epoch: 2/10. Train set: Average loss: 0.0936
# Epoch: 2/10. Validation set: Average loss: 0.0957
# Train: [0/5622 (0%)]	Loss: 0.072867
# Epoch: 3/10. Train set: Average loss: 0.0911
# Epoch: 3/10. Validation set: Average loss: 0.0902
# Train: [0/5622 (0%)]	Loss: 0.118540
# Epoch: 4/10. Train set: Average loss: 0.0860
# Epoch: 4/10. Validation set: Average loss: 0.0893
# Train: [0/5622 (0%)]	Loss: 0.052272
# Epoch: 5/10. Train set: Average loss: 0.0957
# Epoch: 5/10. Validation set: Average loss: 0.0872
# Train: [0/5622 (0%)]	Loss: 0.107505
# Epoch: 6/10. Train set: Average loss: 0.0881
# Epoch: 6/10. Validation set: Average loss: 0.0837
# Train: [0/5622 (0%)]	Loss: 0.104621
# Epoch: 7/10. Train set: Average loss: 0.0821
# Epoch: 7/10. Validation set: Average loss: 0.0823
# Train: [0/5622 (0%)]	Loss: 0.054824
# Epoch: 8/10. Train set: Average loss: 0.0826
# Epoch: 8/10. Validation set: Average loss: 0.0925
# Train: [0/5622 (0%)]	Loss: 0.137450
# Epoch: 9/10. Train set: Average loss: 0.0803
# Epoch: 9/10. Validation set: Average loss: 0.0843
# Train: [0/5622 (0%)]	Loss: 0.101728
# Epoch: 10/10. Train set: Average loss: 0.0792
# Epoch: 10/10. Validation set: Average loss: 0.0826
# Number features: 13
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.187003
# Epoch: 1/10. Train set: Average loss: 0.1167
# Epoch: 1/10. Validation set: Average loss: 0.1024
# Train: [0/5622 (0%)]	Loss: 0.151306
# Epoch: 2/10. Train set: Average loss: 0.1073
# Epoch: 2/10. Validation set: Average loss: 0.1253
# Train: [0/5622 (0%)]	Loss: 0.100858
# Epoch: 3/10. Train set: Average loss: 0.1045
# Epoch: 3/10. Validation set: Average loss: 0.0948
# Train: [0/5622 (0%)]	Loss: 0.070543
# Epoch: 4/10. Train set: Average loss: 0.0974
# Epoch: 4/10. Validation set: Average loss: 0.0921
# Train: [0/5622 (0%)]	Loss: 0.115606
# Epoch: 5/10. Train set: Average loss: 0.0932
# Epoch: 5/10. Validation set: Average loss: 0.0950
# Train: [0/5622 (0%)]	Loss: 0.092653
# Epoch: 6/10. Train set: Average loss: 0.0925
# Epoch: 6/10. Validation set: Average loss: 0.0924
# Train: [0/5622 (0%)]	Loss: 0.069553
# Epoch: 7/10. Train set: Average loss: 0.0927
# Epoch: 7/10. Validation set: Average loss: 0.0906
# Train: [0/5622 (0%)]	Loss: 0.046391
# Epoch: 8/10. Train set: Average loss: 0.0913
# Epoch: 8/10. Validation set: Average loss: 0.0843
# Train: [0/5622 (0%)]	Loss: 0.030899
# Epoch: 9/10. Train set: Average loss: 0.0839
# Epoch: 9/10. Validation set: Average loss: 0.0819
# Train: [0/5622 (0%)]	Loss: 0.046396
# Epoch: 10/10. Train set: Average loss: 0.0815
# Epoch: 10/10. Validation set: Average loss: 0.0810
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.185834
# Epoch: 1/10. Train set: Average loss: 0.1248
# Epoch: 1/10. Validation set: Average loss: 0.1376
# Train: [0/5622 (0%)]	Loss: 0.179129
# Epoch: 2/10. Train set: Average loss: 0.1086
# Epoch: 2/10. Validation set: Average loss: 0.1097
# Train: [0/5622 (0%)]	Loss: 0.112385
# Epoch: 3/10. Train set: Average loss: 0.1024
# Epoch: 3/10. Validation set: Average loss: 0.1046
# Train: [0/5622 (0%)]	Loss: 0.110333
# Epoch: 4/10. Train set: Average loss: 0.0998
# Epoch: 4/10. Validation set: Average loss: 0.1010
# Train: [0/5622 (0%)]	Loss: 0.104766
# Epoch: 5/10. Train set: Average loss: 0.0928
# Epoch: 5/10. Validation set: Average loss: 0.0972
# Train: [0/5622 (0%)]	Loss: 0.116468
# Epoch: 6/10. Train set: Average loss: 0.0959
# Epoch: 6/10. Validation set: Average loss: 0.0911
# Train: [0/5622 (0%)]	Loss: 0.117605
# Epoch: 7/10. Train set: Average loss: 0.0914
# Epoch: 7/10. Validation set: Average loss: 0.0888
# Train: [0/5622 (0%)]	Loss: 0.056069
# Epoch: 8/10. Train set: Average loss: 0.0914
# Epoch: 8/10. Validation set: Average loss: 0.0855
# Train: [0/5622 (0%)]	Loss: 0.065238
# Epoch: 9/10. Train set: Average loss: 0.0838
# Epoch: 9/10. Validation set: Average loss: 0.0828
# Train: [0/5622 (0%)]	Loss: 0.097258
# Epoch: 10/10. Train set: Average loss: 0.0832
# Epoch: 10/10. Validation set: Average loss: 0.0811
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.311723
# Epoch: 1/10. Train set: Average loss: 0.1281
# Epoch: 1/10. Validation set: Average loss: 0.1015
# Train: [0/5622 (0%)]	Loss: 0.066347
# Epoch: 2/10. Train set: Average loss: 0.1056
# Epoch: 2/10. Validation set: Average loss: 0.0940
# Train: [0/5622 (0%)]	Loss: 0.084020
# Epoch: 3/10. Train set: Average loss: 0.0981
# Epoch: 3/10. Validation set: Average loss: 0.1028
# Train: [0/5622 (0%)]	Loss: 0.114856
# Epoch: 4/10. Train set: Average loss: 0.0948
# Epoch: 4/10. Validation set: Average loss: 0.0905
# Train: [0/5622 (0%)]	Loss: 0.159705
# Epoch: 5/10. Train set: Average loss: 0.0950
# Epoch: 5/10. Validation set: Average loss: 0.1075
# Train: [0/5622 (0%)]	Loss: 0.187447
# Epoch: 6/10. Train set: Average loss: 0.0916
# Epoch: 6/10. Validation set: Average loss: 0.0918
# Train: [0/5622 (0%)]	Loss: 0.117675
# Epoch: 7/10. Train set: Average loss: 0.0901
# Epoch: 7/10. Validation set: Average loss: 0.0850
# Train: [0/5622 (0%)]	Loss: 0.107970
# Epoch: 8/10. Train set: Average loss: 0.0902
# Epoch: 8/10. Validation set: Average loss: 0.1025
# Train: [0/5622 (0%)]	Loss: 0.110652
# Epoch: 9/10. Train set: Average loss: 0.0865
# Epoch: 9/10. Validation set: Average loss: 0.0809
# Train: [0/5622 (0%)]	Loss: 0.099629
# Epoch: 10/10. Train set: Average loss: 0.0795
# Epoch: 10/10. Validation set: Average loss: 0.0806
# Number features: 16
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.249795
# Epoch: 1/10. Train set: Average loss: 0.1274
# Epoch: 1/10. Validation set: Average loss: 0.1075
# Train: [0/5622 (0%)]	Loss: 0.090029
# Epoch: 2/10. Train set: Average loss: 0.1015
# Epoch: 2/10. Validation set: Average loss: 0.1011
# Train: [0/5622 (0%)]	Loss: 0.090887
# Epoch: 3/10. Train set: Average loss: 0.0972
# Epoch: 3/10. Validation set: Average loss: 0.0985
# Train: [0/5622 (0%)]	Loss: 0.076648
# Epoch: 4/10. Train set: Average loss: 0.0937
# Epoch: 4/10. Validation set: Average loss: 0.1025
# Train: [0/5622 (0%)]	Loss: 0.101518
# Epoch: 5/10. Train set: Average loss: 0.0908
# Epoch: 5/10. Validation set: Average loss: 0.1003
# Train: [0/5622 (0%)]	Loss: 0.162289
# Epoch: 6/10. Train set: Average loss: 0.0893
# Epoch: 6/10. Validation set: Average loss: 0.0917
# Train: [0/5622 (0%)]	Loss: 0.046603
# Epoch: 7/10. Train set: Average loss: 0.0864
# Epoch: 7/10. Validation set: Average loss: 0.0879
# Train: [0/5622 (0%)]	Loss: 0.029692
# Epoch: 8/10. Train set: Average loss: 0.0839
# Epoch: 8/10. Validation set: Average loss: 0.0896
# Train: [0/5622 (0%)]	Loss: 0.079643
# Epoch: 9/10. Train set: Average loss: 0.0774
# Epoch: 9/10. Validation set: Average loss: 0.0839
# Train: [0/5622 (0%)]	Loss: 0.035610
# Epoch: 10/10. Train set: Average loss: 0.0766
# Epoch: 10/10. Validation set: Average loss: 0.0845
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.374503
# Epoch: 1/10. Train set: Average loss: 0.1268
# Epoch: 1/10. Validation set: Average loss: 0.1029
# Train: [0/5622 (0%)]	Loss: 0.111641
# Epoch: 2/10. Train set: Average loss: 0.0995
# Epoch: 2/10. Validation set: Average loss: 0.1032
# Train: [0/5622 (0%)]	Loss: 0.027477
# Epoch: 3/10. Train set: Average loss: 0.0991
# Epoch: 3/10. Validation set: Average loss: 0.1021
# Train: [0/5622 (0%)]	Loss: 0.223256
# Epoch: 4/10. Train set: Average loss: 0.0944
# Epoch: 4/10. Validation set: Average loss: 0.0947
# Train: [0/5622 (0%)]	Loss: 0.060915
# Epoch: 5/10. Train set: Average loss: 0.0876
# Epoch: 5/10. Validation set: Average loss: 0.0906
# Train: [0/5622 (0%)]	Loss: 0.134836
# Epoch: 6/10. Train set: Average loss: 0.0876
# Epoch: 6/10. Validation set: Average loss: 0.0917
# Train: [0/5622 (0%)]	Loss: 0.120884
# Epoch: 7/10. Train set: Average loss: 0.0872
# Epoch: 7/10. Validation set: Average loss: 0.0928
# Train: [0/5622 (0%)]	Loss: 0.119111
# Epoch: 8/10. Train set: Average loss: 0.0863
# Epoch: 8/10. Validation set: Average loss: 0.0870
# Train: [0/5622 (0%)]	Loss: 0.084203
# Epoch: 9/10. Train set: Average loss: 0.0811
# Epoch: 9/10. Validation set: Average loss: 0.0846
# Train: [0/5622 (0%)]	Loss: 0.066672
# Epoch: 10/10. Train set: Average loss: 0.0800
# Epoch: 10/10. Validation set: Average loss: 0.0829
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.249598
# Epoch: 1/10. Train set: Average loss: 0.1184
# Epoch: 1/10. Validation set: Average loss: 0.1174
# Train: [0/5622 (0%)]	Loss: 0.134743
# Epoch: 2/10. Train set: Average loss: 0.1053
# Epoch: 2/10. Validation set: Average loss: 0.1014
# Train: [0/5622 (0%)]	Loss: 0.141022
# Epoch: 3/10. Train set: Average loss: 0.0950
# Epoch: 3/10. Validation set: Average loss: 0.1102
# Train: [0/5622 (0%)]	Loss: 0.124193
# Epoch: 4/10. Train set: Average loss: 0.0909
# Epoch: 4/10. Validation set: Average loss: 0.0970
# Train: [0/5622 (0%)]	Loss: 0.091316
# Epoch: 5/10. Train set: Average loss: 0.0883
# Epoch: 5/10. Validation set: Average loss: 0.0891
# Train: [0/5622 (0%)]	Loss: 0.137365
# Epoch: 6/10. Train set: Average loss: 0.0879
# Epoch: 6/10. Validation set: Average loss: 0.0863
# Train: [0/5622 (0%)]	Loss: 0.066211
# Epoch: 7/10. Train set: Average loss: 0.0874
# Epoch: 7/10. Validation set: Average loss: 0.0905
# Train: [0/5622 (0%)]	Loss: 0.037224
# Epoch: 8/10. Train set: Average loss: 0.0857
# Epoch: 8/10. Validation set: Average loss: 0.0855
# Train: [0/5622 (0%)]	Loss: 0.072086
# Epoch: 9/10. Train set: Average loss: 0.0791
# Epoch: 9/10. Validation set: Average loss: 0.0830
# Train: [0/5622 (0%)]	Loss: 0.154857
# Epoch: 10/10. Train set: Average loss: 0.0779
# Epoch: 10/10. Validation set: Average loss: 0.0823
# Number features: 19
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.249690
# Epoch: 1/10. Train set: Average loss: 0.1136
# Epoch: 1/10. Validation set: Average loss: 0.1069
# Train: [0/5622 (0%)]	Loss: 0.046720
# Epoch: 2/10. Train set: Average loss: 0.0957
# Epoch: 2/10. Validation set: Average loss: 0.0825
# Train: [0/5622 (0%)]	Loss: 0.074075
# Epoch: 3/10. Train set: Average loss: 0.0874
# Epoch: 3/10. Validation set: Average loss: 0.0839
# Train: [0/5622 (0%)]	Loss: 0.104940
# Epoch: 4/10. Train set: Average loss: 0.0808
# Epoch: 4/10. Validation set: Average loss: 0.0788
# Train: [0/5622 (0%)]	Loss: 0.087107
# Epoch: 5/10. Train set: Average loss: 0.0780
# Epoch: 5/10. Validation set: Average loss: 0.0711
# Train: [0/5622 (0%)]	Loss: 0.127048
# Epoch: 6/10. Train set: Average loss: 0.0779
# Epoch: 6/10. Validation set: Average loss: 0.0780
# Train: [0/5622 (0%)]	Loss: 0.053069
# Epoch: 7/10. Train set: Average loss: 0.0752
# Epoch: 7/10. Validation set: Average loss: 0.0690
# Train: [0/5622 (0%)]	Loss: 0.079612
# Epoch: 8/10. Train set: Average loss: 0.0707
# Epoch: 8/10. Validation set: Average loss: 0.0720
# Train: [0/5622 (0%)]	Loss: 0.095262
# Epoch: 9/10. Train set: Average loss: 0.0670
# Epoch: 9/10. Validation set: Average loss: 0.0669
# Train: [0/5622 (0%)]	Loss: 0.061404
# Epoch: 10/10. Train set: Average loss: 0.0645
# Epoch: 10/10. Validation set: Average loss: 0.0668
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.062201
# Epoch: 1/10. Train set: Average loss: 0.1181
# Epoch: 1/10. Validation set: Average loss: 0.1017
# Train: [0/5622 (0%)]	Loss: 0.042699
# Epoch: 2/10. Train set: Average loss: 0.0988
# Epoch: 2/10. Validation set: Average loss: 0.1172
# Train: [0/5622 (0%)]	Loss: 0.072106
# Epoch: 3/10. Train set: Average loss: 0.0888
# Epoch: 3/10. Validation set: Average loss: 0.0800
# Train: [0/5622 (0%)]	Loss: 0.076769
# Epoch: 4/10. Train set: Average loss: 0.0802
# Epoch: 4/10. Validation set: Average loss: 0.0777
# Train: [0/5622 (0%)]	Loss: 0.064173
# Epoch: 5/10. Train set: Average loss: 0.0785
# Epoch: 5/10. Validation set: Average loss: 0.0913
# Train: [0/5622 (0%)]	Loss: 0.056496
# Epoch: 6/10. Train set: Average loss: 0.0792
# Epoch: 6/10. Validation set: Average loss: 0.0850
# Train: [0/5622 (0%)]	Loss: 0.052354
# Epoch: 7/10. Train set: Average loss: 0.0795
# Epoch: 7/10. Validation set: Average loss: 0.0707
# Train: [0/5622 (0%)]	Loss: 0.042418
# Epoch: 8/10. Train set: Average loss: 0.0731
# Epoch: 8/10. Validation set: Average loss: 0.0769
# Train: [0/5622 (0%)]	Loss: 0.067980
# Epoch: 9/10. Train set: Average loss: 0.0659
# Epoch: 9/10. Validation set: Average loss: 0.0661
# Train: [0/5622 (0%)]	Loss: 0.089476
# Epoch: 10/10. Train set: Average loss: 0.0659
# Epoch: 10/10. Validation set: Average loss: 0.0651
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.062272
# Epoch: 1/10. Train set: Average loss: 0.1107
# Epoch: 1/10. Validation set: Average loss: 0.1233
# Train: [0/5622 (0%)]	Loss: 0.097120
# Epoch: 2/10. Train set: Average loss: 0.1009
# Epoch: 2/10. Validation set: Average loss: 0.0933
# Train: [0/5622 (0%)]	Loss: 0.067583
# Epoch: 3/10. Train set: Average loss: 0.0885
# Epoch: 3/10. Validation set: Average loss: 0.0808
# Train: [0/5622 (0%)]	Loss: 0.066959
# Epoch: 4/10. Train set: Average loss: 0.0806
# Epoch: 4/10. Validation set: Average loss: 0.0825
# Train: [0/5622 (0%)]	Loss: 0.022349
# Epoch: 5/10. Train set: Average loss: 0.0805
# Epoch: 5/10. Validation set: Average loss: 0.0814
# Train: [0/5622 (0%)]	Loss: 0.036874
# Epoch: 6/10. Train set: Average loss: 0.0802
# Epoch: 6/10. Validation set: Average loss: 0.0785
# Train: [0/5622 (0%)]	Loss: 0.060415
# Epoch: 7/10. Train set: Average loss: 0.0734
# Epoch: 7/10. Validation set: Average loss: 0.0786
# Train: [0/5622 (0%)]	Loss: 0.103813
# Epoch: 8/10. Train set: Average loss: 0.0736
# Epoch: 8/10. Validation set: Average loss: 0.0710
# Train: [0/5622 (0%)]	Loss: 0.047951
# Epoch: 9/10. Train set: Average loss: 0.0677
# Epoch: 9/10. Validation set: Average loss: 0.0656
# Train: [0/5622 (0%)]	Loss: 0.088098
# Epoch: 10/10. Train set: Average loss: 0.0664
# Epoch: 10/10. Validation set: Average loss: 0.0662
# Number features: 22
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.124703
# Epoch: 1/10. Train set: Average loss: 0.1142
# Epoch: 1/10. Validation set: Average loss: 0.1006
# Train: [0/5622 (0%)]	Loss: 0.076226
# Epoch: 2/10. Train set: Average loss: 0.0930
# Epoch: 2/10. Validation set: Average loss: 0.1062
# Train: [0/5622 (0%)]	Loss: 0.049835
# Epoch: 3/10. Train set: Average loss: 0.0859
# Epoch: 3/10. Validation set: Average loss: 0.0929
# Train: [0/5622 (0%)]	Loss: 0.134989
# Epoch: 4/10. Train set: Average loss: 0.0801
# Epoch: 4/10. Validation set: Average loss: 0.0848
# Train: [0/5622 (0%)]	Loss: 0.026638
# Epoch: 5/10. Train set: Average loss: 0.0807
# Epoch: 5/10. Validation set: Average loss: 0.0879
# Train: [0/5622 (0%)]	Loss: 0.052486
# Epoch: 6/10. Train set: Average loss: 0.0764
# Epoch: 6/10. Validation set: Average loss: 0.0737
# Train: [0/5622 (0%)]	Loss: 0.082618
# Epoch: 7/10. Train set: Average loss: 0.0689
# Epoch: 7/10. Validation set: Average loss: 0.0717
# Train: [0/5622 (0%)]	Loss: 0.094164
# Epoch: 8/10. Train set: Average loss: 0.0727
# Epoch: 8/10. Validation set: Average loss: 0.0777
# Train: [0/5622 (0%)]	Loss: 0.085187
# Epoch: 9/10. Train set: Average loss: 0.0644
# Epoch: 9/10. Validation set: Average loss: 0.0693
# Train: [0/5622 (0%)]	Loss: 0.083257
# Epoch: 10/10. Train set: Average loss: 0.0617
# Epoch: 10/10. Validation set: Average loss: 0.0664
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.311283
# Epoch: 1/10. Train set: Average loss: 0.1094
# Epoch: 1/10. Validation set: Average loss: 0.1227
# Train: [0/5622 (0%)]	Loss: 0.157847
# Epoch: 2/10. Train set: Average loss: 0.1001
# Epoch: 2/10. Validation set: Average loss: 0.0896
# Train: [0/5622 (0%)]	Loss: 0.153984
# Epoch: 3/10. Train set: Average loss: 0.0830
# Epoch: 3/10. Validation set: Average loss: 0.0853
# Train: [0/5622 (0%)]	Loss: 0.134155
# Epoch: 4/10. Train set: Average loss: 0.0838
# Epoch: 4/10. Validation set: Average loss: 0.0770
# Train: [0/5622 (0%)]	Loss: 0.178056
# Epoch: 5/10. Train set: Average loss: 0.0731
# Epoch: 5/10. Validation set: Average loss: 0.0924
# Train: [0/5622 (0%)]	Loss: 0.153933
# Epoch: 6/10. Train set: Average loss: 0.0749
# Epoch: 6/10. Validation set: Average loss: 0.0792
# Train: [0/5622 (0%)]	Loss: 0.130088
# Epoch: 7/10. Train set: Average loss: 0.0706
# Epoch: 7/10. Validation set: Average loss: 0.0738
# Train: [0/5622 (0%)]	Loss: 0.047682
# Epoch: 8/10. Train set: Average loss: 0.0667
# Epoch: 8/10. Validation set: Average loss: 0.0765
# Train: [0/5622 (0%)]	Loss: 0.076214
# Epoch: 9/10. Train set: Average loss: 0.0605
# Epoch: 9/10. Validation set: Average loss: 0.0628
# Train: [0/5622 (0%)]	Loss: 0.030593
# Epoch: 10/10. Train set: Average loss: 0.0575
# Epoch: 10/10. Validation set: Average loss: 0.0620
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.186660
# Epoch: 1/10. Train set: Average loss: 0.1099
# Epoch: 1/10. Validation set: Average loss: 0.1180
# Train: [0/5622 (0%)]	Loss: 0.176784
# Epoch: 2/10. Train set: Average loss: 0.0902
# Epoch: 2/10. Validation set: Average loss: 0.0827
# Train: [0/5622 (0%)]	Loss: 0.063868
# Epoch: 3/10. Train set: Average loss: 0.0861
# Epoch: 3/10. Validation set: Average loss: 0.0751
# Train: [0/5622 (0%)]	Loss: 0.092379
# Epoch: 4/10. Train set: Average loss: 0.0751
# Epoch: 4/10. Validation set: Average loss: 0.0795
# Train: [0/5622 (0%)]	Loss: 0.041697
# Epoch: 5/10. Train set: Average loss: 0.0745
# Epoch: 5/10. Validation set: Average loss: 0.0787
# Train: [0/5622 (0%)]	Loss: 0.058308
# Epoch: 6/10. Train set: Average loss: 0.0731
# Epoch: 6/10. Validation set: Average loss: 0.0732
# Train: [0/5622 (0%)]	Loss: 0.101701
# Epoch: 7/10. Train set: Average loss: 0.0704
# Epoch: 7/10. Validation set: Average loss: 0.0759
# Train: [0/5622 (0%)]	Loss: 0.055323
# Epoch: 8/10. Train set: Average loss: 0.0674
# Epoch: 8/10. Validation set: Average loss: 0.0715
# Train: [0/5622 (0%)]	Loss: 0.095672
# Epoch: 9/10. Train set: Average loss: 0.0612
# Epoch: 9/10. Validation set: Average loss: 0.0625
# Train: [0/5622 (0%)]	Loss: 0.017886
# Epoch: 10/10. Train set: Average loss: 0.0571
# Epoch: 10/10. Validation set: Average loss: 0.0615
# Number features: 25
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.249750
# Epoch: 1/10. Train set: Average loss: 0.1171
# Epoch: 1/10. Validation set: Average loss: 0.1055
# Train: [0/5622 (0%)]	Loss: 0.104567
# Epoch: 2/10. Train set: Average loss: 0.0968
# Epoch: 2/10. Validation set: Average loss: 0.1057
# Train: [0/5622 (0%)]	Loss: 0.083018
# Epoch: 3/10. Train set: Average loss: 0.0825
# Epoch: 3/10. Validation set: Average loss: 0.0799
# Train: [0/5622 (0%)]	Loss: 0.031527
# Epoch: 4/10. Train set: Average loss: 0.0757
# Epoch: 4/10. Validation set: Average loss: 0.0914
# Train: [0/5622 (0%)]	Loss: 0.101494
# Epoch: 5/10. Train set: Average loss: 0.0747
# Epoch: 5/10. Validation set: Average loss: 0.0703
# Train: [0/5622 (0%)]	Loss: 0.082186
# Epoch: 6/10. Train set: Average loss: 0.0705
# Epoch: 6/10. Validation set: Average loss: 0.0693
# Train: [0/5622 (0%)]	Loss: 0.047705
# Epoch: 7/10. Train set: Average loss: 0.0670
# Epoch: 7/10. Validation set: Average loss: 0.0654
# Train: [0/5622 (0%)]	Loss: 0.062255
# Epoch: 8/10. Train set: Average loss: 0.0642
# Epoch: 8/10. Validation set: Average loss: 0.0680
# Train: [0/5622 (0%)]	Loss: 0.077977
# Epoch: 9/10. Train set: Average loss: 0.0584
# Epoch: 9/10. Validation set: Average loss: 0.0570
# Train: [0/5622 (0%)]	Loss: 0.026062
# Epoch: 10/10. Train set: Average loss: 0.0556
# Epoch: 10/10. Validation set: Average loss: 0.0567
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.312031
# Epoch: 1/10. Train set: Average loss: 0.1008
# Epoch: 1/10. Validation set: Average loss: 0.0978
# Train: [0/5622 (0%)]	Loss: 0.109255
# Epoch: 2/10. Train set: Average loss: 0.0874
# Epoch: 2/10. Validation set: Average loss: 0.0767
# Train: [0/5622 (0%)]	Loss: 0.117009
# Epoch: 3/10. Train set: Average loss: 0.0824
# Epoch: 3/10. Validation set: Average loss: 0.0742
# Train: [0/5622 (0%)]	Loss: 0.054431
# Epoch: 4/10. Train set: Average loss: 0.0780
# Epoch: 4/10. Validation set: Average loss: 0.0834
# Train: [0/5622 (0%)]	Loss: 0.099694
# Epoch: 5/10. Train set: Average loss: 0.0681
# Epoch: 5/10. Validation set: Average loss: 0.0683
# Train: [0/5622 (0%)]	Loss: 0.110215
# Epoch: 6/10. Train set: Average loss: 0.0684
# Epoch: 6/10. Validation set: Average loss: 0.0654
# Train: [0/5622 (0%)]	Loss: 0.120566
# Epoch: 7/10. Train set: Average loss: 0.0694
# Epoch: 7/10. Validation set: Average loss: 0.0642
# Train: [0/5622 (0%)]	Loss: 0.102401
# Epoch: 8/10. Train set: Average loss: 0.0659
# Epoch: 8/10. Validation set: Average loss: 0.0656
# Train: [0/5622 (0%)]	Loss: 0.132631
# Epoch: 9/10. Train set: Average loss: 0.0573
# Epoch: 9/10. Validation set: Average loss: 0.0560
# Train: [0/5622 (0%)]	Loss: 0.044547
# Epoch: 10/10. Train set: Average loss: 0.0548
# Epoch: 10/10. Validation set: Average loss: 0.0555
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.436325
# Epoch: 1/10. Train set: Average loss: 0.1056
# Epoch: 1/10. Validation set: Average loss: 0.0872
# Train: [0/5622 (0%)]	Loss: 0.103179
# Epoch: 2/10. Train set: Average loss: 0.0846
# Epoch: 2/10. Validation set: Average loss: 0.0796
# Train: [0/5622 (0%)]	Loss: 0.175317
# Epoch: 3/10. Train set: Average loss: 0.0821
# Epoch: 3/10. Validation set: Average loss: 0.0995
# Train: [0/5622 (0%)]	Loss: 0.087771
# Epoch: 4/10. Train set: Average loss: 0.0759
# Epoch: 4/10. Validation set: Average loss: 0.0714
# Train: [0/5622 (0%)]	Loss: 0.158280
# Epoch: 5/10. Train set: Average loss: 0.0748
# Epoch: 5/10. Validation set: Average loss: 0.0753
# Train: [0/5622 (0%)]	Loss: 0.061435
# Epoch: 6/10. Train set: Average loss: 0.0702
# Epoch: 6/10. Validation set: Average loss: 0.0721
# Train: [0/5622 (0%)]	Loss: 0.010873
# Epoch: 7/10. Train set: Average loss: 0.0699
# Epoch: 7/10. Validation set: Average loss: 0.0653
# Train: [0/5622 (0%)]	Loss: 0.095776
# Epoch: 8/10. Train set: Average loss: 0.0670
# Epoch: 8/10. Validation set: Average loss: 0.0665
# Train: [0/5622 (0%)]	Loss: 0.045909
# Epoch: 9/10. Train set: Average loss: 0.0590
# Epoch: 9/10. Validation set: Average loss: 0.0598
# Train: [0/5622 (0%)]	Loss: 0.056200
# Epoch: 10/10. Train set: Average loss: 0.0573
# Epoch: 10/10. Validation set: Average loss: 0.0595
# Number features: 28
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.124793
# Epoch: 1/10. Train set: Average loss: 0.1009
# Epoch: 1/10. Validation set: Average loss: 0.1040
# Train: [0/5622 (0%)]	Loss: 0.062569
# Epoch: 2/10. Train set: Average loss: 0.0810
# Epoch: 2/10. Validation set: Average loss: 0.0870
# Train: [0/5622 (0%)]	Loss: 0.058957
# Epoch: 3/10. Train set: Average loss: 0.0796
# Epoch: 3/10. Validation set: Average loss: 0.0820
# Train: [0/5622 (0%)]	Loss: 0.063766
# Epoch: 4/10. Train set: Average loss: 0.0724
# Epoch: 4/10. Validation set: Average loss: 0.0707
# Train: [0/5622 (0%)]	Loss: 0.026270
# Epoch: 5/10. Train set: Average loss: 0.0688
# Epoch: 5/10. Validation set: Average loss: 0.0667
# Train: [0/5622 (0%)]	Loss: 0.052519
# Epoch: 6/10. Train set: Average loss: 0.0636
# Epoch: 6/10. Validation set: Average loss: 0.0688
# Train: [0/5622 (0%)]	Loss: 0.085180
# Epoch: 7/10. Train set: Average loss: 0.0650
# Epoch: 7/10. Validation set: Average loss: 0.0612
# Train: [0/5622 (0%)]	Loss: 0.074400
# Epoch: 8/10. Train set: Average loss: 0.0611
# Epoch: 8/10. Validation set: Average loss: 0.0600
# Train: [0/5622 (0%)]	Loss: 0.050384
# Epoch: 9/10. Train set: Average loss: 0.0531
# Epoch: 9/10. Validation set: Average loss: 0.0536
# Train: [0/5622 (0%)]	Loss: 0.045282
# Epoch: 10/10. Train set: Average loss: 0.0496
# Epoch: 10/10. Validation set: Average loss: 0.0525
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.249798
# Epoch: 1/10. Train set: Average loss: 0.1036
# Epoch: 1/10. Validation set: Average loss: 0.0900
# Train: [0/5622 (0%)]	Loss: 0.049353
# Epoch: 2/10. Train set: Average loss: 0.0876
# Epoch: 2/10. Validation set: Average loss: 0.0843
# Train: [0/5622 (0%)]	Loss: 0.035141
# Epoch: 3/10. Train set: Average loss: 0.0794
# Epoch: 3/10. Validation set: Average loss: 0.0782
# Train: [0/5622 (0%)]	Loss: 0.128400
# Epoch: 4/10. Train set: Average loss: 0.0693
# Epoch: 4/10. Validation set: Average loss: 0.0705
# Train: [0/5622 (0%)]	Loss: 0.022007
# Epoch: 5/10. Train set: Average loss: 0.0682
# Epoch: 5/10. Validation set: Average loss: 0.0676
# Train: [0/5622 (0%)]	Loss: 0.037369
# Epoch: 6/10. Train set: Average loss: 0.0641
# Epoch: 6/10. Validation set: Average loss: 0.0642
# Train: [0/5622 (0%)]	Loss: 0.041299
# Epoch: 7/10. Train set: Average loss: 0.0644
# Epoch: 7/10. Validation set: Average loss: 0.0730
# Train: [0/5622 (0%)]	Loss: 0.038259
# Epoch: 8/10. Train set: Average loss: 0.0607
# Epoch: 8/10. Validation set: Average loss: 0.0656
# Train: [0/5622 (0%)]	Loss: 0.093059
# Epoch: 9/10. Train set: Average loss: 0.0526
# Epoch: 9/10. Validation set: Average loss: 0.0564
# Train: [0/5622 (0%)]	Loss: 0.048577
# Epoch: 10/10. Train set: Average loss: 0.0522
# Epoch: 10/10. Validation set: Average loss: 0.0559
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.249503
# Epoch: 1/10. Train set: Average loss: 0.1038
# Epoch: 1/10. Validation set: Average loss: 0.1066
# Train: [0/5622 (0%)]	Loss: 0.084082
# Epoch: 2/10. Train set: Average loss: 0.0817
# Epoch: 2/10. Validation set: Average loss: 0.0817
# Train: [0/5622 (0%)]	Loss: 0.083834
# Epoch: 3/10. Train set: Average loss: 0.0707
# Epoch: 3/10. Validation set: Average loss: 0.0755
# Train: [0/5622 (0%)]	Loss: 0.184959
# Epoch: 4/10. Train set: Average loss: 0.0722
# Epoch: 4/10. Validation set: Average loss: 0.0829
# Train: [0/5622 (0%)]	Loss: 0.102156
# Epoch: 5/10. Train set: Average loss: 0.0661
# Epoch: 5/10. Validation set: Average loss: 0.0721
# Train: [0/5622 (0%)]	Loss: 0.090375
# Epoch: 6/10. Train set: Average loss: 0.0624
# Epoch: 6/10. Validation set: Average loss: 0.0674
# Train: [0/5622 (0%)]	Loss: 0.104973
# Epoch: 7/10. Train set: Average loss: 0.0583
# Epoch: 7/10. Validation set: Average loss: 0.0651
# Train: [0/5622 (0%)]	Loss: 0.135348
# Epoch: 8/10. Train set: Average loss: 0.0581
# Epoch: 8/10. Validation set: Average loss: 0.0672
# Train: [0/5622 (0%)]	Loss: 0.067974
# Epoch: 9/10. Train set: Average loss: 0.0500
# Epoch: 9/10. Validation set: Average loss: 0.0547
# Train: [0/5622 (0%)]	Loss: 0.053643
# Epoch: 10/10. Train set: Average loss: 0.0475
# Epoch: 10/10. Validation set: Average loss: 0.0525
# Number features: 31
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.186880
# Epoch: 1/10. Train set: Average loss: 0.1147
# Epoch: 1/10. Validation set: Average loss: 0.0937
# Train: [0/5622 (0%)]	Loss: 0.136459
# Epoch: 2/10. Train set: Average loss: 0.0961
# Epoch: 2/10. Validation set: Average loss: 0.0857
# Train: [0/5622 (0%)]	Loss: 0.208782
# Epoch: 3/10. Train set: Average loss: 0.0921
# Epoch: 3/10. Validation set: Average loss: 0.0814
# Train: [0/5622 (0%)]	Loss: 0.085720
# Epoch: 4/10. Train set: Average loss: 0.0907
# Epoch: 4/10. Validation set: Average loss: 0.0806
# Train: [0/5622 (0%)]	Loss: 0.085661
# Epoch: 5/10. Train set: Average loss: 0.0895
# Epoch: 5/10. Validation set: Average loss: 0.0896
# Train: [0/5622 (0%)]	Loss: 0.105570
# Epoch: 6/10. Train set: Average loss: 0.0842
# Epoch: 6/10. Validation set: Average loss: 0.0898
# Train: [0/5622 (0%)]	Loss: 0.061939
# Epoch: 7/10. Train set: Average loss: 0.0803
# Epoch: 7/10. Validation set: Average loss: 0.0839
# Train: [0/5622 (0%)]	Loss: 0.019789
# Epoch: 8/10. Train set: Average loss: 0.0779
# Epoch: 8/10. Validation set: Average loss: 0.0792
# Train: [0/5622 (0%)]	Loss: 0.073351
# Epoch: 9/10. Train set: Average loss: 0.0723
# Epoch: 9/10. Validation set: Average loss: 0.0688
# Train: [0/5622 (0%)]	Loss: 0.055082
# Epoch: 10/10. Train set: Average loss: 0.0679
# Epoch: 10/10. Validation set: Average loss: 0.0679
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.186581
# Epoch: 1/10. Train set: Average loss: 0.1189
# Epoch: 1/10. Validation set: Average loss: 0.0979
# Train: [0/5622 (0%)]	Loss: 0.085255
# Epoch: 2/10. Train set: Average loss: 0.1027
# Epoch: 2/10. Validation set: Average loss: 0.0988
# Train: [0/5622 (0%)]	Loss: 0.140670
# Epoch: 3/10. Train set: Average loss: 0.0892
# Epoch: 3/10. Validation set: Average loss: 0.0912
# Train: [0/5622 (0%)]	Loss: 0.088046
# Epoch: 4/10. Train set: Average loss: 0.0836
# Epoch: 4/10. Validation set: Average loss: 0.0913
# Train: [0/5622 (0%)]	Loss: 0.108551
# Epoch: 5/10. Train set: Average loss: 0.0872
# Epoch: 5/10. Validation set: Average loss: 0.0871
# Train: [0/5622 (0%)]	Loss: 0.122388
# Epoch: 6/10. Train set: Average loss: 0.0815
# Epoch: 6/10. Validation set: Average loss: 0.0801
# Train: [0/5622 (0%)]	Loss: 0.071810
# Epoch: 7/10. Train set: Average loss: 0.0799
# Epoch: 7/10. Validation set: Average loss: 0.0751
# Train: [0/5622 (0%)]	Loss: 0.142837
# Epoch: 8/10. Train set: Average loss: 0.0772
# Epoch: 8/10. Validation set: Average loss: 0.0787
# Train: [0/5622 (0%)]	Loss: 0.020429
# Epoch: 9/10. Train set: Average loss: 0.0697
# Epoch: 9/10. Validation set: Average loss: 0.0667
# Train: [0/5622 (0%)]	Loss: 0.084208
# Epoch: 10/10. Train set: Average loss: 0.0701
# Epoch: 10/10. Validation set: Average loss: 0.0659
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.249337
# Epoch: 1/10. Train set: Average loss: 0.1148
# Epoch: 1/10. Validation set: Average loss: 0.0937
# Train: [0/5622 (0%)]	Loss: 0.087388
# Epoch: 2/10. Train set: Average loss: 0.0987
# Epoch: 2/10. Validation set: Average loss: 0.0851
# Train: [0/5622 (0%)]	Loss: 0.125533
# Epoch: 3/10. Train set: Average loss: 0.0950
# Epoch: 3/10. Validation set: Average loss: 0.0828
# Train: [0/5622 (0%)]	Loss: 0.106934
# Epoch: 4/10. Train set: Average loss: 0.0841
# Epoch: 4/10. Validation set: Average loss: 0.0804
# Train: [0/5622 (0%)]	Loss: 0.097233
# Epoch: 5/10. Train set: Average loss: 0.0835
# Epoch: 5/10. Validation set: Average loss: 0.0876
# Train: [0/5622 (0%)]	Loss: 0.113728
# Epoch: 6/10. Train set: Average loss: 0.0807
# Epoch: 6/10. Validation set: Average loss: 0.0742
# Train: [0/5622 (0%)]	Loss: 0.065558
# Epoch: 7/10. Train set: Average loss: 0.0806
# Epoch: 7/10. Validation set: Average loss: 0.0780
# Train: [0/5622 (0%)]	Loss: 0.085912
# Epoch: 8/10. Train set: Average loss: 0.0765
# Epoch: 8/10. Validation set: Average loss: 0.0950
# Train: [0/5622 (0%)]	Loss: 0.082502
# Epoch: 9/10. Train set: Average loss: 0.0743
# Epoch: 9/10. Validation set: Average loss: 0.0708
# Train: [0/5622 (0%)]	Loss: 0.072970
# Epoch: 10/10. Train set: Average loss: 0.0680
# Epoch: 10/10. Validation set: Average loss: 0.0694
# Number features: 34
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.373136
# Epoch: 1/10. Train set: Average loss: 0.0948
# Epoch: 1/10. Validation set: Average loss: 0.0905
# Train: [0/5622 (0%)]	Loss: 0.056079
# Epoch: 2/10. Train set: Average loss: 0.0833
# Epoch: 2/10. Validation set: Average loss: 0.0746
# Train: [0/5622 (0%)]	Loss: 0.099027
# Epoch: 3/10. Train set: Average loss: 0.0751
# Epoch: 3/10. Validation set: Average loss: 0.0719
# Train: [0/5622 (0%)]	Loss: 0.121990
# Epoch: 4/10. Train set: Average loss: 0.0714
# Epoch: 4/10. Validation set: Average loss: 0.0726
# Train: [0/5622 (0%)]	Loss: 0.129490
# Epoch: 5/10. Train set: Average loss: 0.0704
# Epoch: 5/10. Validation set: Average loss: 0.0813
# Train: [0/5622 (0%)]	Loss: 0.016317
# Epoch: 6/10. Train set: Average loss: 0.0689
# Epoch: 6/10. Validation set: Average loss: 0.0708
# Train: [0/5622 (0%)]	Loss: 0.093636
# Epoch: 7/10. Train set: Average loss: 0.0688
# Epoch: 7/10. Validation set: Average loss: 0.0734
# Train: [0/5622 (0%)]	Loss: 0.059489
# Epoch: 8/10. Train set: Average loss: 0.0681
# Epoch: 8/10. Validation set: Average loss: 0.0609
# Train: [0/5622 (0%)]	Loss: 0.079635
# Epoch: 9/10. Train set: Average loss: 0.0600
# Epoch: 9/10. Validation set: Average loss: 0.0605
# Train: [0/5622 (0%)]	Loss: 0.040461
# Epoch: 10/10. Train set: Average loss: 0.0594
# Epoch: 10/10. Validation set: Average loss: 0.0587
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.249682
# Epoch: 1/10. Train set: Average loss: 0.0975
# Epoch: 1/10. Validation set: Average loss: 0.0871
# Train: [0/5622 (0%)]	Loss: 0.024892
# Epoch: 2/10. Train set: Average loss: 0.0883
# Epoch: 2/10. Validation set: Average loss: 0.0839
# Train: [0/5622 (0%)]	Loss: 0.077931
# Epoch: 3/10. Train set: Average loss: 0.0785
# Epoch: 3/10. Validation set: Average loss: 0.0740
# Train: [0/5622 (0%)]	Loss: 0.155352
# Epoch: 4/10. Train set: Average loss: 0.0761
# Epoch: 4/10. Validation set: Average loss: 0.0769
# Train: [0/5622 (0%)]	Loss: 0.058093
# Epoch: 5/10. Train set: Average loss: 0.0720
# Epoch: 5/10. Validation set: Average loss: 0.0788
# Train: [0/5622 (0%)]	Loss: 0.058603
# Epoch: 6/10. Train set: Average loss: 0.0697
# Epoch: 6/10. Validation set: Average loss: 0.0696
# Train: [0/5622 (0%)]	Loss: 0.048845
# Epoch: 7/10. Train set: Average loss: 0.0706
# Epoch: 7/10. Validation set: Average loss: 0.0702
# Train: [0/5622 (0%)]	Loss: 0.023546
# Epoch: 8/10. Train set: Average loss: 0.0665
# Epoch: 8/10. Validation set: Average loss: 0.0714
# Train: [0/5622 (0%)]	Loss: 0.084392
# Epoch: 9/10. Train set: Average loss: 0.0625
# Epoch: 9/10. Validation set: Average loss: 0.0619
# Train: [0/5622 (0%)]	Loss: 0.077166
# Epoch: 10/10. Train set: Average loss: 0.0610
# Epoch: 10/10. Validation set: Average loss: 0.0604
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.374220
# Epoch: 1/10. Train set: Average loss: 0.1042
# Epoch: 1/10. Validation set: Average loss: 0.0862
# Train: [0/5622 (0%)]	Loss: 0.089359
# Epoch: 2/10. Train set: Average loss: 0.0902
# Epoch: 2/10. Validation set: Average loss: 0.1286
# Train: [0/5622 (0%)]	Loss: 0.207034
# Epoch: 3/10. Train set: Average loss: 0.0795
# Epoch: 3/10. Validation set: Average loss: 0.0682
# Train: [0/5622 (0%)]	Loss: 0.054858
# Epoch: 4/10. Train set: Average loss: 0.0723
# Epoch: 4/10. Validation set: Average loss: 0.0689
# Train: [0/5622 (0%)]	Loss: 0.083467
# Epoch: 5/10. Train set: Average loss: 0.0702
# Epoch: 5/10. Validation set: Average loss: 0.0661
# Train: [0/5622 (0%)]	Loss: 0.019432
# Epoch: 6/10. Train set: Average loss: 0.0689
# Epoch: 6/10. Validation set: Average loss: 0.0638
# Train: [0/5622 (0%)]	Loss: 0.083100
# Epoch: 7/10. Train set: Average loss: 0.0702
# Epoch: 7/10. Validation set: Average loss: 0.0641
# Train: [0/5622 (0%)]	Loss: 0.037993
# Epoch: 8/10. Train set: Average loss: 0.0626
# Epoch: 8/10. Validation set: Average loss: 0.0623
# Train: [0/5622 (0%)]	Loss: 0.082567
# Epoch: 9/10. Train set: Average loss: 0.0579
# Epoch: 9/10. Validation set: Average loss: 0.0590
# Train: [0/5622 (0%)]	Loss: 0.056714
# Epoch: 10/10. Train set: Average loss: 0.0566
# Epoch: 10/10. Validation set: Average loss: 0.0591
# Number features: 37
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.186986
# Epoch: 1/10. Train set: Average loss: 0.0982
# Epoch: 1/10. Validation set: Average loss: 0.0882
# Train: [0/5622 (0%)]	Loss: 0.055180
# Epoch: 2/10. Train set: Average loss: 0.0725
# Epoch: 2/10. Validation set: Average loss: 0.0643
# Train: [0/5622 (0%)]	Loss: 0.038073
# Epoch: 3/10. Train set: Average loss: 0.0692
# Epoch: 3/10. Validation set: Average loss: 0.0708
# Train: [0/5622 (0%)]	Loss: 0.094019
# Epoch: 4/10. Train set: Average loss: 0.0629
# Epoch: 4/10. Validation set: Average loss: 0.0861
# Train: [0/5622 (0%)]	Loss: 0.155363
# Epoch: 5/10. Train set: Average loss: 0.0601
# Epoch: 5/10. Validation set: Average loss: 0.0869
# Train: [0/5622 (0%)]	Loss: 0.078555
# Epoch: 6/10. Train set: Average loss: 0.0567
# Epoch: 6/10. Validation set: Average loss: 0.0558
# Train: [0/5622 (0%)]	Loss: 0.042974
# Epoch: 7/10. Train set: Average loss: 0.0561
# Epoch: 7/10. Validation set: Average loss: 0.0677
# Train: [0/5622 (0%)]	Loss: 0.118627
# Epoch: 8/10. Train set: Average loss: 0.0545
# Epoch: 8/10. Validation set: Average loss: 0.0592
# Train: [0/5622 (0%)]	Loss: 0.095007
# Epoch: 9/10. Train set: Average loss: 0.0471
# Epoch: 9/10. Validation set: Average loss: 0.0456
# Train: [0/5622 (0%)]	Loss: 0.062591
# Epoch: 10/10. Train set: Average loss: 0.0448
# Epoch: 10/10. Validation set: Average loss: 0.0453
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.186859
# Epoch: 1/10. Train set: Average loss: 0.0865
# Epoch: 1/10. Validation set: Average loss: 0.1009
# Train: [0/5622 (0%)]	Loss: 0.129605
# Epoch: 2/10. Train set: Average loss: 0.0719
# Epoch: 2/10. Validation set: Average loss: 0.0792
# Train: [0/5622 (0%)]	Loss: 0.124273
# Epoch: 3/10. Train set: Average loss: 0.0685
# Epoch: 3/10. Validation set: Average loss: 0.0759
# Train: [0/5622 (0%)]	Loss: 0.099071
# Epoch: 4/10. Train set: Average loss: 0.0647
# Epoch: 4/10. Validation set: Average loss: 0.0585
# Train: [0/5622 (0%)]	Loss: 0.035540
# Epoch: 5/10. Train set: Average loss: 0.0589
# Epoch: 5/10. Validation set: Average loss: 0.0712
# Train: [0/5622 (0%)]	Loss: 0.287369
# Epoch: 6/10. Train set: Average loss: 0.0579
# Epoch: 6/10. Validation set: Average loss: 0.0601
# Train: [0/5622 (0%)]	Loss: 0.053515
# Epoch: 7/10. Train set: Average loss: 0.0557
# Epoch: 7/10. Validation set: Average loss: 0.0649
# Train: [0/5622 (0%)]	Loss: 0.105245
# Epoch: 8/10. Train set: Average loss: 0.0549
# Epoch: 8/10. Validation set: Average loss: 0.0683
# Train: [0/5622 (0%)]	Loss: 0.097160
# Epoch: 9/10. Train set: Average loss: 0.0514
# Epoch: 9/10. Validation set: Average loss: 0.0444
# Train: [0/5622 (0%)]	Loss: 0.013423
# Epoch: 10/10. Train set: Average loss: 0.0453
# Epoch: 10/10. Validation set: Average loss: 0.0451
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.249185
# Epoch: 1/10. Train set: Average loss: 0.0932
# Epoch: 1/10. Validation set: Average loss: 0.0708
# Train: [0/5622 (0%)]	Loss: 0.130691
# Epoch: 2/10. Train set: Average loss: 0.0741
# Epoch: 2/10. Validation set: Average loss: 0.0862
# Train: [0/5622 (0%)]	Loss: 0.042183
# Epoch: 3/10. Train set: Average loss: 0.0637
# Epoch: 3/10. Validation set: Average loss: 0.0722
# Train: [0/5622 (0%)]	Loss: 0.038692
# Epoch: 4/10. Train set: Average loss: 0.0614
# Epoch: 4/10. Validation set: Average loss: 0.0694
# Train: [0/5622 (0%)]	Loss: 0.019117
# Epoch: 5/10. Train set: Average loss: 0.0582
# Epoch: 5/10. Validation set: Average loss: 0.0806
# Train: [0/5622 (0%)]	Loss: 0.057229
# Epoch: 6/10. Train set: Average loss: 0.0605
# Epoch: 6/10. Validation set: Average loss: 0.0676
# Train: [0/5622 (0%)]	Loss: 0.133483
# Epoch: 7/10. Train set: Average loss: 0.0555
# Epoch: 7/10. Validation set: Average loss: 0.0588
# Train: [0/5622 (0%)]	Loss: 0.153097
# Epoch: 8/10. Train set: Average loss: 0.0526
# Epoch: 8/10. Validation set: Average loss: 0.0538
# Train: [0/5622 (0%)]	Loss: 0.015333
# Epoch: 9/10. Train set: Average loss: 0.0464
# Epoch: 9/10. Validation set: Average loss: 0.0459
# Train: [0/5622 (0%)]	Loss: 0.085343
# Epoch: 10/10. Train set: Average loss: 0.0430
# Epoch: 10/10. Validation set: Average loss: 0.0451
# Number features: 40
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.124374
# Epoch: 1/10. Train set: Average loss: 0.1076
# Epoch: 1/10. Validation set: Average loss: 0.0814
# Train: [0/5622 (0%)]	Loss: 0.181473
# Epoch: 2/10. Train set: Average loss: 0.0856
# Epoch: 2/10. Validation set: Average loss: 0.0712
# Train: [0/5622 (0%)]	Loss: 0.082958
# Epoch: 3/10. Train set: Average loss: 0.0741
# Epoch: 3/10. Validation set: Average loss: 0.0782
# Train: [0/5622 (0%)]	Loss: 0.027631
# Epoch: 4/10. Train set: Average loss: 0.0718
# Epoch: 4/10. Validation set: Average loss: 0.0788
# Train: [0/5622 (0%)]	Loss: 0.040527
# Epoch: 5/10. Train set: Average loss: 0.0754
# Epoch: 5/10. Validation set: Average loss: 0.0675
# Train: [0/5622 (0%)]	Loss: 0.024875
# Epoch: 6/10. Train set: Average loss: 0.0664
# Epoch: 6/10. Validation set: Average loss: 0.0653
# Train: [0/5622 (0%)]	Loss: 0.045278
# Epoch: 7/10. Train set: Average loss: 0.0773
# Epoch: 7/10. Validation set: Average loss: 0.0766
# Train: [0/5622 (0%)]	Loss: 0.092885
# Epoch: 8/10. Train set: Average loss: 0.0674
# Epoch: 8/10. Validation set: Average loss: 0.0654
# Train: [0/5622 (0%)]	Loss: 0.058080
# Epoch: 9/10. Train set: Average loss: 0.0601
# Epoch: 9/10. Validation set: Average loss: 0.0589
# Train: [0/5622 (0%)]	Loss: 0.066448
# Epoch: 10/10. Train set: Average loss: 0.0586
# Epoch: 10/10. Validation set: Average loss: 0.0570
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.187123
# Epoch: 1/10. Train set: Average loss: 0.0885
# Epoch: 1/10. Validation set: Average loss: 0.0773
# Train: [0/5622 (0%)]	Loss: 0.059920
# Epoch: 2/10. Train set: Average loss: 0.0720
# Epoch: 2/10. Validation set: Average loss: 0.0636
# Train: [0/5622 (0%)]	Loss: 0.125558
# Epoch: 3/10. Train set: Average loss: 0.0673
# Epoch: 3/10. Validation set: Average loss: 0.0704
# Train: [0/5622 (0%)]	Loss: 0.055150
# Epoch: 4/10. Train set: Average loss: 0.0666
# Epoch: 4/10. Validation set: Average loss: 0.0715
# Train: [0/5622 (0%)]	Loss: 0.042662
# Epoch: 5/10. Train set: Average loss: 0.0682
# Epoch: 5/10. Validation set: Average loss: 0.0601
# Train: [0/5622 (0%)]	Loss: 0.056370
# Epoch: 6/10. Train set: Average loss: 0.0623
# Epoch: 6/10. Validation set: Average loss: 0.0569
# Train: [0/5622 (0%)]	Loss: 0.054696
# Epoch: 7/10. Train set: Average loss: 0.0618
# Epoch: 7/10. Validation set: Average loss: 0.0593
# Train: [0/5622 (0%)]	Loss: 0.039993
# Epoch: 8/10. Train set: Average loss: 0.0588
# Epoch: 8/10. Validation set: Average loss: 0.0621
# Train: [0/5622 (0%)]	Loss: 0.081375
# Epoch: 9/10. Train set: Average loss: 0.0532
# Epoch: 9/10. Validation set: Average loss: 0.0538
# Train: [0/5622 (0%)]	Loss: 0.054601
# Epoch: 10/10. Train set: Average loss: 0.0503
# Epoch: 10/10. Validation set: Average loss: 0.0522
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.124688
# Epoch: 1/10. Train set: Average loss: 0.0944
# Epoch: 1/10. Validation set: Average loss: 0.0777
# Train: [0/5622 (0%)]	Loss: 0.051819
# Epoch: 2/10. Train set: Average loss: 0.0755
# Epoch: 2/10. Validation set: Average loss: 0.0835
# Train: [0/5622 (0%)]	Loss: 0.077484
# Epoch: 3/10. Train set: Average loss: 0.0700
# Epoch: 3/10. Validation set: Average loss: 0.0707
# Train: [0/5622 (0%)]	Loss: 0.056799
# Epoch: 4/10. Train set: Average loss: 0.0762
# Epoch: 4/10. Validation set: Average loss: 0.0706
# Train: [0/5622 (0%)]	Loss: 0.100130
# Epoch: 5/10. Train set: Average loss: 0.0698
# Epoch: 5/10. Validation set: Average loss: 0.0722
