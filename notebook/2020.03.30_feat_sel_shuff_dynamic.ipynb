# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("..")

import datetime
import pathlib

from collections import OrderedDict 

import numpy as np
import pandas as pd

# %%
# Pytorch
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable

# Custom
from dutils import Experiment
from trainer import fit
import visualization as vis
from tcga_datasets import SiameseDataset

# Models
from tcga_networks import EmbeddingNet, SiameseNet
from losses import ContrastiveLoss

# Metrics
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score as ANMI

# %%
def getTCGA(disease):
    path = "/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP/TCGA/TCGA_{}_counts.tsv.gz"
    files = [path.format(d) for d in disease]
    return files


def readGCP(files, biotype='protein_coding', mean=True):
    """
    Paths to count matrices.
    """
    data_dict = {}
    for f in files:
        key = os.path.basename(f).split("_")[1]
        data = pd.read_csv(f, sep='\t', index_col=0)
        # transcript metadata
        meta = pd.DataFrame([row[:-1] for row in data.index.str.split("|")],
                            columns=['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'GENE', 'BP', 'BIOTYPE'])
        meta = pd.MultiIndex.from_frame(meta)
        data.index = meta
        # subset transcripts
        data = data.xs(key=biotype, level='BIOTYPE')
        data = data.droplevel(['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'BP'])
        # average gene expression of splice variants
        data = data.T
        if mean:
            data = data.groupby(by=data.columns, axis=1).mean()
        data_dict[key] = data
    return data_dict


def uq_norm(df, q=0.75):
    """
    Upper quartile normalization of GEX for samples.
    """
    quantiles = df.quantile(q=q, axis=1)
    norm = df.divide(quantiles, axis=0)
    return norm


def process_TCGA(disease=['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']):
    base="/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP"
    # get files
    tcga_files = getTCGA(disease)
    # read meta/data
    tcga_meta = pd.read_csv(os.path.join(base, "TCGA/TCGA_GDC_ID_MAP.tsv"), sep="\t")
    tcga_raw = readGCP(tcga_files, mean=True)
    # combine samples
    tcga_raw = pd.concat(tcga_raw.values())
    # Upper quartile normalization
    tcga_raw = uq_norm(tcga_raw)
    # log norm
    tcga = tcga_raw.transform(np.log1p)
    return tcga, tcga_meta

# %%
def generate_fsets(data, n_features, steps=5):
    r = np.linspace(start=1, stop=n_features, num=steps, dtype='int')
    idx = [np.random.choice(data.shape[1], size=i, replace=False) for i in r]
    return idx

# %%
def feature_training(train_data, train_labels, test_data, test_labels, feature_idx, embedding, exp_dir, cuda=True):
    # Meta data
    meta_data = {"n_features":[],
                 "model":[],
                 "ANMI":[]}
    # Params
    batch_size = 8
    kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {'num_workers': 10}
    
    # Feature Index
    for batch, feat in enumerate(feature_idx):
        print("Number features: {}\n".format(len(feat)))
        exp_data = {'feature_idx':feat}
        # Define data
        siamese_train_dataset = SiameseDataset(data=train_data.iloc[:,feat],
                                           labels=train_labels,
                                           train=True)
        siamese_test_dataset = SiameseDataset(data=test_data.iloc[:,feat],
                                          labels=test_labels,
                                          train=False)
        # Loaders
        siamese_train_loader = torch.utils.data.DataLoader(siamese_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
        siamese_test_loader = torch.utils.data.DataLoader(siamese_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)
        # Instantiate model
        n_samples, n_features = siamese_train_dataset.train_data.shape
        for i in range(3):
            nmodel = 'model_{}'.format(i)
            print("\t{}".format(nmodel))
            embedding_net = EmbeddingNet(n_features, embedding)
            model = SiameseNet(embedding_net)
            if cuda:
                model.cuda()
            # Parameters
            margin = 1.
            loss_fn = ContrastiveLoss(margin)
            lr = 1e-3
            optimizer = optim.Adam(model.parameters(), lr=lr)
            scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
            n_epochs = 10
            log_interval = round(len(siamese_train_dataset)/1/batch_size)
            # Train
            train_loss, val_loss = fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, 
                                       n_epochs, cuda, log_interval)
            # Test Embeddings
            val_embeddings_baseline, val_labels_baseline = vis.extract_embeddings(siamese_test_dataset.test_data, siamese_test_dataset.labels, model)
            # Evaluation
            n_clusters = len(np.unique(test_labels))
            kmeans = KMeans(n_clusters=n_clusters)
            siamese_clusters = kmeans.fit_predict(val_embeddings_baseline)
            anmi = ANMI(siamese_clusters, val_labels_baseline)
            # Store
            meta_data['n_features'].append(len(feat))
            meta_data['model'].append(nmodel)
            meta_data['ANMI'].append(anmi)
            exp_data[nmodel] = {'data': (val_embeddings_baseline, val_labels_baseline),
                                'loss': (train_loss, val_loss),
                                'ANMI': anmi}
        pd.to_pickle(exp_data, os.path.join(exp_dir, "model_{}.pkl".format(len(feat))))
    pd.to_pickle(meta_data, os.path.join(exp_dir, "model_meta_data.pkl"))

# %%
def main(disease, sample_type, **kwargs):
    # GPUs
    os.environ["CUDA_VISIBLE_DEVICES"] = kwargs['device']
    cuda = torch.cuda.is_available()
    print("Cuda is available: {}".format(cuda))
    
    # Read / write / process
    tcga, tcga_meta = process_TCGA(disease)
    # Feature design
    feature_idx = generate_fsets(tcga, n_features=kwargs['n_features'], steps=kwargs['steps'])
    # Experiment design
    hierarchy = OrderedDict({'Disease':disease,
                             'Sample Type':sample_type})
    # Define experiment
    exp = Experiment(meta_data=tcga_meta,
                     hierarchy=hierarchy,
                     index='CGHubAnalysisID',
                     cases='Case ID',
                     min_samples=20)
    # Train / Test split
    exp.train_test_split(cases='Case ID')
    # Return data 
    train_data, train_labels = exp.get_data(tcga, subset="train", dtype=np.float32)
    test_data, test_labels = exp.get_data(tcga, subset="test", dtype=np.float32)
    
    # randomize labels
    np.random.shuffle(train_labels)
    
    # Path *fix*
    dtime = datetime.datetime.today().strftime("%Y.%m.%d_%H:%M")
    exp_dir = "/srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/{}_{}_{}_{}_{}-{}".format(dtime,
                                                                                                  kwargs['note'],
                                                                                                  len(exp.labels_dict),
                                                                                                  kwargs['embedding'],
                                                                                                  kwargs['n_features'], 
                                                                                                  kwargs['steps'])
    pathlib.Path(exp_dir).mkdir(parents=True, exist_ok=False)
    print('Saving to: \n{}'.format(exp_dir))
    
    # Meta data
    experiments = {'experiment': exp,
                   'train':(train_data, train_labels),
                   'test': (test_data, test_labels)}
    pd.to_pickle(experiments, os.path.join(exp_dir, "experiment_meta_data.pkl"))
    
    # Training
    feature_training(train_data, train_labels, test_data, test_labels, feature_idx, kwargs['embedding'], exp_dir)

# %% [markdown]
# ### Setup

# %%
base="/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP"
# read meta/data
tcga_meta = pd.read_csv(os.path.join(base, "TCGA/TCGA_GDC_ID_MAP.tsv"), sep="\t")
# select disease
disease = tcga_meta[tcga_meta['Sample Type']=='Solid Tissue Normal']['Disease'].value_counts()
disease = list(disease[disease>=20].index)
disease
# Out:
# ['BRCA',
#  'KIRC',
#  'LUAD',
#  'THCA',
#  'PRAD',
#  'LIHC',
#  'LUSC',
#  'HNSC',
#  'COAD',
#  'UCEC',
#  'KIRP',
#  'STAD',
#  'KICH']

# %%
sample_type = ['Primary Tumor', 'Solid Tissue Normal']
params = {"device":"4",
          "note":"shuffle",
          "n_features":50,
          "steps":150,
          "embedding":2}

# %%
main(disease=disease, sample_type=sample_type, **params)
# Out:
# Cuda is available: True
# Saving to:
# /srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/2020.03.30_09:13_shuffle_26_2_50-150
# Number features: 1
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.186943
# Epoch: 1/10. Train set: Average loss: 0.1767
# Epoch: 1/10. Validation set: Average loss: 0.1657
# Train: [0/5622 (0%)]	Loss: 0.224325
# Epoch: 2/10. Train set: Average loss: 0.1737
# Epoch: 2/10. Validation set: Average loss: 0.1654
# Train: [0/5622 (0%)]	Loss: 0.112294
# Epoch: 3/10. Train set: Average loss: 0.1734
# Epoch: 3/10. Validation set: Average loss: 0.1848
# Train: [0/5622 (0%)]	Loss: 0.163450
# Epoch: 4/10. Train set: Average loss: 0.1720
# Epoch: 4/10. Validation set: Average loss: 0.1687
# Train: [0/5622 (0%)]	Loss: 0.220558
# Epoch: 5/10. Train set: Average loss: 0.1727
# Epoch: 5/10. Validation set: Average loss: 0.1649
# Train: [0/5622 (0%)]	Loss: 0.186757
# Epoch: 6/10. Train set: Average loss: 0.1709
# Epoch: 6/10. Validation set: Average loss: 0.1710
# Train: [0/5622 (0%)]	Loss: 0.186479
# Epoch: 7/10. Train set: Average loss: 0.1719
# Epoch: 7/10. Validation set: Average loss: 0.1647
# Train: [0/5622 (0%)]	Loss: 0.160445
# Epoch: 8/10. Train set: Average loss: 0.1723
# Epoch: 8/10. Validation set: Average loss: 0.1664
# Train: [0/5622 (0%)]	Loss: 0.106067
# Epoch: 9/10. Train set: Average loss: 0.1678
# Epoch: 9/10. Validation set: Average loss: 0.1655
# Train: [0/5622 (0%)]	Loss: 0.107663
# Epoch: 10/10. Train set: Average loss: 0.1678
# Epoch: 10/10. Validation set: Average loss: 0.1645
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.186309
# Epoch: 1/10. Train set: Average loss: 0.1757
# Epoch: 1/10. Validation set: Average loss: 0.1657
# Train: [0/5622 (0%)]	Loss: 0.214942
# Epoch: 2/10. Train set: Average loss: 0.1759
# Epoch: 2/10. Validation set: Average loss: 0.1690
# Train: [0/5622 (0%)]	Loss: 0.081886
# Epoch: 3/10. Train set: Average loss: 0.1760
# Epoch: 3/10. Validation set: Average loss: 0.1652
# Train: [0/5622 (0%)]	Loss: 0.316310
# Epoch: 4/10. Train set: Average loss: 0.1744
# Epoch: 4/10. Validation set: Average loss: 0.1689
# Train: [0/5622 (0%)]	Loss: 0.126054
# Epoch: 5/10. Train set: Average loss: 0.1706
# Epoch: 5/10. Validation set: Average loss: 0.1637
# Train: [0/5622 (0%)]	Loss: 0.279339
# Epoch: 6/10. Train set: Average loss: 0.1754
# Epoch: 6/10. Validation set: Average loss: 0.1634
# Train: [0/5622 (0%)]	Loss: 0.301259
# Epoch: 7/10. Train set: Average loss: 0.1691
# Epoch: 7/10. Validation set: Average loss: 0.1685
# Train: [0/5622 (0%)]	Loss: 0.137574
# Epoch: 8/10. Train set: Average loss: 0.1703
# Epoch: 8/10. Validation set: Average loss: 0.1673
# Train: [0/5622 (0%)]	Loss: 0.182784
# Epoch: 9/10. Train set: Average loss: 0.1646
# Epoch: 9/10. Validation set: Average loss: 0.1606
# Train: [0/5622 (0%)]	Loss: 0.306353
# Epoch: 10/10. Train set: Average loss: 0.1665
# Epoch: 10/10. Validation set: Average loss: 0.1602
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.062476
# Epoch: 1/10. Train set: Average loss: 0.1802
# Epoch: 1/10. Validation set: Average loss: 0.1723
# Train: [0/5622 (0%)]	Loss: 0.106938
# Epoch: 2/10. Train set: Average loss: 0.1713
# Epoch: 2/10. Validation set: Average loss: 0.1754
# Train: [0/5622 (0%)]	Loss: 0.088349
# Epoch: 3/10. Train set: Average loss: 0.1734
# Epoch: 3/10. Validation set: Average loss: 0.1657
# Train: [0/5622 (0%)]	Loss: 0.087287
# Epoch: 4/10. Train set: Average loss: 0.1746
# Epoch: 4/10. Validation set: Average loss: 0.1649
# Train: [0/5622 (0%)]	Loss: 0.131733
# Epoch: 5/10. Train set: Average loss: 0.1750
# Epoch: 5/10. Validation set: Average loss: 0.1655
# Train: [0/5622 (0%)]	Loss: 0.128456
# Epoch: 6/10. Train set: Average loss: 0.1741
# Epoch: 6/10. Validation set: Average loss: 0.1710
# Train: [0/5622 (0%)]	Loss: 0.056708
# Epoch: 7/10. Train set: Average loss: 0.1641
# Epoch: 7/10. Validation set: Average loss: 0.1660
# Train: [0/5622 (0%)]	Loss: 0.128122
# Epoch: 8/10. Train set: Average loss: 0.1725
# Epoch: 8/10. Validation set: Average loss: 0.1672
# Train: [0/5622 (0%)]	Loss: 0.118414
# Epoch: 9/10. Train set: Average loss: 0.1682
# Epoch: 9/10. Validation set: Average loss: 0.1640
# Train: [0/5622 (0%)]	Loss: 0.182871
# Epoch: 10/10. Train set: Average loss: 0.1681
# Epoch: 10/10. Validation set: Average loss: 0.1640
# Number features: 1
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.186659
# Epoch: 1/10. Train set: Average loss: 0.1790
# Epoch: 1/10. Validation set: Average loss: 0.1870
# Train: [0/5622 (0%)]	Loss: 0.102015
# Epoch: 2/10. Train set: Average loss: 0.1753
# Epoch: 2/10. Validation set: Average loss: 0.1674
# Train: [0/5622 (0%)]	Loss: 0.128997
# Epoch: 3/10. Train set: Average loss: 0.1769
# Epoch: 3/10. Validation set: Average loss: 0.1819
# Train: [0/5622 (0%)]	Loss: 0.140702
# Epoch: 4/10. Train set: Average loss: 0.1733
# Epoch: 4/10. Validation set: Average loss: 0.1829
# Train: [0/5622 (0%)]	Loss: 0.155538
# Epoch: 5/10. Train set: Average loss: 0.1718
# Epoch: 5/10. Validation set: Average loss: 0.1643
# Train: [0/5622 (0%)]	Loss: 0.162196
# Epoch: 6/10. Train set: Average loss: 0.1695
# Epoch: 6/10. Validation set: Average loss: 0.1615
# Train: [0/5622 (0%)]	Loss: 0.192660
# Epoch: 7/10. Train set: Average loss: 0.1701
# Epoch: 7/10. Validation set: Average loss: 0.1936
# Train: [0/5622 (0%)]	Loss: 0.141509
# Epoch: 8/10. Train set: Average loss: 0.1640
# Epoch: 8/10. Validation set: Average loss: 0.1499
# Train: [0/5622 (0%)]	Loss: 0.154247
# Epoch: 9/10. Train set: Average loss: 0.1564
# Epoch: 9/10. Validation set: Average loss: 0.1453
# Train: [0/5622 (0%)]	Loss: 0.123191
# Epoch: 10/10. Train set: Average loss: 0.1594
# Epoch: 10/10. Validation set: Average loss: 0.1467
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.249603
# Epoch: 1/10. Train set: Average loss: 0.1783
# Epoch: 1/10. Validation set: Average loss: 0.1744
# Train: [0/5622 (0%)]	Loss: 0.222277
# Epoch: 2/10. Train set: Average loss: 0.1754
# Epoch: 2/10. Validation set: Average loss: 0.1553
# Train: [0/5622 (0%)]	Loss: 0.169841
# Epoch: 3/10. Train set: Average loss: 0.1717
# Epoch: 3/10. Validation set: Average loss: 0.1689
# Train: [0/5622 (0%)]	Loss: 0.190777
# Epoch: 4/10. Train set: Average loss: 0.1711
# Epoch: 4/10. Validation set: Average loss: 0.1690
# Train: [0/5622 (0%)]	Loss: 0.253769
# Epoch: 5/10. Train set: Average loss: 0.1721
# Epoch: 5/10. Validation set: Average loss: 0.1746
# Train: [0/5622 (0%)]	Loss: 0.233430
# Epoch: 6/10. Train set: Average loss: 0.1715
# Epoch: 6/10. Validation set: Average loss: 0.1646
# Train: [0/5622 (0%)]	Loss: 0.210431
# Epoch: 7/10. Train set: Average loss: 0.1689
# Epoch: 7/10. Validation set: Average loss: 0.1572
# Train: [0/5622 (0%)]	Loss: 0.217969
# Epoch: 8/10. Train set: Average loss: 0.1701
# Epoch: 8/10. Validation set: Average loss: 0.1707
# Train: [0/5622 (0%)]	Loss: 0.161935
# Epoch: 9/10. Train set: Average loss: 0.1594
# Epoch: 9/10. Validation set: Average loss: 0.1461
# Train: [0/5622 (0%)]	Loss: 0.188378
# Epoch: 10/10. Train set: Average loss: 0.1601
# Epoch: 10/10. Validation set: Average loss: 0.1459
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.187077
# Epoch: 1/10. Train set: Average loss: 0.1851
# Epoch: 1/10. Validation set: Average loss: 0.1763
# Train: [0/5622 (0%)]	Loss: 0.095963
# Epoch: 2/10. Train set: Average loss: 0.1783
# Epoch: 2/10. Validation set: Average loss: 0.1581
# Train: [0/5622 (0%)]	Loss: 0.196282
# Epoch: 3/10. Train set: Average loss: 0.1760
# Epoch: 3/10. Validation set: Average loss: 0.1734
# Train: [0/5622 (0%)]	Loss: 0.067239
# Epoch: 4/10. Train set: Average loss: 0.1779
# Epoch: 4/10. Validation set: Average loss: 0.1752
# Train: [0/5622 (0%)]	Loss: 0.121999
# Epoch: 5/10. Train set: Average loss: 0.1741
# Epoch: 5/10. Validation set: Average loss: 0.1589
# Train: [0/5622 (0%)]	Loss: 0.144063
# Epoch: 6/10. Train set: Average loss: 0.1748
# Epoch: 6/10. Validation set: Average loss: 0.1628
# Train: [0/5622 (0%)]	Loss: 0.110261
# Epoch: 7/10. Train set: Average loss: 0.1760
# Epoch: 7/10. Validation set: Average loss: 0.1817
# Train: [0/5622 (0%)]	Loss: 0.093733
# Epoch: 8/10. Train set: Average loss: 0.1721
# Epoch: 8/10. Validation set: Average loss: 0.1715
# Train: [0/5622 (0%)]	Loss: 0.093655
# Epoch: 9/10. Train set: Average loss: 0.1624
# Epoch: 9/10. Validation set: Average loss: 0.1498
# Train: [0/5622 (0%)]	Loss: 0.185602
# Epoch: 10/10. Train set: Average loss: 0.1628
# Epoch: 10/10. Validation set: Average loss: 0.1508
# Number features: 1
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.249928
# Epoch: 1/10. Train set: Average loss: 0.1718
# Epoch: 1/10. Validation set: Average loss: 0.1526
# Train: [0/5622 (0%)]	Loss: 0.390027
# Epoch: 2/10. Train set: Average loss: 0.1740
# Epoch: 2/10. Validation set: Average loss: 0.1505
# Train: [0/5622 (0%)]	Loss: 0.147994
# Epoch: 3/10. Train set: Average loss: 0.1717
# Epoch: 3/10. Validation set: Average loss: 0.1423
# Train: [0/5622 (0%)]	Loss: 0.203384
# Epoch: 4/10. Train set: Average loss: 0.1734
# Epoch: 4/10. Validation set: Average loss: 0.1514
# Train: [0/5622 (0%)]	Loss: 0.128354
# Epoch: 5/10. Train set: Average loss: 0.1717
# Epoch: 5/10. Validation set: Average loss: 0.1489
# Train: [0/5622 (0%)]	Loss: 0.223591
# Epoch: 6/10. Train set: Average loss: 0.1687
# Epoch: 6/10. Validation set: Average loss: 0.1513
# Train: [0/5622 (0%)]	Loss: 0.152282
# Epoch: 7/10. Train set: Average loss: 0.1698
# Epoch: 7/10. Validation set: Average loss: 0.1685
# Train: [0/5622 (0%)]	Loss: 0.262746
# Epoch: 8/10. Train set: Average loss: 0.1693
# Epoch: 8/10. Validation set: Average loss: 0.1442
# Train: [0/5622 (0%)]	Loss: 0.152476
# Epoch: 9/10. Train set: Average loss: 0.1644
# Epoch: 9/10. Validation set: Average loss: 0.1450
# Train: [0/5622 (0%)]	Loss: 0.162095
# Epoch: 10/10. Train set: Average loss: 0.1612
# Epoch: 10/10. Validation set: Average loss: 0.1519
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.124948
# Epoch: 1/10. Train set: Average loss: 0.1762
# Epoch: 1/10. Validation set: Average loss: 0.1482
# Train: [0/5622 (0%)]	Loss: 0.152205
# Epoch: 2/10. Train set: Average loss: 0.1785
# Epoch: 2/10. Validation set: Average loss: 0.1487
# Train: [0/5622 (0%)]	Loss: 0.126636
# Epoch: 3/10. Train set: Average loss: 0.1745
# Epoch: 3/10. Validation set: Average loss: 0.1429
# Train: [0/5622 (0%)]	Loss: 0.164619
# Epoch: 4/10. Train set: Average loss: 0.1737
# Epoch: 4/10. Validation set: Average loss: 0.1477
# Train: [0/5622 (0%)]	Loss: 0.095827
# Epoch: 5/10. Train set: Average loss: 0.1716
# Epoch: 5/10. Validation set: Average loss: 0.1429
# Train: [0/5622 (0%)]	Loss: 0.067597
# Epoch: 6/10. Train set: Average loss: 0.1694
# Epoch: 6/10. Validation set: Average loss: 0.1474
# Train: [0/5622 (0%)]	Loss: 0.224490
# Epoch: 7/10. Train set: Average loss: 0.1670
# Epoch: 7/10. Validation set: Average loss: 0.1407
# Train: [0/5622 (0%)]	Loss: 0.156488
# Epoch: 8/10. Train set: Average loss: 0.1600
# Epoch: 8/10. Validation set: Average loss: 0.1444
# Train: [0/5622 (0%)]	Loss: 0.156936
# Epoch: 9/10. Train set: Average loss: 0.1563
# Epoch: 9/10. Validation set: Average loss: 0.1408
# Train: [0/5622 (0%)]	Loss: 0.136703
# Epoch: 10/10. Train set: Average loss: 0.1532
# Epoch: 10/10. Validation set: Average loss: 0.1415
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.124828
# Epoch: 1/10. Train set: Average loss: 0.1733
# Epoch: 1/10. Validation set: Average loss: 0.2159
# Train: [0/5622 (0%)]	Loss: 0.746954
# Epoch: 2/10. Train set: Average loss: 0.1811
# Epoch: 2/10. Validation set: Average loss: 0.1792
# Train: [0/5622 (0%)]	Loss: 0.384193
# Epoch: 3/10. Train set: Average loss: 0.1771
# Epoch: 3/10. Validation set: Average loss: 0.1532
# Train: [0/5622 (0%)]	Loss: 0.063073
# Epoch: 4/10. Train set: Average loss: 0.1753
# Epoch: 4/10. Validation set: Average loss: 0.1416
# Train: [0/5622 (0%)]	Loss: 0.307094
# Epoch: 5/10. Train set: Average loss: 0.1741
# Epoch: 5/10. Validation set: Average loss: 0.1431
# Train: [0/5622 (0%)]	Loss: 0.206261
# Epoch: 6/10. Train set: Average loss: 0.1646
# Epoch: 6/10. Validation set: Average loss: 0.1496
# Train: [0/5622 (0%)]	Loss: 0.165275
# Epoch: 7/10. Train set: Average loss: 0.1649
# Epoch: 7/10. Validation set: Average loss: 0.1470
# Train: [0/5622 (0%)]	Loss: 0.193063
# Epoch: 8/10. Train set: Average loss: 0.1682
# Epoch: 8/10. Validation set: Average loss: 0.1556
# Train: [0/5622 (0%)]	Loss: 0.204033
# Epoch: 9/10. Train set: Average loss: 0.1568
# Epoch: 9/10. Validation set: Average loss: 0.1406
# Train: [0/5622 (0%)]	Loss: 0.147138
# Epoch: 10/10. Train set: Average loss: 0.1511
# Epoch: 10/10. Validation set: Average loss: 0.1358
# Number features: 1
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.248051
# Epoch: 1/10. Train set: Average loss: 0.1805
# Epoch: 1/10. Validation set: Average loss: 0.1901
# Train: [0/5622 (0%)]	Loss: 0.173455
# Epoch: 2/10. Train set: Average loss: 0.1714
# Epoch: 2/10. Validation set: Average loss: 0.1790
# Train: [0/5622 (0%)]	Loss: 0.198468
# Epoch: 3/10. Train set: Average loss: 0.1707
# Epoch: 3/10. Validation set: Average loss: 0.1595
# Train: [0/5622 (0%)]	Loss: 0.162458
# Epoch: 4/10. Train set: Average loss: 0.1671
# Epoch: 4/10. Validation set: Average loss: 0.1593
# Train: [0/5622 (0%)]	Loss: 0.136209
# Epoch: 5/10. Train set: Average loss: 0.1712
# Epoch: 5/10. Validation set: Average loss: 0.1576
# Train: [0/5622 (0%)]	Loss: 0.237033
# Epoch: 6/10. Train set: Average loss: 0.1704
# Epoch: 6/10. Validation set: Average loss: 0.1874
# Train: [0/5622 (0%)]	Loss: 0.157727
# Epoch: 7/10. Train set: Average loss: 0.1724
# Epoch: 7/10. Validation set: Average loss: 0.1538
# Train: [0/5622 (0%)]	Loss: 0.178743
# Epoch: 8/10. Train set: Average loss: 0.1712
# Epoch: 8/10. Validation set: Average loss: 0.1680
# Train: [0/5622 (0%)]	Loss: 0.138744
# Epoch: 9/10. Train set: Average loss: 0.1668
# Epoch: 9/10. Validation set: Average loss: 0.1460
# Train: [0/5622 (0%)]	Loss: 0.134030
# Epoch: 10/10. Train set: Average loss: 0.1641
# Epoch: 10/10. Validation set: Average loss: 0.1476
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.187452
# Epoch: 1/10. Train set: Average loss: 0.1776
# Epoch: 1/10. Validation set: Average loss: 0.1867
# Train: [0/5622 (0%)]	Loss: 0.161987
# Epoch: 2/10. Train set: Average loss: 0.1777
# Epoch: 2/10. Validation set: Average loss: 0.1565
# Train: [0/5622 (0%)]	Loss: 0.100710
# Epoch: 3/10. Train set: Average loss: 0.1750
# Epoch: 3/10. Validation set: Average loss: 0.1679
# Train: [0/5622 (0%)]	Loss: 0.124263
# Epoch: 4/10. Train set: Average loss: 0.1695
# Epoch: 4/10. Validation set: Average loss: 0.1918
# Train: [0/5622 (0%)]	Loss: 0.139689
# Epoch: 5/10. Train set: Average loss: 0.1724
# Epoch: 5/10. Validation set: Average loss: 0.1758
# Train: [0/5622 (0%)]	Loss: 0.142525
# Epoch: 6/10. Train set: Average loss: 0.1675
# Epoch: 6/10. Validation set: Average loss: 0.1710
# Train: [0/5622 (0%)]	Loss: 0.202158
# Epoch: 7/10. Train set: Average loss: 0.1697
# Epoch: 7/10. Validation set: Average loss: 0.1771
# Train: [0/5622 (0%)]	Loss: 0.143856
# Epoch: 8/10. Train set: Average loss: 0.1717
# Epoch: 8/10. Validation set: Average loss: 0.1570
# Train: [0/5622 (0%)]	Loss: 0.118723
# Epoch: 9/10. Train set: Average loss: 0.1714
# Epoch: 9/10. Validation set: Average loss: 0.1528
# Train: [0/5622 (0%)]	Loss: 0.188475
# Epoch: 10/10. Train set: Average loss: 0.1702
# Epoch: 10/10. Validation set: Average loss: 0.1505
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.374090
# Epoch: 1/10. Train set: Average loss: 0.1813
# Epoch: 1/10. Validation set: Average loss: 0.1779
# Train: [0/5622 (0%)]	Loss: 0.133641
# Epoch: 2/10. Train set: Average loss: 0.1754
# Epoch: 2/10. Validation set: Average loss: 0.1852
# Train: [0/5622 (0%)]	Loss: 0.186592
# Epoch: 3/10. Train set: Average loss: 0.1725
# Epoch: 3/10. Validation set: Average loss: 0.1660
# Train: [0/5622 (0%)]	Loss: 0.147482
# Epoch: 4/10. Train set: Average loss: 0.1704
# Epoch: 4/10. Validation set: Average loss: 0.1624
# Train: [0/5622 (0%)]	Loss: 0.152764
# Epoch: 5/10. Train set: Average loss: 0.1724
# Epoch: 5/10. Validation set: Average loss: 0.1662
# Train: [0/5622 (0%)]	Loss: 0.150666
# Epoch: 6/10. Train set: Average loss: 0.1716
# Epoch: 6/10. Validation set: Average loss: 0.1721
# Train: [0/5622 (0%)]	Loss: 0.204742
# Epoch: 7/10. Train set: Average loss: 0.1715
# Epoch: 7/10. Validation set: Average loss: 0.1706
# Train: [0/5622 (0%)]	Loss: 0.174728
# Epoch: 8/10. Train set: Average loss: 0.1746
# Epoch: 8/10. Validation set: Average loss: 0.1684
# Train: [0/5622 (0%)]	Loss: 0.206231
# Epoch: 9/10. Train set: Average loss: 0.1661
# Epoch: 9/10. Validation set: Average loss: 0.1545
# Train: [0/5622 (0%)]	Loss: 0.231189
# Epoch: 10/10. Train set: Average loss: 0.1695
# Epoch: 10/10. Validation set: Average loss: 0.1532
# Number features: 2
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.374956
# Epoch: 1/10. Train set: Average loss: 0.1879
# Epoch: 1/10. Validation set: Average loss: 0.1775
# Train: [0/5622 (0%)]	Loss: 0.431870
# Epoch: 2/10. Train set: Average loss: 0.1710
# Epoch: 2/10. Validation set: Average loss: 0.1857
# Train: [0/5622 (0%)]	Loss: 0.254162
# Epoch: 3/10. Train set: Average loss: 0.1677
# Epoch: 3/10. Validation set: Average loss: 0.1945
# Train: [0/5622 (0%)]	Loss: 0.193040
# Epoch: 4/10. Train set: Average loss: 0.1715
# Epoch: 4/10. Validation set: Average loss: 0.1841
# Train: [0/5622 (0%)]	Loss: 0.322386
# Epoch: 5/10. Train set: Average loss: 0.1674
# Epoch: 5/10. Validation set: Average loss: 0.1790
# Train: [0/5622 (0%)]	Loss: 0.197499
# Epoch: 6/10. Train set: Average loss: 0.1703
# Epoch: 6/10. Validation set: Average loss: 0.1835
# Train: [0/5622 (0%)]	Loss: 0.271950
# Epoch: 7/10. Train set: Average loss: 0.1699
# Epoch: 7/10. Validation set: Average loss: 0.1837
# Train: [0/5622 (0%)]	Loss: 0.240271
# Epoch: 8/10. Train set: Average loss: 0.1664
# Epoch: 8/10. Validation set: Average loss: 0.1763
# Train: [0/5622 (0%)]	Loss: 0.197901
# Epoch: 9/10. Train set: Average loss: 0.1674
# Epoch: 9/10. Validation set: Average loss: 0.1723
# Train: [0/5622 (0%)]	Loss: 0.351625
# Epoch: 10/10. Train set: Average loss: 0.1646
# Epoch: 10/10. Validation set: Average loss: 0.1683
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.374625
# Epoch: 1/10. Train set: Average loss: 0.1810
# Epoch: 1/10. Validation set: Average loss: 0.1681
# Train: [0/5622 (0%)]	Loss: 0.278048
# Epoch: 2/10. Train set: Average loss: 0.1639
# Epoch: 2/10. Validation set: Average loss: 0.1831
# Train: [0/5622 (0%)]	Loss: 0.286674
# Epoch: 3/10. Train set: Average loss: 0.1672
# Epoch: 3/10. Validation set: Average loss: 0.1830
# Train: [0/5622 (0%)]	Loss: 0.295574
# Epoch: 4/10. Train set: Average loss: 0.1707
# Epoch: 4/10. Validation set: Average loss: 0.1891
# Train: [0/5622 (0%)]	Loss: 0.314395
# Epoch: 5/10. Train set: Average loss: 0.1727
# Epoch: 5/10. Validation set: Average loss: 0.1874
# Train: [0/5622 (0%)]	Loss: 0.279021
# Epoch: 6/10. Train set: Average loss: 0.1700
# Epoch: 6/10. Validation set: Average loss: 0.1676
# Train: [0/5622 (0%)]	Loss: 0.198169
# Epoch: 7/10. Train set: Average loss: 0.1725
# Epoch: 7/10. Validation set: Average loss: 0.1793
# Train: [0/5622 (0%)]	Loss: 0.269515
# Epoch: 8/10. Train set: Average loss: 0.1773
# Epoch: 8/10. Validation set: Average loss: 0.1734
# Train: [0/5622 (0%)]	Loss: 0.244840
# Epoch: 9/10. Train set: Average loss: 0.1636
# Epoch: 9/10. Validation set: Average loss: 0.1687
# Train: [0/5622 (0%)]	Loss: 0.256851
# Epoch: 10/10. Train set: Average loss: 0.1625
# Epoch: 10/10. Validation set: Average loss: 0.1725
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.312410
# Epoch: 1/10. Train set: Average loss: 0.1771
# Epoch: 1/10. Validation set: Average loss: 0.1689
# Train: [0/5622 (0%)]	Loss: 0.187465
# Epoch: 2/10. Train set: Average loss: 0.1675
# Epoch: 2/10. Validation set: Average loss: 0.1719
# Train: [0/5622 (0%)]	Loss: 0.191618
# Epoch: 3/10. Train set: Average loss: 0.1707
# Epoch: 3/10. Validation set: Average loss: 0.1675
# Train: [0/5622 (0%)]	Loss: 0.205147
# Epoch: 4/10. Train set: Average loss: 0.1673
# Epoch: 4/10. Validation set: Average loss: 0.1723
# Train: [0/5622 (0%)]	Loss: 0.264457
# Epoch: 5/10. Train set: Average loss: 0.1688
# Epoch: 5/10. Validation set: Average loss: 0.1774
# Train: [0/5622 (0%)]	Loss: 0.241529
# Epoch: 6/10. Train set: Average loss: 0.1639
# Epoch: 6/10. Validation set: Average loss: 0.1854
# Train: [0/5622 (0%)]	Loss: 0.259583
# Epoch: 7/10. Train set: Average loss: 0.1615
# Epoch: 7/10. Validation set: Average loss: 0.1931
# Train: [0/5622 (0%)]	Loss: 0.530577
# Epoch: 8/10. Train set: Average loss: 0.1658
# Epoch: 8/10. Validation set: Average loss: 0.1814
# Train: [0/5622 (0%)]	Loss: 0.267761
# Epoch: 9/10. Train set: Average loss: 0.1639
# Epoch: 9/10. Validation set: Average loss: 0.1696
# Train: [0/5622 (0%)]	Loss: 0.218340
# Epoch: 10/10. Train set: Average loss: 0.1646
# Epoch: 10/10. Validation set: Average loss: 0.1698
# Number features: 2
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.249961
# Epoch: 1/10. Train set: Average loss: 0.1969
# Epoch: 1/10. Validation set: Average loss: 0.1934
# Train: [0/5622 (0%)]	Loss: 0.181537
# Epoch: 2/10. Train set: Average loss: 0.1758
# Epoch: 2/10. Validation set: Average loss: 0.1674
# Train: [0/5622 (0%)]	Loss: 0.211406
# Epoch: 3/10. Train set: Average loss: 0.1819
# Epoch: 3/10. Validation set: Average loss: 0.1636
# Train: [0/5622 (0%)]	Loss: 0.217474
# Epoch: 4/10. Train set: Average loss: 0.1673
# Epoch: 4/10. Validation set: Average loss: 0.1613
# Train: [0/5622 (0%)]	Loss: 0.194242
# Epoch: 5/10. Train set: Average loss: 0.1648
# Epoch: 5/10. Validation set: Average loss: 0.1633
# Train: [0/5622 (0%)]	Loss: 0.222325
# Epoch: 6/10. Train set: Average loss: 0.1659
# Epoch: 6/10. Validation set: Average loss: 0.1601
# Train: [0/5622 (0%)]	Loss: 0.116286
# Epoch: 7/10. Train set: Average loss: 0.1589
# Epoch: 7/10. Validation set: Average loss: 0.1531
# Train: [0/5622 (0%)]	Loss: 0.156722
# Epoch: 8/10. Train set: Average loss: 0.1604
# Epoch: 8/10. Validation set: Average loss: 0.1687
# Train: [0/5622 (0%)]	Loss: 0.160155
# Epoch: 9/10. Train set: Average loss: 0.1543
# Epoch: 9/10. Validation set: Average loss: 0.1479
# Train: [0/5622 (0%)]	Loss: 0.138750
# Epoch: 10/10. Train set: Average loss: 0.1485
# Epoch: 10/10. Validation set: Average loss: 0.1451
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.062482
# Epoch: 1/10. Train set: Average loss: 0.1937
# Epoch: 1/10. Validation set: Average loss: 0.1734
# Train: [0/5622 (0%)]	Loss: 0.108171
# Epoch: 2/10. Train set: Average loss: 0.1752
# Epoch: 2/10. Validation set: Average loss: 0.1713
# Train: [0/5622 (0%)]	Loss: 0.138062
# Epoch: 3/10. Train set: Average loss: 0.1690
# Epoch: 3/10. Validation set: Average loss: 0.1623
# Train: [0/5622 (0%)]	Loss: 0.084925
# Epoch: 4/10. Train set: Average loss: 0.1610
# Epoch: 4/10. Validation set: Average loss: 0.1686
# Train: [0/5622 (0%)]	Loss: 0.160049
# Epoch: 5/10. Train set: Average loss: 0.1648
# Epoch: 5/10. Validation set: Average loss: 0.1624
# Train: [0/5622 (0%)]	Loss: 0.107828
# Epoch: 6/10. Train set: Average loss: 0.1707
# Epoch: 6/10. Validation set: Average loss: 0.1586
# Train: [0/5622 (0%)]	Loss: 0.125097
# Epoch: 7/10. Train set: Average loss: 0.1583
# Epoch: 7/10. Validation set: Average loss: 0.1601
# Train: [0/5622 (0%)]	Loss: 0.074489
# Epoch: 8/10. Train set: Average loss: 0.1593
# Epoch: 8/10. Validation set: Average loss: 0.1468
# Train: [0/5622 (0%)]	Loss: 0.119580
# Epoch: 9/10. Train set: Average loss: 0.1501
# Epoch: 9/10. Validation set: Average loss: 0.1461
# Train: [0/5622 (0%)]	Loss: 0.168938
# Epoch: 10/10. Train set: Average loss: 0.1488
# Epoch: 10/10. Validation set: Average loss: 0.1457
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.312043
# Epoch: 1/10. Train set: Average loss: 0.2007
# Epoch: 1/10. Validation set: Average loss: 0.1875
# Train: [0/5622 (0%)]	Loss: 0.182219
# Epoch: 2/10. Train set: Average loss: 0.1748
# Epoch: 2/10. Validation set: Average loss: 0.1747
# Train: [0/5622 (0%)]	Loss: 0.171566
# Epoch: 3/10. Train set: Average loss: 0.1748
# Epoch: 3/10. Validation set: Average loss: 0.1732
# Train: [0/5622 (0%)]	Loss: 0.191660
# Epoch: 4/10. Train set: Average loss: 0.1704
# Epoch: 4/10. Validation set: Average loss: 0.1671
# Train: [0/5622 (0%)]	Loss: 0.141035
# Epoch: 5/10. Train set: Average loss: 0.1625
# Epoch: 5/10. Validation set: Average loss: 0.1647
# Train: [0/5622 (0%)]	Loss: 0.147816
# Epoch: 6/10. Train set: Average loss: 0.1678
# Epoch: 6/10. Validation set: Average loss: 0.1729
# Train: [0/5622 (0%)]	Loss: 0.204112
# Epoch: 7/10. Train set: Average loss: 0.1670
# Epoch: 7/10. Validation set: Average loss: 0.1677
# Train: [0/5622 (0%)]	Loss: 0.196335
# Epoch: 8/10. Train set: Average loss: 0.1685
# Epoch: 8/10. Validation set: Average loss: 0.1731
# Train: [0/5622 (0%)]	Loss: 0.201624
# Epoch: 9/10. Train set: Average loss: 0.1603
# Epoch: 9/10. Validation set: Average loss: 0.1587
# Train: [0/5622 (0%)]	Loss: 0.161837
# Epoch: 10/10. Train set: Average loss: 0.1552
# Epoch: 10/10. Validation set: Average loss: 0.1561
# Number features: 2
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.249402
# Epoch: 1/10. Train set: Average loss: 0.1664
# Epoch: 1/10. Validation set: Average loss: 0.1522
# Train: [0/5622 (0%)]	Loss: 0.228282
# Epoch: 2/10. Train set: Average loss: 0.1633
# Epoch: 2/10. Validation set: Average loss: 0.1352
# Train: [0/5622 (0%)]	Loss: 0.207219
# Epoch: 3/10. Train set: Average loss: 0.1609
# Epoch: 3/10. Validation set: Average loss: 0.1336
# Train: [0/5622 (0%)]	Loss: 0.196192
# Epoch: 4/10. Train set: Average loss: 0.1511
# Epoch: 4/10. Validation set: Average loss: 0.1463
# Train: [0/5622 (0%)]	Loss: 0.217686
# Epoch: 5/10. Train set: Average loss: 0.1499
# Epoch: 5/10. Validation set: Average loss: 0.1270
# Train: [0/5622 (0%)]	Loss: 0.150547
# Epoch: 6/10. Train set: Average loss: 0.1477
# Epoch: 6/10. Validation set: Average loss: 0.1433
# Train: [0/5622 (0%)]	Loss: 0.211941
# Epoch: 7/10. Train set: Average loss: 0.1502
# Epoch: 7/10. Validation set: Average loss: 0.1345
# Train: [0/5622 (0%)]	Loss: 0.184345
# Epoch: 8/10. Train set: Average loss: 0.1480
# Epoch: 8/10. Validation set: Average loss: 0.1323
# Train: [0/5622 (0%)]	Loss: 0.178976
# Epoch: 9/10. Train set: Average loss: 0.1466
# Epoch: 9/10. Validation set: Average loss: 0.1261
# Train: [0/5622 (0%)]	Loss: 0.144329
# Epoch: 10/10. Train set: Average loss: 0.1441
# Epoch: 10/10. Validation set: Average loss: 0.1266
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.499602
# Epoch: 1/10. Train set: Average loss: 0.1761
# Epoch: 1/10. Validation set: Average loss: 0.1608
# Train: [0/5622 (0%)]	Loss: 0.300264
# Epoch: 2/10. Train set: Average loss: 0.1573
# Epoch: 2/10. Validation set: Average loss: 0.1370
# Train: [0/5622 (0%)]	Loss: 0.216789
# Epoch: 3/10. Train set: Average loss: 0.1569
# Epoch: 3/10. Validation set: Average loss: 0.1312
# Train: [0/5622 (0%)]	Loss: 0.262829
# Epoch: 4/10. Train set: Average loss: 0.1552
# Epoch: 4/10. Validation set: Average loss: 0.1598
# Train: [0/5622 (0%)]	Loss: 0.219932
# Epoch: 5/10. Train set: Average loss: 0.1542
# Epoch: 5/10. Validation set: Average loss: 0.1476
# Train: [0/5622 (0%)]	Loss: 0.305439
# Epoch: 6/10. Train set: Average loss: 0.1508
# Epoch: 6/10. Validation set: Average loss: 0.1456
# Train: [0/5622 (0%)]	Loss: 0.230248
# Epoch: 7/10. Train set: Average loss: 0.1512
# Epoch: 7/10. Validation set: Average loss: 0.1350
# Train: [0/5622 (0%)]	Loss: 0.230205
# Epoch: 8/10. Train set: Average loss: 0.1494
# Epoch: 8/10. Validation set: Average loss: 0.1386
# Train: [0/5622 (0%)]	Loss: 0.233316
# Epoch: 9/10. Train set: Average loss: 0.1469
# Epoch: 9/10. Validation set: Average loss: 0.1283
# Train: [0/5622 (0%)]	Loss: 0.184719
# Epoch: 10/10. Train set: Average loss: 0.1463
# Epoch: 10/10. Validation set: Average loss: 0.1282
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.436046
# Epoch: 1/10. Train set: Average loss: 0.1738
# Epoch: 1/10. Validation set: Average loss: 0.1686
# Train: [0/5622 (0%)]	Loss: 0.291562
# Epoch: 2/10. Train set: Average loss: 0.1513
# Epoch: 2/10. Validation set: Average loss: 0.1435
# Train: [0/5622 (0%)]	Loss: 0.200680
# Epoch: 3/10. Train set: Average loss: 0.1568
# Epoch: 3/10. Validation set: Average loss: 0.1428
# Train: [0/5622 (0%)]	Loss: 0.217871
# Epoch: 4/10. Train set: Average loss: 0.1676
# Epoch: 4/10. Validation set: Average loss: 0.1718
# Train: [0/5622 (0%)]	Loss: 0.290911
# Epoch: 5/10. Train set: Average loss: 0.1535
# Epoch: 5/10. Validation set: Average loss: 0.1541
# Train: [0/5622 (0%)]	Loss: 0.223813
# Epoch: 6/10. Train set: Average loss: 0.1550
# Epoch: 6/10. Validation set: Average loss: 0.1458
# Train: [0/5622 (0%)]	Loss: 0.190467
# Epoch: 7/10. Train set: Average loss: 0.1539
# Epoch: 7/10. Validation set: Average loss: 0.1427
# Train: [0/5622 (0%)]	Loss: 0.248661
# Epoch: 8/10. Train set: Average loss: 0.1521
# Epoch: 8/10. Validation set: Average loss: 0.1521
# Train: [0/5622 (0%)]	Loss: 0.163876
# Epoch: 9/10. Train set: Average loss: 0.1501
# Epoch: 9/10. Validation set: Average loss: 0.1290
# Train: [0/5622 (0%)]	Loss: 0.187521
# Epoch: 10/10. Train set: Average loss: 0.1462
# Epoch: 10/10. Validation set: Average loss: 0.1289
# Number features: 3
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.249815
# Epoch: 1/10. Train set: Average loss: 0.1824
# Epoch: 1/10. Validation set: Average loss: 0.1709
# Train: [0/5622 (0%)]	Loss: 0.093111
# Epoch: 2/10. Train set: Average loss: 0.1649
# Epoch: 2/10. Validation set: Average loss: 0.1600
# Train: [0/5622 (0%)]	Loss: 0.216780
# Epoch: 3/10. Train set: Average loss: 0.1640
# Epoch: 3/10. Validation set: Average loss: 0.1462
# Train: [0/5622 (0%)]	Loss: 0.057465
# Epoch: 4/10. Train set: Average loss: 0.1609
# Epoch: 4/10. Validation set: Average loss: 0.1397
# Train: [0/5622 (0%)]	Loss: 0.073659
# Epoch: 5/10. Train set: Average loss: 0.1582
# Epoch: 5/10. Validation set: Average loss: 0.1549
# Train: [0/5622 (0%)]	Loss: 0.172322
# Epoch: 6/10. Train set: Average loss: 0.1535
# Epoch: 6/10. Validation set: Average loss: 0.1477
# Train: [0/5622 (0%)]	Loss: 0.145522
# Epoch: 7/10. Train set: Average loss: 0.1530
# Epoch: 7/10. Validation set: Average loss: 0.1399
# Train: [0/5622 (0%)]	Loss: 0.145201
# Epoch: 8/10. Train set: Average loss: 0.1628
# Epoch: 8/10. Validation set: Average loss: 0.1450
# Train: [0/5622 (0%)]	Loss: 0.102615
# Epoch: 9/10. Train set: Average loss: 0.1538
# Epoch: 9/10. Validation set: Average loss: 0.1404
# Train: [0/5622 (0%)]	Loss: 0.135846
# Epoch: 10/10. Train set: Average loss: 0.1522
# Epoch: 10/10. Validation set: Average loss: 0.1392
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.000000
# Epoch: 1/10. Train set: Average loss: 0.1786
# Epoch: 1/10. Validation set: Average loss: 0.2627
# Train: [0/5622 (0%)]	Loss: 0.529654
# Epoch: 2/10. Train set: Average loss: 0.1673
# Epoch: 2/10. Validation set: Average loss: 0.1627
# Train: [0/5622 (0%)]	Loss: 0.042394
# Epoch: 3/10. Train set: Average loss: 0.1714
# Epoch: 3/10. Validation set: Average loss: 0.1748
# Train: [0/5622 (0%)]	Loss: 0.097408
# Epoch: 4/10. Train set: Average loss: 0.1698
# Epoch: 4/10. Validation set: Average loss: 0.1673
# Train: [0/5622 (0%)]	Loss: 0.052528
# Epoch: 5/10. Train set: Average loss: 0.1627
# Epoch: 5/10. Validation set: Average loss: 0.1494
# Train: [0/5622 (0%)]	Loss: 0.057596
# Epoch: 6/10. Train set: Average loss: 0.1568
# Epoch: 6/10. Validation set: Average loss: 0.1421
# Train: [0/5622 (0%)]	Loss: 0.081183
# Epoch: 7/10. Train set: Average loss: 0.1526
# Epoch: 7/10. Validation set: Average loss: 0.1393
# Train: [0/5622 (0%)]	Loss: 0.081448
# Epoch: 8/10. Train set: Average loss: 0.1532
# Epoch: 8/10. Validation set: Average loss: 0.1527
# Train: [0/5622 (0%)]	Loss: 0.167184
# Epoch: 9/10. Train set: Average loss: 0.1506
# Epoch: 9/10. Validation set: Average loss: 0.1367
# Train: [0/5622 (0%)]	Loss: 0.113817
# Epoch: 10/10. Train set: Average loss: 0.1495
# Epoch: 10/10. Validation set: Average loss: 0.1370
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.124898
# Epoch: 1/10. Train set: Average loss: 0.1795
# Epoch: 1/10. Validation set: Average loss: 0.1795
# Train: [0/5622 (0%)]	Loss: 0.083742
# Epoch: 2/10. Train set: Average loss: 0.1751
# Epoch: 2/10. Validation set: Average loss: 0.1678
# Train: [0/5622 (0%)]	Loss: 0.074552
# Epoch: 3/10. Train set: Average loss: 0.1640
# Epoch: 3/10. Validation set: Average loss: 0.1524
# Train: [0/5622 (0%)]	Loss: 0.174755
# Epoch: 4/10. Train set: Average loss: 0.1595
# Epoch: 4/10. Validation set: Average loss: 0.1466
# Train: [0/5622 (0%)]	Loss: 0.063032
# Epoch: 5/10. Train set: Average loss: 0.1568
# Epoch: 5/10. Validation set: Average loss: 0.1393
# Train: [0/5622 (0%)]	Loss: 0.107502
# Epoch: 6/10. Train set: Average loss: 0.1533
# Epoch: 6/10. Validation set: Average loss: 0.1411
# Train: [0/5622 (0%)]	Loss: 0.150817
# Epoch: 7/10. Train set: Average loss: 0.1549
# Epoch: 7/10. Validation set: Average loss: 0.1385
# Train: [0/5622 (0%)]	Loss: 0.115894
# Epoch: 8/10. Train set: Average loss: 0.1560
# Epoch: 8/10. Validation set: Average loss: 0.1434
# Train: [0/5622 (0%)]	Loss: 0.065615
# Epoch: 9/10. Train set: Average loss: 0.1477
# Epoch: 9/10. Validation set: Average loss: 0.1394
# Train: [0/5622 (0%)]	Loss: 0.102875
# Epoch: 10/10. Train set: Average loss: 0.1480
# Epoch: 10/10. Validation set: Average loss: 0.1388
# Number features: 3
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.187448
# Epoch: 1/10. Train set: Average loss: 0.1798
# Epoch: 1/10. Validation set: Average loss: 0.1326
# Train: [0/5622 (0%)]	Loss: 0.135859
# Epoch: 2/10. Train set: Average loss: 0.1631
# Epoch: 2/10. Validation set: Average loss: 0.1391
# Train: [0/5622 (0%)]	Loss: 0.098193
# Epoch: 3/10. Train set: Average loss: 0.1611
# Epoch: 3/10. Validation set: Average loss: 0.1222
# Train: [0/5622 (0%)]	Loss: 0.110975
# Epoch: 4/10. Train set: Average loss: 0.1560
# Epoch: 4/10. Validation set: Average loss: 0.1175
# Train: [0/5622 (0%)]	Loss: 0.092727
# Epoch: 5/10. Train set: Average loss: 0.1516
# Epoch: 5/10. Validation set: Average loss: 0.1210
# Train: [0/5622 (0%)]	Loss: 0.160754
# Epoch: 6/10. Train set: Average loss: 0.1535
# Epoch: 6/10. Validation set: Average loss: 0.1154
# Train: [0/5622 (0%)]	Loss: 0.120853
# Epoch: 7/10. Train set: Average loss: 0.1537
# Epoch: 7/10. Validation set: Average loss: 0.1153
# Train: [0/5622 (0%)]	Loss: 0.107981
# Epoch: 8/10. Train set: Average loss: 0.1508
# Epoch: 8/10. Validation set: Average loss: 0.1196
# Train: [0/5622 (0%)]	Loss: 0.215995
# Epoch: 9/10. Train set: Average loss: 0.1478
# Epoch: 9/10. Validation set: Average loss: 0.1199
# Train: [0/5622 (0%)]	Loss: 0.116370
# Epoch: 10/10. Train set: Average loss: 0.1492
# Epoch: 10/10. Validation set: Average loss: 0.1192
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.187266
# Epoch: 1/10. Train set: Average loss: 0.1709
# Epoch: 1/10. Validation set: Average loss: 0.1460
# Train: [0/5622 (0%)]	Loss: 0.127747
# Epoch: 2/10. Train set: Average loss: 0.1585
# Epoch: 2/10. Validation set: Average loss: 0.1319
# Train: [0/5622 (0%)]	Loss: 0.105146
# Epoch: 3/10. Train set: Average loss: 0.1594
# Epoch: 3/10. Validation set: Average loss: 0.1347
# Train: [0/5622 (0%)]	Loss: 0.096574
# Epoch: 4/10. Train set: Average loss: 0.1588
# Epoch: 4/10. Validation set: Average loss: 0.1151
# Train: [0/5622 (0%)]	Loss: 0.237536
# Epoch: 5/10. Train set: Average loss: 0.1546
# Epoch: 5/10. Validation set: Average loss: 0.1175
# Train: [0/5622 (0%)]	Loss: 0.135865
# Epoch: 6/10. Train set: Average loss: 0.1517
# Epoch: 6/10. Validation set: Average loss: 0.1144
# Train: [0/5622 (0%)]	Loss: 0.144731
# Epoch: 7/10. Train set: Average loss: 0.1518
# Epoch: 7/10. Validation set: Average loss: 0.1190
# Train: [0/5622 (0%)]	Loss: 0.125749
# Epoch: 8/10. Train set: Average loss: 0.1518
# Epoch: 8/10. Validation set: Average loss: 0.1109
# Train: [0/5622 (0%)]	Loss: 0.243261
# Epoch: 9/10. Train set: Average loss: 0.1501
# Epoch: 9/10. Validation set: Average loss: 0.1197
# Train: [0/5622 (0%)]	Loss: 0.101966
# Epoch: 10/10. Train set: Average loss: 0.1504
# Epoch: 10/10. Validation set: Average loss: 0.1199
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.187391
# Epoch: 1/10. Train set: Average loss: 0.1756
# Epoch: 1/10. Validation set: Average loss: 0.1429
# Train: [0/5622 (0%)]	Loss: 0.244479
# Epoch: 2/10. Train set: Average loss: 0.1640
# Epoch: 2/10. Validation set: Average loss: 0.1235
# Train: [0/5622 (0%)]	Loss: 0.141045
# Epoch: 3/10. Train set: Average loss: 0.1585
# Epoch: 3/10. Validation set: Average loss: 0.1161
# Train: [0/5622 (0%)]	Loss: 0.112469
# Epoch: 4/10. Train set: Average loss: 0.1519
# Epoch: 4/10. Validation set: Average loss: 0.1196
# Train: [0/5622 (0%)]	Loss: 0.115898
# Epoch: 5/10. Train set: Average loss: 0.1536
# Epoch: 5/10. Validation set: Average loss: 0.1187
# Train: [0/5622 (0%)]	Loss: 0.130890
# Epoch: 6/10. Train set: Average loss: 0.1557
# Epoch: 6/10. Validation set: Average loss: 0.1230
# Train: [0/5622 (0%)]	Loss: 0.119730
# Epoch: 7/10. Train set: Average loss: 0.1538
# Epoch: 7/10. Validation set: Average loss: 0.1115
# Train: [0/5622 (0%)]	Loss: 0.177234
# Epoch: 8/10. Train set: Average loss: 0.1514
# Epoch: 8/10. Validation set: Average loss: 0.1140
# Train: [0/5622 (0%)]	Loss: 0.166298
# Epoch: 9/10. Train set: Average loss: 0.1503
# Epoch: 9/10. Validation set: Average loss: 0.1169
# Train: [0/5622 (0%)]	Loss: 0.149122
# Epoch: 10/10. Train set: Average loss: 0.1482
# Epoch: 10/10. Validation set: Average loss: 0.1178
# Number features: 3
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.311446
# Epoch: 1/10. Train set: Average loss: 0.1642
# Epoch: 1/10. Validation set: Average loss: 0.1684
# Train: [0/5622 (0%)]	Loss: 0.249423
# Epoch: 2/10. Train set: Average loss: 0.1580
# Epoch: 2/10. Validation set: Average loss: 0.1519
# Train: [0/5622 (0%)]	Loss: 0.166089
# Epoch: 3/10. Train set: Average loss: 0.1565
# Epoch: 3/10. Validation set: Average loss: 0.1250
# Train: [0/5622 (0%)]	Loss: 0.154551
# Epoch: 4/10. Train set: Average loss: 0.1585
# Epoch: 4/10. Validation set: Average loss: 0.1241
# Train: [0/5622 (0%)]	Loss: 0.205261
# Epoch: 5/10. Train set: Average loss: 0.1510
# Epoch: 5/10. Validation set: Average loss: 0.1364
# Train: [0/5622 (0%)]	Loss: 0.132284
# Epoch: 6/10. Train set: Average loss: 0.1556
# Epoch: 6/10. Validation set: Average loss: 0.1420
# Train: [0/5622 (0%)]	Loss: 0.155964
# Epoch: 7/10. Train set: Average loss: 0.1528
# Epoch: 7/10. Validation set: Average loss: 0.1396
# Train: [0/5622 (0%)]	Loss: 0.181671
# Epoch: 8/10. Train set: Average loss: 0.1524
# Epoch: 8/10. Validation set: Average loss: 0.1470
# Train: [0/5622 (0%)]	Loss: 0.198044
# Epoch: 9/10. Train set: Average loss: 0.1492
# Epoch: 9/10. Validation set: Average loss: 0.1284
# Train: [0/5622 (0%)]	Loss: 0.215422
# Epoch: 10/10. Train set: Average loss: 0.1471
# Epoch: 10/10. Validation set: Average loss: 0.1254
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.372954
# Epoch: 1/10. Train set: Average loss: 0.1634
# Epoch: 1/10. Validation set: Average loss: 0.1498
# Train: [0/5622 (0%)]	Loss: 0.145824
# Epoch: 2/10. Train set: Average loss: 0.1579
# Epoch: 2/10. Validation set: Average loss: 0.1582
# Train: [0/5622 (0%)]	Loss: 0.267111
# Epoch: 3/10. Train set: Average loss: 0.1575
# Epoch: 3/10. Validation set: Average loss: 0.1583
# Train: [0/5622 (0%)]	Loss: 0.171363
# Epoch: 4/10. Train set: Average loss: 0.1629
# Epoch: 4/10. Validation set: Average loss: 0.1432
# Train: [0/5622 (0%)]	Loss: 0.167933
# Epoch: 5/10. Train set: Average loss: 0.1601
# Epoch: 5/10. Validation set: Average loss: 0.1577
# Train: [0/5622 (0%)]	Loss: 0.255355
# Epoch: 6/10. Train set: Average loss: 0.1551
# Epoch: 6/10. Validation set: Average loss: 0.1483
# Train: [0/5622 (0%)]	Loss: 0.231483
# Epoch: 7/10. Train set: Average loss: 0.1607
# Epoch: 7/10. Validation set: Average loss: 0.1412
# Train: [0/5622 (0%)]	Loss: 0.184912
# Epoch: 8/10. Train set: Average loss: 0.1520
# Epoch: 8/10. Validation set: Average loss: 0.1424
# Train: [0/5622 (0%)]	Loss: 0.243528
# Epoch: 9/10. Train set: Average loss: 0.1500
# Epoch: 9/10. Validation set: Average loss: 0.1248
# Train: [0/5622 (0%)]	Loss: 0.228832
# Epoch: 10/10. Train set: Average loss: 0.1498
# Epoch: 10/10. Validation set: Average loss: 0.1243
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.249491
# Epoch: 1/10. Train set: Average loss: 0.1629
# Epoch: 1/10. Validation set: Average loss: 0.1679
# Train: [0/5622 (0%)]	Loss: 0.173986
# Epoch: 2/10. Train set: Average loss: 0.1623
# Epoch: 2/10. Validation set: Average loss: 0.1591
# Train: [0/5622 (0%)]	Loss: 0.184676
# Epoch: 3/10. Train set: Average loss: 0.1638
# Epoch: 3/10. Validation set: Average loss: 0.1351
# Train: [0/5622 (0%)]	Loss: 0.176758
# Epoch: 4/10. Train set: Average loss: 0.1542
# Epoch: 4/10. Validation set: Average loss: 0.1568
# Train: [0/5622 (0%)]	Loss: 0.180346
# Epoch: 5/10. Train set: Average loss: 0.1563
# Epoch: 5/10. Validation set: Average loss: 0.1585
# Train: [0/5622 (0%)]	Loss: 0.194423
# Epoch: 6/10. Train set: Average loss: 0.1570
# Epoch: 6/10. Validation set: Average loss: 0.1466
# Train: [0/5622 (0%)]	Loss: 0.159204
# Epoch: 7/10. Train set: Average loss: 0.1562
# Epoch: 7/10. Validation set: Average loss: 0.1449
# Train: [0/5622 (0%)]	Loss: 0.116058
# Epoch: 8/10. Train set: Average loss: 0.1545
# Epoch: 8/10. Validation set: Average loss: 0.1547
# Train: [0/5622 (0%)]	Loss: 0.132397
# Epoch: 9/10. Train set: Average loss: 0.1487
# Epoch: 9/10. Validation set: Average loss: 0.1291
# Train: [0/5622 (0%)]	Loss: 0.151268
# Epoch: 10/10. Train set: Average loss: 0.1472
# Epoch: 10/10. Validation set: Average loss: 0.1318
# Number features: 4
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.311676
# Epoch: 1/10. Train set: Average loss: 0.1704
# Epoch: 1/10. Validation set: Average loss: 0.1647
# Train: [0/5622 (0%)]	Loss: 0.229379
# Epoch: 2/10. Train set: Average loss: 0.1599
# Epoch: 2/10. Validation set: Average loss: 0.1232
# Train: [0/5622 (0%)]	Loss: 0.239419
# Epoch: 3/10. Train set: Average loss: 0.1610
# Epoch: 3/10. Validation set: Average loss: 0.1346
# Train: [0/5622 (0%)]	Loss: 0.219637
# Epoch: 4/10. Train set: Average loss: 0.1620
# Epoch: 4/10. Validation set: Average loss: 0.1402
# Train: [0/5622 (0%)]	Loss: 0.155285
# Epoch: 5/10. Train set: Average loss: 0.1547
# Epoch: 5/10. Validation set: Average loss: 0.1738
# Train: [0/5622 (0%)]	Loss: 0.296030
# Epoch: 6/10. Train set: Average loss: 0.1567
# Epoch: 6/10. Validation set: Average loss: 0.1378
# Train: [0/5622 (0%)]	Loss: 0.188868
# Epoch: 7/10. Train set: Average loss: 0.1548
# Epoch: 7/10. Validation set: Average loss: 0.1416
# Train: [0/5622 (0%)]	Loss: 0.174941
# Epoch: 8/10. Train set: Average loss: 0.1555
# Epoch: 8/10. Validation set: Average loss: 0.1332
# Train: [0/5622 (0%)]	Loss: 0.090241
# Epoch: 9/10. Train set: Average loss: 0.1510
# Epoch: 9/10. Validation set: Average loss: 0.1233
# Train: [0/5622 (0%)]	Loss: 0.176090
# Epoch: 10/10. Train set: Average loss: 0.1492
# Epoch: 10/10. Validation set: Average loss: 0.1247
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.124728
# Epoch: 1/10. Train set: Average loss: 0.1670
# Epoch: 1/10. Validation set: Average loss: 0.1176
# Train: [0/5622 (0%)]	Loss: 0.079231
# Epoch: 2/10. Train set: Average loss: 0.1610
# Epoch: 2/10. Validation set: Average loss: 0.1265
# Train: [0/5622 (0%)]	Loss: 0.153722
# Epoch: 3/10. Train set: Average loss: 0.1600
# Epoch: 3/10. Validation set: Average loss: 0.1730
# Train: [0/5622 (0%)]	Loss: 0.150729
# Epoch: 4/10. Train set: Average loss: 0.1718
# Epoch: 4/10. Validation set: Average loss: 0.1333
# Train: [0/5622 (0%)]	Loss: 0.124682
# Epoch: 5/10. Train set: Average loss: 0.1596
# Epoch: 5/10. Validation set: Average loss: 0.1319
# Train: [0/5622 (0%)]	Loss: 0.193411
# Epoch: 6/10. Train set: Average loss: 0.1562
# Epoch: 6/10. Validation set: Average loss: 0.1246
# Train: [0/5622 (0%)]	Loss: 0.159779
# Epoch: 7/10. Train set: Average loss: 0.1562
# Epoch: 7/10. Validation set: Average loss: 0.1275
# Train: [0/5622 (0%)]	Loss: 0.145511
# Epoch: 8/10. Train set: Average loss: 0.1524
# Epoch: 8/10. Validation set: Average loss: 0.1171
# Train: [0/5622 (0%)]	Loss: 0.090453
# Epoch: 9/10. Train set: Average loss: 0.1480
# Epoch: 9/10. Validation set: Average loss: 0.1197
# Train: [0/5622 (0%)]	Loss: 0.247873
# Epoch: 10/10. Train set: Average loss: 0.1467
# Epoch: 10/10. Validation set: Average loss: 0.1209
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.061939
# Epoch: 1/10. Train set: Average loss: 0.1645
# Epoch: 1/10. Validation set: Average loss: 0.1261
# Train: [0/5622 (0%)]	Loss: 0.117048
# Epoch: 2/10. Train set: Average loss: 0.1652
# Epoch: 2/10. Validation set: Average loss: 0.1221
# Train: [0/5622 (0%)]	Loss: 0.096599
# Epoch: 3/10. Train set: Average loss: 0.1611
# Epoch: 3/10. Validation set: Average loss: 0.1294
# Train: [0/5622 (0%)]	Loss: 0.092314
# Epoch: 4/10. Train set: Average loss: 0.1581
# Epoch: 4/10. Validation set: Average loss: 0.1336
# Train: [0/5622 (0%)]	Loss: 0.129084
# Epoch: 5/10. Train set: Average loss: 0.1576
# Epoch: 5/10. Validation set: Average loss: 0.1290
# Train: [0/5622 (0%)]	Loss: 0.181308
# Epoch: 6/10. Train set: Average loss: 0.1589
# Epoch: 6/10. Validation set: Average loss: 0.1333
# Train: [0/5622 (0%)]	Loss: 0.075340
# Epoch: 7/10. Train set: Average loss: 0.1563
# Epoch: 7/10. Validation set: Average loss: 0.1150
# Train: [0/5622 (0%)]	Loss: 0.137613
# Epoch: 8/10. Train set: Average loss: 0.1522
# Epoch: 8/10. Validation set: Average loss: 0.1213
# Train: [0/5622 (0%)]	Loss: 0.121253
# Epoch: 9/10. Train set: Average loss: 0.1479
# Epoch: 9/10. Validation set: Average loss: 0.1206
# Train: [0/5622 (0%)]	Loss: 0.127970
# Epoch: 10/10. Train set: Average loss: 0.1486
# Epoch: 10/10. Validation set: Average loss: 0.1192
# Number features: 4
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.124498
# Epoch: 1/10. Train set: Average loss: 0.1708
# Epoch: 1/10. Validation set: Average loss: 0.1515
# Train: [0/5622 (0%)]	Loss: 0.176156
# Epoch: 2/10. Train set: Average loss: 0.1717
# Epoch: 2/10. Validation set: Average loss: 0.1216
# Train: [0/5622 (0%)]	Loss: 0.100279
# Epoch: 3/10. Train set: Average loss: 0.1592
# Epoch: 3/10. Validation set: Average loss: 0.1180
# Train: [0/5622 (0%)]	Loss: 0.153087
# Epoch: 4/10. Train set: Average loss: 0.1572
# Epoch: 4/10. Validation set: Average loss: 0.1149
# Train: [0/5622 (0%)]	Loss: 0.092924
# Epoch: 5/10. Train set: Average loss: 0.1563
# Epoch: 5/10. Validation set: Average loss: 0.1204
# Train: [0/5622 (0%)]	Loss: 0.111952
# Epoch: 6/10. Train set: Average loss: 0.1561
# Epoch: 6/10. Validation set: Average loss: 0.1126
# Train: [0/5622 (0%)]	Loss: 0.125814
# Epoch: 7/10. Train set: Average loss: 0.1527
# Epoch: 7/10. Validation set: Average loss: 0.1132
# Train: [0/5622 (0%)]	Loss: 0.099655
# Epoch: 8/10. Train set: Average loss: 0.1541
# Epoch: 8/10. Validation set: Average loss: 0.1146
# Train: [0/5622 (0%)]	Loss: 0.153749
# Epoch: 9/10. Train set: Average loss: 0.1509
# Epoch: 9/10. Validation set: Average loss: 0.1161
# Train: [0/5622 (0%)]	Loss: 0.141854
# Epoch: 10/10. Train set: Average loss: 0.1515
# Epoch: 10/10. Validation set: Average loss: 0.1167
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.249538
# Epoch: 1/10. Train set: Average loss: 0.1741
# Epoch: 1/10. Validation set: Average loss: 0.1519
# Train: [0/5622 (0%)]	Loss: 0.130892
# Epoch: 2/10. Train set: Average loss: 0.1591
# Epoch: 2/10. Validation set: Average loss: 0.1227
# Train: [0/5622 (0%)]	Loss: 0.126570
# Epoch: 3/10. Train set: Average loss: 0.1640
# Epoch: 3/10. Validation set: Average loss: 0.1120
# Train: [0/5622 (0%)]	Loss: 0.146177
# Epoch: 4/10. Train set: Average loss: 0.1623
# Epoch: 4/10. Validation set: Average loss: 0.1341
# Train: [0/5622 (0%)]	Loss: 0.139820
# Epoch: 5/10. Train set: Average loss: 0.1570
# Epoch: 5/10. Validation set: Average loss: 0.1240
# Train: [0/5622 (0%)]	Loss: 0.155886
# Epoch: 6/10. Train set: Average loss: 0.1531
# Epoch: 6/10. Validation set: Average loss: 0.1146
# Train: [0/5622 (0%)]	Loss: 0.161305
# Epoch: 7/10. Train set: Average loss: 0.1522
# Epoch: 7/10. Validation set: Average loss: 0.1128
# Train: [0/5622 (0%)]	Loss: 0.172543
# Epoch: 8/10. Train set: Average loss: 0.1515
# Epoch: 8/10. Validation set: Average loss: 0.1268
# Train: [0/5622 (0%)]	Loss: 0.132147
# Epoch: 9/10. Train set: Average loss: 0.1486
# Epoch: 9/10. Validation set: Average loss: 0.1182
# Train: [0/5622 (0%)]	Loss: 0.070525
# Epoch: 10/10. Train set: Average loss: 0.1456
# Epoch: 10/10. Validation set: Average loss: 0.1169
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.249616
# Epoch: 1/10. Train set: Average loss: 0.1676
# Epoch: 1/10. Validation set: Average loss: 0.1453
# Train: [0/5622 (0%)]	Loss: 0.182637
# Epoch: 2/10. Train set: Average loss: 0.1648
# Epoch: 2/10. Validation set: Average loss: 0.1267
# Train: [0/5622 (0%)]	Loss: 0.149645
# Epoch: 3/10. Train set: Average loss: 0.1607
# Epoch: 3/10. Validation set: Average loss: 0.1336
# Train: [0/5622 (0%)]	Loss: 0.157890
# Epoch: 4/10. Train set: Average loss: 0.1676
# Epoch: 4/10. Validation set: Average loss: 0.1658
# Train: [0/5622 (0%)]	Loss: 0.204048
# Epoch: 5/10. Train set: Average loss: 0.1583
# Epoch: 5/10. Validation set: Average loss: 0.1330
# Train: [0/5622 (0%)]	Loss: 0.164938
# Epoch: 6/10. Train set: Average loss: 0.1554
# Epoch: 6/10. Validation set: Average loss: 0.1305
# Train: [0/5622 (0%)]	Loss: 0.163882
# Epoch: 7/10. Train set: Average loss: 0.1539
# Epoch: 7/10. Validation set: Average loss: 0.1218
# Train: [0/5622 (0%)]	Loss: 0.172187
# Epoch: 8/10. Train set: Average loss: 0.1566
# Epoch: 8/10. Validation set: Average loss: 0.1341
# Train: [0/5622 (0%)]	Loss: 0.127276
# Epoch: 9/10. Train set: Average loss: 0.1509
# Epoch: 9/10. Validation set: Average loss: 0.1196
# Train: [0/5622 (0%)]	Loss: 0.164179
# Epoch: 10/10. Train set: Average loss: 0.1495
# Epoch: 10/10. Validation set: Average loss: 0.1191
# Number features: 4
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.499470
# Epoch: 1/10. Train set: Average loss: 0.1697
# Epoch: 1/10. Validation set: Average loss: 0.1248
# Train: [0/5622 (0%)]	Loss: 0.169206
# Epoch: 2/10. Train set: Average loss: 0.1565
# Epoch: 2/10. Validation set: Average loss: 0.1150
# Train: [0/5622 (0%)]	Loss: 0.089445
# Epoch: 3/10. Train set: Average loss: 0.1559
# Epoch: 3/10. Validation set: Average loss: 0.1133
# Train: [0/5622 (0%)]	Loss: 0.202571
# Epoch: 4/10. Train set: Average loss: 0.1566
# Epoch: 4/10. Validation set: Average loss: 0.1298
# Train: [0/5622 (0%)]	Loss: 0.137448
# Epoch: 5/10. Train set: Average loss: 0.1534
# Epoch: 5/10. Validation set: Average loss: 0.1170
# Train: [0/5622 (0%)]	Loss: 0.106809
# Epoch: 6/10. Train set: Average loss: 0.1513
# Epoch: 6/10. Validation set: Average loss: 0.1341
# Train: [0/5622 (0%)]	Loss: 0.155507
# Epoch: 7/10. Train set: Average loss: 0.1510
# Epoch: 7/10. Validation set: Average loss: 0.1262
# Train: [0/5622 (0%)]	Loss: 0.281916
# Epoch: 8/10. Train set: Average loss: 0.1494
# Epoch: 8/10. Validation set: Average loss: 0.1153
# Train: [0/5622 (0%)]	Loss: 0.176354
# Epoch: 9/10. Train set: Average loss: 0.1444
# Epoch: 9/10. Validation set: Average loss: 0.1133
# Train: [0/5622 (0%)]	Loss: 0.167971
# Epoch: 10/10. Train set: Average loss: 0.1496
# Epoch: 10/10. Validation set: Average loss: 0.1165
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.374621
# Epoch: 1/10. Train set: Average loss: 0.1653
# Epoch: 1/10. Validation set: Average loss: 0.1327
# Train: [0/5622 (0%)]	Loss: 0.211207
# Epoch: 2/10. Train set: Average loss: 0.1637
# Epoch: 2/10. Validation set: Average loss: 0.1081
# Train: [0/5622 (0%)]	Loss: 0.123649
# Epoch: 3/10. Train set: Average loss: 0.1572
# Epoch: 3/10. Validation set: Average loss: 0.1262
# Train: [0/5622 (0%)]	Loss: 0.131575
# Epoch: 4/10. Train set: Average loss: 0.1567
# Epoch: 4/10. Validation set: Average loss: 0.1179
# Train: [0/5622 (0%)]	Loss: 0.140375
# Epoch: 5/10. Train set: Average loss: 0.1533
# Epoch: 5/10. Validation set: Average loss: 0.1244
# Train: [0/5622 (0%)]	Loss: 0.170686
# Epoch: 6/10. Train set: Average loss: 0.1550
# Epoch: 6/10. Validation set: Average loss: 0.1249
# Train: [0/5622 (0%)]	Loss: 0.202701
# Epoch: 7/10. Train set: Average loss: 0.1513
# Epoch: 7/10. Validation set: Average loss: 0.1270
# Train: [0/5622 (0%)]	Loss: 0.136292
# Epoch: 8/10. Train set: Average loss: 0.1539
# Epoch: 8/10. Validation set: Average loss: 0.1269
# Train: [0/5622 (0%)]	Loss: 0.122268
# Epoch: 9/10. Train set: Average loss: 0.1460
# Epoch: 9/10. Validation set: Average loss: 0.1152
# Train: [0/5622 (0%)]	Loss: 0.115458
# Epoch: 10/10. Train set: Average loss: 0.1492
# Epoch: 10/10. Validation set: Average loss: 0.1176
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.312158
# Epoch: 1/10. Train set: Average loss: 0.1712
# Epoch: 1/10. Validation set: Average loss: 0.1350
# Train: [0/5622 (0%)]	Loss: 0.137249
# Epoch: 2/10. Train set: Average loss: 0.1574
# Epoch: 2/10. Validation set: Average loss: 0.1403
# Train: [0/5622 (0%)]	Loss: 0.105716
# Epoch: 3/10. Train set: Average loss: 0.1579
# Epoch: 3/10. Validation set: Average loss: 0.1209
# Train: [0/5622 (0%)]	Loss: 0.153561
# Epoch: 4/10. Train set: Average loss: 0.1573
# Epoch: 4/10. Validation set: Average loss: 0.1331
# Train: [0/5622 (0%)]	Loss: 0.096416
# Epoch: 5/10. Train set: Average loss: 0.1538
# Epoch: 5/10. Validation set: Average loss: 0.1182
# Train: [0/5622 (0%)]	Loss: 0.144737
# Epoch: 6/10. Train set: Average loss: 0.1537
# Epoch: 6/10. Validation set: Average loss: 0.1203
# Train: [0/5622 (0%)]	Loss: 0.110284
# Epoch: 7/10. Train set: Average loss: 0.1543
# Epoch: 7/10. Validation set: Average loss: 0.1244
# Train: [0/5622 (0%)]	Loss: 0.125835
# Epoch: 8/10. Train set: Average loss: 0.1544
# Epoch: 8/10. Validation set: Average loss: 0.1188
# Train: [0/5622 (0%)]	Loss: 0.127538
# Epoch: 9/10. Train set: Average loss: 0.1512
# Epoch: 9/10. Validation set: Average loss: 0.1178
# Train: [0/5622 (0%)]	Loss: 0.161895
# Epoch: 10/10. Train set: Average loss: 0.1479
# Epoch: 10/10. Validation set: Average loss: 0.1151
# Number features: 5
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.312022
# Epoch: 1/10. Train set: Average loss: 0.1707
# Epoch: 1/10. Validation set: Average loss: 0.1397
# Train: [0/5622 (0%)]	Loss: 0.115631
# Epoch: 2/10. Train set: Average loss: 0.1664
# Epoch: 2/10. Validation set: Average loss: 0.1497
# Train: [0/5622 (0%)]	Loss: 0.251262
# Epoch: 3/10. Train set: Average loss: 0.1646
# Epoch: 3/10. Validation set: Average loss: 0.1574
# Train: [0/5622 (0%)]	Loss: 0.290874
# Epoch: 4/10. Train set: Average loss: 0.1661
# Epoch: 4/10. Validation set: Average loss: 0.1408
# Train: [0/5622 (0%)]	Loss: 0.255149
# Epoch: 5/10. Train set: Average loss: 0.1561
# Epoch: 5/10. Validation set: Average loss: 0.1406
# Train: [0/5622 (0%)]	Loss: 0.199254
# Epoch: 6/10. Train set: Average loss: 0.1572
# Epoch: 6/10. Validation set: Average loss: 0.1514
# Train: [0/5622 (0%)]	Loss: 0.209228
# Epoch: 7/10. Train set: Average loss: 0.1564
# Epoch: 7/10. Validation set: Average loss: 0.1490
# Train: [0/5622 (0%)]	Loss: 0.333408
# Epoch: 8/10. Train set: Average loss: 0.1571
# Epoch: 8/10. Validation set: Average loss: 0.1384
# Train: [0/5622 (0%)]	Loss: 0.118614
# Epoch: 9/10. Train set: Average loss: 0.1534
# Epoch: 9/10. Validation set: Average loss: 0.1336
# Train: [0/5622 (0%)]	Loss: 0.200930
# Epoch: 10/10. Train set: Average loss: 0.1518
# Epoch: 10/10. Validation set: Average loss: 0.1314
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.311124
# Epoch: 1/10. Train set: Average loss: 0.1726
# Epoch: 1/10. Validation set: Average loss: 0.1540
# Train: [0/5622 (0%)]	Loss: 0.196381
# Epoch: 2/10. Train set: Average loss: 0.1695
# Epoch: 2/10. Validation set: Average loss: 0.1773
# Train: [0/5622 (0%)]	Loss: 0.156686
# Epoch: 3/10. Train set: Average loss: 0.1605
# Epoch: 3/10. Validation set: Average loss: 0.1578
# Train: [0/5622 (0%)]	Loss: 0.103140
# Epoch: 4/10. Train set: Average loss: 0.1569
# Epoch: 4/10. Validation set: Average loss: 0.1506
# Train: [0/5622 (0%)]	Loss: 0.095595
# Epoch: 5/10. Train set: Average loss: 0.1577
# Epoch: 5/10. Validation set: Average loss: 0.2134
# Train: [0/5622 (0%)]	Loss: 0.145199
# Epoch: 6/10. Train set: Average loss: 0.1605
# Epoch: 6/10. Validation set: Average loss: 0.1408
# Train: [0/5622 (0%)]	Loss: 0.147569
# Epoch: 7/10. Train set: Average loss: 0.1527
# Epoch: 7/10. Validation set: Average loss: 0.1400
# Train: [0/5622 (0%)]	Loss: 0.327977
# Epoch: 8/10. Train set: Average loss: 0.1588
# Epoch: 8/10. Validation set: Average loss: 0.1469
# Train: [0/5622 (0%)]	Loss: 0.251391
# Epoch: 9/10. Train set: Average loss: 0.1519
# Epoch: 9/10. Validation set: Average loss: 0.1367
# Train: [0/5622 (0%)]	Loss: 0.136888
# Epoch: 10/10. Train set: Average loss: 0.1507
# Epoch: 10/10. Validation set: Average loss: 0.1353
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.311592
# Epoch: 1/10. Train set: Average loss: 0.1761
# Epoch: 1/10. Validation set: Average loss: 0.1357
# Train: [0/5622 (0%)]	Loss: 0.177951
# Epoch: 2/10. Train set: Average loss: 0.1669
# Epoch: 2/10. Validation set: Average loss: 0.1517
# Train: [0/5622 (0%)]	Loss: 0.192095
# Epoch: 3/10. Train set: Average loss: 0.1642
# Epoch: 3/10. Validation set: Average loss: 0.1571
# Train: [0/5622 (0%)]	Loss: 0.094605
# Epoch: 4/10. Train set: Average loss: 0.1627
# Epoch: 4/10. Validation set: Average loss: 0.1417
# Train: [0/5622 (0%)]	Loss: 0.201269
# Epoch: 5/10. Train set: Average loss: 0.1569
# Epoch: 5/10. Validation set: Average loss: 0.1433
# Train: [0/5622 (0%)]	Loss: 0.114370
# Epoch: 6/10. Train set: Average loss: 0.1666
# Epoch: 6/10. Validation set: Average loss: 0.1433
# Train: [0/5622 (0%)]	Loss: 0.193238
# Epoch: 7/10. Train set: Average loss: 0.1581
# Epoch: 7/10. Validation set: Average loss: 0.1464
# Train: [0/5622 (0%)]	Loss: 0.226471
# Epoch: 8/10. Train set: Average loss: 0.1515
# Epoch: 8/10. Validation set: Average loss: 0.1481
# Train: [0/5622 (0%)]	Loss: 0.256821
# Epoch: 9/10. Train set: Average loss: 0.1496
# Epoch: 9/10. Validation set: Average loss: 0.1332
# Train: [0/5622 (0%)]	Loss: 0.161101
# Epoch: 10/10. Train set: Average loss: 0.1531
# Epoch: 10/10. Validation set: Average loss: 0.1339
# Number features: 5
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.062434
# Epoch: 1/10. Train set: Average loss: 0.1712
# Epoch: 1/10. Validation set: Average loss: 0.1646
# Train: [0/5622 (0%)]	Loss: 0.162854
# Epoch: 2/10. Train set: Average loss: 0.1586
# Epoch: 2/10. Validation set: Average loss: 0.1569
# Train: [0/5622 (0%)]	Loss: 0.158272
# Epoch: 3/10. Train set: Average loss: 0.1618
# Epoch: 3/10. Validation set: Average loss: 0.1510
# Train: [0/5622 (0%)]	Loss: 0.197468
# Epoch: 4/10. Train set: Average loss: 0.1634
# Epoch: 4/10. Validation set: Average loss: 0.1604
# Train: [0/5622 (0%)]	Loss: 0.106434
# Epoch: 5/10. Train set: Average loss: 0.1636
# Epoch: 5/10. Validation set: Average loss: 0.1622
# Train: [0/5622 (0%)]	Loss: 0.080391
# Epoch: 6/10. Train set: Average loss: 0.1586
# Epoch: 6/10. Validation set: Average loss: 0.1558
# Train: [0/5622 (0%)]	Loss: 0.115100
# Epoch: 7/10. Train set: Average loss: 0.1518
# Epoch: 7/10. Validation set: Average loss: 0.1618
# Train: [0/5622 (0%)]	Loss: 0.111397
# Epoch: 8/10. Train set: Average loss: 0.1545
# Epoch: 8/10. Validation set: Average loss: 0.1487
# Train: [0/5622 (0%)]	Loss: 0.117522
# Epoch: 9/10. Train set: Average loss: 0.1477
# Epoch: 9/10. Validation set: Average loss: 0.1423
# Train: [0/5622 (0%)]	Loss: 0.160268
# Epoch: 10/10. Train set: Average loss: 0.1466
# Epoch: 10/10. Validation set: Average loss: 0.1403
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.249300
# Epoch: 1/10. Train set: Average loss: 0.1668
# Epoch: 1/10. Validation set: Average loss: 0.1513
# Train: [0/5622 (0%)]	Loss: 0.091737
