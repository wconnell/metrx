# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("..")

import datetime
import pathlib

from collections import OrderedDict 

import numpy as np
import pandas as pd

# %%
# Pytorch
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable

# Custom
from dutils import Experiment
from trainer import fit
import visualization as vis
from tcga_datasets import SiameseDataset

# Models
from tcga_networks import EmbeddingNet, SiameseNet
from losses import ContrastiveLoss

# Metrics
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score as ANMI

# %%
def getTCGA(disease):
    path = "/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP/TCGA/TCGA_{}_counts.tsv.gz"
    files = [path.format(d) for d in disease]
    return files


def readGCP(files, biotype='protein_coding', mean=True):
    """
    Paths to count matrices.
    """
    data_dict = {}
    for f in files:
        key = os.path.basename(f).split("_")[1]
        data = pd.read_csv(f, sep='\t', index_col=0)
        # transcript metadata
        meta = pd.DataFrame([row[:-1] for row in data.index.str.split("|")],
                            columns=['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'GENE', 'BP', 'BIOTYPE'])
        meta = pd.MultiIndex.from_frame(meta)
        data.index = meta
        # subset transcripts
        data = data.xs(key=biotype, level='BIOTYPE')
        data = data.droplevel(['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'BP'])
        # average gene expression of splice variants
        data = data.T
        if mean:
            data = data.groupby(by=data.columns, axis=1).mean()
        data_dict[key] = data
    return data_dict


def uq_norm(df, q=0.75):
    """
    Upper quartile normalization of GEX for samples.
    """
    quantiles = df.quantile(q=q, axis=1)
    norm = df.divide(quantiles, axis=0)
    return norm


def process_TCGA(disease=['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']):
    base="/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP"
    # get files
    tcga_files = getTCGA(disease)
    # read meta/data
    tcga_meta = pd.read_csv(os.path.join(base, "TCGA/TCGA_GDC_ID_MAP.tsv"), sep="\t")
    tcga_raw = readGCP(tcga_files, mean=True)
    # combine samples
    tcga_raw = pd.concat(tcga_raw.values())
    # Upper quartile normalization
    tcga_raw = uq_norm(tcga_raw)
    # log norm
    tcga = tcga_raw.transform(np.log1p)
    return tcga, tcga_meta

# %%
def generate_fsets(data, n_features, steps=5):
    r = np.linspace(start=1, stop=n_features, num=steps, dtype='int')
    idx = [np.random.choice(data.shape[1], size=i, replace=False) for i in r]
    return idx

# %%
def feature_training(train_data, train_labels, test_data, test_labels, feature_idx, embedding, exp_dir, cuda=True):
    # Meta data
    meta_data = {"n_features":[],
                 "model":[],
                 "ANMI":[]}
    # Params
    batch_size = 8
    kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {'num_workers': 10}
    
    # Feature Index
    for batch, feat in enumerate(feature_idx):
        print("Number features: {}\n".format(len(feat)))
        exp_data = {'feature_idx':feat}
        # Define data
        siamese_train_dataset = SiameseDataset(data=train_data.iloc[:,feat],
                                           labels=train_labels,
                                           train=True)
        siamese_test_dataset = SiameseDataset(data=test_data.iloc[:,feat],
                                          labels=test_labels,
                                          train=False)
        # Loaders
        siamese_train_loader = torch.utils.data.DataLoader(siamese_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
        siamese_test_loader = torch.utils.data.DataLoader(siamese_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)
        # Instantiate model
        n_samples, n_features = siamese_train_dataset.train_data.shape
        for i in range(3):
            nmodel = 'model_{}'.format(i)
            print("\t{}".format(nmodel))
            embedding_net = EmbeddingNet(n_features, embedding)
            model = SiameseNet(embedding_net)
            if cuda:
                model.cuda()
            # Parameters
            margin = 1.
            loss_fn = ContrastiveLoss(margin)
            lr = 1e-3
            optimizer = optim.Adam(model.parameters(), lr=lr)
            scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
            n_epochs = 10
            log_interval = round(len(siamese_train_dataset)/1/batch_size)
            # Train
            train_loss, val_loss = fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, 
                                       n_epochs, cuda, log_interval)
            # Test Embeddings
            val_embeddings_baseline, val_labels_baseline = vis.extract_embeddings(siamese_test_dataset.test_data, siamese_test_dataset.labels, model)
            # Evaluation
            n_clusters = len(np.unique(test_labels))
            kmeans = KMeans(n_clusters=n_clusters)
            siamese_clusters = kmeans.fit_predict(val_embeddings_baseline)
            anmi = ANMI(siamese_clusters, val_labels_baseline)
            # Store
            meta_data['n_features'].append(len(feat))
            meta_data['model'].append(nmodel)
            meta_data['ANMI'].append(anmi)
            exp_data[nmodel] = {'data': (val_embeddings_baseline, val_labels_baseline),
                                'loss': (train_loss, val_loss),
                                'ANMI': anmi}
        pd.to_pickle(exp_data, os.path.join(exp_dir, "model_{}.pkl".format(len(feat))))
    pd.to_pickle(meta_data, os.path.join(exp_dir, "model_meta_data.pkl"))

# %%
def main(disease, sample_type, **kwargs):
    # GPUs
    os.environ["CUDA_VISIBLE_DEVICES"] = kwargs['device']
    cuda = torch.cuda.is_available()
    print("Cuda is available: {}".format(cuda))
    
    # Read / write / process
    tcga, tcga_meta = process_TCGA(disease)
    # Subset to GO feature subset
    uniprot = pd.read_csv("/srv/home/wconnell/keiser/data/uniprot_mapping_ids/TCGA_rnaseq_uniprot_features.tab.gz", sep="\t")
    gpcr = uniprot[uniprot["Gene ontology (biological process)"] == "G protein-coupled receptor signaling pathway [GO:0007186]"]
    tcga = tcga.loc[:,tcga.columns.isin(gpcr['Gene names  (primary )'])]
    # Feature design
    feature_idx = generate_fsets(tcga, n_features=kwargs['n_features'], steps=kwargs['steps'])
    # Experiment design
    hierarchy = OrderedDict({'Disease':disease,
                             'Sample Type':sample_type})
    # Define experiment
    exp = Experiment(meta_data=tcga_meta,
                     hierarchy=hierarchy,
                     index='CGHubAnalysisID',
                     cases='Case ID',
                     min_samples=20)
    # Train / Test split
    exp.train_test_split(cases='Case ID')
    # Return data 
    train_data, train_labels = exp.get_data(tcga, subset="train", dtype=np.float32)
    test_data, test_labels = exp.get_data(tcga, subset="test", dtype=np.float32)
    
    # Path *fix*
    dtime = datetime.datetime.today().strftime("%Y.%m.%d_%H:%M")
    exp_dir = "/srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/{}_{}_{}_{}_{}-{}".format(dtime,
                                                                                                  kwargs['note'],
                                                                                                  len(exp.labels_dict),
                                                                                                  kwargs['embedding'],
                                                                                                  kwargs['n_features'], 
                                                                                                  kwargs['steps'])
    pathlib.Path(exp_dir).mkdir(parents=True, exist_ok=False)
    print('Saving to: \n{}'.format(exp_dir))
    
    # Meta data
    experiments = {'experiment': exp,
                   'train':(train_data, train_labels),
                   'test': (test_data, test_labels)}
    pd.to_pickle(experiments, os.path.join(exp_dir, "experiment_meta_data.pkl"))
    
    # Training
    feature_training(train_data, train_labels, test_data, test_labels, feature_idx, kwargs['embedding'], exp_dir)

# %% [markdown]
# ### Setup

# %%
uniprot = pd.read_csv("/srv/home/wconnell/keiser/data/uniprot_mapping_ids/TCGA_rnaseq_uniprot_features.tab.gz", sep="\t")
keratin = uniprot[uniprot["Gene ontology (biological process)"] == "keratinization [GO:0031424]"]

# %%
disease = ['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']
sample_type = ['Primary Tumor', 'Solid Tissue Normal']
params = {"device":"1",
          "note":"gpcr",
          "n_features":len(keratin),
          "steps":50,
          "embedding":2}

# %%
main(disease=disease, sample_type=sample_type, **params)
# Out:
# Cuda is available: True
# Saving to:
# /srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/2020.03.30_10:41_gpcr_11_2_94-50
# Number features: 1
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.245263
# Epoch: 1/10. Train set: Average loss: 0.2451
# Epoch: 1/10. Validation set: Average loss: 0.2463
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.248584
# Epoch: 2/10. Train set: Average loss: 0.2486
# Epoch: 2/10. Validation set: Average loss: 0.2473
# Train: [0/2931 (0%)]	Loss: 0.239031
# Train: [1098/2931 (100%)]	Loss: 0.242213
# Epoch: 3/10. Train set: Average loss: 0.2422
# Epoch: 3/10. Validation set: Average loss: 0.2466
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.243032
# Epoch: 4/10. Train set: Average loss: 0.2431
# Epoch: 4/10. Validation set: Average loss: 0.2461
# Train: [0/2931 (0%)]	Loss: 0.275748
# Train: [1098/2931 (100%)]	Loss: 0.242656
# Epoch: 5/10. Train set: Average loss: 0.2427
# Epoch: 5/10. Validation set: Average loss: 0.2498
# Train: [0/2931 (0%)]	Loss: 0.252587
# Train: [1098/2931 (100%)]	Loss: 0.239010
# Epoch: 6/10. Train set: Average loss: 0.2390
# Epoch: 6/10. Validation set: Average loss: 0.2464
# Train: [0/2931 (0%)]	Loss: 0.251019
# Train: [1098/2931 (100%)]	Loss: 0.244557
# Epoch: 7/10. Train set: Average loss: 0.2446
# Epoch: 7/10. Validation set: Average loss: 0.2473
# Train: [0/2931 (0%)]	Loss: 0.250325
# Train: [1098/2931 (100%)]	Loss: 0.237518
# Epoch: 8/10. Train set: Average loss: 0.2376
# Epoch: 8/10. Validation set: Average loss: 0.2461
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.242337
# Epoch: 9/10. Train set: Average loss: 0.2424
# Epoch: 9/10. Validation set: Average loss: 0.2461
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.238081
# Epoch: 10/10. Train set: Average loss: 0.2381
# Epoch: 10/10. Validation set: Average loss: 0.2475
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.241414
# Epoch: 1/10. Train set: Average loss: 0.2414
# Epoch: 1/10. Validation set: Average loss: 0.2483
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.239072
# Epoch: 2/10. Train set: Average loss: 0.2389
# Epoch: 2/10. Validation set: Average loss: 0.2466
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.236674
# Epoch: 3/10. Train set: Average loss: 0.2367
# Epoch: 3/10. Validation set: Average loss: 0.2461
# Train: [0/2931 (0%)]	Loss: 0.250560
# Train: [1098/2931 (100%)]	Loss: 0.248315
# Epoch: 4/10. Train set: Average loss: 0.2483
# Epoch: 4/10. Validation set: Average loss: 0.2462
# Train: [0/2931 (0%)]	Loss: 0.252002
# Train: [1098/2931 (100%)]	Loss: 0.241074
# Epoch: 5/10. Train set: Average loss: 0.2411
# Epoch: 5/10. Validation set: Average loss: 0.2481
# Train: [0/2931 (0%)]	Loss: 0.245799
# Train: [1098/2931 (100%)]	Loss: 0.248881
# Epoch: 6/10. Train set: Average loss: 0.2489
# Epoch: 6/10. Validation set: Average loss: 0.2470
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.251715
# Epoch: 7/10. Train set: Average loss: 0.2517
# Epoch: 7/10. Validation set: Average loss: 0.2461
# Train: [0/2931 (0%)]	Loss: 0.250470
# Train: [1098/2931 (100%)]	Loss: 0.236671
# Epoch: 8/10. Train set: Average loss: 0.2367
# Epoch: 8/10. Validation set: Average loss: 0.2469
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.241964
# Epoch: 9/10. Train set: Average loss: 0.2420
# Epoch: 9/10. Validation set: Average loss: 0.2466
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.241707
# Epoch: 10/10. Train set: Average loss: 0.2417
# Epoch: 10/10. Validation set: Average loss: 0.2461
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.251000
# Epoch: 1/10. Train set: Average loss: 0.2508
# Epoch: 1/10. Validation set: Average loss: 0.2461
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.253108
# Epoch: 2/10. Train set: Average loss: 0.2529
# Epoch: 2/10. Validation set: Average loss: 0.2495
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.233457
# Epoch: 3/10. Train set: Average loss: 0.2333
# Epoch: 3/10. Validation set: Average loss: 0.2463
# Train: [0/2931 (0%)]	Loss: 0.188021
# Train: [1098/2931 (100%)]	Loss: 0.240380
# Epoch: 4/10. Train set: Average loss: 0.2402
# Epoch: 4/10. Validation set: Average loss: 0.2470
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.236415
# Epoch: 5/10. Train set: Average loss: 0.2363
# Epoch: 5/10. Validation set: Average loss: 0.2462
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.238311
# Epoch: 6/10. Train set: Average loss: 0.2382
# Epoch: 6/10. Validation set: Average loss: 0.2463
# Train: [0/2931 (0%)]	Loss: 0.189947
# Train: [1098/2931 (100%)]	Loss: 0.244420
# Epoch: 7/10. Train set: Average loss: 0.2443
# Epoch: 7/10. Validation set: Average loss: 0.2462
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.238656
# Epoch: 8/10. Train set: Average loss: 0.2385
# Epoch: 8/10. Validation set: Average loss: 0.2481
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.240782
# Epoch: 9/10. Train set: Average loss: 0.2406
# Epoch: 9/10. Validation set: Average loss: 0.2471
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.235501
# Epoch: 10/10. Train set: Average loss: 0.2354
# Epoch: 10/10. Validation set: Average loss: 0.2461
# Number features: 2
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.279548
# Epoch: 1/10. Train set: Average loss: 0.2793
# Epoch: 1/10. Validation set: Average loss: 0.2463
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.239905
# Epoch: 2/10. Train set: Average loss: 0.2399
# Epoch: 2/10. Validation set: Average loss: 0.2507
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.238295
# Epoch: 3/10. Train set: Average loss: 0.2382
# Epoch: 3/10. Validation set: Average loss: 0.2495
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.245381
# Epoch: 4/10. Train set: Average loss: 0.2454
# Epoch: 4/10. Validation set: Average loss: 0.2500
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.238149
# Epoch: 5/10. Train set: Average loss: 0.2384
# Epoch: 5/10. Validation set: Average loss: 0.2477
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.241087
# Epoch: 6/10. Train set: Average loss: 0.2411
# Epoch: 6/10. Validation set: Average loss: 0.2492
# Train: [0/2931 (0%)]	Loss: 0.124992
# Train: [1098/2931 (100%)]	Loss: 0.238838
# Epoch: 7/10. Train set: Average loss: 0.2385
# Epoch: 7/10. Validation set: Average loss: 0.2474
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.241976
# Epoch: 8/10. Train set: Average loss: 0.2420
# Epoch: 8/10. Validation set: Average loss: 0.2625
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.244444
# Epoch: 9/10. Train set: Average loss: 0.2445
# Epoch: 9/10. Validation set: Average loss: 0.2484
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.245547
# Epoch: 10/10. Train set: Average loss: 0.2454
# Epoch: 10/10. Validation set: Average loss: 0.2488
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.248031
# Epoch: 1/10. Train set: Average loss: 0.2482
# Epoch: 1/10. Validation set: Average loss: 0.2949
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.245191
# Epoch: 2/10. Train set: Average loss: 0.2454
# Epoch: 2/10. Validation set: Average loss: 0.2720
# Train: [0/2931 (0%)]	Loss: 0.304063
# Train: [1098/2931 (100%)]	Loss: 0.249698
# Epoch: 3/10. Train set: Average loss: 0.2498
# Epoch: 3/10. Validation set: Average loss: 0.2495
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.367969
# Epoch: 4/10. Train set: Average loss: 0.3678
# Epoch: 4/10. Validation set: Average loss: 0.2602
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.242199
# Epoch: 5/10. Train set: Average loss: 0.2421
# Epoch: 5/10. Validation set: Average loss: 0.2817
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.242338
# Epoch: 6/10. Train set: Average loss: 0.2424
# Epoch: 6/10. Validation set: Average loss: 0.2464
# Train: [0/2931 (0%)]	Loss: 0.374976
# Train: [1098/2931 (100%)]	Loss: 0.244276
# Epoch: 7/10. Train set: Average loss: 0.2446
# Epoch: 7/10. Validation set: Average loss: 0.2600
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.234784
# Epoch: 8/10. Train set: Average loss: 0.2350
# Epoch: 8/10. Validation set: Average loss: 0.2481
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.243491
# Epoch: 9/10. Train set: Average loss: 0.2435
# Epoch: 9/10. Validation set: Average loss: 0.2475
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.243772
# Epoch: 10/10. Train set: Average loss: 0.2436
# Epoch: 10/10. Validation set: Average loss: 0.2480
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.256373
# Epoch: 1/10. Train set: Average loss: 0.2565
# Epoch: 1/10. Validation set: Average loss: 0.2463
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.243641
# Epoch: 2/10. Train set: Average loss: 0.2438
# Epoch: 2/10. Validation set: Average loss: 0.2492
# Train: [0/2931 (0%)]	Loss: 0.124992
# Train: [1098/2931 (100%)]	Loss: 0.245130
# Epoch: 3/10. Train set: Average loss: 0.2448
# Epoch: 3/10. Validation set: Average loss: 0.2489
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.243027
# Epoch: 4/10. Train set: Average loss: 0.2430
# Epoch: 4/10. Validation set: Average loss: 0.2565
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.244173
# Epoch: 5/10. Train set: Average loss: 0.2444
# Epoch: 5/10. Validation set: Average loss: 0.2506
# Train: [0/2931 (0%)]	Loss: 0.317860
# Train: [1098/2931 (100%)]	Loss: 0.249292
# Epoch: 6/10. Train set: Average loss: 0.2495
# Epoch: 6/10. Validation set: Average loss: 0.2468
# Train: [0/2931 (0%)]	Loss: 0.313106
# Train: [1098/2931 (100%)]	Loss: 0.240401
# Epoch: 7/10. Train set: Average loss: 0.2406
# Epoch: 7/10. Validation set: Average loss: 0.2632
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.248473
# Epoch: 8/10. Train set: Average loss: 0.2486
# Epoch: 8/10. Validation set: Average loss: 0.2483
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.244169
# Epoch: 9/10. Train set: Average loss: 0.2440
# Epoch: 9/10. Validation set: Average loss: 0.2482
# Train: [0/2931 (0%)]	Loss: 0.312519
# Train: [1098/2931 (100%)]	Loss: 0.242503
# Epoch: 10/10. Train set: Average loss: 0.2427
# Epoch: 10/10. Validation set: Average loss: 0.2478
# Number features: 4
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.186491
# Train: [1098/2931 (100%)]	Loss: 0.134373
# Epoch: 1/10. Train set: Average loss: 0.1345
# Epoch: 1/10. Validation set: Average loss: 0.1308
# Train: [0/2931 (0%)]	Loss: 0.060324
# Train: [1098/2931 (100%)]	Loss: 0.133969
# Epoch: 2/10. Train set: Average loss: 0.1338
# Epoch: 2/10. Validation set: Average loss: 0.1363
# Train: [0/2931 (0%)]	Loss: 0.138464
# Train: [1098/2931 (100%)]	Loss: 0.122340
# Epoch: 3/10. Train set: Average loss: 0.1224
# Epoch: 3/10. Validation set: Average loss: 0.1260
# Train: [0/2931 (0%)]	Loss: 0.066588
# Train: [1098/2931 (100%)]	Loss: 0.128428
# Epoch: 4/10. Train set: Average loss: 0.1283
# Epoch: 4/10. Validation set: Average loss: 0.1426
# Train: [0/2931 (0%)]	Loss: 0.103254
# Train: [1098/2931 (100%)]	Loss: 0.130635
# Epoch: 5/10. Train set: Average loss: 0.1306
# Epoch: 5/10. Validation set: Average loss: 0.1369
# Train: [0/2931 (0%)]	Loss: 0.128362
# Train: [1098/2931 (100%)]	Loss: 0.126099
# Epoch: 6/10. Train set: Average loss: 0.1261
# Epoch: 6/10. Validation set: Average loss: 0.1284
# Train: [0/2931 (0%)]	Loss: 0.053122
# Train: [1098/2931 (100%)]	Loss: 0.130746
# Epoch: 7/10. Train set: Average loss: 0.1305
# Epoch: 7/10. Validation set: Average loss: 0.1251
# Train: [0/2931 (0%)]	Loss: 0.129606
# Train: [1098/2931 (100%)]	Loss: 0.128208
# Epoch: 8/10. Train set: Average loss: 0.1282
# Epoch: 8/10. Validation set: Average loss: 0.1296
# Train: [0/2931 (0%)]	Loss: 0.066290
# Train: [1098/2931 (100%)]	Loss: 0.121110
# Epoch: 9/10. Train set: Average loss: 0.1210
# Epoch: 9/10. Validation set: Average loss: 0.1255
# Train: [0/2931 (0%)]	Loss: 0.022951
# Train: [1098/2931 (100%)]	Loss: 0.124600
# Epoch: 10/10. Train set: Average loss: 0.1243
# Epoch: 10/10. Validation set: Average loss: 0.1251
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249774
# Train: [1098/2931 (100%)]	Loss: 0.137476
# Epoch: 1/10. Train set: Average loss: 0.1378
# Epoch: 1/10. Validation set: Average loss: 0.2079
# Train: [0/2931 (0%)]	Loss: 0.217308
# Train: [1098/2931 (100%)]	Loss: 0.141751
# Epoch: 2/10. Train set: Average loss: 0.1420
# Epoch: 2/10. Validation set: Average loss: 0.1328
# Train: [0/2931 (0%)]	Loss: 0.178764
# Train: [1098/2931 (100%)]	Loss: 0.137290
# Epoch: 3/10. Train set: Average loss: 0.1374
# Epoch: 3/10. Validation set: Average loss: 0.1299
# Train: [0/2931 (0%)]	Loss: 0.142312
# Train: [1098/2931 (100%)]	Loss: 0.127553
# Epoch: 4/10. Train set: Average loss: 0.1276
# Epoch: 4/10. Validation set: Average loss: 0.1424
# Train: [0/2931 (0%)]	Loss: 0.140891
# Train: [1098/2931 (100%)]	Loss: 0.130265
# Epoch: 5/10. Train set: Average loss: 0.1303
# Epoch: 5/10. Validation set: Average loss: 0.1383
# Train: [0/2931 (0%)]	Loss: 0.117780
# Train: [1098/2931 (100%)]	Loss: 0.131614
# Epoch: 6/10. Train set: Average loss: 0.1316
# Epoch: 6/10. Validation set: Average loss: 0.1306
# Train: [0/2931 (0%)]	Loss: 0.050299
# Train: [1098/2931 (100%)]	Loss: 0.130117
# Epoch: 7/10. Train set: Average loss: 0.1299
# Epoch: 7/10. Validation set: Average loss: 0.1258
# Train: [0/2931 (0%)]	Loss: 0.109500
# Train: [1098/2931 (100%)]	Loss: 0.130412
# Epoch: 8/10. Train set: Average loss: 0.1304
# Epoch: 8/10. Validation set: Average loss: 0.1248
# Train: [0/2931 (0%)]	Loss: 0.130750
# Train: [1098/2931 (100%)]	Loss: 0.126143
# Epoch: 9/10. Train set: Average loss: 0.1262
# Epoch: 9/10. Validation set: Average loss: 0.1246
# Train: [0/2931 (0%)]	Loss: 0.101718
# Train: [1098/2931 (100%)]	Loss: 0.126460
# Epoch: 10/10. Train set: Average loss: 0.1264
# Epoch: 10/10. Validation set: Average loss: 0.1244
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249925
# Train: [1098/2931 (100%)]	Loss: 0.135792
# Epoch: 1/10. Train set: Average loss: 0.1361
# Epoch: 1/10. Validation set: Average loss: 0.1256
# Train: [0/2931 (0%)]	Loss: 0.053539
# Train: [1098/2931 (100%)]	Loss: 0.134285
# Epoch: 2/10. Train set: Average loss: 0.1341
# Epoch: 2/10. Validation set: Average loss: 0.1253
# Train: [0/2931 (0%)]	Loss: 0.095563
# Train: [1098/2931 (100%)]	Loss: 0.134477
# Epoch: 3/10. Train set: Average loss: 0.1344
# Epoch: 3/10. Validation set: Average loss: 0.1256
# Train: [0/2931 (0%)]	Loss: 0.161058
# Train: [1098/2931 (100%)]	Loss: 0.130513
# Epoch: 4/10. Train set: Average loss: 0.1306
# Epoch: 4/10. Validation set: Average loss: 0.1292
# Train: [0/2931 (0%)]	Loss: 0.184361
# Train: [1098/2931 (100%)]	Loss: 0.126353
# Epoch: 5/10. Train set: Average loss: 0.1265
# Epoch: 5/10. Validation set: Average loss: 0.1273
# Train: [0/2931 (0%)]	Loss: 0.056035
# Train: [1098/2931 (100%)]	Loss: 0.127954
# Epoch: 6/10. Train set: Average loss: 0.1278
# Epoch: 6/10. Validation set: Average loss: 0.1245
# Train: [0/2931 (0%)]	Loss: 0.113889
# Train: [1098/2931 (100%)]	Loss: 0.127264
# Epoch: 7/10. Train set: Average loss: 0.1272
# Epoch: 7/10. Validation set: Average loss: 0.1302
# Train: [0/2931 (0%)]	Loss: 0.167348
# Train: [1098/2931 (100%)]	Loss: 0.127668
# Epoch: 8/10. Train set: Average loss: 0.1278
# Epoch: 8/10. Validation set: Average loss: 0.1445
# Train: [0/2931 (0%)]	Loss: 0.141304
# Train: [1098/2931 (100%)]	Loss: 0.125746
# Epoch: 9/10. Train set: Average loss: 0.1258
# Epoch: 9/10. Validation set: Average loss: 0.1240
# Train: [0/2931 (0%)]	Loss: 0.081946
# Train: [1098/2931 (100%)]	Loss: 0.128044
# Epoch: 10/10. Train set: Average loss: 0.1279
# Epoch: 10/10. Validation set: Average loss: 0.1242
# Number features: 6
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.483210
# Epoch: 1/10. Train set: Average loss: 0.4826
# Epoch: 1/10. Validation set: Average loss: 0.2456
# Train: [0/2931 (0%)]	Loss: 0.270629
# Train: [1098/2931 (100%)]	Loss: 0.258010
# Epoch: 2/10. Train set: Average loss: 0.2580
# Epoch: 2/10. Validation set: Average loss: 0.2389
# Train: [0/2931 (0%)]	Loss: 0.186512
# Train: [1098/2931 (100%)]	Loss: 0.354131
# Epoch: 3/10. Train set: Average loss: 0.3537
# Epoch: 3/10. Validation set: Average loss: 0.2497
# Train: [0/2931 (0%)]	Loss: 0.249394
# Train: [1098/2931 (100%)]	Loss: 0.262872
# Epoch: 4/10. Train set: Average loss: 0.2628
# Epoch: 4/10. Validation set: Average loss: 0.2604
# Train: [0/2931 (0%)]	Loss: 0.255289
# Train: [1098/2931 (100%)]	Loss: 0.250862
# Epoch: 5/10. Train set: Average loss: 0.2509
# Epoch: 5/10. Validation set: Average loss: 0.4731
# Train: [0/2931 (0%)]	Loss: 0.229279
# Train: [1098/2931 (100%)]	Loss: 0.258841
# Epoch: 6/10. Train set: Average loss: 0.2588
# Epoch: 6/10. Validation set: Average loss: 0.2428
# Train: [0/2931 (0%)]	Loss: 0.242791
# Train: [1098/2931 (100%)]	Loss: 0.263045
# Epoch: 7/10. Train set: Average loss: 0.2630
# Epoch: 7/10. Validation set: Average loss: 0.4195
# Train: [0/2931 (0%)]	Loss: 0.262907
# Train: [1098/2931 (100%)]	Loss: 0.261757
# Epoch: 8/10. Train set: Average loss: 0.2618
# Epoch: 8/10. Validation set: Average loss: 0.2453
# Train: [0/2931 (0%)]	Loss: 0.244793
# Train: [1098/2931 (100%)]	Loss: 0.290993
# Epoch: 9/10. Train set: Average loss: 0.2909
# Epoch: 9/10. Validation set: Average loss: 0.2457
# Train: [0/2931 (0%)]	Loss: 0.247933
# Train: [1098/2931 (100%)]	Loss: 0.260908
# Epoch: 10/10. Train set: Average loss: 0.2609
# Epoch: 10/10. Validation set: Average loss: 0.2458
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.277177
# Epoch: 1/10. Train set: Average loss: 0.2771
# Epoch: 1/10. Validation set: Average loss: 0.2505
# Train: [0/2931 (0%)]	Loss: 0.186773
# Train: [1098/2931 (100%)]	Loss: 0.303486
# Epoch: 2/10. Train set: Average loss: 0.3032
# Epoch: 2/10. Validation set: Average loss: 0.2476
# Train: [0/2931 (0%)]	Loss: 0.187448
# Train: [1098/2931 (100%)]	Loss: 0.278422
# Epoch: 3/10. Train set: Average loss: 0.2782
# Epoch: 3/10. Validation set: Average loss: 0.2621
# Train: [0/2931 (0%)]	Loss: 0.195349
# Train: [1098/2931 (100%)]	Loss: 0.371921
# Epoch: 4/10. Train set: Average loss: 0.3714
# Epoch: 4/10. Validation set: Average loss: 0.2478
# Train: [0/2931 (0%)]	Loss: 0.187490
# Train: [1098/2931 (100%)]	Loss: 0.262492
# Epoch: 5/10. Train set: Average loss: 0.2623
# Epoch: 5/10. Validation set: Average loss: 0.2480
# Train: [0/2931 (0%)]	Loss: 0.187275
# Train: [1098/2931 (100%)]	Loss: 0.422124
# Epoch: 6/10. Train set: Average loss: 0.4215
# Epoch: 6/10. Validation set: Average loss: 0.2416
# Train: [0/2931 (0%)]	Loss: 0.179495
# Train: [1098/2931 (100%)]	Loss: 0.253778
# Epoch: 7/10. Train set: Average loss: 0.2536
# Epoch: 7/10. Validation set: Average loss: 0.2395
# Train: [0/2931 (0%)]	Loss: 0.187638
# Train: [1098/2931 (100%)]	Loss: 0.302294
# Epoch: 8/10. Train set: Average loss: 0.3020
# Epoch: 8/10. Validation set: Average loss: 0.2793
# Train: [0/2931 (0%)]	Loss: 0.240032
# Train: [1098/2931 (100%)]	Loss: 0.323148
# Epoch: 9/10. Train set: Average loss: 0.3229
# Epoch: 9/10. Validation set: Average loss: 0.2549
# Train: [0/2931 (0%)]	Loss: 0.187710
# Train: [1098/2931 (100%)]	Loss: 0.255187
# Epoch: 10/10. Train set: Average loss: 0.2550
# Epoch: 10/10. Validation set: Average loss: 0.2550
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.374976
# Train: [1098/2931 (100%)]	Loss: 0.302061
# Epoch: 1/10. Train set: Average loss: 0.3023
# Epoch: 1/10. Validation set: Average loss: 0.2483
# Train: [0/2931 (0%)]	Loss: 0.311516
# Train: [1098/2931 (100%)]	Loss: 0.269109
# Epoch: 2/10. Train set: Average loss: 0.2692
# Epoch: 2/10. Validation set: Average loss: 0.2446
# Train: [0/2931 (0%)]	Loss: 0.367480
# Train: [1098/2931 (100%)]	Loss: 0.262262
# Epoch: 3/10. Train set: Average loss: 0.2625
# Epoch: 3/10. Validation set: Average loss: 0.2481
# Train: [0/2931 (0%)]	Loss: 0.352929
# Train: [1098/2931 (100%)]	Loss: 0.265449
# Epoch: 4/10. Train set: Average loss: 0.2657
# Epoch: 4/10. Validation set: Average loss: 0.2452
# Train: [0/2931 (0%)]	Loss: 0.369132
# Train: [1098/2931 (100%)]	Loss: 0.267932
# Epoch: 5/10. Train set: Average loss: 0.2682
# Epoch: 5/10. Validation set: Average loss: 0.2438
# Train: [0/2931 (0%)]	Loss: 0.361442
# Train: [1098/2931 (100%)]	Loss: 0.260693
# Epoch: 6/10. Train set: Average loss: 0.2610
# Epoch: 6/10. Validation set: Average loss: 0.2474
# Train: [0/2931 (0%)]	Loss: 0.373708
# Train: [1098/2931 (100%)]	Loss: 0.262478
# Epoch: 7/10. Train set: Average loss: 0.2628
# Epoch: 7/10. Validation set: Average loss: 0.2485
# Train: [0/2931 (0%)]	Loss: 0.369985
# Train: [1098/2931 (100%)]	Loss: 0.265214
# Epoch: 8/10. Train set: Average loss: 0.2655
# Epoch: 8/10. Validation set: Average loss: 0.2460
# Train: [0/2931 (0%)]	Loss: 0.356407
# Train: [1098/2931 (100%)]	Loss: 0.263862
# Epoch: 9/10. Train set: Average loss: 0.2641
# Epoch: 9/10. Validation set: Average loss: 0.2453
# Train: [0/2931 (0%)]	Loss: 0.369348
# Train: [1098/2931 (100%)]	Loss: 0.259284
