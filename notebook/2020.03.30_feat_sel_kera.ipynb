# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("..")

import datetime
import pathlib

from collections import OrderedDict 

import numpy as np
import pandas as pd

# %%
# Pytorch
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable

# Custom
from dutils import Experiment
from trainer import fit
import visualization as vis
from tcga_datasets import SiameseDataset

# Models
from tcga_networks import EmbeddingNet, SiameseNet
from losses import ContrastiveLoss

# Metrics
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score as ANMI

# %%
def getTCGA(disease):
    path = "/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP/TCGA/TCGA_{}_counts.tsv.gz"
    files = [path.format(d) for d in disease]
    return files


def readGCP(files, biotype='protein_coding', mean=True):
    """
    Paths to count matrices.
    """
    data_dict = {}
    for f in files:
        key = os.path.basename(f).split("_")[1]
        data = pd.read_csv(f, sep='\t', index_col=0)
        # transcript metadata
        meta = pd.DataFrame([row[:-1] for row in data.index.str.split("|")],
                            columns=['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'GENE', 'BP', 'BIOTYPE'])
        meta = pd.MultiIndex.from_frame(meta)
        data.index = meta
        # subset transcripts
        data = data.xs(key=biotype, level='BIOTYPE')
        data = data.droplevel(['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'BP'])
        # average gene expression of splice variants
        data = data.T
        if mean:
            data = data.groupby(by=data.columns, axis=1).mean()
        data_dict[key] = data
    return data_dict


def uq_norm(df, q=0.75):
    """
    Upper quartile normalization of GEX for samples.
    """
    quantiles = df.quantile(q=q, axis=1)
    norm = df.divide(quantiles, axis=0)
    return norm


def process_TCGA(disease=['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']):
    base="/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP"
    # get files
    tcga_files = getTCGA(disease)
    # read meta/data
    tcga_meta = pd.read_csv(os.path.join(base, "TCGA/TCGA_GDC_ID_MAP.tsv"), sep="\t")
    tcga_raw = readGCP(tcga_files, mean=True)
    # combine samples
    tcga_raw = pd.concat(tcga_raw.values())
    # Upper quartile normalization
    tcga_raw = uq_norm(tcga_raw)
    # log norm
    tcga = tcga_raw.transform(np.log1p)
    return tcga, tcga_meta

# %%
def generate_fsets(data, n_features, steps=5):
    r = np.linspace(start=1, stop=n_features, num=steps, dtype='int')
    idx = [np.random.choice(data.shape[1], size=i, replace=False) for i in r]
    return idx

# %%
def feature_training(train_data, train_labels, test_data, test_labels, feature_idx, embedding, exp_dir, cuda=True):
    # Meta data
    meta_data = {"n_features":[],
                 "model":[],
                 "ANMI":[]}
    # Params
    batch_size = 8
    kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {'num_workers': 10}
    
    # Feature Index
    for batch, feat in enumerate(feature_idx):
        print("Number features: {}\n".format(len(feat)))
        exp_data = {'feature_idx':feat}
        # Define data
        siamese_train_dataset = SiameseDataset(data=train_data.iloc[:,feat],
                                           labels=train_labels,
                                           train=True)
        siamese_test_dataset = SiameseDataset(data=test_data.iloc[:,feat],
                                          labels=test_labels,
                                          train=False)
        # Loaders
        siamese_train_loader = torch.utils.data.DataLoader(siamese_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
        siamese_test_loader = torch.utils.data.DataLoader(siamese_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)
        # Instantiate model
        n_samples, n_features = siamese_train_dataset.train_data.shape
        for i in range(3):
            nmodel = 'model_{}'.format(i)
            print("\t{}".format(nmodel))
            embedding_net = EmbeddingNet(n_features, embedding)
            model = SiameseNet(embedding_net)
            if cuda:
                model.cuda()
            # Parameters
            margin = 1.
            loss_fn = ContrastiveLoss(margin)
            lr = 1e-3
            optimizer = optim.Adam(model.parameters(), lr=lr)
            scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
            n_epochs = 10
            log_interval = round(len(siamese_train_dataset)/1/batch_size)
            # Train
            train_loss, val_loss = fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, 
                                       n_epochs, cuda, log_interval)
            # Test Embeddings
            val_embeddings_baseline, val_labels_baseline = vis.extract_embeddings(siamese_test_dataset.test_data, siamese_test_dataset.labels, model)
            # Evaluation
            n_clusters = len(np.unique(test_labels))
            kmeans = KMeans(n_clusters=n_clusters)
            siamese_clusters = kmeans.fit_predict(val_embeddings_baseline)
            anmi = ANMI(siamese_clusters, val_labels_baseline)
            # Store
            meta_data['n_features'].append(len(feat))
            meta_data['model'].append(nmodel)
            meta_data['ANMI'].append(anmi)
            exp_data[nmodel] = {'data': (val_embeddings_baseline, val_labels_baseline),
                                'loss': (train_loss, val_loss),
                                'ANMI': anmi}
        pd.to_pickle(exp_data, os.path.join(exp_dir, "model_{}.pkl".format(len(feat))))
    pd.to_pickle(meta_data, os.path.join(exp_dir, "model_meta_data.pkl"))

# %%
def main(disease, sample_type, **kwargs):
    # GPUs
    os.environ["CUDA_VISIBLE_DEVICES"] = kwargs['device']
    cuda = torch.cuda.is_available()
    print("Cuda is available: {}".format(cuda))
    
    # Read / write / process
    tcga, tcga_meta = process_TCGA(disease)
    # Subset to GO feature subset
    uniprot = pd.read_csv("/srv/home/wconnell/keiser/data/uniprot_mapping_ids/TCGA_rnaseq_uniprot_features.tab.gz", sep="\t")
    keratin = uniprot[uniprot["Gene ontology (biological process)"] == "keratinization [GO:0031424]"]
    tcga = tcga.loc[:,tcga.columns.isin(keratin['Gene names  (primary )'])]
    # Feature design
    feature_idx = generate_fsets(tcga, n_features=kwargs['n_features'], steps=kwargs['steps'])
    # Experiment design
    hierarchy = OrderedDict({'Disease':disease,
                             'Sample Type':sample_type})
    # Define experiment
    exp = Experiment(meta_data=tcga_meta,
                     hierarchy=hierarchy,
                     index='CGHubAnalysisID',
                     cases='Case ID',
                     min_samples=20)
    # Train / Test split
    exp.train_test_split(cases='Case ID')
    # Return data 
    train_data, train_labels = exp.get_data(tcga, subset="train", dtype=np.float32)
    test_data, test_labels = exp.get_data(tcga, subset="test", dtype=np.float32)
    
    # Path *fix*
    dtime = datetime.datetime.today().strftime("%Y.%m.%d_%H:%M")
    exp_dir = "/srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/{}_{}_{}_{}_{}-{}".format(dtime,
                                                                                                  kwargs['note'],
                                                                                                  len(exp.labels_dict),
                                                                                                  kwargs['embedding'],
                                                                                                  kwargs['n_features'], 
                                                                                                  kwargs['steps'])
    pathlib.Path(exp_dir).mkdir(parents=True, exist_ok=False)
    print('Saving to: \n{}'.format(exp_dir))
    
    # Meta data
    experiments = {'experiment': exp,
                   'train':(train_data, train_labels),
                   'test': (test_data, test_labels)}
    pd.to_pickle(experiments, os.path.join(exp_dir, "experiment_meta_data.pkl"))
    
    # Training
    feature_training(train_data, train_labels, test_data, test_labels, feature_idx, kwargs['embedding'], exp_dir)

# %% [markdown]
# ### Setup

# %%
uniprot = pd.read_csv("/srv/home/wconnell/keiser/data/uniprot_mapping_ids/TCGA_rnaseq_uniprot_features.tab.gz", sep="\t")
keratin = uniprot[uniprot["Gene ontology (biological process)"] == "keratinization [GO:0031424]"]

# %%
disease = ['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']
sample_type = ['Primary Tumor', 'Solid Tissue Normal']
params = {"device":"3",
          "note":"keratinization",
          "n_features":len(keratin),
          "steps":50,
          "embedding":2}

# %%
main(disease=disease, sample_type=sample_type, **params)
# Out:
# Cuda is available: True
# Saving to:
# /srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/2020.03.30_10:08_keratinization_11_2_94-50
# Number features: 1
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.268095
# Epoch: 1/10. Train set: Average loss: 0.2682
# Epoch: 1/10. Validation set: Average loss: 0.2473
# Train: [0/2931 (0%)]	Loss: 0.315754
# Train: [1098/2931 (100%)]	Loss: 0.238790
# Epoch: 2/10. Train set: Average loss: 0.2390
# Epoch: 2/10. Validation set: Average loss: 0.2476
# Train: [0/2931 (0%)]	Loss: 0.249706
# Train: [1098/2931 (100%)]	Loss: 0.239386
# Epoch: 3/10. Train set: Average loss: 0.2394
# Epoch: 3/10. Validation set: Average loss: 0.2568
# Train: [0/2931 (0%)]	Loss: 0.124994
# Train: [1098/2931 (100%)]	Loss: 0.624472
# Epoch: 4/10. Train set: Average loss: 0.6231
# Epoch: 4/10. Validation set: Average loss: 0.2457
# Train: [0/2931 (0%)]	Loss: 0.312323
# Train: [1098/2931 (100%)]	Loss: 0.233084
# Epoch: 5/10. Train set: Average loss: 0.2333
# Epoch: 5/10. Validation set: Average loss: 0.2417
# Train: [0/2931 (0%)]	Loss: 0.265846
# Train: [1098/2931 (100%)]	Loss: 0.230804
# Epoch: 6/10. Train set: Average loss: 0.2309
# Epoch: 6/10. Validation set: Average loss: 0.2429
# Train: [0/2931 (0%)]	Loss: 0.311531
# Train: [1098/2931 (100%)]	Loss: 0.231661
# Epoch: 7/10. Train set: Average loss: 0.2319
# Epoch: 7/10. Validation set: Average loss: 0.2471
# Train: [0/2931 (0%)]	Loss: 0.311780
# Train: [1098/2931 (100%)]	Loss: 0.225826
# Epoch: 8/10. Train set: Average loss: 0.2261
# Epoch: 8/10. Validation set: Average loss: 0.2474
# Train: [0/2931 (0%)]	Loss: 0.312286
# Train: [1098/2931 (100%)]	Loss: 0.236162
# Epoch: 9/10. Train set: Average loss: 0.2364
# Epoch: 9/10. Validation set: Average loss: 0.2457
# Train: [0/2931 (0%)]	Loss: 0.310863
# Train: [1098/2931 (100%)]	Loss: 0.234611
# Epoch: 10/10. Train set: Average loss: 0.2348
# Epoch: 10/10. Validation set: Average loss: 0.2447
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.374976
# Train: [1098/2931 (100%)]	Loss: 0.274737
# Epoch: 1/10. Train set: Average loss: 0.2750
# Epoch: 1/10. Validation set: Average loss: 0.2431
# Train: [0/2931 (0%)]	Loss: 0.374632
# Train: [1098/2931 (100%)]	Loss: 0.232251
# Epoch: 2/10. Train set: Average loss: 0.2326
# Epoch: 2/10. Validation set: Average loss: 0.2454
# Train: [0/2931 (0%)]	Loss: 0.374701
# Train: [1098/2931 (100%)]	Loss: 0.241122
# Epoch: 3/10. Train set: Average loss: 0.2415
# Epoch: 3/10. Validation set: Average loss: 0.2482
# Train: [0/2931 (0%)]	Loss: 0.361353
# Train: [1098/2931 (100%)]	Loss: 0.234824
# Epoch: 4/10. Train set: Average loss: 0.2352
# Epoch: 4/10. Validation set: Average loss: 0.2439
# Train: [0/2931 (0%)]	Loss: 0.374240
# Train: [1098/2931 (100%)]	Loss: 0.232891
# Epoch: 5/10. Train set: Average loss: 0.2333
# Epoch: 5/10. Validation set: Average loss: 0.2459
# Train: [0/2931 (0%)]	Loss: 0.354147
# Train: [1098/2931 (100%)]	Loss: 0.227820
# Epoch: 6/10. Train set: Average loss: 0.2282
# Epoch: 6/10. Validation set: Average loss: 0.2416
# Train: [0/2931 (0%)]	Loss: 0.374085
# Train: [1098/2931 (100%)]	Loss: 0.249923
# Epoch: 7/10. Train set: Average loss: 0.2503
# Epoch: 7/10. Validation set: Average loss: 0.2458
# Train: [0/2931 (0%)]	Loss: 0.374636
# Train: [1098/2931 (100%)]	Loss: 0.241257
# Epoch: 8/10. Train set: Average loss: 0.2416
# Epoch: 8/10. Validation set: Average loss: 0.2466
# Train: [0/2931 (0%)]	Loss: 0.374720
# Train: [1098/2931 (100%)]	Loss: 0.238619
# Epoch: 9/10. Train set: Average loss: 0.2390
# Epoch: 9/10. Validation set: Average loss: 0.2460
# Train: [0/2931 (0%)]	Loss: 0.374588
# Train: [1098/2931 (100%)]	Loss: 0.235981
# Epoch: 10/10. Train set: Average loss: 0.2364
# Epoch: 10/10. Validation set: Average loss: 0.2457
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.248432
# Epoch: 1/10. Train set: Average loss: 0.2486
# Epoch: 1/10. Validation set: Average loss: 0.2483
# Train: [0/2931 (0%)]	Loss: 0.312373
# Train: [1098/2931 (100%)]	Loss: 0.242174
# Epoch: 2/10. Train set: Average loss: 0.2424
# Epoch: 2/10. Validation set: Average loss: 0.2482
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.233815
# Epoch: 3/10. Train set: Average loss: 0.2340
# Epoch: 3/10. Validation set: Average loss: 0.2477
# Train: [0/2931 (0%)]	Loss: 0.297731
# Train: [1098/2931 (100%)]	Loss: 0.345616
# Epoch: 4/10. Train set: Average loss: 0.3455
# Epoch: 4/10. Validation set: Average loss: 0.2497
# Train: [0/2931 (0%)]	Loss: 0.312204
# Train: [1098/2931 (100%)]	Loss: 0.242694
# Epoch: 5/10. Train set: Average loss: 0.2429
# Epoch: 5/10. Validation set: Average loss: 0.2473
# Train: [0/2931 (0%)]	Loss: 0.312313
# Train: [1098/2931 (100%)]	Loss: 0.230557
# Epoch: 6/10. Train set: Average loss: 0.2308
# Epoch: 6/10. Validation set: Average loss: 0.2436
# Train: [0/2931 (0%)]	Loss: 0.312096
# Train: [1098/2931 (100%)]	Loss: 0.228170
# Epoch: 7/10. Train set: Average loss: 0.2284
# Epoch: 7/10. Validation set: Average loss: 0.2445
# Train: [0/2931 (0%)]	Loss: 0.312044
# Train: [1098/2931 (100%)]	Loss: 0.235081
# Epoch: 8/10. Train set: Average loss: 0.2353
# Epoch: 8/10. Validation set: Average loss: 0.2410
# Train: [0/2931 (0%)]	Loss: 0.310709
# Train: [1098/2931 (100%)]	Loss: 0.231433
# Epoch: 9/10. Train set: Average loss: 0.2316
# Epoch: 9/10. Validation set: Average loss: 0.2393
# Train: [0/2931 (0%)]	Loss: 0.310341
# Train: [1098/2931 (100%)]	Loss: 0.230682
# Epoch: 10/10. Train set: Average loss: 0.2309
# Epoch: 10/10. Validation set: Average loss: 0.2387
# Number features: 2
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.395568
# Epoch: 1/10. Train set: Average loss: 0.3952
# Epoch: 1/10. Validation set: Average loss: 0.2416
# Train: [0/2931 (0%)]	Loss: 0.302930
# Train: [1098/2931 (100%)]	Loss: 0.223027
# Epoch: 2/10. Train set: Average loss: 0.2232
# Epoch: 2/10. Validation set: Average loss: 0.2363
# Train: [0/2931 (0%)]	Loss: 0.322400
# Train: [1098/2931 (100%)]	Loss: 0.220359
# Epoch: 3/10. Train set: Average loss: 0.2206
# Epoch: 3/10. Validation set: Average loss: 0.2407
# Train: [0/2931 (0%)]	Loss: 0.239832
# Train: [1098/2931 (100%)]	Loss: 0.225451
# Epoch: 4/10. Train set: Average loss: 0.2255
# Epoch: 4/10. Validation set: Average loss: 0.2303
# Train: [0/2931 (0%)]	Loss: 0.225370
# Train: [1098/2931 (100%)]	Loss: 0.219360
# Epoch: 5/10. Train set: Average loss: 0.2194
# Epoch: 5/10. Validation set: Average loss: 0.2383
# Train: [0/2931 (0%)]	Loss: 0.250338
# Train: [1098/2931 (100%)]	Loss: 0.228323
# Epoch: 6/10. Train set: Average loss: 0.2284
# Epoch: 6/10. Validation set: Average loss: 0.2484
# Train: [0/2931 (0%)]	Loss: 0.310108
# Train: [1098/2931 (100%)]	Loss: 0.229130
# Epoch: 7/10. Train set: Average loss: 0.2294
# Epoch: 7/10. Validation set: Average loss: 0.2407
# Train: [0/2931 (0%)]	Loss: 0.245432
# Train: [1098/2931 (100%)]	Loss: 0.235656
# Epoch: 8/10. Train set: Average loss: 0.2357
# Epoch: 8/10. Validation set: Average loss: 0.2405
# Train: [0/2931 (0%)]	Loss: 0.233771
# Train: [1098/2931 (100%)]	Loss: 0.223938
# Epoch: 9/10. Train set: Average loss: 0.2240
# Epoch: 9/10. Validation set: Average loss: 0.2388
# Train: [0/2931 (0%)]	Loss: 0.236216
# Train: [1098/2931 (100%)]	Loss: 0.224113
# Epoch: 10/10. Train set: Average loss: 0.2241
# Epoch: 10/10. Validation set: Average loss: 0.2381
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249977
# Train: [1098/2931 (100%)]	Loss: 0.234752
# Epoch: 1/10. Train set: Average loss: 0.2348
# Epoch: 1/10. Validation set: Average loss: 0.2212
# Train: [0/2931 (0%)]	Loss: 1.422477
# Train: [1098/2931 (100%)]	Loss: 0.242267
# Epoch: 2/10. Train set: Average loss: 0.2455
# Epoch: 2/10. Validation set: Average loss: 0.2428
# Train: [0/2931 (0%)]	Loss: 0.306653
# Train: [1098/2931 (100%)]	Loss: 0.226457
# Epoch: 3/10. Train set: Average loss: 0.2267
# Epoch: 3/10. Validation set: Average loss: 0.2343
# Train: [0/2931 (0%)]	Loss: 0.238725
# Train: [1098/2931 (100%)]	Loss: 0.216040
# Epoch: 4/10. Train set: Average loss: 0.2161
# Epoch: 4/10. Validation set: Average loss: 0.2118
# Train: [0/2931 (0%)]	Loss: 0.216342
# Train: [1098/2931 (100%)]	Loss: 0.267522
# Epoch: 5/10. Train set: Average loss: 0.2674
# Epoch: 5/10. Validation set: Average loss: 0.2374
# Train: [0/2931 (0%)]	Loss: 0.301642
# Train: [1098/2931 (100%)]	Loss: 0.308544
# Epoch: 6/10. Train set: Average loss: 0.3085
# Epoch: 6/10. Validation set: Average loss: 0.2375
# Train: [0/2931 (0%)]	Loss: 0.328499
# Train: [1098/2931 (100%)]	Loss: 0.254666
# Epoch: 7/10. Train set: Average loss: 0.2549
# Epoch: 7/10. Validation set: Average loss: 0.2372
# Train: [0/2931 (0%)]	Loss: 0.182156
# Train: [1098/2931 (100%)]	Loss: 0.215051
# Epoch: 8/10. Train set: Average loss: 0.2150
# Epoch: 8/10. Validation set: Average loss: 0.2405
# Train: [0/2931 (0%)]	Loss: 0.245808
# Train: [1098/2931 (100%)]	Loss: 0.216365
# Epoch: 9/10. Train set: Average loss: 0.2164
# Epoch: 9/10. Validation set: Average loss: 0.2292
# Train: [0/2931 (0%)]	Loss: 0.218816
# Train: [1098/2931 (100%)]	Loss: 0.209459
# Epoch: 10/10. Train set: Average loss: 0.2095
# Epoch: 10/10. Validation set: Average loss: 0.2201
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.290417
# Epoch: 1/10. Train set: Average loss: 0.2903
# Epoch: 1/10. Validation set: Average loss: 0.2442
# Train: [0/2931 (0%)]	Loss: 0.308201
# Train: [1098/2931 (100%)]	Loss: 0.261744
# Epoch: 2/10. Train set: Average loss: 0.2619
# Epoch: 2/10. Validation set: Average loss: 0.2366
# Train: [0/2931 (0%)]	Loss: 0.238030
# Train: [1098/2931 (100%)]	Loss: 0.227411
# Epoch: 3/10. Train set: Average loss: 0.2274
# Epoch: 3/10. Validation set: Average loss: 0.2422
# Train: [0/2931 (0%)]	Loss: 0.236047
# Train: [1098/2931 (100%)]	Loss: 0.232988
# Epoch: 4/10. Train set: Average loss: 0.2330
# Epoch: 4/10. Validation set: Average loss: 0.2454
# Train: [0/2931 (0%)]	Loss: 0.307999
# Train: [1098/2931 (100%)]	Loss: 0.227653
# Epoch: 5/10. Train set: Average loss: 0.2279
# Epoch: 5/10. Validation set: Average loss: 0.2479
# Train: [0/2931 (0%)]	Loss: 0.310694
# Train: [1098/2931 (100%)]	Loss: 0.230571
# Epoch: 6/10. Train set: Average loss: 0.2308
# Epoch: 6/10. Validation set: Average loss: 0.2483
# Train: [0/2931 (0%)]	Loss: 0.310926
# Train: [1098/2931 (100%)]	Loss: 0.222764
# Epoch: 7/10. Train set: Average loss: 0.2230
# Epoch: 7/10. Validation set: Average loss: 0.2398
# Train: [0/2931 (0%)]	Loss: 0.245823
# Train: [1098/2931 (100%)]	Loss: 0.219683
# Epoch: 8/10. Train set: Average loss: 0.2198
# Epoch: 8/10. Validation set: Average loss: 0.2354
# Train: [0/2931 (0%)]	Loss: 0.266174
# Train: [1098/2931 (100%)]	Loss: 0.222629
# Epoch: 9/10. Train set: Average loss: 0.2227
# Epoch: 9/10. Validation set: Average loss: 0.2339
# Train: [0/2931 (0%)]	Loss: 0.232031
# Train: [1098/2931 (100%)]	Loss: 0.215407
# Epoch: 10/10. Train set: Average loss: 0.2155
# Epoch: 10/10. Validation set: Average loss: 0.2284
# Number features: 4
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.249749
# Train: [1098/2931 (100%)]	Loss: 0.618955
# Epoch: 1/10. Train set: Average loss: 0.6179
# Epoch: 1/10. Validation set: Average loss: 0.2461
# Train: [0/2931 (0%)]	Loss: 0.310282
# Train: [1098/2931 (100%)]	Loss: 0.232346
# Epoch: 2/10. Train set: Average loss: 0.2326
# Epoch: 2/10. Validation set: Average loss: 0.2446
# Train: [0/2931 (0%)]	Loss: 0.277842
# Train: [1098/2931 (100%)]	Loss: 0.232651
# Epoch: 3/10. Train set: Average loss: 0.2328
# Epoch: 3/10. Validation set: Average loss: 0.2443
# Train: [0/2931 (0%)]	Loss: 0.185844
# Train: [1098/2931 (100%)]	Loss: 0.231123
# Epoch: 4/10. Train set: Average loss: 0.2310
# Epoch: 4/10. Validation set: Average loss: 0.2442
# Train: [0/2931 (0%)]	Loss: 0.311104
# Train: [1098/2931 (100%)]	Loss: 0.228630
# Epoch: 5/10. Train set: Average loss: 0.2289
# Epoch: 5/10. Validation set: Average loss: 0.2490
# Train: [0/2931 (0%)]	Loss: 0.062501
# Train: [1098/2931 (100%)]	Loss: 0.232726
# Epoch: 6/10. Train set: Average loss: 0.2323
# Epoch: 6/10. Validation set: Average loss: 0.2459
# Train: [0/2931 (0%)]	Loss: 0.182341
# Train: [1098/2931 (100%)]	Loss: 0.228747
# Epoch: 7/10. Train set: Average loss: 0.2286
# Epoch: 7/10. Validation set: Average loss: 0.2449
# Train: [0/2931 (0%)]	Loss: 0.185608
# Train: [1098/2931 (100%)]	Loss: 0.234486
# Epoch: 8/10. Train set: Average loss: 0.2344
# Epoch: 8/10. Validation set: Average loss: 0.2471
# Train: [0/2931 (0%)]	Loss: 0.249545
# Train: [1098/2931 (100%)]	Loss: 0.230558
# Epoch: 9/10. Train set: Average loss: 0.2306
# Epoch: 9/10. Validation set: Average loss: 0.2437
# Train: [0/2931 (0%)]	Loss: 0.123519
# Train: [1098/2931 (100%)]	Loss: 0.234239
# Epoch: 10/10. Train set: Average loss: 0.2339
# Epoch: 10/10. Validation set: Average loss: 0.2438
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.312479
# Train: [1098/2931 (100%)]	Loss: 0.249649
# Epoch: 1/10. Train set: Average loss: 0.2498
# Epoch: 1/10. Validation set: Average loss: 0.2478
# Train: [0/2931 (0%)]	Loss: 0.312404
# Train: [1098/2931 (100%)]	Loss: 0.232257
# Epoch: 2/10. Train set: Average loss: 0.2325
# Epoch: 2/10. Validation set: Average loss: 0.2470
# Train: [0/2931 (0%)]	Loss: 0.374527
# Train: [1098/2931 (100%)]	Loss: 0.234776
# Epoch: 3/10. Train set: Average loss: 0.2352
# Epoch: 3/10. Validation set: Average loss: 0.2488
# Train: [0/2931 (0%)]	Loss: 0.311634
# Train: [1098/2931 (100%)]	Loss: 0.234825
# Epoch: 4/10. Train set: Average loss: 0.2350
# Epoch: 4/10. Validation set: Average loss: 0.2465
# Train: [0/2931 (0%)]	Loss: 0.311785
# Train: [1098/2931 (100%)]	Loss: 0.233363
# Epoch: 5/10. Train set: Average loss: 0.2336
# Epoch: 5/10. Validation set: Average loss: 0.2470
# Train: [0/2931 (0%)]	Loss: 0.308235
# Train: [1098/2931 (100%)]	Loss: 0.235156
# Epoch: 6/10. Train set: Average loss: 0.2354
# Epoch: 6/10. Validation set: Average loss: 0.2497
# Train: [0/2931 (0%)]	Loss: 0.249904
# Train: [1098/2931 (100%)]	Loss: 0.254499
# Epoch: 7/10. Train set: Average loss: 0.2545
# Epoch: 7/10. Validation set: Average loss: 0.2478
# Train: [0/2931 (0%)]	Loss: 0.315546
# Train: [1098/2931 (100%)]	Loss: 0.234148
# Epoch: 8/10. Train set: Average loss: 0.2344
# Epoch: 8/10. Validation set: Average loss: 0.2461
# Train: [0/2931 (0%)]	Loss: 0.374253
# Train: [1098/2931 (100%)]	Loss: 0.233220
# Epoch: 9/10. Train set: Average loss: 0.2336
# Epoch: 9/10. Validation set: Average loss: 0.2451
# Train: [0/2931 (0%)]	Loss: 0.373524
# Train: [1098/2931 (100%)]	Loss: 0.227533
# Epoch: 10/10. Train set: Average loss: 0.2279
# Epoch: 10/10. Validation set: Average loss: 0.2441
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249982
# Train: [1098/2931 (100%)]	Loss: 0.241468
# Epoch: 1/10. Train set: Average loss: 0.2415
# Epoch: 1/10. Validation set: Average loss: 0.2478
# Train: [0/2931 (0%)]	Loss: 0.190938
# Train: [1098/2931 (100%)]	Loss: 0.237604
# Epoch: 2/10. Train set: Average loss: 0.2375
# Epoch: 2/10. Validation set: Average loss: 0.2476
# Train: [0/2931 (0%)]	Loss: 0.249744
# Train: [1098/2931 (100%)]	Loss: 0.231967
# Epoch: 3/10. Train set: Average loss: 0.2320
# Epoch: 3/10. Validation set: Average loss: 0.2460
# Train: [0/2931 (0%)]	Loss: 0.248772
# Train: [1098/2931 (100%)]	Loss: 0.232419
# Epoch: 4/10. Train set: Average loss: 0.2325
# Epoch: 4/10. Validation set: Average loss: 0.2478
# Train: [0/2931 (0%)]	Loss: 0.306674
# Train: [1098/2931 (100%)]	Loss: 0.234488
# Epoch: 5/10. Train set: Average loss: 0.2347
# Epoch: 5/10. Validation set: Average loss: 0.2444
# Train: [0/2931 (0%)]	Loss: 0.247212
# Train: [1098/2931 (100%)]	Loss: 0.229513
# Epoch: 6/10. Train set: Average loss: 0.2296
# Epoch: 6/10. Validation set: Average loss: 0.2443
# Train: [0/2931 (0%)]	Loss: 0.249064
# Train: [1098/2931 (100%)]	Loss: 0.225744
# Epoch: 7/10. Train set: Average loss: 0.2258
# Epoch: 7/10. Validation set: Average loss: 0.2390
# Train: [0/2931 (0%)]	Loss: 0.227025
# Train: [1098/2931 (100%)]	Loss: 0.227670
# Epoch: 8/10. Train set: Average loss: 0.2277
# Epoch: 8/10. Validation set: Average loss: 0.2455
# Train: [0/2931 (0%)]	Loss: 0.248789
# Train: [1098/2931 (100%)]	Loss: 0.228495
# Epoch: 9/10. Train set: Average loss: 0.2286
# Epoch: 9/10. Validation set: Average loss: 0.2387
# Train: [0/2931 (0%)]	Loss: 0.244148
# Train: [1098/2931 (100%)]	Loss: 0.212305
# Epoch: 10/10. Train set: Average loss: 0.2124
# Epoch: 10/10. Validation set: Average loss: 0.2332
# Number features: 6
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.312415
# Train: [1098/2931 (100%)]	Loss: 0.352776
# Epoch: 1/10. Train set: Average loss: 0.3527
# Epoch: 1/10. Validation set: Average loss: 0.2170
# Train: [0/2931 (0%)]	Loss: 0.121767
# Train: [1098/2931 (100%)]	Loss: 0.245980
# Epoch: 2/10. Train set: Average loss: 0.2456
# Epoch: 2/10. Validation set: Average loss: 0.2460
# Train: [0/2931 (0%)]	Loss: 0.256876
# Train: [1098/2931 (100%)]	Loss: 0.245459
# Epoch: 3/10. Train set: Average loss: 0.2455
# Epoch: 3/10. Validation set: Average loss: 0.2478
# Train: [0/2931 (0%)]	Loss: 0.305547
# Train: [1098/2931 (100%)]	Loss: 0.243337
# Epoch: 4/10. Train set: Average loss: 0.2435
# Epoch: 4/10. Validation set: Average loss: 0.2250
# Train: [0/2931 (0%)]	Loss: 0.183604
# Train: [1098/2931 (100%)]	Loss: 0.236456
# Epoch: 5/10. Train set: Average loss: 0.2363
# Epoch: 5/10. Validation set: Average loss: 0.2338
# Train: [0/2931 (0%)]	Loss: 0.255288
# Train: [1098/2931 (100%)]	Loss: 0.221288
# Epoch: 6/10. Train set: Average loss: 0.2214
# Epoch: 6/10. Validation set: Average loss: 0.1897
# Train: [0/2931 (0%)]	Loss: 0.247703
# Train: [1098/2931 (100%)]	Loss: 0.195921
# Epoch: 7/10. Train set: Average loss: 0.1961
# Epoch: 7/10. Validation set: Average loss: 0.2035
# Train: [0/2931 (0%)]	Loss: 0.215927
# Train: [1098/2931 (100%)]	Loss: 0.207309
# Epoch: 8/10. Train set: Average loss: 0.2073
# Epoch: 8/10. Validation set: Average loss: 0.1702
# Train: [0/2931 (0%)]	Loss: 0.286528
# Train: [1098/2931 (100%)]	Loss: 0.167706
# Epoch: 9/10. Train set: Average loss: 0.1680
# Epoch: 9/10. Validation set: Average loss: 0.1658
# Train: [0/2931 (0%)]	Loss: 0.178680
# Train: [1098/2931 (100%)]	Loss: 0.166654
# Epoch: 10/10. Train set: Average loss: 0.1667
# Epoch: 10/10. Validation set: Average loss: 0.1667
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.312379
# Train: [1098/2931 (100%)]	Loss: 0.251987
# Epoch: 1/10. Train set: Average loss: 0.2522
# Epoch: 1/10. Validation set: Average loss: 0.2379
# Train: [0/2931 (0%)]	Loss: 0.236199
# Train: [1098/2931 (100%)]	Loss: 0.294012
# Epoch: 2/10. Train set: Average loss: 0.2939
# Epoch: 2/10. Validation set: Average loss: 0.2458
# Train: [0/2931 (0%)]	Loss: 0.248686
# Train: [1098/2931 (100%)]	Loss: 0.240005
# Epoch: 3/10. Train set: Average loss: 0.2400
# Epoch: 3/10. Validation set: Average loss: 0.2396
# Train: [0/2931 (0%)]	Loss: 0.244521
# Train: [1098/2931 (100%)]	Loss: 0.252965
# Epoch: 4/10. Train set: Average loss: 0.2529
# Epoch: 4/10. Validation set: Average loss: 0.2348
# Train: [0/2931 (0%)]	Loss: 0.270138
# Train: [1098/2931 (100%)]	Loss: 0.247663
# Epoch: 5/10. Train set: Average loss: 0.2477
# Epoch: 5/10. Validation set: Average loss: 0.2169
# Train: [0/2931 (0%)]	Loss: 0.247230
# Train: [1098/2931 (100%)]	Loss: 0.228484
# Epoch: 6/10. Train set: Average loss: 0.2285
# Epoch: 6/10. Validation set: Average loss: 0.2465
# Train: [0/2931 (0%)]	Loss: 0.297778
# Train: [1098/2931 (100%)]	Loss: 0.229438
# Epoch: 7/10. Train set: Average loss: 0.2296
# Epoch: 7/10. Validation set: Average loss: 0.2001
# Train: [0/2931 (0%)]	Loss: 0.229311
# Train: [1098/2931 (100%)]	Loss: 0.224160
# Epoch: 8/10. Train set: Average loss: 0.2242
# Epoch: 8/10. Validation set: Average loss: 0.2146
# Train: [0/2931 (0%)]	Loss: 0.172907
# Train: [1098/2931 (100%)]	Loss: 0.191208
# Epoch: 9/10. Train set: Average loss: 0.1912
# Epoch: 9/10. Validation set: Average loss: 0.1781
# Train: [0/2931 (0%)]	Loss: 0.226067
# Train: [1098/2931 (100%)]	Loss: 0.180132
# Epoch: 10/10. Train set: Average loss: 0.1803
# Epoch: 10/10. Validation set: Average loss: 0.1712
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.312475
# Train: [1098/2931 (100%)]	Loss: 0.255171
# Epoch: 1/10. Train set: Average loss: 0.2553
# Epoch: 1/10. Validation set: Average loss: 0.2401
# Train: [0/2931 (0%)]	Loss: 0.303185
# Train: [1098/2931 (100%)]	Loss: 0.267664
# Epoch: 2/10. Train set: Average loss: 0.2678
# Epoch: 2/10. Validation set: Average loss: 0.2521
# Train: [0/2931 (0%)]	Loss: 0.309281
# Train: [1098/2931 (100%)]	Loss: 0.246463
# Epoch: 3/10. Train set: Average loss: 0.2466
# Epoch: 3/10. Validation set: Average loss: 0.2451
# Train: [0/2931 (0%)]	Loss: 0.309807
# Train: [1098/2931 (100%)]	Loss: 0.243496
# Epoch: 4/10. Train set: Average loss: 0.2437
# Epoch: 4/10. Validation set: Average loss: 0.2658
# Train: [0/2931 (0%)]	Loss: 0.278057
# Train: [1098/2931 (100%)]	Loss: 0.239692
# Epoch: 5/10. Train set: Average loss: 0.2398
# Epoch: 5/10. Validation set: Average loss: 0.2193
# Train: [0/2931 (0%)]	Loss: 0.236836
# Train: [1098/2931 (100%)]	Loss: 0.252919
# Epoch: 6/10. Train set: Average loss: 0.2529
# Epoch: 6/10. Validation set: Average loss: 0.2417
# Train: [0/2931 (0%)]	Loss: 0.303415
# Train: [1098/2931 (100%)]	Loss: 0.232746
# Epoch: 7/10. Train set: Average loss: 0.2329
# Epoch: 7/10. Validation set: Average loss: 0.3488
# Train: [0/2931 (0%)]	Loss: 0.214575
# Train: [1098/2931 (100%)]	Loss: 0.258288
# Epoch: 8/10. Train set: Average loss: 0.2582
# Epoch: 8/10. Validation set: Average loss: 0.2322
# Train: [0/2931 (0%)]	Loss: 0.290429
# Train: [1098/2931 (100%)]	Loss: 0.217994
# Epoch: 9/10. Train set: Average loss: 0.2182
# Epoch: 9/10. Validation set: Average loss: 0.2014
# Train: [0/2931 (0%)]	Loss: 0.270488
# Train: [1098/2931 (100%)]	Loss: 0.192017
# Epoch: 10/10. Train set: Average loss: 0.1922
# Epoch: 10/10. Validation set: Average loss: 0.1804
# Number features: 8
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187488
# Train: [1098/2931 (100%)]	Loss: 0.261763
# Epoch: 1/10. Train set: Average loss: 0.2616
# Epoch: 1/10. Validation set: Average loss: 0.2467
# Train: [0/2931 (0%)]	Loss: 0.124800
# Train: [1098/2931 (100%)]	Loss: 0.243189
# Epoch: 2/10. Train set: Average loss: 0.2429
# Epoch: 2/10. Validation set: Average loss: 0.2448
# Train: [0/2931 (0%)]	Loss: 0.243846
# Train: [1098/2931 (100%)]	Loss: 0.237292
# Epoch: 3/10. Train set: Average loss: 0.2373
# Epoch: 3/10. Validation set: Average loss: 0.2434
# Train: [0/2931 (0%)]	Loss: 0.124369
# Train: [1098/2931 (100%)]	Loss: 0.240542
# Epoch: 4/10. Train set: Average loss: 0.2402
# Epoch: 4/10. Validation set: Average loss: 0.3829
# Train: [0/2931 (0%)]	Loss: 0.245334
# Train: [1098/2931 (100%)]	Loss: 0.230771
# Epoch: 5/10. Train set: Average loss: 0.2308
# Epoch: 5/10. Validation set: Average loss: 0.2706
# Train: [0/2931 (0%)]	Loss: 0.177067
# Train: [1098/2931 (100%)]	Loss: 0.226577
# Epoch: 6/10. Train set: Average loss: 0.2264
# Epoch: 6/10. Validation set: Average loss: 0.2234
# Train: [0/2931 (0%)]	Loss: 0.114379
# Train: [1098/2931 (100%)]	Loss: 0.225125
# Epoch: 7/10. Train set: Average loss: 0.2248
# Epoch: 7/10. Validation set: Average loss: 0.2301
# Train: [0/2931 (0%)]	Loss: 0.235638
# Train: [1098/2931 (100%)]	Loss: 0.224780
# Epoch: 8/10. Train set: Average loss: 0.2248
# Epoch: 8/10. Validation set: Average loss: 0.2428
# Train: [0/2931 (0%)]	Loss: 0.116967
# Train: [1098/2931 (100%)]	Loss: 0.230733
# Epoch: 9/10. Train set: Average loss: 0.2304
# Epoch: 9/10. Validation set: Average loss: 0.2295
# Train: [0/2931 (0%)]	Loss: 0.461861
# Train: [1098/2931 (100%)]	Loss: 0.220858
# Epoch: 10/10. Train set: Average loss: 0.2215
# Epoch: 10/10. Validation set: Average loss: 0.2183
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249976
# Train: [1098/2931 (100%)]	Loss: 0.327509
# Epoch: 1/10. Train set: Average loss: 0.3273
# Epoch: 1/10. Validation set: Average loss: 0.2489
# Train: [0/2931 (0%)]	Loss: 0.278768
# Train: [1098/2931 (100%)]	Loss: 0.248132
# Epoch: 2/10. Train set: Average loss: 0.2482
# Epoch: 2/10. Validation set: Average loss: 0.2377
# Train: [0/2931 (0%)]	Loss: 0.244107
# Train: [1098/2931 (100%)]	Loss: 0.235914
# Epoch: 3/10. Train set: Average loss: 0.2359
# Epoch: 3/10. Validation set: Average loss: 0.2371
# Train: [0/2931 (0%)]	Loss: 0.240947
# Train: [1098/2931 (100%)]	Loss: 0.229415
# Epoch: 4/10. Train set: Average loss: 0.2294
# Epoch: 4/10. Validation set: Average loss: 0.2506
# Train: [0/2931 (0%)]	Loss: 0.298990
# Train: [1098/2931 (100%)]	Loss: 0.229537
# Epoch: 5/10. Train set: Average loss: 0.2297
# Epoch: 5/10. Validation set: Average loss: 0.2298
# Train: [0/2931 (0%)]	Loss: 0.224347
# Train: [1098/2931 (100%)]	Loss: 0.222601
# Epoch: 6/10. Train set: Average loss: 0.2226
# Epoch: 6/10. Validation set: Average loss: 0.2386
# Train: [0/2931 (0%)]	Loss: 0.155912
# Train: [1098/2931 (100%)]	Loss: 0.225692
# Epoch: 7/10. Train set: Average loss: 0.2255
# Epoch: 7/10. Validation set: Average loss: 0.2418
# Train: [0/2931 (0%)]	Loss: 0.302524
# Train: [1098/2931 (100%)]	Loss: 0.228360
# Epoch: 8/10. Train set: Average loss: 0.2286
# Epoch: 8/10. Validation set: Average loss: 0.2266
# Train: [0/2931 (0%)]	Loss: 0.248851
# Train: [1098/2931 (100%)]	Loss: 0.224275
# Epoch: 9/10. Train set: Average loss: 0.2243
# Epoch: 9/10. Validation set: Average loss: 0.2220
# Train: [0/2931 (0%)]	Loss: 0.277526
# Train: [1098/2931 (100%)]	Loss: 0.216439
# Epoch: 10/10. Train set: Average loss: 0.2166
# Epoch: 10/10. Validation set: Average loss: 0.2191
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.246583
# Epoch: 1/10. Train set: Average loss: 0.2466
# Epoch: 1/10. Validation set: Average loss: 0.5753
# Train: [0/2931 (0%)]	Loss: 0.371360
# Train: [1098/2931 (100%)]	Loss: 0.270418
# Epoch: 2/10. Train set: Average loss: 0.2707
# Epoch: 2/10. Validation set: Average loss: 0.2465
# Train: [0/2931 (0%)]	Loss: 0.310993
# Train: [1098/2931 (100%)]	Loss: 0.243945
# Epoch: 3/10. Train set: Average loss: 0.2441
# Epoch: 3/10. Validation set: Average loss: 0.2412
# Train: [0/2931 (0%)]	Loss: 0.246695
# Train: [1098/2931 (100%)]	Loss: 0.235816
# Epoch: 4/10. Train set: Average loss: 0.2358
# Epoch: 4/10. Validation set: Average loss: 0.2384
# Train: [0/2931 (0%)]	Loss: 0.240555
# Train: [1098/2931 (100%)]	Loss: 0.231172
# Epoch: 5/10. Train set: Average loss: 0.2312
# Epoch: 5/10. Validation set: Average loss: 0.2173
# Train: [0/2931 (0%)]	Loss: 0.234143
# Train: [1098/2931 (100%)]	Loss: 0.220486
# Epoch: 6/10. Train set: Average loss: 0.2205
# Epoch: 6/10. Validation set: Average loss: 0.2160
# Train: [0/2931 (0%)]	Loss: 0.288255
# Train: [1098/2931 (100%)]	Loss: 0.233459
# Epoch: 7/10. Train set: Average loss: 0.2336
# Epoch: 7/10. Validation set: Average loss: 0.2186
# Train: [0/2931 (0%)]	Loss: 0.170972
# Train: [1098/2931 (100%)]	Loss: 0.213163
# Epoch: 8/10. Train set: Average loss: 0.2130
# Epoch: 8/10. Validation set: Average loss: 0.2057
# Train: [0/2931 (0%)]	Loss: 0.224559
# Train: [1098/2931 (100%)]	Loss: 0.202649
# Epoch: 9/10. Train set: Average loss: 0.2027
# Epoch: 9/10. Validation set: Average loss: 0.1989
# Train: [0/2931 (0%)]	Loss: 0.238403
# Train: [1098/2931 (100%)]	Loss: 0.196064
# Epoch: 10/10. Train set: Average loss: 0.1962
# Epoch: 10/10. Validation set: Average loss: 0.1951
# Number features: 10
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.062496
# Train: [1098/2931 (100%)]	Loss: 0.230262
# Epoch: 1/10. Train set: Average loss: 0.2298
# Epoch: 1/10. Validation set: Average loss: 0.3190
# Train: [0/2931 (0%)]	Loss: 0.082711
# Train: [1098/2931 (100%)]	Loss: 0.258073
# Epoch: 2/10. Train set: Average loss: 0.2576
# Epoch: 2/10. Validation set: Average loss: 0.2312
# Train: [0/2931 (0%)]	Loss: 0.064643
# Train: [1098/2931 (100%)]	Loss: 0.230920
# Epoch: 3/10. Train set: Average loss: 0.2305
# Epoch: 3/10. Validation set: Average loss: 0.2299
# Train: [0/2931 (0%)]	Loss: 0.061242
# Train: [1098/2931 (100%)]	Loss: 0.228017
# Epoch: 4/10. Train set: Average loss: 0.2276
# Epoch: 4/10. Validation set: Average loss: 0.2218
# Train: [0/2931 (0%)]	Loss: 0.023707
# Train: [1098/2931 (100%)]	Loss: 0.224737
# Epoch: 5/10. Train set: Average loss: 0.2242
# Epoch: 5/10. Validation set: Average loss: 0.2210
# Train: [0/2931 (0%)]	Loss: 0.069834
# Train: [1098/2931 (100%)]	Loss: 0.239497
# Epoch: 6/10. Train set: Average loss: 0.2390
# Epoch: 6/10. Validation set: Average loss: 0.2356
# Train: [0/2931 (0%)]	Loss: 0.063357
# Train: [1098/2931 (100%)]	Loss: 0.231745
# Epoch: 7/10. Train set: Average loss: 0.2313
# Epoch: 7/10. Validation set: Average loss: 0.2225
# Train: [0/2931 (0%)]	Loss: 0.022882
# Train: [1098/2931 (100%)]	Loss: 0.245577
# Epoch: 8/10. Train set: Average loss: 0.2450
# Epoch: 8/10. Validation set: Average loss: 0.2302
# Train: [0/2931 (0%)]	Loss: 0.123005
# Train: [1098/2931 (100%)]	Loss: 0.226614
# Epoch: 9/10. Train set: Average loss: 0.2263
# Epoch: 9/10. Validation set: Average loss: 0.2119
# Train: [0/2931 (0%)]	Loss: 0.067785
# Train: [1098/2931 (100%)]	Loss: 0.220891
# Epoch: 10/10. Train set: Average loss: 0.2205
# Epoch: 10/10. Validation set: Average loss: 0.2156
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249983
# Train: [1098/2931 (100%)]	Loss: 0.287282
# Epoch: 1/10. Train set: Average loss: 0.2872
# Epoch: 1/10. Validation set: Average loss: 0.2237
# Train: [0/2931 (0%)]	Loss: 0.197502
# Train: [1098/2931 (100%)]	Loss: 0.233164
# Epoch: 2/10. Train set: Average loss: 0.2331
# Epoch: 2/10. Validation set: Average loss: 0.2214
# Train: [0/2931 (0%)]	Loss: 0.236753
# Train: [1098/2931 (100%)]	Loss: 0.253067
# Epoch: 3/10. Train set: Average loss: 0.2530
# Epoch: 3/10. Validation set: Average loss: 0.2207
# Train: [0/2931 (0%)]	Loss: 0.167467
# Train: [1098/2931 (100%)]	Loss: 0.242661
# Epoch: 4/10. Train set: Average loss: 0.2425
# Epoch: 4/10. Validation set: Average loss: 0.2318
# Train: [0/2931 (0%)]	Loss: 0.241231
# Train: [1098/2931 (100%)]	Loss: 0.237093
# Epoch: 5/10. Train set: Average loss: 0.2371
# Epoch: 5/10. Validation set: Average loss: 0.2425
# Train: [0/2931 (0%)]	Loss: 0.302403
# Train: [1098/2931 (100%)]	Loss: 0.224465
# Epoch: 6/10. Train set: Average loss: 0.2247
# Epoch: 6/10. Validation set: Average loss: 0.2237
# Train: [0/2931 (0%)]	Loss: 0.194814
# Train: [1098/2931 (100%)]	Loss: 0.250841
# Epoch: 7/10. Train set: Average loss: 0.2507
# Epoch: 7/10. Validation set: Average loss: 0.2246
# Train: [0/2931 (0%)]	Loss: 0.116162
# Train: [1098/2931 (100%)]	Loss: 0.228129
# Epoch: 8/10. Train set: Average loss: 0.2278
# Epoch: 8/10. Validation set: Average loss: 0.2202
# Train: [0/2931 (0%)]	Loss: 0.250463
# Train: [1098/2931 (100%)]	Loss: 0.222613
# Epoch: 9/10. Train set: Average loss: 0.2227
# Epoch: 9/10. Validation set: Average loss: 0.2226
# Train: [0/2931 (0%)]	Loss: 0.138881
# Train: [1098/2931 (100%)]	Loss: 0.231658
# Epoch: 10/10. Train set: Average loss: 0.2314
# Epoch: 10/10. Validation set: Average loss: 0.2207
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.258351
# Epoch: 1/10. Train set: Average loss: 0.2583
# Epoch: 1/10. Validation set: Average loss: 0.2457
# Train: [0/2931 (0%)]	Loss: 0.249791
# Train: [1098/2931 (100%)]	Loss: 0.267825
# Epoch: 2/10. Train set: Average loss: 0.2678
# Epoch: 2/10. Validation set: Average loss: 0.2345
# Train: [0/2931 (0%)]	Loss: 0.238755
# Train: [1098/2931 (100%)]	Loss: 0.238416
# Epoch: 3/10. Train set: Average loss: 0.2384
# Epoch: 3/10. Validation set: Average loss: 0.2249
# Train: [0/2931 (0%)]	Loss: 0.239933
# Train: [1098/2931 (100%)]	Loss: 0.232265
# Epoch: 4/10. Train set: Average loss: 0.2323
# Epoch: 4/10. Validation set: Average loss: 0.2790
# Train: [0/2931 (0%)]	Loss: 0.176493
# Train: [1098/2931 (100%)]	Loss: 0.277987
# Epoch: 5/10. Train set: Average loss: 0.2777
# Epoch: 5/10. Validation set: Average loss: 0.2320
# Train: [0/2931 (0%)]	Loss: 0.229342
# Train: [1098/2931 (100%)]	Loss: 0.228432
# Epoch: 6/10. Train set: Average loss: 0.2284
# Epoch: 6/10. Validation set: Average loss: 0.2286
# Train: [0/2931 (0%)]	Loss: 0.132041
# Train: [1098/2931 (100%)]	Loss: 0.226165
# Epoch: 7/10. Train set: Average loss: 0.2259
# Epoch: 7/10. Validation set: Average loss: 0.2244
# Train: [0/2931 (0%)]	Loss: 0.227364
# Train: [1098/2931 (100%)]	Loss: 0.221205
# Epoch: 8/10. Train set: Average loss: 0.2212
# Epoch: 8/10. Validation set: Average loss: 0.2363
# Train: [0/2931 (0%)]	Loss: 0.189845
# Train: [1098/2931 (100%)]	Loss: 0.219539
# Epoch: 9/10. Train set: Average loss: 0.2195
# Epoch: 9/10. Validation set: Average loss: 0.2273
# Train: [0/2931 (0%)]	Loss: 0.226113
# Train: [1098/2931 (100%)]	Loss: 0.226363
# Epoch: 10/10. Train set: Average loss: 0.2264
# Epoch: 10/10. Validation set: Average loss: 0.2258
# Number features: 12
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.312465
# Train: [1098/2931 (100%)]	Loss: 0.281880
# Epoch: 1/10. Train set: Average loss: 0.2820
# Epoch: 1/10. Validation set: Average loss: 0.1911
# Train: [0/2931 (0%)]	Loss: 0.261579
# Train: [1098/2931 (100%)]	Loss: 0.179909
# Epoch: 2/10. Train set: Average loss: 0.1801
# Epoch: 2/10. Validation set: Average loss: 0.1846
# Train: [0/2931 (0%)]	Loss: 0.267220
# Train: [1098/2931 (100%)]	Loss: 0.212730
# Epoch: 3/10. Train set: Average loss: 0.2129
# Epoch: 3/10. Validation set: Average loss: 0.2367
# Train: [0/2931 (0%)]	Loss: 0.308575
# Train: [1098/2931 (100%)]	Loss: 0.214217
# Epoch: 4/10. Train set: Average loss: 0.2145
# Epoch: 4/10. Validation set: Average loss: 0.1880
# Train: [0/2931 (0%)]	Loss: 0.245358
# Train: [1098/2931 (100%)]	Loss: 0.176602
# Epoch: 5/10. Train set: Average loss: 0.1768
# Epoch: 5/10. Validation set: Average loss: 0.1665
# Train: [0/2931 (0%)]	Loss: 0.506262
# Train: [1098/2931 (100%)]	Loss: 0.174114
# Epoch: 6/10. Train set: Average loss: 0.1750
# Epoch: 6/10. Validation set: Average loss: 0.1712
# Train: [0/2931 (0%)]	Loss: 0.204709
# Train: [1098/2931 (100%)]	Loss: 0.174313
# Epoch: 7/10. Train set: Average loss: 0.1744
# Epoch: 7/10. Validation set: Average loss: 0.1706
# Train: [0/2931 (0%)]	Loss: 0.207556
# Train: [1098/2931 (100%)]	Loss: 0.172750
# Epoch: 8/10. Train set: Average loss: 0.1728
# Epoch: 8/10. Validation set: Average loss: 0.1480
# Train: [0/2931 (0%)]	Loss: 0.185058
# Train: [1098/2931 (100%)]	Loss: 0.156516
# Epoch: 9/10. Train set: Average loss: 0.1566
# Epoch: 9/10. Validation set: Average loss: 0.1477
# Train: [0/2931 (0%)]	Loss: 0.152561
# Train: [1098/2931 (100%)]	Loss: 0.153453
# Epoch: 10/10. Train set: Average loss: 0.1535
# Epoch: 10/10. Validation set: Average loss: 0.1466
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.124992
# Train: [1098/2931 (100%)]	Loss: 0.234824
# Epoch: 1/10. Train set: Average loss: 0.2345
# Epoch: 1/10. Validation set: Average loss: 0.2171
# Train: [0/2931 (0%)]	Loss: 0.059641
# Train: [1098/2931 (100%)]	Loss: 0.229111
# Epoch: 2/10. Train set: Average loss: 0.2286
# Epoch: 2/10. Validation set: Average loss: 0.2425
# Train: [0/2931 (0%)]	Loss: 0.063195
# Train: [1098/2931 (100%)]	Loss: 0.220915
# Epoch: 3/10. Train set: Average loss: 0.2205
# Epoch: 3/10. Validation set: Average loss: 0.2137
# Train: [0/2931 (0%)]	Loss: 0.117605
# Train: [1098/2931 (100%)]	Loss: 0.211170
# Epoch: 4/10. Train set: Average loss: 0.2109
# Epoch: 4/10. Validation set: Average loss: 0.2190
# Train: [0/2931 (0%)]	Loss: 0.061791
# Train: [1098/2931 (100%)]	Loss: 0.337024
# Epoch: 5/10. Train set: Average loss: 0.3363
# Epoch: 5/10. Validation set: Average loss: 0.1897
# Train: [0/2931 (0%)]	Loss: 0.099742
# Train: [1098/2931 (100%)]	Loss: 0.191080
# Epoch: 6/10. Train set: Average loss: 0.1908
# Epoch: 6/10. Validation set: Average loss: 0.1658
# Train: [0/2931 (0%)]	Loss: 0.049492
# Train: [1098/2931 (100%)]	Loss: 0.204909
# Epoch: 7/10. Train set: Average loss: 0.2045
# Epoch: 7/10. Validation set: Average loss: 0.2446
# Train: [0/2931 (0%)]	Loss: 0.131925
# Train: [1098/2931 (100%)]	Loss: 0.220160
# Epoch: 8/10. Train set: Average loss: 0.2199
# Epoch: 8/10. Validation set: Average loss: 0.1898
# Train: [0/2931 (0%)]	Loss: 0.057317
# Train: [1098/2931 (100%)]	Loss: 0.183416
# Epoch: 9/10. Train set: Average loss: 0.1831
# Epoch: 9/10. Validation set: Average loss: 0.1786
# Train: [0/2931 (0%)]	Loss: 0.088102
# Train: [1098/2931 (100%)]	Loss: 0.175314
# Epoch: 10/10. Train set: Average loss: 0.1751
# Epoch: 10/10. Validation set: Average loss: 0.1696
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249982
# Train: [1098/2931 (100%)]	Loss: 0.233758
# Epoch: 1/10. Train set: Average loss: 0.2338
# Epoch: 1/10. Validation set: Average loss: 0.2370
# Train: [0/2931 (0%)]	Loss: 0.241019
# Train: [1098/2931 (100%)]	Loss: 0.207027
# Epoch: 2/10. Train set: Average loss: 0.2071
# Epoch: 2/10. Validation set: Average loss: 0.1790
# Train: [0/2931 (0%)]	Loss: 0.132108
# Train: [1098/2931 (100%)]	Loss: 0.194484
# Epoch: 3/10. Train set: Average loss: 0.1943
# Epoch: 3/10. Validation set: Average loss: 0.1690
# Train: [0/2931 (0%)]	Loss: 0.094579
# Train: [1098/2931 (100%)]	Loss: 0.186833
# Epoch: 4/10. Train set: Average loss: 0.1866
# Epoch: 4/10. Validation set: Average loss: 0.1689
# Train: [0/2931 (0%)]	Loss: 0.122652
# Train: [1098/2931 (100%)]	Loss: 0.167454
# Epoch: 5/10. Train set: Average loss: 0.1673
# Epoch: 5/10. Validation set: Average loss: 0.1951
# Train: [0/2931 (0%)]	Loss: 0.114213
# Train: [1098/2931 (100%)]	Loss: 0.181024
# Epoch: 6/10. Train set: Average loss: 0.1808
# Epoch: 6/10. Validation set: Average loss: 0.1656
# Train: [0/2931 (0%)]	Loss: 0.134265
# Train: [1098/2931 (100%)]	Loss: 0.158780
# Epoch: 7/10. Train set: Average loss: 0.1587
# Epoch: 7/10. Validation set: Average loss: 0.1811
# Train: [0/2931 (0%)]	Loss: 0.060677
# Train: [1098/2931 (100%)]	Loss: 0.157897
# Epoch: 8/10. Train set: Average loss: 0.1576
# Epoch: 8/10. Validation set: Average loss: 0.1583
# Train: [0/2931 (0%)]	Loss: 0.080809
# Train: [1098/2931 (100%)]	Loss: 0.144637
# Epoch: 9/10. Train set: Average loss: 0.1445
# Epoch: 9/10. Validation set: Average loss: 0.1545
# Train: [0/2931 (0%)]	Loss: 0.091447
# Train: [1098/2931 (100%)]	Loss: 0.146697
# Epoch: 10/10. Train set: Average loss: 0.1465
# Epoch: 10/10. Validation set: Average loss: 0.1552
# Number features: 14
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.312479
# Train: [1098/2931 (100%)]	Loss: 0.385645
# Epoch: 1/10. Train set: Average loss: 0.3854
# Epoch: 1/10. Validation set: Average loss: 0.2393
# Train: [0/2931 (0%)]	Loss: 0.303607
# Train: [1098/2931 (100%)]	Loss: 0.250673
# Epoch: 2/10. Train set: Average loss: 0.2508
# Epoch: 2/10. Validation set: Average loss: 0.2437
# Train: [0/2931 (0%)]	Loss: 0.310369
# Train: [1098/2931 (100%)]	Loss: 0.257396
# Epoch: 3/10. Train set: Average loss: 0.2575
# Epoch: 3/10. Validation set: Average loss: 0.2423
# Train: [0/2931 (0%)]	Loss: 0.265479
# Train: [1098/2931 (100%)]	Loss: 0.244588
# Epoch: 4/10. Train set: Average loss: 0.2446
# Epoch: 4/10. Validation set: Average loss: 0.4294
# Train: [0/2931 (0%)]	Loss: 0.231620
# Train: [1098/2931 (100%)]	Loss: 0.270458
# Epoch: 5/10. Train set: Average loss: 0.2704
# Epoch: 5/10. Validation set: Average loss: 0.2411
# Train: [0/2931 (0%)]	Loss: 0.302329
# Train: [1098/2931 (100%)]	Loss: 0.239899
# Epoch: 6/10. Train set: Average loss: 0.2401
# Epoch: 6/10. Validation set: Average loss: 0.2258
# Train: [0/2931 (0%)]	Loss: 0.279479
# Train: [1098/2931 (100%)]	Loss: 0.238070
# Epoch: 7/10. Train set: Average loss: 0.2382
# Epoch: 7/10. Validation set: Average loss: 0.2558
# Train: [0/2931 (0%)]	Loss: 0.304156
# Train: [1098/2931 (100%)]	Loss: 0.287029
# Epoch: 8/10. Train set: Average loss: 0.2871
# Epoch: 8/10. Validation set: Average loss: 0.2441
# Train: [0/2931 (0%)]	Loss: 0.306280
# Train: [1098/2931 (100%)]	Loss: 0.244311
# Epoch: 9/10. Train set: Average loss: 0.2445
# Epoch: 9/10. Validation set: Average loss: 0.2340
# Train: [0/2931 (0%)]	Loss: 0.341165
# Train: [1098/2931 (100%)]	Loss: 0.222857
# Epoch: 10/10. Train set: Average loss: 0.2232
# Epoch: 10/10. Validation set: Average loss: 0.2198
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.124992
# Train: [1098/2931 (100%)]	Loss: 0.279158
# Epoch: 1/10. Train set: Average loss: 0.2787
# Epoch: 1/10. Validation set: Average loss: 0.2467
# Train: [0/2931 (0%)]	Loss: 0.186227
# Train: [1098/2931 (100%)]	Loss: 0.251340
# Epoch: 2/10. Train set: Average loss: 0.2512
# Epoch: 2/10. Validation set: Average loss: 0.2421
# Train: [0/2931 (0%)]	Loss: 0.123132
# Train: [1098/2931 (100%)]	Loss: 0.249394
# Epoch: 3/10. Train set: Average loss: 0.2490
# Epoch: 3/10. Validation set: Average loss: 0.2265
# Train: [0/2931 (0%)]	Loss: 0.121960
# Train: [1098/2931 (100%)]	Loss: 0.231223
# Epoch: 4/10. Train set: Average loss: 0.2309
# Epoch: 4/10. Validation set: Average loss: 0.2310
# Train: [0/2931 (0%)]	Loss: 0.070569
# Train: [1098/2931 (100%)]	Loss: 0.211231
# Epoch: 5/10. Train set: Average loss: 0.2108
# Epoch: 5/10. Validation set: Average loss: 0.2049
# Train: [0/2931 (0%)]	Loss: 0.118279
# Train: [1098/2931 (100%)]	Loss: 0.250977
# Epoch: 6/10. Train set: Average loss: 0.2506
# Epoch: 6/10. Validation set: Average loss: 0.2418
# Train: [0/2931 (0%)]	Loss: 0.184016
# Train: [1098/2931 (100%)]	Loss: 0.387682
# Epoch: 7/10. Train set: Average loss: 0.3871
# Epoch: 7/10. Validation set: Average loss: 0.2441
# Train: [0/2931 (0%)]	Loss: 0.177317
# Train: [1098/2931 (100%)]	Loss: 0.248132
# Epoch: 8/10. Train set: Average loss: 0.2479
# Epoch: 8/10. Validation set: Average loss: 0.2201
# Train: [0/2931 (0%)]	Loss: 0.216892
# Train: [1098/2931 (100%)]	Loss: 0.213283
# Epoch: 9/10. Train set: Average loss: 0.2133
# Epoch: 9/10. Validation set: Average loss: 0.2120
# Train: [0/2931 (0%)]	Loss: 0.117507
# Train: [1098/2931 (100%)]	Loss: 0.206067
# Epoch: 10/10. Train set: Average loss: 0.2058
# Epoch: 10/10. Validation set: Average loss: 0.2105
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.062496
# Train: [1098/2931 (100%)]	Loss: 3.807356
# Epoch: 1/10. Train set: Average loss: 3.7972
# Epoch: 1/10. Validation set: Average loss: 0.2340
# Train: [0/2931 (0%)]	Loss: 0.001443
# Train: [1098/2931 (100%)]	Loss: 0.270267
# Epoch: 2/10. Train set: Average loss: 0.2695
# Epoch: 2/10. Validation set: Average loss: 0.2302
# Train: [0/2931 (0%)]	Loss: 0.060549
# Train: [1098/2931 (100%)]	Loss: 0.245280
# Epoch: 3/10. Train set: Average loss: 0.2448
# Epoch: 3/10. Validation set: Average loss: 0.2274
# Train: [0/2931 (0%)]	Loss: 0.024034
# Train: [1098/2931 (100%)]	Loss: 0.218844
# Epoch: 4/10. Train set: Average loss: 0.2183
# Epoch: 4/10. Validation set: Average loss: 0.2244
# Train: [0/2931 (0%)]	Loss: 0.061934
# Train: [1098/2931 (100%)]	Loss: 0.241409
# Epoch: 5/10. Train set: Average loss: 0.2409
# Epoch: 5/10. Validation set: Average loss: 0.2276
# Train: [0/2931 (0%)]	Loss: 0.062900
# Train: [1098/2931 (100%)]	Loss: 0.217302
# Epoch: 6/10. Train set: Average loss: 0.2169
# Epoch: 6/10. Validation set: Average loss: 0.2196
# Train: [0/2931 (0%)]	Loss: 0.059773
# Train: [1098/2931 (100%)]	Loss: 0.216613
# Epoch: 7/10. Train set: Average loss: 0.2162
# Epoch: 7/10. Validation set: Average loss: 0.2196
# Train: [0/2931 (0%)]	Loss: 0.002796
# Train: [1098/2931 (100%)]	Loss: 0.212122
# Epoch: 8/10. Train set: Average loss: 0.2116
# Epoch: 8/10. Validation set: Average loss: 0.2112
# Train: [0/2931 (0%)]	Loss: 0.008498
# Train: [1098/2931 (100%)]	Loss: 0.218965
# Epoch: 9/10. Train set: Average loss: 0.2184
# Epoch: 9/10. Validation set: Average loss: 0.2105
# Train: [0/2931 (0%)]	Loss: 0.053827
# Train: [1098/2931 (100%)]	Loss: 0.210821
# Epoch: 10/10. Train set: Average loss: 0.2104
# Epoch: 10/10. Validation set: Average loss: 0.2076
# Number features: 16
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.062495
# Train: [1098/2931 (100%)]	Loss: 0.239940
# Epoch: 1/10. Train set: Average loss: 0.2395
# Epoch: 1/10. Validation set: Average loss: 0.2194
# Train: [0/2931 (0%)]	Loss: 0.129828
# Train: [1098/2931 (100%)]	Loss: 0.192360
# Epoch: 2/10. Train set: Average loss: 0.1922
# Epoch: 2/10. Validation set: Average loss: 0.1876
# Train: [0/2931 (0%)]	Loss: 0.280713
# Train: [1098/2931 (100%)]	Loss: 0.180968
# Epoch: 3/10. Train set: Average loss: 0.1812
# Epoch: 3/10. Validation set: Average loss: 0.1664
# Train: [0/2931 (0%)]	Loss: 0.049281
# Train: [1098/2931 (100%)]	Loss: 0.169332
# Epoch: 4/10. Train set: Average loss: 0.1690
# Epoch: 4/10. Validation set: Average loss: 0.1615
# Train: [0/2931 (0%)]	Loss: 0.121738
# Train: [1098/2931 (100%)]	Loss: 0.162430
# Epoch: 5/10. Train set: Average loss: 0.1623
# Epoch: 5/10. Validation set: Average loss: 0.1723
# Train: [0/2931 (0%)]	Loss: 0.167785
# Train: [1098/2931 (100%)]	Loss: 0.169614
# Epoch: 6/10. Train set: Average loss: 0.1696
# Epoch: 6/10. Validation set: Average loss: 0.1739
# Train: [0/2931 (0%)]	Loss: 0.104721
# Train: [1098/2931 (100%)]	Loss: 0.161737
# Epoch: 7/10. Train set: Average loss: 0.1616
# Epoch: 7/10. Validation set: Average loss: 0.1564
# Train: [0/2931 (0%)]	Loss: 0.177528
# Train: [1098/2931 (100%)]	Loss: 0.170129
# Epoch: 8/10. Train set: Average loss: 0.1701
# Epoch: 8/10. Validation set: Average loss: 0.1691
# Train: [0/2931 (0%)]	Loss: 0.067052
# Train: [1098/2931 (100%)]	Loss: 0.168667
# Epoch: 9/10. Train set: Average loss: 0.1684
# Epoch: 9/10. Validation set: Average loss: 0.1627
# Train: [0/2931 (0%)]	Loss: 0.146465
# Train: [1098/2931 (100%)]	Loss: 0.164347
# Epoch: 10/10. Train set: Average loss: 0.1643
# Epoch: 10/10. Validation set: Average loss: 0.1593
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.312428
# Train: [1098/2931 (100%)]	Loss: 0.243378
# Epoch: 1/10. Train set: Average loss: 0.2436
# Epoch: 1/10. Validation set: Average loss: 0.1983
# Train: [0/2931 (0%)]	Loss: 0.249553
# Train: [1098/2931 (100%)]	Loss: 0.208652
# Epoch: 2/10. Train set: Average loss: 0.2088
# Epoch: 2/10. Validation set: Average loss: 0.2034
# Train: [0/2931 (0%)]	Loss: 0.240288
# Train: [1098/2931 (100%)]	Loss: 0.180109
# Epoch: 3/10. Train set: Average loss: 0.1803
# Epoch: 3/10. Validation set: Average loss: 0.2094
# Train: [0/2931 (0%)]	Loss: 0.191792
# Train: [1098/2931 (100%)]	Loss: 0.181174
# Epoch: 4/10. Train set: Average loss: 0.1812
# Epoch: 4/10. Validation set: Average loss: 0.1642
# Train: [0/2931 (0%)]	Loss: 0.214783
# Train: [1098/2931 (100%)]	Loss: 0.169724
# Epoch: 5/10. Train set: Average loss: 0.1698
# Epoch: 5/10. Validation set: Average loss: 0.1596
# Train: [0/2931 (0%)]	Loss: 0.251754
# Train: [1098/2931 (100%)]	Loss: 0.158421
# Epoch: 6/10. Train set: Average loss: 0.1587
# Epoch: 6/10. Validation set: Average loss: 0.1547
# Train: [0/2931 (0%)]	Loss: 0.121348
# Train: [1098/2931 (100%)]	Loss: 0.164734
# Epoch: 7/10. Train set: Average loss: 0.1646
# Epoch: 7/10. Validation set: Average loss: 0.1537
# Train: [0/2931 (0%)]	Loss: 0.222016
# Train: [1098/2931 (100%)]	Loss: 0.158254
# Epoch: 8/10. Train set: Average loss: 0.1584
# Epoch: 8/10. Validation set: Average loss: 0.1633
# Train: [0/2931 (0%)]	Loss: 0.249040
# Train: [1098/2931 (100%)]	Loss: 0.164470
# Epoch: 9/10. Train set: Average loss: 0.1647
# Epoch: 9/10. Validation set: Average loss: 0.1576
# Train: [0/2931 (0%)]	Loss: 0.149778
# Train: [1098/2931 (100%)]	Loss: 0.163934
# Epoch: 10/10. Train set: Average loss: 0.1639
# Epoch: 10/10. Validation set: Average loss: 0.1549
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.312290
# Train: [1098/2931 (100%)]	Loss: 0.223266
# Epoch: 1/10. Train set: Average loss: 0.2235
# Epoch: 1/10. Validation set: Average loss: 0.2047
# Train: [0/2931 (0%)]	Loss: 0.184566
# Train: [1098/2931 (100%)]	Loss: 0.273098
# Epoch: 2/10. Train set: Average loss: 0.2729
# Epoch: 2/10. Validation set: Average loss: 0.1863
# Train: [0/2931 (0%)]	Loss: 0.179173
# Train: [1098/2931 (100%)]	Loss: 0.188474
# Epoch: 3/10. Train set: Average loss: 0.1884
# Epoch: 3/10. Validation set: Average loss: 0.1904
# Train: [0/2931 (0%)]	Loss: 0.156096
# Train: [1098/2931 (100%)]	Loss: 0.171121
# Epoch: 4/10. Train set: Average loss: 0.1711
# Epoch: 4/10. Validation set: Average loss: 0.1594
# Train: [0/2931 (0%)]	Loss: 0.128985
# Train: [1098/2931 (100%)]	Loss: 0.162305
# Epoch: 5/10. Train set: Average loss: 0.1622
# Epoch: 5/10. Validation set: Average loss: 0.1647
# Train: [0/2931 (0%)]	Loss: 0.176778
# Train: [1098/2931 (100%)]	Loss: 0.163836
# Epoch: 6/10. Train set: Average loss: 0.1639
# Epoch: 6/10. Validation set: Average loss: 0.1629
# Train: [0/2931 (0%)]	Loss: 0.098718
# Train: [1098/2931 (100%)]	Loss: 0.177264
# Epoch: 7/10. Train set: Average loss: 0.1771
# Epoch: 7/10. Validation set: Average loss: 0.1739
# Train: [0/2931 (0%)]	Loss: 0.204547
# Train: [1098/2931 (100%)]	Loss: 0.165316
# Epoch: 8/10. Train set: Average loss: 0.1654
# Epoch: 8/10. Validation set: Average loss: 0.1555
# Train: [0/2931 (0%)]	Loss: 0.126404
# Train: [1098/2931 (100%)]	Loss: 0.159785
# Epoch: 9/10. Train set: Average loss: 0.1597
# Epoch: 9/10. Validation set: Average loss: 0.1526
# Train: [0/2931 (0%)]	Loss: 0.227970
# Train: [1098/2931 (100%)]	Loss: 0.155635
# Epoch: 10/10. Train set: Average loss: 0.1558
# Epoch: 10/10. Validation set: Average loss: 0.1522
# Number features: 18
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.249975
# Train: [1098/2931 (100%)]	Loss: 0.227686
# Epoch: 1/10. Train set: Average loss: 0.2277
# Epoch: 1/10. Validation set: Average loss: 0.2249
# Train: [0/2931 (0%)]	Loss: 0.200627
# Train: [1098/2931 (100%)]	Loss: 0.211368
# Epoch: 2/10. Train set: Average loss: 0.2113
# Epoch: 2/10. Validation set: Average loss: 0.2389
# Train: [0/2931 (0%)]	Loss: 0.181240
# Train: [1098/2931 (100%)]	Loss: 0.202389
# Epoch: 3/10. Train set: Average loss: 0.2023
# Epoch: 3/10. Validation set: Average loss: 0.1891
# Train: [0/2931 (0%)]	Loss: 0.184837
# Train: [1098/2931 (100%)]	Loss: 0.181663
# Epoch: 4/10. Train set: Average loss: 0.1817
# Epoch: 4/10. Validation set: Average loss: 0.1831
# Train: [0/2931 (0%)]	Loss: 0.120247
# Train: [1098/2931 (100%)]	Loss: 0.162937
# Epoch: 5/10. Train set: Average loss: 0.1628
# Epoch: 5/10. Validation set: Average loss: 0.1683
# Train: [0/2931 (0%)]	Loss: 0.197848
# Train: [1098/2931 (100%)]	Loss: 0.163048
# Epoch: 6/10. Train set: Average loss: 0.1631
# Epoch: 6/10. Validation set: Average loss: 0.1623
# Train: [0/2931 (0%)]	Loss: 0.123583
# Train: [1098/2931 (100%)]	Loss: 0.154724
# Epoch: 7/10. Train set: Average loss: 0.1546
# Epoch: 7/10. Validation set: Average loss: 0.1938
# Train: [0/2931 (0%)]	Loss: 0.206060
# Train: [1098/2931 (100%)]	Loss: 0.156494
# Epoch: 8/10. Train set: Average loss: 0.1566
# Epoch: 8/10. Validation set: Average loss: 0.1598
# Train: [0/2931 (0%)]	Loss: 0.092758
# Train: [1098/2931 (100%)]	Loss: 0.155414
# Epoch: 9/10. Train set: Average loss: 0.1552
# Epoch: 9/10. Validation set: Average loss: 0.1534
# Train: [0/2931 (0%)]	Loss: 0.067686
# Train: [1098/2931 (100%)]	Loss: 0.153517
# Epoch: 10/10. Train set: Average loss: 0.1533
# Epoch: 10/10. Validation set: Average loss: 0.1514
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.124982
# Train: [1098/2931 (100%)]	Loss: 0.217335
# Epoch: 1/10. Train set: Average loss: 0.2171
# Epoch: 1/10. Validation set: Average loss: 0.2082
# Train: [0/2931 (0%)]	Loss: 0.221148
# Train: [1098/2931 (100%)]	Loss: 0.196807
# Epoch: 2/10. Train set: Average loss: 0.1969
# Epoch: 2/10. Validation set: Average loss: 0.2410
# Train: [0/2931 (0%)]	Loss: 0.180818
# Train: [1098/2931 (100%)]	Loss: 0.219976
# Epoch: 3/10. Train set: Average loss: 0.2199
# Epoch: 3/10. Validation set: Average loss: 0.2124
# Train: [0/2931 (0%)]	Loss: 0.202528
# Train: [1098/2931 (100%)]	Loss: 0.185018
# Epoch: 4/10. Train set: Average loss: 0.1851
# Epoch: 4/10. Validation set: Average loss: 0.2048
# Train: [0/2931 (0%)]	Loss: 0.154185
# Train: [1098/2931 (100%)]	Loss: 0.226176
# Epoch: 5/10. Train set: Average loss: 0.2260
# Epoch: 5/10. Validation set: Average loss: 0.2439
# Train: [0/2931 (0%)]	Loss: 0.180709
# Train: [1098/2931 (100%)]	Loss: 0.183470
# Epoch: 6/10. Train set: Average loss: 0.1835
# Epoch: 6/10. Validation set: Average loss: 0.2034
# Train: [0/2931 (0%)]	Loss: 0.069002
# Train: [1098/2931 (100%)]	Loss: 0.169108
# Epoch: 7/10. Train set: Average loss: 0.1688
# Epoch: 7/10. Validation set: Average loss: 0.1617
# Train: [0/2931 (0%)]	Loss: 0.207211
# Train: [1098/2931 (100%)]	Loss: 0.167558
# Epoch: 8/10. Train set: Average loss: 0.1677
# Epoch: 8/10. Validation set: Average loss: 0.1678
# Train: [0/2931 (0%)]	Loss: 0.112975
# Train: [1098/2931 (100%)]	Loss: 0.159951
# Epoch: 9/10. Train set: Average loss: 0.1598
# Epoch: 9/10. Validation set: Average loss: 0.1597
# Train: [0/2931 (0%)]	Loss: 0.116588
# Train: [1098/2931 (100%)]	Loss: 0.154362
# Epoch: 10/10. Train set: Average loss: 0.1543
# Epoch: 10/10. Validation set: Average loss: 0.1557
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.124980
# Train: [1098/2931 (100%)]	Loss: 0.216755
# Epoch: 1/10. Train set: Average loss: 0.2165
# Epoch: 1/10. Validation set: Average loss: 0.2238
# Train: [0/2931 (0%)]	Loss: 0.119128
# Train: [1098/2931 (100%)]	Loss: 0.200752
# Epoch: 2/10. Train set: Average loss: 0.2005
# Epoch: 2/10. Validation set: Average loss: 0.2188
# Train: [0/2931 (0%)]	Loss: 0.112112
# Train: [1098/2931 (100%)]	Loss: 0.180365
# Epoch: 3/10. Train set: Average loss: 0.1802
# Epoch: 3/10. Validation set: Average loss: 0.1940
# Train: [0/2931 (0%)]	Loss: 0.144013
# Train: [1098/2931 (100%)]	Loss: 0.160093
# Epoch: 4/10. Train set: Average loss: 0.1600
# Epoch: 4/10. Validation set: Average loss: 0.1611
# Train: [0/2931 (0%)]	Loss: 0.158617
# Train: [1098/2931 (100%)]	Loss: 0.168636
# Epoch: 5/10. Train set: Average loss: 0.1686
# Epoch: 5/10. Validation set: Average loss: 0.1817
# Train: [0/2931 (0%)]	Loss: 0.199870
# Train: [1098/2931 (100%)]	Loss: 0.161867
# Epoch: 6/10. Train set: Average loss: 0.1620
# Epoch: 6/10. Validation set: Average loss: 0.1549
# Train: [0/2931 (0%)]	Loss: 0.110770
# Train: [1098/2931 (100%)]	Loss: 0.169057
# Epoch: 7/10. Train set: Average loss: 0.1689
# Epoch: 7/10. Validation set: Average loss: 0.1793
# Train: [0/2931 (0%)]	Loss: 0.144974
# Train: [1098/2931 (100%)]	Loss: 0.162398
# Epoch: 8/10. Train set: Average loss: 0.1624
# Epoch: 8/10. Validation set: Average loss: 0.1597
# Train: [0/2931 (0%)]	Loss: 0.100120
# Train: [1098/2931 (100%)]	Loss: 0.162241
# Epoch: 9/10. Train set: Average loss: 0.1621
# Epoch: 9/10. Validation set: Average loss: 0.1548
# Train: [0/2931 (0%)]	Loss: 0.173621
# Train: [1098/2931 (100%)]	Loss: 0.158500
# Epoch: 10/10. Train set: Average loss: 0.1585
# Epoch: 10/10. Validation set: Average loss: 0.1527
# Number features: 19
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187482
# Train: [1098/2931 (100%)]	Loss: 0.241545
# Epoch: 1/10. Train set: Average loss: 0.2414
# Epoch: 1/10. Validation set: Average loss: 0.2291
# Train: [0/2931 (0%)]	Loss: 0.236303
# Train: [1098/2931 (100%)]	Loss: 0.235614
# Epoch: 2/10. Train set: Average loss: 0.2356
# Epoch: 2/10. Validation set: Average loss: 0.2351
# Train: [0/2931 (0%)]	Loss: 0.266340
# Train: [1098/2931 (100%)]	Loss: 0.223268
# Epoch: 3/10. Train set: Average loss: 0.2234
# Epoch: 3/10. Validation set: Average loss: 0.2178
# Train: [0/2931 (0%)]	Loss: 0.203321
# Train: [1098/2931 (100%)]	Loss: 0.218266
# Epoch: 4/10. Train set: Average loss: 0.2182
# Epoch: 4/10. Validation set: Average loss: 0.2194
# Train: [0/2931 (0%)]	Loss: 0.158111
# Train: [1098/2931 (100%)]	Loss: 0.205532
# Epoch: 5/10. Train set: Average loss: 0.2054
# Epoch: 5/10. Validation set: Average loss: 0.1668
# Train: [0/2931 (0%)]	Loss: 0.081222
# Train: [1098/2931 (100%)]	Loss: 0.195160
# Epoch: 6/10. Train set: Average loss: 0.1948
# Epoch: 6/10. Validation set: Average loss: 0.1845
# Train: [0/2931 (0%)]	Loss: 0.162691
# Train: [1098/2931 (100%)]	Loss: 0.190998
# Epoch: 7/10. Train set: Average loss: 0.1909
# Epoch: 7/10. Validation set: Average loss: 0.1719
# Train: [0/2931 (0%)]	Loss: 0.192524
# Train: [1098/2931 (100%)]	Loss: 0.183239
# Epoch: 8/10. Train set: Average loss: 0.1833
# Epoch: 8/10. Validation set: Average loss: 0.1467
# Train: [0/2931 (0%)]	Loss: 0.112287
# Train: [1098/2931 (100%)]	Loss: 0.168228
# Epoch: 9/10. Train set: Average loss: 0.1681
# Epoch: 9/10. Validation set: Average loss: 0.1489
# Train: [0/2931 (0%)]	Loss: 0.168222
# Train: [1098/2931 (100%)]	Loss: 0.161502
# Epoch: 10/10. Train set: Average loss: 0.1615
# Epoch: 10/10. Validation set: Average loss: 0.1457
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.312479
# Train: [1098/2931 (100%)]	Loss: 0.244176
# Epoch: 1/10. Train set: Average loss: 0.2444
# Epoch: 1/10. Validation set: Average loss: 0.2200
# Train: [0/2931 (0%)]	Loss: 0.307527
# Train: [1098/2931 (100%)]	Loss: 0.229056
# Epoch: 2/10. Train set: Average loss: 0.2293
# Epoch: 2/10. Validation set: Average loss: 0.2062
# Train: [0/2931 (0%)]	Loss: 0.278527
# Train: [1098/2931 (100%)]	Loss: 0.221792
# Epoch: 3/10. Train set: Average loss: 0.2219
# Epoch: 3/10. Validation set: Average loss: 0.1810
# Train: [0/2931 (0%)]	Loss: 0.148294
# Train: [1098/2931 (100%)]	Loss: 0.208591
# Epoch: 4/10. Train set: Average loss: 0.2084
# Epoch: 4/10. Validation set: Average loss: 0.1692
# Train: [0/2931 (0%)]	Loss: 0.176284
# Train: [1098/2931 (100%)]	Loss: 0.188340
# Epoch: 5/10. Train set: Average loss: 0.1883
# Epoch: 5/10. Validation set: Average loss: 0.1672
# Train: [0/2931 (0%)]	Loss: 0.094778
# Train: [1098/2931 (100%)]	Loss: 0.201015
# Epoch: 6/10. Train set: Average loss: 0.2007
# Epoch: 6/10. Validation set: Average loss: 0.1984
# Train: [0/2931 (0%)]	Loss: 0.227677
# Train: [1098/2931 (100%)]	Loss: 0.194560
# Epoch: 7/10. Train set: Average loss: 0.1947
# Epoch: 7/10. Validation set: Average loss: 0.1628
# Train: [0/2931 (0%)]	Loss: 0.136933
# Train: [1098/2931 (100%)]	Loss: 0.180817
# Epoch: 8/10. Train set: Average loss: 0.1807
# Epoch: 8/10. Validation set: Average loss: 0.1582
# Train: [0/2931 (0%)]	Loss: 0.436211
# Train: [1098/2931 (100%)]	Loss: 0.165138
# Epoch: 9/10. Train set: Average loss: 0.1659
# Epoch: 9/10. Validation set: Average loss: 0.1490
# Train: [0/2931 (0%)]	Loss: 0.227274
# Train: [1098/2931 (100%)]	Loss: 0.159646
# Epoch: 10/10. Train set: Average loss: 0.1598
# Epoch: 10/10. Validation set: Average loss: 0.1473
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249967
# Train: [1098/2931 (100%)]	Loss: 0.247730
# Epoch: 1/10. Train set: Average loss: 0.2477
# Epoch: 1/10. Validation set: Average loss: 0.2381
# Train: [0/2931 (0%)]	Loss: 0.242173
# Train: [1098/2931 (100%)]	Loss: 0.224306
# Epoch: 2/10. Train set: Average loss: 0.2244
# Epoch: 2/10. Validation set: Average loss: 0.2143
# Train: [0/2931 (0%)]	Loss: 0.195863
# Train: [1098/2931 (100%)]	Loss: 0.214587
# Epoch: 3/10. Train set: Average loss: 0.2145
# Epoch: 3/10. Validation set: Average loss: 0.2079
# Train: [0/2931 (0%)]	Loss: 0.195808
# Train: [1098/2931 (100%)]	Loss: 0.216116
# Epoch: 4/10. Train set: Average loss: 0.2161
# Epoch: 4/10. Validation set: Average loss: 0.1891
# Train: [0/2931 (0%)]	Loss: 0.171735
# Train: [1098/2931 (100%)]	Loss: 0.202720
# Epoch: 5/10. Train set: Average loss: 0.2026
# Epoch: 5/10. Validation set: Average loss: 0.1970
# Train: [0/2931 (0%)]	Loss: 0.206897
# Train: [1098/2931 (100%)]	Loss: 0.207272
# Epoch: 6/10. Train set: Average loss: 0.2073
# Epoch: 6/10. Validation set: Average loss: 0.1889
# Train: [0/2931 (0%)]	Loss: 0.196453
# Train: [1098/2931 (100%)]	Loss: 0.200966
# Epoch: 7/10. Train set: Average loss: 0.2010
# Epoch: 7/10. Validation set: Average loss: 0.1697
# Train: [0/2931 (0%)]	Loss: 0.099677
# Train: [1098/2931 (100%)]	Loss: 0.179358
# Epoch: 8/10. Train set: Average loss: 0.1791
# Epoch: 8/10. Validation set: Average loss: 0.1634
# Train: [0/2931 (0%)]	Loss: 0.170652
# Train: [1098/2931 (100%)]	Loss: 0.168289
# Epoch: 9/10. Train set: Average loss: 0.1683
# Epoch: 9/10. Validation set: Average loss: 0.1537
# Train: [0/2931 (0%)]	Loss: 0.225308
# Train: [1098/2931 (100%)]	Loss: 0.164076
# Epoch: 10/10. Train set: Average loss: 0.1642
# Epoch: 10/10. Validation set: Average loss: 0.1492
# Number features: 21
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.312220
# Train: [1098/2931 (100%)]	Loss: 0.163904
# Epoch: 1/10. Train set: Average loss: 0.1643
# Epoch: 1/10. Validation set: Average loss: 0.1610
# Train: [0/2931 (0%)]	Loss: 0.188132
# Train: [1098/2931 (100%)]	Loss: 0.148597
# Epoch: 2/10. Train set: Average loss: 0.1487
# Epoch: 2/10. Validation set: Average loss: 0.1662
# Train: [0/2931 (0%)]	Loss: 0.106990
# Train: [1098/2931 (100%)]	Loss: 0.152900
# Epoch: 3/10. Train set: Average loss: 0.1528
# Epoch: 3/10. Validation set: Average loss: 0.1672
# Train: [0/2931 (0%)]	Loss: 0.136632
# Train: [1098/2931 (100%)]	Loss: 0.148285
# Epoch: 4/10. Train set: Average loss: 0.1483
# Epoch: 4/10. Validation set: Average loss: 0.5824
# Train: [0/2931 (0%)]	Loss: 0.117733
# Train: [1098/2931 (100%)]	Loss: 0.144895
# Epoch: 5/10. Train set: Average loss: 0.1448
# Epoch: 5/10. Validation set: Average loss: 0.1416
# Train: [0/2931 (0%)]	Loss: 0.143477
# Train: [1098/2931 (100%)]	Loss: 0.145351
# Epoch: 6/10. Train set: Average loss: 0.1453
# Epoch: 6/10. Validation set: Average loss: 0.1501
# Train: [0/2931 (0%)]	Loss: 0.158101
# Train: [1098/2931 (100%)]	Loss: 0.144650
# Epoch: 7/10. Train set: Average loss: 0.1447
# Epoch: 7/10. Validation set: Average loss: 0.1467
# Train: [0/2931 (0%)]	Loss: 0.132380
# Train: [1098/2931 (100%)]	Loss: 0.144255
# Epoch: 8/10. Train set: Average loss: 0.1442
# Epoch: 8/10. Validation set: Average loss: 0.1423
# Train: [0/2931 (0%)]	Loss: 0.119857
# Train: [1098/2931 (100%)]	Loss: 0.131378
# Epoch: 9/10. Train set: Average loss: 0.1313
# Epoch: 9/10. Validation set: Average loss: 0.1416
# Train: [0/2931 (0%)]	Loss: 0.072028
# Train: [1098/2931 (100%)]	Loss: 0.137343
# Epoch: 10/10. Train set: Average loss: 0.1372
# Epoch: 10/10. Validation set: Average loss: 0.1406
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.311676
# Train: [1098/2931 (100%)]	Loss: 0.173934
# Epoch: 1/10. Train set: Average loss: 0.1743
# Epoch: 1/10. Validation set: Average loss: 0.1445
# Train: [0/2931 (0%)]	Loss: 0.119648
# Train: [1098/2931 (100%)]	Loss: 0.159283
# Epoch: 2/10. Train set: Average loss: 0.1592
# Epoch: 2/10. Validation set: Average loss: 0.1838
# Train: [0/2931 (0%)]	Loss: 0.072058
# Train: [1098/2931 (100%)]	Loss: 0.143109
# Epoch: 3/10. Train set: Average loss: 0.1429
# Epoch: 3/10. Validation set: Average loss: 0.1504
# Train: [0/2931 (0%)]	Loss: 0.172468
# Train: [1098/2931 (100%)]	Loss: 0.144286
# Epoch: 4/10. Train set: Average loss: 0.1444
# Epoch: 4/10. Validation set: Average loss: 0.1431
# Train: [0/2931 (0%)]	Loss: 0.139374
# Train: [1098/2931 (100%)]	Loss: 0.137231
# Epoch: 5/10. Train set: Average loss: 0.1372
# Epoch: 5/10. Validation set: Average loss: 0.1464
# Train: [0/2931 (0%)]	Loss: 0.225694
# Train: [1098/2931 (100%)]	Loss: 0.139429
# Epoch: 6/10. Train set: Average loss: 0.1397
# Epoch: 6/10. Validation set: Average loss: 0.1594
# Train: [0/2931 (0%)]	Loss: 0.171651
# Train: [1098/2931 (100%)]	Loss: 0.138498
# Epoch: 7/10. Train set: Average loss: 0.1386
# Epoch: 7/10. Validation set: Average loss: 0.1470
# Train: [0/2931 (0%)]	Loss: 0.135869
# Train: [1098/2931 (100%)]	Loss: 0.139793
# Epoch: 8/10. Train set: Average loss: 0.1398
# Epoch: 8/10. Validation set: Average loss: 0.1505
# Train: [0/2931 (0%)]	Loss: 0.148958
# Train: [1098/2931 (100%)]	Loss: 0.131685
# Epoch: 9/10. Train set: Average loss: 0.1317
# Epoch: 9/10. Validation set: Average loss: 0.1397
# Train: [0/2931 (0%)]	Loss: 0.244837
# Train: [1098/2931 (100%)]	Loss: 0.133581
# Epoch: 10/10. Train set: Average loss: 0.1339
# Epoch: 10/10. Validation set: Average loss: 0.1392
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.187472
