# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("..")

import datetime
import pathlib

from collections import OrderedDict 

import numpy as np
import pandas as pd

# %%
# Pytorch
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable

# Custom
from dutils import Experiment
from trainer import fit
import visualization as vis
from tcga_datasets import SiameseDataset

# Models
from tcga_networks import EmbeddingNet, SiameseNet
from losses import ContrastiveLoss

# Metrics
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score as ANMI

# %%
def getTCGA(disease):
    path = "/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP/TCGA/TCGA_{}_counts.tsv.gz"
    files = [path.format(d) for d in disease]
    return files


def readGCP(files, biotype='protein_coding', mean=True):
    """
    Paths to count matrices.
    """
    data_dict = {}
    for f in files:
        key = os.path.basename(f).split("_")[1]
        data = pd.read_csv(f, sep='\t', index_col=0)
        # transcript metadata
        meta = pd.DataFrame([row[:-1] for row in data.index.str.split("|")],
                            columns=['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'GENE', 'BP', 'BIOTYPE'])
        meta = pd.MultiIndex.from_frame(meta)
        data.index = meta
        # subset transcripts
        data = data.xs(key=biotype, level='BIOTYPE')
        data = data.droplevel(['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'BP'])
        # average gene expression of splice variants
        data = data.T
        if mean:
            data = data.groupby(by=data.columns, axis=1).mean()
        data_dict[key] = data
    return data_dict


def uq_norm(df, q=0.75):
    """
    Upper quartile normalization of GEX for samples.
    """
    quantiles = df.quantile(q=q, axis=1)
    norm = df.divide(quantiles, axis=0)
    return norm


def process_TCGA(disease=['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']):
    base="/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP"
    # get files
    tcga_files = getTCGA(disease)
    # read meta/data
    tcga_meta = pd.read_csv(os.path.join(base, "TCGA/TCGA_GDC_ID_MAP.tsv"), sep="\t")
    tcga_raw = readGCP(tcga_files, mean=True)
    # combine samples
    tcga_raw = pd.concat(tcga_raw.values())
    # Upper quartile normalization
    tcga_raw = uq_norm(tcga_raw)
    # log norm
    tcga = tcga_raw.transform(np.log1p)
    return tcga, tcga_meta

# %%
def generate_fsets(data, n_features, steps=5):
    r = np.linspace(start=1, stop=n_features, num=steps, dtype='int')
    idx = [np.random.randint(low=1, high=data.shape[1], size=i) for i in r]
    return idx

# %%
def feature_training(train_data, train_labels, test_data, test_labels, feature_idx, embedding, exp_dir, cuda=True):
    # Meta data
    meta_data = {"n_features":[],
                 "model":[],
                 "ANMI":[]}
    # Params
    batch_size = 8
    kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {'num_workers': 10}
    
    # Feature Index
    for batch, feat in enumerate(feature_idx):
        print("Number features: {}\n".format(len(feat)))
        exp_data = {'feature_idx':feat}
        # Define data
        siamese_train_dataset = SiameseDataset(data=train_data.iloc[:,feat],
                                           labels=train_labels,
                                           train=True)
        siamese_test_dataset = SiameseDataset(data=test_data.iloc[:,feat],
                                          labels=test_labels,
                                          train=False)
        # Loaders
        siamese_train_loader = torch.utils.data.DataLoader(siamese_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
        siamese_test_loader = torch.utils.data.DataLoader(siamese_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)
        # Instantiate model
        n_samples, n_features = siamese_train_dataset.train_data.shape
        for i in range(3):
            nmodel = 'model_{}'.format(i)
            print("\t{}".format(nmodel))
            embedding_net = EmbeddingNet(n_features, embedding)
            model = SiameseNet(embedding_net)
            if cuda:
                model.cuda()
            # Parameters
            margin = 1.
            loss_fn = ContrastiveLoss(margin)
            lr = 1e-3
            optimizer = optim.Adam(model.parameters(), lr=lr)
            scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
            n_epochs = 10
            log_interval = round(len(siamese_train_dataset)/1/batch_size)
            # Train
            train_loss, val_loss = fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, 
                                       n_epochs, cuda, log_interval)
            # Test Embeddings
            val_embeddings_baseline, val_labels_baseline = vis.extract_embeddings(siamese_test_dataset.test_data, siamese_test_dataset.labels, model)
            # Evaluation
            n_clusters = len(np.unique(test_labels))
            kmeans = KMeans(n_clusters=n_clusters)
            siamese_clusters = kmeans.fit_predict(val_embeddings_baseline)
            anmi = ANMI(siamese_clusters, val_labels_baseline)
            # Store
            meta_data['n_features'].append(len(feat))
            meta_data['model'].append(nmodel)
            meta_data['ANMI'].append(anmi)
            exp_data[nmodel] = {'data': (val_embeddings_baseline, val_labels_baseline),
                                'loss': (train_loss, val_loss),
                                'ANMI': anmi}
        pd.to_pickle(exp_data, os.path.join(exp_dir, "model_{}.pkl".format(len(feat))))
    pd.to_pickle(meta_data, os.path.join(exp_dir, "model_meta_data.pkl"))

# %%
def main(disease, sample_type, **kwargs):
    # GPUs
    os.environ["CUDA_VISIBLE_DEVICES"] = kwargs['device']
    cuda = torch.cuda.is_available()
    print("Cuda is available: {}".format(cuda))
    
    # Read / write / process
    tcga, tcga_meta = process_TCGA(disease)
    # Feature design
    feature_idx = generate_fsets(tcga, n_features=kwargs['n_features'], steps=kwargs['steps'])
    # Experiment design
    hierarchy = OrderedDict({'Disease':disease,
                             'Sample Type':sample_type})
    # Define experiment
    exp = Experiment(meta_data=tcga_meta,
                     hierarchy=hierarchy,
                     index='CGHubAnalysisID',
                     cases='Case ID',
                     min_samples=20)
    # Train / Test split
    exp.train_test_split(cases='Case ID')
    # Return data 
    train_data, train_labels = exp.get_data(tcga, subset="train", dtype=np.float32)
    test_data, test_labels = exp.get_data(tcga, subset="test", dtype=np.float32)
    
    # Path *fix*
    dtime = datetime.datetime.today().strftime("%Y.%m.%d_%H:%M")
    exp_dir = "/srv/nas/mk2/projects/pan-cancer/experiments/{}_{}_{}_{}-{}".format(dtime, 
                                                                                len(exp.labels_dict),
                                                                                kwars['embedding'],
                                                                                kwargs['n_features'], 
                                                                                kwargs['steps'])
    pathlib.Path(exp_dir).mkdir(parents=True, exist_ok=False)
    
    # Meta data
    experiments = {'experiment': exp,
                   'train':(train_data, train_labels),
                   'test': (test_data, test_labels)}
    pd.to_pickle(experiments, os.path.join(exp_dir, "experiment_meta_data.pkl"))
    
    # Training
    feature_training(train_data, train_labels, test_data, test_labels, feature_idx, kwargs['embedding'], exp_dir)

# %% [markdown]
# ### Setup

# %%
base="/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP"
# read meta/data
tcga_meta = pd.read_csv(os.path.join(base, "TCGA/TCGA_GDC_ID_MAP.tsv"), sep="\t")

# %%
disease = tcga_meta[tcga_meta['Sample Type']=='Solid Tissue Normal']['Disease'].value_counts()
disease = list(disease[disease>=20].index)
disease
# Out:
# ['BRCA',
#  'KIRC',
#  'LUAD',
#  'THCA',
#  'PRAD',
#  'LIHC',
#  'LUSC',
#  'HNSC',
#  'COAD',
#  'UCEC',
#  'STAD',
#  'KIRP',
#  'KICH']

# %%
sample_type = ['Primary Tumor', 'Solid Tissue Normal']
params = {"device":"5",
          "n_features":2000,
          "steps":100,
          "embedding":2}

# %%
main(disease=disease, sample_type=sample_type, **params)
# Out:
# Cuda is available: True
# Number features: 1
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.062493
# Epoch: 1/10. Train set: Average loss: 0.1721
# Epoch: 1/10. Validation set: Average loss: 0.1538
# Train: [0/5622 (0%)]	Loss: 0.135741
# Epoch: 2/10. Train set: Average loss: 0.1554
# Epoch: 2/10. Validation set: Average loss: 0.1524
# Train: [0/5622 (0%)]	Loss: 0.173120
# Epoch: 3/10. Train set: Average loss: 0.1482
# Epoch: 3/10. Validation set: Average loss: 0.1527
# Train: [0/5622 (0%)]	Loss: 0.217097
# Epoch: 4/10. Train set: Average loss: 0.1536
# Epoch: 4/10. Validation set: Average loss: 0.1421
# Train: [0/5622 (0%)]	Loss: 0.029476
# Epoch: 5/10. Train set: Average loss: 0.1569
# Epoch: 5/10. Validation set: Average loss: 0.1472
# Train: [0/5622 (0%)]	Loss: 0.066172
# Epoch: 6/10. Train set: Average loss: 0.1504
# Epoch: 6/10. Validation set: Average loss: 0.1411
# Train: [0/5622 (0%)]	Loss: 0.109551
# Epoch: 7/10. Train set: Average loss: 0.1498
# Epoch: 7/10. Validation set: Average loss: 0.1468
# Train: [0/5622 (0%)]	Loss: 0.199020
# Epoch: 8/10. Train set: Average loss: 0.1472
# Epoch: 8/10. Validation set: Average loss: 0.1452
# Train: [0/5622 (0%)]	Loss: 0.076339
# Epoch: 9/10. Train set: Average loss: 0.1437
# Epoch: 9/10. Validation set: Average loss: 0.1407
# Train: [0/5622 (0%)]	Loss: 0.071774
# Epoch: 10/10. Train set: Average loss: 0.1451
# Epoch: 10/10. Validation set: Average loss: 0.1409
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.124964
# Epoch: 1/10. Train set: Average loss: 0.1865
# Epoch: 1/10. Validation set: Average loss: 0.1563
# Train: [0/5622 (0%)]	Loss: 0.116797
# Epoch: 2/10. Train set: Average loss: 0.1515
# Epoch: 2/10. Validation set: Average loss: 0.1533
# Train: [0/5622 (0%)]	Loss: 0.140829
# Epoch: 3/10. Train set: Average loss: 0.1484
# Epoch: 3/10. Validation set: Average loss: 0.1786
# Train: [0/5622 (0%)]	Loss: 0.227855
# Epoch: 4/10. Train set: Average loss: 0.1508
# Epoch: 4/10. Validation set: Average loss: 0.1521
# Train: [0/5622 (0%)]	Loss: 0.211683
# Epoch: 5/10. Train set: Average loss: 0.1500
# Epoch: 5/10. Validation set: Average loss: 0.1683
# Train: [0/5622 (0%)]	Loss: 0.181101
# Epoch: 6/10. Train set: Average loss: 0.1487
# Epoch: 6/10. Validation set: Average loss: 0.1760
# Train: [0/5622 (0%)]	Loss: 0.118344
# Epoch: 7/10. Train set: Average loss: 0.1505
# Epoch: 7/10. Validation set: Average loss: 0.2027
# Train: [0/5622 (0%)]	Loss: 0.066940
# Epoch: 8/10. Train set: Average loss: 0.1529
# Epoch: 8/10. Validation set: Average loss: 0.1452
# Train: [0/5622 (0%)]	Loss: 0.286298
# Epoch: 9/10. Train set: Average loss: 0.1436
# Epoch: 9/10. Validation set: Average loss: 0.1420
# Train: [0/5622 (0%)]	Loss: 0.116081
# Epoch: 10/10. Train set: Average loss: 0.1463
# Epoch: 10/10. Validation set: Average loss: 0.1415
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.187304
# Epoch: 1/10. Train set: Average loss: 0.1746
# Epoch: 1/10. Validation set: Average loss: 0.1431
# Train: [0/5622 (0%)]	Loss: 0.070213
# Epoch: 2/10. Train set: Average loss: 0.1551
# Epoch: 2/10. Validation set: Average loss: 0.1487
# Train: [0/5622 (0%)]	Loss: 0.105269
# Epoch: 3/10. Train set: Average loss: 0.1522
# Epoch: 3/10. Validation set: Average loss: 0.1451
# Train: [0/5622 (0%)]	Loss: 0.225931
# Epoch: 4/10. Train set: Average loss: 0.1484
# Epoch: 4/10. Validation set: Average loss: 0.1534
# Train: [0/5622 (0%)]	Loss: 0.156082
# Epoch: 5/10. Train set: Average loss: 0.1442
# Epoch: 5/10. Validation set: Average loss: 0.1594
# Train: [0/5622 (0%)]	Loss: 0.074873
# Epoch: 6/10. Train set: Average loss: 0.1486
# Epoch: 6/10. Validation set: Average loss: 0.1556
# Train: [0/5622 (0%)]	Loss: 0.159758
# Epoch: 7/10. Train set: Average loss: 0.1551
# Epoch: 7/10. Validation set: Average loss: 0.1461
# Train: [0/5622 (0%)]	Loss: 0.136793
# Epoch: 8/10. Train set: Average loss: 0.1545
# Epoch: 8/10. Validation set: Average loss: 0.1450
# Train: [0/5622 (0%)]	Loss: 0.220112
# Epoch: 9/10. Train set: Average loss: 0.1455
# Epoch: 9/10. Validation set: Average loss: 0.1418
# Train: [0/5622 (0%)]	Loss: 0.077150
# Epoch: 10/10. Train set: Average loss: 0.1493
# Epoch: 10/10. Validation set: Average loss: 0.1405
# Number features: 21
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.124559
# Epoch: 1/10. Train set: Average loss: 0.1165
# Epoch: 1/10. Validation set: Average loss: 0.1069
# Train: [0/5622 (0%)]	Loss: 0.100554
# Epoch: 2/10. Train set: Average loss: 0.0955
# Epoch: 2/10. Validation set: Average loss: 0.0937
# Train: [0/5622 (0%)]	Loss: 0.056210
# Epoch: 3/10. Train set: Average loss: 0.0994
# Epoch: 3/10. Validation set: Average loss: 0.0916
# Train: [0/5622 (0%)]	Loss: 0.143609
# Epoch: 4/10. Train set: Average loss: 0.0870
# Epoch: 4/10. Validation set: Average loss: 0.0836
# Train: [0/5622 (0%)]	Loss: 0.154874
# Epoch: 5/10. Train set: Average loss: 0.0794
# Epoch: 5/10. Validation set: Average loss: 0.0761
# Train: [0/5622 (0%)]	Loss: 0.068072
# Epoch: 6/10. Train set: Average loss: 0.0723
# Epoch: 6/10. Validation set: Average loss: 0.0775
# Train: [0/5622 (0%)]	Loss: 0.118427
# Epoch: 7/10. Train set: Average loss: 0.0729
# Epoch: 7/10. Validation set: Average loss: 0.0667
# Train: [0/5622 (0%)]	Loss: 0.059861
# Epoch: 8/10. Train set: Average loss: 0.0655
# Epoch: 8/10. Validation set: Average loss: 0.0707
# Train: [0/5622 (0%)]	Loss: 0.072808
# Epoch: 9/10. Train set: Average loss: 0.0630
# Epoch: 9/10. Validation set: Average loss: 0.0622
# Train: [0/5622 (0%)]	Loss: 0.084078
# Epoch: 10/10. Train set: Average loss: 0.0566
# Epoch: 10/10. Validation set: Average loss: 0.0605
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.187030
# Epoch: 1/10. Train set: Average loss: 0.1122
# Epoch: 1/10. Validation set: Average loss: 0.0997
# Train: [0/5622 (0%)]	Loss: 0.101355
# Epoch: 2/10. Train set: Average loss: 0.0895
# Epoch: 2/10. Validation set: Average loss: 0.0925
# Train: [0/5622 (0%)]	Loss: 0.086898
# Epoch: 3/10. Train set: Average loss: 0.0815
# Epoch: 3/10. Validation set: Average loss: 0.0804
# Train: [0/5622 (0%)]	Loss: 0.064820
# Epoch: 4/10. Train set: Average loss: 0.0791
# Epoch: 4/10. Validation set: Average loss: 0.0774
# Train: [0/5622 (0%)]	Loss: 0.070779
# Epoch: 5/10. Train set: Average loss: 0.0774
# Epoch: 5/10. Validation set: Average loss: 0.0738
# Train: [0/5622 (0%)]	Loss: 0.048055
# Epoch: 6/10. Train set: Average loss: 0.0713
# Epoch: 6/10. Validation set: Average loss: 0.0745
# Train: [0/5622 (0%)]	Loss: 0.110712
# Epoch: 7/10. Train set: Average loss: 0.0706
# Epoch: 7/10. Validation set: Average loss: 0.0753
# Train: [0/5622 (0%)]	Loss: 0.067160
# Epoch: 8/10. Train set: Average loss: 0.0709
# Epoch: 8/10. Validation set: Average loss: 0.0782
# Train: [0/5622 (0%)]	Loss: 0.081564
# Epoch: 9/10. Train set: Average loss: 0.0631
# Epoch: 9/10. Validation set: Average loss: 0.0661
# Train: [0/5622 (0%)]	Loss: 0.046066
# Epoch: 10/10. Train set: Average loss: 0.0587
# Epoch: 10/10. Validation set: Average loss: 0.0647
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.249278
# Epoch: 1/10. Train set: Average loss: 0.1162
# Epoch: 1/10. Validation set: Average loss: 0.1039
# Train: [0/5622 (0%)]	Loss: 0.068808
# Epoch: 2/10. Train set: Average loss: 0.0964
# Epoch: 2/10. Validation set: Average loss: 0.0903
# Train: [0/5622 (0%)]	Loss: 0.071226
# Epoch: 3/10. Train set: Average loss: 0.0831
# Epoch: 3/10. Validation set: Average loss: 0.0815
# Train: [0/5622 (0%)]	Loss: 0.051689
# Epoch: 4/10. Train set: Average loss: 0.0803
# Epoch: 4/10. Validation set: Average loss: 0.0834
# Train: [0/5622 (0%)]	Loss: 0.047977
# Epoch: 5/10. Train set: Average loss: 0.0738
# Epoch: 5/10. Validation set: Average loss: 0.0764
# Train: [0/5622 (0%)]	Loss: 0.020687
# Epoch: 6/10. Train set: Average loss: 0.0746
# Epoch: 6/10. Validation set: Average loss: 0.0716
# Train: [0/5622 (0%)]	Loss: 0.072223
# Epoch: 7/10. Train set: Average loss: 0.0690
# Epoch: 7/10. Validation set: Average loss: 0.0744
# Train: [0/5622 (0%)]	Loss: 0.067695
# Epoch: 8/10. Train set: Average loss: 0.0708
# Epoch: 8/10. Validation set: Average loss: 0.0769
# Train: [0/5622 (0%)]	Loss: 0.035592
# Epoch: 9/10. Train set: Average loss: 0.0638
# Epoch: 9/10. Validation set: Average loss: 0.0682
# Train: [0/5622 (0%)]	Loss: 0.034861
# Epoch: 10/10. Train set: Average loss: 0.0595
# Epoch: 10/10. Validation set: Average loss: 0.0683
# Number features: 41
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.062231
# Epoch: 1/10. Train set: Average loss: 0.0955
# Epoch: 1/10. Validation set: Average loss: 0.0952
# Train: [0/5622 (0%)]	Loss: 0.055869
# Epoch: 2/10. Train set: Average loss: 0.0863
# Epoch: 2/10. Validation set: Average loss: 0.0972
# Train: [0/5622 (0%)]	Loss: 0.100130
# Epoch: 3/10. Train set: Average loss: 0.0842
# Epoch: 3/10. Validation set: Average loss: 0.0794
# Train: [0/5622 (0%)]	Loss: 0.068180
# Epoch: 4/10. Train set: Average loss: 0.0751
# Epoch: 4/10. Validation set: Average loss: 0.0704
# Train: [0/5622 (0%)]	Loss: 0.044138
# Epoch: 5/10. Train set: Average loss: 0.0616
# Epoch: 5/10. Validation set: Average loss: 0.0736
# Train: [0/5622 (0%)]	Loss: 0.026531
# Epoch: 6/10. Train set: Average loss: 0.0666
# Epoch: 6/10. Validation set: Average loss: 0.0667
# Train: [0/5622 (0%)]	Loss: 0.010411
# Epoch: 7/10. Train set: Average loss: 0.0586
# Epoch: 7/10. Validation set: Average loss: 0.0660
# Train: [0/5622 (0%)]	Loss: 0.059232
# Epoch: 8/10. Train set: Average loss: 0.0556
# Epoch: 8/10. Validation set: Average loss: 0.0646
# Train: [0/5622 (0%)]	Loss: 0.070123
# Epoch: 9/10. Train set: Average loss: 0.0481
# Epoch: 9/10. Validation set: Average loss: 0.0553
# Train: [0/5622 (0%)]	Loss: 0.016848
# Epoch: 10/10. Train set: Average loss: 0.0454
# Epoch: 10/10. Validation set: Average loss: 0.0535
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.186665
# Epoch: 1/10. Train set: Average loss: 0.0930
# Epoch: 1/10. Validation set: Average loss: 0.0824
# Train: [0/5622 (0%)]	Loss: 0.022789
# Epoch: 2/10. Train set: Average loss: 0.0823
# Epoch: 2/10. Validation set: Average loss: 0.0829
# Train: [0/5622 (0%)]	Loss: 0.051966
# Epoch: 3/10. Train set: Average loss: 0.0749
# Epoch: 3/10. Validation set: Average loss: 0.0818
# Train: [0/5622 (0%)]	Loss: 0.030511
# Epoch: 4/10. Train set: Average loss: 0.0732
# Epoch: 4/10. Validation set: Average loss: 0.0699
# Train: [0/5622 (0%)]	Loss: 0.069908
# Epoch: 5/10. Train set: Average loss: 0.0679
# Epoch: 5/10. Validation set: Average loss: 0.0680
# Train: [0/5622 (0%)]	Loss: 0.035199
# Epoch: 6/10. Train set: Average loss: 0.0668
# Epoch: 6/10. Validation set: Average loss: 0.0790
# Train: [0/5622 (0%)]	Loss: 0.036794
# Epoch: 7/10. Train set: Average loss: 0.0631
# Epoch: 7/10. Validation set: Average loss: 0.0743
# Train: [0/5622 (0%)]	Loss: 0.044477
# Epoch: 8/10. Train set: Average loss: 0.0617
# Epoch: 8/10. Validation set: Average loss: 0.0689
# Train: [0/5622 (0%)]	Loss: 0.052351
# Epoch: 9/10. Train set: Average loss: 0.0535
# Epoch: 9/10. Validation set: Average loss: 0.0588
# Train: [0/5622 (0%)]	Loss: 0.049104
# Epoch: 10/10. Train set: Average loss: 0.0496
# Epoch: 10/10. Validation set: Average loss: 0.0577
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.187215
# Epoch: 1/10. Train set: Average loss: 0.0979
# Epoch: 1/10. Validation set: Average loss: 0.0822
# Train: [0/5622 (0%)]	Loss: 0.088345
# Epoch: 2/10. Train set: Average loss: 0.0748
# Epoch: 2/10. Validation set: Average loss: 0.0838
# Train: [0/5622 (0%)]	Loss: 0.032860
# Epoch: 3/10. Train set: Average loss: 0.0727
# Epoch: 3/10. Validation set: Average loss: 0.0682
# Train: [0/5622 (0%)]	Loss: 0.100362
# Epoch: 4/10. Train set: Average loss: 0.0705
# Epoch: 4/10. Validation set: Average loss: 0.0770
# Train: [0/5622 (0%)]	Loss: 0.066244
# Epoch: 5/10. Train set: Average loss: 0.0662
# Epoch: 5/10. Validation set: Average loss: 0.0727
# Train: [0/5622 (0%)]	Loss: 0.108817
# Epoch: 6/10. Train set: Average loss: 0.0732
# Epoch: 6/10. Validation set: Average loss: 0.0931
# Train: [0/5622 (0%)]	Loss: 0.073872
# Epoch: 7/10. Train set: Average loss: 0.0610
# Epoch: 7/10. Validation set: Average loss: 0.0627
# Train: [0/5622 (0%)]	Loss: 0.095632
# Epoch: 8/10. Train set: Average loss: 0.0607
# Epoch: 8/10. Validation set: Average loss: 0.0671
# Train: [0/5622 (0%)]	Loss: 0.019034
# Epoch: 9/10. Train set: Average loss: 0.0512
# Epoch: 9/10. Validation set: Average loss: 0.0597
# Train: [0/5622 (0%)]	Loss: 0.078625
# Epoch: 10/10. Train set: Average loss: 0.0482
# Epoch: 10/10. Validation set: Average loss: 0.0556
# Number features: 61
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.248704
# Epoch: 1/10. Train set: Average loss: 0.0885
# Epoch: 1/10. Validation set: Average loss: 0.0784
# Train: [0/5622 (0%)]	Loss: 0.091902
# Epoch: 2/10. Train set: Average loss: 0.0684
# Epoch: 2/10. Validation set: Average loss: 0.0799
# Train: [0/5622 (0%)]	Loss: 0.072184
# Epoch: 3/10. Train set: Average loss: 0.0609
# Epoch: 3/10. Validation set: Average loss: 0.0624
# Train: [0/5622 (0%)]	Loss: 0.050466
# Epoch: 4/10. Train set: Average loss: 0.0629
# Epoch: 4/10. Validation set: Average loss: 0.0577
# Train: [0/5622 (0%)]	Loss: 0.037018
# Epoch: 5/10. Train set: Average loss: 0.0569
# Epoch: 5/10. Validation set: Average loss: 0.0529
# Train: [0/5622 (0%)]	Loss: 0.054440
# Epoch: 6/10. Train set: Average loss: 0.0518
# Epoch: 6/10. Validation set: Average loss: 0.0544
# Train: [0/5622 (0%)]	Loss: 0.017966
# Epoch: 7/10. Train set: Average loss: 0.0524
# Epoch: 7/10. Validation set: Average loss: 0.0483
# Train: [0/5622 (0%)]	Loss: 0.062670
# Epoch: 8/10. Train set: Average loss: 0.0460
# Epoch: 8/10. Validation set: Average loss: 0.0521
# Train: [0/5622 (0%)]	Loss: 0.042163
# Epoch: 9/10. Train set: Average loss: 0.0394
# Epoch: 9/10. Validation set: Average loss: 0.0400
# Train: [0/5622 (0%)]	Loss: 0.018404
# Epoch: 10/10. Train set: Average loss: 0.0394
# Epoch: 10/10. Validation set: Average loss: 0.0400
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.311756
# Epoch: 1/10. Train set: Average loss: 0.0875
# Epoch: 1/10. Validation set: Average loss: 0.0744
# Train: [0/5622 (0%)]	Loss: 0.042018
# Epoch: 2/10. Train set: Average loss: 0.0760
# Epoch: 2/10. Validation set: Average loss: 0.0733
# Train: [0/5622 (0%)]	Loss: 0.056573
# Epoch: 3/10. Train set: Average loss: 0.0659
# Epoch: 3/10. Validation set: Average loss: 0.0681
# Train: [0/5622 (0%)]	Loss: 0.089436
# Epoch: 4/10. Train set: Average loss: 0.0640
# Epoch: 4/10. Validation set: Average loss: 0.0659
# Train: [0/5622 (0%)]	Loss: 0.033333
# Epoch: 5/10. Train set: Average loss: 0.0599
# Epoch: 5/10. Validation set: Average loss: 0.0594
# Train: [0/5622 (0%)]	Loss: 0.052152
# Epoch: 6/10. Train set: Average loss: 0.0587
# Epoch: 6/10. Validation set: Average loss: 0.0557
# Train: [0/5622 (0%)]	Loss: 0.070139
# Epoch: 7/10. Train set: Average loss: 0.0539
# Epoch: 7/10. Validation set: Average loss: 0.0503
# Train: [0/5622 (0%)]	Loss: 0.049701
# Epoch: 8/10. Train set: Average loss: 0.0527
# Epoch: 8/10. Validation set: Average loss: 0.0520
# Train: [0/5622 (0%)]	Loss: 0.100701
# Epoch: 9/10. Train set: Average loss: 0.0467
# Epoch: 9/10. Validation set: Average loss: 0.0423
# Train: [0/5622 (0%)]	Loss: 0.034318
# Epoch: 10/10. Train set: Average loss: 0.0438
# Epoch: 10/10. Validation set: Average loss: 0.0408
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.373995
# Epoch: 1/10. Train set: Average loss: 0.0872
# Epoch: 1/10. Validation set: Average loss: 0.0816
# Train: [0/5622 (0%)]	Loss: 0.062876
# Epoch: 2/10. Train set: Average loss: 0.0708
# Epoch: 2/10. Validation set: Average loss: 0.0670
# Train: [0/5622 (0%)]	Loss: 0.095106
# Epoch: 3/10. Train set: Average loss: 0.0612
# Epoch: 3/10. Validation set: Average loss: 0.0615
# Train: [0/5622 (0%)]	Loss: 0.146396
# Epoch: 4/10. Train set: Average loss: 0.0579
# Epoch: 4/10. Validation set: Average loss: 0.0654
# Train: [0/5622 (0%)]	Loss: 0.069917
# Epoch: 5/10. Train set: Average loss: 0.0550
# Epoch: 5/10. Validation set: Average loss: 0.0538
# Train: [0/5622 (0%)]	Loss: 0.053101
# Epoch: 6/10. Train set: Average loss: 0.0518
# Epoch: 6/10. Validation set: Average loss: 0.0534
# Train: [0/5622 (0%)]	Loss: 0.027487
# Epoch: 7/10. Train set: Average loss: 0.0497
# Epoch: 7/10. Validation set: Average loss: 0.0444
# Train: [0/5622 (0%)]	Loss: 0.085864
# Epoch: 8/10. Train set: Average loss: 0.0475
# Epoch: 8/10. Validation set: Average loss: 0.0461
# Train: [0/5622 (0%)]	Loss: 0.024217
# Epoch: 9/10. Train set: Average loss: 0.0420
# Epoch: 9/10. Validation set: Average loss: 0.0416
# Train: [0/5622 (0%)]	Loss: 0.031001
# Epoch: 10/10. Train set: Average loss: 0.0383
# Epoch: 10/10. Validation set: Average loss: 0.0417
# Number features: 81
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.311590
# Epoch: 1/10. Train set: Average loss: 0.0759
# Epoch: 1/10. Validation set: Average loss: 0.0660
# Train: [0/5622 (0%)]	Loss: 0.072939
# Epoch: 2/10. Train set: Average loss: 0.0674
# Epoch: 2/10. Validation set: Average loss: 0.0707
# Train: [0/5622 (0%)]	Loss: 0.049592
# Epoch: 3/10. Train set: Average loss: 0.0741
# Epoch: 3/10. Validation set: Average loss: 0.0753
# Train: [0/5622 (0%)]	Loss: 0.054269
# Epoch: 4/10. Train set: Average loss: 0.0611
# Epoch: 4/10. Validation set: Average loss: 0.0541
# Train: [0/5622 (0%)]	Loss: 0.046370
# Epoch: 5/10. Train set: Average loss: 0.0550
# Epoch: 5/10. Validation set: Average loss: 0.0673
# Train: [0/5622 (0%)]	Loss: 0.059877
# Epoch: 6/10. Train set: Average loss: 0.0503
# Epoch: 6/10. Validation set: Average loss: 0.0514
# Train: [0/5622 (0%)]	Loss: 0.065859
# Epoch: 7/10. Train set: Average loss: 0.0563
# Epoch: 7/10. Validation set: Average loss: 0.0539
# Train: [0/5622 (0%)]	Loss: 0.036044
# Epoch: 8/10. Train set: Average loss: 0.0485
# Epoch: 8/10. Validation set: Average loss: 0.0610
# Train: [0/5622 (0%)]	Loss: 0.047777
# Epoch: 9/10. Train set: Average loss: 0.0415
# Epoch: 9/10. Validation set: Average loss: 0.0423
# Train: [0/5622 (0%)]	Loss: 0.052413
# Epoch: 10/10. Train set: Average loss: 0.0374
# Epoch: 10/10. Validation set: Average loss: 0.0420
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.311930
# Epoch: 1/10. Train set: Average loss: 0.0832
# Epoch: 1/10. Validation set: Average loss: 0.0948
# Train: [0/5622 (0%)]	Loss: 0.084574
# Epoch: 2/10. Train set: Average loss: 0.0718
# Epoch: 2/10. Validation set: Average loss: 0.0556
# Train: [0/5622 (0%)]	Loss: 0.086180
# Epoch: 3/10. Train set: Average loss: 0.0617
# Epoch: 3/10. Validation set: Average loss: 0.0521
# Train: [0/5622 (0%)]	Loss: 0.040281
# Epoch: 4/10. Train set: Average loss: 0.0554
# Epoch: 4/10. Validation set: Average loss: 0.0546
# Train: [0/5622 (0%)]	Loss: 0.082731
# Epoch: 5/10. Train set: Average loss: 0.0535
# Epoch: 5/10. Validation set: Average loss: 0.0481
# Train: [0/5622 (0%)]	Loss: 0.038422
# Epoch: 6/10. Train set: Average loss: 0.0541
# Epoch: 6/10. Validation set: Average loss: 0.0459
# Train: [0/5622 (0%)]	Loss: 0.033791
# Epoch: 7/10. Train set: Average loss: 0.0462
# Epoch: 7/10. Validation set: Average loss: 0.0476
# Train: [0/5622 (0%)]	Loss: 0.076861
# Epoch: 8/10. Train set: Average loss: 0.0479
# Epoch: 8/10. Validation set: Average loss: 0.0523
# Train: [0/5622 (0%)]	Loss: 0.053508
# Epoch: 9/10. Train set: Average loss: 0.0404
# Epoch: 9/10. Validation set: Average loss: 0.0404
# Train: [0/5622 (0%)]	Loss: 0.039565
# Epoch: 10/10. Train set: Average loss: 0.0361
# Epoch: 10/10. Validation set: Average loss: 0.0406
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.186467
# Epoch: 1/10. Train set: Average loss: 0.0717
# Epoch: 1/10. Validation set: Average loss: 0.0734
# Train: [0/5622 (0%)]	Loss: 0.055330
# Epoch: 2/10. Train set: Average loss: 0.0641
# Epoch: 2/10. Validation set: Average loss: 0.0528
# Train: [0/5622 (0%)]	Loss: 0.068541
# Epoch: 3/10. Train set: Average loss: 0.0574
# Epoch: 3/10. Validation set: Average loss: 0.0496
# Train: [0/5622 (0%)]	Loss: 0.067561
# Epoch: 4/10. Train set: Average loss: 0.0582
# Epoch: 4/10. Validation set: Average loss: 0.0508
# Train: [0/5622 (0%)]	Loss: 0.063220
# Epoch: 5/10. Train set: Average loss: 0.0554
# Epoch: 5/10. Validation set: Average loss: 0.0473
# Train: [0/5622 (0%)]	Loss: 0.045636
# Epoch: 6/10. Train set: Average loss: 0.0499
# Epoch: 6/10. Validation set: Average loss: 0.0575
# Train: [0/5622 (0%)]	Loss: 0.032918
# Epoch: 7/10. Train set: Average loss: 0.0500
# Epoch: 7/10. Validation set: Average loss: 0.0425
# Train: [0/5622 (0%)]	Loss: 0.105048
# Epoch: 8/10. Train set: Average loss: 0.0482
# Epoch: 8/10. Validation set: Average loss: 0.0441
# Train: [0/5622 (0%)]	Loss: 0.072770
# Epoch: 9/10. Train set: Average loss: 0.0395
# Epoch: 9/10. Validation set: Average loss: 0.0407
# Train: [0/5622 (0%)]	Loss: 0.061818
# Epoch: 10/10. Train set: Average loss: 0.0375
# Epoch: 10/10. Validation set: Average loss: 0.0391
# Number features: 101
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.311913
# Epoch: 1/10. Train set: Average loss: 0.0893
# Epoch: 1/10. Validation set: Average loss: 0.1112
# Train: [0/5622 (0%)]	Loss: 0.063107
# Epoch: 2/10. Train set: Average loss: 0.0685
# Epoch: 2/10. Validation set: Average loss: 0.0694
# Train: [0/5622 (0%)]	Loss: 0.069043
# Epoch: 3/10. Train set: Average loss: 0.0620
# Epoch: 3/10. Validation set: Average loss: 0.0603
# Train: [0/5622 (0%)]	Loss: 0.044153
# Epoch: 4/10. Train set: Average loss: 0.0552
# Epoch: 4/10. Validation set: Average loss: 0.0717
# Train: [0/5622 (0%)]	Loss: 0.007914
# Epoch: 5/10. Train set: Average loss: 0.0544
# Epoch: 5/10. Validation set: Average loss: 0.0700
# Train: [0/5622 (0%)]	Loss: 0.054296
# Epoch: 6/10. Train set: Average loss: 0.0509
# Epoch: 6/10. Validation set: Average loss: 0.0545
# Train: [0/5622 (0%)]	Loss: 0.065253
# Epoch: 7/10. Train set: Average loss: 0.0492
# Epoch: 7/10. Validation set: Average loss: 0.0604
# Train: [0/5622 (0%)]	Loss: 0.006350
# Epoch: 8/10. Train set: Average loss: 0.0489
# Epoch: 8/10. Validation set: Average loss: 0.0687
# Train: [0/5622 (0%)]	Loss: 0.007417
# Epoch: 9/10. Train set: Average loss: 0.0429
# Epoch: 9/10. Validation set: Average loss: 0.0464
# Train: [0/5622 (0%)]	Loss: 0.035406
# Epoch: 10/10. Train set: Average loss: 0.0402
# Epoch: 10/10. Validation set: Average loss: 0.0448
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.374449
# Epoch: 1/10. Train set: Average loss: 0.0833
# Epoch: 1/10. Validation set: Average loss: 0.0856
# Train: [0/5622 (0%)]	Loss: 0.035180
# Epoch: 2/10. Train set: Average loss: 0.0655
# Epoch: 2/10. Validation set: Average loss: 0.0856
# Train: [0/5622 (0%)]	Loss: 0.065261
# Epoch: 3/10. Train set: Average loss: 0.0616
# Epoch: 3/10. Validation set: Average loss: 0.1206
# Train: [0/5622 (0%)]	Loss: 0.039094
# Epoch: 4/10. Train set: Average loss: 0.0597
# Epoch: 4/10. Validation set: Average loss: 0.0851
# Train: [0/5622 (0%)]	Loss: 0.082836
# Epoch: 5/10. Train set: Average loss: 0.0543
# Epoch: 5/10. Validation set: Average loss: 0.0654
# Train: [0/5622 (0%)]	Loss: 0.053594
# Epoch: 6/10. Train set: Average loss: 0.0532
# Epoch: 6/10. Validation set: Average loss: 0.0649
# Train: [0/5622 (0%)]	Loss: 0.097482
# Epoch: 7/10. Train set: Average loss: 0.0522
# Epoch: 7/10. Validation set: Average loss: 0.0592
# Train: [0/5622 (0%)]	Loss: 0.136797
# Epoch: 8/10. Train set: Average loss: 0.0515
# Epoch: 8/10. Validation set: Average loss: 0.0535
# Train: [0/5622 (0%)]	Loss: 0.099372
# Epoch: 9/10. Train set: Average loss: 0.0454
# Epoch: 9/10. Validation set: Average loss: 0.0482
# Train: [0/5622 (0%)]	Loss: 0.074977
# Epoch: 10/10. Train set: Average loss: 0.0420
# Epoch: 10/10. Validation set: Average loss: 0.0473
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.249584
# Epoch: 1/10. Train set: Average loss: 0.0838
# Epoch: 1/10. Validation set: Average loss: 0.0801
# Train: [0/5622 (0%)]	Loss: 0.036925
# Epoch: 2/10. Train set: Average loss: 0.0691
# Epoch: 2/10. Validation set: Average loss: 0.0936
# Train: [0/5622 (0%)]	Loss: 0.037048
# Epoch: 3/10. Train set: Average loss: 0.0641
# Epoch: 3/10. Validation set: Average loss: 0.0609
# Train: [0/5622 (0%)]	Loss: 0.103231
# Epoch: 4/10. Train set: Average loss: 0.0586
# Epoch: 4/10. Validation set: Average loss: 0.0723
# Train: [0/5622 (0%)]	Loss: 0.038301
# Epoch: 5/10. Train set: Average loss: 0.0566
# Epoch: 5/10. Validation set: Average loss: 0.0536
# Train: [0/5622 (0%)]	Loss: 0.025555
# Epoch: 10/10. Train set: Average loss: 0.0410
# Epoch: 10/10. Validation set: Average loss: 0.0443
# Number features: 122
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.124580
# Epoch: 1/10. Train set: Average loss: 0.0907
# Epoch: 1/10. Validation set: Average loss: 0.0858
# Train: [0/5622 (0%)]	Loss: 0.160459
# Epoch: 2/10. Train set: Average loss: 0.0730
# Epoch: 2/10. Validation set: Average loss: 0.0661
# Train: [0/5622 (0%)]	Loss: 0.022022
# Epoch: 3/10. Train set: Average loss: 0.0661
# Epoch: 3/10. Validation set: Average loss: 0.0713
# Train: [0/5622 (0%)]	Loss: 0.091688
# Epoch: 4/10. Train set: Average loss: 0.0607
# Epoch: 4/10. Validation set: Average loss: 0.0648
# Train: [0/5622 (0%)]	Loss: 0.033653
# Epoch: 5/10. Train set: Average loss: 0.0607
# Epoch: 5/10. Validation set: Average loss: 0.0680
# Train: [0/5622 (0%)]	Loss: 0.058186
# Epoch: 6/10. Train set: Average loss: 0.0579
# Epoch: 6/10. Validation set: Average loss: 0.0905
# Train: [0/5622 (0%)]	Loss: 0.061623
# Epoch: 7/10. Train set: Average loss: 0.0611
# Epoch: 7/10. Validation set: Average loss: 0.0634
# Train: [0/5622 (0%)]	Loss: 0.105001
# Epoch: 8/10. Train set: Average loss: 0.0499
# Epoch: 8/10. Validation set: Average loss: 0.0543
# Train: [0/5622 (0%)]	Loss: 0.017088
# Epoch: 9/10. Train set: Average loss: 0.0468
# Epoch: 9/10. Validation set: Average loss: 0.0511
# Train: [0/5622 (0%)]	Loss: 0.031063
# Epoch: 10/10. Train set: Average loss: 0.0442
# Epoch: 10/10. Validation set: Average loss: 0.0506
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.124721
# Epoch: 1/10. Train set: Average loss: 0.0869
# Epoch: 1/10. Validation set: Average loss: 0.0716
# Train: [0/5622 (0%)]	Loss: 0.136737
# Epoch: 2/10. Train set: Average loss: 0.0669
# Epoch: 2/10. Validation set: Average loss: 0.0688
# Train: [0/5622 (0%)]	Loss: 0.032737
# Epoch: 3/10. Train set: Average loss: 0.0697
# Epoch: 3/10. Validation set: Average loss: 0.0682
# Train: [0/5622 (0%)]	Loss: 0.034769
# Epoch: 4/10. Train set: Average loss: 0.0697
# Epoch: 4/10. Validation set: Average loss: 0.0678
# Train: [0/5622 (0%)]	Loss: 0.103157
# Epoch: 5/10. Train set: Average loss: 0.0609
# Epoch: 5/10. Validation set: Average loss: 0.0787
# Train: [0/5622 (0%)]	Loss: 0.291363
# Epoch: 6/10. Train set: Average loss: 0.0588
# Epoch: 6/10. Validation set: Average loss: 0.0576
# Train: [0/5622 (0%)]	Loss: 0.057030
# Epoch: 7/10. Train set: Average loss: 0.0551
# Epoch: 7/10. Validation set: Average loss: 0.0630
# Train: [0/5622 (0%)]	Loss: 0.071146
# Epoch: 8/10. Train set: Average loss: 0.0545
# Epoch: 8/10. Validation set: Average loss: 0.0568
# Train: [0/5622 (0%)]	Loss: 0.031950
# Epoch: 9/10. Train set: Average loss: 0.0477
# Epoch: 9/10. Validation set: Average loss: 0.0499
# Train: [0/5622 (0%)]	Loss: 0.058014
# Epoch: 10/10. Train set: Average loss: 0.0458
# Epoch: 10/10. Validation set: Average loss: 0.0481
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.187026
# Epoch: 1/10. Train set: Average loss: 0.0796
# Epoch: 1/10. Validation set: Average loss: 0.0728
# Train: [0/5622 (0%)]	Loss: 0.060855
# Epoch: 2/10. Train set: Average loss: 0.0719
# Epoch: 2/10. Validation set: Average loss: 0.1136
# Train: [0/5622 (0%)]	Loss: 0.028861
# Epoch: 3/10. Train set: Average loss: 0.0686
# Epoch: 3/10. Validation set: Average loss: 0.0822
# Train: [0/5622 (0%)]	Loss: 0.071459
# Epoch: 4/10. Train set: Average loss: 0.0616
# Epoch: 4/10. Validation set: Average loss: 0.0677
# Train: [0/5622 (0%)]	Loss: 0.073348
# Epoch: 5/10. Train set: Average loss: 0.0557
# Epoch: 5/10. Validation set: Average loss: 0.0641
# Train: [0/5622 (0%)]	Loss: 0.096826
# Epoch: 6/10. Train set: Average loss: 0.0537
# Epoch: 6/10. Validation set: Average loss: 0.0724
# Train: [0/5622 (0%)]	Loss: 0.110522
# Epoch: 7/10. Train set: Average loss: 0.0504
# Epoch: 7/10. Validation set: Average loss: 0.0619
# Train: [0/5622 (0%)]	Loss: 0.012120
# Epoch: 8/10. Train set: Average loss: 0.0474
# Epoch: 8/10. Validation set: Average loss: 0.0670
# Train: [0/5622 (0%)]	Loss: 0.031161
# Epoch: 9/10. Train set: Average loss: 0.0439
# Epoch: 9/10. Validation set: Average loss: 0.0498
# Train: [0/5622 (0%)]	Loss: 0.052345
# Epoch: 10/10. Train set: Average loss: 0.0393
# Epoch: 10/10. Validation set: Average loss: 0.0486
# Number features: 142
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.374130
# Epoch: 1/10. Train set: Average loss: 0.0896
# Epoch: 1/10. Validation set: Average loss: 0.0659
# Train: [0/5622 (0%)]	Loss: 0.012318
# Epoch: 2/10. Train set: Average loss: 0.0601
# Epoch: 2/10. Validation set: Average loss: 0.0667
# Train: [0/5622 (0%)]	Loss: 0.006008
# Epoch: 3/10. Train set: Average loss: 0.0576
# Epoch: 3/10. Validation set: Average loss: 0.0591
# Train: [0/5622 (0%)]	Loss: 0.066676
# Epoch: 4/10. Train set: Average loss: 0.0522
# Epoch: 4/10. Validation set: Average loss: 0.0535
# Train: [0/5622 (0%)]	Loss: 0.077941
# Epoch: 5/10. Train set: Average loss: 0.0475
# Epoch: 5/10. Validation set: Average loss: 0.0471
# Train: [0/5622 (0%)]	Loss: 0.017182
# Epoch: 6/10. Train set: Average loss: 0.0477
# Epoch: 6/10. Validation set: Average loss: 0.0524
# Train: [0/5622 (0%)]	Loss: 0.021146
# Epoch: 7/10. Train set: Average loss: 0.0453
# Epoch: 7/10. Validation set: Average loss: 0.0464
# Train: [0/5622 (0%)]	Loss: 0.025268
# Epoch: 8/10. Train set: Average loss: 0.0406
# Epoch: 8/10. Validation set: Average loss: 0.0436
# Train: [0/5622 (0%)]	Loss: 0.070259
# Epoch: 9/10. Train set: Average loss: 0.0344
# Epoch: 9/10. Validation set: Average loss: 0.0380
# Train: [0/5622 (0%)]	Loss: 0.025777
# Epoch: 10/10. Train set: Average loss: 0.0311
# Epoch: 10/10. Validation set: Average loss: 0.0360
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.436153
# Epoch: 1/10. Train set: Average loss: 0.0823
# Epoch: 1/10. Validation set: Average loss: 0.0604
# Train: [0/5622 (0%)]	Loss: 0.020782
# Epoch: 2/10. Train set: Average loss: 0.0705
# Epoch: 2/10. Validation set: Average loss: 0.0705
# Train: [0/5622 (0%)]	Loss: 0.049713
# Epoch: 3/10. Train set: Average loss: 0.0600
# Epoch: 3/10. Validation set: Average loss: 0.0556
# Train: [0/5622 (0%)]	Loss: 0.010369
# Epoch: 4/10. Train set: Average loss: 0.0515
# Epoch: 4/10. Validation set: Average loss: 0.0482
# Train: [0/5622 (0%)]	Loss: 0.051555
# Epoch: 5/10. Train set: Average loss: 0.0491
# Epoch: 5/10. Validation set: Average loss: 0.0442
# Train: [0/5622 (0%)]	Loss: 0.010609
# Epoch: 6/10. Train set: Average loss: 0.0429
# Epoch: 6/10. Validation set: Average loss: 0.0465
# Train: [0/5622 (0%)]	Loss: 0.039012
# Epoch: 7/10. Train set: Average loss: 0.0426
# Epoch: 7/10. Validation set: Average loss: 0.0461
# Train: [0/5622 (0%)]	Loss: 0.069886
# Epoch: 8/10. Train set: Average loss: 0.0352
# Epoch: 8/10. Validation set: Average loss: 0.0392
# Train: [0/5622 (0%)]	Loss: 0.016879
# Epoch: 9/10. Train set: Average loss: 0.0314
# Epoch: 9/10. Validation set: Average loss: 0.0356
# Train: [0/5622 (0%)]	Loss: 0.065500
# Epoch: 10/10. Train set: Average loss: 0.0300
# Epoch: 10/10. Validation set: Average loss: 0.0337
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.373679
# Epoch: 1/10. Train set: Average loss: 0.0794
# Epoch: 1/10. Validation set: Average loss: 0.0609
# Train: [0/5622 (0%)]	Loss: 0.069970
# Epoch: 2/10. Train set: Average loss: 0.0644
# Epoch: 2/10. Validation set: Average loss: 0.0584
# Train: [0/5622 (0%)]	Loss: 0.033691
# Epoch: 3/10. Train set: Average loss: 0.0563
# Epoch: 3/10. Validation set: Average loss: 0.0663
# Train: [0/5622 (0%)]	Loss: 0.070014
# Epoch: 4/10. Train set: Average loss: 0.0479
# Epoch: 4/10. Validation set: Average loss: 0.0533
# Train: [0/5622 (0%)]	Loss: 0.062180
# Epoch: 5/10. Train set: Average loss: 0.0518
# Epoch: 5/10. Validation set: Average loss: 0.0506
# Train: [0/5622 (0%)]	Loss: 0.041446
# Epoch: 6/10. Train set: Average loss: 0.0492
# Epoch: 6/10. Validation set: Average loss: 0.0439
# Train: [0/5622 (0%)]	Loss: 0.007442
# Epoch: 7/10. Train set: Average loss: 0.0407
# Epoch: 7/10. Validation set: Average loss: 0.0423
# Train: [0/5622 (0%)]	Loss: 0.016254
# Epoch: 8/10. Train set: Average loss: 0.0393
# Epoch: 8/10. Validation set: Average loss: 0.0436
# Train: [0/5622 (0%)]	Loss: 0.034259
# Epoch: 9/10. Train set: Average loss: 0.0342
# Epoch: 9/10. Validation set: Average loss: 0.0357
# Train: [0/5622 (0%)]	Loss: 0.028492
# Epoch: 10/10. Train set: Average loss: 0.0310
# Epoch: 10/10. Validation set: Average loss: 0.0351
# Number features: 162
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.249479
# Epoch: 1/10. Train set: Average loss: 0.0806
# Epoch: 1/10. Validation set: Average loss: 0.0631
# Train: [0/5622 (0%)]	Loss: 0.076627
# Epoch: 2/10. Train set: Average loss: 0.0719
# Epoch: 2/10. Validation set: Average loss: 0.0612
# Train: [0/5622 (0%)]	Loss: 0.049280
# Epoch: 3/10. Train set: Average loss: 0.0585
# Epoch: 3/10. Validation set: Average loss: 0.0535
# Train: [0/5622 (0%)]	Loss: 0.021744
# Epoch: 4/10. Train set: Average loss: 0.0521
# Epoch: 4/10. Validation set: Average loss: 0.0473
# Train: [0/5622 (0%)]	Loss: 0.070271
# Epoch: 5/10. Train set: Average loss: 0.0492
# Epoch: 5/10. Validation set: Average loss: 0.0464
# Train: [0/5622 (0%)]	Loss: 0.095627
# Epoch: 6/10. Train set: Average loss: 0.0455
# Epoch: 6/10. Validation set: Average loss: 0.0407
# Train: [0/5622 (0%)]	Loss: 0.018595
# Epoch: 7/10. Train set: Average loss: 0.0455
# Epoch: 7/10. Validation set: Average loss: 0.0435
# Train: [0/5622 (0%)]	Loss: 0.021632
# Epoch: 8/10. Train set: Average loss: 0.0417
# Epoch: 8/10. Validation set: Average loss: 0.0381
# Train: [0/5622 (0%)]	Loss: 0.033544
# Epoch: 9/10. Train set: Average loss: 0.0353
# Epoch: 9/10. Validation set: Average loss: 0.0357
# Train: [0/5622 (0%)]	Loss: 0.072546
# Epoch: 10/10. Train set: Average loss: 0.0325
# Epoch: 10/10. Validation set: Average loss: 0.0345
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.124662
# Epoch: 1/10. Train set: Average loss: 0.0783
# Epoch: 1/10. Validation set: Average loss: 0.0605
# Train: [0/5622 (0%)]	Loss: 0.089142
# Epoch: 2/10. Train set: Average loss: 0.0620
# Epoch: 2/10. Validation set: Average loss: 0.0570
# Train: [0/5622 (0%)]	Loss: 0.026355
# Epoch: 3/10. Train set: Average loss: 0.0578
# Epoch: 3/10. Validation set: Average loss: 0.0524
# Train: [0/5622 (0%)]	Loss: 0.075266
# Epoch: 4/10. Train set: Average loss: 0.0596
# Epoch: 4/10. Validation set: Average loss: 0.0795
# Train: [0/5622 (0%)]	Loss: 0.050978
# Epoch: 5/10. Train set: Average loss: 0.0578
# Epoch: 5/10. Validation set: Average loss: 0.0488
# Train: [0/5622 (0%)]	Loss: 0.055144
# Epoch: 6/10. Train set: Average loss: 0.0507
# Epoch: 6/10. Validation set: Average loss: 0.0478
# Train: [0/5622 (0%)]	Loss: 0.014430
# Epoch: 7/10. Train set: Average loss: 0.0463
# Epoch: 7/10. Validation set: Average loss: 0.0479
# Train: [0/5622 (0%)]	Loss: 0.083720
# Epoch: 8/10. Train set: Average loss: 0.0456
# Epoch: 8/10. Validation set: Average loss: 0.0425
# Train: [0/5622 (0%)]	Loss: 0.152536
# Epoch: 9/10. Train set: Average loss: 0.0406
# Epoch: 9/10. Validation set: Average loss: 0.0403
# Train: [0/5622 (0%)]	Loss: 0.063027
# Epoch: 10/10. Train set: Average loss: 0.0373
# Epoch: 10/10. Validation set: Average loss: 0.0389
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.249638
# Epoch: 1/10. Train set: Average loss: 0.0958
# Epoch: 1/10. Validation set: Average loss: 0.0854
# Train: [0/5622 (0%)]	Loss: 0.133115
# Epoch: 2/10. Train set: Average loss: 0.0722
# Epoch: 2/10. Validation set: Average loss: 0.0606
# Train: [0/5622 (0%)]	Loss: 0.039802
# Epoch: 3/10. Train set: Average loss: 0.0586
# Epoch: 3/10. Validation set: Average loss: 0.0568
# Train: [0/5622 (0%)]	Loss: 0.041909
# Epoch: 4/10. Train set: Average loss: 0.0547
# Epoch: 4/10. Validation set: Average loss: 0.0529
# Train: [0/5622 (0%)]	Loss: 0.017903
# Epoch: 5/10. Train set: Average loss: 0.0476
# Epoch: 5/10. Validation set: Average loss: 0.0479
# Train: [0/5622 (0%)]	Loss: 0.052866
# Epoch: 6/10. Train set: Average loss: 0.0483
# Epoch: 6/10. Validation set: Average loss: 0.0473
# Train: [0/5622 (0%)]	Loss: 0.059573
# Epoch: 7/10. Train set: Average loss: 0.0458
# Epoch: 7/10. Validation set: Average loss: 0.0441
# Train: [0/5622 (0%)]	Loss: 0.050054
# Epoch: 8/10. Train set: Average loss: 0.0408
# Epoch: 8/10. Validation set: Average loss: 0.0507
# Train: [0/5622 (0%)]	Loss: 0.017174
# Epoch: 9/10. Train set: Average loss: 0.0378
# Epoch: 9/10. Validation set: Average loss: 0.0374
# Train: [0/5622 (0%)]	Loss: 0.022404
# Epoch: 10/10. Train set: Average loss: 0.0357
# Epoch: 10/10. Validation set: Average loss: 0.0364
# Number features: 182
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.311944
# Epoch: 1/10. Train set: Average loss: 0.0697
# Epoch: 1/10. Validation set: Average loss: 0.0750
# Train: [0/5622 (0%)]	Loss: 0.142158
# Epoch: 2/10. Train set: Average loss: 0.0536
# Epoch: 2/10. Validation set: Average loss: 0.0619
# Train: [0/5622 (0%)]	Loss: 0.032490
# Epoch: 3/10. Train set: Average loss: 0.0547
# Epoch: 3/10. Validation set: Average loss: 0.0874
# Train: [0/5622 (0%)]	Loss: 0.107182
# Epoch: 4/10. Train set: Average loss: 0.0499
# Epoch: 4/10. Validation set: Average loss: 0.0471
# Train: [0/5622 (0%)]	Loss: 0.056126
# Epoch: 5/10. Train set: Average loss: 0.0448
# Epoch: 5/10. Validation set: Average loss: 0.0441
# Train: [0/5622 (0%)]	Loss: 0.070794
# Epoch: 6/10. Train set: Average loss: 0.0448
# Epoch: 6/10. Validation set: Average loss: 0.0449
# Train: [0/5622 (0%)]	Loss: 0.089336
# Epoch: 7/10. Train set: Average loss: 0.0434
# Epoch: 7/10. Validation set: Average loss: 0.0451
# Train: [0/5622 (0%)]	Loss: 0.060971
# Epoch: 8/10. Train set: Average loss: 0.0429
# Epoch: 8/10. Validation set: Average loss: 0.0476
# Train: [0/5622 (0%)]	Loss: 0.076533
# Epoch: 9/10. Train set: Average loss: 0.0357
# Epoch: 9/10. Validation set: Average loss: 0.0409
# Train: [0/5622 (0%)]	Loss: 0.030038
# Epoch: 10/10. Train set: Average loss: 0.0337
# Epoch: 10/10. Validation set: Average loss: 0.0399
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.311025
# Epoch: 1/10. Train set: Average loss: 0.0793
# Epoch: 1/10. Validation set: Average loss: 0.1147
# Train: [0/5622 (0%)]	Loss: 0.090222
# Epoch: 2/10. Train set: Average loss: 0.0613
# Epoch: 2/10. Validation set: Average loss: 0.0558
# Train: [0/5622 (0%)]	Loss: 0.064711
# Epoch: 3/10. Train set: Average loss: 0.0507
# Epoch: 3/10. Validation set: Average loss: 0.0653
# Train: [0/5622 (0%)]	Loss: 0.065700
# Epoch: 4/10. Train set: Average loss: 0.0531
# Epoch: 4/10. Validation set: Average loss: 0.2697
# Train: [0/5622 (0%)]	Loss: 0.075864
# Epoch: 5/10. Train set: Average loss: 0.0570
# Epoch: 5/10. Validation set: Average loss: 0.0548
# Train: [0/5622 (0%)]	Loss: 0.019185
# Epoch: 6/10. Train set: Average loss: 0.0437
# Epoch: 6/10. Validation set: Average loss: 0.0464
# Train: [0/5622 (0%)]	Loss: 0.110993
# Epoch: 7/10. Train set: Average loss: 0.0428
# Epoch: 7/10. Validation set: Average loss: 0.0448
# Train: [0/5622 (0%)]	Loss: 0.052456
# Epoch: 8/10. Train set: Average loss: 0.0421
# Epoch: 8/10. Validation set: Average loss: 0.0485
# Train: [0/5622 (0%)]	Loss: 0.029580
# Epoch: 9/10. Train set: Average loss: 0.0350
# Epoch: 9/10. Validation set: Average loss: 0.0401
# Train: [0/5622 (0%)]	Loss: 0.052152
# Epoch: 10/10. Train set: Average loss: 0.0328
# Epoch: 10/10. Validation set: Average loss: 0.0389
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.249002
# Epoch: 1/10. Train set: Average loss: 0.0773
# Epoch: 1/10. Validation set: Average loss: 0.0709
# Train: [0/5622 (0%)]	Loss: 0.107270
# Epoch: 2/10. Train set: Average loss: 0.0602
# Epoch: 2/10. Validation set: Average loss: 0.0627
# Train: [0/5622 (0%)]	Loss: 0.066497
# Epoch: 3/10. Train set: Average loss: 0.0563
# Epoch: 3/10. Validation set: Average loss: 0.0601
# Train: [0/5622 (0%)]	Loss: 0.099881
# Epoch: 4/10. Train set: Average loss: 0.0508
# Epoch: 4/10. Validation set: Average loss: 0.0559
# Train: [0/5622 (0%)]	Loss: 0.044862
# Epoch: 5/10. Train set: Average loss: 0.0529
# Epoch: 5/10. Validation set: Average loss: 0.0504
# Train: [0/5622 (0%)]	Loss: 0.051150
# Epoch: 6/10. Train set: Average loss: 0.0453
# Epoch: 6/10. Validation set: Average loss: 0.0629
# Train: [0/5622 (0%)]	Loss: 0.052259
# Epoch: 7/10. Train set: Average loss: 0.0534
# Epoch: 7/10. Validation set: Average loss: 0.0590
# Train: [0/5622 (0%)]	Loss: 0.056107
# Epoch: 8/10. Train set: Average loss: 0.0419
# Epoch: 8/10. Validation set: Average loss: 0.0570
# Train: [0/5622 (0%)]	Loss: 0.031665
# Epoch: 9/10. Train set: Average loss: 0.0355
# Epoch: 9/10. Validation set: Average loss: 0.0417
# Train: [0/5622 (0%)]	Loss: 0.030872
# Epoch: 10/10. Train set: Average loss: 0.0340
# Epoch: 10/10. Validation set: Average loss: 0.0402
# Number features: 202
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.124785
# Epoch: 1/10. Train set: Average loss: 0.0699
# Epoch: 1/10. Validation set: Average loss: 0.0500
# Train: [0/5622 (0%)]	Loss: 0.172158
# Epoch: 2/10. Train set: Average loss: 0.0679
# Epoch: 2/10. Validation set: Average loss: 0.0669
# Train: [0/5622 (0%)]	Loss: 0.055617
# Epoch: 3/10. Train set: Average loss: 0.0541
# Epoch: 3/10. Validation set: Average loss: 0.0478
# Train: [0/5622 (0%)]	Loss: 0.039596
# Epoch: 4/10. Train set: Average loss: 0.0487
# Epoch: 4/10. Validation set: Average loss: 0.0459
# Train: [0/5622 (0%)]	Loss: 0.058696
# Epoch: 5/10. Train set: Average loss: 0.0448
# Epoch: 5/10. Validation set: Average loss: 0.0449
# Train: [0/5622 (0%)]	Loss: 0.010185
# Epoch: 6/10. Train set: Average loss: 0.0412
# Epoch: 6/10. Validation set: Average loss: 0.0445
# Train: [0/5622 (0%)]	Loss: 0.017529
# Epoch: 7/10. Train set: Average loss: 0.0421
# Epoch: 7/10. Validation set: Average loss: 0.0428
# Train: [0/5622 (0%)]	Loss: 0.012124
# Epoch: 8/10. Train set: Average loss: 0.0410
# Epoch: 8/10. Validation set: Average loss: 0.0484
# Train: [0/5622 (0%)]	Loss: 0.024254
# Epoch: 9/10. Train set: Average loss: 0.0335
# Epoch: 9/10. Validation set: Average loss: 0.0349
# Train: [0/5622 (0%)]	Loss: 0.024740
# Epoch: 10/10. Train set: Average loss: 0.0335
# Epoch: 10/10. Validation set: Average loss: 0.0348
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.373440
# Epoch: 1/10. Train set: Average loss: 0.0727
# Epoch: 1/10. Validation set: Average loss: 0.0682
# Train: [0/5622 (0%)]	Loss: 0.079194
# Epoch: 2/10. Train set: Average loss: 0.0610
# Epoch: 2/10. Validation set: Average loss: 0.0715
# Train: [0/5622 (0%)]	Loss: 0.031866
# Epoch: 3/10. Train set: Average loss: 0.0553
# Epoch: 3/10. Validation set: Average loss: 0.0513
# Train: [0/5622 (0%)]	Loss: 0.026694
# Epoch: 4/10. Train set: Average loss: 0.0497
# Epoch: 4/10. Validation set: Average loss: 0.0494
# Train: [0/5622 (0%)]	Loss: 0.005845
# Epoch: 5/10. Train set: Average loss: 0.0427
# Epoch: 5/10. Validation set: Average loss: 0.0388
# Train: [0/5622 (0%)]	Loss: 0.016764
# Epoch: 6/10. Train set: Average loss: 0.0411
# Epoch: 6/10. Validation set: Average loss: 0.0478
# Train: [0/5622 (0%)]	Loss: 0.035132
# Epoch: 7/10. Train set: Average loss: 0.0423
# Epoch: 7/10. Validation set: Average loss: 0.0482
# Train: [0/5622 (0%)]	Loss: 0.062916
# Epoch: 8/10. Train set: Average loss: 0.0418
# Epoch: 8/10. Validation set: Average loss: 0.0479
# Train: [0/5622 (0%)]	Loss: 0.046028
# Epoch: 9/10. Train set: Average loss: 0.0339
# Epoch: 9/10. Validation set: Average loss: 0.0353
# Train: [0/5622 (0%)]	Loss: 0.001528
# Epoch: 10/10. Train set: Average loss: 0.0289
# Epoch: 10/10. Validation set: Average loss: 0.0342
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.249238
# Epoch: 1/10. Train set: Average loss: 0.0830
# Epoch: 1/10. Validation set: Average loss: 0.0872
# Train: [0/5622 (0%)]	Loss: 0.008145
# Epoch: 2/10. Train set: Average loss: 0.0762
# Epoch: 2/10. Validation set: Average loss: 0.0937
# Train: [0/5622 (0%)]	Loss: 0.084048
# Epoch: 3/10. Train set: Average loss: 0.0669
# Epoch: 3/10. Validation set: Average loss: 0.0598
# Train: [0/5622 (0%)]	Loss: 0.022650
# Epoch: 4/10. Train set: Average loss: 0.0497
# Epoch: 4/10. Validation set: Average loss: 0.0526
# Train: [0/5622 (0%)]	Loss: 0.047856
# Epoch: 5/10. Train set: Average loss: 0.0471
# Epoch: 5/10. Validation set: Average loss: 0.0497
# Train: [0/5622 (0%)]	Loss: 0.077090
# Epoch: 6/10. Train set: Average loss: 0.0436
# Epoch: 6/10. Validation set: Average loss: 0.0501
# Train: [0/5622 (0%)]	Loss: 0.008856
# Epoch: 7/10. Train set: Average loss: 0.0394
# Epoch: 7/10. Validation set: Average loss: 0.0505
# Train: [0/5622 (0%)]	Loss: 0.058526
# Epoch: 8/10. Train set: Average loss: 0.0381
# Epoch: 8/10. Validation set: Average loss: 0.0403
# Train: [0/5622 (0%)]	Loss: 0.035851
# Epoch: 9/10. Train set: Average loss: 0.0281
# Epoch: 9/10. Validation set: Average loss: 0.0368
# Train: [0/5622 (0%)]	Loss: 0.003760
# Epoch: 10/10. Train set: Average loss: 0.0294
# Epoch: 10/10. Validation set: Average loss: 0.0356
# Number features: 223
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.186547
# Epoch: 1/10. Train set: Average loss: 0.0853
# Epoch: 1/10. Validation set: Average loss: 0.0578
# Train: [0/5622 (0%)]	Loss: 0.034362
# Epoch: 2/10. Train set: Average loss: 0.0609
# Epoch: 2/10. Validation set: Average loss: 0.0544
# Train: [0/5622 (0%)]	Loss: 0.044792
# Epoch: 3/10. Train set: Average loss: 0.0584
# Epoch: 3/10. Validation set: Average loss: 0.0534
# Train: [0/5622 (0%)]	Loss: 0.046930
# Epoch: 4/10. Train set: Average loss: 0.0522
# Epoch: 4/10. Validation set: Average loss: 0.0462
# Train: [0/5622 (0%)]	Loss: 0.003655
# Epoch: 5/10. Train set: Average loss: 0.0509
# Epoch: 5/10. Validation set: Average loss: 0.0447
# Train: [0/5622 (0%)]	Loss: 0.029341
# Epoch: 6/10. Train set: Average loss: 0.0425
# Epoch: 6/10. Validation set: Average loss: 0.0429
# Train: [0/5622 (0%)]	Loss: 0.018696
# Epoch: 7/10. Train set: Average loss: 0.0429
# Epoch: 7/10. Validation set: Average loss: 0.0460
# Train: [0/5622 (0%)]	Loss: 0.074038
# Epoch: 8/10. Train set: Average loss: 0.0412
# Epoch: 8/10. Validation set: Average loss: 0.0404
# Train: [0/5622 (0%)]	Loss: 0.064684
# Epoch: 9/10. Train set: Average loss: 0.0354
# Epoch: 9/10. Validation set: Average loss: 0.0365
# Train: [0/5622 (0%)]	Loss: 0.070081
# Epoch: 10/10. Train set: Average loss: 0.0317
# Epoch: 10/10. Validation set: Average loss: 0.0347
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.248963
# Epoch: 1/10. Train set: Average loss: 0.0732
# Epoch: 1/10. Validation set: Average loss: 0.0593
# Train: [0/5622 (0%)]	Loss: 0.032639
# Epoch: 2/10. Train set: Average loss: 0.0574
# Epoch: 2/10. Validation set: Average loss: 0.0568
# Train: [0/5622 (0%)]	Loss: 0.045256
# Epoch: 3/10. Train set: Average loss: 0.0516
# Epoch: 3/10. Validation set: Average loss: 0.0503
# Train: [0/5622 (0%)]	Loss: 0.030659
# Epoch: 4/10. Train set: Average loss: 0.0491
# Epoch: 4/10. Validation set: Average loss: 0.0466
# Train: [0/5622 (0%)]	Loss: 0.036274
# Epoch: 5/10. Train set: Average loss: 0.0442
# Epoch: 5/10. Validation set: Average loss: 0.0426
# Train: [0/5622 (0%)]	Loss: 0.003565
# Epoch: 6/10. Train set: Average loss: 0.0403
# Epoch: 6/10. Validation set: Average loss: 0.0419
# Train: [0/5622 (0%)]	Loss: 0.014097
# Epoch: 7/10. Train set: Average loss: 0.0400
# Epoch: 7/10. Validation set: Average loss: 0.0385
# Train: [0/5622 (0%)]	Loss: 0.010742
# Epoch: 8/10. Train set: Average loss: 0.0382
# Epoch: 8/10. Validation set: Average loss: 0.0379
# Train: [0/5622 (0%)]	Loss: 0.007861
# Epoch: 9/10. Train set: Average loss: 0.0319
# Epoch: 9/10. Validation set: Average loss: 0.0329
# Train: [0/5622 (0%)]	Loss: 0.023188
# Epoch: 10/10. Train set: Average loss: 0.0309
# Epoch: 10/10. Validation set: Average loss: 0.0322
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.248724
# Epoch: 1/10. Train set: Average loss: 0.0728
# Epoch: 1/10. Validation set: Average loss: 0.0688
# Train: [0/5622 (0%)]	Loss: 0.046939
# Epoch: 2/10. Train set: Average loss: 0.0577
# Epoch: 2/10. Validation set: Average loss: 0.0518
# Train: [0/5622 (0%)]	Loss: 0.070516
# Epoch: 3/10. Train set: Average loss: 0.0491
# Epoch: 3/10. Validation set: Average loss: 0.0486
# Train: [0/5622 (0%)]	Loss: 0.029506
# Epoch: 4/10. Train set: Average loss: 0.0478
# Epoch: 4/10. Validation set: Average loss: 0.0455
# Train: [0/5622 (0%)]	Loss: 0.027975
# Epoch: 5/10. Train set: Average loss: 0.0460
# Epoch: 5/10. Validation set: Average loss: 0.0467
# Train: [0/5622 (0%)]	Loss: 0.094038
# Epoch: 6/10. Train set: Average loss: 0.0493
# Epoch: 6/10. Validation set: Average loss: 0.0599
# Train: [0/5622 (0%)]	Loss: 0.123054
# Epoch: 7/10. Train set: Average loss: 0.0423
# Epoch: 7/10. Validation set: Average loss: 0.0470
# Train: [0/5622 (0%)]	Loss: 0.020544
# Epoch: 8/10. Train set: Average loss: 0.0391
# Epoch: 8/10. Validation set: Average loss: 0.0338
# Train: [0/5622 (0%)]	Loss: 0.023704
# Epoch: 9/10. Train set: Average loss: 0.0315
# Epoch: 9/10. Validation set: Average loss: 0.0312
# Train: [0/5622 (0%)]	Loss: 0.062925
# Epoch: 10/10. Train set: Average loss: 0.0300
# Epoch: 10/10. Validation set: Average loss: 0.0309
# Number features: 243
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.311995
# Epoch: 1/10. Train set: Average loss: 0.0766
# Epoch: 1/10. Validation set: Average loss: 0.0636
# Train: [0/5622 (0%)]	Loss: 0.036483
# Epoch: 2/10. Train set: Average loss: 0.0599
# Epoch: 2/10. Validation set: Average loss: 0.0659
# Train: [0/5622 (0%)]	Loss: 0.076967
# Epoch: 3/10. Train set: Average loss: 0.0495
# Epoch: 3/10. Validation set: Average loss: 0.0515
# Train: [0/5622 (0%)]	Loss: 0.098362
# Epoch: 4/10. Train set: Average loss: 0.0469
# Epoch: 4/10. Validation set: Average loss: 0.0680
# Train: [0/5622 (0%)]	Loss: 0.122573
# Epoch: 5/10. Train set: Average loss: 0.0469
# Epoch: 5/10. Validation set: Average loss: 0.0511
# ...
# Train: [0/5622 (0%)]	Loss: 0.005961
# Epoch: 9/10. Train set: Average loss: 0.0308
# Epoch: 9/10. Validation set: Average loss: 0.0371
# Train: [0/5622 (0%)]	Loss: 0.011252
# Epoch: 10/10. Train set: Average loss: 0.0288
# Epoch: 10/10. Validation set: Average loss: 0.0364
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.374372
# Epoch: 1/10. Train set: Average loss: 0.0673
# Epoch: 1/10. Validation set: Average loss: 0.0588
# Train: [0/5622 (0%)]	Loss: 0.021153
# Epoch: 2/10. Train set: Average loss: 0.0574
# Epoch: 2/10. Validation set: Average loss: 0.0519
# Train: [0/5622 (0%)]	Loss: 0.086529
# Epoch: 3/10. Train set: Average loss: 0.0479
# Epoch: 3/10. Validation set: Average loss: 0.0498
# Train: [0/5622 (0%)]	Loss: 0.013541
# Epoch: 4/10. Train set: Average loss: 0.0470
# Epoch: 4/10. Validation set: Average loss: 0.0501
# Train: [0/5622 (0%)]	Loss: 0.049973
# Epoch: 5/10. Train set: Average loss: 0.0435
# Epoch: 5/10. Validation set: Average loss: 0.0475
# Train: [0/5622 (0%)]	Loss: 0.075784
# Epoch: 6/10. Train set: Average loss: 0.0368
# Epoch: 6/10. Validation set: Average loss: 0.0434
# Train: [0/5622 (0%)]	Loss: 0.013576
# Epoch: 7/10. Train set: Average loss: 0.0413
# Epoch: 7/10. Validation set: Average loss: 0.0481
# Train: [0/5622 (0%)]	Loss: 0.023954
# Epoch: 8/10. Train set: Average loss: 0.0339
# Epoch: 8/10. Validation set: Average loss: 0.0412
# Train: [0/5622 (0%)]	Loss: 0.020414
# Epoch: 9/10. Train set: Average loss: 0.0284
# Epoch: 9/10. Validation set: Average loss: 0.0345
# Train: [0/5622 (0%)]	Loss: 0.030063
# Epoch: 10/10. Train set: Average loss: 0.0276
# Epoch: 10/10. Validation set: Average loss: 0.0340
# Number features: 344
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.124706
# Epoch: 1/10. Train set: Average loss: 0.0742
# Epoch: 1/10. Validation set: Average loss: 0.0608
# Train: [0/5622 (0%)]	Loss: 0.061762
# Epoch: 2/10. Train set: Average loss: 0.0540
# Epoch: 2/10. Validation set: Average loss: 0.0692
# Train: [0/5622 (0%)]	Loss: 0.018083
# Epoch: 3/10. Train set: Average loss: 0.0546
# Epoch: 3/10. Validation set: Average loss: 0.0492
# Train: [0/5622 (0%)]	Loss: 0.020657
# Epoch: 4/10. Train set: Average loss: 0.0455
# Epoch: 4/10. Validation set: Average loss: 0.0489
# Train: [0/5622 (0%)]	Loss: 0.028637
# Epoch: 5/10. Train set: Average loss: 0.0441
# Epoch: 5/10. Validation set: Average loss: 0.0533
# Train: [0/5622 (0%)]	Loss: 0.022301
# Epoch: 6/10. Train set: Average loss: 0.0413
# Epoch: 6/10. Validation set: Average loss: 0.0584
# Train: [0/5622 (0%)]	Loss: 0.044033
# Epoch: 7/10. Train set: Average loss: 0.0443
# Epoch: 7/10. Validation set: Average loss: 0.0418
# Train: [0/5622 (0%)]	Loss: 0.048528
# Epoch: 8/10. Train set: Average loss: 0.0400
# Epoch: 8/10. Validation set: Average loss: 0.0441
# Train: [0/5622 (0%)]	Loss: 0.023521
# Epoch: 9/10. Train set: Average loss: 0.0348
# Epoch: 9/10. Validation set: Average loss: 0.0382
# Train: [0/5622 (0%)]	Loss: 0.020014
# Epoch: 10/10. Train set: Average loss: 0.0331
# Epoch: 10/10. Validation set: Average loss: 0.0366
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.249770
# Epoch: 1/10. Train set: Average loss: 0.0659
# Epoch: 1/10. Validation set: Average loss: 0.0572
# Train: [0/5622 (0%)]	Loss: 0.023046
# Epoch: 2/10. Train set: Average loss: 0.0478
# Epoch: 2/10. Validation set: Average loss: 0.0484
# Train: [0/5622 (0%)]	Loss: 0.032009
# Epoch: 3/10. Train set: Average loss: 0.0454
# Epoch: 3/10. Validation set: Average loss: 0.0528
# Train: [0/5622 (0%)]	Loss: 0.029999
# Epoch: 4/10. Train set: Average loss: 0.0436
# Epoch: 4/10. Validation set: Average loss: 0.0461
# Train: [0/5622 (0%)]	Loss: 0.018177
# Epoch: 5/10. Train set: Average loss: 0.0480
# Epoch: 5/10. Validation set: Average loss: 0.0564
# Train: [0/5622 (0%)]	Loss: 0.070651
# Epoch: 6/10. Train set: Average loss: 0.0415
# Epoch: 6/10. Validation set: Average loss: 0.0585
# Train: [0/5622 (0%)]	Loss: 0.049478
# Epoch: 7/10. Train set: Average loss: 0.0398
# Epoch: 7/10. Validation set: Average loss: 0.0483
# Train: [0/5622 (0%)]	Loss: 0.033107
# Epoch: 8/10. Train set: Average loss: 0.0400
# Epoch: 8/10. Validation set: Average loss: 0.0384
# Train: [0/5622 (0%)]	Loss: 0.085703
# Epoch: 9/10. Train set: Average loss: 0.0329
# Epoch: 9/10. Validation set: Average loss: 0.0350
# Train: [0/5622 (0%)]	Loss: 0.057211
# Epoch: 10/10. Train set: Average loss: 0.0313
# Epoch: 10/10. Validation set: Average loss: 0.0339
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.186707
# Epoch: 1/10. Train set: Average loss: 0.0844
# Epoch: 1/10. Validation set: Average loss: 0.0798
# Train: [0/5622 (0%)]	Loss: 0.105819
# Epoch: 2/10. Train set: Average loss: 0.0650
# Epoch: 2/10. Validation set: Average loss: 0.0691
# Train: [0/5622 (0%)]	Loss: 0.073224
# Epoch: 3/10. Train set: Average loss: 0.0487
# Epoch: 3/10. Validation set: Average loss: 0.0547
# Train: [0/5622 (0%)]	Loss: 0.068471
# Epoch: 4/10. Train set: Average loss: 0.0449
# Epoch: 4/10. Validation set: Average loss: 0.0490
# Train: [0/5622 (0%)]	Loss: 0.062683
# Epoch: 5/10. Train set: Average loss: 0.0464
# Epoch: 5/10. Validation set: Average loss: 0.0460
# Train: [0/5622 (0%)]	Loss: 0.076815
# Epoch: 6/10. Train set: Average loss: 0.0448
# Epoch: 6/10. Validation set: Average loss: 0.0445
# Train: [0/5622 (0%)]	Loss: 0.064876
# Epoch: 7/10. Train set: Average loss: 0.0456
# Epoch: 7/10. Validation set: Average loss: 0.0471
# Train: [0/5622 (0%)]	Loss: 0.022306
# Epoch: 8/10. Train set: Average loss: 0.0415
# Epoch: 8/10. Validation set: Average loss: 0.0436
# Train: [0/5622 (0%)]	Loss: 0.040529
# Epoch: 9/10. Train set: Average loss: 0.0355
# Epoch: 9/10. Validation set: Average loss: 0.0384
# Train: [0/5622 (0%)]	Loss: 0.016417
# Epoch: 10/10. Train set: Average loss: 0.0344
# Epoch: 10/10. Validation set: Average loss: 0.0381
# Number features: 364
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.124633
# Epoch: 1/10. Train set: Average loss: 0.0712
# Epoch: 1/10. Validation set: Average loss: 0.0545
# Train: [0/5622 (0%)]	Loss: 0.068422
# Epoch: 2/10. Train set: Average loss: 0.0591
# Epoch: 2/10. Validation set: Average loss: 0.0470
# Train: [0/5622 (0%)]	Loss: 0.041027
# Epoch: 3/10. Train set: Average loss: 0.0465
# Epoch: 3/10. Validation set: Average loss: 0.0476
# Train: [0/5622 (0%)]	Loss: 0.071058
# Epoch: 4/10. Train set: Average loss: 0.0495
# Epoch: 4/10. Validation set: Average loss: 0.1986
# Train: [0/5622 (0%)]	Loss: 0.181098
# Epoch: 5/10. Train set: Average loss: 0.0498
# Epoch: 5/10. Validation set: Average loss: 0.0456
# Train: [0/5622 (0%)]	Loss: 0.084512
# Epoch: 6/10. Train set: Average loss: 0.0431
# Epoch: 6/10. Validation set: Average loss: 0.0412
# Train: [0/5622 (0%)]	Loss: 0.037136
# Epoch: 7/10. Train set: Average loss: 0.0389
# Epoch: 7/10. Validation set: Average loss: 0.0407
# Train: [0/5622 (0%)]	Loss: 0.015707
# Epoch: 8/10. Train set: Average loss: 0.0409
# Epoch: 8/10. Validation set: Average loss: 0.0410
# Train: [0/5622 (0%)]	Loss: 0.008143
# Epoch: 9/10. Train set: Average loss: 0.0330
# Epoch: 9/10. Validation set: Average loss: 0.0335
# Train: [0/5622 (0%)]	Loss: 0.009450
# Epoch: 10/10. Train set: Average loss: 0.0291
# Epoch: 10/10. Validation set: Average loss: 0.0321
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.249406
# Epoch: 1/10. Train set: Average loss: 0.0849
# Epoch: 1/10. Validation set: Average loss: 0.0814
# Train: [0/5622 (0%)]	Loss: 0.082749
# Epoch: 2/10. Train set: Average loss: 0.0598
# Epoch: 2/10. Validation set: Average loss: 0.0663
# Train: [0/5622 (0%)]	Loss: 0.006252
# Epoch: 3/10. Train set: Average loss: 0.0473
# Epoch: 3/10. Validation set: Average loss: 0.0541
# Train: [0/5622 (0%)]	Loss: 0.100668
# Epoch: 4/10. Train set: Average loss: 0.0417
# Epoch: 4/10. Validation set: Average loss: 0.0489
# Train: [0/5622 (0%)]	Loss: 0.057714
# Epoch: 5/10. Train set: Average loss: 0.0408
# Epoch: 5/10. Validation set: Average loss: 0.0496
# Train: [0/5622 (0%)]	Loss: 0.009663
# Epoch: 6/10. Train set: Average loss: 0.0380
# Epoch: 6/10. Validation set: Average loss: 0.0508
# Train: [0/5622 (0%)]	Loss: 0.007274
# Epoch: 7/10. Train set: Average loss: 0.0418
# Epoch: 7/10. Validation set: Average loss: 0.0593
# Train: [0/5622 (0%)]	Loss: 0.047281
# Epoch: 8/10. Train set: Average loss: 0.0422
# Epoch: 8/10. Validation set: Average loss: 0.0458
# Train: [0/5622 (0%)]	Loss: 0.008507
# Epoch: 9/10. Train set: Average loss: 0.0322
# Epoch: 9/10. Validation set: Average loss: 0.0353
# Train: [0/5622 (0%)]	Loss: 0.039454
# Epoch: 10/10. Train set: Average loss: 0.0299
# Epoch: 10/10. Validation set: Average loss: 0.0344
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.249236
# Epoch: 1/10. Train set: Average loss: 0.0619
# Epoch: 1/10. Validation set: Average loss: 0.0741
# Train: [0/5622 (0%)]	Loss: 0.055345
# Epoch: 2/10. Train set: Average loss: 0.0591
# Epoch: 2/10. Validation set: Average loss: 0.0626
# Train: [0/5622 (0%)]	Loss: 0.030014
# Epoch: 3/10. Train set: Average loss: 0.0521
# Epoch: 3/10. Validation set: Average loss: 0.0621
# Train: [0/5622 (0%)]	Loss: 0.035418
# Epoch: 4/10. Train set: Average loss: 0.0501
# Epoch: 4/10. Validation set: Average loss: 0.0513
# Train: [0/5622 (0%)]	Loss: 0.055760
# Epoch: 5/10. Train set: Average loss: 0.0443
# Epoch: 5/10. Validation set: Average loss: 0.0566
# Train: [0/5622 (0%)]	Loss: 0.018199
# Epoch: 6/10. Train set: Average loss: 0.0389
# Epoch: 6/10. Validation set: Average loss: 0.0514
# Train: [0/5622 (0%)]	Loss: 0.022892
# Epoch: 7/10. Train set: Average loss: 0.0415
# Epoch: 7/10. Validation set: Average loss: 0.0400
# Train: [0/5622 (0%)]	Loss: 0.032872
# Epoch: 8/10. Train set: Average loss: 0.0386
# Epoch: 8/10. Validation set: Average loss: 0.0373
# Train: [0/5622 (0%)]	Loss: 0.086594
# Epoch: 9/10. Train set: Average loss: 0.0292
# Epoch: 9/10. Validation set: Average loss: 0.0307
# Train: [0/5622 (0%)]	Loss: 0.015301
# Epoch: 10/10. Train set: Average loss: 0.0261
# Epoch: 10/10. Validation set: Average loss: 0.0298
# Number features: 384
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.124638
# Epoch: 1/10. Train set: Average loss: 0.0897
# Epoch: 1/10. Validation set: Average loss: 0.0804
# Train: [0/5622 (0%)]	Loss: 0.042841
# Epoch: 2/10. Train set: Average loss: 0.0585
# Epoch: 2/10. Validation set: Average loss: 0.0571
# Train: [0/5622 (0%)]	Loss: 0.030068
# Epoch: 3/10. Train set: Average loss: 0.0483
# Epoch: 3/10. Validation set: Average loss: 0.0536
# Train: [0/5622 (0%)]	Loss: 0.021687
# Epoch: 4/10. Train set: Average loss: 0.0460
# Epoch: 4/10. Validation set: Average loss: 0.0481
# Train: [0/5622 (0%)]	Loss: 0.055492
# Epoch: 5/10. Train set: Average loss: 0.0466
# Epoch: 5/10. Validation set: Average loss: 0.0455
# Train: [0/5622 (0%)]	Loss: 0.013758
# Epoch: 6/10. Train set: Average loss: 0.0412
# Epoch: 6/10. Validation set: Average loss: 0.0477
# Train: [0/5622 (0%)]	Loss: 0.040082
# Epoch: 7/10. Train set: Average loss: 0.0413
# Epoch: 7/10. Validation set: Average loss: 0.0451
# Train: [0/5622 (0%)]	Loss: 0.017425
# Epoch: 8/10. Train set: Average loss: 0.0411
# Epoch: 8/10. Validation set: Average loss: 0.0487
# Train: [0/5622 (0%)]	Loss: 0.014769
# Epoch: 9/10. Train set: Average loss: 0.0359
# Epoch: 9/10. Validation set: Average loss: 0.0420
# Train: [0/5622 (0%)]	Loss: 0.023360
# Epoch: 10/10. Train set: Average loss: 0.0359
# Epoch: 10/10. Validation set: Average loss: 0.0403
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.311807
# Epoch: 1/10. Train set: Average loss: 0.0736
# Epoch: 1/10. Validation set: Average loss: 0.0767
# Train: [0/5622 (0%)]	Loss: 0.153646
# Epoch: 2/10. Train set: Average loss: 0.0533
# Epoch: 2/10. Validation set: Average loss: 0.0693
# Train: [0/5622 (0%)]	Loss: 0.017788
# Epoch: 3/10. Train set: Average loss: 0.0502
# Epoch: 3/10. Validation set: Average loss: 0.0735
# Train: [0/5622 (0%)]	Loss: 0.033824
# Epoch: 4/10. Train set: Average loss: 0.0441
# Epoch: 4/10. Validation set: Average loss: 0.0577
# Train: [0/5622 (0%)]	Loss: 0.078180
# Epoch: 5/10. Train set: Average loss: 0.0442
# Epoch: 5/10. Validation set: Average loss: 0.0563
# Train: [0/5622 (0%)]	Loss: 0.004005
# Epoch: 6/10. Train set: Average loss: 0.0401
# Epoch: 6/10. Validation set: Average loss: 0.0572
# Train: [0/5622 (0%)]	Loss: 0.027795
# Epoch: 7/10. Train set: Average loss: 0.0359
# Epoch: 7/10. Validation set: Average loss: 0.0438
# Train: [0/5622 (0%)]	Loss: 0.016443
# Epoch: 8/10. Train set: Average loss: 0.0386
# Epoch: 8/10. Validation set: Average loss: 0.0478
# Train: [0/5622 (0%)]	Loss: 0.018630
# Epoch: 9/10. Train set: Average loss: 0.0357
# Epoch: 9/10. Validation set: Average loss: 0.0421
# Train: [0/5622 (0%)]	Loss: 0.024762
# Epoch: 10/10. Train set: Average loss: 0.0303
# Epoch: 10/10. Validation set: Average loss: 0.0407
# 	model_2
# Train: [0/5622 (0%)]	Loss: 0.187233
# Epoch: 1/10. Train set: Average loss: 0.0639
# Epoch: 1/10. Validation set: Average loss: 0.0699
# Train: [0/5622 (0%)]	Loss: 0.128788
# Epoch: 2/10. Train set: Average loss: 0.0518
# Epoch: 2/10. Validation set: Average loss: 0.0689
# Train: [0/5622 (0%)]	Loss: 0.045712
# Epoch: 3/10. Train set: Average loss: 0.0501
# Epoch: 3/10. Validation set: Average loss: 0.0664
# Train: [0/5622 (0%)]	Loss: 0.036189
# Epoch: 4/10. Train set: Average loss: 0.0464
# Epoch: 4/10. Validation set: Average loss: 0.0526
# Train: [0/5622 (0%)]	Loss: 0.063695
# Epoch: 5/10. Train set: Average loss: 0.0517
# Epoch: 5/10. Validation set: Average loss: 0.0488
# Train: [0/5622 (0%)]	Loss: 0.026116
# Epoch: 6/10. Train set: Average loss: 0.0452
# Epoch: 6/10. Validation set: Average loss: 0.0460
# Train: [0/5622 (0%)]	Loss: 0.056168
# Epoch: 7/10. Train set: Average loss: 0.0447
# Epoch: 7/10. Validation set: Average loss: 0.0474
# Train: [0/5622 (0%)]	Loss: 0.026987
# Epoch: 8/10. Train set: Average loss: 0.0427
# Epoch: 8/10. Validation set: Average loss: 0.0472
# Train: [0/5622 (0%)]	Loss: 0.072913
# Epoch: 9/10. Train set: Average loss: 0.0386
# Epoch: 9/10. Validation set: Average loss: 0.0429
# Train: [0/5622 (0%)]	Loss: 0.123776
# Epoch: 10/10. Train set: Average loss: 0.0368
# Epoch: 10/10. Validation set: Average loss: 0.0429
# Number features: 404
#
# 	model_0
# Train: [0/5622 (0%)]	Loss: 0.124577
# Epoch: 1/10. Train set: Average loss: 0.0675
# Epoch: 1/10. Validation set: Average loss: 0.0550
# Train: [0/5622 (0%)]	Loss: 0.018498
# Epoch: 2/10. Train set: Average loss: 0.0620
# Epoch: 2/10. Validation set: Average loss: 0.0493
# Train: [0/5622 (0%)]	Loss: 0.070027
# Epoch: 3/10. Train set: Average loss: 0.0443
# Epoch: 3/10. Validation set: Average loss: 0.0425
# Train: [0/5622 (0%)]	Loss: 0.013725
# Epoch: 4/10. Train set: Average loss: 0.0446
# Epoch: 4/10. Validation set: Average loss: 0.0472
# Train: [0/5622 (0%)]	Loss: 0.027163
# Epoch: 5/10. Train set: Average loss: 0.0437
# Epoch: 5/10. Validation set: Average loss: 0.0457
# Train: [0/5622 (0%)]	Loss: 0.021256
# Epoch: 6/10. Train set: Average loss: 0.0421
# Epoch: 6/10. Validation set: Average loss: 0.0373
# Train: [0/5622 (0%)]	Loss: 0.021633
# Epoch: 7/10. Train set: Average loss: 0.0403
# Epoch: 7/10. Validation set: Average loss: 0.0405
# Train: [0/5622 (0%)]	Loss: 0.028537
# Epoch: 8/10. Train set: Average loss: 0.0362
# Epoch: 8/10. Validation set: Average loss: 0.0412
# Train: [0/5622 (0%)]	Loss: 0.022056
# Epoch: 9/10. Train set: Average loss: 0.0338
# Epoch: 9/10. Validation set: Average loss: 0.0351
# Train: [0/5622 (0%)]	Loss: 0.043731
# Epoch: 10/10. Train set: Average loss: 0.0327
# Epoch: 10/10. Validation set: Average loss: 0.0344
# 	model_1
# Train: [0/5622 (0%)]	Loss: 0.124338
# Epoch: 1/10. Train set: Average loss: 0.0683
# Epoch: 1/10. Validation set: Average loss: 0.0597
# Train: [0/5622 (0%)]	Loss: 0.012325
# Epoch: 2/10. Train set: Average loss: 0.0589
# Epoch: 2/10. Validation set: Average loss: 0.0610
# Train: [0/5622 (0%)]	Loss: 0.033354
# Epoch: 3/10. Train set: Average loss: 0.0556
# Epoch: 3/10. Validation set: Average loss: 0.0434
# Train: [0/5622 (0%)]	Loss: 0.042148
# Epoch: 4/10. Train set: Average loss: 0.0452
# Epoch: 4/10. Validation set: Average loss: 0.0426
# Train: [0/5622 (0%)]	Loss: 0.071398
# Epoch: 5/10. Train set: Average loss: 0.0466
# Epoch: 5/10. Validation set: Average loss: 0.0432
# Train: [0/5622 (0%)]	Loss: 0.067898
# Epoch: 6/10. Train set: Average loss: 0.0442
# Epoch: 6/10. Validation set: Average loss: 0.0399
# Train: [0/5622 (0%)]	Loss: 0.038244
# Epoch: 7/10. Train set: Average loss: 0.0409
# Epoch: 7/10. Validation set: Average loss: 0.0392
# Train: [0/5622 (0%)]	Loss: 0.044312
# Epoch: 8/10. Train set: Average loss: 0.0429
# Epoch: 8/10. Validation set: Average loss: 0.0401
# Train: [0/5622 (0%)]	Loss: 0.037506
