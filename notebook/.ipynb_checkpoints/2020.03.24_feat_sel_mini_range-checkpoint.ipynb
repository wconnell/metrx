# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

from collections import OrderedDict 

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 100)

# viz
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(12.7,10.27)})

# notebook settings
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable
#torch.manual_seed(123)

from dutils import Experiment
from trainer import fit
import visualization as vis
from tcga_datasets import SiameseDataset
import numpy as np
cuda = torch.cuda.is_available()
print("Cuda is available: {}".format(cuda))

# Models
from tcga_networks import EmbeddingNet, SiameseNet
from losses import ContrastiveLoss
# Out:
# Cuda is available: True

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score as ANMI

# %%
def getTCGA(disease):
    path = "/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP/TCGA/TCGA_{}_counts.tsv.gz"
    files = [path.format(d) for d in disease]
    return files


def readGCP(files, biotype='protein_coding', mean=True):
    """
    Paths to count matrices.
    """
    data_dict = {}
    for f in files:
        key = os.path.basename(f).split("_")[1]
        data = pd.read_csv(f, sep='\t', index_col=0)
        # transcript metadata
        meta = pd.DataFrame([row[:-1] for row in data.index.str.split("|")],
                            columns=['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'GENE', 'BP', 'BIOTYPE'])
        meta = pd.MultiIndex.from_frame(meta)
        data.index = meta
        # subset transcripts
        data = data.xs(key=biotype, level='BIOTYPE')
        data = data.droplevel(['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'BP'])
        # average gene expression of splice variants
        data = data.T
        if mean:
            data = data.groupby(by=data.columns, axis=1).mean()
        data_dict[key] = data
    return data_dict


def uq_norm(df, q=0.75):
    """
    Upper quartile normalization of GEX for samples.
    """
    quantiles = df.quantile(q=q, axis=1)
    norm = df.divide(quantiles, axis=0)
    return norm

# %%
def generate_fsets(data, n, steps=5):
    r = np.linspace(start=1, stop=n, num=steps, dtype='int')
    idx = [np.random.randint(low=1, high=data.shape[1], size=i) for i in r]
    return idx

# %%
def process_data():
    base = "/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP"
    disease = ['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']

    tcga_files = getTCGA(disease)
    tcga_meta = pd.read_csv(os.path.join(base, "TCGA/TCGA_GDC_ID_MAP.tsv"), sep="\t")
    tcga_raw = readGCP(tcga_files, mean=True)
    # combine samples
    tcga_raw = pd.concat(tcga_raw.values())
    # Upper quartile normalization
    tcga_raw = uq_norm(tcga_raw)
    # log norm
    tcga = tcga_raw.transform(np.log1p)
    return tcga, tcga_meta

# %%
import datetime
import pathlib

# %% [markdown]
# ### Setup

# %%
tcga, tcga_meta = process_data()

# %%
n_features = 300
steps = 60
feature_idx = generate_fsets(tcga, n=n_features, steps=steps)

# %%
hierarchy = OrderedDict({'Disease':['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM'],
                         'Sample Type':['Primary Tumor', 'Solid Tissue Normal']})

# %%
# Define experiment
exp = Experiment(meta_data=tcga_meta,
                 hierarchy=hierarchy,
                 index='CGHubAnalysisID',
                 cases='Case ID',
                 min_samples=20)
# Train / Test split
exp.train_test_split(cases='Case ID')
# Return data 
train_data, train_labels = exp.get_data(tcga, subset="train", dtype=np.float32)
test_data, test_labels = exp.get_data(tcga, subset="test", dtype=np.float32)

# %%
# Path
dtime = datetime.datetime.today().strftime("%Y.%m.%d_%H:%M")
exp_dir = "/srv/nas/mk2/projects/pan-cancer/experiments/{}_{}_{}-{}".format(dtime, len(exp.labels_dict), n_features, steps)
pathlib.Path(exp_dir).mkdir(parents=True, exist_ok=False)

# %%
experiments = {'experiment': exp,
               'train':(train_data, train_labels),
               'test': (test_data, test_labels)}
pd.to_pickle(experiments, os.path.join(exp_dir, "experiment_meta_data.pkl"))

# %% [markdown]
# ### Network

# %%
def feature_training(train_data, train_labels, test_data, test_labels, feature_idx, exp_dir, cuda=True):
    # Meta data
    meta_data = {"n_features":[],
                 "model":[],
                 "ANMI":[]}
    # Params
    batch_size = 8
    kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {'num_workers': 10}
    
    # Feature Index
    for batch, feat in enumerate(feature_idx):
        print("Number features: {}\n".format(len(feat)))
        exp_data = {'feature_idx':feat}
        # Define data
        siamese_train_dataset = SiameseDataset(data=train_data.iloc[:,feat],
                                           labels=train_labels,
                                           train=True)
        siamese_test_dataset = SiameseDataset(data=test_data.iloc[:,feat],
                                          labels=test_labels,
                                          train=False)
        # Loaders
        siamese_train_loader = torch.utils.data.DataLoader(siamese_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
        siamese_test_loader = torch.utils.data.DataLoader(siamese_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)
        # Instantiate model
        n_samples, n_features = siamese_train_dataset.train_data.shape
        for i in range(3):
            nmodel = 'model_{}'.format(i)
            print("\t{}".format(nmodel))
            embedding_net = EmbeddingNet(n_features, 2)
            model = SiameseNet(embedding_net)
            if cuda:
                model.cuda()
            # Parameters
            margin = 1.
            loss_fn = ContrastiveLoss(margin)
            lr = 1e-3
            optimizer = optim.Adam(model.parameters(), lr=lr)
            scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
            n_epochs = 10
            log_interval = round(len(siamese_train_dataset)/1/batch_size)
            # Train
            train_loss, val_loss = fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, 
                                       n_epochs, cuda, log_interval)
            # Test Embeddings
            val_embeddings_baseline, val_labels_baseline = vis.extract_embeddings(siamese_test_dataset.test_data, siamese_test_dataset.labels, model)
            # Evaluation
            n_clusters = len(np.unique(test_labels))
            kmeans = KMeans(n_clusters=n_clusters)
            siamese_clusters = kmeans.fit_predict(val_embeddings_baseline)
            anmi = ANMI(siamese_clusters, val_labels_baseline)
            # Store
            meta_data['n_features'].append(len(feat))
            meta_data['model'].append(nmodel)
            meta_data['ANMI'].append(anmi)
            exp_data[nmodel] = {'data': (val_embeddings_baseline, val_labels_baseline),
                                'loss': (train_loss, val_loss),
                                'ANMI': anmi}
        pd.to_pickle(exp_data, os.path.join(exp_dir, "model_{}.pkl".format(len(feat))))
    pd.to_pickle(meta_data, os.path.join(exp_dir, "model_meta_data.pkl"))

# %%
feature_training(train_data, train_labels, test_data, test_labels, feature_idx, exp_dir)
# Out:
# Batch 0
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187258
# Train: [1098/2931 (100%)]	Loss: 0.147975
# Epoch: 1/10. Train set: Average loss: 0.1481
# Epoch: 1/10. Validation set: Average loss: 0.1453
# Train: [0/2931 (0%)]	Loss: 0.067953
# Train: [1098/2931 (100%)]	Loss: 0.138040
# Epoch: 2/10. Train set: Average loss: 0.1378
# Epoch: 2/10. Validation set: Average loss: 0.1450
# Train: [0/2931 (0%)]	Loss: 0.059779
# Train: [1098/2931 (100%)]	Loss: 0.141913
# Epoch: 3/10. Train set: Average loss: 0.1417
# Epoch: 3/10. Validation set: Average loss: 0.1457
# Train: [0/2931 (0%)]	Loss: 0.215458
# Train: [1098/2931 (100%)]	Loss: 0.139657
# Epoch: 4/10. Train set: Average loss: 0.1399
# Epoch: 4/10. Validation set: Average loss: 0.1542
# Train: [0/2931 (0%)]	Loss: 0.129223
# Train: [1098/2931 (100%)]	Loss: 0.140416
# Epoch: 5/10. Train set: Average loss: 0.1404
# Epoch: 5/10. Validation set: Average loss: 0.1535
# Train: [0/2931 (0%)]	Loss: 0.208968
# Train: [1098/2931 (100%)]	Loss: 0.145198
# Epoch: 6/10. Train set: Average loss: 0.1454
# Epoch: 6/10. Validation set: Average loss: 0.1545
# Train: [0/2931 (0%)]	Loss: 0.141262
# Train: [1098/2931 (100%)]	Loss: 0.142927
# Epoch: 7/10. Train set: Average loss: 0.1429
# Epoch: 7/10. Validation set: Average loss: 0.1580
# Train: [0/2931 (0%)]	Loss: 0.163689
# Train: [1098/2931 (100%)]	Loss: 0.140268
# Epoch: 8/10. Train set: Average loss: 0.1403
# Epoch: 8/10. Validation set: Average loss: 0.1500
# Train: [0/2931 (0%)]	Loss: 0.199330
# Train: [1098/2931 (100%)]	Loss: 0.135420
# Epoch: 9/10. Train set: Average loss: 0.1356
# Epoch: 9/10. Validation set: Average loss: 0.1417
# Train: [0/2931 (0%)]	Loss: 0.135909
# Train: [1098/2931 (100%)]	Loss: 0.136691
# Epoch: 10/10. Train set: Average loss: 0.1367
# Epoch: 10/10. Validation set: Average loss: 0.1416
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.184075
# Train: [1098/2931 (100%)]	Loss: 0.138883
# Epoch: 1/10. Train set: Average loss: 0.1390
# Epoch: 1/10. Validation set: Average loss: 0.1453
# Train: [0/2931 (0%)]	Loss: 0.196935
# Train: [1098/2931 (100%)]	Loss: 0.148214
# Epoch: 2/10. Train set: Average loss: 0.1483
# Epoch: 2/10. Validation set: Average loss: 0.1425
# Train: [0/2931 (0%)]	Loss: 0.064455
# Train: [1098/2931 (100%)]	Loss: 0.141974
# Epoch: 3/10. Train set: Average loss: 0.1418
# Epoch: 3/10. Validation set: Average loss: 0.1419
# Train: [0/2931 (0%)]	Loss: 0.105943
# Train: [1098/2931 (100%)]	Loss: 0.143189
# Epoch: 4/10. Train set: Average loss: 0.1431
# Epoch: 4/10. Validation set: Average loss: 0.1517
# Train: [0/2931 (0%)]	Loss: 0.055563
# Train: [1098/2931 (100%)]	Loss: 0.140018
# Epoch: 5/10. Train set: Average loss: 0.1398
# Epoch: 5/10. Validation set: Average loss: 0.1424
# Train: [0/2931 (0%)]	Loss: 0.105056
# Train: [1098/2931 (100%)]	Loss: 0.144264
# Epoch: 6/10. Train set: Average loss: 0.1442
# Epoch: 6/10. Validation set: Average loss: 0.1652
# Train: [0/2931 (0%)]	Loss: 0.128561
# Train: [1098/2931 (100%)]	Loss: 0.139517
# Epoch: 7/10. Train set: Average loss: 0.1395
# Epoch: 7/10. Validation set: Average loss: 0.1424
# Train: [0/2931 (0%)]	Loss: 0.022888
# Train: [1098/2931 (100%)]	Loss: 0.140792
# Epoch: 8/10. Train set: Average loss: 0.1405
# Epoch: 8/10. Validation set: Average loss: 0.1426
# Train: [0/2931 (0%)]	Loss: 0.112125
# Train: [1098/2931 (100%)]	Loss: 0.140308
# Epoch: 9/10. Train set: Average loss: 0.1402
# Epoch: 9/10. Validation set: Average loss: 0.1423
# Train: [0/2931 (0%)]	Loss: 0.105101
# Train: [1098/2931 (100%)]	Loss: 0.136593
# Epoch: 10/10. Train set: Average loss: 0.1365
# Epoch: 10/10. Validation set: Average loss: 0.1414
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.248971
# Train: [1098/2931 (100%)]	Loss: 0.147888
# Epoch: 1/10. Train set: Average loss: 0.1482
# Epoch: 1/10. Validation set: Average loss: 0.1455
# Train: [0/2931 (0%)]	Loss: 0.134827
# Train: [1098/2931 (100%)]	Loss: 0.146713
# Epoch: 2/10. Train set: Average loss: 0.1467
# Epoch: 2/10. Validation set: Average loss: 0.1434
# Train: [0/2931 (0%)]	Loss: 0.114375
# Train: [1098/2931 (100%)]	Loss: 0.141841
# Epoch: 3/10. Train set: Average loss: 0.1418
# Epoch: 3/10. Validation set: Average loss: 0.1525
# Train: [0/2931 (0%)]	Loss: 0.101381
# Train: [1098/2931 (100%)]	Loss: 0.143565
# Epoch: 4/10. Train set: Average loss: 0.1435
# Epoch: 4/10. Validation set: Average loss: 0.1525
# Train: [0/2931 (0%)]	Loss: 0.139164
# Train: [1098/2931 (100%)]	Loss: 0.143485
# Epoch: 5/10. Train set: Average loss: 0.1435
# Epoch: 5/10. Validation set: Average loss: 0.1463
# Train: [0/2931 (0%)]	Loss: 0.159635
# Train: [1098/2931 (100%)]	Loss: 0.139844
# Epoch: 6/10. Train set: Average loss: 0.1399
# Epoch: 6/10. Validation set: Average loss: 0.1457
# Train: [0/2931 (0%)]	Loss: 0.142433
# Train: [1098/2931 (100%)]	Loss: 0.143537
# Epoch: 7/10. Train set: Average loss: 0.1435
# Epoch: 7/10. Validation set: Average loss: 0.1422
# Train: [0/2931 (0%)]	Loss: 0.110157
# Train: [1098/2931 (100%)]	Loss: 0.146157
# Epoch: 8/10. Train set: Average loss: 0.1461
# Epoch: 8/10. Validation set: Average loss: 0.1545
# Train: [0/2931 (0%)]	Loss: 0.119046
# Train: [1098/2931 (100%)]	Loss: 0.138770
# Epoch: 9/10. Train set: Average loss: 0.1387
# Epoch: 9/10. Validation set: Average loss: 0.1426
# Train: [0/2931 (0%)]	Loss: 0.176405
# Train: [1098/2931 (100%)]	Loss: 0.137221
# Epoch: 10/10. Train set: Average loss: 0.1373
# Epoch: 10/10. Validation set: Average loss: 0.1428
# Batch 1
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187333
# Train: [1098/2931 (100%)]	Loss: 0.118327
# Epoch: 1/10. Train set: Average loss: 0.1185
# Epoch: 1/10. Validation set: Average loss: 0.1104
# Train: [0/2931 (0%)]	Loss: 0.103277
# Train: [1098/2931 (100%)]	Loss: 0.105170
# Epoch: 2/10. Train set: Average loss: 0.1052
# Epoch: 2/10. Validation set: Average loss: 0.1076
# Train: [0/2931 (0%)]	Loss: 0.089984
# Train: [1098/2931 (100%)]	Loss: 0.099660
# Epoch: 3/10. Train set: Average loss: 0.0996
# Epoch: 3/10. Validation set: Average loss: 0.0878
# Train: [0/2931 (0%)]	Loss: 0.122477
# Train: [1098/2931 (100%)]	Loss: 0.088979
# Epoch: 4/10. Train set: Average loss: 0.0891
# Epoch: 4/10. Validation set: Average loss: 0.0902
# Train: [0/2931 (0%)]	Loss: 0.037168
# Train: [1098/2931 (100%)]	Loss: 0.081897
# Epoch: 5/10. Train set: Average loss: 0.0818
# Epoch: 5/10. Validation set: Average loss: 0.0844
# Train: [0/2931 (0%)]	Loss: 0.041520
# Train: [1098/2931 (100%)]	Loss: 0.082328
# Epoch: 6/10. Train set: Average loss: 0.0822
# Epoch: 6/10. Validation set: Average loss: 0.0928
# Train: [0/2931 (0%)]	Loss: 0.106967
# Train: [1098/2931 (100%)]	Loss: 0.080812
# Epoch: 7/10. Train set: Average loss: 0.0809
# Epoch: 7/10. Validation set: Average loss: 0.0984
# Train: [0/2931 (0%)]	Loss: 0.102685
# Train: [1098/2931 (100%)]	Loss: 0.081471
# Epoch: 8/10. Train set: Average loss: 0.0815
# Epoch: 8/10. Validation set: Average loss: 0.0891
# Train: [0/2931 (0%)]	Loss: 0.046151
# Train: [1098/2931 (100%)]	Loss: 0.078140
# Epoch: 9/10. Train set: Average loss: 0.0781
# Epoch: 9/10. Validation set: Average loss: 0.0846
# Train: [0/2931 (0%)]	Loss: 0.123712
# Train: [1098/2931 (100%)]	Loss: 0.077208
# Epoch: 10/10. Train set: Average loss: 0.0773
# Epoch: 10/10. Validation set: Average loss: 0.0870
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.062383
# Train: [1098/2931 (100%)]	Loss: 0.130084
# Epoch: 1/10. Train set: Average loss: 0.1299
# Epoch: 1/10. Validation set: Average loss: 0.1238
# Train: [0/2931 (0%)]	Loss: 0.052206
# Train: [1098/2931 (100%)]	Loss: 0.108972
# Epoch: 2/10. Train set: Average loss: 0.1088
# Epoch: 2/10. Validation set: Average loss: 0.1052
# Train: [0/2931 (0%)]	Loss: 0.244223
# Train: [1098/2931 (100%)]	Loss: 0.100277
# Epoch: 3/10. Train set: Average loss: 0.1007
# Epoch: 3/10. Validation set: Average loss: 0.1070
# Train: [0/2931 (0%)]	Loss: 0.056176
# Train: [1098/2931 (100%)]	Loss: 0.091317
# Epoch: 4/10. Train set: Average loss: 0.0912
# Epoch: 4/10. Validation set: Average loss: 0.1039
# Train: [0/2931 (0%)]	Loss: 0.089984
# Train: [1098/2931 (100%)]	Loss: 0.088546
# Epoch: 5/10. Train set: Average loss: 0.0885
# Epoch: 5/10. Validation set: Average loss: 0.0901
# Train: [0/2931 (0%)]	Loss: 0.096517
# Train: [1098/2931 (100%)]	Loss: 0.084678
# Epoch: 6/10. Train set: Average loss: 0.0847
# Epoch: 6/10. Validation set: Average loss: 0.0998
# Train: [0/2931 (0%)]	Loss: 0.103353
# Train: [1098/2931 (100%)]	Loss: 0.090569
# Epoch: 7/10. Train set: Average loss: 0.0906
# Epoch: 7/10. Validation set: Average loss: 0.0938
# Train: [0/2931 (0%)]	Loss: 0.044669
# Train: [1098/2931 (100%)]	Loss: 0.082254
# Epoch: 8/10. Train set: Average loss: 0.0822
# Epoch: 8/10. Validation set: Average loss: 0.0939
# Train: [0/2931 (0%)]	Loss: 0.116061
# Train: [1098/2931 (100%)]	Loss: 0.080574
# Epoch: 9/10. Train set: Average loss: 0.0807
# Epoch: 9/10. Validation set: Average loss: 0.0845
# Train: [0/2931 (0%)]	Loss: 0.068508
# Train: [1098/2931 (100%)]	Loss: 0.078069
# Epoch: 10/10. Train set: Average loss: 0.0780
# Epoch: 10/10. Validation set: Average loss: 0.0828
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.062422
# Train: [1098/2931 (100%)]	Loss: 0.133537
# Epoch: 1/10. Train set: Average loss: 0.1333
# Epoch: 1/10. Validation set: Average loss: 0.1340
# Train: [0/2931 (0%)]	Loss: 0.075743
# Train: [1098/2931 (100%)]	Loss: 0.114792
# Epoch: 2/10. Train set: Average loss: 0.1147
# Epoch: 2/10. Validation set: Average loss: 0.1258
# Train: [0/2931 (0%)]	Loss: 0.079754
# Train: [1098/2931 (100%)]	Loss: 0.097157
# Epoch: 3/10. Train set: Average loss: 0.0971
# Epoch: 3/10. Validation set: Average loss: 0.0989
# Train: [0/2931 (0%)]	Loss: 0.156477
# Train: [1098/2931 (100%)]	Loss: 0.098519
# Epoch: 4/10. Train set: Average loss: 0.0987
# Epoch: 4/10. Validation set: Average loss: 0.0938
# Train: [0/2931 (0%)]	Loss: 0.038335
# Train: [1098/2931 (100%)]	Loss: 0.083855
# Epoch: 5/10. Train set: Average loss: 0.0837
# Epoch: 5/10. Validation set: Average loss: 0.0944
# Train: [0/2931 (0%)]	Loss: 0.127130
# Train: [1098/2931 (100%)]	Loss: 0.090586
# Epoch: 6/10. Train set: Average loss: 0.0907
# Epoch: 6/10. Validation set: Average loss: 0.0920
# Train: [0/2931 (0%)]	Loss: 0.185333
# Train: [1098/2931 (100%)]	Loss: 0.087732
# Epoch: 7/10. Train set: Average loss: 0.0880
# Epoch: 7/10. Validation set: Average loss: 0.0937
# Train: [0/2931 (0%)]	Loss: 0.114735
# Train: [1098/2931 (100%)]	Loss: 0.083432
# Epoch: 8/10. Train set: Average loss: 0.0835
# Epoch: 8/10. Validation set: Average loss: 0.0896
# Train: [0/2931 (0%)]	Loss: 0.057175
# Train: [1098/2931 (100%)]	Loss: 0.079129
# Epoch: 9/10. Train set: Average loss: 0.0791
# Epoch: 9/10. Validation set: Average loss: 0.0864
# Train: [0/2931 (0%)]	Loss: 0.100886
# Train: [1098/2931 (100%)]	Loss: 0.074770
# Epoch: 10/10. Train set: Average loss: 0.0748
# Epoch: 10/10. Validation set: Average loss: 0.0858
# Batch 2
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.311900
# Train: [1098/2931 (100%)]	Loss: 0.119399
# Epoch: 1/10. Train set: Average loss: 0.1199
# Epoch: 1/10. Validation set: Average loss: 0.1245
# Train: [0/2931 (0%)]	Loss: 0.145122
# Train: [1098/2931 (100%)]	Loss: 0.096866
# Epoch: 2/10. Train set: Average loss: 0.0970
# Epoch: 2/10. Validation set: Average loss: 0.1059
# Train: [0/2931 (0%)]	Loss: 0.053972
# Train: [1098/2931 (100%)]	Loss: 0.081094
# Epoch: 3/10. Train set: Average loss: 0.0810
# Epoch: 3/10. Validation set: Average loss: 0.0963
# Train: [0/2931 (0%)]	Loss: 0.072169
# Train: [1098/2931 (100%)]	Loss: 0.081488
# Epoch: 4/10. Train set: Average loss: 0.0815
# Epoch: 4/10. Validation set: Average loss: 0.0897
# Train: [0/2931 (0%)]	Loss: 0.079753
# Train: [1098/2931 (100%)]	Loss: 0.076621
# Epoch: 5/10. Train set: Average loss: 0.0766
# Epoch: 5/10. Validation set: Average loss: 0.0825
# Train: [0/2931 (0%)]	Loss: 0.055671
# Train: [1098/2931 (100%)]	Loss: 0.077621
# Epoch: 6/10. Train set: Average loss: 0.0776
# Epoch: 6/10. Validation set: Average loss: 0.0829
# Train: [0/2931 (0%)]	Loss: 0.123581
# Train: [1098/2931 (100%)]	Loss: 0.073626
# Epoch: 7/10. Train set: Average loss: 0.0738
# Epoch: 7/10. Validation set: Average loss: 0.0817
# Train: [0/2931 (0%)]	Loss: 0.118424
# Train: [1098/2931 (100%)]	Loss: 0.077031
# Epoch: 8/10. Train set: Average loss: 0.0771
# Epoch: 8/10. Validation set: Average loss: 0.0929
# Train: [0/2931 (0%)]	Loss: 0.079147
# Train: [1098/2931 (100%)]	Loss: 0.073677
# Epoch: 9/10. Train set: Average loss: 0.0737
# Epoch: 9/10. Validation set: Average loss: 0.0743
# Train: [0/2931 (0%)]	Loss: 0.056273
# Train: [1098/2931 (100%)]	Loss: 0.065328
# Epoch: 10/10. Train set: Average loss: 0.0653
# Epoch: 10/10. Validation set: Average loss: 0.0719
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.312286
# Train: [1098/2931 (100%)]	Loss: 0.123453
# Epoch: 1/10. Train set: Average loss: 0.1240
# Epoch: 1/10. Validation set: Average loss: 0.0982
# Train: [0/2931 (0%)]	Loss: 0.072041
# Train: [1098/2931 (100%)]	Loss: 0.080034
# Epoch: 2/10. Train set: Average loss: 0.0800
# Epoch: 2/10. Validation set: Average loss: 0.1580
# Train: [0/2931 (0%)]	Loss: 0.328090
# Train: [1098/2931 (100%)]	Loss: 0.095974
# Epoch: 3/10. Train set: Average loss: 0.0966
# Epoch: 3/10. Validation set: Average loss: 0.1161
# Train: [0/2931 (0%)]	Loss: 0.122485
# Train: [1098/2931 (100%)]	Loss: 0.085731
# Epoch: 4/10. Train set: Average loss: 0.0858
# Epoch: 4/10. Validation set: Average loss: 0.0814
# Train: [0/2931 (0%)]	Loss: 0.070550
# Train: [1098/2931 (100%)]	Loss: 0.075770
# Epoch: 5/10. Train set: Average loss: 0.0758
# Epoch: 5/10. Validation set: Average loss: 0.0790
# Train: [0/2931 (0%)]	Loss: 0.084286
# Train: [1098/2931 (100%)]	Loss: 0.080212
# Epoch: 6/10. Train set: Average loss: 0.0802
# Epoch: 6/10. Validation set: Average loss: 0.0791
# Train: [0/2931 (0%)]	Loss: 0.105124
# Train: [1098/2931 (100%)]	Loss: 0.076246
# Epoch: 7/10. Train set: Average loss: 0.0763
# Epoch: 7/10. Validation set: Average loss: 0.0801
# Train: [0/2931 (0%)]	Loss: 0.052107
# Train: [1098/2931 (100%)]	Loss: 0.077588
# Epoch: 8/10. Train set: Average loss: 0.0775
# Epoch: 8/10. Validation set: Average loss: 0.0794
# Train: [0/2931 (0%)]	Loss: 0.071669
# Train: [1098/2931 (100%)]	Loss: 0.069270
# Epoch: 9/10. Train set: Average loss: 0.0693
# Epoch: 9/10. Validation set: Average loss: 0.0741
# Train: [0/2931 (0%)]	Loss: 0.044361
# Train: [1098/2931 (100%)]	Loss: 0.068288
# Epoch: 10/10. Train set: Average loss: 0.0682
# Epoch: 10/10. Validation set: Average loss: 0.0723
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.186930
