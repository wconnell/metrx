# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("..")

import datetime
import pathlib

from collections import OrderedDict 

import numpy as np
import pandas as pd

# %%
# Pytorch
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable

# Custom
from dutils import Experiment
from trainer import fit
import visualization as vis
from tcga_datasets import SiameseDataset

# Models
from tcga_networks import EmbeddingNet, SiameseNet
from losses import ContrastiveLoss

# Metrics
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score as ANMI

# %%
def getTCGA(disease):
    path = "/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP/TCGA/TCGA_{}_counts.tsv.gz"
    files = [path.format(d) for d in disease]
    return files


def readGCP(files, biotype='protein_coding', mean=True):
    """
    Paths to count matrices.
    """
    data_dict = {}
    for f in files:
        key = os.path.basename(f).split("_")[1]
        data = pd.read_csv(f, sep='\t', index_col=0)
        # transcript metadata
        meta = pd.DataFrame([row[:-1] for row in data.index.str.split("|")],
                            columns=['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'GENE', 'BP', 'BIOTYPE'])
        meta = pd.MultiIndex.from_frame(meta)
        data.index = meta
        # subset transcripts
        data = data.xs(key=biotype, level='BIOTYPE')
        data = data.droplevel(['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'BP'])
        # average gene expression of splice variants
        data = data.T
        if mean:
            data = data.groupby(by=data.columns, axis=1).mean()
        data_dict[key] = data
    return data_dict


def uq_norm(df, q=0.75):
    """
    Upper quartile normalization of GEX for samples.
    """
    quantiles = df.quantile(q=q, axis=1)
    norm = df.divide(quantiles, axis=0)
    return norm


def process_TCGA(disease=['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']):
    base="/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP"
    # get files
    tcga_files = getTCGA(disease)
    # read meta/data
    tcga_meta = pd.read_csv(os.path.join(base, "TCGA/TCGA_GDC_ID_MAP.tsv"), sep="\t")
    tcga_raw = readGCP(tcga_files, mean=True)
    # combine samples
    tcga_raw = pd.concat(tcga_raw.values())
    # Upper quartile normalization
    tcga_raw = uq_norm(tcga_raw)
    # log norm
    tcga = tcga_raw.transform(np.log1p)
    return tcga, tcga_meta

# %%
def generate_fsets(data, n_features, steps=5):
    r = np.linspace(start=1, stop=n_features, num=steps, dtype='int')
    idx = [np.random.choice(data.shape[1], size=i, replace=False) for i in r]
    return idx

# %%
def feature_training(train_data, train_labels, test_data, test_labels, feature_idx, embedding, exp_dir, cuda=True):
    # Meta data
    meta_data = {"n_features":[],
                 "model":[],
                 "ANMI":[]}
    # Params
    batch_size = 8
    kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {'num_workers': 10}
    
    # Feature Index
    for batch, feat in enumerate(feature_idx):
        print("Number features: {}\n".format(len(feat)))
        exp_data = {'feature_idx':feat}
        # Define data
        siamese_train_dataset = SiameseDataset(data=train_data.iloc[:,feat],
                                           labels=train_labels,
                                           train=True)
        siamese_test_dataset = SiameseDataset(data=test_data.iloc[:,feat],
                                          labels=test_labels,
                                          train=False)
        # Loaders
        siamese_train_loader = torch.utils.data.DataLoader(siamese_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
        siamese_test_loader = torch.utils.data.DataLoader(siamese_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)
        # Instantiate model
        n_samples, n_features = siamese_train_dataset.train_data.shape
        for i in range(3):
            nmodel = 'model_{}'.format(i)
            print("\t{}".format(nmodel))
            embedding_net = EmbeddingNet(n_features, embedding)
            model = SiameseNet(embedding_net)
            if cuda:
                model.cuda()
            # Parameters
            margin = 1.
            loss_fn = ContrastiveLoss(margin)
            lr = 1e-3
            optimizer = optim.Adam(model.parameters(), lr=lr)
            scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
            n_epochs = 10
            log_interval = round(len(siamese_train_dataset)/1/batch_size)
            # Train
            train_loss, val_loss = fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, 
                                       n_epochs, cuda, log_interval)
            # Test Embeddings
            val_embeddings_baseline, val_labels_baseline = vis.extract_embeddings(siamese_test_dataset.test_data, siamese_test_dataset.labels, model)
            # Evaluation
            n_clusters = len(np.unique(test_labels))
            kmeans = KMeans(n_clusters=n_clusters)
            siamese_clusters = kmeans.fit_predict(val_embeddings_baseline)
            anmi = ANMI(siamese_clusters, val_labels_baseline)
            # Store
            meta_data['n_features'].append(len(feat))
            meta_data['model'].append(nmodel)
            meta_data['ANMI'].append(anmi)
            exp_data[nmodel] = {'data': (val_embeddings_baseline, val_labels_baseline),
                                'loss': (train_loss, val_loss),
                                'ANMI': anmi}
        pd.to_pickle(exp_data, os.path.join(exp_dir, "model_{}.pkl".format(len(feat))))
    pd.to_pickle(meta_data, os.path.join(exp_dir, "model_meta_data.pkl"))

# %%
def main(disease, sample_type, **kwargs):
    # GPUs
    os.environ["CUDA_VISIBLE_DEVICES"] = kwargs['device']
    cuda = torch.cuda.is_available()
    print("Cuda is available: {}".format(cuda))
    
    # Read / write / process
    tcga, tcga_meta = process_TCGA(disease)
    # Feature design
    feature_idx = generate_fsets(tcga, n_features=kwargs['n_features'], steps=kwargs['steps'])
    # Experiment design
    hierarchy = OrderedDict({'Disease':disease,
                             'Sample Type':sample_type})
    # Define experiment
    exp = Experiment(meta_data=tcga_meta,
                     hierarchy=hierarchy,
                     index='CGHubAnalysisID',
                     cases='Case ID',
                     min_samples=20)
    # Train / Test split
    exp.train_test_split(cases='Case ID')
    # Return data 
    train_data, train_labels = exp.get_data(tcga, subset="train", dtype=np.float32)
    test_data, test_labels = exp.get_data(tcga, subset="test", dtype=np.float32)
    
    # Path *fix*
    dtime = datetime.datetime.today().strftime("%Y.%m.%d_%H:%M")
    exp_dir = "/srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/{}_{}_{}_{}-{}".format(dtime, 
                                                                                len(exp.labels_dict),
                                                                                kwargs['embedding'],
                                                                                kwargs['n_features'], 
                                                                                kwargs['steps'])
    pathlib.Path(exp_dir).mkdir(parents=True, exist_ok=False)
    print('Saving to: \n{}'.format(exp_dir))
    
    # Meta data
    experiments = {'experiment': exp,
                   'train':(train_data, train_labels),
                   'test': (test_data, test_labels)}
    pd.to_pickle(experiments, os.path.join(exp_dir, "experiment_meta_data.pkl"))
    
    # Training
    feature_training(train_data, train_labels, test_data, test_labels, feature_idx, kwargs['embedding'], exp_dir)

# %% [markdown]
# ### Setup

# %%
disease = ['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']
sample_type = ['Primary Tumor', 'Solid Tissue Normal']
params = {"device":"6",
          "n_features":2000,
          "steps":100,
          "embedding":2}

# %%
main(disease=disease, sample_type=sample_type, **params)
# Out:
# Cuda is available: True
# Saving to:
# /srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/2020.03.27_17:43_11_2_2000-100
# Number features: 1
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.249285
# Train: [1098/2931 (100%)]	Loss: 0.174593
# Epoch: 1/10. Train set: Average loss: 0.1748
# Epoch: 1/10. Validation set: Average loss: 0.1617
# Train: [0/2931 (0%)]	Loss: 0.506345
# Train: [1098/2931 (100%)]	Loss: 0.153746
# Epoch: 2/10. Train set: Average loss: 0.1547
# Epoch: 2/10. Validation set: Average loss: 0.1604
# Train: [0/2931 (0%)]	Loss: 0.236462
# Train: [1098/2931 (100%)]	Loss: 0.156686
# Epoch: 3/10. Train set: Average loss: 0.1569
# Epoch: 3/10. Validation set: Average loss: 0.1531
# Train: [0/2931 (0%)]	Loss: 0.160946
# Train: [1098/2931 (100%)]	Loss: 0.164751
# Epoch: 4/10. Train set: Average loss: 0.1647
# Epoch: 4/10. Validation set: Average loss: 0.1664
# Train: [0/2931 (0%)]	Loss: 0.106919
# Train: [1098/2931 (100%)]	Loss: 0.153411
# Epoch: 5/10. Train set: Average loss: 0.1533
# Epoch: 5/10. Validation set: Average loss: 0.1782
# Train: [0/2931 (0%)]	Loss: 0.213499
# Train: [1098/2931 (100%)]	Loss: 0.153869
# Epoch: 6/10. Train set: Average loss: 0.1540
# Epoch: 6/10. Validation set: Average loss: 0.1476
# Train: [0/2931 (0%)]	Loss: 0.174512
# Train: [1098/2931 (100%)]	Loss: 0.150986
# Epoch: 7/10. Train set: Average loss: 0.1511
# Epoch: 7/10. Validation set: Average loss: 0.1664
# Train: [0/2931 (0%)]	Loss: 0.108368
# Train: [1098/2931 (100%)]	Loss: 0.153102
# Epoch: 8/10. Train set: Average loss: 0.1530
# Epoch: 8/10. Validation set: Average loss: 0.1505
# Train: [0/2931 (0%)]	Loss: 0.235415
# Train: [1098/2931 (100%)]	Loss: 0.149342
# Epoch: 9/10. Train set: Average loss: 0.1496
# Epoch: 9/10. Validation set: Average loss: 0.1507
# Train: [0/2931 (0%)]	Loss: 0.181156
# Train: [1098/2931 (100%)]	Loss: 0.145957
# Epoch: 10/10. Train set: Average loss: 0.1461
# Epoch: 10/10. Validation set: Average loss: 0.1554
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249602
# Train: [1098/2931 (100%)]	Loss: 0.164604
# Epoch: 1/10. Train set: Average loss: 0.1648
# Epoch: 1/10. Validation set: Average loss: 0.1526
# Train: [0/2931 (0%)]	Loss: 0.158012
# Train: [1098/2931 (100%)]	Loss: 0.155662
# Epoch: 2/10. Train set: Average loss: 0.1557
# Epoch: 2/10. Validation set: Average loss: 0.1500
# Train: [0/2931 (0%)]	Loss: 0.147176
# Train: [1098/2931 (100%)]	Loss: 0.157941
# Epoch: 3/10. Train set: Average loss: 0.1579
# Epoch: 3/10. Validation set: Average loss: 0.1476
# Train: [0/2931 (0%)]	Loss: 0.183282
# Train: [1098/2931 (100%)]	Loss: 0.152144
# Epoch: 4/10. Train set: Average loss: 0.1522
# Epoch: 4/10. Validation set: Average loss: 0.1494
# Train: [0/2931 (0%)]	Loss: 0.209644
# Train: [1098/2931 (100%)]	Loss: 0.151902
# Epoch: 5/10. Train set: Average loss: 0.1521
# Epoch: 5/10. Validation set: Average loss: 0.1470
# Train: [0/2931 (0%)]	Loss: 0.079365
# Train: [1098/2931 (100%)]	Loss: 0.157423
# Epoch: 6/10. Train set: Average loss: 0.1572
# Epoch: 6/10. Validation set: Average loss: 0.1584
# Train: [0/2931 (0%)]	Loss: 0.107607
# Train: [1098/2931 (100%)]	Loss: 0.154123
# Epoch: 7/10. Train set: Average loss: 0.1540
# Epoch: 7/10. Validation set: Average loss: 0.1476
# Train: [0/2931 (0%)]	Loss: 0.120965
# Train: [1098/2931 (100%)]	Loss: 0.157041
# Epoch: 8/10. Train set: Average loss: 0.1569
# Epoch: 8/10. Validation set: Average loss: 0.1494
# Train: [0/2931 (0%)]	Loss: 0.137910
# Train: [1098/2931 (100%)]	Loss: 0.146257
# Epoch: 9/10. Train set: Average loss: 0.1462
# Epoch: 9/10. Validation set: Average loss: 0.1471
# Train: [0/2931 (0%)]	Loss: 0.095110
# Train: [1098/2931 (100%)]	Loss: 0.143130
# Epoch: 10/10. Train set: Average loss: 0.1430
# Epoch: 10/10. Validation set: Average loss: 0.1533
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249600
# Train: [1098/2931 (100%)]	Loss: 0.170636
# Epoch: 1/10. Train set: Average loss: 0.1709
# Epoch: 1/10. Validation set: Average loss: 0.1757
# Train: [0/2931 (0%)]	Loss: 0.071204
# Train: [1098/2931 (100%)]	Loss: 0.154919
# Epoch: 2/10. Train set: Average loss: 0.1547
# Epoch: 2/10. Validation set: Average loss: 0.1568
# Train: [0/2931 (0%)]	Loss: 0.234550
# Train: [1098/2931 (100%)]	Loss: 0.151616
# Epoch: 3/10. Train set: Average loss: 0.1518
# Epoch: 3/10. Validation set: Average loss: 0.1575
# Train: [0/2931 (0%)]	Loss: 0.184835
# Train: [1098/2931 (100%)]	Loss: 0.149169
# Epoch: 4/10. Train set: Average loss: 0.1493
# Epoch: 4/10. Validation set: Average loss: 0.1550
# Train: [0/2931 (0%)]	Loss: 0.135393
# Train: [1098/2931 (100%)]	Loss: 0.153049
# Epoch: 5/10. Train set: Average loss: 0.1530
# Epoch: 5/10. Validation set: Average loss: 0.1546
# Train: [0/2931 (0%)]	Loss: 0.139380
# Train: [1098/2931 (100%)]	Loss: 0.157245
# Epoch: 6/10. Train set: Average loss: 0.1572
# Epoch: 6/10. Validation set: Average loss: 0.1488
# Train: [0/2931 (0%)]	Loss: 0.229622
# Train: [1098/2931 (100%)]	Loss: 0.153916
# Epoch: 7/10. Train set: Average loss: 0.1541
# Epoch: 7/10. Validation set: Average loss: 0.1474
# Train: [0/2931 (0%)]	Loss: 0.102004
# Train: [1098/2931 (100%)]	Loss: 0.149814
# Epoch: 8/10. Train set: Average loss: 0.1497
# Epoch: 8/10. Validation set: Average loss: 0.1470
# Train: [0/2931 (0%)]	Loss: 0.152296
# Train: [1098/2931 (100%)]	Loss: 0.146916
# Epoch: 9/10. Train set: Average loss: 0.1469
# Epoch: 9/10. Validation set: Average loss: 0.1502
# Train: [0/2931 (0%)]	Loss: 0.163272
# Train: [1098/2931 (100%)]	Loss: 0.148240
# Epoch: 10/10. Train set: Average loss: 0.1483
# Epoch: 10/10. Validation set: Average loss: 0.1497
# Number features: 21
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.374305
# Train: [1098/2931 (100%)]	Loss: 0.111272
# Epoch: 1/10. Train set: Average loss: 0.1120
# Epoch: 1/10. Validation set: Average loss: 0.0895
# Train: [0/2931 (0%)]	Loss: 0.109127
# Train: [1098/2931 (100%)]	Loss: 0.083896
# Epoch: 2/10. Train set: Average loss: 0.0840
# Epoch: 2/10. Validation set: Average loss: 0.0919
# Train: [0/2931 (0%)]	Loss: 0.088156
# Train: [1098/2931 (100%)]	Loss: 0.067793
# Epoch: 3/10. Train set: Average loss: 0.0678
# Epoch: 3/10. Validation set: Average loss: 0.1076
# Train: [0/2931 (0%)]	Loss: 0.034447
# Train: [1098/2931 (100%)]	Loss: 0.066525
# Epoch: 4/10. Train set: Average loss: 0.0664
# Epoch: 4/10. Validation set: Average loss: 0.0708
# Train: [0/2931 (0%)]	Loss: 0.081808
# Train: [1098/2931 (100%)]	Loss: 0.067344
# Epoch: 5/10. Train set: Average loss: 0.0674
# Epoch: 5/10. Validation set: Average loss: 0.0835
# Train: [0/2931 (0%)]	Loss: 0.064665
# Train: [1098/2931 (100%)]	Loss: 0.059957
# Epoch: 6/10. Train set: Average loss: 0.0600
# Epoch: 6/10. Validation set: Average loss: 0.0703
# Train: [0/2931 (0%)]	Loss: 0.018523
# Train: [1098/2931 (100%)]	Loss: 0.054001
# Epoch: 7/10. Train set: Average loss: 0.0539
# Epoch: 7/10. Validation set: Average loss: 0.0743
# Train: [0/2931 (0%)]	Loss: 0.008926
# Train: [1098/2931 (100%)]	Loss: 0.050039
# Epoch: 8/10. Train set: Average loss: 0.0499
# Epoch: 8/10. Validation set: Average loss: 0.0618
# Train: [0/2931 (0%)]	Loss: 0.056246
# Train: [1098/2931 (100%)]	Loss: 0.042985
# Epoch: 9/10. Train set: Average loss: 0.0430
# Epoch: 9/10. Validation set: Average loss: 0.0529
# Train: [0/2931 (0%)]	Loss: 0.015498
# Train: [1098/2931 (100%)]	Loss: 0.041196
# Epoch: 10/10. Train set: Average loss: 0.0411
# Epoch: 10/10. Validation set: Average loss: 0.0521
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.311513
# Train: [1098/2931 (100%)]	Loss: 0.110928
# Epoch: 1/10. Train set: Average loss: 0.1115
# Epoch: 1/10. Validation set: Average loss: 0.1046
# Train: [0/2931 (0%)]	Loss: 0.058372
# Train: [1098/2931 (100%)]	Loss: 0.086304
# Epoch: 2/10. Train set: Average loss: 0.0862
# Epoch: 2/10. Validation set: Average loss: 0.0992
# Train: [0/2931 (0%)]	Loss: 0.141852
# Train: [1098/2931 (100%)]	Loss: 0.083290
# Epoch: 3/10. Train set: Average loss: 0.0834
# Epoch: 3/10. Validation set: Average loss: 0.0816
# Train: [0/2931 (0%)]	Loss: 0.121611
# Train: [1098/2931 (100%)]	Loss: 0.069035
# Epoch: 4/10. Train set: Average loss: 0.0692
# Epoch: 4/10. Validation set: Average loss: 0.0785
# Train: [0/2931 (0%)]	Loss: 0.049690
# Train: [1098/2931 (100%)]	Loss: 0.061786
# Epoch: 5/10. Train set: Average loss: 0.0618
# Epoch: 5/10. Validation set: Average loss: 0.0705
# Train: [0/2931 (0%)]	Loss: 0.071712
# Train: [1098/2931 (100%)]	Loss: 0.054772
# Epoch: 6/10. Train set: Average loss: 0.0548
# Epoch: 6/10. Validation set: Average loss: 0.0650
# Train: [0/2931 (0%)]	Loss: 0.044051
# Train: [1098/2931 (100%)]	Loss: 0.059684
# Epoch: 7/10. Train set: Average loss: 0.0596
# Epoch: 7/10. Validation set: Average loss: 0.0626
# Train: [0/2931 (0%)]	Loss: 0.018618
# Train: [1098/2931 (100%)]	Loss: 0.048660
# Epoch: 8/10. Train set: Average loss: 0.0486
# Epoch: 8/10. Validation set: Average loss: 0.0703
# Train: [0/2931 (0%)]	Loss: 0.025990
# Train: [1098/2931 (100%)]	Loss: 0.044413
# Epoch: 9/10. Train set: Average loss: 0.0444
# Epoch: 9/10. Validation set: Average loss: 0.0541
# Train: [0/2931 (0%)]	Loss: 0.059380
# Train: [1098/2931 (100%)]	Loss: 0.038286
# Epoch: 10/10. Train set: Average loss: 0.0383
# Epoch: 10/10. Validation set: Average loss: 0.0524
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249615
# Train: [1098/2931 (100%)]	Loss: 0.111942
# Epoch: 1/10. Train set: Average loss: 0.1123
# Epoch: 1/10. Validation set: Average loss: 0.0947
# Train: [0/2931 (0%)]	Loss: 0.128977
# Train: [1098/2931 (100%)]	Loss: 0.083608
# Epoch: 2/10. Train set: Average loss: 0.0837
# Epoch: 2/10. Validation set: Average loss: 0.1017
# Train: [0/2931 (0%)]	Loss: 0.112340
# Train: [1098/2931 (100%)]	Loss: 0.074338
# Epoch: 3/10. Train set: Average loss: 0.0744
# Epoch: 3/10. Validation set: Average loss: 0.1173
# Train: [0/2931 (0%)]	Loss: 0.142508
# Train: [1098/2931 (100%)]	Loss: 0.066891
# Epoch: 4/10. Train set: Average loss: 0.0671
# Epoch: 4/10. Validation set: Average loss: 0.0959
# Train: [0/2931 (0%)]	Loss: 0.123103
# Train: [1098/2931 (100%)]	Loss: 0.064153
# Epoch: 5/10. Train set: Average loss: 0.0643
# Epoch: 5/10. Validation set: Average loss: 0.0789
# Train: [0/2931 (0%)]	Loss: 0.077734
# Train: [1098/2931 (100%)]	Loss: 0.060535
# Epoch: 6/10. Train set: Average loss: 0.0606
# Epoch: 6/10. Validation set: Average loss: 0.0823
# Train: [0/2931 (0%)]	Loss: 0.078598
# Train: [1098/2931 (100%)]	Loss: 0.059897
# Epoch: 7/10. Train set: Average loss: 0.0599
# Epoch: 7/10. Validation set: Average loss: 0.0758
# Train: [0/2931 (0%)]	Loss: 0.082100
# Train: [1098/2931 (100%)]	Loss: 0.055140
# Epoch: 8/10. Train set: Average loss: 0.0552
# Epoch: 8/10. Validation set: Average loss: 0.0732
# Train: [0/2931 (0%)]	Loss: 0.080979
# Train: [1098/2931 (100%)]	Loss: 0.048401
# Epoch: 9/10. Train set: Average loss: 0.0485
# Epoch: 9/10. Validation set: Average loss: 0.0579
# Train: [0/2931 (0%)]	Loss: 0.053348
# Train: [1098/2931 (100%)]	Loss: 0.043773
# Epoch: 10/10. Train set: Average loss: 0.0438
# Epoch: 10/10. Validation set: Average loss: 0.0554
# Number features: 41
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.373758
# Train: [1098/2931 (100%)]	Loss: 0.087728
# Epoch: 1/10. Train set: Average loss: 0.0885
# Epoch: 1/10. Validation set: Average loss: 0.0722
# Train: [0/2931 (0%)]	Loss: 0.084417
# Train: [1098/2931 (100%)]	Loss: 0.074235
# Epoch: 2/10. Train set: Average loss: 0.0743
# Epoch: 2/10. Validation set: Average loss: 0.0706
# Train: [0/2931 (0%)]	Loss: 0.113257
# Train: [1098/2931 (100%)]	Loss: 0.065238
# Epoch: 3/10. Train set: Average loss: 0.0654
# Epoch: 3/10. Validation set: Average loss: 0.0620
# Train: [0/2931 (0%)]	Loss: 0.007742
# Train: [1098/2931 (100%)]	Loss: 0.049581
# Epoch: 4/10. Train set: Average loss: 0.0495
# Epoch: 4/10. Validation set: Average loss: 0.0521
# Train: [0/2931 (0%)]	Loss: 0.058843
# Train: [1098/2931 (100%)]	Loss: 0.047123
# Epoch: 5/10. Train set: Average loss: 0.0472
# Epoch: 5/10. Validation set: Average loss: 0.0519
# Train: [0/2931 (0%)]	Loss: 0.063940
# Train: [1098/2931 (100%)]	Loss: 0.044421
# Epoch: 6/10. Train set: Average loss: 0.0445
# Epoch: 6/10. Validation set: Average loss: 0.0405
# Train: [0/2931 (0%)]	Loss: 0.060127
# Train: [1098/2931 (100%)]	Loss: 0.035744
# Epoch: 7/10. Train set: Average loss: 0.0358
# Epoch: 7/10. Validation set: Average loss: 0.0471
# Train: [0/2931 (0%)]	Loss: 0.038000
# Train: [1098/2931 (100%)]	Loss: 0.033585
# Epoch: 8/10. Train set: Average loss: 0.0336
# Epoch: 8/10. Validation set: Average loss: 0.0428
# Train: [0/2931 (0%)]	Loss: 0.065328
# Train: [1098/2931 (100%)]	Loss: 0.033846
# Epoch: 9/10. Train set: Average loss: 0.0339
# Epoch: 9/10. Validation set: Average loss: 0.0339
# Train: [0/2931 (0%)]	Loss: 0.012076
# Train: [1098/2931 (100%)]	Loss: 0.026115
# Epoch: 10/10. Train set: Average loss: 0.0261
# Epoch: 10/10. Validation set: Average loss: 0.0321
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.248867
# Train: [1098/2931 (100%)]	Loss: 0.108510
# Epoch: 1/10. Train set: Average loss: 0.1089
# Epoch: 1/10. Validation set: Average loss: 0.0986
# Train: [0/2931 (0%)]	Loss: 0.072806
# Train: [1098/2931 (100%)]	Loss: 0.079137
# Epoch: 2/10. Train set: Average loss: 0.0791
# Epoch: 2/10. Validation set: Average loss: 0.0712
# Train: [0/2931 (0%)]	Loss: 0.117567
# Train: [1098/2931 (100%)]	Loss: 0.064381
# Epoch: 3/10. Train set: Average loss: 0.0645
# Epoch: 3/10. Validation set: Average loss: 0.0672
# Train: [0/2931 (0%)]	Loss: 0.057715
# Train: [1098/2931 (100%)]	Loss: 0.059695
# Epoch: 4/10. Train set: Average loss: 0.0597
# Epoch: 4/10. Validation set: Average loss: 0.0599
# Train: [0/2931 (0%)]	Loss: 0.030442
# Train: [1098/2931 (100%)]	Loss: 0.053140
# Epoch: 5/10. Train set: Average loss: 0.0531
# Epoch: 5/10. Validation set: Average loss: 0.0569
# Train: [0/2931 (0%)]	Loss: 0.050457
# Train: [1098/2931 (100%)]	Loss: 0.052948
# Epoch: 6/10. Train set: Average loss: 0.0529
# Epoch: 6/10. Validation set: Average loss: 0.0501
# Train: [0/2931 (0%)]	Loss: 0.063032
# Train: [1098/2931 (100%)]	Loss: 0.044455
# Epoch: 7/10. Train set: Average loss: 0.0445
# Epoch: 7/10. Validation set: Average loss: 0.0484
# Train: [0/2931 (0%)]	Loss: 0.013780
# Train: [1098/2931 (100%)]	Loss: 0.042068
# Epoch: 8/10. Train set: Average loss: 0.0420
# Epoch: 8/10. Validation set: Average loss: 0.0435
# Train: [0/2931 (0%)]	Loss: 0.071562
# Train: [1098/2931 (100%)]	Loss: 0.033616
# Epoch: 9/10. Train set: Average loss: 0.0337
# Epoch: 9/10. Validation set: Average loss: 0.0362
# Train: [0/2931 (0%)]	Loss: 0.040256
# Train: [1098/2931 (100%)]	Loss: 0.028924
# Epoch: 10/10. Train set: Average loss: 0.0290
# Epoch: 10/10. Validation set: Average loss: 0.0346
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249530
# Train: [1098/2931 (100%)]	Loss: 0.101178
# Epoch: 1/10. Train set: Average loss: 0.1016
# Epoch: 1/10. Validation set: Average loss: 0.0857
# Train: [0/2931 (0%)]	Loss: 0.218910
# Train: [1098/2931 (100%)]	Loss: 0.074323
# Epoch: 2/10. Train set: Average loss: 0.0747
# Epoch: 2/10. Validation set: Average loss: 0.0633
# Train: [0/2931 (0%)]	Loss: 0.096318
# Train: [1098/2931 (100%)]	Loss: 0.057301
# Epoch: 3/10. Train set: Average loss: 0.0574
# Epoch: 3/10. Validation set: Average loss: 0.0550
# Train: [0/2931 (0%)]	Loss: 0.032303
# Train: [1098/2931 (100%)]	Loss: 0.055107
# Epoch: 4/10. Train set: Average loss: 0.0550
# Epoch: 4/10. Validation set: Average loss: 0.0568
# Train: [0/2931 (0%)]	Loss: 0.046089
# Train: [1098/2931 (100%)]	Loss: 0.049229
# Epoch: 5/10. Train set: Average loss: 0.0492
# Epoch: 5/10. Validation set: Average loss: 0.0440
# Train: [0/2931 (0%)]	Loss: 0.039485
# Train: [1098/2931 (100%)]	Loss: 0.040128
# Epoch: 6/10. Train set: Average loss: 0.0401
# Epoch: 6/10. Validation set: Average loss: 0.0473
# Train: [0/2931 (0%)]	Loss: 0.033158
# Train: [1098/2931 (100%)]	Loss: 0.034145
# Epoch: 7/10. Train set: Average loss: 0.0341
# Epoch: 7/10. Validation set: Average loss: 0.0499
# Train: [0/2931 (0%)]	Loss: 0.032616
# Train: [1098/2931 (100%)]	Loss: 0.038662
# Epoch: 8/10. Train set: Average loss: 0.0386
# Epoch: 8/10. Validation set: Average loss: 0.0348
# Train: [0/2931 (0%)]	Loss: 0.005579
# Train: [1098/2931 (100%)]	Loss: 0.027355
# Epoch: 9/10. Train set: Average loss: 0.0273
# Epoch: 9/10. Validation set: Average loss: 0.0326
# Train: [0/2931 (0%)]	Loss: 0.009157
# Train: [1098/2931 (100%)]	Loss: 0.023680
# Epoch: 10/10. Train set: Average loss: 0.0236
# Epoch: 10/10. Validation set: Average loss: 0.0304
# Number features: 61
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.311941
# Train: [1098/2931 (100%)]	Loss: 0.092004
# Epoch: 1/10. Train set: Average loss: 0.0926
# Epoch: 1/10. Validation set: Average loss: 0.0987
# Train: [0/2931 (0%)]	Loss: 0.139197
# Train: [1098/2931 (100%)]	Loss: 0.067484
# Epoch: 2/10. Train set: Average loss: 0.0677
# Epoch: 2/10. Validation set: Average loss: 0.0844
# Train: [0/2931 (0%)]	Loss: 0.066328
# Train: [1098/2931 (100%)]	Loss: 0.060746
# Epoch: 3/10. Train set: Average loss: 0.0608
# Epoch: 3/10. Validation set: Average loss: 0.0701
# Train: [0/2931 (0%)]	Loss: 0.043268
# Train: [1098/2931 (100%)]	Loss: 0.051263
# Epoch: 4/10. Train set: Average loss: 0.0512
# Epoch: 4/10. Validation set: Average loss: 0.0554
# Train: [0/2931 (0%)]	Loss: 0.031227
# Train: [1098/2931 (100%)]	Loss: 0.040979
# Epoch: 5/10. Train set: Average loss: 0.0410
# Epoch: 5/10. Validation set: Average loss: 0.0505
# Train: [0/2931 (0%)]	Loss: 0.045292
# Train: [1098/2931 (100%)]	Loss: 0.037644
# Epoch: 6/10. Train set: Average loss: 0.0377
# Epoch: 6/10. Validation set: Average loss: 0.0514
# Train: [0/2931 (0%)]	Loss: 0.058743
# Train: [1098/2931 (100%)]	Loss: 0.034451
# Epoch: 7/10. Train set: Average loss: 0.0345
# Epoch: 7/10. Validation set: Average loss: 0.0521
# Train: [0/2931 (0%)]	Loss: 0.021782
# Train: [1098/2931 (100%)]	Loss: 0.032524
# Epoch: 8/10. Train set: Average loss: 0.0325
# Epoch: 8/10. Validation set: Average loss: 0.0426
# Train: [0/2931 (0%)]	Loss: 0.010255
# Train: [1098/2931 (100%)]	Loss: 0.025342
# Epoch: 9/10. Train set: Average loss: 0.0253
# Epoch: 9/10. Validation set: Average loss: 0.0390
# Train: [0/2931 (0%)]	Loss: 0.005339
# Train: [1098/2931 (100%)]	Loss: 0.018879
# Epoch: 10/10. Train set: Average loss: 0.0188
# Epoch: 10/10. Validation set: Average loss: 0.0369
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.374623
# Train: [1098/2931 (100%)]	Loss: 0.100248
# Epoch: 1/10. Train set: Average loss: 0.1010
# Epoch: 1/10. Validation set: Average loss: 0.0990
# Train: [0/2931 (0%)]	Loss: 0.190600
# Train: [1098/2931 (100%)]	Loss: 0.073226
# Epoch: 2/10. Train set: Average loss: 0.0735
# Epoch: 2/10. Validation set: Average loss: 0.0700
# Train: [0/2931 (0%)]	Loss: 0.108956
# Train: [1098/2931 (100%)]	Loss: 0.063395
# Epoch: 3/10. Train set: Average loss: 0.0635
# Epoch: 3/10. Validation set: Average loss: 0.0677
# Train: [0/2931 (0%)]	Loss: 0.073407
# Train: [1098/2931 (100%)]	Loss: 0.058407
# Epoch: 4/10. Train set: Average loss: 0.0584
# Epoch: 4/10. Validation set: Average loss: 0.0616
# Train: [0/2931 (0%)]	Loss: 0.037602
# Train: [1098/2931 (100%)]	Loss: 0.043713
# Epoch: 5/10. Train set: Average loss: 0.0437
# Epoch: 5/10. Validation set: Average loss: 0.0652
# Train: [0/2931 (0%)]	Loss: 0.079400
# Train: [1098/2931 (100%)]	Loss: 0.040808
# Epoch: 6/10. Train set: Average loss: 0.0409
# Epoch: 6/10. Validation set: Average loss: 0.0491
# Train: [0/2931 (0%)]	Loss: 0.109329
# Train: [1098/2931 (100%)]	Loss: 0.035969
# Epoch: 7/10. Train set: Average loss: 0.0362
# Epoch: 7/10. Validation set: Average loss: 0.0626
# Train: [0/2931 (0%)]	Loss: 0.090147
# Train: [1098/2931 (100%)]	Loss: 0.035147
# Epoch: 8/10. Train set: Average loss: 0.0353
# Epoch: 8/10. Validation set: Average loss: 0.0570
# Train: [0/2931 (0%)]	Loss: 0.036723
# Train: [1098/2931 (100%)]	Loss: 0.026058
# Epoch: 9/10. Train set: Average loss: 0.0261
# Epoch: 9/10. Validation set: Average loss: 0.0356
# Train: [0/2931 (0%)]	Loss: 0.016011
# Train: [1098/2931 (100%)]	Loss: 0.020754
# Epoch: 10/10. Train set: Average loss: 0.0207
# Epoch: 10/10. Validation set: Average loss: 0.0334
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.311373
# Train: [1098/2931 (100%)]	Loss: 0.095171
# Epoch: 1/10. Train set: Average loss: 0.0958
# Epoch: 1/10. Validation set: Average loss: 0.0924
# Train: [0/2931 (0%)]	Loss: 0.086341
# Train: [1098/2931 (100%)]	Loss: 0.066139
# Epoch: 2/10. Train set: Average loss: 0.0662
# Epoch: 2/10. Validation set: Average loss: 0.0838
# Train: [0/2931 (0%)]	Loss: 0.082449
# Train: [1098/2931 (100%)]	Loss: 0.063756
# Epoch: 3/10. Train set: Average loss: 0.0638
# Epoch: 3/10. Validation set: Average loss: 0.1160
# Train: [0/2931 (0%)]	Loss: 0.181493
# Train: [1098/2931 (100%)]	Loss: 0.052669
# Epoch: 4/10. Train set: Average loss: 0.0530
# Epoch: 4/10. Validation set: Average loss: 0.0590
# Train: [0/2931 (0%)]	Loss: 0.085059
# Train: [1098/2931 (100%)]	Loss: 0.050122
# Epoch: 5/10. Train set: Average loss: 0.0502
# Epoch: 5/10. Validation set: Average loss: 0.0544
# Train: [0/2931 (0%)]	Loss: 0.107953
# Train: [1098/2931 (100%)]	Loss: 0.045701
# Epoch: 6/10. Train set: Average loss: 0.0459
# Epoch: 6/10. Validation set: Average loss: 0.0523
# Train: [0/2931 (0%)]	Loss: 0.082620
# Train: [1098/2931 (100%)]	Loss: 0.041637
# Epoch: 7/10. Train set: Average loss: 0.0417
# Epoch: 7/10. Validation set: Average loss: 0.0741
# Train: [0/2931 (0%)]	Loss: 0.102572
# Train: [1098/2931 (100%)]	Loss: 0.037077
# Epoch: 8/10. Train set: Average loss: 0.0373
# Epoch: 8/10. Validation set: Average loss: 0.0481
# Train: [0/2931 (0%)]	Loss: 0.022044
# Train: [1098/2931 (100%)]	Loss: 0.025726
# Epoch: 9/10. Train set: Average loss: 0.0257
# Epoch: 9/10. Validation set: Average loss: 0.0387
# Train: [0/2931 (0%)]	Loss: 0.011939
# Train: [1098/2931 (100%)]	Loss: 0.023755
# Epoch: 10/10. Train set: Average loss: 0.0237
# Epoch: 10/10. Validation set: Average loss: 0.0349
# Number features: 81
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.124752
# Train: [1098/2931 (100%)]	Loss: 0.092050
# Epoch: 1/10. Train set: Average loss: 0.0921
# Epoch: 1/10. Validation set: Average loss: 0.0559
# Train: [0/2931 (0%)]	Loss: 0.033574
# Train: [1098/2931 (100%)]	Loss: 0.054683
# Epoch: 2/10. Train set: Average loss: 0.0546
# Epoch: 2/10. Validation set: Average loss: 0.0535
# Train: [0/2931 (0%)]	Loss: 0.033968
# Train: [1098/2931 (100%)]	Loss: 0.045225
# Epoch: 3/10. Train set: Average loss: 0.0452
# Epoch: 3/10. Validation set: Average loss: 0.0587
# Train: [0/2931 (0%)]	Loss: 0.015867
# Train: [1098/2931 (100%)]	Loss: 0.048197
# Epoch: 4/10. Train set: Average loss: 0.0481
# Epoch: 4/10. Validation set: Average loss: 0.0507
# Train: [0/2931 (0%)]	Loss: 0.080252
# Train: [1098/2931 (100%)]	Loss: 0.039996
# Epoch: 5/10. Train set: Average loss: 0.0401
# Epoch: 5/10. Validation set: Average loss: 0.0426
# Train: [0/2931 (0%)]	Loss: 0.087048
# Train: [1098/2931 (100%)]	Loss: 0.034849
# Epoch: 6/10. Train set: Average loss: 0.0350
# Epoch: 6/10. Validation set: Average loss: 0.0398
# Train: [0/2931 (0%)]	Loss: 0.019728
# Train: [1098/2931 (100%)]	Loss: 0.033375
# Epoch: 7/10. Train set: Average loss: 0.0333
# Epoch: 7/10. Validation set: Average loss: 0.0402
# Train: [0/2931 (0%)]	Loss: 0.039152
# Train: [1098/2931 (100%)]	Loss: 0.036727
# Epoch: 8/10. Train set: Average loss: 0.0367
# Epoch: 8/10. Validation set: Average loss: 0.0406
# Train: [0/2931 (0%)]	Loss: 0.014913
# Train: [1098/2931 (100%)]	Loss: 0.024688
# Epoch: 9/10. Train set: Average loss: 0.0247
# Epoch: 9/10. Validation set: Average loss: 0.0291
# Train: [0/2931 (0%)]	Loss: 0.013004
# Train: [1098/2931 (100%)]	Loss: 0.021938
# Epoch: 10/10. Train set: Average loss: 0.0219
# Epoch: 10/10. Validation set: Average loss: 0.0274
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249208
# Train: [1098/2931 (100%)]	Loss: 0.070055
# Epoch: 1/10. Train set: Average loss: 0.0705
# Epoch: 1/10. Validation set: Average loss: 0.0629
# Train: [0/2931 (0%)]	Loss: 0.020501
# Train: [1098/2931 (100%)]	Loss: 0.054441
# Epoch: 2/10. Train set: Average loss: 0.0543
# Epoch: 2/10. Validation set: Average loss: 0.0646
# Train: [0/2931 (0%)]	Loss: 0.061277
# Train: [1098/2931 (100%)]	Loss: 0.042867
# Epoch: 3/10. Train set: Average loss: 0.0429
# Epoch: 3/10. Validation set: Average loss: 0.0408
# Train: [0/2931 (0%)]	Loss: 0.025965
# Train: [1098/2931 (100%)]	Loss: 0.040188
# Epoch: 4/10. Train set: Average loss: 0.0401
# Epoch: 4/10. Validation set: Average loss: 0.0390
# Train: [0/2931 (0%)]	Loss: 0.027290
# Train: [1098/2931 (100%)]	Loss: 0.034822
# Epoch: 5/10. Train set: Average loss: 0.0348
# Epoch: 5/10. Validation set: Average loss: 0.0371
# Train: [0/2931 (0%)]	Loss: 0.014696
# Train: [1098/2931 (100%)]	Loss: 0.032330
# Epoch: 6/10. Train set: Average loss: 0.0323
# Epoch: 6/10. Validation set: Average loss: 0.0376
# Train: [0/2931 (0%)]	Loss: 0.034845
# Train: [1098/2931 (100%)]	Loss: 0.031930
# Epoch: 7/10. Train set: Average loss: 0.0319
# Epoch: 7/10. Validation set: Average loss: 0.0396
# Train: [0/2931 (0%)]	Loss: 0.014799
# Train: [1098/2931 (100%)]	Loss: 0.030614
# Epoch: 8/10. Train set: Average loss: 0.0306
# Epoch: 8/10. Validation set: Average loss: 0.0337
# Train: [0/2931 (0%)]	Loss: 0.022791
# Train: [1098/2931 (100%)]	Loss: 0.021233
# Epoch: 9/10. Train set: Average loss: 0.0212
# Epoch: 9/10. Validation set: Average loss: 0.0271
# Train: [0/2931 (0%)]	Loss: 0.004856
# Train: [1098/2931 (100%)]	Loss: 0.019455
# Epoch: 10/10. Train set: Average loss: 0.0194
# Epoch: 10/10. Validation set: Average loss: 0.0263
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249705
# Train: [1098/2931 (100%)]	Loss: 0.073900
# Epoch: 1/10. Train set: Average loss: 0.0744
# Epoch: 1/10. Validation set: Average loss: 0.0689
# Train: [0/2931 (0%)]	Loss: 0.111490
# Train: [1098/2931 (100%)]	Loss: 0.069118
# Epoch: 2/10. Train set: Average loss: 0.0692
# Epoch: 2/10. Validation set: Average loss: 0.0623
# Train: [0/2931 (0%)]	Loss: 0.055684
# Train: [1098/2931 (100%)]	Loss: 0.059487
# Epoch: 3/10. Train set: Average loss: 0.0595
# Epoch: 3/10. Validation set: Average loss: 0.0767
# Train: [0/2931 (0%)]	Loss: 0.072525
# Train: [1098/2931 (100%)]	Loss: 0.057644
# Epoch: 4/10. Train set: Average loss: 0.0577
# Epoch: 4/10. Validation set: Average loss: 0.0519
# Train: [0/2931 (0%)]	Loss: 0.030341
# Train: [1098/2931 (100%)]	Loss: 0.043153
# Epoch: 5/10. Train set: Average loss: 0.0431
# Epoch: 5/10. Validation set: Average loss: 0.0471
# Train: [0/2931 (0%)]	Loss: 0.057727
# Train: [1098/2931 (100%)]	Loss: 0.038287
# Epoch: 6/10. Train set: Average loss: 0.0383
# Epoch: 6/10. Validation set: Average loss: 0.0405
# Train: [0/2931 (0%)]	Loss: 0.043193
# Train: [1098/2931 (100%)]	Loss: 0.038031
# Epoch: 7/10. Train set: Average loss: 0.0380
# Epoch: 7/10. Validation set: Average loss: 0.0385
# Train: [0/2931 (0%)]	Loss: 0.033832
# Train: [1098/2931 (100%)]	Loss: 0.033345
# Epoch: 8/10. Train set: Average loss: 0.0333
# Epoch: 8/10. Validation set: Average loss: 0.0416
# Train: [0/2931 (0%)]	Loss: 0.052273
# Train: [1098/2931 (100%)]	Loss: 0.029483
# Epoch: 9/10. Train set: Average loss: 0.0295
# Epoch: 9/10. Validation set: Average loss: 0.0325
# Train: [0/2931 (0%)]	Loss: 0.011943
# Train: [1098/2931 (100%)]	Loss: 0.028085
# Epoch: 10/10. Train set: Average loss: 0.0280
# Epoch: 10/10. Validation set: Average loss: 0.0306
# Number features: 101
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.374340
# Train: [1098/2931 (100%)]	Loss: 0.084692
# Epoch: 1/10. Train set: Average loss: 0.0855
# Epoch: 1/10. Validation set: Average loss: 0.0648
# Train: [0/2931 (0%)]	Loss: 0.106144
# Train: [1098/2931 (100%)]	Loss: 0.058775
# Epoch: 2/10. Train set: Average loss: 0.0589
# Epoch: 2/10. Validation set: Average loss: 0.0614
# Train: [0/2931 (0%)]	Loss: 0.042288
# Train: [1098/2931 (100%)]	Loss: 0.051260
# Epoch: 3/10. Train set: Average loss: 0.0512
# Epoch: 3/10. Validation set: Average loss: 0.0527
# Train: [0/2931 (0%)]	Loss: 0.067636
# Train: [1098/2931 (100%)]	Loss: 0.051966
# Epoch: 4/10. Train set: Average loss: 0.0520
# Epoch: 4/10. Validation set: Average loss: 0.0548
# Train: [0/2931 (0%)]	Loss: 0.034115
# Train: [1098/2931 (100%)]	Loss: 0.047747
# Epoch: 5/10. Train set: Average loss: 0.0477
# Epoch: 5/10. Validation set: Average loss: 0.0509
# Train: [0/2931 (0%)]	Loss: 0.104719
# Train: [1098/2931 (100%)]	Loss: 0.044406
# Epoch: 6/10. Train set: Average loss: 0.0446
# Epoch: 6/10. Validation set: Average loss: 0.0503
# Train: [0/2931 (0%)]	Loss: 0.085434
# Train: [1098/2931 (100%)]	Loss: 0.043502
# Epoch: 7/10. Train set: Average loss: 0.0436
# Epoch: 7/10. Validation set: Average loss: 0.0418
# Train: [0/2931 (0%)]	Loss: 0.021826
# Train: [1098/2931 (100%)]	Loss: 0.040251
# Epoch: 8/10. Train set: Average loss: 0.0402
# Epoch: 8/10. Validation set: Average loss: 0.0470
# Train: [0/2931 (0%)]	Loss: 0.000616
# Train: [1098/2931 (100%)]	Loss: 0.036392
# Epoch: 9/10. Train set: Average loss: 0.0363
# Epoch: 9/10. Validation set: Average loss: 0.0360
# Train: [0/2931 (0%)]	Loss: 0.042932
# Train: [1098/2931 (100%)]	Loss: 0.032652
# Epoch: 10/10. Train set: Average loss: 0.0327
# Epoch: 10/10. Validation set: Average loss: 0.0348
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.311905
# Train: [1098/2931 (100%)]	Loss: 0.079411
# Epoch: 1/10. Train set: Average loss: 0.0800
# Epoch: 1/10. Validation set: Average loss: 0.0739
# Train: [0/2931 (0%)]	Loss: 0.087834
# Train: [1098/2931 (100%)]	Loss: 0.066026
# Epoch: 2/10. Train set: Average loss: 0.0661
# Epoch: 2/10. Validation set: Average loss: 0.0620
# Train: [0/2931 (0%)]	Loss: 0.040469
# Train: [1098/2931 (100%)]	Loss: 0.056981
# Epoch: 3/10. Train set: Average loss: 0.0569
# Epoch: 3/10. Validation set: Average loss: 0.0537
# Train: [0/2931 (0%)]	Loss: 0.077985
# Train: [1098/2931 (100%)]	Loss: 0.049669
# Epoch: 4/10. Train set: Average loss: 0.0497
# Epoch: 4/10. Validation set: Average loss: 0.0532
# Train: [0/2931 (0%)]	Loss: 0.099147
# Train: [1098/2931 (100%)]	Loss: 0.047489
# Epoch: 5/10. Train set: Average loss: 0.0476
# Epoch: 5/10. Validation set: Average loss: 0.0635
# Train: [0/2931 (0%)]	Loss: 0.047993
# Train: [1098/2931 (100%)]	Loss: 0.049874
# Epoch: 6/10. Train set: Average loss: 0.0499
# Epoch: 6/10. Validation set: Average loss: 0.0432
# Train: [0/2931 (0%)]	Loss: 0.034542
# Train: [1098/2931 (100%)]	Loss: 0.044110
# Epoch: 7/10. Train set: Average loss: 0.0441
# Epoch: 7/10. Validation set: Average loss: 0.0432
# Train: [0/2931 (0%)]	Loss: 0.026228
# Train: [1098/2931 (100%)]	Loss: 0.042924
# Epoch: 8/10. Train set: Average loss: 0.0429
# Epoch: 8/10. Validation set: Average loss: 0.0404
# Train: [0/2931 (0%)]	Loss: 0.080779
# Train: [1098/2931 (100%)]	Loss: 0.031486
# Epoch: 9/10. Train set: Average loss: 0.0316
# Epoch: 9/10. Validation set: Average loss: 0.0335
# Train: [0/2931 (0%)]	Loss: 0.013762
# Train: [1098/2931 (100%)]	Loss: 0.031700
# Epoch: 10/10. Train set: Average loss: 0.0317
# Epoch: 10/10. Validation set: Average loss: 0.0318
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.186913
# Train: [1098/2931 (100%)]	Loss: 0.092788
# Epoch: 1/10. Train set: Average loss: 0.0930
# Epoch: 1/10. Validation set: Average loss: 0.0880
# Train: [0/2931 (0%)]	Loss: 0.059663
# Train: [1098/2931 (100%)]	Loss: 0.072969
# Epoch: 2/10. Train set: Average loss: 0.0729
# Epoch: 2/10. Validation set: Average loss: 0.0727
# Train: [0/2931 (0%)]	Loss: 0.053981
# Train: [1098/2931 (100%)]	Loss: 0.054878
# Epoch: 3/10. Train set: Average loss: 0.0549
# Epoch: 3/10. Validation set: Average loss: 0.0511
# Train: [0/2931 (0%)]	Loss: 0.064142
# Train: [1098/2931 (100%)]	Loss: 0.057836
# Epoch: 4/10. Train set: Average loss: 0.0579
# Epoch: 4/10. Validation set: Average loss: 0.0497
# Train: [0/2931 (0%)]	Loss: 0.054610
# Train: [1098/2931 (100%)]	Loss: 0.048110
# Epoch: 5/10. Train set: Average loss: 0.0481
# Epoch: 5/10. Validation set: Average loss: 0.0455
# Train: [0/2931 (0%)]	Loss: 0.026097
# Train: [1098/2931 (100%)]	Loss: 0.052515
# Epoch: 6/10. Train set: Average loss: 0.0524
# Epoch: 6/10. Validation set: Average loss: 0.0551
# Train: [0/2931 (0%)]	Loss: 0.082988
# Train: [1098/2931 (100%)]	Loss: 0.048034
# Epoch: 7/10. Train set: Average loss: 0.0481
# Epoch: 7/10. Validation set: Average loss: 0.0497
# Train: [0/2931 (0%)]	Loss: 0.080203
# Train: [1098/2931 (100%)]	Loss: 0.044425
# Epoch: 8/10. Train set: Average loss: 0.0445
# Epoch: 8/10. Validation set: Average loss: 0.0422
# Train: [0/2931 (0%)]	Loss: 0.031424
# Train: [1098/2931 (100%)]	Loss: 0.035692
# Epoch: 9/10. Train set: Average loss: 0.0357
# Epoch: 9/10. Validation set: Average loss: 0.0371
# Train: [0/2931 (0%)]	Loss: 0.029525
# Train: [1098/2931 (100%)]	Loss: 0.033118
# Epoch: 10/10. Train set: Average loss: 0.0331
# Epoch: 10/10. Validation set: Average loss: 0.0360
# Number features: 122
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.311037
# Train: [1098/2931 (100%)]	Loss: 0.067163
# Epoch: 1/10. Train set: Average loss: 0.0678
# Epoch: 1/10. Validation set: Average loss: 0.0450
# Train: [0/2931 (0%)]	Loss: 0.047617
# Train: [1098/2931 (100%)]	Loss: 0.051741
# Epoch: 2/10. Train set: Average loss: 0.0517
# Epoch: 2/10. Validation set: Average loss: 0.0442
# Train: [0/2931 (0%)]	Loss: 0.014318
# Train: [1098/2931 (100%)]	Loss: 0.050907
# Epoch: 3/10. Train set: Average loss: 0.0508
# Epoch: 3/10. Validation set: Average loss: 0.0401
# Train: [0/2931 (0%)]	Loss: 0.070363
# Train: [1098/2931 (100%)]	Loss: 0.043457
# Epoch: 4/10. Train set: Average loss: 0.0435
# Epoch: 4/10. Validation set: Average loss: 0.0485
# Train: [0/2931 (0%)]	Loss: 0.031789
# Train: [1098/2931 (100%)]	Loss: 0.035988
# Epoch: 5/10. Train set: Average loss: 0.0360
# Epoch: 5/10. Validation set: Average loss: 0.0332
# Train: [0/2931 (0%)]	Loss: 0.063086
# Train: [1098/2931 (100%)]	Loss: 0.038469
# Epoch: 6/10. Train set: Average loss: 0.0385
# Epoch: 6/10. Validation set: Average loss: 0.0554
# Train: [0/2931 (0%)]	Loss: 0.045678
# Train: [1098/2931 (100%)]	Loss: 0.033921
# Epoch: 7/10. Train set: Average loss: 0.0340
# Epoch: 7/10. Validation set: Average loss: 0.0465
# Train: [0/2931 (0%)]	Loss: 0.006446
# Train: [1098/2931 (100%)]	Loss: 0.032310
# Epoch: 8/10. Train set: Average loss: 0.0322
# Epoch: 8/10. Validation set: Average loss: 0.0508
# Train: [0/2931 (0%)]	Loss: 0.172053
# Train: [1098/2931 (100%)]	Loss: 0.027849
# Epoch: 9/10. Train set: Average loss: 0.0282
# Epoch: 9/10. Validation set: Average loss: 0.0316
# Train: [0/2931 (0%)]	Loss: 0.030048
# Train: [1098/2931 (100%)]	Loss: 0.024411
# Epoch: 10/10. Train set: Average loss: 0.0244
# Epoch: 10/10. Validation set: Average loss: 0.0293
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249312
# Train: [1098/2931 (100%)]	Loss: 0.064497
# Epoch: 1/10. Train set: Average loss: 0.0650
# Epoch: 1/10. Validation set: Average loss: 0.0537
# Train: [0/2931 (0%)]	Loss: 0.059205
# Train: [1098/2931 (100%)]	Loss: 0.054017
# Epoch: 2/10. Train set: Average loss: 0.0540
# Epoch: 2/10. Validation set: Average loss: 0.0540
# Train: [0/2931 (0%)]	Loss: 0.030204
# Train: [1098/2931 (100%)]	Loss: 0.054998
# Epoch: 3/10. Train set: Average loss: 0.0549
# Epoch: 3/10. Validation set: Average loss: 0.0496
# Train: [0/2931 (0%)]	Loss: 0.030280
# Train: [1098/2931 (100%)]	Loss: 0.043862
# Epoch: 4/10. Train set: Average loss: 0.0438
# Epoch: 4/10. Validation set: Average loss: 0.0428
# Train: [0/2931 (0%)]	Loss: 0.060042
# Train: [1098/2931 (100%)]	Loss: 0.041423
# Epoch: 5/10. Train set: Average loss: 0.0415
# Epoch: 5/10. Validation set: Average loss: 0.0383
# Train: [0/2931 (0%)]	Loss: 0.009734
# Train: [1098/2931 (100%)]	Loss: 0.040197
# Epoch: 6/10. Train set: Average loss: 0.0401
# Epoch: 6/10. Validation set: Average loss: 0.0369
# Train: [0/2931 (0%)]	Loss: 0.029847
# Train: [1098/2931 (100%)]	Loss: 0.038656
# Epoch: 7/10. Train set: Average loss: 0.0386
# Epoch: 7/10. Validation set: Average loss: 0.0405
# Train: [0/2931 (0%)]	Loss: 0.027891
# Train: [1098/2931 (100%)]	Loss: 0.033436
# Epoch: 8/10. Train set: Average loss: 0.0334
# Epoch: 8/10. Validation set: Average loss: 0.0447
# Train: [0/2931 (0%)]	Loss: 0.250017
# Train: [1098/2931 (100%)]	Loss: 0.027921
# Epoch: 9/10. Train set: Average loss: 0.0285
# Epoch: 9/10. Validation set: Average loss: 0.0281
# Train: [0/2931 (0%)]	Loss: 0.009034
# Train: [1098/2931 (100%)]	Loss: 0.023330
# Epoch: 10/10. Train set: Average loss: 0.0233
# Epoch: 10/10. Validation set: Average loss: 0.0267
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.310804
# Train: [1098/2931 (100%)]	Loss: 0.069548
# Epoch: 1/10. Train set: Average loss: 0.0702
# Epoch: 1/10. Validation set: Average loss: 0.0513
# Train: [0/2931 (0%)]	Loss: 0.104347
# Train: [1098/2931 (100%)]	Loss: 0.046854
# Epoch: 2/10. Train set: Average loss: 0.0470
# Epoch: 2/10. Validation set: Average loss: 0.0393
# Train: [0/2931 (0%)]	Loss: 0.022311
# Train: [1098/2931 (100%)]	Loss: 0.041085
# Epoch: 3/10. Train set: Average loss: 0.0410
# Epoch: 3/10. Validation set: Average loss: 0.0379
# Train: [0/2931 (0%)]	Loss: 0.031901
# Train: [1098/2931 (100%)]	Loss: 0.037850
# Epoch: 4/10. Train set: Average loss: 0.0378
# Epoch: 4/10. Validation set: Average loss: 0.0370
# Train: [0/2931 (0%)]	Loss: 0.034839
# Train: [1098/2931 (100%)]	Loss: 0.036013
# Epoch: 5/10. Train set: Average loss: 0.0360
# Epoch: 5/10. Validation set: Average loss: 0.0501
# Train: [0/2931 (0%)]	Loss: 0.022894
# Train: [1098/2931 (100%)]	Loss: 0.041899
# Epoch: 6/10. Train set: Average loss: 0.0418
# Epoch: 6/10. Validation set: Average loss: 0.0407
# Train: [0/2931 (0%)]	Loss: 0.034559
# Train: [1098/2931 (100%)]	Loss: 0.038380
# Epoch: 7/10. Train set: Average loss: 0.0384
# Epoch: 7/10. Validation set: Average loss: 0.0356
# Train: [0/2931 (0%)]	Loss: 0.003158
# Train: [1098/2931 (100%)]	Loss: 0.033299
# Epoch: 8/10. Train set: Average loss: 0.0332
# Epoch: 8/10. Validation set: Average loss: 0.0312
# Train: [0/2931 (0%)]	Loss: 0.065906
# Train: [1098/2931 (100%)]	Loss: 0.026149
# Epoch: 9/10. Train set: Average loss: 0.0263
# Epoch: 9/10. Validation set: Average loss: 0.0273
# Train: [0/2931 (0%)]	Loss: 0.008501
# Train: [1098/2931 (100%)]	Loss: 0.024910
# Epoch: 10/10. Train set: Average loss: 0.0249
# Epoch: 10/10. Validation set: Average loss: 0.0272
# Number features: 142
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.435959
# Train: [1098/2931 (100%)]	Loss: 0.078262
# Epoch: 1/10. Train set: Average loss: 0.0792
# Epoch: 1/10. Validation set: Average loss: 0.0750
# Train: [0/2931 (0%)]	Loss: 0.029738
# Train: [1098/2931 (100%)]	Loss: 0.054988
# Epoch: 2/10. Train set: Average loss: 0.0549
# Epoch: 2/10. Validation set: Average loss: 0.0554
# Train: [0/2931 (0%)]	Loss: 0.060037
# Train: [1098/2931 (100%)]	Loss: 0.053943
# Epoch: 3/10. Train set: Average loss: 0.0540
# Epoch: 3/10. Validation set: Average loss: 0.0560
# Train: [0/2931 (0%)]	Loss: 0.031229
# Train: [1098/2931 (100%)]	Loss: 0.046476
# Epoch: 4/10. Train set: Average loss: 0.0464
# Epoch: 4/10. Validation set: Average loss: 0.0554
# Train: [0/2931 (0%)]	Loss: 0.037169
# Train: [1098/2931 (100%)]	Loss: 0.044242
# Epoch: 5/10. Train set: Average loss: 0.0442
# Epoch: 5/10. Validation set: Average loss: 0.0522
# Train: [0/2931 (0%)]	Loss: 0.050637
# Train: [1098/2931 (100%)]	Loss: 0.040315
# Epoch: 6/10. Train set: Average loss: 0.0403
# Epoch: 6/10. Validation set: Average loss: 0.0512
# Train: [0/2931 (0%)]	Loss: 0.087876
# Train: [1098/2931 (100%)]	Loss: 0.040867
# Epoch: 7/10. Train set: Average loss: 0.0410
# Epoch: 7/10. Validation set: Average loss: 0.0456
# Train: [0/2931 (0%)]	Loss: 0.014308
# Train: [1098/2931 (100%)]	Loss: 0.039058
# Epoch: 8/10. Train set: Average loss: 0.0390
# Epoch: 8/10. Validation set: Average loss: 0.0467
# Train: [0/2931 (0%)]	Loss: 0.059996
# Train: [1098/2931 (100%)]	Loss: 0.031361
# Epoch: 9/10. Train set: Average loss: 0.0314
# Epoch: 9/10. Validation set: Average loss: 0.0384
# Train: [0/2931 (0%)]	Loss: 0.017905
# Train: [1098/2931 (100%)]	Loss: 0.029347
# Epoch: 10/10. Train set: Average loss: 0.0293
# Epoch: 10/10. Validation set: Average loss: 0.0369
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.310940
# Train: [1098/2931 (100%)]	Loss: 0.091888
# Epoch: 1/10. Train set: Average loss: 0.0925
# Epoch: 1/10. Validation set: Average loss: 0.0555
# Train: [0/2931 (0%)]	Loss: 0.046914
# Train: [1098/2931 (100%)]	Loss: 0.051353
# Epoch: 2/10. Train set: Average loss: 0.0513
# Epoch: 2/10. Validation set: Average loss: 0.0448
# Train: [0/2931 (0%)]	Loss: 0.029672
# Train: [1098/2931 (100%)]	Loss: 0.047083
# Epoch: 3/10. Train set: Average loss: 0.0470
# Epoch: 3/10. Validation set: Average loss: 0.0470
# Train: [0/2931 (0%)]	Loss: 0.084333
# Train: [1098/2931 (100%)]	Loss: 0.043553
# Epoch: 4/10. Train set: Average loss: 0.0437
# Epoch: 4/10. Validation set: Average loss: 0.0527
# Train: [0/2931 (0%)]	Loss: 0.044924
# Train: [1098/2931 (100%)]	Loss: 0.045809
# Epoch: 5/10. Train set: Average loss: 0.0458
# Epoch: 5/10. Validation set: Average loss: 0.0506
# Train: [0/2931 (0%)]	Loss: 0.024731
# Train: [1098/2931 (100%)]	Loss: 0.039294
# Epoch: 6/10. Train set: Average loss: 0.0393
# Epoch: 6/10. Validation set: Average loss: 0.0379
# Train: [0/2931 (0%)]	Loss: 0.020928
# Train: [1098/2931 (100%)]	Loss: 0.031072
# Epoch: 7/10. Train set: Average loss: 0.0310
# Epoch: 7/10. Validation set: Average loss: 0.0381
# Train: [0/2931 (0%)]	Loss: 0.037307
# Train: [1098/2931 (100%)]	Loss: 0.033092
# Epoch: 8/10. Train set: Average loss: 0.0331
# Epoch: 8/10. Validation set: Average loss: 0.0403
# Train: [0/2931 (0%)]	Loss: 0.032651
# Train: [1098/2931 (100%)]	Loss: 0.026577
# Epoch: 9/10. Train set: Average loss: 0.0266
# Epoch: 9/10. Validation set: Average loss: 0.0299
# Train: [0/2931 (0%)]	Loss: 0.020777
# Train: [1098/2931 (100%)]	Loss: 0.024102
# Epoch: 10/10. Train set: Average loss: 0.0241
# Epoch: 10/10. Validation set: Average loss: 0.0287
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.187124
# Train: [1098/2931 (100%)]	Loss: 0.079129
# Epoch: 1/10. Train set: Average loss: 0.0794
# Epoch: 1/10. Validation set: Average loss: 0.0542
# Train: [0/2931 (0%)]	Loss: 0.076662
# Train: [1098/2931 (100%)]	Loss: 0.049393
# Epoch: 2/10. Train set: Average loss: 0.0495
# Epoch: 2/10. Validation set: Average loss: 0.0453
# Train: [0/2931 (0%)]	Loss: 0.060258
# Train: [1098/2931 (100%)]	Loss: 0.049368
# Epoch: 3/10. Train set: Average loss: 0.0494
# Epoch: 3/10. Validation set: Average loss: 0.0425
# Train: [0/2931 (0%)]	Loss: 0.035741
# Train: [1098/2931 (100%)]	Loss: 0.046173
# Epoch: 4/10. Train set: Average loss: 0.0461
# Epoch: 4/10. Validation set: Average loss: 0.0403
# Train: [0/2931 (0%)]	Loss: 0.033292
# Train: [1098/2931 (100%)]	Loss: 0.041734
# Epoch: 5/10. Train set: Average loss: 0.0417
# Epoch: 5/10. Validation set: Average loss: 0.0404
# Train: [0/2931 (0%)]	Loss: 0.001364
# Train: [1098/2931 (100%)]	Loss: 0.042483
# Epoch: 6/10. Train set: Average loss: 0.0424
# Epoch: 6/10. Validation set: Average loss: 0.0393
# Train: [0/2931 (0%)]	Loss: 0.036162
# Train: [1098/2931 (100%)]	Loss: 0.038005
# Epoch: 7/10. Train set: Average loss: 0.0380
# Epoch: 7/10. Validation set: Average loss: 0.0415
# Train: [0/2931 (0%)]	Loss: 0.070941
# Train: [1098/2931 (100%)]	Loss: 0.036187
# Epoch: 8/10. Train set: Average loss: 0.0363
# Epoch: 8/10. Validation set: Average loss: 0.0357
# Train: [0/2931 (0%)]	Loss: 0.029472
# Train: [1098/2931 (100%)]	Loss: 0.030867
# Epoch: 9/10. Train set: Average loss: 0.0309
# Epoch: 9/10. Validation set: Average loss: 0.0309
# Train: [0/2931 (0%)]	Loss: 0.039499
# Train: [1098/2931 (100%)]	Loss: 0.029787
# Epoch: 10/10. Train set: Average loss: 0.0298
# Epoch: 10/10. Validation set: Average loss: 0.0304
# Number features: 162
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.374712
# Train: [1098/2931 (100%)]	Loss: 0.091348
# Epoch: 1/10. Train set: Average loss: 0.0921
# Epoch: 1/10. Validation set: Average loss: 0.0668
# Train: [0/2931 (0%)]	Loss: 0.018968
# Train: [1098/2931 (100%)]	Loss: 0.062788
# Epoch: 2/10. Train set: Average loss: 0.0627
# Epoch: 2/10. Validation set: Average loss: 0.0638
# Train: [0/2931 (0%)]	Loss: 0.019883
# Train: [1098/2931 (100%)]	Loss: 0.056437
# Epoch: 3/10. Train set: Average loss: 0.0563
# Epoch: 3/10. Validation set: Average loss: 0.0554
# Train: [0/2931 (0%)]	Loss: 0.056369
# Train: [1098/2931 (100%)]	Loss: 0.041100
# Epoch: 4/10. Train set: Average loss: 0.0411
# Epoch: 4/10. Validation set: Average loss: 0.0524
# Train: [0/2931 (0%)]	Loss: 0.070954
# Train: [1098/2931 (100%)]	Loss: 0.046393
# Epoch: 5/10. Train set: Average loss: 0.0465
# Epoch: 5/10. Validation set: Average loss: 0.0494
# Train: [0/2931 (0%)]	Loss: 0.023777
# Train: [1098/2931 (100%)]	Loss: 0.036827
# Epoch: 6/10. Train set: Average loss: 0.0368
# Epoch: 6/10. Validation set: Average loss: 0.0443
# Train: [0/2931 (0%)]	Loss: 0.027288
# Train: [1098/2931 (100%)]	Loss: 0.038240
# Epoch: 7/10. Train set: Average loss: 0.0382
# Epoch: 7/10. Validation set: Average loss: 0.0358
# Train: [0/2931 (0%)]	Loss: 0.024929
# Train: [1098/2931 (100%)]	Loss: 0.031914
# Epoch: 8/10. Train set: Average loss: 0.0319
# Epoch: 8/10. Validation set: Average loss: 0.0374
# Train: [0/2931 (0%)]	Loss: 0.028532
# Train: [1098/2931 (100%)]	Loss: 0.024730
# Epoch: 9/10. Train set: Average loss: 0.0247
# Epoch: 9/10. Validation set: Average loss: 0.0311
# Train: [0/2931 (0%)]	Loss: 0.009143
# Train: [1098/2931 (100%)]	Loss: 0.023684
# Epoch: 10/10. Train set: Average loss: 0.0236
# Epoch: 10/10. Validation set: Average loss: 0.0298
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249240
# Train: [1098/2931 (100%)]	Loss: 0.070610
# Epoch: 1/10. Train set: Average loss: 0.0711
# Epoch: 1/10. Validation set: Average loss: 0.0526
# Train: [0/2931 (0%)]	Loss: 0.022626
# Train: [1098/2931 (100%)]	Loss: 0.046774
# Epoch: 2/10. Train set: Average loss: 0.0467
# Epoch: 2/10. Validation set: Average loss: 0.0612
# Train: [0/2931 (0%)]	Loss: 0.097506
# Train: [1098/2931 (100%)]	Loss: 0.047185
# Epoch: 3/10. Train set: Average loss: 0.0473
# Epoch: 3/10. Validation set: Average loss: 0.0449
# Train: [0/2931 (0%)]	Loss: 0.006886
# Train: [1098/2931 (100%)]	Loss: 0.038809
# Epoch: 4/10. Train set: Average loss: 0.0387
# Epoch: 4/10. Validation set: Average loss: 0.0488
# Train: [0/2931 (0%)]	Loss: 0.029405
# Train: [1098/2931 (100%)]	Loss: 0.040996
# Epoch: 5/10. Train set: Average loss: 0.0410
# Epoch: 5/10. Validation set: Average loss: 0.0471
# Train: [0/2931 (0%)]	Loss: 0.043842
# Train: [1098/2931 (100%)]	Loss: 0.040111
# Epoch: 6/10. Train set: Average loss: 0.0401
# Epoch: 6/10. Validation set: Average loss: 0.0434
# Train: [0/2931 (0%)]	Loss: 0.006452
# Train: [1098/2931 (100%)]	Loss: 0.038600
# Epoch: 7/10. Train set: Average loss: 0.0385
# Epoch: 7/10. Validation set: Average loss: 0.0393
# Train: [0/2931 (0%)]	Loss: 0.009462
# Train: [1098/2931 (100%)]	Loss: 0.034905
# Epoch: 8/10. Train set: Average loss: 0.0348
# Epoch: 8/10. Validation set: Average loss: 0.0380
# Train: [0/2931 (0%)]	Loss: 0.021051
# Train: [1098/2931 (100%)]	Loss: 0.029669
# Epoch: 9/10. Train set: Average loss: 0.0296
# Epoch: 9/10. Validation set: Average loss: 0.0333
# Train: [0/2931 (0%)]	Loss: 0.007770
# Train: [1098/2931 (100%)]	Loss: 0.027911
# Epoch: 10/10. Train set: Average loss: 0.0279
# Epoch: 10/10. Validation set: Average loss: 0.0340
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.187102
# Train: [1098/2931 (100%)]	Loss: 0.082482
# Epoch: 1/10. Train set: Average loss: 0.0828
# Epoch: 1/10. Validation set: Average loss: 0.0655
# Train: [0/2931 (0%)]	Loss: 0.063527
# Train: [1098/2931 (100%)]	Loss: 0.060058
# Epoch: 2/10. Train set: Average loss: 0.0601
# Epoch: 2/10. Validation set: Average loss: 0.0801
# Train: [0/2931 (0%)]	Loss: 0.009901
# Train: [1098/2931 (100%)]	Loss: 0.050624
# Epoch: 3/10. Train set: Average loss: 0.0505
# Epoch: 3/10. Validation set: Average loss: 0.0554
# Train: [0/2931 (0%)]	Loss: 0.005106
# Train: [1098/2931 (100%)]	Loss: 0.044123
# Epoch: 4/10. Train set: Average loss: 0.0440
# Epoch: 4/10. Validation set: Average loss: 0.0472
# Train: [0/2931 (0%)]	Loss: 0.038714
# Train: [1098/2931 (100%)]	Loss: 0.039316
# Epoch: 5/10. Train set: Average loss: 0.0393
# Epoch: 5/10. Validation set: Average loss: 0.0408
# Train: [0/2931 (0%)]	Loss: 0.002047
# Train: [1098/2931 (100%)]	Loss: 0.038481
# Epoch: 6/10. Train set: Average loss: 0.0384
# Epoch: 6/10. Validation set: Average loss: 0.0452
# Train: [0/2931 (0%)]	Loss: 0.005971
# Train: [1098/2931 (100%)]	Loss: 0.038752
# Epoch: 7/10. Train set: Average loss: 0.0387
# Epoch: 7/10. Validation set: Average loss: 0.0503
# Train: [0/2931 (0%)]	Loss: 0.021791
# Train: [1098/2931 (100%)]	Loss: 0.043246
# Epoch: 8/10. Train set: Average loss: 0.0432
# Epoch: 8/10. Validation set: Average loss: 0.0378
# Train: [0/2931 (0%)]	Loss: 0.013580
# Train: [1098/2931 (100%)]	Loss: 0.030699
# Epoch: 9/10. Train set: Average loss: 0.0307
# Epoch: 9/10. Validation set: Average loss: 0.0355
# Train: [0/2931 (0%)]	Loss: 0.008125
# Train: [1098/2931 (100%)]	Loss: 0.030844
# Epoch: 10/10. Train set: Average loss: 0.0308
# Epoch: 10/10. Validation set: Average loss: 0.0346
# Number features: 182
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.062243
# Train: [1098/2931 (100%)]	Loss: 0.060535
# Epoch: 1/10. Train set: Average loss: 0.0605
# Epoch: 1/10. Validation set: Average loss: 0.0599
# Train: [0/2931 (0%)]	Loss: 0.172866
# Train: [1098/2931 (100%)]	Loss: 0.044209
# Epoch: 2/10. Train set: Average loss: 0.0446
# Epoch: 2/10. Validation set: Average loss: 0.0554
# Train: [0/2931 (0%)]	Loss: 0.031551
# Train: [1098/2931 (100%)]	Loss: 0.045495
# Epoch: 3/10. Train set: Average loss: 0.0455
# Epoch: 3/10. Validation set: Average loss: 0.0419
# Train: [0/2931 (0%)]	Loss: 0.028021
# Train: [1098/2931 (100%)]	Loss: 0.036960
# Epoch: 4/10. Train set: Average loss: 0.0369
# Epoch: 4/10. Validation set: Average loss: 0.0418
# Train: [0/2931 (0%)]	Loss: 0.007873
# Train: [1098/2931 (100%)]	Loss: 0.032961
# Epoch: 5/10. Train set: Average loss: 0.0329
# Epoch: 5/10. Validation set: Average loss: 0.0535
# Train: [0/2931 (0%)]	Loss: 0.018736
# ...
# Train: [1098/2931 (100%)]	Loss: 0.038295
# Epoch: 4/10. Train set: Average loss: 0.0383
# Epoch: 4/10. Validation set: Average loss: 0.0458
# Train: [0/2931 (0%)]	Loss: 0.028968
# Train: [1098/2931 (100%)]	Loss: 0.034013
# Epoch: 5/10. Train set: Average loss: 0.0340
# Epoch: 5/10. Validation set: Average loss: 0.0698
# Train: [0/2931 (0%)]	Loss: 0.097539
# Train: [1098/2931 (100%)]	Loss: 0.033410
# Epoch: 6/10. Train set: Average loss: 0.0336
# Epoch: 6/10. Validation set: Average loss: 0.0371
# Train: [0/2931 (0%)]	Loss: 0.032365
# Train: [1098/2931 (100%)]	Loss: 0.029841
# Epoch: 7/10. Train set: Average loss: 0.0298
# Epoch: 7/10. Validation set: Average loss: 0.0385
# Train: [0/2931 (0%)]	Loss: 0.013551
# Train: [1098/2931 (100%)]	Loss: 0.026122
# Epoch: 8/10. Train set: Average loss: 0.0261
# Epoch: 8/10. Validation set: Average loss: 0.0459
# Train: [0/2931 (0%)]	Loss: 0.029615
# Train: [1098/2931 (100%)]	Loss: 0.020206
# Epoch: 9/10. Train set: Average loss: 0.0202
# Epoch: 9/10. Validation set: Average loss: 0.0300
# Train: [0/2931 (0%)]	Loss: 0.007122
# Train: [1098/2931 (100%)]	Loss: 0.018604
# Epoch: 10/10. Train set: Average loss: 0.0186
# Epoch: 10/10. Validation set: Average loss: 0.0289
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.124802
# Train: [1098/2931 (100%)]	Loss: 0.072483
# Epoch: 1/10. Train set: Average loss: 0.0726
# Epoch: 1/10. Validation set: Average loss: 0.0615
# Train: [0/2931 (0%)]	Loss: 0.035584
# Train: [1098/2931 (100%)]	Loss: 0.045030
# Epoch: 2/10. Train set: Average loss: 0.0450
# Epoch: 2/10. Validation set: Average loss: 0.0539
# Train: [0/2931 (0%)]	Loss: 0.050229
# Train: [1098/2931 (100%)]	Loss: 0.048417
# Epoch: 3/10. Train set: Average loss: 0.0484
# Epoch: 3/10. Validation set: Average loss: 0.0589
# Train: [0/2931 (0%)]	Loss: 0.026551
# Train: [1098/2931 (100%)]	Loss: 0.041281
# Epoch: 4/10. Train set: Average loss: 0.0412
# Epoch: 4/10. Validation set: Average loss: 0.0477
# Train: [0/2931 (0%)]	Loss: 0.011236
# Train: [1098/2931 (100%)]	Loss: 0.037923
# Epoch: 5/10. Train set: Average loss: 0.0379
# Epoch: 5/10. Validation set: Average loss: 0.0644
# Train: [0/2931 (0%)]	Loss: 0.057292
# Train: [1098/2931 (100%)]	Loss: 0.036491
# Epoch: 6/10. Train set: Average loss: 0.0365
# Epoch: 6/10. Validation set: Average loss: 0.0448
# Train: [0/2931 (0%)]	Loss: 0.070956
# Train: [1098/2931 (100%)]	Loss: 0.032037
# Epoch: 7/10. Train set: Average loss: 0.0321
# Epoch: 7/10. Validation set: Average loss: 0.0467
# Train: [0/2931 (0%)]	Loss: 0.034640
# Train: [1098/2931 (100%)]	Loss: 0.031168
# Epoch: 8/10. Train set: Average loss: 0.0312
# Epoch: 8/10. Validation set: Average loss: 0.0423
# Train: [0/2931 (0%)]	Loss: 0.013857
# Train: [1098/2931 (100%)]	Loss: 0.023345
# Epoch: 9/10. Train set: Average loss: 0.0233
# Epoch: 9/10. Validation set: Average loss: 0.0314
# Train: [0/2931 (0%)]	Loss: 0.007738
# Train: [1098/2931 (100%)]	Loss: 0.019870
# Epoch: 10/10. Train set: Average loss: 0.0198
# Epoch: 10/10. Validation set: Average loss: 0.0302
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249447
# Train: [1098/2931 (100%)]	Loss: 0.056799
# Epoch: 1/10. Train set: Average loss: 0.0573
# Epoch: 1/10. Validation set: Average loss: 0.0548
# Train: [0/2931 (0%)]	Loss: 0.035941
# Train: [1098/2931 (100%)]	Loss: 0.049227
# Epoch: 2/10. Train set: Average loss: 0.0492
# Epoch: 2/10. Validation set: Average loss: 0.0386
# Train: [0/2931 (0%)]	Loss: 0.031512
# Train: [1098/2931 (100%)]	Loss: 0.035722
# Epoch: 3/10. Train set: Average loss: 0.0357
# Epoch: 3/10. Validation set: Average loss: 0.0389
# Train: [0/2931 (0%)]	Loss: 0.041002
# Train: [1098/2931 (100%)]	Loss: 0.033295
# Epoch: 4/10. Train set: Average loss: 0.0333
# Epoch: 4/10. Validation set: Average loss: 0.0408
# Train: [0/2931 (0%)]	Loss: 0.028533
# Train: [1098/2931 (100%)]	Loss: 0.033192
# Epoch: 5/10. Train set: Average loss: 0.0332
# Epoch: 5/10. Validation set: Average loss: 0.0377
# Train: [0/2931 (0%)]	Loss: 0.024189
# Train: [1098/2931 (100%)]	Loss: 0.032823
# Epoch: 6/10. Train set: Average loss: 0.0328
# Epoch: 6/10. Validation set: Average loss: 0.0423
# Train: [0/2931 (0%)]	Loss: 0.059311
# Train: [1098/2931 (100%)]	Loss: 0.027185
# Epoch: 7/10. Train set: Average loss: 0.0273
# Epoch: 7/10. Validation set: Average loss: 0.0319
# Train: [0/2931 (0%)]	Loss: 0.002098
# Train: [1098/2931 (100%)]	Loss: 0.027915
# Epoch: 8/10. Train set: Average loss: 0.0278
# Epoch: 8/10. Validation set: Average loss: 0.0336
# Train: [0/2931 (0%)]	Loss: 0.063170
# Train: [1098/2931 (100%)]	Loss: 0.019376
# Epoch: 9/10. Train set: Average loss: 0.0195
# Epoch: 9/10. Validation set: Average loss: 0.0267
# Train: [0/2931 (0%)]	Loss: 0.014113
# Train: [1098/2931 (100%)]	Loss: 0.017635
# Epoch: 10/10. Train set: Average loss: 0.0176
# Epoch: 10/10. Validation set: Average loss: 0.0248
# Number features: 243
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.186643
# Train: [1098/2931 (100%)]	Loss: 0.054087
# Epoch: 1/10. Train set: Average loss: 0.0544
# Epoch: 1/10. Validation set: Average loss: 0.0456
# Train: [0/2931 (0%)]	Loss: 0.032136
# Train: [1098/2931 (100%)]	Loss: 0.039228
# Epoch: 2/10. Train set: Average loss: 0.0392
# Epoch: 2/10. Validation set: Average loss: 0.0387
# Train: [0/2931 (0%)]	Loss: 0.022707
# Train: [1098/2931 (100%)]	Loss: 0.030686
# Epoch: 3/10. Train set: Average loss: 0.0307
# Epoch: 3/10. Validation set: Average loss: 0.0338
# Train: [0/2931 (0%)]	Loss: 0.020453
# Train: [1098/2931 (100%)]	Loss: 0.028857
# Epoch: 4/10. Train set: Average loss: 0.0288
# Epoch: 4/10. Validation set: Average loss: 0.0336
# Train: [0/2931 (0%)]	Loss: 0.006938
# Train: [1098/2931 (100%)]	Loss: 0.039539
# Epoch: 5/10. Train set: Average loss: 0.0394
# Epoch: 5/10. Validation set: Average loss: 0.0431
# Train: [0/2931 (0%)]	Loss: 0.053566
# Train: [1098/2931 (100%)]	Loss: 0.034447
# Epoch: 6/10. Train set: Average loss: 0.0345
# Epoch: 6/10. Validation set: Average loss: 0.0358
# Train: [0/2931 (0%)]	Loss: 0.052097
# Train: [1098/2931 (100%)]	Loss: 0.034638
# Epoch: 7/10. Train set: Average loss: 0.0347
# Epoch: 7/10. Validation set: Average loss: 0.0319
# Train: [0/2931 (0%)]	Loss: 0.017018
# Train: [1098/2931 (100%)]	Loss: 0.025455
# Epoch: 8/10. Train set: Average loss: 0.0254
# Epoch: 8/10. Validation set: Average loss: 0.0286
# Train: [0/2931 (0%)]	Loss: 0.022524
# Train: [1098/2931 (100%)]	Loss: 0.019720
# Epoch: 9/10. Train set: Average loss: 0.0197
# Epoch: 9/10. Validation set: Average loss: 0.0233
# Train: [0/2931 (0%)]	Loss: 0.022825
# Train: [1098/2931 (100%)]	Loss: 0.019851
# Epoch: 10/10. Train set: Average loss: 0.0199
# Epoch: 10/10. Validation set: Average loss: 0.0225
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.248963
# Train: [1098/2931 (100%)]	Loss: 0.050903
# Epoch: 1/10. Train set: Average loss: 0.0514
# Epoch: 1/10. Validation set: Average loss: 0.0467
# Train: [0/2931 (0%)]	Loss: 0.036096
# Train: [1098/2931 (100%)]	Loss: 0.040925
# Epoch: 2/10. Train set: Average loss: 0.0409
# Epoch: 2/10. Validation set: Average loss: 0.0443
# Train: [0/2931 (0%)]	Loss: 0.021744
# Train: [1098/2931 (100%)]	Loss: 0.046505
# Epoch: 3/10. Train set: Average loss: 0.0464
# Epoch: 3/10. Validation set: Average loss: 0.0378
# Train: [0/2931 (0%)]	Loss: 0.021829
# Train: [1098/2931 (100%)]	Loss: 0.031924
# Epoch: 4/10. Train set: Average loss: 0.0319
# Epoch: 4/10. Validation set: Average loss: 0.0310
# Train: [0/2931 (0%)]	Loss: 0.031560
# Train: [1098/2931 (100%)]	Loss: 0.032174
# Epoch: 5/10. Train set: Average loss: 0.0322
# Epoch: 5/10. Validation set: Average loss: 0.0316
# Train: [0/2931 (0%)]	Loss: 0.009468
# Train: [1098/2931 (100%)]	Loss: 0.027872
# Epoch: 6/10. Train set: Average loss: 0.0278
# Epoch: 6/10. Validation set: Average loss: 0.0367
# Train: [0/2931 (0%)]	Loss: 0.048582
# Train: [1098/2931 (100%)]	Loss: 0.024835
# Epoch: 7/10. Train set: Average loss: 0.0249
# Epoch: 7/10. Validation set: Average loss: 0.0263
# Train: [0/2931 (0%)]	Loss: 0.051114
# Train: [1098/2931 (100%)]	Loss: 0.028567
# Epoch: 8/10. Train set: Average loss: 0.0286
# Epoch: 8/10. Validation set: Average loss: 0.0286
# Train: [0/2931 (0%)]	Loss: 0.023106
# Train: [1098/2931 (100%)]	Loss: 0.020592
# Epoch: 9/10. Train set: Average loss: 0.0206
# Epoch: 9/10. Validation set: Average loss: 0.0224
# Train: [0/2931 (0%)]	Loss: 0.030980
# Train: [1098/2931 (100%)]	Loss: 0.018805
# Epoch: 10/10. Train set: Average loss: 0.0188
# Epoch: 10/10. Validation set: Average loss: 0.0220
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.187073
# Train: [1098/2931 (100%)]	Loss: 0.054717
# Epoch: 1/10. Train set: Average loss: 0.0551
# Epoch: 1/10. Validation set: Average loss: 0.0842
# Train: [0/2931 (0%)]	Loss: 0.068016
# Train: [1098/2931 (100%)]	Loss: 0.035461
# Epoch: 2/10. Train set: Average loss: 0.0355
# Epoch: 2/10. Validation set: Average loss: 0.0389
# Train: [0/2931 (0%)]	Loss: 0.027417
# Train: [1098/2931 (100%)]	Loss: 0.031100
# Epoch: 3/10. Train set: Average loss: 0.0311
# Epoch: 3/10. Validation set: Average loss: 0.0550
# Train: [0/2931 (0%)]	Loss: 0.011662
# Train: [1098/2931 (100%)]	Loss: 0.031088
# Epoch: 4/10. Train set: Average loss: 0.0310
# Epoch: 4/10. Validation set: Average loss: 0.0315
# Train: [0/2931 (0%)]	Loss: 0.018834
# Train: [1098/2931 (100%)]	Loss: 0.026780
# Epoch: 5/10. Train set: Average loss: 0.0268
# Epoch: 5/10. Validation set: Average loss: 0.0310
# Train: [0/2931 (0%)]	Loss: 0.013711
# Train: [1098/2931 (100%)]	Loss: 0.027124
# Epoch: 6/10. Train set: Average loss: 0.0271
# Epoch: 6/10. Validation set: Average loss: 0.0285
# Train: [0/2931 (0%)]	Loss: 0.030150
# Train: [1098/2931 (100%)]	Loss: 0.022369
# Epoch: 7/10. Train set: Average loss: 0.0224
# Epoch: 7/10. Validation set: Average loss: 0.0249
# Train: [0/2931 (0%)]	Loss: 0.007167
# Train: [1098/2931 (100%)]	Loss: 0.025986
# Epoch: 8/10. Train set: Average loss: 0.0259
# Epoch: 8/10. Validation set: Average loss: 0.0296
# Train: [0/2931 (0%)]	Loss: 0.058267
# Train: [1098/2931 (100%)]	Loss: 0.020036
# Epoch: 9/10. Train set: Average loss: 0.0201
# Epoch: 9/10. Validation set: Average loss: 0.0237
# Train: [0/2931 (0%)]	Loss: 0.028708
# Train: [1098/2931 (100%)]	Loss: 0.018334
# Epoch: 10/10. Train set: Average loss: 0.0184
# Epoch: 10/10. Validation set: Average loss: 0.0219
# Number features: 263
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.436568
# Train: [1098/2931 (100%)]	Loss: 0.057365
# Epoch: 1/10. Train set: Average loss: 0.0584
# Epoch: 1/10. Validation set: Average loss: 0.0544
# Train: [0/2931 (0%)]	Loss: 0.067005
# Train: [1098/2931 (100%)]	Loss: 0.040340
# Epoch: 2/10. Train set: Average loss: 0.0404
# Epoch: 2/10. Validation set: Average loss: 0.0482
# Train: [0/2931 (0%)]	Loss: 0.017278
# Train: [1098/2931 (100%)]	Loss: 0.040510
# Epoch: 3/10. Train set: Average loss: 0.0404
# Epoch: 3/10. Validation set: Average loss: 0.0444
# Train: [0/2931 (0%)]	Loss: 0.032509
# Train: [1098/2931 (100%)]	Loss: 0.036250
# Epoch: 4/10. Train set: Average loss: 0.0362
# Epoch: 4/10. Validation set: Average loss: 0.0429
# Train: [0/2931 (0%)]	Loss: 0.032183
# Train: [1098/2931 (100%)]	Loss: 0.033250
# Epoch: 5/10. Train set: Average loss: 0.0332
# Epoch: 5/10. Validation set: Average loss: 0.0390
# Train: [0/2931 (0%)]	Loss: 0.029675
# Train: [1098/2931 (100%)]	Loss: 0.033451
# Epoch: 6/10. Train set: Average loss: 0.0334
# Epoch: 6/10. Validation set: Average loss: 0.0373
# Train: [0/2931 (0%)]	Loss: 0.022362
# Train: [1098/2931 (100%)]	Loss: 0.031283
# Epoch: 7/10. Train set: Average loss: 0.0313
# Epoch: 7/10. Validation set: Average loss: 0.0456
# Train: [0/2931 (0%)]	Loss: 0.038237
# Train: [1098/2931 (100%)]	Loss: 0.031238
# Epoch: 8/10. Train set: Average loss: 0.0313
# Epoch: 8/10. Validation set: Average loss: 0.0335
# Train: [0/2931 (0%)]	Loss: 0.013708
# Train: [1098/2931 (100%)]	Loss: 0.024731
# Epoch: 9/10. Train set: Average loss: 0.0247
# Epoch: 9/10. Validation set: Average loss: 0.0300
# Train: [0/2931 (0%)]	Loss: 0.036597
# Train: [1098/2931 (100%)]	Loss: 0.023652
# Epoch: 10/10. Train set: Average loss: 0.0237
# Epoch: 10/10. Validation set: Average loss: 0.0291
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.374208
# Train: [1098/2931 (100%)]	Loss: 0.060473
# Epoch: 1/10. Train set: Average loss: 0.0613
# Epoch: 1/10. Validation set: Average loss: 0.0459
# Train: [0/2931 (0%)]	Loss: 0.059593
# Train: [1098/2931 (100%)]	Loss: 0.042722
# Epoch: 2/10. Train set: Average loss: 0.0428
# Epoch: 2/10. Validation set: Average loss: 0.0464
# Train: [0/2931 (0%)]	Loss: 0.042372
# Train: [1098/2931 (100%)]	Loss: 0.036477
# Epoch: 3/10. Train set: Average loss: 0.0365
# Epoch: 3/10. Validation set: Average loss: 0.0413
# Train: [0/2931 (0%)]	Loss: 0.043873
# Train: [1098/2931 (100%)]	Loss: 0.032729
# Epoch: 4/10. Train set: Average loss: 0.0328
# Epoch: 4/10. Validation set: Average loss: 0.0398
# Train: [0/2931 (0%)]	Loss: 0.048159
# Train: [1098/2931 (100%)]	Loss: 0.036666
# Epoch: 5/10. Train set: Average loss: 0.0367
# Epoch: 5/10. Validation set: Average loss: 0.0403
# Train: [0/2931 (0%)]	Loss: 0.054850
# Train: [1098/2931 (100%)]	Loss: 0.033865
# Epoch: 6/10. Train set: Average loss: 0.0339
# Epoch: 6/10. Validation set: Average loss: 0.0371
# Train: [0/2931 (0%)]	Loss: 0.016361
# Train: [1098/2931 (100%)]	Loss: 0.030930
# Epoch: 7/10. Train set: Average loss: 0.0309
# Epoch: 7/10. Validation set: Average loss: 0.0347
# Train: [0/2931 (0%)]	Loss: 0.008484
# Train: [1098/2931 (100%)]	Loss: 0.028455
# Epoch: 8/10. Train set: Average loss: 0.0284
# Epoch: 8/10. Validation set: Average loss: 0.0346
# Train: [0/2931 (0%)]	Loss: 0.032144
# Train: [1098/2931 (100%)]	Loss: 0.025767
# Epoch: 9/10. Train set: Average loss: 0.0258
# Epoch: 9/10. Validation set: Average loss: 0.0322
# Train: [0/2931 (0%)]	Loss: 0.005916
# Train: [1098/2931 (100%)]	Loss: 0.024392
# Epoch: 10/10. Train set: Average loss: 0.0243
# Epoch: 10/10. Validation set: Average loss: 0.0289
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.311584
# Train: [1098/2931 (100%)]	Loss: 0.058927
# Epoch: 1/10. Train set: Average loss: 0.0596
# Epoch: 1/10. Validation set: Average loss: 0.0460
# Train: [0/2931 (0%)]	Loss: 0.042502
# Train: [1098/2931 (100%)]	Loss: 0.040961
# Epoch: 2/10. Train set: Average loss: 0.0410
# Epoch: 2/10. Validation set: Average loss: 0.0374
# Train: [0/2931 (0%)]	Loss: 0.013232
# Train: [1098/2931 (100%)]	Loss: 0.038894
# Epoch: 3/10. Train set: Average loss: 0.0388
# Epoch: 3/10. Validation set: Average loss: 0.0439
# Train: [0/2931 (0%)]	Loss: 0.023547
# Train: [1098/2931 (100%)]	Loss: 0.038293
# Epoch: 4/10. Train set: Average loss: 0.0383
# Epoch: 4/10. Validation set: Average loss: 0.0454
# Train: [0/2931 (0%)]	Loss: 0.043823
# Train: [1098/2931 (100%)]	Loss: 0.033400
# Epoch: 5/10. Train set: Average loss: 0.0334
# Epoch: 5/10. Validation set: Average loss: 0.0369
# Train: [0/2931 (0%)]	Loss: 0.075237
# Train: [1098/2931 (100%)]	Loss: 0.030687
# Epoch: 6/10. Train set: Average loss: 0.0308
# Epoch: 6/10. Validation set: Average loss: 0.0364
# Train: [0/2931 (0%)]	Loss: 0.047866
# Train: [1098/2931 (100%)]	Loss: 0.032831
# Epoch: 7/10. Train set: Average loss: 0.0329
# Epoch: 7/10. Validation set: Average loss: 0.0468
# Train: [0/2931 (0%)]	Loss: 0.044743
# Train: [1098/2931 (100%)]	Loss: 0.033747
# Epoch: 8/10. Train set: Average loss: 0.0338
# Epoch: 8/10. Validation set: Average loss: 0.0756
# Train: [0/2931 (0%)]	Loss: 0.045430
# Train: [1098/2931 (100%)]	Loss: 0.028915
# Epoch: 9/10. Train set: Average loss: 0.0290
# Epoch: 9/10. Validation set: Average loss: 0.0315
# Train: [0/2931 (0%)]	Loss: 0.022937
# Train: [1098/2931 (100%)]	Loss: 0.025780
# Epoch: 10/10. Train set: Average loss: 0.0258
# Epoch: 10/10. Validation set: Average loss: 0.0283
# Number features: 283
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.311853
# Train: [1098/2931 (100%)]	Loss: 0.060707
# Epoch: 1/10. Train set: Average loss: 0.0614
# Epoch: 1/10. Validation set: Average loss: 0.0495
# Train: [0/2931 (0%)]	Loss: 0.081522
# Train: [1098/2931 (100%)]	Loss: 0.035906
# Epoch: 2/10. Train set: Average loss: 0.0360
# Epoch: 2/10. Validation set: Average loss: 0.0483
# Train: [0/2931 (0%)]	Loss: 0.007495
# Train: [1098/2931 (100%)]	Loss: 0.048402
# Epoch: 3/10. Train set: Average loss: 0.0483
# Epoch: 3/10. Validation set: Average loss: 0.0484
# Train: [0/2931 (0%)]	Loss: 0.043946
# Train: [1098/2931 (100%)]	Loss: 0.041854
# Epoch: 4/10. Train set: Average loss: 0.0419
# Epoch: 4/10. Validation set: Average loss: 0.0639
# Train: [0/2931 (0%)]	Loss: 0.122052
# Train: [1098/2931 (100%)]	Loss: 0.036947
# Epoch: 5/10. Train set: Average loss: 0.0372
# Epoch: 5/10. Validation set: Average loss: 0.0401
# Train: [0/2931 (0%)]	Loss: 0.052329
