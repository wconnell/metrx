# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("..")

import datetime
import pathlib

from collections import OrderedDict 

import numpy as np
import pandas as pd

# %%
# Pytorch
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable

# Custom
from dutils import Experiment
from trainer import fit
import visualization as vis
from tcga_datasets import SiameseDataset

# Models
from tcga_networks import EmbeddingNet, SiameseNet
from losses import ContrastiveLoss

# Metrics
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score as ANMI

# %%
def getTCGA(disease):
    path = "/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP/TCGA/TCGA_{}_counts.tsv.gz"
    files = [path.format(d) for d in disease]
    return files


def readGCP(files, biotype='protein_coding', mean=True):
    """
    Paths to count matrices.
    """
    data_dict = {}
    for f in files:
        key = os.path.basename(f).split("_")[1]
        data = pd.read_csv(f, sep='\t', index_col=0)
        # transcript metadata
        meta = pd.DataFrame([row[:-1] for row in data.index.str.split("|")],
                            columns=['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'GENE', 'BP', 'BIOTYPE'])
        meta = pd.MultiIndex.from_frame(meta)
        data.index = meta
        # subset transcripts
        data = data.xs(key=biotype, level='BIOTYPE')
        data = data.droplevel(['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'BP'])
        # average gene expression of splice variants
        data = data.T
        if mean:
            data = data.groupby(by=data.columns, axis=1).mean()
        data_dict[key] = data
    return data_dict


def uq_norm(df, q=0.75):
    """
    Upper quartile normalization of GEX for samples.
    """
    quantiles = df.quantile(q=q, axis=1)
    norm = df.divide(quantiles, axis=0)
    return norm


def process_TCGA(disease=['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']):
    base="/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP"
    # get files
    tcga_files = getTCGA(disease)
    # read meta/data
    tcga_meta = pd.read_csv(os.path.join(base, "TCGA/TCGA_GDC_ID_MAP.tsv"), sep="\t")
    tcga_raw = readGCP(tcga_files, mean=True)
    # combine samples
    tcga_raw = pd.concat(tcga_raw.values())
    # Upper quartile normalization
    tcga_raw = uq_norm(tcga_raw)
    # log norm
    tcga = tcga_raw.transform(np.log1p)
    return tcga, tcga_meta

# %%
def generate_fsets(data, n_features, steps=5):
    r = np.linspace(start=1, stop=n_features, num=steps, dtype='int')
    idx = [np.random.choice(data.shape[1], size=i, replace=False) for i in r]
    return idx

# %%
def feature_training(train_data, train_labels, test_data, test_labels, feature_idx, embedding, exp_dir, cuda=True):
    # Meta data
    meta_data = {"n_features":[],
                 "model":[],
                 "ANMI":[]}
    # Params
    batch_size = 8
    kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {'num_workers': 10}
    
    # Feature Index
    for batch, feat in enumerate(feature_idx):
        print("Number features: {}\n".format(len(feat)))
        exp_data = {'feature_idx':feat}
        # Define data
        siamese_train_dataset = SiameseDataset(data=train_data.iloc[:,feat],
                                           labels=train_labels,
                                           train=True)
        siamese_test_dataset = SiameseDataset(data=test_data.iloc[:,feat],
                                          labels=test_labels,
                                          train=False)
        # Loaders
        siamese_train_loader = torch.utils.data.DataLoader(siamese_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
        siamese_test_loader = torch.utils.data.DataLoader(siamese_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)
        # Instantiate model
        n_samples, n_features = siamese_train_dataset.train_data.shape
        for i in range(3):
            nmodel = 'model_{}'.format(i)
            print("\t{}".format(nmodel))
            embedding_net = EmbeddingNet(n_features, embedding)
            model = SiameseNet(embedding_net)
            if cuda:
                model.cuda()
            # Parameters
            margin = 1.
            loss_fn = ContrastiveLoss(margin)
            lr = 1e-3
            optimizer = optim.Adam(model.parameters(), lr=lr)
            scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
            n_epochs = 10
            log_interval = round(len(siamese_train_dataset)/1/batch_size)
            # Train
            train_loss, val_loss = fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, 
                                       n_epochs, cuda, log_interval)
            # Test Embeddings
            val_embeddings_baseline, val_labels_baseline = vis.extract_embeddings(siamese_test_dataset.test_data, siamese_test_dataset.labels, model)
            # Evaluation
            n_clusters = len(np.unique(test_labels))
            kmeans = KMeans(n_clusters=n_clusters)
            siamese_clusters = kmeans.fit_predict(val_embeddings_baseline)
            anmi = ANMI(siamese_clusters, val_labels_baseline)
            # Store
            meta_data['n_features'].append(len(feat))
            meta_data['model'].append(nmodel)
            meta_data['ANMI'].append(anmi)
            exp_data[nmodel] = {'data': (val_embeddings_baseline, val_labels_baseline),
                                'loss': (train_loss, val_loss),
                                'ANMI': anmi}
        pd.to_pickle(exp_data, os.path.join(exp_dir, "model_{}.pkl".format(len(feat))))
    pd.to_pickle(meta_data, os.path.join(exp_dir, "model_meta_data.pkl"))

# %%
def main(disease, sample_type, **kwargs):
    # GPUs
    os.environ["CUDA_VISIBLE_DEVICES"] = kwargs['device']
    cuda = torch.cuda.is_available()
    print("Cuda is available: {}".format(cuda))
    
    # Read / write / process
    tcga, tcga_meta = process_TCGA(disease)
    # Feature design
    feature_idx = generate_fsets(tcga, n_features=kwargs['n_features'], steps=kwargs['steps'])
    # Experiment design
    hierarchy = OrderedDict({'Disease':disease,
                             'Sample Type':sample_type})
    # Define experiment
    exp = Experiment(meta_data=tcga_meta,
                     hierarchy=hierarchy,
                     index='CGHubAnalysisID',
                     cases='Case ID',
                     min_samples=20)
    # Train / Test split
    exp.train_test_split(cases='Case ID')
    # Return data 
    train_data, train_labels = exp.get_data(tcga, subset="train", dtype=np.float32)
    test_data, test_labels = exp.get_data(tcga, subset="test", dtype=np.float32)
    
    # Path *fix*
    dtime = datetime.datetime.today().strftime("%Y.%m.%d_%H:%M")
    exp_dir = "/srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/{}_{}_{}_{}_{}-{}".format(dtime,
                                                                                                  kwargs['note'],
                                                                                                  len(exp.labels_dict),
                                                                                                  kwargs['embedding'],
                                                                                                  kwargs['n_features'], 
                                                                                                  kwargs['steps'])
    pathlib.Path(exp_dir).mkdir(parents=True, exist_ok=False)
    print('Saving to: \n{}'.format(exp_dir))
    
    # Meta data
    experiments = {'experiment': exp,
                   'train':(train_data, train_labels),
                   'test': (test_data, test_labels)}
    pd.to_pickle(experiments, os.path.join(exp_dir, "experiment_meta_data.pkl"))
    
    # Training
    feature_training(train_data, train_labels, test_data, test_labels, feature_idx, kwargs['embedding'], exp_dir)

# %% [markdown]
# ### Setup

# %%
disease = ['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']
sample_type = ['Primary Tumor', 'Solid Tissue Normal']
params = {"device":"6",
          "note":"true",
          "n_features":50,
          "steps":50,
          "embedding":2}

# %%
main(disease=disease, sample_type=sample_type, **params)
# Out:
# Cuda is available: True
# Saving to:
# /srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/2020.03.29_22:18_true_11_2_50-50
# Number features: 1
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.247488
# Epoch: 1/10. Train set: Average loss: 0.2475
# Epoch: 1/10. Validation set: Average loss: 0.2494
# Train: [0/2931 (0%)]	Loss: 0.250970
# Train: [1098/2931 (100%)]	Loss: 0.247684
# Epoch: 2/10. Train set: Average loss: 0.2477
# Epoch: 2/10. Validation set: Average loss: 0.2497
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.249031
# Epoch: 3/10. Train set: Average loss: 0.2490
# Epoch: 3/10. Validation set: Average loss: 0.2493
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.247218
# Epoch: 4/10. Train set: Average loss: 0.2472
# Epoch: 4/10. Validation set: Average loss: 0.2493
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.248689
# Epoch: 5/10. Train set: Average loss: 0.2487
# Epoch: 5/10. Validation set: Average loss: 0.2493
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.249320
# Epoch: 6/10. Train set: Average loss: 0.2493
# Epoch: 6/10. Validation set: Average loss: 0.2495
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.246035
# Epoch: 7/10. Train set: Average loss: 0.2460
# Epoch: 7/10. Validation set: Average loss: 0.2494
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.248277
# Epoch: 8/10. Train set: Average loss: 0.2483
# Epoch: 8/10. Validation set: Average loss: 0.2499
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.251485
# Epoch: 9/10. Train set: Average loss: 0.2515
# Epoch: 9/10. Validation set: Average loss: 0.2499
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.244225
# Epoch: 10/10. Train set: Average loss: 0.2442
# Epoch: 10/10. Validation set: Average loss: 0.2497
# 	model_1
# /srv/home/wconnell/anaconda3/envs/torch/lib/python3.7/site-packages/sklearn/cluster/_k_means.py:1007: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (11). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.253504
# Epoch: 1/10. Train set: Average loss: 0.2537
# Epoch: 1/10. Validation set: Average loss: 0.2495
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.246860
# Epoch: 2/10. Train set: Average loss: 0.2470
# Epoch: 2/10. Validation set: Average loss: 0.2498
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.253001
# Epoch: 3/10. Train set: Average loss: 0.2532
# Epoch: 3/10. Validation set: Average loss: 0.2494
# Train: [0/2931 (0%)]	Loss: 0.482513
# Train: [1098/2931 (100%)]	Loss: 0.253008
# Epoch: 4/10. Train set: Average loss: 0.2536
# Epoch: 4/10. Validation set: Average loss: 0.2493
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.250459
# Epoch: 5/10. Train set: Average loss: 0.2506
# Epoch: 5/10. Validation set: Average loss: 0.2498
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.248954
# Epoch: 6/10. Train set: Average loss: 0.2491
# Epoch: 6/10. Validation set: Average loss: 0.2500
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.254230
# Epoch: 7/10. Train set: Average loss: 0.2544
# Epoch: 7/10. Validation set: Average loss: 0.2499
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.248790
# Epoch: 8/10. Train set: Average loss: 0.2490
# Epoch: 8/10. Validation set: Average loss: 0.2494
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.249395
# Epoch: 9/10. Train set: Average loss: 0.2494
# Epoch: 9/10. Validation set: Average loss: 0.2493
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.249660
# Epoch: 10/10. Train set: Average loss: 0.2498
# Epoch: 10/10. Validation set: Average loss: 0.2493
# 	model_2
# /srv/home/wconnell/anaconda3/envs/torch/lib/python3.7/site-packages/sklearn/cluster/_k_means.py:1007: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (11). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.250614
# Epoch: 1/10. Train set: Average loss: 0.2506
# Epoch: 1/10. Validation set: Average loss: 0.2494
# Train: [0/2931 (0%)]	Loss: 0.251270
# Train: [1098/2931 (100%)]	Loss: 0.303033
# Epoch: 2/10. Train set: Average loss: 0.3029
# Epoch: 2/10. Validation set: Average loss: 0.2497
# Train: [0/2931 (0%)]	Loss: 0.312480
# Train: [1098/2931 (100%)]	Loss: 0.247482
# Epoch: 3/10. Train set: Average loss: 0.2477
# Epoch: 3/10. Validation set: Average loss: 0.2501
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.251955
# Epoch: 4/10. Train set: Average loss: 0.2519
# Epoch: 4/10. Validation set: Average loss: 0.2499
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.249482
# Epoch: 5/10. Train set: Average loss: 0.2495
# Epoch: 5/10. Validation set: Average loss: 0.2493
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.251877
# Epoch: 6/10. Train set: Average loss: 0.2519
# Epoch: 6/10. Validation set: Average loss: 0.2496
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.249417
# Epoch: 7/10. Train set: Average loss: 0.2494
# Epoch: 7/10. Validation set: Average loss: 0.2493
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.247033
# Epoch: 8/10. Train set: Average loss: 0.2470
# Epoch: 8/10. Validation set: Average loss: 0.2493
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.245889
# Epoch: 9/10. Train set: Average loss: 0.2459
# Epoch: 9/10. Validation set: Average loss: 0.2493
# Train: [0/2931 (0%)]	Loss: 0.249984
# Train: [1098/2931 (100%)]	Loss: 0.246092
# Epoch: 10/10. Train set: Average loss: 0.2461
# Epoch: 10/10. Validation set: Average loss: 0.2493
# Number features: 2
#
# 	model_0
# /srv/home/wconnell/anaconda3/envs/torch/lib/python3.7/site-packages/sklearn/cluster/_k_means.py:1007: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (11). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# Train: [0/2931 (0%)]	Loss: 0.374665
# Train: [1098/2931 (100%)]	Loss: 0.175273
# Epoch: 1/10. Train set: Average loss: 0.1758
# Epoch: 1/10. Validation set: Average loss: 0.1605
# Train: [0/2931 (0%)]	Loss: 0.280952
# Train: [1098/2931 (100%)]	Loss: 0.156881
# Epoch: 2/10. Train set: Average loss: 0.1572
# Epoch: 2/10. Validation set: Average loss: 0.1869
# Train: [0/2931 (0%)]	Loss: 0.333449
# Train: [1098/2931 (100%)]	Loss: 0.144892
# Epoch: 3/10. Train set: Average loss: 0.1454
# Epoch: 3/10. Validation set: Average loss: 0.1288
# Train: [0/2931 (0%)]	Loss: 0.230704
# Train: [1098/2931 (100%)]	Loss: 0.137932
# Epoch: 4/10. Train set: Average loss: 0.1382
# Epoch: 4/10. Validation set: Average loss: 0.1657
# Train: [0/2931 (0%)]	Loss: 0.243933
# Train: [1098/2931 (100%)]	Loss: 0.139121
# Epoch: 5/10. Train set: Average loss: 0.1394
# Epoch: 5/10. Validation set: Average loss: 0.1413
# Train: [0/2931 (0%)]	Loss: 0.235949
# Train: [1098/2931 (100%)]	Loss: 0.136595
# Epoch: 6/10. Train set: Average loss: 0.1369
# Epoch: 6/10. Validation set: Average loss: 0.1248
# Train: [0/2931 (0%)]	Loss: 0.153332
# Train: [1098/2931 (100%)]	Loss: 0.128234
# Epoch: 7/10. Train set: Average loss: 0.1283
# Epoch: 7/10. Validation set: Average loss: 0.1327
# Train: [0/2931 (0%)]	Loss: 0.143125
# Train: [1098/2931 (100%)]	Loss: 0.125685
# Epoch: 8/10. Train set: Average loss: 0.1257
# Epoch: 8/10. Validation set: Average loss: 0.1311
# Train: [0/2931 (0%)]	Loss: 0.254926
# Train: [1098/2931 (100%)]	Loss: 0.126012
# Epoch: 9/10. Train set: Average loss: 0.1264
# Epoch: 9/10. Validation set: Average loss: 0.1187
# Train: [0/2931 (0%)]	Loss: 0.100160
# Train: [1098/2931 (100%)]	Loss: 0.126167
# Epoch: 10/10. Train set: Average loss: 0.1261
# Epoch: 10/10. Validation set: Average loss: 0.1196
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249139
# Train: [1098/2931 (100%)]	Loss: 0.155439
# Epoch: 1/10. Train set: Average loss: 0.1557
# Epoch: 1/10. Validation set: Average loss: 0.1381
# Train: [0/2931 (0%)]	Loss: 0.104638
# Train: [1098/2931 (100%)]	Loss: 0.144678
# Epoch: 2/10. Train set: Average loss: 0.1446
# Epoch: 2/10. Validation set: Average loss: 0.1574
# Train: [0/2931 (0%)]	Loss: 0.085116
# Train: [1098/2931 (100%)]	Loss: 0.148320
# Epoch: 3/10. Train set: Average loss: 0.1481
# Epoch: 3/10. Validation set: Average loss: 0.1841
# Train: [0/2931 (0%)]	Loss: 0.102854
# Train: [1098/2931 (100%)]	Loss: 0.144324
# Epoch: 4/10. Train set: Average loss: 0.1442
# Epoch: 4/10. Validation set: Average loss: 0.1403
# Train: [0/2931 (0%)]	Loss: 0.124657
# Train: [1098/2931 (100%)]	Loss: 0.127374
# Epoch: 5/10. Train set: Average loss: 0.1274
# Epoch: 5/10. Validation set: Average loss: 0.1587
# Train: [0/2931 (0%)]	Loss: 0.118920
# Train: [1098/2931 (100%)]	Loss: 0.133428
# Epoch: 6/10. Train set: Average loss: 0.1334
# Epoch: 6/10. Validation set: Average loss: 0.1393
# Train: [0/2931 (0%)]	Loss: 0.131032
# Train: [1098/2931 (100%)]	Loss: 0.129133
# Epoch: 7/10. Train set: Average loss: 0.1291
# Epoch: 7/10. Validation set: Average loss: 0.1289
# Train: [0/2931 (0%)]	Loss: 0.136214
# Train: [1098/2931 (100%)]	Loss: 0.127835
# Epoch: 8/10. Train set: Average loss: 0.1279
# Epoch: 8/10. Validation set: Average loss: 0.1384
# Train: [0/2931 (0%)]	Loss: 0.097389
# Train: [1098/2931 (100%)]	Loss: 0.125817
# Epoch: 9/10. Train set: Average loss: 0.1257
# Epoch: 9/10. Validation set: Average loss: 0.1231
# Train: [0/2931 (0%)]	Loss: 0.087025
# Train: [1098/2931 (100%)]	Loss: 0.127333
# Epoch: 10/10. Train set: Average loss: 0.1272
# Epoch: 10/10. Validation set: Average loss: 0.1215
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.374355
# Train: [1098/2931 (100%)]	Loss: 0.159435
# Epoch: 1/10. Train set: Average loss: 0.1600
# Epoch: 1/10. Validation set: Average loss: 0.1397
# Train: [0/2931 (0%)]	Loss: 0.297939
# Train: [1098/2931 (100%)]	Loss: 0.141528
# Epoch: 2/10. Train set: Average loss: 0.1420
# Epoch: 2/10. Validation set: Average loss: 0.1414
# Train: [0/2931 (0%)]	Loss: 0.181983
# Train: [1098/2931 (100%)]	Loss: 0.134393
# Epoch: 3/10. Train set: Average loss: 0.1345
# Epoch: 3/10. Validation set: Average loss: 0.1314
# Train: [0/2931 (0%)]	Loss: 0.142987
# Train: [1098/2931 (100%)]	Loss: 0.136461
# Epoch: 4/10. Train set: Average loss: 0.1365
# Epoch: 4/10. Validation set: Average loss: 0.1331
# Train: [0/2931 (0%)]	Loss: 0.217797
# Train: [1098/2931 (100%)]	Loss: 0.133416
# Epoch: 5/10. Train set: Average loss: 0.1336
# Epoch: 5/10. Validation set: Average loss: 0.1310
# Train: [0/2931 (0%)]	Loss: 0.197302
# Train: [1098/2931 (100%)]	Loss: 0.153661
# Epoch: 6/10. Train set: Average loss: 0.1538
# Epoch: 6/10. Validation set: Average loss: 0.1491
# Train: [0/2931 (0%)]	Loss: 0.178531
# Train: [1098/2931 (100%)]	Loss: 0.153387
# Epoch: 7/10. Train set: Average loss: 0.1535
# Epoch: 7/10. Validation set: Average loss: 0.1547
# Train: [0/2931 (0%)]	Loss: 0.280399
# Train: [1098/2931 (100%)]	Loss: 0.146560
# Epoch: 8/10. Train set: Average loss: 0.1469
# Epoch: 8/10. Validation set: Average loss: 0.1615
# Train: [0/2931 (0%)]	Loss: 0.239142
# Train: [1098/2931 (100%)]	Loss: 0.132444
# Epoch: 9/10. Train set: Average loss: 0.1327
# Epoch: 9/10. Validation set: Average loss: 0.1263
# Train: [0/2931 (0%)]	Loss: 0.078208
# Train: [1098/2931 (100%)]	Loss: 0.127244
# Epoch: 10/10. Train set: Average loss: 0.1271
# Epoch: 10/10. Validation set: Average loss: 0.1222
# Number features: 3
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.374253
# Train: [1098/2931 (100%)]	Loss: 0.157289
# Epoch: 1/10. Train set: Average loss: 0.1579
# Epoch: 1/10. Validation set: Average loss: 0.1629
# Train: [0/2931 (0%)]	Loss: 0.212227
# Train: [1098/2931 (100%)]	Loss: 0.153630
# Epoch: 2/10. Train set: Average loss: 0.1538
# Epoch: 2/10. Validation set: Average loss: 0.1564
# Train: [0/2931 (0%)]	Loss: 0.274308
# Train: [1098/2931 (100%)]	Loss: 0.147280
# Epoch: 3/10. Train set: Average loss: 0.1476
# Epoch: 3/10. Validation set: Average loss: 0.1596
# Train: [0/2931 (0%)]	Loss: 0.228030
# Train: [1098/2931 (100%)]	Loss: 0.141118
# Epoch: 4/10. Train set: Average loss: 0.1414
# Epoch: 4/10. Validation set: Average loss: 0.1411
# Train: [0/2931 (0%)]	Loss: 0.142539
# Train: [1098/2931 (100%)]	Loss: 0.143390
# Epoch: 5/10. Train set: Average loss: 0.1434
# Epoch: 5/10. Validation set: Average loss: 0.1553
# Train: [0/2931 (0%)]	Loss: 0.241651
# Train: [1098/2931 (100%)]	Loss: 0.137127
# Epoch: 6/10. Train set: Average loss: 0.1374
# Epoch: 6/10. Validation set: Average loss: 0.1322
# Train: [0/2931 (0%)]	Loss: 0.233048
# Train: [1098/2931 (100%)]	Loss: 0.127052
# Epoch: 7/10. Train set: Average loss: 0.1273
# Epoch: 7/10. Validation set: Average loss: 0.1494
# Train: [0/2931 (0%)]	Loss: 0.177415
# Train: [1098/2931 (100%)]	Loss: 0.118310
# Epoch: 8/10. Train set: Average loss: 0.1185
# Epoch: 8/10. Validation set: Average loss: 0.1300
# Train: [0/2931 (0%)]	Loss: 0.184862
# Train: [1098/2931 (100%)]	Loss: 0.113713
# Epoch: 9/10. Train set: Average loss: 0.1139
# Epoch: 9/10. Validation set: Average loss: 0.1264
# Train: [0/2931 (0%)]	Loss: 0.085870
# Train: [1098/2931 (100%)]	Loss: 0.114120
# Epoch: 10/10. Train set: Average loss: 0.1140
# Epoch: 10/10. Validation set: Average loss: 0.1244
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.311919
# Train: [1098/2931 (100%)]	Loss: 0.168549
# Epoch: 1/10. Train set: Average loss: 0.1689
# Epoch: 1/10. Validation set: Average loss: 0.1575
# Train: [0/2931 (0%)]	Loss: 0.187949
# Train: [1098/2931 (100%)]	Loss: 0.140968
# Epoch: 2/10. Train set: Average loss: 0.1411
# Epoch: 2/10. Validation set: Average loss: 0.1604
# Train: [0/2931 (0%)]	Loss: 0.180212
# Train: [1098/2931 (100%)]	Loss: 0.135690
# Epoch: 3/10. Train set: Average loss: 0.1358
# Epoch: 3/10. Validation set: Average loss: 0.1513
# Train: [0/2931 (0%)]	Loss: 0.165098
# Train: [1098/2931 (100%)]	Loss: 0.139182
# Epoch: 4/10. Train set: Average loss: 0.1393
# Epoch: 4/10. Validation set: Average loss: 0.1405
# Train: [0/2931 (0%)]	Loss: 0.111288
# Train: [1098/2931 (100%)]	Loss: 0.137733
# Epoch: 5/10. Train set: Average loss: 0.1377
# Epoch: 5/10. Validation set: Average loss: 0.1509
# Train: [0/2931 (0%)]	Loss: 0.174557
# Train: [1098/2931 (100%)]	Loss: 0.135039
# Epoch: 6/10. Train set: Average loss: 0.1351
# Epoch: 6/10. Validation set: Average loss: 0.1356
# Train: [0/2931 (0%)]	Loss: 0.106901
# Train: [1098/2931 (100%)]	Loss: 0.128459
# Epoch: 7/10. Train set: Average loss: 0.1284
# Epoch: 7/10. Validation set: Average loss: 0.1349
# Train: [0/2931 (0%)]	Loss: 0.185036
# Train: [1098/2931 (100%)]	Loss: 0.125389
# Epoch: 8/10. Train set: Average loss: 0.1256
# Epoch: 8/10. Validation set: Average loss: 0.1343
# Train: [0/2931 (0%)]	Loss: 0.137161
# Train: [1098/2931 (100%)]	Loss: 0.121774
# Epoch: 9/10. Train set: Average loss: 0.1218
# Epoch: 9/10. Validation set: Average loss: 0.1280
# Train: [0/2931 (0%)]	Loss: 0.172336
# Train: [1098/2931 (100%)]	Loss: 0.118203
# Epoch: 10/10. Train set: Average loss: 0.1184
# Epoch: 10/10. Validation set: Average loss: 0.1307
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.062324
# Train: [1098/2931 (100%)]	Loss: 0.146595
# Epoch: 1/10. Train set: Average loss: 0.1464
# Epoch: 1/10. Validation set: Average loss: 0.1482
# Train: [0/2931 (0%)]	Loss: 0.074654
# Train: [1098/2931 (100%)]	Loss: 0.157325
# Epoch: 2/10. Train set: Average loss: 0.1571
# Epoch: 2/10. Validation set: Average loss: 0.1554
# Train: [0/2931 (0%)]	Loss: 0.067752
# Train: [1098/2931 (100%)]	Loss: 0.151340
# Epoch: 3/10. Train set: Average loss: 0.1511
# Epoch: 3/10. Validation set: Average loss: 0.1603
# Train: [0/2931 (0%)]	Loss: 0.064844
# Train: [1098/2931 (100%)]	Loss: 0.144425
# Epoch: 4/10. Train set: Average loss: 0.1442
# Epoch: 4/10. Validation set: Average loss: 0.1511
# Train: [0/2931 (0%)]	Loss: 0.157542
# Train: [1098/2931 (100%)]	Loss: 0.145345
# Epoch: 5/10. Train set: Average loss: 0.1454
# Epoch: 5/10. Validation set: Average loss: 0.1457
# Train: [0/2931 (0%)]	Loss: 0.062558
# Train: [1098/2931 (100%)]	Loss: 0.131171
# Epoch: 6/10. Train set: Average loss: 0.1310
# Epoch: 6/10. Validation set: Average loss: 0.1451
# Train: [0/2931 (0%)]	Loss: 0.072624
# Train: [1098/2931 (100%)]	Loss: 0.129430
# Epoch: 7/10. Train set: Average loss: 0.1293
# Epoch: 7/10. Validation set: Average loss: 0.1489
# Train: [0/2931 (0%)]	Loss: 0.073961
# Train: [1098/2931 (100%)]	Loss: 0.131679
# Epoch: 8/10. Train set: Average loss: 0.1315
# Epoch: 8/10. Validation set: Average loss: 0.1388
# Train: [0/2931 (0%)]	Loss: 0.056058
# Train: [1098/2931 (100%)]	Loss: 0.120193
# Epoch: 9/10. Train set: Average loss: 0.1200
# Epoch: 9/10. Validation set: Average loss: 0.1317
# Train: [0/2931 (0%)]	Loss: 0.093745
# Train: [1098/2931 (100%)]	Loss: 0.118376
# Epoch: 10/10. Train set: Average loss: 0.1183
# Epoch: 10/10. Validation set: Average loss: 0.1300
# Number features: 4
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.312153
# Train: [1098/2931 (100%)]	Loss: 0.123228
# Epoch: 1/10. Train set: Average loss: 0.1237
# Epoch: 1/10. Validation set: Average loss: 0.1175
# Train: [0/2931 (0%)]	Loss: 0.219790
# Train: [1098/2931 (100%)]	Loss: 0.117638
# Epoch: 2/10. Train set: Average loss: 0.1179
# Epoch: 2/10. Validation set: Average loss: 0.1228
# Train: [0/2931 (0%)]	Loss: 0.065130
# Train: [1098/2931 (100%)]	Loss: 0.116484
# Epoch: 3/10. Train set: Average loss: 0.1163
# Epoch: 3/10. Validation set: Average loss: 0.1104
# Train: [0/2931 (0%)]	Loss: 0.157763
# Train: [1098/2931 (100%)]	Loss: 0.109269
# Epoch: 4/10. Train set: Average loss: 0.1094
# Epoch: 4/10. Validation set: Average loss: 0.1058
# Train: [0/2931 (0%)]	Loss: 0.079563
# Train: [1098/2931 (100%)]	Loss: 0.104494
# Epoch: 5/10. Train set: Average loss: 0.1044
# Epoch: 5/10. Validation set: Average loss: 0.1000
# Train: [0/2931 (0%)]	Loss: 0.116874
# Train: [1098/2931 (100%)]	Loss: 0.101560
# Epoch: 6/10. Train set: Average loss: 0.1016
# Epoch: 6/10. Validation set: Average loss: 0.0984
# Train: [0/2931 (0%)]	Loss: 0.153839
# Train: [1098/2931 (100%)]	Loss: 0.100136
# Epoch: 7/10. Train set: Average loss: 0.1003
# Epoch: 7/10. Validation set: Average loss: 0.0917
# Train: [0/2931 (0%)]	Loss: 0.064808
# Train: [1098/2931 (100%)]	Loss: 0.107633
# Epoch: 8/10. Train set: Average loss: 0.1075
# Epoch: 8/10. Validation set: Average loss: 0.1084
# Train: [0/2931 (0%)]	Loss: 0.161936
# Train: [1098/2931 (100%)]	Loss: 0.098529
# Epoch: 9/10. Train set: Average loss: 0.0987
# Epoch: 9/10. Validation set: Average loss: 0.0938
# Train: [0/2931 (0%)]	Loss: 0.111681
# Train: [1098/2931 (100%)]	Loss: 0.096697
# Epoch: 10/10. Train set: Average loss: 0.0967
# Epoch: 10/10. Validation set: Average loss: 0.0934
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.187102
# Train: [1098/2931 (100%)]	Loss: 0.122848
# Epoch: 1/10. Train set: Average loss: 0.1230
# Epoch: 1/10. Validation set: Average loss: 0.1597
# Train: [0/2931 (0%)]	Loss: 0.124265
# Train: [1098/2931 (100%)]	Loss: 0.120888
# Epoch: 2/10. Train set: Average loss: 0.1209
# Epoch: 2/10. Validation set: Average loss: 0.1212
# Train: [0/2931 (0%)]	Loss: 0.173375
# Train: [1098/2931 (100%)]	Loss: 0.108532
# Epoch: 3/10. Train set: Average loss: 0.1087
# Epoch: 3/10. Validation set: Average loss: 0.1210
# Train: [0/2931 (0%)]	Loss: 0.039805
# Train: [1098/2931 (100%)]	Loss: 0.109701
# Epoch: 4/10. Train set: Average loss: 0.1095
# Epoch: 4/10. Validation set: Average loss: 0.1157
# Train: [0/2931 (0%)]	Loss: 0.136107
# Train: [1098/2931 (100%)]	Loss: 0.102101
# Epoch: 5/10. Train set: Average loss: 0.1022
# Epoch: 5/10. Validation set: Average loss: 0.1003
# Train: [0/2931 (0%)]	Loss: 0.096395
# Train: [1098/2931 (100%)]	Loss: 0.106037
# Epoch: 6/10. Train set: Average loss: 0.1060
# Epoch: 6/10. Validation set: Average loss: 0.0974
# Train: [0/2931 (0%)]	Loss: 0.040409
# Train: [1098/2931 (100%)]	Loss: 0.100454
# Epoch: 7/10. Train set: Average loss: 0.1003
# Epoch: 7/10. Validation set: Average loss: 0.0993
# Train: [0/2931 (0%)]	Loss: 0.089615
# Train: [1098/2931 (100%)]	Loss: 0.099884
# Epoch: 8/10. Train set: Average loss: 0.0999
# Epoch: 8/10. Validation set: Average loss: 0.0995
# Train: [0/2931 (0%)]	Loss: 0.047622
# Train: [1098/2931 (100%)]	Loss: 0.096447
# Epoch: 9/10. Train set: Average loss: 0.0963
# Epoch: 9/10. Validation set: Average loss: 0.0925
# Train: [0/2931 (0%)]	Loss: 0.137344
# Train: [1098/2931 (100%)]	Loss: 0.095188
# Epoch: 10/10. Train set: Average loss: 0.0953
# Epoch: 10/10. Validation set: Average loss: 0.0925
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.124825
# Train: [1098/2931 (100%)]	Loss: 0.133717
# Epoch: 1/10. Train set: Average loss: 0.1337
# Epoch: 1/10. Validation set: Average loss: 0.1244
# Train: [0/2931 (0%)]	Loss: 0.098715
# Train: [1098/2931 (100%)]	Loss: 0.110956
# Epoch: 2/10. Train set: Average loss: 0.1109
# Epoch: 2/10. Validation set: Average loss: 0.1014
# Train: [0/2931 (0%)]	Loss: 0.055735
# Train: [1098/2931 (100%)]	Loss: 0.121587
# Epoch: 3/10. Train set: Average loss: 0.1214
# Epoch: 3/10. Validation set: Average loss: 0.1231
# Train: [0/2931 (0%)]	Loss: 0.063411
# Train: [1098/2931 (100%)]	Loss: 0.117923
# Epoch: 4/10. Train set: Average loss: 0.1178
# Epoch: 4/10. Validation set: Average loss: 0.1317
# Train: [0/2931 (0%)]	Loss: 0.192489
# Train: [1098/2931 (100%)]	Loss: 0.112912
# Epoch: 5/10. Train set: Average loss: 0.1131
# Epoch: 5/10. Validation set: Average loss: 0.1235
# Train: [0/2931 (0%)]	Loss: 0.288754
# Train: [1098/2931 (100%)]	Loss: 0.103000
# Epoch: 6/10. Train set: Average loss: 0.1035
# Epoch: 6/10. Validation set: Average loss: 0.0957
# Train: [0/2931 (0%)]	Loss: 0.055365
# Train: [1098/2931 (100%)]	Loss: 0.103220
# Epoch: 7/10. Train set: Average loss: 0.1031
# Epoch: 7/10. Validation set: Average loss: 0.1299
# Train: [0/2931 (0%)]	Loss: 0.178303
# Train: [1098/2931 (100%)]	Loss: 0.103737
# Epoch: 8/10. Train set: Average loss: 0.1039
# Epoch: 8/10. Validation set: Average loss: 0.0942
# Train: [0/2931 (0%)]	Loss: 0.124161
# Train: [1098/2931 (100%)]	Loss: 0.094604
# Epoch: 9/10. Train set: Average loss: 0.0947
# Epoch: 9/10. Validation set: Average loss: 0.0899
# Train: [0/2931 (0%)]	Loss: 0.034557
# Train: [1098/2931 (100%)]	Loss: 0.095958
# Epoch: 10/10. Train set: Average loss: 0.0958
# Epoch: 10/10. Validation set: Average loss: 0.0910
# Number features: 5
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.249820
# Train: [1098/2931 (100%)]	Loss: 0.146343
# Epoch: 1/10. Train set: Average loss: 0.1466
# Epoch: 1/10. Validation set: Average loss: 0.1771
# Train: [0/2931 (0%)]	Loss: 0.436897
# Train: [1098/2931 (100%)]	Loss: 0.136325
# Epoch: 2/10. Train set: Average loss: 0.1371
# Epoch: 2/10. Validation set: Average loss: 0.1300
# Train: [0/2931 (0%)]	Loss: 0.121635
# Train: [1098/2931 (100%)]	Loss: 0.123545
# Epoch: 3/10. Train set: Average loss: 0.1235
# Epoch: 3/10. Validation set: Average loss: 0.1162
# Train: [0/2931 (0%)]	Loss: 0.098463
# Train: [1098/2931 (100%)]	Loss: 0.120313
# Epoch: 4/10. Train set: Average loss: 0.1203
# Epoch: 4/10. Validation set: Average loss: 0.1233
# Train: [0/2931 (0%)]	Loss: 0.110518
# Train: [1098/2931 (100%)]	Loss: 0.111481
# Epoch: 5/10. Train set: Average loss: 0.1115
# Epoch: 5/10. Validation set: Average loss: 0.1047
# Train: [0/2931 (0%)]	Loss: 0.110043
# Train: [1098/2931 (100%)]	Loss: 0.108250
# Epoch: 6/10. Train set: Average loss: 0.1083
# Epoch: 6/10. Validation set: Average loss: 0.1104
# Train: [0/2931 (0%)]	Loss: 0.097903
# Train: [1098/2931 (100%)]	Loss: 0.107970
# Epoch: 7/10. Train set: Average loss: 0.1079
# Epoch: 7/10. Validation set: Average loss: 0.1008
# Train: [0/2931 (0%)]	Loss: 0.189315
# Train: [1098/2931 (100%)]	Loss: 0.105613
# Epoch: 8/10. Train set: Average loss: 0.1058
# Epoch: 8/10. Validation set: Average loss: 0.0991
# Train: [0/2931 (0%)]	Loss: 0.125329
# Train: [1098/2931 (100%)]	Loss: 0.092186
# Epoch: 9/10. Train set: Average loss: 0.0923
# Epoch: 9/10. Validation set: Average loss: 0.0873
# Train: [0/2931 (0%)]	Loss: 0.093478
# Train: [1098/2931 (100%)]	Loss: 0.092686
# Epoch: 10/10. Train set: Average loss: 0.0927
# Epoch: 10/10. Validation set: Average loss: 0.0876
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.124495
# Train: [1098/2931 (100%)]	Loss: 0.132060
# Epoch: 1/10. Train set: Average loss: 0.1320
# Epoch: 1/10. Validation set: Average loss: 0.1092
# Train: [0/2931 (0%)]	Loss: 0.091325
# Train: [1098/2931 (100%)]	Loss: 0.124841
# Epoch: 2/10. Train set: Average loss: 0.1247
# Epoch: 2/10. Validation set: Average loss: 0.1104
# Train: [0/2931 (0%)]	Loss: 0.105159
# Train: [1098/2931 (100%)]	Loss: 0.123862
# Epoch: 3/10. Train set: Average loss: 0.1238
# Epoch: 3/10. Validation set: Average loss: 0.1168
# Train: [0/2931 (0%)]	Loss: 0.128330
# Train: [1098/2931 (100%)]	Loss: 0.121556
# Epoch: 4/10. Train set: Average loss: 0.1216
# Epoch: 4/10. Validation set: Average loss: 0.1171
# Train: [0/2931 (0%)]	Loss: 0.111047
# Train: [1098/2931 (100%)]	Loss: 0.121680
# Epoch: 5/10. Train set: Average loss: 0.1217
# Epoch: 5/10. Validation set: Average loss: 0.1151
# Train: [0/2931 (0%)]	Loss: 0.052125
# Train: [1098/2931 (100%)]	Loss: 0.115757
# Epoch: 6/10. Train set: Average loss: 0.1156
# Epoch: 6/10. Validation set: Average loss: 0.1078
# Train: [0/2931 (0%)]	Loss: 0.016055
# Train: [1098/2931 (100%)]	Loss: 0.107739
# Epoch: 7/10. Train set: Average loss: 0.1075
# Epoch: 7/10. Validation set: Average loss: 0.1067
# Train: [0/2931 (0%)]	Loss: 0.097254
# Train: [1098/2931 (100%)]	Loss: 0.111285
# Epoch: 8/10. Train set: Average loss: 0.1112
# Epoch: 8/10. Validation set: Average loss: 0.1060
# Train: [0/2931 (0%)]	Loss: 0.069197
# Train: [1098/2931 (100%)]	Loss: 0.099707
# Epoch: 9/10. Train set: Average loss: 0.0996
# Epoch: 9/10. Validation set: Average loss: 0.0907
# Train: [0/2931 (0%)]	Loss: 0.085123
# Train: [1098/2931 (100%)]	Loss: 0.093438
# Epoch: 10/10. Train set: Average loss: 0.0934
# Epoch: 10/10. Validation set: Average loss: 0.0905
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.062449
# Train: [1098/2931 (100%)]	Loss: 0.137253
# Epoch: 1/10. Train set: Average loss: 0.1370
# Epoch: 1/10. Validation set: Average loss: 0.1155
# Train: [0/2931 (0%)]	Loss: 0.063679
# Train: [1098/2931 (100%)]	Loss: 0.132688
# Epoch: 2/10. Train set: Average loss: 0.1325
# Epoch: 2/10. Validation set: Average loss: 0.1172
# Train: [0/2931 (0%)]	Loss: 0.064203
# Train: [1098/2931 (100%)]	Loss: 0.123261
# Epoch: 3/10. Train set: Average loss: 0.1231
# Epoch: 3/10. Validation set: Average loss: 0.1153
# Train: [0/2931 (0%)]	Loss: 0.026287
# Train: [1098/2931 (100%)]	Loss: 0.129106
# Epoch: 4/10. Train set: Average loss: 0.1288
# Epoch: 4/10. Validation set: Average loss: 0.1157
# Train: [0/2931 (0%)]	Loss: 0.051791
# Train: [1098/2931 (100%)]	Loss: 0.122079
# Epoch: 5/10. Train set: Average loss: 0.1219
# Epoch: 5/10. Validation set: Average loss: 0.1109
# Train: [0/2931 (0%)]	Loss: 0.091804
# Train: [1098/2931 (100%)]	Loss: 0.116755
# Epoch: 6/10. Train set: Average loss: 0.1167
# Epoch: 6/10. Validation set: Average loss: 0.1096
# Train: [0/2931 (0%)]	Loss: 0.125810
# Train: [1098/2931 (100%)]	Loss: 0.114532
# Epoch: 7/10. Train set: Average loss: 0.1146
# Epoch: 7/10. Validation set: Average loss: 0.1116
# Train: [0/2931 (0%)]	Loss: 0.025263
# Train: [1098/2931 (100%)]	Loss: 0.118557
# Epoch: 8/10. Train set: Average loss: 0.1183
# Epoch: 8/10. Validation set: Average loss: 0.1039
# Train: [0/2931 (0%)]	Loss: 0.051385
# Train: [1098/2931 (100%)]	Loss: 0.102285
# Epoch: 9/10. Train set: Average loss: 0.1021
# Epoch: 9/10. Validation set: Average loss: 0.0956
# Train: [0/2931 (0%)]	Loss: 0.129696
# Train: [1098/2931 (100%)]	Loss: 0.097567
# Epoch: 10/10. Train set: Average loss: 0.0977
# Epoch: 10/10. Validation set: Average loss: 0.0915
# Number features: 6
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187209
# Train: [1098/2931 (100%)]	Loss: 0.143839
# Epoch: 1/10. Train set: Average loss: 0.1440
# Epoch: 1/10. Validation set: Average loss: 0.1493
# Train: [0/2931 (0%)]	Loss: 0.175049
# Train: [1098/2931 (100%)]	Loss: 0.123882
# Epoch: 2/10. Train set: Average loss: 0.1240
# Epoch: 2/10. Validation set: Average loss: 0.1140
# Train: [0/2931 (0%)]	Loss: 0.091423
# Train: [1098/2931 (100%)]	Loss: 0.122723
# Epoch: 3/10. Train set: Average loss: 0.1226
# Epoch: 3/10. Validation set: Average loss: 0.1427
# Train: [0/2931 (0%)]	Loss: 0.050197
# Train: [1098/2931 (100%)]	Loss: 0.123889
# Epoch: 4/10. Train set: Average loss: 0.1237
# Epoch: 4/10. Validation set: Average loss: 0.1157
# Train: [0/2931 (0%)]	Loss: 0.085013
# Train: [1098/2931 (100%)]	Loss: 0.121243
# Epoch: 5/10. Train set: Average loss: 0.1211
# Epoch: 5/10. Validation set: Average loss: 0.1147
# Train: [0/2931 (0%)]	Loss: 0.053952
# Train: [1098/2931 (100%)]	Loss: 0.123587
# Epoch: 6/10. Train set: Average loss: 0.1234
# Epoch: 6/10. Validation set: Average loss: 0.1192
# Train: [0/2931 (0%)]	Loss: 0.157318
# Train: [1098/2931 (100%)]	Loss: 0.117950
# Epoch: 7/10. Train set: Average loss: 0.1181
# Epoch: 7/10. Validation set: Average loss: 0.1107
# Train: [0/2931 (0%)]	Loss: 0.168044
# Train: [1098/2931 (100%)]	Loss: 0.115252
# Epoch: 8/10. Train set: Average loss: 0.1154
# Epoch: 8/10. Validation set: Average loss: 0.1141
# Train: [0/2931 (0%)]	Loss: 0.104850
# Train: [1098/2931 (100%)]	Loss: 0.108166
# Epoch: 9/10. Train set: Average loss: 0.1082
# Epoch: 9/10. Validation set: Average loss: 0.1042
# Train: [0/2931 (0%)]	Loss: 0.082061
# Train: [1098/2931 (100%)]	Loss: 0.104686
# Epoch: 10/10. Train set: Average loss: 0.1046
# Epoch: 10/10. Validation set: Average loss: 0.1029
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.311769
# Train: [1098/2931 (100%)]	Loss: 0.145259
# Epoch: 1/10. Train set: Average loss: 0.1457
# Epoch: 1/10. Validation set: Average loss: 0.1203
# Train: [0/2931 (0%)]	Loss: 0.114890
# Train: [1098/2931 (100%)]	Loss: 0.124729
# Epoch: 2/10. Train set: Average loss: 0.1247
# Epoch: 2/10. Validation set: Average loss: 0.1249
# Train: [0/2931 (0%)]	Loss: 0.052351
# Train: [1098/2931 (100%)]	Loss: 0.123461
# Epoch: 3/10. Train set: Average loss: 0.1233
# Epoch: 3/10. Validation set: Average loss: 0.1273
# Train: [0/2931 (0%)]	Loss: 0.183509
# Train: [1098/2931 (100%)]	Loss: 0.119424
# Epoch: 4/10. Train set: Average loss: 0.1196
# Epoch: 4/10. Validation set: Average loss: 0.1310
# Train: [0/2931 (0%)]	Loss: 0.059879
# Train: [1098/2931 (100%)]	Loss: 0.127852
# Epoch: 5/10. Train set: Average loss: 0.1277
# Epoch: 5/10. Validation set: Average loss: 0.1273
# Train: [0/2931 (0%)]	Loss: 0.118551
# Train: [1098/2931 (100%)]	Loss: 0.120919
# Epoch: 6/10. Train set: Average loss: 0.1209
# Epoch: 6/10. Validation set: Average loss: 0.1053
# Train: [0/2931 (0%)]	Loss: 0.076656
# Train: [1098/2931 (100%)]	Loss: 0.113612
# Epoch: 7/10. Train set: Average loss: 0.1135
# Epoch: 7/10. Validation set: Average loss: 0.1045
# Train: [0/2931 (0%)]	Loss: 0.179674
# Train: [1098/2931 (100%)]	Loss: 0.110717
# Epoch: 8/10. Train set: Average loss: 0.1109
# Epoch: 8/10. Validation set: Average loss: 0.1048
# Train: [0/2931 (0%)]	Loss: 0.146978
# Train: [1098/2931 (100%)]	Loss: 0.102802
# Epoch: 9/10. Train set: Average loss: 0.1029
# Epoch: 9/10. Validation set: Average loss: 0.1003
# Train: [0/2931 (0%)]	Loss: 0.126246
# Train: [1098/2931 (100%)]	Loss: 0.100066
# Epoch: 10/10. Train set: Average loss: 0.1001
# Epoch: 10/10. Validation set: Average loss: 0.0988
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.062407
# Train: [1098/2931 (100%)]	Loss: 0.141435
# Epoch: 1/10. Train set: Average loss: 0.1412
# Epoch: 1/10. Validation set: Average loss: 0.1308
# Train: [0/2931 (0%)]	Loss: 0.084685
# Train: [1098/2931 (100%)]	Loss: 0.136287
# Epoch: 2/10. Train set: Average loss: 0.1361
# Epoch: 2/10. Validation set: Average loss: 0.1267
# Train: [0/2931 (0%)]	Loss: 0.101265
# Train: [1098/2931 (100%)]	Loss: 0.127870
# Epoch: 3/10. Train set: Average loss: 0.1278
# Epoch: 3/10. Validation set: Average loss: 0.1222
# Train: [0/2931 (0%)]	Loss: 0.101703
# Train: [1098/2931 (100%)]	Loss: 0.127947
# Epoch: 4/10. Train set: Average loss: 0.1279
# Epoch: 4/10. Validation set: Average loss: 0.1100
# Train: [0/2931 (0%)]	Loss: 0.082189
# Train: [1098/2931 (100%)]	Loss: 0.118555
# Epoch: 5/10. Train set: Average loss: 0.1185
# Epoch: 5/10. Validation set: Average loss: 0.1024
# Train: [0/2931 (0%)]	Loss: 0.073736
# Train: [1098/2931 (100%)]	Loss: 0.117521
# Epoch: 6/10. Train set: Average loss: 0.1174
# Epoch: 6/10. Validation set: Average loss: 0.1018
# Train: [0/2931 (0%)]	Loss: 0.135698
# Train: [1098/2931 (100%)]	Loss: 0.107930
# Epoch: 7/10. Train set: Average loss: 0.1080
# Epoch: 7/10. Validation set: Average loss: 0.1021
# Train: [0/2931 (0%)]	Loss: 0.121681
# Train: [1098/2931 (100%)]	Loss: 0.105606
# Epoch: 8/10. Train set: Average loss: 0.1057
# Epoch: 8/10. Validation set: Average loss: 0.1083
# Train: [0/2931 (0%)]	Loss: 0.047337
# Train: [1098/2931 (100%)]	Loss: 0.097721
# Epoch: 9/10. Train set: Average loss: 0.0976
# Epoch: 9/10. Validation set: Average loss: 0.1002
# Train: [0/2931 (0%)]	Loss: 0.105751
# Train: [1098/2931 (100%)]	Loss: 0.098631
# Epoch: 10/10. Train set: Average loss: 0.0987
# Epoch: 10/10. Validation set: Average loss: 0.0993
# Number features: 7
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.062166
# Train: [1098/2931 (100%)]	Loss: 0.140460
# Epoch: 1/10. Train set: Average loss: 0.1402
# Epoch: 1/10. Validation set: Average loss: 0.1258
# Train: [0/2931 (0%)]	Loss: 0.147105
# Train: [1098/2931 (100%)]	Loss: 0.137763
# Epoch: 2/10. Train set: Average loss: 0.1378
# Epoch: 2/10. Validation set: Average loss: 0.1445
# Train: [0/2931 (0%)]	Loss: 0.154972
# Train: [1098/2931 (100%)]	Loss: 0.139766
# Epoch: 3/10. Train set: Average loss: 0.1398
# Epoch: 3/10. Validation set: Average loss: 0.1315
# Train: [0/2931 (0%)]	Loss: 0.156200
# Train: [1098/2931 (100%)]	Loss: 0.137129
# Epoch: 4/10. Train set: Average loss: 0.1372
# Epoch: 4/10. Validation set: Average loss: 0.1319
# Train: [0/2931 (0%)]	Loss: 0.124827
# Train: [1098/2931 (100%)]	Loss: 0.128806
# Epoch: 5/10. Train set: Average loss: 0.1288
# Epoch: 5/10. Validation set: Average loss: 0.1585
# Train: [0/2931 (0%)]	Loss: 0.162921
# Train: [1098/2931 (100%)]	Loss: 0.135726
# Epoch: 6/10. Train set: Average loss: 0.1358
# Epoch: 6/10. Validation set: Average loss: 0.1421
# Train: [0/2931 (0%)]	Loss: 0.065212
# Train: [1098/2931 (100%)]	Loss: 0.134707
# Epoch: 7/10. Train set: Average loss: 0.1345
# Epoch: 7/10. Validation set: Average loss: 0.1308
# Train: [0/2931 (0%)]	Loss: 0.076121
# Train: [1098/2931 (100%)]	Loss: 0.123154
# Epoch: 8/10. Train set: Average loss: 0.1230
# Epoch: 8/10. Validation set: Average loss: 0.1626
# Train: [0/2931 (0%)]	Loss: 0.061639
# Train: [1098/2931 (100%)]	Loss: 0.121273
# Epoch: 9/10. Train set: Average loss: 0.1211
# Epoch: 9/10. Validation set: Average loss: 0.1155
# Train: [0/2931 (0%)]	Loss: 0.169423
# Train: [1098/2931 (100%)]	Loss: 0.110069
# Epoch: 10/10. Train set: Average loss: 0.1102
# Epoch: 10/10. Validation set: Average loss: 0.1091
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.373663
# Train: [1098/2931 (100%)]	Loss: 0.141814
# Epoch: 1/10. Train set: Average loss: 0.1424
# Epoch: 1/10. Validation set: Average loss: 0.1460
# Train: [0/2931 (0%)]	Loss: 0.115682
# Train: [1098/2931 (100%)]	Loss: 0.145539
# Epoch: 2/10. Train set: Average loss: 0.1455
# Epoch: 2/10. Validation set: Average loss: 0.1297
# Train: [0/2931 (0%)]	Loss: 0.185148
# Train: [1098/2931 (100%)]	Loss: 0.146590
# Epoch: 3/10. Train set: Average loss: 0.1467
# Epoch: 3/10. Validation set: Average loss: 0.1458
# Train: [0/2931 (0%)]	Loss: 0.176323
# Train: [1098/2931 (100%)]	Loss: 0.131960
# Epoch: 4/10. Train set: Average loss: 0.1321
# Epoch: 4/10. Validation set: Average loss: 0.1325
# Train: [0/2931 (0%)]	Loss: 0.205878
# Train: [1098/2931 (100%)]	Loss: 0.129262
# Epoch: 5/10. Train set: Average loss: 0.1295
# Epoch: 5/10. Validation set: Average loss: 0.1408
# Train: [0/2931 (0%)]	Loss: 0.242964
# Train: [1098/2931 (100%)]	Loss: 0.129450
# Epoch: 6/10. Train set: Average loss: 0.1298
# Epoch: 6/10. Validation set: Average loss: 0.1314
# Train: [0/2931 (0%)]	Loss: 0.135319
# Train: [1098/2931 (100%)]	Loss: 0.132093
# Epoch: 7/10. Train set: Average loss: 0.1321
# Epoch: 7/10. Validation set: Average loss: 0.1524
# Train: [0/2931 (0%)]	Loss: 0.107841
# Train: [1098/2931 (100%)]	Loss: 0.129780
# Epoch: 8/10. Train set: Average loss: 0.1297
# Epoch: 8/10. Validation set: Average loss: 0.1203
# Train: [0/2931 (0%)]	Loss: 0.184274
# Train: [1098/2931 (100%)]	Loss: 0.112616
# Epoch: 9/10. Train set: Average loss: 0.1128
# Epoch: 9/10. Validation set: Average loss: 0.1132
# Train: [0/2931 (0%)]	Loss: 0.094857
# Train: [1098/2931 (100%)]	Loss: 0.114567
# Epoch: 10/10. Train set: Average loss: 0.1145
# Epoch: 10/10. Validation set: Average loss: 0.1125
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.187206
# Train: [1098/2931 (100%)]	Loss: 0.140429
# Epoch: 1/10. Train set: Average loss: 0.1406
# Epoch: 1/10. Validation set: Average loss: 0.1278
# Train: [0/2931 (0%)]	Loss: 0.114751
# Train: [1098/2931 (100%)]	Loss: 0.134890
# Epoch: 2/10. Train set: Average loss: 0.1348
# Epoch: 2/10. Validation set: Average loss: 0.1219
# Train: [0/2931 (0%)]	Loss: 0.095800
# Train: [1098/2931 (100%)]	Loss: 0.134626
# Epoch: 3/10. Train set: Average loss: 0.1345
# Epoch: 3/10. Validation set: Average loss: 0.1427
# Train: [0/2931 (0%)]	Loss: 0.165956
# Train: [1098/2931 (100%)]	Loss: 0.132429
# Epoch: 4/10. Train set: Average loss: 0.1325
# Epoch: 4/10. Validation set: Average loss: 0.1422
# Train: [0/2931 (0%)]	Loss: 0.130404
# Train: [1098/2931 (100%)]	Loss: 0.140226
# Epoch: 5/10. Train set: Average loss: 0.1402
# Epoch: 5/10. Validation set: Average loss: 0.1389
# Train: [0/2931 (0%)]	Loss: 0.102450
# Train: [1098/2931 (100%)]	Loss: 0.136627
# Epoch: 6/10. Train set: Average loss: 0.1365
# Epoch: 6/10. Validation set: Average loss: 0.1363
# Train: [0/2931 (0%)]	Loss: 0.144492
# Train: [1098/2931 (100%)]	Loss: 0.137835
# Epoch: 7/10. Train set: Average loss: 0.1379
# Epoch: 7/10. Validation set: Average loss: 0.1423
# Train: [0/2931 (0%)]	Loss: 0.086339
# Train: [1098/2931 (100%)]	Loss: 0.127610
# Epoch: 8/10. Train set: Average loss: 0.1275
# Epoch: 8/10. Validation set: Average loss: 0.1189
# Train: [0/2931 (0%)]	Loss: 0.110867
# Train: [1098/2931 (100%)]	Loss: 0.116609
# Epoch: 9/10. Train set: Average loss: 0.1166
# Epoch: 9/10. Validation set: Average loss: 0.1156
# Train: [0/2931 (0%)]	Loss: 0.142615
# Train: [1098/2931 (100%)]	Loss: 0.114175
# Epoch: 10/10. Train set: Average loss: 0.1143
# Epoch: 10/10. Validation set: Average loss: 0.1125
# Number features: 8
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.248771
# Train: [1098/2931 (100%)]	Loss: 0.150017
# Epoch: 1/10. Train set: Average loss: 0.1503
# Epoch: 1/10. Validation set: Average loss: 0.1442
# Train: [0/2931 (0%)]	Loss: 0.080494
# Train: [1098/2931 (100%)]	Loss: 0.127485
# Epoch: 2/10. Train set: Average loss: 0.1274
# Epoch: 2/10. Validation set: Average loss: 0.1165
# Train: [0/2931 (0%)]	Loss: 0.160215
# Train: [1098/2931 (100%)]	Loss: 0.115076
# Epoch: 3/10. Train set: Average loss: 0.1152
# Epoch: 3/10. Validation set: Average loss: 0.1423
# Train: [0/2931 (0%)]	Loss: 0.221098
# Train: [1098/2931 (100%)]	Loss: 0.117326
# Epoch: 4/10. Train set: Average loss: 0.1176
# Epoch: 4/10. Validation set: Average loss: 0.1263
# Train: [0/2931 (0%)]	Loss: 0.195684
# Train: [1098/2931 (100%)]	Loss: 0.111555
# Epoch: 5/10. Train set: Average loss: 0.1118
# Epoch: 5/10. Validation set: Average loss: 0.1084
# Train: [0/2931 (0%)]	Loss: 0.201051
# Train: [1098/2931 (100%)]	Loss: 0.107478
# Epoch: 6/10. Train set: Average loss: 0.1077
# Epoch: 6/10. Validation set: Average loss: 0.1179
# Train: [0/2931 (0%)]	Loss: 0.067139
# Train: [1098/2931 (100%)]	Loss: 0.109280
# Epoch: 7/10. Train set: Average loss: 0.1092
# Epoch: 7/10. Validation set: Average loss: 0.1070
# Train: [0/2931 (0%)]	Loss: 0.055692
# Train: [1098/2931 (100%)]	Loss: 0.106822
# Epoch: 8/10. Train set: Average loss: 0.1067
# Epoch: 8/10. Validation set: Average loss: 0.1143
# Train: [0/2931 (0%)]	Loss: 0.069264
# Train: [1098/2931 (100%)]	Loss: 0.100133
# Epoch: 9/10. Train set: Average loss: 0.1000
# Epoch: 9/10. Validation set: Average loss: 0.0970
# Train: [0/2931 (0%)]	Loss: 0.116539
# Train: [1098/2931 (100%)]	Loss: 0.097902
# Epoch: 10/10. Train set: Average loss: 0.0980
# Epoch: 10/10. Validation set: Average loss: 0.0986
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.311528
# Train: [1098/2931 (100%)]	Loss: 0.155764
# Epoch: 1/10. Train set: Average loss: 0.1562
# Epoch: 1/10. Validation set: Average loss: 0.1656
# Train: [0/2931 (0%)]	Loss: 0.341898
# Train: [1098/2931 (100%)]	Loss: 0.160164
# Epoch: 2/10. Train set: Average loss: 0.1607
# Epoch: 2/10. Validation set: Average loss: 0.1223
# Train: [0/2931 (0%)]	Loss: 0.168693
# Train: [1098/2931 (100%)]	Loss: 0.127933
# Epoch: 3/10. Train set: Average loss: 0.1280
# Epoch: 3/10. Validation set: Average loss: 0.1234
# Train: [0/2931 (0%)]	Loss: 0.134765
# Train: [1098/2931 (100%)]	Loss: 0.112891
# Epoch: 4/10. Train set: Average loss: 0.1130
# Epoch: 4/10. Validation set: Average loss: 0.1099
# Train: [0/2931 (0%)]	Loss: 0.139979
# Train: [1098/2931 (100%)]	Loss: 0.117430
# Epoch: 5/10. Train set: Average loss: 0.1175
# Epoch: 5/10. Validation set: Average loss: 0.1388
# Train: [0/2931 (0%)]	Loss: 0.103386
# Train: [1098/2931 (100%)]	Loss: 0.110915
# Epoch: 6/10. Train set: Average loss: 0.1109
# Epoch: 6/10. Validation set: Average loss: 0.1054
# Train: [0/2931 (0%)]	Loss: 0.131316
# Train: [1098/2931 (100%)]	Loss: 0.105154
# Epoch: 7/10. Train set: Average loss: 0.1052
# Epoch: 7/10. Validation set: Average loss: 0.1091
# Train: [0/2931 (0%)]	Loss: 0.145633
# Train: [1098/2931 (100%)]	Loss: 0.106749
# Epoch: 8/10. Train set: Average loss: 0.1069
# Epoch: 8/10. Validation set: Average loss: 0.1010
# Train: [0/2931 (0%)]	Loss: 0.113133
# Train: [1098/2931 (100%)]	Loss: 0.100143
# Epoch: 9/10. Train set: Average loss: 0.1002
# Epoch: 9/10. Validation set: Average loss: 0.0997
# Train: [0/2931 (0%)]	Loss: 0.153587
# Train: [1098/2931 (100%)]	Loss: 0.097811
# Epoch: 10/10. Train set: Average loss: 0.0980
# Epoch: 10/10. Validation set: Average loss: 0.0992
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249172
# Train: [1098/2931 (100%)]	Loss: 0.138995
# Epoch: 1/10. Train set: Average loss: 0.1393
# Epoch: 1/10. Validation set: Average loss: 0.1297
# Train: [0/2931 (0%)]	Loss: 0.084400
# Train: [1098/2931 (100%)]	Loss: 0.124339
# Epoch: 2/10. Train set: Average loss: 0.1242
# Epoch: 2/10. Validation set: Average loss: 0.1541
# Train: [0/2931 (0%)]	Loss: 0.118719
# Train: [1098/2931 (100%)]	Loss: 0.121992
# Epoch: 3/10. Train set: Average loss: 0.1220
# Epoch: 3/10. Validation set: Average loss: 0.1831
# Train: [0/2931 (0%)]	Loss: 0.218857
# Train: [1098/2931 (100%)]	Loss: 0.134987
# Epoch: 4/10. Train set: Average loss: 0.1352
# Epoch: 4/10. Validation set: Average loss: 0.1311
# Train: [0/2931 (0%)]	Loss: 0.255034
# Train: [1098/2931 (100%)]	Loss: 0.117612
# Epoch: 5/10. Train set: Average loss: 0.1180
# Epoch: 5/10. Validation set: Average loss: 0.1051
# Train: [0/2931 (0%)]	Loss: 0.170514
# Train: [1098/2931 (100%)]	Loss: 0.109593
# Epoch: 6/10. Train set: Average loss: 0.1098
# Epoch: 6/10. Validation set: Average loss: 0.1091
# Train: [0/2931 (0%)]	Loss: 0.115048
# Train: [1098/2931 (100%)]	Loss: 0.106463
# Epoch: 7/10. Train set: Average loss: 0.1065
# Epoch: 7/10. Validation set: Average loss: 0.1017
# Train: [0/2931 (0%)]	Loss: 0.022611
# Train: [1098/2931 (100%)]	Loss: 0.103251
# Epoch: 8/10. Train set: Average loss: 0.1030
# Epoch: 8/10. Validation set: Average loss: 0.1080
# Train: [0/2931 (0%)]	Loss: 0.149274
# Train: [1098/2931 (100%)]	Loss: 0.098449
# Epoch: 9/10. Train set: Average loss: 0.0986
# Epoch: 9/10. Validation set: Average loss: 0.0983
# Train: [0/2931 (0%)]	Loss: 0.095844
# Train: [1098/2931 (100%)]	Loss: 0.095585
# Epoch: 10/10. Train set: Average loss: 0.0956
# Epoch: 10/10. Validation set: Average loss: 0.0969
# Number features: 9
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.311876
# Train: [1098/2931 (100%)]	Loss: 0.149168
# Epoch: 1/10. Train set: Average loss: 0.1496
# Epoch: 1/10. Validation set: Average loss: 0.2222
# Train: [0/2931 (0%)]	Loss: 0.229436
# Train: [1098/2931 (100%)]	Loss: 0.139339
# Epoch: 2/10. Train set: Average loss: 0.1396
# Epoch: 2/10. Validation set: Average loss: 0.1293
# Train: [0/2931 (0%)]	Loss: 0.220431
# Train: [1098/2931 (100%)]	Loss: 0.119018
# Epoch: 3/10. Train set: Average loss: 0.1193
# Epoch: 3/10. Validation set: Average loss: 0.1285
# Train: [0/2931 (0%)]	Loss: 0.134924
# Train: [1098/2931 (100%)]	Loss: 0.122363
# Epoch: 4/10. Train set: Average loss: 0.1224
# Epoch: 4/10. Validation set: Average loss: 0.1211
# Train: [0/2931 (0%)]	Loss: 0.123718
# Train: [1098/2931 (100%)]	Loss: 0.121233
# Epoch: 5/10. Train set: Average loss: 0.1212
# Epoch: 5/10. Validation set: Average loss: 0.1239
# Train: [0/2931 (0%)]	Loss: 0.111909
# Train: [1098/2931 (100%)]	Loss: 0.116421
# Epoch: 6/10. Train set: Average loss: 0.1164
# Epoch: 6/10. Validation set: Average loss: 0.1226
# Train: [0/2931 (0%)]	Loss: 0.136505
# Train: [1098/2931 (100%)]	Loss: 0.113099
# Epoch: 7/10. Train set: Average loss: 0.1132
# Epoch: 7/10. Validation set: Average loss: 0.1182
# Train: [0/2931 (0%)]	Loss: 0.138499
# Train: [1098/2931 (100%)]	Loss: 0.114814
# Epoch: 8/10. Train set: Average loss: 0.1149
# Epoch: 8/10. Validation set: Average loss: 0.1194
# Train: [0/2931 (0%)]	Loss: 0.160896
# Train: [1098/2931 (100%)]	Loss: 0.105584
# Epoch: 9/10. Train set: Average loss: 0.1057
# Epoch: 9/10. Validation set: Average loss: 0.1124
# Train: [0/2931 (0%)]	Loss: 0.146013
# Train: [1098/2931 (100%)]	Loss: 0.104239
# Epoch: 10/10. Train set: Average loss: 0.1044
# Epoch: 10/10. Validation set: Average loss: 0.1116
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.311472
# Train: [1098/2931 (100%)]	Loss: 0.143581
# Epoch: 1/10. Train set: Average loss: 0.1440
# Epoch: 1/10. Validation set: Average loss: 0.1393
# Train: [0/2931 (0%)]	Loss: 0.130119
# Train: [1098/2931 (100%)]	Loss: 0.126147
# Epoch: 2/10. Train set: Average loss: 0.1262
# Epoch: 2/10. Validation set: Average loss: 0.1272
# Train: [0/2931 (0%)]	Loss: 0.175583
# Train: [1098/2931 (100%)]	Loss: 0.127237
# Epoch: 3/10. Train set: Average loss: 0.1274
# Epoch: 3/10. Validation set: Average loss: 0.1224
# Train: [0/2931 (0%)]	Loss: 0.146637
# Train: [1098/2931 (100%)]	Loss: 0.126695
# Epoch: 4/10. Train set: Average loss: 0.1267
# Epoch: 4/10. Validation set: Average loss: 0.1260
# Train: [0/2931 (0%)]	Loss: 0.188054
# Train: [1098/2931 (100%)]	Loss: 0.116416
# Epoch: 5/10. Train set: Average loss: 0.1166
# Epoch: 5/10. Validation set: Average loss: 0.1262
# Train: [0/2931 (0%)]	Loss: 0.133946
# Train: [1098/2931 (100%)]	Loss: 0.114834
# Epoch: 6/10. Train set: Average loss: 0.1149
# Epoch: 6/10. Validation set: Average loss: 0.1181
# Train: [0/2931 (0%)]	Loss: 0.220774
# Train: [1098/2931 (100%)]	Loss: 0.113283
# Epoch: 7/10. Train set: Average loss: 0.1136
# Epoch: 7/10. Validation set: Average loss: 0.1336
# Train: [0/2931 (0%)]	Loss: 0.169284
# Train: [1098/2931 (100%)]	Loss: 0.110502
# Epoch: 8/10. Train set: Average loss: 0.1107
# Epoch: 8/10. Validation set: Average loss: 0.1117
# Train: [0/2931 (0%)]	Loss: 0.115592
# Train: [1098/2931 (100%)]	Loss: 0.106958
# Epoch: 9/10. Train set: Average loss: 0.1070
# Epoch: 9/10. Validation set: Average loss: 0.1091
# Train: [0/2931 (0%)]	Loss: 0.168583
# Train: [1098/2931 (100%)]	Loss: 0.103999
# Epoch: 10/10. Train set: Average loss: 0.1042
# Epoch: 10/10. Validation set: Average loss: 0.1088
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249825
# Train: [1098/2931 (100%)]	Loss: 0.141639
# Epoch: 1/10. Train set: Average loss: 0.1419
# Epoch: 1/10. Validation set: Average loss: 0.1306
# Train: [0/2931 (0%)]	Loss: 0.109095
# Train: [1098/2931 (100%)]	Loss: 0.124028
# Epoch: 2/10. Train set: Average loss: 0.1240
# Epoch: 2/10. Validation set: Average loss: 0.1406
# Train: [0/2931 (0%)]	Loss: 0.142982
# Train: [1098/2931 (100%)]	Loss: 0.129126
# Epoch: 3/10. Train set: Average loss: 0.1292
# Epoch: 3/10. Validation set: Average loss: 0.1170
# Train: [0/2931 (0%)]	Loss: 0.226522
# Train: [1098/2931 (100%)]	Loss: 0.123462
# Epoch: 4/10. Train set: Average loss: 0.1237
# Epoch: 4/10. Validation set: Average loss: 0.1243
# Train: [0/2931 (0%)]	Loss: 0.130227
# Train: [1098/2931 (100%)]	Loss: 0.112996
# Epoch: 5/10. Train set: Average loss: 0.1130
# Epoch: 5/10. Validation set: Average loss: 0.1300
# Train: [0/2931 (0%)]	Loss: 0.142743
# Train: [1098/2931 (100%)]	Loss: 0.121954
# Epoch: 6/10. Train set: Average loss: 0.1220
# Epoch: 6/10. Validation set: Average loss: 0.1188
# Train: [0/2931 (0%)]	Loss: 0.106621
# Train: [1098/2931 (100%)]	Loss: 0.110808
# Epoch: 7/10. Train set: Average loss: 0.1108
# Epoch: 7/10. Validation set: Average loss: 0.1128
# Train: [0/2931 (0%)]	Loss: 0.102158
# Train: [1098/2931 (100%)]	Loss: 0.115107
# Epoch: 8/10. Train set: Average loss: 0.1151
# Epoch: 8/10. Validation set: Average loss: 0.1138
# Train: [0/2931 (0%)]	Loss: 0.120881
# Train: [1098/2931 (100%)]	Loss: 0.104845
# Epoch: 9/10. Train set: Average loss: 0.1049
# Epoch: 9/10. Validation set: Average loss: 0.1098
# Train: [0/2931 (0%)]	Loss: 0.122206
# Train: [1098/2931 (100%)]	Loss: 0.106846
# Epoch: 10/10. Train set: Average loss: 0.1069
# Epoch: 10/10. Validation set: Average loss: 0.1096
# Number features: 10
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.124790
# ...
# Epoch: 1/10. Train set: Average loss: 0.1213
# Epoch: 1/10. Validation set: Average loss: 0.0960
# Train: [0/2931 (0%)]	Loss: 0.050283
# Train: [1098/2931 (100%)]	Loss: 0.102864
# Epoch: 2/10. Train set: Average loss: 0.1027
# Epoch: 2/10. Validation set: Average loss: 0.1111
# Train: [0/2931 (0%)]	Loss: 0.084867
# Train: [1098/2931 (100%)]	Loss: 0.090822
# Epoch: 3/10. Train set: Average loss: 0.0908
# Epoch: 3/10. Validation set: Average loss: 0.0819
# Train: [0/2931 (0%)]	Loss: 0.067314
# Train: [1098/2931 (100%)]	Loss: 0.080826
# Epoch: 4/10. Train set: Average loss: 0.0808
# Epoch: 4/10. Validation set: Average loss: 0.0873
# Train: [0/2931 (0%)]	Loss: 0.176911
# Train: [1098/2931 (100%)]	Loss: 0.076336
# Epoch: 5/10. Train set: Average loss: 0.0766
# Epoch: 5/10. Validation set: Average loss: 0.0694
# Train: [0/2931 (0%)]	Loss: 0.031891
# Train: [1098/2931 (100%)]	Loss: 0.070041
# Epoch: 6/10. Train set: Average loss: 0.0699
# Epoch: 6/10. Validation set: Average loss: 0.0746
# Train: [0/2931 (0%)]	Loss: 0.076018
# Train: [1098/2931 (100%)]	Loss: 0.068453
# Epoch: 7/10. Train set: Average loss: 0.0685
# Epoch: 7/10. Validation set: Average loss: 0.0590
# Train: [0/2931 (0%)]	Loss: 0.067631
# Train: [1098/2931 (100%)]	Loss: 0.060767
# Epoch: 8/10. Train set: Average loss: 0.0608
# Epoch: 8/10. Validation set: Average loss: 0.0644
# Train: [0/2931 (0%)]	Loss: 0.059111
# Train: [1098/2931 (100%)]	Loss: 0.055412
# Epoch: 9/10. Train set: Average loss: 0.0554
# Epoch: 9/10. Validation set: Average loss: 0.0542
# Train: [0/2931 (0%)]	Loss: 0.091278
# Train: [1098/2931 (100%)]	Loss: 0.052345
# Epoch: 10/10. Train set: Average loss: 0.0525
# Epoch: 10/10. Validation set: Average loss: 0.0523
# Number features: 37
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.311848
# Train: [1098/2931 (100%)]	Loss: 0.101998
# Epoch: 1/10. Train set: Average loss: 0.1026
# Epoch: 1/10. Validation set: Average loss: 0.1141
# Train: [0/2931 (0%)]	Loss: 0.053067
# Train: [1098/2931 (100%)]	Loss: 0.096939
# Epoch: 2/10. Train set: Average loss: 0.0968
# Epoch: 2/10. Validation set: Average loss: 0.0811
# Train: [0/2931 (0%)]	Loss: 0.124660
# Train: [1098/2931 (100%)]	Loss: 0.072524
# Epoch: 3/10. Train set: Average loss: 0.0727
# Epoch: 3/10. Validation set: Average loss: 0.0761
# Train: [0/2931 (0%)]	Loss: 0.040689
# Train: [1098/2931 (100%)]	Loss: 0.068561
# Epoch: 4/10. Train set: Average loss: 0.0685
# Epoch: 4/10. Validation set: Average loss: 0.0672
# Train: [0/2931 (0%)]	Loss: 0.032652
# Train: [1098/2931 (100%)]	Loss: 0.065104
# Epoch: 5/10. Train set: Average loss: 0.0650
# Epoch: 5/10. Validation set: Average loss: 0.0665
# Train: [0/2931 (0%)]	Loss: 0.042801
# Train: [1098/2931 (100%)]	Loss: 0.061196
# Epoch: 6/10. Train set: Average loss: 0.0611
# Epoch: 6/10. Validation set: Average loss: 0.0568
# Train: [0/2931 (0%)]	Loss: 0.078075
# Train: [1098/2931 (100%)]	Loss: 0.056699
# Epoch: 7/10. Train set: Average loss: 0.0568
# Epoch: 7/10. Validation set: Average loss: 0.0666
# Train: [0/2931 (0%)]	Loss: 0.130892
# Train: [1098/2931 (100%)]	Loss: 0.056788
# Epoch: 8/10. Train set: Average loss: 0.0570
# Epoch: 8/10. Validation set: Average loss: 0.0817
# Train: [0/2931 (0%)]	Loss: 0.019386
# Train: [1098/2931 (100%)]	Loss: 0.055513
# Epoch: 9/10. Train set: Average loss: 0.0554
# Epoch: 9/10. Validation set: Average loss: 0.0443
# Train: [0/2931 (0%)]	Loss: 0.010559
# Train: [1098/2931 (100%)]	Loss: 0.044063
# Epoch: 10/10. Train set: Average loss: 0.0440
# Epoch: 10/10. Validation set: Average loss: 0.0424
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.248724
# Train: [1098/2931 (100%)]	Loss: 0.093080
# Epoch: 1/10. Train set: Average loss: 0.0935
# Epoch: 1/10. Validation set: Average loss: 0.0807
# Train: [0/2931 (0%)]	Loss: 0.033676
# Train: [1098/2931 (100%)]	Loss: 0.081318
# Epoch: 2/10. Train set: Average loss: 0.0812
# Epoch: 2/10. Validation set: Average loss: 0.0710
# Train: [0/2931 (0%)]	Loss: 0.031382
# Train: [1098/2931 (100%)]	Loss: 0.063288
# Epoch: 3/10. Train set: Average loss: 0.0632
# Epoch: 3/10. Validation set: Average loss: 0.0547
# Train: [0/2931 (0%)]	Loss: 0.037343
# Train: [1098/2931 (100%)]	Loss: 0.054561
# Epoch: 4/10. Train set: Average loss: 0.0545
# Epoch: 4/10. Validation set: Average loss: 0.0490
# Train: [0/2931 (0%)]	Loss: 0.012418
# Train: [1098/2931 (100%)]	Loss: 0.054816
# Epoch: 5/10. Train set: Average loss: 0.0547
# Epoch: 5/10. Validation set: Average loss: 0.0531
# Train: [0/2931 (0%)]	Loss: 0.039198
# Train: [1098/2931 (100%)]	Loss: 0.054943
# Epoch: 6/10. Train set: Average loss: 0.0549
# Epoch: 6/10. Validation set: Average loss: 0.0438
# Train: [0/2931 (0%)]	Loss: 0.028785
# Train: [1098/2931 (100%)]	Loss: 0.050375
# Epoch: 7/10. Train set: Average loss: 0.0503
# Epoch: 7/10. Validation set: Average loss: 0.0437
# Train: [0/2931 (0%)]	Loss: 0.039684
# Train: [1098/2931 (100%)]	Loss: 0.052581
# Epoch: 8/10. Train set: Average loss: 0.0525
# Epoch: 8/10. Validation set: Average loss: 0.0543
# Train: [0/2931 (0%)]	Loss: 0.061896
# Train: [1098/2931 (100%)]	Loss: 0.041329
# Epoch: 9/10. Train set: Average loss: 0.0414
# Epoch: 9/10. Validation set: Average loss: 0.0323
# Train: [0/2931 (0%)]	Loss: 0.008909
# Train: [1098/2931 (100%)]	Loss: 0.037902
# Epoch: 10/10. Train set: Average loss: 0.0378
# Epoch: 10/10. Validation set: Average loss: 0.0288
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249264
# Train: [1098/2931 (100%)]	Loss: 0.107830
# Epoch: 1/10. Train set: Average loss: 0.1082
# Epoch: 1/10. Validation set: Average loss: 0.0854
# Train: [0/2931 (0%)]	Loss: 0.047801
# Train: [1098/2931 (100%)]	Loss: 0.086244
# Epoch: 2/10. Train set: Average loss: 0.0861
# Epoch: 2/10. Validation set: Average loss: 0.0823
# Train: [0/2931 (0%)]	Loss: 0.048035
# Train: [1098/2931 (100%)]	Loss: 0.074879
# Epoch: 3/10. Train set: Average loss: 0.0748
# Epoch: 3/10. Validation set: Average loss: 0.0715
# Train: [0/2931 (0%)]	Loss: 0.136700
# Train: [1098/2931 (100%)]	Loss: 0.068614
# Epoch: 4/10. Train set: Average loss: 0.0688
# Epoch: 4/10. Validation set: Average loss: 0.0571
# Train: [0/2931 (0%)]	Loss: 0.066970
# Train: [1098/2931 (100%)]	Loss: 0.061749
# Epoch: 5/10. Train set: Average loss: 0.0618
# Epoch: 5/10. Validation set: Average loss: 0.0557
# Train: [0/2931 (0%)]	Loss: 0.071985
# Train: [1098/2931 (100%)]	Loss: 0.053619
# Epoch: 6/10. Train set: Average loss: 0.0537
# Epoch: 6/10. Validation set: Average loss: 0.0538
# Train: [0/2931 (0%)]	Loss: 0.040515
# Train: [1098/2931 (100%)]	Loss: 0.050971
# Epoch: 7/10. Train set: Average loss: 0.0509
# Epoch: 7/10. Validation set: Average loss: 0.0482
# Train: [0/2931 (0%)]	Loss: 0.007668
# Train: [1098/2931 (100%)]	Loss: 0.048376
# Epoch: 8/10. Train set: Average loss: 0.0483
# Epoch: 8/10. Validation set: Average loss: 0.0434
# Train: [0/2931 (0%)]	Loss: 0.023853
# Train: [1098/2931 (100%)]	Loss: 0.043466
# Epoch: 9/10. Train set: Average loss: 0.0434
# Epoch: 9/10. Validation set: Average loss: 0.0386
# Train: [0/2931 (0%)]	Loss: 0.043117
# Train: [1098/2931 (100%)]	Loss: 0.036975
# Epoch: 10/10. Train set: Average loss: 0.0370
# Epoch: 10/10. Validation set: Average loss: 0.0370
# Number features: 38
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.124641
# Train: [1098/2931 (100%)]	Loss: 0.118159
# Epoch: 1/10. Train set: Average loss: 0.1182
# Epoch: 1/10. Validation set: Average loss: 0.0971
# Train: [0/2931 (0%)]	Loss: 0.044036
# Train: [1098/2931 (100%)]	Loss: 0.081377
# Epoch: 2/10. Train set: Average loss: 0.0813
# Epoch: 2/10. Validation set: Average loss: 0.0842
# Train: [0/2931 (0%)]	Loss: 0.068471
# Train: [1098/2931 (100%)]	Loss: 0.071626
# Epoch: 3/10. Train set: Average loss: 0.0716
# Epoch: 3/10. Validation set: Average loss: 0.0643
# Train: [0/2931 (0%)]	Loss: 0.105047
# Train: [1098/2931 (100%)]	Loss: 0.064388
# Epoch: 4/10. Train set: Average loss: 0.0645
# Epoch: 4/10. Validation set: Average loss: 0.0645
# Train: [0/2931 (0%)]	Loss: 0.069028
# Train: [1098/2931 (100%)]	Loss: 0.056846
# Epoch: 5/10. Train set: Average loss: 0.0569
# Epoch: 5/10. Validation set: Average loss: 0.0594
# Train: [0/2931 (0%)]	Loss: 0.060384
# Train: [1098/2931 (100%)]	Loss: 0.054385
# Epoch: 6/10. Train set: Average loss: 0.0544
# Epoch: 6/10. Validation set: Average loss: 0.0576
# Train: [0/2931 (0%)]	Loss: 0.029267
# Train: [1098/2931 (100%)]	Loss: 0.047092
# Epoch: 7/10. Train set: Average loss: 0.0470
# Epoch: 7/10. Validation set: Average loss: 0.0519
# Train: [0/2931 (0%)]	Loss: 0.039658
# Train: [1098/2931 (100%)]	Loss: 0.041364
# Epoch: 8/10. Train set: Average loss: 0.0414
# Epoch: 8/10. Validation set: Average loss: 0.0447
# Train: [0/2931 (0%)]	Loss: 0.044772
# Train: [1098/2931 (100%)]	Loss: 0.032836
# Epoch: 9/10. Train set: Average loss: 0.0329
# Epoch: 9/10. Validation set: Average loss: 0.0396
# Train: [0/2931 (0%)]	Loss: 0.052486
# Train: [1098/2931 (100%)]	Loss: 0.030037
# Epoch: 10/10. Train set: Average loss: 0.0301
# Epoch: 10/10. Validation set: Average loss: 0.0375
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.311880
# Train: [1098/2931 (100%)]	Loss: 0.088457
# Epoch: 1/10. Train set: Average loss: 0.0891
# Epoch: 1/10. Validation set: Average loss: 0.0869
# Train: [0/2931 (0%)]	Loss: 0.107954
# Train: [1098/2931 (100%)]	Loss: 0.077673
# Epoch: 2/10. Train set: Average loss: 0.0778
# Epoch: 2/10. Validation set: Average loss: 0.0747
# Train: [0/2931 (0%)]	Loss: 0.023292
# Train: [1098/2931 (100%)]	Loss: 0.069085
# Epoch: 3/10. Train set: Average loss: 0.0690
# Epoch: 3/10. Validation set: Average loss: 0.0711
# Train: [0/2931 (0%)]	Loss: 0.104033
# Train: [1098/2931 (100%)]	Loss: 0.070574
# Epoch: 4/10. Train set: Average loss: 0.0707
# Epoch: 4/10. Validation set: Average loss: 0.0804
# Train: [0/2931 (0%)]	Loss: 0.123397
# Train: [1098/2931 (100%)]	Loss: 0.054489
# Epoch: 5/10. Train set: Average loss: 0.0547
# Epoch: 5/10. Validation set: Average loss: 0.0630
# Train: [0/2931 (0%)]	Loss: 0.102460
# Train: [1098/2931 (100%)]	Loss: 0.049065
# Epoch: 6/10. Train set: Average loss: 0.0492
# Epoch: 6/10. Validation set: Average loss: 0.0528
# Train: [0/2931 (0%)]	Loss: 0.052650
# Train: [1098/2931 (100%)]	Loss: 0.048250
# Epoch: 7/10. Train set: Average loss: 0.0483
# Epoch: 7/10. Validation set: Average loss: 0.0505
# Train: [0/2931 (0%)]	Loss: 0.204727
# Train: [1098/2931 (100%)]	Loss: 0.040401
# Epoch: 8/10. Train set: Average loss: 0.0408
# Epoch: 8/10. Validation set: Average loss: 0.0449
# Train: [0/2931 (0%)]	Loss: 0.037092
# Train: [1098/2931 (100%)]	Loss: 0.034142
# Epoch: 9/10. Train set: Average loss: 0.0341
# Epoch: 9/10. Validation set: Average loss: 0.0383
# Train: [0/2931 (0%)]	Loss: 0.030039
# Train: [1098/2931 (100%)]	Loss: 0.028700
# Epoch: 10/10. Train set: Average loss: 0.0287
# Epoch: 10/10. Validation set: Average loss: 0.0369
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.311692
# Train: [1098/2931 (100%)]	Loss: 0.103069
# Epoch: 1/10. Train set: Average loss: 0.1036
# Epoch: 1/10. Validation set: Average loss: 0.0868
# Train: [0/2931 (0%)]	Loss: 0.049432
# Train: [1098/2931 (100%)]	Loss: 0.075005
# Epoch: 2/10. Train set: Average loss: 0.0749
# Epoch: 2/10. Validation set: Average loss: 0.0829
# Train: [0/2931 (0%)]	Loss: 0.133153
# Train: [1098/2931 (100%)]	Loss: 0.067993
# Epoch: 3/10. Train set: Average loss: 0.0682
# Epoch: 3/10. Validation set: Average loss: 0.0737
# Train: [0/2931 (0%)]	Loss: 0.039298
# Train: [1098/2931 (100%)]	Loss: 0.060159
# Epoch: 4/10. Train set: Average loss: 0.0601
# Epoch: 4/10. Validation set: Average loss: 0.0743
# Train: [0/2931 (0%)]	Loss: 0.046896
# Train: [1098/2931 (100%)]	Loss: 0.055058
# Epoch: 5/10. Train set: Average loss: 0.0550
# Epoch: 5/10. Validation set: Average loss: 0.0700
# Train: [0/2931 (0%)]	Loss: 0.109273
# Train: [1098/2931 (100%)]	Loss: 0.050425
# Epoch: 6/10. Train set: Average loss: 0.0506
# Epoch: 6/10. Validation set: Average loss: 0.0524
# Train: [0/2931 (0%)]	Loss: 0.067884
# Train: [1098/2931 (100%)]	Loss: 0.047075
# Epoch: 7/10. Train set: Average loss: 0.0471
# Epoch: 7/10. Validation set: Average loss: 0.0536
# Train: [0/2931 (0%)]	Loss: 0.039437
# Train: [1098/2931 (100%)]	Loss: 0.040981
# Epoch: 8/10. Train set: Average loss: 0.0410
# Epoch: 8/10. Validation set: Average loss: 0.0663
# Train: [0/2931 (0%)]	Loss: 0.109179
# Train: [1098/2931 (100%)]	Loss: 0.034679
# Epoch: 9/10. Train set: Average loss: 0.0349
# Epoch: 9/10. Validation set: Average loss: 0.0391
# Train: [0/2931 (0%)]	Loss: 0.057643
# Train: [1098/2931 (100%)]	Loss: 0.029358
# Epoch: 10/10. Train set: Average loss: 0.0294
# Epoch: 10/10. Validation set: Average loss: 0.0376
# Number features: 39
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187117
# Train: [1098/2931 (100%)]	Loss: 0.084127
# Epoch: 1/10. Train set: Average loss: 0.0844
# Epoch: 1/10. Validation set: Average loss: 0.0649
# Train: [0/2931 (0%)]	Loss: 0.091098
# Train: [1098/2931 (100%)]	Loss: 0.068621
# Epoch: 2/10. Train set: Average loss: 0.0687
# Epoch: 2/10. Validation set: Average loss: 0.0547
# Train: [0/2931 (0%)]	Loss: 0.038865
# Train: [1098/2931 (100%)]	Loss: 0.063290
# Epoch: 3/10. Train set: Average loss: 0.0632
# Epoch: 3/10. Validation set: Average loss: 0.0515
# Train: [0/2931 (0%)]	Loss: 0.059441
# Train: [1098/2931 (100%)]	Loss: 0.055834
# Epoch: 4/10. Train set: Average loss: 0.0558
# Epoch: 4/10. Validation set: Average loss: 0.0574
# Train: [0/2931 (0%)]	Loss: 0.052021
# Train: [1098/2931 (100%)]	Loss: 0.059092
# Epoch: 5/10. Train set: Average loss: 0.0591
# Epoch: 5/10. Validation set: Average loss: 0.0463
# Train: [0/2931 (0%)]	Loss: 0.063165
# Train: [1098/2931 (100%)]	Loss: 0.068596
# Epoch: 6/10. Train set: Average loss: 0.0686
# Epoch: 6/10. Validation set: Average loss: 0.0968
# Train: [0/2931 (0%)]	Loss: 0.147924
# Train: [1098/2931 (100%)]	Loss: 0.057838
# Epoch: 7/10. Train set: Average loss: 0.0581
# Epoch: 7/10. Validation set: Average loss: 0.0514
# Train: [0/2931 (0%)]	Loss: 0.089892
# Train: [1098/2931 (100%)]	Loss: 0.050802
# Epoch: 8/10. Train set: Average loss: 0.0509
# Epoch: 8/10. Validation set: Average loss: 0.0480
# Train: [0/2931 (0%)]	Loss: 0.022099
# Train: [1098/2931 (100%)]	Loss: 0.040801
# Epoch: 9/10. Train set: Average loss: 0.0408
# Epoch: 9/10. Validation set: Average loss: 0.0364
# Train: [0/2931 (0%)]	Loss: 0.048635
# Train: [1098/2931 (100%)]	Loss: 0.037292
# Epoch: 10/10. Train set: Average loss: 0.0373
# Epoch: 10/10. Validation set: Average loss: 0.0344
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.248688
# Train: [1098/2931 (100%)]	Loss: 0.086893
# Epoch: 1/10. Train set: Average loss: 0.0873
# Epoch: 1/10. Validation set: Average loss: 0.0836
# Train: [0/2931 (0%)]	Loss: 0.153672
# Train: [1098/2931 (100%)]	Loss: 0.065732
# Epoch: 2/10. Train set: Average loss: 0.0660
# Epoch: 2/10. Validation set: Average loss: 0.0524
# Train: [0/2931 (0%)]	Loss: 0.120154
# Train: [1098/2931 (100%)]	Loss: 0.061977
# Epoch: 3/10. Train set: Average loss: 0.0621
# Epoch: 3/10. Validation set: Average loss: 0.0688
# Train: [0/2931 (0%)]	Loss: 0.053570
# Train: [1098/2931 (100%)]	Loss: 0.058171
# Epoch: 4/10. Train set: Average loss: 0.0582
# Epoch: 4/10. Validation set: Average loss: 0.0690
# Train: [0/2931 (0%)]	Loss: 0.040382
# Train: [1098/2931 (100%)]	Loss: 0.056866
# Epoch: 5/10. Train set: Average loss: 0.0568
# Epoch: 5/10. Validation set: Average loss: 0.0443
# Train: [0/2931 (0%)]	Loss: 0.063523
# Train: [1098/2931 (100%)]	Loss: 0.052103
# Epoch: 6/10. Train set: Average loss: 0.0521
# Epoch: 6/10. Validation set: Average loss: 0.0470
# Train: [0/2931 (0%)]	Loss: 0.104091
# Train: [1098/2931 (100%)]	Loss: 0.051176
# Epoch: 7/10. Train set: Average loss: 0.0513
# Epoch: 7/10. Validation set: Average loss: 0.0634
# Train: [0/2931 (0%)]	Loss: 0.028374
# Train: [1098/2931 (100%)]	Loss: 0.053418
# Epoch: 8/10. Train set: Average loss: 0.0534
# Epoch: 8/10. Validation set: Average loss: 0.0492
# Train: [0/2931 (0%)]	Loss: 0.053176
# Train: [1098/2931 (100%)]	Loss: 0.041600
# Epoch: 9/10. Train set: Average loss: 0.0416
# Epoch: 9/10. Validation set: Average loss: 0.0360
# Train: [0/2931 (0%)]	Loss: 0.013755
# Train: [1098/2931 (100%)]	Loss: 0.035619
# Epoch: 10/10. Train set: Average loss: 0.0356
# Epoch: 10/10. Validation set: Average loss: 0.0351
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.124563
# Train: [1098/2931 (100%)]	Loss: 0.085387
# Epoch: 1/10. Train set: Average loss: 0.0855
# Epoch: 1/10. Validation set: Average loss: 0.0702
# Train: [0/2931 (0%)]	Loss: 0.031948
# Train: [1098/2931 (100%)]	Loss: 0.073373
# Epoch: 2/10. Train set: Average loss: 0.0733
# Epoch: 2/10. Validation set: Average loss: 0.0918
# Train: [0/2931 (0%)]	Loss: 0.019602
# Train: [1098/2931 (100%)]	Loss: 0.066503
