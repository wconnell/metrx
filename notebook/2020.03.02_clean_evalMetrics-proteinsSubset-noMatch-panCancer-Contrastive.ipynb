# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")
                
import numpy as np
import pandas as pd
#np.random.seed(123)

# viz
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(12.7,10.27)})

# notebook settings
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

pd.set_option('display.max_columns', 1000)

# %% [markdown]
# ## Sample Prep

# %%
HGNC = pd.read_csv("../../../keiser/data/hgnc_mapping_ids/hgnc.txt", sep="\t")

# %% [markdown]
# ### Define sample types

# %%
from collections import OrderedDict 
hierarchy = OrderedDict({'Project ID':['TCGA-BRCA', 'TCGA-LUAD', 'TCGA-KIRC', 'TCGA-THCA', 'TCGA-PRAD', 'TCGA-SKCM'],
                         'Sample Type':['Primary Tumor', 'Solid Tissue Normal']})

# %%
from dutils import Experiment, train_test_split_case, featurize
exp = Experiment(samples_dir='../../data/TCGA/rna-seq_pan/meta/gdc_sample_sheet.2019-12-12.tsv',
                 hierarchy=hierarchy,
                 cases='Case ID',
                 min_samples=20)

# %% [markdown]
# ## Dataset Prep

# %% [markdown]
# Need to ensure test set has health/diseased samples matched for each case

# %%
exp.samples['meta'].value_counts()
# Out:
# TCGA-BRCA:Primary Tumor          1087
# TCGA-LUAD:Primary Tumor           528
# TCGA-KIRC:Primary Tumor           483
# TCGA-PRAD:Primary Tumor           466
# TCGA-THCA:Primary Tumor           445
# TCGA-BRCA:Solid Tissue Normal     112
# TCGA-SKCM:Primary Tumor           103
# TCGA-KIRC:Solid Tissue Normal      70
# TCGA-LUAD:Solid Tissue Normal      58
# TCGA-THCA:Solid Tissue Normal      53
# TCGA-PRAD:Solid Tissue Normal      50
# Name: meta, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

target = 'meta'

train, test = train_test_split_case(exp.samples, cases='Case ID')
# stratification is not quite perfect but close
# in order to preserve matched samples for each case together
# in train or test set
case_counts = exp.samples[target].value_counts()
train[target].value_counts()[case_counts.index.to_numpy()] / case_counts
test[target].value_counts()[case_counts.index.to_numpy()] / case_counts
# Out:
# TCGA-BRCA:Primary Tumor          0.804968
# TCGA-LUAD:Primary Tumor          0.785985
# TCGA-KIRC:Primary Tumor          0.815735
# TCGA-PRAD:Primary Tumor          0.783262
# TCGA-THCA:Primary Tumor          0.802247
# TCGA-BRCA:Solid Tissue Normal    0.830357
# TCGA-SKCM:Primary Tumor          0.834951
# TCGA-KIRC:Solid Tissue Normal    0.742857
# TCGA-LUAD:Solid Tissue Normal    0.758621
# TCGA-THCA:Solid Tissue Normal    0.867925
# TCGA-PRAD:Solid Tissue Normal    0.840000
# Name: meta, dtype: float64
# TCGA-BRCA:Primary Tumor          0.195032
# TCGA-LUAD:Primary Tumor          0.214015
# TCGA-KIRC:Primary Tumor          0.184265
# TCGA-PRAD:Primary Tumor          0.216738
# TCGA-THCA:Primary Tumor          0.197753
# TCGA-BRCA:Solid Tissue Normal    0.169643
# TCGA-SKCM:Primary Tumor          0.165049
# TCGA-KIRC:Solid Tissue Normal    0.257143
# TCGA-LUAD:Solid Tissue Normal    0.241379
# TCGA-THCA:Solid Tissue Normal    0.132075
# TCGA-PRAD:Solid Tissue Normal    0.160000
# Name: meta, dtype: float64

# %%
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable
#torch.manual_seed(123)

from trainer import fit
import visualization as vis
import numpy as np
cuda = torch.cuda.is_available()
print("Cuda is available: {}".format(cuda))
# Out:
# Cuda is available: True

# %%
from tcga_datasets import TCGA, SiameseTCGA
root_dir = "../../data/TCGA/rna-seq_pan/"

train_tcga = TCGA(root_dir, samples=train.sample(n=100), train=True, target=target, log=True)
test_tcga = TCGA(root_dir, samples=test.sample(n=100), train=False, target=target, log=True)

scaler = StandardScaler()
train_tcga.data = pd.DataFrame(scaler.fit_transform(train_tcga.data),
                                  index=train_tcga.data.index,
                                  columns=train_tcga.data.columns)
test_tcga.data = pd.DataFrame(scaler.transform(test_tcga.data),
                                 index=test_tcga.data.index,
                                 columns=test_tcga.data.columns)

# %%
# Featurize
train_dataset, test_dataset = featurize(train_tcga, test_tcga, HGNC=HGNC, features='all', proteins_only=True)

# %%
train_dataset.data.shape
test_dataset.data.shape

# Still required in order to feed single samples for embedding extraction
batch_size = 1
kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {'num_workers': 10}
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, **kwargs)
# Out:
# (100, 19577)
# (100, 19577)

# %% [markdown]
# ## Siamese Network

# %%
# Step 1 set up dataloader
siamese_train_dataset = SiameseTCGA(train_dataset) # Returns pairs of images and target same/different
siamese_test_dataset = SiameseTCGA(test_dataset)
batch_size = 8
kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {'num_workers': 10}
siamese_train_loader = torch.utils.data.DataLoader(siamese_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
siamese_test_loader = torch.utils.data.DataLoader(siamese_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)

# Set up the network and training parameters
from tcga_networks import EmbeddingNet, SiameseNet
from losses import ContrastiveLoss
from metrics import AccumulatedAccuracyMetric

# Step 2
n_samples, n_features = siamese_train_dataset.data.shape
embedding_net = EmbeddingNet(n_features)
# Step 3
model = SiameseNet(embedding_net)
if cuda:
    model.cuda()
    
# Step 4
margin = 1.
loss_fn = ContrastiveLoss(margin)
lr = 1e-3
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 3
# print training metrics every log_interval * batch_size
log_interval = round(len(siamese_train_dataset)/4/batch_size)
# Out:
# SiameseNet(
#   (embedding_net): EmbeddingNet(
#     (fc): Sequential(
#       (linear1): Linear(in_features=19577, out_features=2000, bias=True)
#       (relu1): PReLU(num_parameters=1)
#       (linear2): Linear(in_features=2000, out_features=500, bias=True)
#       (relu2): PReLU(num_parameters=1)
#       (linear3): Linear(in_features=500, out_features=250, bias=True)
#       (relu3): PReLU(num_parameters=1)
#       (linear4): Linear(in_features=250, out_features=100, bias=True)
#       (relu4): PReLU(num_parameters=1)
#       (linear5): Linear(in_features=100, out_features=50, bias=True)
#       (relu5): PReLU(num_parameters=1)
#       (linear6): Linear(in_features=50, out_features=10, bias=True)
#       (relu6): PReLU(num_parameters=1)
#       (linear7): Linear(in_features=10, out_features=2, bias=True)
#     )
#   )
# )

# %%
train_loss, val_loss = fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, 
    n_epochs, cuda, log_interval)
# Out:
# Train: [0/100 (0%)]	Loss: 0.186717
# Train: [24/100 (23%)]	Loss: 0.163017
# Train: [48/100 (46%)]	Loss: 0.033089
# Train: [72/100 (69%)]	Loss: 0.027441

# %%
plt.plot(range(0, n_epochs), train_loss, 'rx-', label='train')
plt.plot(range(0, n_epochs), val_loss, 'bx-', label='validation')
plt.legend()

# %%
train_embeddings_cl, train_labels_cl = vis.extract_embeddings(train_loader, model)
vis.sns_plot_embeddings(train_embeddings_cl, train_labels_cl, siamese_train_dataset, hue='meta', style='Sample Type')
plt.title('PanCancer Train: Siamese')

# %%
val_embeddings_baseline, val_labels_baseline = vis.extract_embeddings(test_loader, model)
vis.sns_plot_embeddings(val_embeddings_baseline, val_labels_baseline, siamese_test_dataset, hue='meta', style='Sample Type')
plt.title('PanCancer Test: Siamese')

# %% [markdown]
# ## Save Model

# %%
save = False
if save:
    torch.save(model.state_dict(), "../../data/TCGA/models/220_seminar_results.pt")

# %% [markdown]
# ## Kmeans Cluster and NMI Evaluation

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import normalized_mutual_info_score as NMI
from sklearn.metrics import adjusted_mutual_info_score as aNMI

# %%
n_clusters = len(siamese_test_dataset.labels_dict)
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
siamese_clusters = kmeans.fit_predict(val_embeddings_baseline)

# %%
aNMI(siamese_clusters, val_labels_baseline)

# %% [markdown]
# ## Project Metastatic SKCM

# %%
proj_hierarchy = OrderedDict({'Project ID':['TCGA-SKCM'],
                              'Sample Type':['Metastatic']})

# %%
# Need to define Experiment method for use in adding classes for projection
# because categorical classes are predefined, need to add an additional class based
# on these numerical labels
# this will probably be helpful with plotting also...

# %%
proj = Experiment(samples_dir='../../data/TCGA/rna-seq_pan/meta/gdc_sample_sheet.2019-12-12.tsv',
                 hierarchy=proj_hierarchy,
                 cases='Case ID',
                 min_samples=20)

# %%
proj_tcga= TCGA(root_dir, samples=proj.samples, train=False, target=target, log=True)

# %%
proj_dataset.data = pd.DataFrame(scaler.transform(proj_tcga.data),
                                 index=proj_tcga.data.index,
                                 columns=proj_tcga.data.columns)

# %%
test_tcga.data.shape

# %%
proj_dataset.data.shape

# %%
# Featurize
proj_dataset, _ = featurize(proj_tcga, test_tcga, HGNC=HGNC, features='all', proteins_only=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-339-58bc620f1477> in <module>
#       1 # Featurize
# ----> 2 proj_dataset, _ = featurize(proj_tcga, test_tcga, HGNC=HGNC, features='all', proteins_only=True)
#
# ~/github/metrx/dutils.py in featurize(train_TCGA, test_TCGA, HGNC, features, proteins_only)
#      72     parsed_cols = pd.DataFrame([ens[0] for ens in train_TCGA.data.columns.str.split(".")],
#      73                                 columns=['ENSEMBL_ID'])
# ---> 74     train_TCGA.data.columns, test_TCGA.data.columns = parsed_cols['ENSEMBL_ID'].values, parsed_cols['ENSEMBL_ID'].values
#      75     protein_overlap_idx = parsed_cols['ENSEMBL_ID'].isin(HGNC['Ensembl gene ID'].values).values
#      76     # downsample
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     688
#     689     def _set_axis(self, axis, labels):
# --> 690         self._data.set_axis(axis, labels)
#     691         self._clear_item_cache()
#     692
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     181             raise ValueError(
#     182                 "Length mismatch: Expected axis has {old} elements, new "
# --> 183                 "values have {new} elements".format(old=old_len, new=new_len)
#     184             )
#     185
#
# ValueError: Length mismatch: Expected axis has 19577 elements, new values have 60483 elements

# %%
proj_loader = torch.utils.data.DataLoader(proj_dataset, batch_size=batch_size, shuffle=False, **kwargs)

# %%
proj_embeddings_baseline, proj_labels_baseline = vis.extract_embeddings(proj_loader, model)

# %% [markdown]
# ## SKCM Clinical Info

# %%
skcm_clinical = pd.read_csv("../../data/TCGA/clinical/skcm/https:/api.gdc.cancer.gov/data/58cbbc07-5ec4-47c7-9295-11ccbf7693f4/nationwidechildrens.org_clinical_patient_skcm.txt", 
                            sep="\t")
# remove extra header
skcm_clinical = skcm_clinical.loc[2:, :].reset_index(drop=True)
skcm_clinical.shape
# Out:
# (470, 65)

# %%
skcm_metas_dist = skcm_clinical[skcm_clinical['primary_location'] == 'Distant Metastasis']
skcm_metas_dist = skcm_clinical[skcm_clinical['metastatic_tumor_site'] == 'Lung']
skcm_metas_dist.shape
# Out:
# (5, 65)

# %%
bool_skcm_metas_dist = projection_dataset.samples['Case ID'].isin(skcm_metas_dist['bcr_patient_barcode'])
bool_skcm_metas_dist.sum()
# Out:
# 5

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(18.7,14.27)})

# %%
vis.sns_plot_embeddings(proj_embeddings_baseline, projection_dataset, hue='Meta ID', style='Sample Type')
plt.scatter(proj_embeddings_baseline[bool_skcm_metas_dist,0], 
            proj_embeddings_baseline[bool_skcm_metas_dist,1],
            marker="+", color='k', s=200)
plt.title('PanCancer Metastatic: Siamese')
# Out:
# Text(0.5, 1.0, 'PanCancer Metastatic: Siamese')

# %% [markdown]
# ## Project CCLE Cells
# - no normalization or scaling done here...

# %%
ccle_meta = pd.read_csv("../../data/DepMap/sample_info_v2.csv", index_col=0)
ccle_meta.head()
# Out:
#            stripped_cell_line_name  \
# DepMap_ID
# ACH-000001               NIHOVCAR3
# ACH-000002                    HL60
# ACH-000003                   CACO2
# ACH-000004                     HEL
# ACH-000005                 HEL9217
#
#                                              CCLE_Name          alias  \
# DepMap_ID
# ACH-000001                             NIHOVCAR3_OVARY         OVCAR3
# ACH-000002     HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NaN
# ACH-000003                       CACO2_LARGE_INTESTINE  CACO2, CaCo-2
# ACH-000004      HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NaN
# ACH-000005  HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NaN
#
#             COSMIC_ID     lineage            lineage_subtype  \
# DepMap_ID
# ACH-000001   905933.0       ovary       ovary_adenocarcinoma
# ACH-000002   905938.0       blood                        AML
# ACH-000003        NaN  colorectal  colorectal_adenocarcinoma
# ACH-000004   907053.0       blood                        AML
# ACH-000005        NaN       blood                        AML
#
#            lineage_sub_subtype lineage_molecular_subtype     sex source  \
# DepMap_ID
# ACH-000001   high_grade_serous                       NaN  Female   ATCC
# ACH-000002                  M3                       NaN  Female   ATCC
# ACH-000003                 NaN                       NaN    Male   ATCC
# ACH-000004                  M6                       NaN    Male   DSMZ
# ACH-000005                  M6                       NaN    Male   ATCC
#
#             Achilles_n_replicates  cell_line_NNMD   culture_type  \
# DepMap_ID
# ACH-000001                    NaN             NaN            NaN
# ACH-000002                    NaN             NaN            NaN
# ACH-000003                    NaN             NaN            NaN
# ACH-000004                    2.0       -3.079202     Suspension
# ACH-000005                    2.0       -2.404409  Semi-adherent
#
#                culture_medium cas9_activity       RRID  \
# DepMap_ID
# ACH-000001                NaN           NaN  CVCL_0465
# ACH-000002                NaN           NaN  CVCL_0002
# ACH-000003                NaN           NaN  CVCL_0025
# ACH-000004  RPMI-1640: 10%FBS          47.6  CVCL_0001
# ACH-000005      RPMI; 10% FBS          13.4  CVCL_2481
#
#                         sample_collection_site primary_or_metastasis  \
# DepMap_ID
# ACH-000001                             ascites            Metastasis
# ACH-000002  haematopoietic_and_lymphoid_tissue               Primary
# ACH-000003                               Colon                   NaN
# ACH-000004  haematopoietic_and_lymphoid_tissue                   NaN
# ACH-000005                         bone_marrow                   NaN
#
#                             disease  \
# DepMap_ID
# ACH-000001           Ovarian Cancer
# ACH-000002                 Leukemia
# ACH-000003  Colon/Colorectal Cancer
# ACH-000004                 Leukemia
# ACH-000005                 Leukemia
#
#                                               disease_subtype   age  \
# DepMap_ID
# ACH-000001                  Adenocarcinoma, high grade serous  60.0
# ACH-000002  Acute Myelogenous Leukemia (AML), M3 (Promyelo...  35.0
# ACH-000003                                     Adenocarcinoma   NaN
# ACH-000004  Acute Myelogenous Leukemia (AML), M6 (Erythrol...  30.0
# ACH-000005  Acute Myelogenous Leukemia (AML), M6 (Erythrol...  30.0
#
#            Sanger_model_ID additional_info
# DepMap_ID
# ACH-000001       SIDM00105             NaN
# ACH-000002       SIDM00829             NaN
# ACH-000003       SIDM00891             NaN
# ACH-000004       SIDM00594             NaN
# ACH-000005       SIDM00593             NaN

# %%
msys = ['Lung Cancer', 'Breast Cancer', 'Kidney Cancer', 'Prostate Cancer', 'Skin Cancer', 'Thyroid Cancer']
ccle_meta_sub = ccle_meta[ccle_meta['disease'].isin(msys)]
ccle_meta_sub.shape
# Out:
# (547, 23)

# %%
# get shared protein subset to training data
ccle_overlap_idx = ccle.columns.isin(train_dataset.data.columns)
ccle = ccle.loc[:, ccle_overlap_idx]

# %%
# reorder columns to match training columns
ccle = ccle[train_dataset.data.columns]
assert np.array_equal(ccle.columns.values, train_dataset.data.columns.values)

# %%
# reorder rows to match data and meta data
ccle_sub = ccle.loc[ccle_meta_sub.index,:]
assert np.array_equal(ccle_meta_sub.index, ccle_sub.index)
# Out:
# /srv/home/wconnell/anaconda3/envs/torch/lib/python3.7/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
from tcga_datasets import CCLE
ccle_dataset = CCLE(ccle_sub, ccle_meta_sub, train=False, log=True)
ccle_dataset.data.head()
# Out:
#               TSPAN6  TNMD      DPM1     SCYL3  C1orf112       FGR       CFH  \
# DepMap_ID
# ACH-000008  1.496780   0.0  2.090904  1.164639  1.634322  0.000000  0.093136
# ACH-000010  1.695171   0.0  2.107514  1.225536  1.721793  0.028169  1.482656
# ACH-000012  1.917283   0.0  1.945588  1.088849  1.565382  0.028169  1.321918
# ACH-000014  1.516135   0.0  2.139578  1.220702  1.537032  0.055041  0.223913
# ACH-000015  1.756984   0.0  2.070582  1.374306  1.549537  0.014253  1.517479
#
#                FUCA2      GCLC      NFYA     STPG1    NIPAL3     LAS1L  \
# DepMap_ID
# ACH-000008  2.004548  1.747150  1.658844  1.314973  1.830357  1.875565
# ACH-000010  2.043531  1.665508  1.696140  1.299926  1.201413  1.872562
# ACH-000012  1.977249  1.687885  1.629267  1.253719  1.751345  2.028450
# ACH-000014  1.988292  1.665787  1.655652  1.289857  1.831641  1.847920
# ACH-000015  1.965306  1.682154  1.710719  1.501694  1.250065  1.882769
#
#                ENPP4    SEMA3F      CFTR    ANKIB1   CYP51A1     KRIT1  \
# DepMap_ID
# ACH-000008  0.717660  0.242952  0.261332  1.741417  1.832978  1.858293
# ACH-000010  1.323058  0.864135  0.000000  1.598538  2.051697  1.773414
# ACH-000012  1.138158  0.287750  0.014253  1.710042  1.878282  1.711057
# ACH-000014  0.808655  0.506772  0.183682  1.771590  1.907476  1.877714
# ACH-000015  1.218255  0.889108  0.055041  1.573129  1.886153  1.817071
#
#                RAD52       BAD      LAP3      CD99    HS3ST1      AOC1  \
# DepMap_ID
# ACH-000008  1.482966  1.845218  2.001945  2.125100  0.093136  0.151432
# ACH-000010  1.378053  1.956189  1.790705  2.078140  0.000000  0.093136
# ACH-000012  1.597589  1.807966  1.956067  1.947193  1.026318  0.435650
# ACH-000014  1.547183  1.920894  1.953438  2.245929  0.093136  0.128836
# ACH-000015  1.477342  1.967446  1.809480  1.988017  0.000000  0.014253
#
#                WNT16     HECW1    MAD1L1     LASP1     SNX11  TMEM176A  \
# DepMap_ID
# ACH-000008  0.151432  1.427898  2.018768  1.987389  1.684465  0.140248
# ACH-000010  1.399056  0.000000  1.677057  1.980716  1.723916  0.041760
# ACH-000012  0.223913  0.304645  1.585085  2.155035  1.544567  0.014253
# ACH-000014  0.204172  1.233423  2.080578  2.008620  1.736115  0.183682
# ACH-000015  1.282722  0.000000  1.723282  1.961118  1.580418  0.140248
#
#                 M6PR    KLHL13   CYP26B1      ICA1    DBNDD1      ALS2  \
# DepMap_ID
# ACH-000008  2.165933  1.149636  0.359742  0.789200  1.717369  1.700917
# ACH-000010  1.929995  0.942191  0.093136  0.914567  1.880072  1.717260
# ACH-000012  2.052488  0.506772  0.242952  1.679032  1.854451  1.592008
# ACH-000014  2.155288  1.232643  0.442000  1.348592  1.718999  1.641614
# ACH-000015  1.922561  0.261332  1.220702  1.234975  1.978421  1.576281
#
#               CASP10     CFLAR      TFPI   NDUFAF7      RBM5     MTMR7  \
# DepMap_ID
# ACH-000008  0.926664  1.737305  0.936446  1.673859  1.950423  0.435650
# ACH-000010  0.055041  1.811389  1.997865  1.680988  1.969195  1.007902
# ACH-000012  1.220702  1.943020  1.948277  1.607263  1.925232  0.402591
# ACH-000014  0.918644  1.701507  0.789200  1.652412  1.966479  0.460561
# ACH-000015  0.041760  1.705472  2.038570  1.662839  1.967333  1.049418
#
#               SLC7A2      ARF5     SARM1   POLDIP2    PLXND1       AK2  \
# DepMap_ID
# ACH-000008  1.232643  2.119316  1.385843  2.057229  1.832311  2.211583
# ACH-000010  1.459324  2.175045  1.277418  1.956733  1.756086  2.241812
# ACH-000012  1.060400  2.104930  0.966073  1.922339  1.167555  2.192583
# ACH-000014  0.861780  2.159142  1.576698  2.053608  1.997629  2.174803
# ACH-000015  1.343883  2.221437  1.486035  2.032366  1.691622  2.148826
#
#                 CD38     FKBP4     KDM1A      RBM6    CAMKK1     RECQL  \
# DepMap_ID
# ACH-000008  0.055041  1.946007  1.906104  1.828196  1.065758  1.946841
# ACH-000010  0.000000  1.942758  2.056266  1.984496  1.171401  1.773662
# ACH-000012  0.055041  2.092774  1.952356  1.762643  1.284032  1.795259
# ACH-000014  0.128836  1.909394  1.914911  1.958716  1.121804  1.956975
# ACH-000015  0.068022  1.933561  2.051883  1.977916  1.142381  1.686751
#
#                VPS50     HSPB6  ARHGAP33   NDUFAB1      PDK4  SLC22A16  \
# DepMap_ID
# ACH-000008  1.540464  0.685871  1.223934  2.131393  1.155724  0.151432
# ACH-000010  1.415294  0.321004  1.557141  2.123123  1.233423  0.000000
# ACH-000012  1.590444  0.183682  1.193516  2.007933  0.501239  0.117186
# ACH-000014  1.545760  1.256610  1.319045  2.093944  1.162680  0.151432
# ACH-000015  1.376654  0.381629  1.289857  2.106752  0.958894  0.028169
#
#              ZMYND10     ABCB5       ARX  SLC25A13       ST7     CDC27  \
# DepMap_ID
# ACH-000008  0.352228  1.049418  0.151432  1.889118  1.688011  1.899587
# ACH-000010  0.819354  0.014253  0.000000  1.912115  1.468332  1.850802
# ACH-000012  0.472545  0.000000  0.028169  1.808311  1.630747  1.846461
# ACH-000014  0.940286  0.651484  0.204172  1.834244  1.516405  1.927719
# ACH-000015  0.740799  0.261332  0.028169  1.971674  1.574605  1.824116
#
#               SLC4A1     CALCR      HCCS      DVL2    PRSS22      UPF1  \
# DepMap_ID
# ACH-000008  0.000000  0.014253  2.036523  1.751714  0.367145  1.837758
# ACH-000010  0.055041  0.080717  1.806301  1.853694  0.117186  1.669793
# ACH-000012  0.000000  0.068022  1.861901  1.819881  1.754094  1.842190
# ACH-000014  0.000000  0.140248  1.960558  1.885336  0.093136  1.795702
# ACH-000015  0.233517  0.670931  1.826762  1.781737  0.041760  1.754639
#
#                SKAP2   SLC25A5      MCUB    HOXA11    POLR2J     DHX33  \
# DepMap_ID
# ACH-000008  1.755725  2.352375  1.457278  0.777637  2.114070  1.687760
# ACH-000010  1.945781  2.353896  1.539244  1.252992  2.033505  1.529759
# ACH-000012  1.654185  2.373342  1.372413  0.563621  2.018518  1.799059
# ACH-000014  1.731384  2.274154  1.451738  1.057688  2.130204  1.702212
# ACH-000015  1.616013  2.293597  1.399485  1.065758  2.151154  1.569503
#
#                MEOX1    THSD7A      LIG3     RPAP3     ACSM3     REXO5  \
# DepMap_ID
# ACH-000008  0.041760  0.014253  1.698303  1.826575  0.183682  1.164639
# ACH-000010  0.014253  0.800435  1.615838  1.790175  0.014253  1.401195
# ACH-000012  0.014253  0.028169  1.567126  1.778144  1.138158  1.043790
# ACH-000014  0.014253  0.117186  1.662980  1.695050  0.747177  1.311435
# ACH-000015  0.055041  0.920666  1.726227  1.837345  0.162393  1.431714
#
#              CIAPIN1    SPPL2B   FAM214B     COPZ2   PRKAR2B      MSL3  \
# DepMap_ID
# ACH-000008  1.912663  1.769412  1.680729  1.824813  1.626612  1.676129
# ACH-000010  1.996538  1.901634  1.223934  1.392972  1.532544  1.560070
# ACH-000012  1.999836  1.761594  1.289857  1.146547  0.204172  1.502265
# ACH-000014  1.900049  1.857870  1.701507  2.048409  1.592592  1.661563
# ACH-000015  2.036708  1.913402  0.727737  1.255168  1.468986  1.560964
#
#               CREBBP   TSPOAP1       MPO      PON1     GCFC2     WDR54  \
# DepMap_ID
# ACH-000008  1.486645  0.028169  0.000000  0.068022  1.526683  1.773909
# ACH-000010  1.412860  0.028169  0.183682  0.068022  1.661989  2.113566
# ACH-000012  1.527199  0.336856  0.696738  0.128836  1.399913  1.877856
# ACH-000014  1.600235  0.631115  0.000000  0.014253  1.525908  1.849311
# ACH-000015  1.518015  0.068022  0.028169  0.068022  1.768483  1.924868
#
#                 CROT     ABCB4     KMT2E    RHBDD2      SOX8      IBTK  \
# DepMap_ID
# ACH-000008  1.621888  1.228716  1.775957  1.845445  0.028169  1.578566
# ACH-000010  1.360269  0.028169  1.795554  1.836456  1.103386  1.657978
# ACH-000012  1.438073  0.080717  1.660850  1.773084  0.000000  1.577737
# ACH-000014  1.555549  1.484198  1.837640  1.910424  0.173141  1.618278
# ACH-000015  1.424025  0.128836  1.708909  1.949385  1.035167  1.540464
#
#               ZNF195    MYCBP2     FBXL3     ITGAL      PDK2     ITGA3  \
# DepMap_ID
# ACH-000008  1.578979  1.799565  1.589461  0.162393  1.490869  1.971951
# ACH-000010  1.605068  1.584482  1.118430  0.068022  1.592592  1.012600
# ACH-000012  1.648369  1.713627  1.503689  0.105289  1.453829  2.235604
# ACH-000014  1.683184  1.813347  1.666900  0.000000  1.755183  2.224476
# ACH-000015  1.776201  1.544567  1.024821  0.041760  1.708568  1.366166
#
#                  ZFX     LAMP2    ITGA2B      ASB4      GDE1    REX1BD  \
# DepMap_ID
# ACH-000008  1.535794  2.168870  0.194023  0.028169  1.773662  1.953130
# ACH-000010  1.382205  1.806510  0.670931  1.289857  1.743826  1.730465
# ACH-000012  1.505667  2.003708  0.312890  0.068022  1.801217  1.740446
# ACH-000014  1.536290  2.189988  0.651484  0.128836  1.842937  1.957758
# ACH-000015  1.385843  1.723176  1.293043  1.583472  1.773084  1.865592
#
#                CRLF1    OSBPL7    TMEM98      YBX2    KRT33A   MAP3K14  \
# DepMap_ID
# ACH-000008  1.511233  1.175199  1.846349  0.140248  0.000000  1.252263
# ACH-000010  1.320772  0.422695  1.879320  1.808793  0.000000  1.406676
# ACH-000012  1.255168  1.498235  0.204172  1.602106  0.028169  1.689138
# ACH-000014  1.525390  1.490569  1.506791  0.573235  0.000000  1.336935
# ACH-000015  1.238821  1.464701  1.908158  1.835562  0.000000  1.474481
#
#                ABCC8  CACNG3  TMEM132A     AP2B1      TAC1    ZNF263  \
# DepMap_ID
# ACH-000008  0.055041     0.0  1.871778  1.912663  0.789200  1.660279
# ACH-000010  0.920666     0.0  1.856915  2.025313  0.162393  1.669793
# ACH-000012  0.000000     0.0  1.887147  2.011467  0.000000  1.686878
# ACH-000014  0.000000     0.0  2.036300  1.956370  1.531787  1.814618
# ACH-000015  1.109256     0.0  1.930277  1.978951  0.080717  1.720400
#
#               CX3CL1   SPATA20   CACNA1G  TNFRSF12A      DLX6    MAP3K9  \
# DepMap_ID
# ACH-000008  0.880218  1.738095  0.080717   2.132967  0.960702  1.093767
# ACH-000010  0.000000  1.597209  0.573235   1.823034  1.780228  1.185409
# ACH-000012  0.981714  1.846010  0.014253   2.204083  0.336856  1.589264
# ACH-000014  1.209952  1.863756  0.140248   2.158541  0.962502  0.971364
# ACH-000015  0.080717  1.905577  0.734320   1.793107  1.866957  1.139219
#
#                 RALA  BAIAP2L1     KDM7A      ETV1       AGK   ALDH3B1  \
# DepMap_ID
# ACH-000008  1.809411  1.542404  1.174254  1.662131  2.004661  1.299308
# ACH-000010  1.703616  1.745543  1.160709  1.832311  1.776201  0.367145
# ACH-000012  1.868861  1.714735  1.009475  0.591864  1.825065  1.767890
# ACH-000014  1.810573  1.392532  1.217435  1.671836  1.989265  1.533298
# ACH-000015  1.734416  1.772919  1.162680  1.561187  1.823989  0.707331
#
#                TTC22     PHTF2     CCL26     FARP2     USH1C      GGCT  \
# DepMap_ID
# ACH-000008  0.014253  1.686372  0.882461  1.848477  0.028169  2.087455
# ACH-000010  0.014253  1.631238  0.093136  1.607445  0.454454  2.066972
# ACH-000012  1.050811  1.569718  0.995055  1.690508  0.151432  2.063214
# ACH-000014  0.000000  1.656236  1.251532  1.788195  0.000000  1.992149
# ACH-000015  0.117186  1.542162  0.000000  1.482347  0.747177  2.051967
#
#                 DBF4    TBXA2R     IFRD1  LGALS14     COX10  GTF2IRD1  \
# DepMap_ID
# ACH-000008  1.857287  1.106921  1.856649      0.0  1.586885  1.515325
# ACH-000010  1.879509  0.321004  1.727373      0.0  1.416903  1.545760
# ACH-000012  1.774649  0.252222  1.929783      0.0  1.658844  1.521731
# ACH-000014  1.709363  1.199676  1.801146      0.0  1.523044  1.526167
# ACH-000015  1.822395  0.685871  1.731486      0.0  1.368586  1.557594
#
#                 PAF1     VPS41  ARHGAP44     ELAC2      SCIN      ARSD  \
# DepMap_ID
# ACH-000008  1.963544  1.771340  0.204172  2.004842  0.093136  1.138158
# ACH-000010  1.843224  1.747150  0.714245  1.818252  0.568454  0.454454
# ACH-000012  1.882307  1.751253  0.996687  2.041781  0.558736  1.673052
# ACH-000014  1.957998  1.808862  0.553798  1.959699  0.093136  1.479857
# ACH-000015  1.841786  1.666205  0.631115  1.837699  0.667112  1.584884
#
#               PNPLA4     MYH13   ADIPOR2     CDKL3      UPP2    PRSS21  \
# DepMap_ID
# ACH-000008  1.579597  0.194023  1.906549  0.734320  0.000000  0.080717
# ACH-000010  1.511233  0.000000  1.781737  1.043790  0.000000  0.080717
# ACH-000012  1.774402  0.014253  1.904027  0.710802  0.028169  1.980138
# ACH-000014  1.644095  0.242952  1.907315  0.875693  0.000000  0.041760
# ACH-000015  1.565163  0.000000  1.747809  0.859411  0.000000  0.000000
#
#                MARK4     PROM1   CCDC124  CEACAM21  PAFAH1B1      NOS2  \
# DepMap_ID
# ACH-000008  1.467347  0.573235  2.157290  0.093136  1.981160  0.214133
# ACH-000010  1.567126  0.080717  2.055215  0.367145  1.795922  0.605341
# ACH-000012  1.299926  0.080717  2.216284  0.117186  2.005316  0.000000
# ACH-000014  1.575235  0.448267  2.139842  0.080717  1.943706  0.359742
# ACH-000015  1.499971  0.055041  2.118645  0.028169  1.756266  0.651484
#
#                DNAH9  KIAA0100  SLC13A2  TRAPPC6A      MATK   CEACAM7  \
# DepMap_ID
# ACH-000008  1.668006  1.942593      0.0  1.160709  0.000000  0.014253
# ACH-000010  0.080717  1.872170      0.0  1.741029  1.629597  0.014253
# ACH-000012  0.014253  1.938574      0.0  1.597209  0.296266  0.028169
# ACH-000014  1.750142  1.984163      0.0  1.645631  0.055041  0.000000
# ACH-000015  0.014253  1.952418      0.0  1.836396  1.714403  0.000000
#
#                CD79B      ST7L     TKTL1      PAX6    RPUSD1    RHBDF1  \
# DepMap_ID
# ACH-000008  0.162393  1.581032  0.204172  0.068022  1.772753  1.863858
# ACH-000010  0.304645  1.701153  0.014253  1.418104  1.546235  1.502551
# ACH-000012  0.055041  1.446073  0.000000  0.717660  1.851954  1.568857
# ACH-000014  0.882461  1.570575  0.183682  0.055041  1.767635  2.020993
# ACH-000015  0.128836  1.732501  0.000000  1.718240  1.731180  1.601546
#
#                LUC7L  CACNA2D2    BAIAP3      TSR3      PIGQ    CRAMP1  \
# DepMap_ID
# ACH-000008  1.738390  0.194023  0.374439  1.879556  1.680988  1.313209
# ACH-000010  1.848031  1.163661  1.021806  1.728925  1.619660  1.306042
# ACH-000012  1.741708  0.422695  0.873409  1.940446  1.633676  1.526683
# ACH-000014  1.865998  0.512241  0.647487  1.908037  1.772421  1.420489
# ACH-000015  1.861383  1.381288  0.936446  1.829001  1.766356  1.303612
#
#                TEAD3      SELE   DNAJC11      FMO3     MYLIP      NOX1  \
# DepMap_ID
# ACH-000008  1.305437  0.041760  1.913790  0.055041  1.553946  0.014253
# ACH-000010  1.463033  0.014253  1.930136  0.055041  1.126248  0.014253
# ACH-000012  1.328693  0.014253  1.862779  0.000000  0.912512  0.028169
# ACH-000014  1.472233  0.128836  1.868062  0.068022  1.541920  0.028169
# ACH-000015  1.316725  0.000000  1.924504  0.000000  0.980010  0.014253
#
#                 E2F2     PSMB1      SYN1    JARID2     CDKL5    CAMK1G  \
# DepMap_ID
# ACH-000008  1.171401  2.213237  0.252222  1.566909  0.886906  0.093136
# ACH-000010  1.432847  2.261090  0.242952  1.578772  0.573235  0.000000
# ACH-000012  0.489971  2.183028  0.055041  1.384485  1.003140  0.287750
# ACH-000014  1.017234  2.213787  0.635267  1.703149  0.854627  0.128836
# ACH-000015  1.444637  2.297667  0.328992  1.382205  0.381629  0.000000
#
#               CDK11A      NADK    TFAP2B     DLEC1     CYTH3    ADAM22  \
# DepMap_ID
# ACH-000008  1.914216  1.905007  0.173141  0.117186  1.689388  1.152695
# ACH-000010  1.866301  1.887956  0.533490  0.183682  1.533799  1.267201
# ACH-000012  1.758948  1.826073  0.000000  0.140248  1.775140  0.991767
# ACH-000014  1.950674  1.920707  0.233517  0.183682  1.835024  1.269961
# ACH-000015  1.917207  1.993924  0.582647  0.128836  1.537525  1.198803
#
#                SYPL1    CYB561     SPAG9    CELSR3      AASS   PLEKHG6  \
# DepMap_ID
# ACH-000008  2.033051  1.792435  1.845388  0.971364  1.395161  0.533490
# ACH-000010  1.837404  1.618278  1.782684  1.648066  0.422695  0.028169
# ACH-000012  1.931752  1.836753  1.922376  1.196171  0.587279  1.173306
# ACH-000014  2.028684  1.803705  1.900760  1.322489  1.478917  0.429216
# ACH-000015  1.834545  1.704081  1.801503  1.720615  0.352228  0.573235
#
#               SS18L2      MPND     MGST1      CRY1   PGLYRP1      NFIX  \
# DepMap_ID
# ACH-000008  1.751068  1.509577  1.567777  1.495315  0.093136  1.799709
# ACH-000010  1.705819  1.483583  0.783460  1.684593  0.105289  1.373834
# ACH-000012  1.756805  1.502551  2.270161  1.588474  0.214133  0.951567
# ACH-000014  1.782211  1.569288  1.663262  1.416903  0.055041  1.873147
# ACH-000015  1.788730  1.585486  0.756559  1.633515  0.000000  1.308452
#
#              ST3GAL1     MMP25      IL32      PKD1  MAPK8IP2     MED24  \
# DepMap_ID
# ACH-000008  1.625776  0.252222  1.372413  1.778547  0.947846  1.831580
# ACH-000010  0.261332  0.388716  0.460561  1.855473  1.494137  2.002931
# ACH-000012  1.824180  0.416085  1.788883  1.722432  0.908365  1.946649
# ACH-000014  1.496487  0.861780  1.399056  1.828754  1.036619  1.855633
# ACH-000015  0.055041  0.682185  0.367145  1.811931  1.542645  2.024675
#
#              RHOBTB2   HEATR5B     SEC62     RPS20     CSDE1     UBE3C  \
# DepMap_ID
# ACH-000008  1.413674  1.453482  1.980532  2.410628  2.214959  2.050801
# ACH-000010  1.032243  1.496195  1.814418  2.516133  2.212975  1.689388
# ACH-000012  1.296192  1.470290  1.899167  2.402182  2.208145  1.881146
# ACH-000014  1.438442  1.471910  1.989662  2.429670  2.185632  1.990603
# ACH-000015  1.328134  1.534049  1.890405  2.521224  2.199041  1.744495
#
#                REV3L     TENM1      PAX7     MASP2       IYD    FAM76A  \
# DepMap_ID
# ACH-000008  1.507351  0.068022  0.000000  0.622692  0.014253  1.249329
# ACH-000010  1.476392  0.028169  0.014253  0.839904  0.000000  1.369548
# ACH-000012  1.245619  0.279091  0.014253  0.381629  0.014253  1.052198
# ACH-000014  1.446073  0.448267  0.014253  0.647487  0.014253  1.158724
# ACH-000015  1.461354  0.014253  0.151432  0.864135  0.000000  1.314973
#
#             TRAF3IP3     POMT2      VTA1    MLXIPL     BAZ1B    RANBP9  \
# DepMap_ID
# ACH-000008  0.489971  1.636088  1.828878  0.105289  1.952975  1.755635
# ACH-000010  0.242952  1.631238  1.898322  1.385843  1.878046  1.803281
# ACH-000012  0.233517  1.589855  1.838230  0.328992  1.823926  1.479231
# ACH-000014  0.321004  1.589264  1.807135  0.183682  1.919473  1.777499
# ACH-000015  0.105289  1.775875  1.826887  1.443555  1.860759  1.741127
#
#                 ETV7     SPRTN     DYRK4    ZNF207    UQCRC1  STARD3NL  \
# DepMap_ID
# ACH-000008  0.296266  1.519614  1.639735  2.074720  2.212157  1.920819
# ACH-000010  0.041760  1.442468  1.715617  2.057164  2.169666  1.890891
# ACH-000012  0.312890  1.394725  1.671429  2.054023  2.138018  1.898026
# ACH-000014  0.359742  1.503405  1.727892  2.063964  2.209239  1.893040
# ACH-000015  0.028169  1.492657  1.644403  2.103410  2.160661  1.885062
#
#                  CD9     HHATL    NCAPD2     IFFO1      GIPR      PHF7  \
# DepMap_ID
# ACH-000008  2.167087  0.000000  2.034204  1.808862  0.957076  1.133879
# ACH-000010  1.823034  0.117186  1.993609  0.055041  0.808655  1.469965
# ACH-000012  2.242741  0.000000  2.052706  0.819354  0.304645  1.071031
# ACH-000014  2.237870  0.105289  1.994744  1.804973  1.161696  1.330361
# ACH-000015  1.798479  0.055041  1.939546  0.252222  1.064426  1.477658
#
#               SEMA3G     NISCH     STAB1       FUZ   SLC6A13       IDS  \
# DepMap_ID
# ACH-000008  0.261332  1.669107  0.080717  1.840337  0.740799  1.837640
# ACH-000010  0.553798  1.751622  0.080717  1.757611  0.242952  1.650025
# ACH-000012  0.287750  1.745922  0.028169  0.949711  0.117186  2.027627
# ACH-000014  0.596402  1.794446  0.296266  1.886153  0.501239  1.825318
# ACH-000015  1.043790  1.746962  0.194023  1.710268  0.028169  1.555321
#
#                PRSS3    ZNF200       CD4    LRRC23       BTK       HFE  \
# DepMap_ID
# ACH-000008  1.376654  1.387195  0.321004  1.354239  0.242952  1.730772
# ACH-000010  0.068022  1.313209  0.814041  1.581848  0.233517  1.466688
# ACH-000012  1.757611  1.455559  0.093136  1.328134  0.287750  0.780559
# ACH-000014  1.722538  1.381288  0.478425  1.497654  0.336856  1.802145
# ACH-000015  0.173141  1.291773  0.506772  1.556233  0.381629  1.307249
#
#                SCMH1       FYN    HIVEP2      FMO1      ELOA    LYPLA2  \
# DepMap_ID
# ACH-000008  1.667730  1.895636  1.385843  0.000000  1.933318  2.077998
# ACH-000010  1.760452  1.872366  1.516943  0.000000  1.792509  1.989687
# ACH-000012  1.738784  1.784876  1.475120  0.000000  1.782763  1.948150
# ACH-000014  1.661989  1.958925  1.280082  0.000000  1.841959  2.062492
# ACH-000015  1.786890  1.587880  1.219073  0.014253  1.845218  1.998760
#
#                CLCN6      MRC2    SLC6A7    TSPAN9     BTBD7     APBA3  \
# DepMap_ID
# ACH-000008  1.427898  0.942191  0.028169  1.185409  1.320198  1.638474
# ACH-000010  1.850637  1.890979  0.000000  1.311435  1.263714  1.640990
# ACH-000012  1.288573  1.305437  0.000000  1.553255  1.752633  1.553255
# ACH-000014  1.540708  1.814218  0.014253  1.458644  1.356768  1.675864
# ACH-000015  1.755092  1.727477  0.000000  1.368104  1.412044  1.499682
#
#                 MKS1     ABHD5     ANOS1    AKAP8L     MBTD1     UTP18  \
# DepMap_ID
# ACH-000008  1.490270  1.597399  0.055041  1.854451  1.063090  1.894948
# ACH-000010  1.699377  1.222322  0.014253  1.965076  1.527970  1.931156
# ACH-000012  1.582459  1.685103  1.039506  1.781895  1.356768  1.892691
# ACH-000014  1.555549  1.540951  0.740799  1.884971  1.329806  1.897261
# ACH-000015  1.738587  1.278753  0.140248  1.929959  1.446431  1.985390
#
#               RNF216     TTC19     PTBP1      DPF1      SYT7     LARS2  \
# DepMap_ID
# ACH-000008  1.730976  1.575445  2.218639  1.220702  0.080717  1.508466
# ACH-000010  1.754639  1.569933  2.221987  1.087608  0.940286  1.521994
# ACH-000012  1.611770  1.857658  2.229757  0.906275  1.012600  1.603221
# ACH-000014  1.749864  1.632542  2.153334  1.258045  0.000000  1.521203
# ACH-000015  1.709250  1.573974  2.188209  1.246365  1.098612  1.532544
#
#              PIK3C2A     PLAUR      ANLN       WIZ   RABGAP1       DCN  \
# DepMap_ID
# ACH-000008  1.563846  1.895292  2.047771  1.660565  1.497071  0.028169
# ACH-000010  1.656527  1.130631  1.899293  1.578152  1.578152  2.111428
# ACH-000012  1.580623  1.977783  2.120500  1.556233  1.658411  0.000000
# ACH-000014  1.662697  1.878424  1.939446  1.715727  1.631074  0.703830
# ACH-000015  1.488162  1.081331  1.843910  1.665647  1.511508  1.694076
#
#                QPCTL     PPP5C     CEP68    MAP4K3    ZBTB32    TYROBP  \
# DepMap_ID
# ACH-000008  1.651967  2.036300  1.074931  1.560741  0.117186  0.000000
# ACH-000010  1.628441  1.975258  1.252992  1.520675  0.183682  0.435650
# ACH-000012  1.316142  1.858293  1.272014  1.680208  0.028169  0.000000
# ACH-000014  1.704778  1.957156  1.147580  1.547183  0.374439  0.000000
# ACH-000015  1.507351  1.945265  1.354239  1.512057  0.233517  0.538652
#
#              TMEM159    GABRA3     BRCA1     ERCC1      CD22    SEMA3B  \
# DepMap_ID
# ACH-000008  1.702915  1.163661  1.696382  2.015201  1.677322  2.128326
# ACH-000010  1.475438  0.014253  1.727581  1.949069  0.080717  1.309649
# ACH-000012  1.600985  0.388716  1.701271  1.622399  0.522988  1.368586
# ACH-000014  1.562742  1.446788  1.655213  1.943412  1.701036  2.295474
# ACH-000015  1.348592  0.028169  1.712178  1.846349  0.151432  1.285987
#
#               MBTPS2  PRICKLE3       LTF     EXTL3     NR1H4    ELOVL5  \
# DepMap_ID
# ACH-000008  1.682024  1.509300  0.162393  1.694320  0.591864  1.991390
# ACH-000010  1.547420  1.549068  0.014253  1.518015  0.000000  2.103290
# ACH-000012  1.524610  1.626779  0.000000  1.560518  0.000000  1.958447
# ACH-000014  1.718999  1.519083  0.367145  1.717587  0.893475  1.989762
# ACH-000015  1.435473  1.468332  0.000000  1.464035  0.000000  1.962701
#
#                ALOX5     KDM5D  CALCOCO1      UBR7    MAP4K5      EHD3  \
# DepMap_ID
# ACH-000008  0.068022  0.041760  1.621205  1.730568  1.686245  1.774731
# ACH-000010  0.000000  0.041760  1.714735  1.671564  1.685738  1.103386
# ACH-000012  0.966073  0.055041  1.713849  1.615662  1.840685  0.805934
# ACH-000014  0.093136  0.000000  1.884057  1.705472  1.650175  1.823862
# ACH-000015  0.183682  1.208263  1.694685  1.724338  1.711618  1.116161
#
#                PSMC4    MAN2B2   SLC7A14    CLDN11  SLC25A39       MVP  \
# DepMap_ID
# ACH-000008  2.263352  1.557141  0.014253  0.957076  2.003890  1.854989
# ACH-000010  2.070522  1.185409  0.359742  2.100778  2.108156  1.186320
# ACH-000012  2.044328  1.462027  0.000000  0.460561  2.218912  1.959431
# ACH-000014  2.200944  1.665508  0.014253  1.374306  2.024675  1.979322
# ACH-000015  2.103410  1.256610  0.183682  1.729851  2.206252  1.174254
#
#                 NUB1      PGM3    RWDD2A      CLK1    POLR3B    ANGEL1  \
# DepMap_ID
# ACH-000008  2.035498  1.855794  0.886906  1.800357  1.458644  1.328693
# ACH-000010  1.844651  1.746868  1.229506  1.903493  1.269274  1.523306
# ACH-000012  1.753547  1.677981  0.829766  1.929676  1.454523  1.626946
# ACH-000014  2.009039  1.833099  0.993415  1.764810  1.307851  1.507909
# ACH-000015  1.856222  1.666066  1.157727  1.789340  1.396899  1.711282
#
#                RNF14  DNASE1L1     DDX11     HEBP1    GPRC5A    MAMLD1  \
# DepMap_ID
# ACH-000008  1.867912  1.770755  1.874118  1.730874  1.863756  1.247108
# ACH-000010  1.662556  1.483890  1.781500  1.647460  0.128836  0.573235
# ACH-000012  1.807759  1.664949  1.989538  1.866149  2.152279  1.505386
# ACH-000014  1.873972  1.928112  1.805952  1.695171  1.504256  1.138158
# ACH-000015  1.569933  1.665368  1.845275  1.648218  0.374439  0.422695
#
#                  CD6     TACC3      UFL1     POLA2     ZC3H3     CAPN1  \
# DepMap_ID
# ACH-000008  0.028169  2.003366  1.391208  1.731587  1.361755  1.868961
# ACH-000010  0.014253  1.917928  1.626779  1.714845  1.599105  1.976606
# ACH-000012  0.028169  2.068175  1.489067  1.744113  1.355254  2.011141
# ACH-000014  0.214133  1.905455  1.450685  1.591813  1.398626  1.921414
# ACH-000015  0.068022  1.949100  1.531787  1.807897  1.638790  1.978713
#
#                 MDH1   SLC30A9    MTMR11     COX15   CCDC88C      YAF2  \
# DepMap_ID
# ACH-000008  2.178454  1.789035  1.248591  1.660565  0.442000  1.466358
# ACH-000010  2.174560  1.681507  1.229506  1.850582  1.132800  1.775957
# ACH-000012  2.106092  1.832614  1.291136  1.744495  1.541436  1.480794
# ACH-000014  2.147416  1.840278  1.314386  1.682024  0.162393  1.469313
# ACH-000015  2.173851  1.656090  1.142381  1.815749  1.464701  1.779749
#
#              ZMYND11       WAS     DPEP1       BID     MATR3    NPC1L1  \
# DepMap_ID
# ACH-000008  1.648066  0.448267  0.000000  1.939412  2.051427  0.055041
# ACH-000010  1.776851  0.678467  0.472545  1.661136  2.139154  0.105289
# ACH-000012  1.509022  0.173141  0.055041  1.334761  2.078863  0.055041
# ACH-000014  1.714735  0.270287  0.028169  1.928754  2.034430  0.162393
# ACH-000015  1.758592  0.827189  0.388716  1.706739  2.094149  0.055041
#
#                XYLT2     RGPD5     STMN4    NUDCD3      ISL1      CHDH  \
# DepMap_ID
# ACH-000008  1.618451  1.419299  0.000000  1.934974  0.000000  0.041760
# ACH-000010  1.474161  1.789948  0.028169  1.816807  0.422695  0.663258
# ACH-000012  1.680988  1.510958  0.041760  1.910306  0.093136  1.040940
# ACH-000014  1.750698  1.126248  0.041760  1.998101  0.000000  0.055041
# ACH-000015  1.480482  1.745827  0.000000  1.776282  1.550938  0.707331
#
#               IL20RA     CLCA1     CLCA4    GLT8D1    ATP2C1      IGF1  \
# DepMap_ID
# ACH-000008  0.028169  0.055041  0.000000  1.895292  1.956643  1.042368
# ACH-000010  0.055041  0.000000  0.000000  1.897048  1.711169  0.000000
# ACH-000012  0.014253  0.000000  0.000000  1.715837  1.923003  0.422695
# ACH-000014  0.014253  0.055041  0.000000  2.032004  1.912858  0.140248
# ACH-000015  0.270287  0.000000  0.014253  1.906347  1.838289  0.000000
#
#              SLC38A5    RALBP1     RUFY3     CNTN1   SLC11A1     WWTR1  \
# DepMap_ID
# ACH-000008  0.448267  1.707427  1.543608  0.214133  0.204172  2.124601
# ACH-000010  0.734320  1.622399  1.705703  0.041760  0.548805  1.348592
# ACH-000012  0.533490  1.796876  1.617235  1.105747  0.093136  1.931297
# ACH-000014  0.223913  1.668144  1.566692  0.117186  0.374439  2.128296
# ACH-000015  1.946328  1.779749  1.866705  0.321004  0.435650  1.365680
#
#                 AGPS   CXorf56    ATP1A2     TTC27    ZNF582     VSIG2  \
# DepMap_ID
# ACH-000008  1.869508  1.781183  0.028169  1.568426  0.703830  0.128836
# ACH-000010  1.695777  1.772172  0.041760  1.625944  0.194023  0.173141
# ACH-000012  1.862057  1.867811  0.435650  1.657254  0.886906  0.055041
# ACH-000014  1.749305  1.750883  0.194023  1.500259  0.958894  0.093136
# ACH-000015  1.608353  1.748839  0.000000  1.690135  0.614102  0.296266
#
#               PHLDB1     MARCO   CYP24A1    PRDM11     SYT13     SNAI2  \
# DepMap_ID
# ACH-000008  1.812539  0.000000  0.242952  0.596402  0.151432  1.577322
# ACH-000010  1.494432  0.000000  0.328992  0.768739  0.055041  0.223913
# ACH-000012  1.784331  0.466591  1.390765  0.582647  0.367145  1.587880
# ACH-000014  1.963486  0.000000  0.359742  1.116161  0.233517  1.651520
# ACH-000015  1.631074  0.000000  0.194023  1.082596  0.041760  0.080717
#
#                 CD74       HGF    ZRANB1      NCDN    ADGRA2     ZFP64  \
# DepMap_ID
# ACH-000008  2.254863  0.041760  1.241862  1.905577  0.800435  1.586287
# ACH-000010  0.460561  2.163700  1.518015  1.637999  1.406676  1.587085
# ACH-000012  0.821983  0.849782  1.274729  1.634322  0.080717  1.528226
# ACH-000014  2.249391  0.162393  1.342295  1.885062  1.319622  1.600047
# ACH-000015  0.466591  1.882861  1.438073  1.798552  1.304221  1.790251
#
#                MNAT1    SAMD4A     RUNX3     MRE11   PLEKHB1  SERPINB1  \
# DepMap_ID
# ACH-000008  1.734717  1.546473  1.476392  1.463033  1.811525  1.558047
# ACH-000010  1.862470  0.797656  1.484812  1.527970  1.429813  0.183682
# ACH-000012  1.856222  1.829001  0.080717  1.718022  1.228716  1.802856
# ACH-000014  1.777741  1.556688  1.424804  1.485118  2.061830  1.626445
# ACH-000015  1.949574  1.155724  1.344937  1.664528  1.753729  0.814041
#
#              CYP3A43    SLC7A9     SPAST     NRXN3    OSBPL5       AQR  \
# DepMap_ID
# ACH-000008  0.000000  0.055041  1.360269  1.575863  1.053579  1.404160
# ACH-000010  0.000000  0.194023  1.528738  1.376186  1.346509  1.474481
# ACH-000012  0.000000  0.093136  1.339091  0.014253  1.104568  1.583068
# ACH-000014  0.028169  0.151432  1.416502  1.646548  1.086362  1.445715
# ACH-000015  0.000000  0.173141  1.580418  1.661136  1.329250  1.638315
#
#                 CPS1       C8B      FHL1      RTF2    GABRA1     NLRP2  \
# DepMap_ID
# ACH-000008  1.052198  0.014253  1.495315  2.086395  0.000000  0.553798
# ACH-000010  0.359742  0.000000  1.694442  2.004910  0.140248  1.831092
# ACH-000012  0.374439  0.000000  0.971364  1.971508  0.014253  0.270287
# ACH-000014  1.330361  0.041760  1.704778  2.091374  0.000000  1.519880
# ACH-000015  0.374439  0.000000  1.185409  1.980453  0.028169  1.757701
#
#              SLC45A4     RNF10    ZNF839    ZDHHC6   GRAMD1B      RNH1  \
# DepMap_ID
# ACH-000008  1.386294  1.990133  1.119559  1.776526  0.312890  2.049199
# ACH-000010  1.370506  2.043584  1.605251  1.862263  0.080717  1.970119
# ACH-000012  0.991767  2.041421  1.518549  1.700799  0.093136  1.962963
# ACH-000014  1.395161  1.961295  1.180810  1.691745  0.765728  2.128570
# ACH-000015  1.347553  2.099919  1.820594  1.843682  0.117186  2.024074
#
#               NDUFS1    RB1CC1     ERP44     ALAS1     BIRC3    AKAP11  \
# DepMap_ID
# ACH-000008  2.008708  1.510682  1.633029  1.872170  1.490270  1.513151
# ACH-000010  2.021972  1.641614  1.328693  1.824370  1.117298  1.249329
# ACH-000012  1.931857  1.521994  1.666205  1.832856  1.771340  1.272695
# ACH-000014  1.984931  1.585486  1.674529  1.891332  1.503405  1.616887
# ACH-000015  1.851680  1.699496  1.355759  1.750606  1.288573  1.029293
#
#                GLRX2    SNAPC1      DERA     STRAP     ABCC2      DEF6  \
# DepMap_ID
# ACH-000008  1.909116  1.804832  1.788425  2.155844  1.834845  0.162393
# ACH-000010  1.934424  1.568642  1.765756  2.006328  0.402591  0.270287
# ACH-000012  1.763599  1.656818  2.059843  2.152287  1.569933  1.443555
# ACH-000014  1.827947  1.826825  1.792435  2.110948  1.699377  0.304645
# ACH-000015  1.966935  1.397332  1.779909  2.005834  0.999929  0.367145
#
#              PLEKHO1      GCLM      UBR2      EHD2    DEPDC1   CCDC28A  \
# DepMap_ID
# ACH-000008  1.658267  1.712514  1.423243  1.713183  1.704894  1.436219
# ACH-000010  1.679163  1.441741  1.597209  0.128836  1.676925  1.720400
# ACH-000012  1.204857  1.750791  1.333119  1.853043  1.847640  1.339628
# ACH-000014  1.677322  1.480170  1.466688  1.816609  1.555777  1.574605
# ACH-000015  1.436591  1.403316  1.512605  0.643452  1.592203  1.602664
#
#                RRAGD      HSF2     PHF20   HSD17B6     NR1H3      TYMP  \
# DepMap_ID
# ACH-000008  1.500834  1.440280  1.853152  0.889108  1.169484  1.626445
# ACH-000010  1.630911  1.836158  1.794223  0.568454  1.501121  0.659369
# ACH-000012  0.506772  1.334761  1.820076  0.577966  1.388986  1.349110
# ACH-000014  1.378981  1.532795  1.849311  1.261601  1.361755  1.552100
# ACH-000015  1.518549  1.725495  1.869558  1.035167  1.595872  0.717660
#
#               NCAPH2    TOMM34     SEC63     KPNA6       VIM       FAS  \
# DepMap_ID
# ACH-000008  1.889162  1.944032  1.694198  1.688888  2.498178  1.566038
# ACH-000010  1.839169  1.862986  1.857976  1.692975  2.529173  0.940286
# ACH-000012  1.785808  2.003320  1.727373  1.650924  2.116226  1.396899
# ACH-000014  1.784487  1.942790  1.739763  1.661847  2.461798  1.607081
# ACH-000015  1.871435  1.912311  1.791910  1.591228  2.499414  1.221513
#
#              RNASET2      CD44     KCNG1    AGPAT4    SLAMF7    BTN3A1  \
# DepMap_ID
# ACH-000008  1.617757  2.266754  1.782920  1.162680  1.054954  1.462698
# ACH-000010  1.725390  0.819354  1.094985  1.224736  0.041760  0.014253
# ACH-000012  1.733713  2.285065  0.028169  1.169484  1.959193  1.366652
# ACH-000014  1.720722  2.320171  1.829187  1.269274  0.466591  1.467347
# ACH-000015  1.761331  0.918644  0.916612  0.837395  0.068022  0.635267
#
#                MIPEP     PRKCH     INSRR    IFNGR1   B4GALT7    SH2D2A  \
# DepMap_ID
# ACH-000008  1.676793  1.712514  0.000000  1.613901  1.744400  0.304645
# ACH-000010  1.680468  1.247850  0.014253  1.711057  1.439546  1.011041
# ACH-000012  1.487859  1.553485  0.000000  1.626111  1.756895  0.800435
# ACH-000014  1.612661  1.613371  0.000000  1.672647  1.844764  0.651484
# ACH-000015  1.581441  1.057688  0.014253  1.558498  1.575025  1.483274
#
#                 VRK2  TNFRSF1B      VEZT    POU2F2      BRD9      SNX1  \
# DepMap_ID
# ACH-000008  1.644864  0.460561  1.787428  1.081331  1.889385  1.990553
# ACH-000010  1.699258  0.068022  1.867209  0.448267  1.929959  1.960114
# ACH-000012  1.680078  0.296266  1.895292  0.151432  1.833401  1.794668
# ACH-000014  1.670749  0.344601  1.755092  1.053579  1.881983  1.975339
# ACH-000015  1.744686  0.442000  1.896108  0.214133  2.018851  1.925123
#
#                TBPL1    ARNTL2    BCLAF1   SLC39A9      ANK1      IBSP  \
# DepMap_ID
# ACH-000008  1.778305  0.995055  1.899040  1.786427  0.194023  0.014253
# ACH-000010  1.928469  0.932565  1.883690  1.610517  0.304645  0.000000
# ACH-000012  1.686499  1.919398  1.890759  1.722645  0.140248  0.528269
# ACH-000014  1.701389  1.272014  1.854451  1.850417  0.857026  0.041760
# ACH-000015  1.795185  0.783460  1.860498  1.722538  0.117186  0.000000
#
#                TFB1M     HMGB3    NUP160      BAK1      MUSK     IKZF2  \
# DepMap_ID
# ACH-000008  1.773909  1.936851  1.707427  1.858346  0.000000  0.484233
# ACH-000010  1.750421  2.037835  1.867259  1.755725  1.674529  0.573235
# ACH-000012  1.672782  2.184923  1.693588  1.579802  0.000000  1.112727
# ACH-000014  1.497945  1.837876  1.730261  1.825192  0.080717  0.374439
# ACH-000015  1.749864  2.076985  1.787812  1.767380  0.573235  0.882461
#
#                  GRN    FAM13B  ARHGAP31     CENPQ    RANBP3    ARID4A  \
# DepMap_ID
# ACH-000008  2.063745  1.636727  1.507909  1.581441  1.936783  1.140277
# ACH-000010  2.096886  1.262307  1.219889  1.543608  1.934424  1.345986
# ACH-000012  2.112631  1.549068  0.388716  1.438811  1.826010  1.394725
# ACH-000014  2.198589  1.589855  1.461691  1.541678  1.944390  1.284686
# ACH-000015  2.142207  1.323627  1.068405  1.452786  1.861175  1.344410
#
#                EIPR1     IFT88      ALG1     ABCF2     CHPF2     LRRC7  \
# DepMap_ID
# ACH-000008  1.766270  1.331468  1.714735  2.100974  2.070178  0.252222
# ACH-000010  1.731180  1.488162  1.440646  1.774976  1.459324  0.682185
# ACH-000012  1.827885  1.113876  1.666205  1.926750  1.783235  0.093136
# ACH-000014  1.748465  1.476709  1.766099  2.000116  2.135311  0.639379
# ACH-000015  1.836396  1.382205  1.623248  1.887821  1.663826  0.563621
#
#                 FUT8      UBA6      GAB2  ATP6V0A1     PIAS1    SLC4A7  \
# DepMap_ID
# ACH-000008  1.622399  1.825759  1.468659  1.689013  1.616363  1.746584
# ACH-000010  1.456248  1.662414  1.310245  1.805183  1.741224  1.377587
# ACH-000012  1.883598  1.778386  1.336935  1.710494  1.582052  1.620691
# ACH-000014  1.661705  1.743730  1.327014  1.765241  1.572705  1.632216
# ACH-000015  1.722645  1.454523  1.237288  1.828072  1.583877  1.112727
#
#                APBA2    MAP2K3    EFCAB1    TMSB10     ASTE1    RNF19A  \
# DepMap_ID
# ACH-000008  1.550239  1.978262  0.000000  2.516677  1.274729  1.784331
# ACH-000010  1.411635  1.430955  0.014253  2.438032  0.974848  1.430955
# ACH-000012  1.038066  2.005407  0.478425  2.590128  1.215788  1.454176
# ACH-000014  1.501980  1.937529  0.000000  2.503599  1.267894  1.855687
# ACH-000015  1.362249  1.430955  0.000000  2.420321  1.241862  1.540221
#
#                 PEX3  ...    BORCS8      DPP3  KRTAP5-9      BRK1  UBTFL1  \
# DepMap_ID             ...
# ACH-000008  1.566038  ...  1.850967  1.880493  0.000000  2.082234     0.0
# ACH-000010  1.848087  ...  1.472556  1.843624  0.000000  2.120264     0.0
# ACH-000012  1.702564  ...  1.538263  1.880726  0.270287  2.086503     0.0
# ACH-000014  1.499682  ...  1.842707  1.853749  0.000000  2.136747     0.0
# ACH-000015  1.643632  ...  1.583675  1.934630  0.055041  2.086368     0.0
#
#             PIGY  OR1D4    CHMP1B      EID3  GLYATL1B      HTD2   CCDC166  \
# DepMap_ID
# ACH-000008   0.0    0.0  1.567126  0.582647   0.00000  1.284686  0.000000
# ACH-000010   0.0    0.0  1.760099  0.947846   0.00000  1.098612  0.041760
# ACH-000012   0.0    0.0  1.715507  0.805934   0.04176  1.292408  0.000000
# ACH-000014   0.0    0.0  1.660708  0.448267   0.04176  1.357271  0.000000
# ACH-000015   0.0    0.0  1.723493  1.292408   0.00000  1.192626  0.028169
#
#              NANOGP8    CARD17   PRR23D1  SMIM35     OR8G5      EID1  \
# DepMap_ID
# ACH-000008  0.000000  0.000000  0.014253     0.0  0.912512  2.089090
# ACH-000010  0.105289  0.000000  0.000000     0.0  0.422695  2.118916
# ACH-000012  0.000000  0.000000  0.000000     0.0  0.000000  2.036151
# ACH-000014  0.041760  0.000000  0.055041     0.0  0.849782  2.084376
# ACH-000015  0.041760  0.117186  0.000000     0.0  0.685871  2.074560
#
#               OR52B2      NOX5   CCDC179   PRR23D2  OOSP4B     HCAR3  \
# DepMap_ID
# ACH-000008  0.000000  0.279091  0.000000  0.014253     0.0  0.080717
# ACH-000010  0.000000  0.296266  0.000000  0.000000     0.0  0.000000
# ACH-000012  0.000000  0.553798  0.000000  0.000000     0.0  0.703830
# ACH-000014  0.000000  0.000000  0.055041  0.055041     0.0  0.068022
# ACH-000015  0.028169  0.495638  0.041760  0.000000     0.0  0.000000
#
#                EBLN2    CARD18    NPIPB8    POLR2M   FDXACB1  OR10G2  \
# DepMap_ID
# ACH-000008  0.854627  0.000000  0.204172  1.721365  0.861780     0.0
# ACH-000010  0.538652  0.000000  0.714245  1.674529  0.991767     0.0
# ACH-000012  0.800435  0.014253  0.466591  1.640677  1.059047     0.0
# ACH-000014  0.777637  0.128836  0.321004  1.746962  0.899930     0.0
# ACH-000015  0.737572  0.429216  0.466591  1.570361  1.035167     0.0
#
#                RAB44      TRIL  OR4D2     OR6J1  MTRNR2L8     TIFAB   TAS2R20  \
# DepMap_ID
# ACH-000008  0.000000  0.028169    0.0  0.014253  0.000000  0.000000  0.381629
# ACH-000010  0.028169  0.093136    0.0  0.000000  0.336856  0.000000  0.618418
# ACH-000012  0.068022  0.028169    0.0  0.000000  0.416085  0.014253  0.655445
# ACH-000014  0.014253  0.279091    0.0  0.014253  0.105289  0.000000  0.321004
# ACH-000015  0.014253  0.014253    0.0  0.000000  0.068022  0.000000  0.721046
#
#               CYP2A6      CTSO  MTRNR2L10  TRAPPC2B    DNAAF4     SMLR1  \
# DepMap_ID
# ACH-000008  0.028169  0.484233   0.000000  1.754730  1.057688  0.028169
# ACH-000010  0.000000  0.374439   0.014253  1.485424  1.082596  0.000000
# ACH-000012  0.055041  1.252263   0.000000  1.673052  0.942191  0.028169
# ACH-000014  0.128836  0.995055   0.000000  1.716823  0.827189  0.028169
# ACH-000015  0.080717  0.409385   0.000000  1.566692  0.962502  0.028169
#
#             MTRNR2L3     ZNF10    ZNF486     SMIM3      HMBS   PPIAL4D  \
# DepMap_ID
# ACH-000008  0.055041  1.208263  0.014253  1.368586  1.874505  0.080717
# ACH-000010  0.080717  1.321345  0.614102  1.405840  1.819166  0.000000
# ACH-000012  0.014253  1.416903  1.200545  0.800435  1.907596  0.000000
# ACH-000014  0.151432  1.224736  0.429216  1.356264  1.866251  0.173141
# ACH-000015  0.000000  1.586686  0.953413  1.379444  1.973763  0.080717
#
#                ASIC5      DND1     SALL3     POLG2  SMIM10L1    OR13A1  \
# DepMap_ID
# ACH-000008  0.000000  0.252222  0.000000  1.620004  1.480482  0.028169
# ACH-000010  0.000000  0.151432  0.105289  1.751622  1.304830  0.128836
# ACH-000012  0.000000  0.344601  0.000000  1.701742  1.586287  0.000000
# ACH-000014  0.014253  0.261332  0.000000  1.689388  1.436591  0.000000
# ACH-000015  0.014253  0.261332  0.321004  1.787966  1.504821  0.000000
#
#             MTRNR2L1   CLEC12B     LIMS4    ZNF350      PGA5       STH  \
# DepMap_ID
# ...
# ACH-000008  1.868362    0.0  0.924676  0.151432  0.151432  2.035274  0.000000
# ACH-000010  1.836158    0.0  0.460561  0.819354  0.682185  1.893345  0.014253
# ACH-000012  1.702564    0.0  2.179943  0.041760  0.128836  1.278753  0.223913
# ACH-000014  1.889029    0.0  1.274729  0.214133  0.442000  2.042569  0.000000
# ACH-000015  1.836634    0.0  1.770420  0.805934  0.093136  1.667868  0.028169
#
#             KRTAP10-7     DCP1A  ATP6V1FNB  OR5AL1   C2orf15    GRIN2B  \
# DepMap_ID
# ACH-000008    0.00000  1.374306   0.374439     0.0  0.312890  0.932565
# ACH-000010    0.04176  1.358774   0.501239     0.0  0.877962  0.000000
# ACH-000012    0.00000  1.416100   0.336856     0.0  1.006322  0.000000
# ACH-000014    0.00000  1.520675   0.495638     0.0  0.631115  0.296266
# ACH-000015    0.00000  1.204857   0.478425     0.0  1.203140  0.000000
#
#              OR52E1  LYPD4    NBPF26     SNURF    ZBTB8B   TBC1D3K   FOXD4L6  \
# DepMap_ID
# ACH-000008  0.04176    0.0  1.616712  1.737701  0.041760  0.252222  0.068022
# ACH-000010  0.04176    0.0  1.536290  0.000000  0.409385  0.128836  0.000000
# ACH-000012  0.00000    0.0  1.648822  0.352228  0.105289  0.028169  0.080717
# ACH-000014  0.00000    0.0  1.463702  1.817925  0.128836  0.279091  0.080717
# ACH-000015  0.00000    0.0  1.586885  0.117186  0.522988  0.117186  0.000000
#
#                AGBL1     CWC25   SMIM11B      EPOP    ZNHIT3    CT45A7  \
# DepMap_ID
# ACH-000008  0.014253  1.655213  1.710155  1.203140  1.864727  0.000000
# ACH-000010  0.093136  1.699258  1.729542  1.583877  1.926173  0.055041
# ACH-000012  0.000000  1.761243  1.244122  1.307249  1.785343  0.000000
# ACH-000014  0.000000  1.667730  1.641926  1.488766  1.846911  0.000000
# ACH-000015  0.014253  1.712848  1.818187  1.824623  2.005699  0.140248
#
#                 LHX1    CYFIP1  CEACAM20    USP27X      TAF9     NOL12  \
# DepMap_ID
# ACH-000008  0.618418  1.841208  0.000000  1.065758  1.999556  1.868861
# ACH-000010  0.693147  1.861746  0.000000  1.160709  1.966079  1.737503
# ACH-000012  0.344601  1.857128  0.055041  0.707331  2.062020  1.707083
# ACH-000014  1.174254  1.839403  0.000000  1.130631  1.965507  1.760363
# ACH-000015  0.374439  1.746773  0.000000  1.076221  1.997132  1.810709
#
#             GOLGA6L1   CASTOR2     OR4M2     NATD1    ANTXRL     SOCS7  \
# DepMap_ID
# ACH-000008       0.0  0.902057  0.000000  0.827189  0.014253  1.572068
# ACH-000010       0.0  0.768739  0.000000  1.033708  0.000000  1.453134
# ACH-000012       0.0  0.768739  0.000000  0.635267  0.014253  1.370984
# ACH-000014       0.0  1.046616  0.055041  1.216613  0.117186  1.693832
# ACH-000015       0.0  1.038066  0.055041  0.974848  0.014253  1.525130
#
#              TBC1D3H    GGTLC3    GAGE13      CBSL    ADRA2B    ZNF658  \
# DepMap_ID
# ACH-000008  0.000000  0.000000  2.035087  0.321004  0.014253  0.839904
# ACH-000010  0.000000  0.000000  0.000000  2.043780  0.055041  0.904172
# ACH-000012  1.329806  0.028169  0.000000  1.753090  0.028169  0.591864
# ACH-000014  0.000000  0.000000  2.105761  0.151432  0.068022  0.951567
# ACH-000015  0.000000  0.000000  0.000000  1.807274  0.093136  0.786340
#
#              TMEM269      TPTE   TBC1D3D   C8orf89   TBC1D3L     RCC1L  \
# DepMap_ID
# ACH-000008  0.055041  1.241862  0.128836  0.000000  1.018765  2.030372
# ACH-000010  0.478425  0.000000  1.157727  0.000000  0.000000  1.929818
# ACH-000012  0.478425  0.000000  0.128836  0.080717  1.491765  1.882538
# ACH-000014  0.080717  1.259472  0.000000  0.000000  1.202278  2.018102
# ACH-000015  0.395702  0.000000  1.327575  0.000000  0.000000  2.030179
#
#                SEBOX      DGKK   RIMBP3B    TBC1D3  CCL23     ELOA3  KRTAP7-1  \
# DepMap_ID
# ACH-000008  0.000000  0.014253  0.128836  0.000000    0.0  0.041760  0.533490
# ACH-000010  0.000000  0.000000  0.041760  1.322489    0.0  0.261332  0.000000
# ACH-000012  0.000000  0.000000  0.014253  0.000000    0.0  0.000000  0.000000
# ACH-000014  0.068022  0.014253  0.270287  0.000000    0.0  0.028169  0.762695
# ACH-000015  0.117186  0.028169  0.312890  1.401195    0.0  0.223913  0.000000
#
#             PRAMEF27  F8A2   TBC1D3B     PANO1   TBC1D3I   ZNF280B     MLLT6  \
# DepMap_ID
# ACH-000008       0.0   0.0  0.710802  0.614102  0.173141  0.783460  1.676528
# ACH-000010       0.0   0.0  0.553798  0.904172  0.460561  1.007902  1.850582
# ACH-000012       0.0   0.0  1.188135  0.204172  0.093136  0.891298  1.871975
# ACH-000014       0.0   0.0  0.955249  0.635267  0.296266  0.958894  1.810437
# ACH-000015       0.0   0.0  0.985097  0.976577  0.528269  0.889108  1.928825
#
#             TP53TG3E   PPP4R3B     SYNRG    NUDT18      ZNF2    GAGE2E  CCL16  \
# DepMap_ID
# ACH-000008       0.0  1.730465  1.608715  1.082596  1.053579  2.203072    0.0
# ACH-000010       0.0  1.779749  1.593368  1.086362  1.208263  0.000000    0.0
# ACH-000012       0.0  1.754185  1.676925  1.298687  1.063090  0.223913    0.0
# ACH-000014       0.0  1.712848  1.650325  1.255168  1.131717  2.158120    0.0
# ACH-000015       0.0  1.777741  1.602664  0.932565  1.215788  0.000000    0.0
#
#                LENG9      CCL4     PRAG1   C7orf77     CCL18     FCGBP  \
# DepMap_ID
# ACH-000008  1.030771  0.041760  1.306646  0.000000  0.689525  0.304645
# ACH-000010  0.352228  0.000000  0.214133  0.000000  0.000000  0.287750
# ACH-000012  0.721046  0.068022  1.509577  0.000000  0.000000  0.381629
# ACH-000014  1.435100  0.080717  1.297443  0.080717  0.882461  0.270287
# ACH-000015  1.060400  0.014253  0.140248  0.000000  0.000000  0.304645
#
#                HNF1B  C17orf98  FAM236A    ELOA3C    GRIFIN      XKR5  \
# DepMap_ID
# ACH-000008  0.055041       0.0      0.0  0.117186  0.000000  0.000000
# ACH-000010  0.028169       0.0      0.0  0.000000  0.000000  0.140248
# ACH-000012  1.705241       0.0      0.0  0.000000  0.105289  0.068022
# ACH-000014  0.014253       0.0      0.0  0.000000  0.000000  0.041760
# ACH-000015  0.028169       0.0      0.0  0.000000  0.068022  0.242952
#
#                 AATF     CCL15  LYZL6  HNRNPCL2    RIMBP3  ARHGAP23   TUBGCP5  \
# DepMap_ID
# ACH-000008  2.008111  0.055041    0.0  0.000000  0.279091  1.449981  1.377121
# ACH-000010  1.869855  0.000000    0.0  0.055041  0.287750  1.257328  1.422459
# ACH-000012  2.074050  0.000000    0.0  0.055041  0.041760  1.514784  1.525130
# ACH-000014  1.957487  0.000000    0.0  0.000000  0.409385  1.653596  1.378517
# ACH-000015  1.958925  0.000000    0.0  0.105289  0.460561  1.260893  1.459664
#
#              U2AF1L5     PRSS2   TBC1D3F  SPATA31A3     SIK1B    DUSP14  \
# DepMap_ID
# ACH-000008  2.092088  0.173141  0.448267   0.014253  1.104568  1.834365
# ACH-000010  2.171770  0.151432  0.000000   0.173141  0.877962  1.604884
# ACH-000012  2.081248  0.000000  0.000000   0.000000  1.489970  1.962788
# ACH-000014  2.062885  0.000000  0.643452   0.000000  1.129541  1.869259
# ACH-000015  2.217201  0.000000  0.000000   0.000000  1.038066  1.711169
#
#             SPATA31A7     UHRF1     ORAI1  CCL4L2    CRYAA2    CCL3L3  OR13C2  \
# DepMap_ID
# ACH-000008        0.0  1.846855  1.837640     0.0  0.055041  0.080717     0.0
# ACH-000010        0.0  1.814752  1.486035     0.0  0.028169  0.068022     0.0
# ACH-000012        0.0  1.874650  1.585486     0.0  0.000000  0.068022     0.0
# ACH-000014        0.0  1.814284  1.834725     0.0  0.000000  0.000000     0.0
# ACH-000015        0.0  1.840045  1.638790     0.0  0.080717  0.028169     0.0
#
#               PIK3R6    TADA2A  OR4E1    KCNE1B   PIP4K2B    UBE2NL  CCL14  \
# DepMap_ID
# ACH-000008  0.105289  1.392091    0.0  0.409385  1.740932  0.055041    0.0
# ACH-000010  0.000000  1.593755    0.0  0.000000  1.824939  0.080717    0.0
# ACH-000012  0.014253  1.706394    0.0  0.000000  1.657399  0.080717    0.0
# ACH-000014  0.080717  1.413674    0.0  0.409385  1.805743  0.105289    0.0
# ACH-000015  0.000000  1.707083    0.0  0.000000  1.883092  0.000000    0.0
#
#               FAM25C  SPATA31A5     RAB7B     DACH1     PADI6     GSTT4  \
# DepMap_ID
# ACH-000008  0.000000   0.014253  1.640520  0.093136  0.000000  0.140248
# ACH-000010  0.000000   0.000000  0.128836  1.535048  0.000000  0.000000
# ACH-000012  1.465033   0.000000  0.914567  0.068022  0.000000  0.000000
# ACH-000014  0.000000   0.000000  1.586487  0.105289  0.014253  0.055041
# ACH-000015  0.000000   0.000000  0.756559  1.531535  0.000000  0.000000
#
#             HNRNPCL3     TYW1B      F8A3      PIGW      F8A1   FAM243B  \
# DepMap_ID
# ACH-000008  0.000000  1.255168  0.765728  1.684593  1.785886  0.233517
# ACH-000010  0.028169  1.053579  1.633676  1.532795  1.603036  0.533490
# ACH-000012  0.000000  0.639379  0.960702  1.682541  1.901260  0.242952
# ACH-000014  0.000000  1.260184  0.643452  1.726227  1.760540  0.374439
# ACH-000015  0.000000  1.149636  1.695777  1.665368  1.667868  0.344601
#
#             GOLGA6L6    SRCIN1    GPR179    MARCKS    ZNF670    PKD1L3  \
# DepMap_ID
# ACH-000008  0.000000  1.436591  0.041760  1.422066  0.777637  0.000000
# ACH-000010  0.000000  1.303612  0.028169  1.842822  1.269961  0.000000
# ACH-000012  0.000000  0.955249  0.028169  1.820076  1.126248  0.014253
# ACH-000014  0.014253  1.599482  0.080717  1.751990  0.897791  0.000000
# ACH-000015  0.000000  1.536042  0.117186  1.581848  1.169484  0.000000
#
#              GPIHBP1    PNMA8C  OR13C5      NEFL      CCL3     PSMB3  \
# DepMap_ID
# ACH-000008  0.028169  0.014253     0.0  1.891244  0.501239  2.253096
# ACH-000010  0.416085  0.055041     0.0  0.651484  0.173141  2.239246
# ACH-000012  0.014253  0.000000     0.0  0.055041  0.223913  2.276125
# ACH-000014  0.028169  0.080717     0.0  1.874939  0.429216  2.231418
# ACH-000015  0.670931  0.028169     0.0  0.622692  0.000000  2.287389
#
#             GOLGA6L22    SRD5A2    OR52E5     CISD3      RDM1     DDX52  \
# DepMap_ID
# ACH-000008        0.0  0.388716  0.093136  1.787659  0.873409  1.577737
# ACH-000010        0.0  0.000000  0.000000  1.604699  1.488766  1.679555
# ACH-000012        0.0  0.000000  0.000000  1.870350  1.092545  1.760363
# ACH-000014        0.0  0.028169  0.028169  1.794816  0.852212  1.583472
# ACH-000015        0.0  0.000000  0.000000  1.874408  1.641458  1.730465
#
#             TEX28    CT45A8      ZNF8     SSTR3  PRICKLE4     MYO19  CT45A6  \
# DepMap_ID
# ACH-000008    0.0  0.028169  0.808655  0.041760  0.587279  1.938305     0.0
# ACH-000010    0.0  0.000000  1.074931  0.028169  1.043790  1.917473     0.0
# ACH-000012    0.0  0.000000  0.891298  0.068022  0.252222  1.909116     0.0
# ACH-000014    0.0  0.128836  0.945971  0.000000  0.682185  1.874698     0.0
# ACH-000015    0.0  0.000000  0.897791  0.000000  0.882461  1.957908     0.0
#
#              TBC1D3C    GGNBP2  C17orf78    POTEB3    DHRS11     ACACA  \
# DepMap_ID
# ACH-000008  0.678467  1.889385  0.014253  0.000000  1.668970  1.747245
# ACH-000010  0.261332  1.914487  0.068022  0.000000  1.577530  1.983469
# ACH-000012  0.000000  1.806092  0.055041  0.000000  1.339091  1.960941
# ACH-000014  1.132800  1.903411  0.041760  0.000000  1.595872  1.809959
# ACH-000015  0.600894  1.894083  0.068022  0.028169  1.648822  1.955520
#
#                NR2E3   TBC1D3E  C11orf98      MRM1  GOLGA6L10    ELOA3B  \
# DepMap_ID
# ACH-000008  0.041760  0.000000  2.076526  1.614078   0.374439  0.000000
# ACH-000010  0.151432  0.000000  2.125774  1.225536   1.142381  0.000000
# ACH-000012  0.194023  0.028169  2.127634  1.376654   0.882461  0.014253
# ACH-000014  0.028169  0.000000  2.092283  1.507630   0.517645  0.000000
# ACH-000015  0.261332  0.093136  2.193833  1.688763   0.895639  0.204172
#
#               IQCA1L    MRPL45  TP53TG3F  OR51G1     OR2S2   SMIM34B  OR10A6  \
# DepMap_ID
# ACH-000008  0.055041  1.834064  0.533490     0.0  0.000000  0.093136     0.0
# ACH-000010  0.068022  1.949637  1.090086     0.0  0.000000  0.093136     0.0
# ACH-000012  0.014253  1.931472  0.000000     0.0  0.028169  0.014253     0.0
# ACH-000014  0.014253  1.852445  0.484233     0.0  0.000000  0.105289     0.0
# ACH-000015  0.117186  1.939880  1.064426     0.0  0.000000  0.140248     0.0
#
#              OR51B2  OR6Q1  OR10X1     OR8D2     TSTD3    OR2L8    OR52R1  \
# DepMap_ID
# ACH-000008  0.00000    0.0     0.0  0.140248  0.916612  0.04176  0.000000
# ACH-000010  0.00000    0.0     0.0  0.068022  1.252992  0.00000  0.000000
# ACH-000012  0.00000    0.0     0.0  0.000000  0.635267  0.00000  0.028169
# ACH-000014  0.04176    0.0     0.0  0.028169  0.808655  0.00000  0.000000
# ACH-000015  0.00000    0.0     0.0  0.000000  1.161696  0.00000  0.000000
#
#               OR2T11  OR5L1    OR2AG1  OR4C16  OR5D13   PPIAL4F  PRAMEF18  \
# DepMap_ID
# ACH-000008  0.000000    0.0  0.000000     0.0     0.0  0.162393  0.000000
# ACH-000010  0.000000    0.0  0.028169     0.0     0.0  0.000000  0.014253
# ACH-000012  0.000000    0.0  0.014253     0.0     0.0  0.000000  0.000000
# ACH-000014  0.000000    0.0  0.028169     0.0     0.0  0.000000  0.000000
# ACH-000015  0.028169    0.0  0.000000     0.0     0.0  0.080717  0.000000
#
#             OR5R1  OR51F1    GATD3B  OR8B4  OR1B1    PCDH20  OR1S1    OR12D2  \
# DepMap_ID
# ACH-000008    0.0     0.0  1.990750    0.0    0.0  0.252222    0.0  0.000000
# ACH-000010    0.0     0.0  2.021136    0.0    0.0  0.028169    0.0  0.028169
# ACH-000012    0.0     0.0  1.873001    0.0    0.0  0.014253    0.0  0.000000
# ACH-000014    0.0     0.0  2.049747    0.0    0.0  0.908365    0.0  0.000000
# ACH-000015    0.0     0.0  2.106775    0.0    0.0  0.055041    0.0  0.000000
#
#             PRAMEF26     OR8K3   CCDC163     PAGR1  RPS4Y2   TMEM272
# DepMap_ID
# ACH-000008       0.0  0.000000  0.194023  1.756446     0.0  0.395702
# ACH-000010       0.0  0.000000  1.251532  1.799420     0.0  0.014253
# ACH-000012       0.0  0.000000  0.934511  1.614784     0.0  0.014253
# ACH-000014       0.0  0.014253  1.060400  1.741417     0.0  0.344601
# ACH-000015       0.0  0.000000  1.305437  1.871090     0.0  0.080717
#
# [5 rows x 18382 columns]

# %%
ccle_scaler = StandardScaler()
ccle_dataset.data = pd.DataFrame(ccle_scaler.fit_transform(ccle_dataset.data),
                                  index=ccle_dataset.data.index,
                                  columns=ccle_dataset.data.columns)

# %%
ccle_loader = torch.utils.data.DataLoader(ccle_dataset, batch_size=batch_size, shuffle=False, **kwargs)

# %%
ccle_embeddings_baseline, ccle_labels_baseline = vis.extract_embeddings(ccle_loader, model)

# %%
vis.sns_plot_embeddings(ccle_embeddings_baseline, ccle_dataset, hue="disease", style="primary_or_metastasis")
