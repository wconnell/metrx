# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("..")

import datetime
import pathlib

from collections import OrderedDict 

import numpy as np
import pandas as pd

# %%
# Pytorch
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable

# Custom
from dutils import Experiment
from trainer import fit
import visualization as vis
from tcga_datasets import SiameseDataset

# Models
from tcga_networks import EmbeddingNet, SiameseNet
from losses import ContrastiveLoss

# Metrics
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score as ANMI

# %%
def getTCGA(disease):
    path = "/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP/TCGA/TCGA_{}_counts.tsv.gz"
    files = [path.format(d) for d in disease]
    return files


def readGCP(files, biotype='protein_coding', mean=True):
    """
    Paths to count matrices.
    """
    data_dict = {}
    for f in files:
        key = os.path.basename(f).split("_")[1]
        data = pd.read_csv(f, sep='\t', index_col=0)
        # transcript metadata
        meta = pd.DataFrame([row[:-1] for row in data.index.str.split("|")],
                            columns=['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'GENE', 'BP', 'BIOTYPE'])
        meta = pd.MultiIndex.from_frame(meta)
        data.index = meta
        # subset transcripts
        data = data.xs(key=biotype, level='BIOTYPE')
        data = data.droplevel(['ENST', 'ENSG', 'OTTHUMG', 'OTTHUMT', 'GENE-NUM', 'BP'])
        # average gene expression of splice variants
        data = data.T
        if mean:
            data = data.groupby(by=data.columns, axis=1).mean()
        data_dict[key] = data
    return data_dict


def uq_norm(df, q=0.75):
    """
    Upper quartile normalization of GEX for samples.
    """
    quantiles = df.quantile(q=q, axis=1)
    norm = df.divide(quantiles, axis=0)
    return norm


def process_TCGA(disease=['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']):
    base="/srv/nas/mk2/projects/pan-cancer/TCGA_CCLE_GCP"
    # get files
    tcga_files = getTCGA(disease)
    # read meta/data
    tcga_meta = pd.read_csv(os.path.join(base, "TCGA/TCGA_GDC_ID_MAP.tsv"), sep="\t")
    tcga_raw = readGCP(tcga_files, mean=True)
    # combine samples
    tcga_raw = pd.concat(tcga_raw.values())
    # Upper quartile normalization
    tcga_raw = uq_norm(tcga_raw)
    # log norm
    tcga = tcga_raw.transform(np.log1p)
    return tcga, tcga_meta

# %%
def generate_fsets(data, n_features, steps=5):
    r = np.linspace(start=1, stop=n_features, num=steps, dtype='int')
    idx = [np.random.choice(data.shape[1], size=i, replace=False) for i in r]
    return idx

# %%
def feature_training(train_data, train_labels, test_data, test_labels, feature_idx, embedding, exp_dir, cuda=True):
    # Meta data
    meta_data = {"n_features":[],
                 "model":[],
                 "ANMI":[]}
    # Params
    batch_size = 8
    kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {'num_workers': 10}
    
    # Feature Index
    for batch, feat in enumerate(feature_idx):
        print("Number features: {}\n".format(len(feat)))
        exp_data = {'feature_idx':feat}
        # Define data
        siamese_train_dataset = SiameseDataset(data=train_data.iloc[:,feat],
                                           labels=train_labels,
                                           train=True)
        siamese_test_dataset = SiameseDataset(data=test_data.iloc[:,feat],
                                          labels=test_labels,
                                          train=False)
        # Loaders
        siamese_train_loader = torch.utils.data.DataLoader(siamese_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
        siamese_test_loader = torch.utils.data.DataLoader(siamese_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)
        # Instantiate model
        n_samples, n_features = siamese_train_dataset.train_data.shape
        for i in range(3):
            nmodel = 'model_{}'.format(i)
            print("\t{}".format(nmodel))
            embedding_net = EmbeddingNet(n_features, embedding)
            model = SiameseNet(embedding_net)
            if cuda:
                model.cuda()
            # Parameters
            margin = 1.
            loss_fn = ContrastiveLoss(margin)
            lr = 1e-3
            optimizer = optim.Adam(model.parameters(), lr=lr)
            scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
            n_epochs = 10
            log_interval = round(len(siamese_train_dataset)/1/batch_size)
            # Train
            train_loss, val_loss = fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, 
                                       n_epochs, cuda, log_interval)
            # Test Embeddings
            val_embeddings_baseline, val_labels_baseline = vis.extract_embeddings(siamese_test_dataset.test_data, siamese_test_dataset.labels, model)
            # Evaluation
            n_clusters = len(np.unique(test_labels))
            kmeans = KMeans(n_clusters=n_clusters)
            siamese_clusters = kmeans.fit_predict(val_embeddings_baseline)
            anmi = ANMI(siamese_clusters, val_labels_baseline)
            # Store
            meta_data['n_features'].append(len(feat))
            meta_data['model'].append(nmodel)
            meta_data['ANMI'].append(anmi)
            exp_data[nmodel] = {'data': (val_embeddings_baseline, val_labels_baseline),
                                'loss': (train_loss, val_loss),
                                'ANMI': anmi}
        pd.to_pickle(exp_data, os.path.join(exp_dir, "model_{}.pkl".format(len(feat))))
    pd.to_pickle(meta_data, os.path.join(exp_dir, "model_meta_data.pkl"))

# %%
def main(disease, sample_type, **kwargs):
    # GPUs
    os.environ["CUDA_VISIBLE_DEVICES"] = kwargs['device']
    cuda = torch.cuda.is_available()
    print("Cuda is available: {}".format(cuda))
    
    # Read / write / process
    tcga, tcga_meta = process_TCGA(disease)
    # Feature design
    feature_idx = generate_fsets(tcga, n_features=kwargs['n_features'], steps=kwargs['steps'])
    # Experiment design
    hierarchy = OrderedDict({'Disease':disease,
                             'Sample Type':sample_type})
    # Define experiment
    exp = Experiment(meta_data=tcga_meta,
                     hierarchy=hierarchy,
                     index='CGHubAnalysisID',
                     cases='Case ID',
                     min_samples=20)
    # Train / Test split
    exp.train_test_split(cases='Case ID')
    # Return data 
    train_data, train_labels = exp.get_data(tcga, subset="train", dtype=np.float32)
    test_data, test_labels = exp.get_data(tcga, subset="test", dtype=np.float32)
    
    # randomize labels
    np.random.shuffle(train_labels)
    
    # Path *fix*
    dtime = datetime.datetime.today().strftime("%Y.%m.%d_%H:%M")
    exp_dir = "/srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/{}_shuffle_{}_{}_{}-{}".format(dtime, 
                                                                                len(exp.labels_dict),
                                                                                kwargs['embedding'],
                                                                                kwargs['n_features'], 
                                                                                kwargs['steps'])
    pathlib.Path(exp_dir).mkdir(parents=True, exist_ok=False)
    print('Saving to: \n{}'.format(exp_dir))
    
    # Meta data
    experiments = {'experiment': exp,
                   'train':(train_data, train_labels),
                   'test': (test_data, test_labels)}
    pd.to_pickle(experiments, os.path.join(exp_dir, "experiment_meta_data.pkl"))
    
    # Training
    feature_training(train_data, train_labels, test_data, test_labels, feature_idx, kwargs['embedding'], exp_dir)

# %% [markdown]
# ### Setup

# %%
disease = ['BRCA', 'LUAD', 'KIRC', 'THCA', 'PRAD', 'SKCM']
sample_type = ['Primary Tumor', 'Solid Tissue Normal']
params = {"device":"4",
          "n_features":2000,
          "steps":100,
          "embedding":2}

# %%
main(disease=disease, sample_type=sample_type, **params)
# Out:
# Cuda is available: True
# Saving to:
# /srv/nas/mk2/projects/pan-cancer/experiments/feature_sel/2020.03.27_18:57_shuffle_11_2_2000-100
# Number features: 1
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187198
# Train: [1098/2931 (100%)]	Loss: 0.178199
# Epoch: 1/10. Train set: Average loss: 0.1782
# Epoch: 1/10. Validation set: Average loss: 0.1560
# Train: [0/2931 (0%)]	Loss: 0.165139
# Train: [1098/2931 (100%)]	Loss: 0.176239
# Epoch: 2/10. Train set: Average loss: 0.1762
# Epoch: 2/10. Validation set: Average loss: 0.1452
# Train: [0/2931 (0%)]	Loss: 0.183051
# Train: [1098/2931 (100%)]	Loss: 0.175056
# Epoch: 3/10. Train set: Average loss: 0.1751
# Epoch: 3/10. Validation set: Average loss: 0.1372
# Train: [0/2931 (0%)]	Loss: 0.206648
# Train: [1098/2931 (100%)]	Loss: 0.174462
# Epoch: 4/10. Train set: Average loss: 0.1746
# Epoch: 4/10. Validation set: Average loss: 0.1371
# Train: [0/2931 (0%)]	Loss: 0.113080
# Train: [1098/2931 (100%)]	Loss: 0.174879
# Epoch: 5/10. Train set: Average loss: 0.1747
# Epoch: 5/10. Validation set: Average loss: 0.2002
# Train: [0/2931 (0%)]	Loss: 0.165194
# Train: [1098/2931 (100%)]	Loss: 0.173207
# Epoch: 6/10. Train set: Average loss: 0.1732
# Epoch: 6/10. Validation set: Average loss: 0.1983
# Train: [0/2931 (0%)]	Loss: 0.163892
# Train: [1098/2931 (100%)]	Loss: 0.172574
# Epoch: 7/10. Train set: Average loss: 0.1726
# Epoch: 7/10. Validation set: Average loss: 0.1514
# Train: [0/2931 (0%)]	Loss: 0.182235
# Train: [1098/2931 (100%)]	Loss: 0.170531
# Epoch: 8/10. Train set: Average loss: 0.1706
# Epoch: 8/10. Validation set: Average loss: 0.1462
# Train: [0/2931 (0%)]	Loss: 0.266203
# Train: [1098/2931 (100%)]	Loss: 0.156582
# Epoch: 9/10. Train set: Average loss: 0.1569
# Epoch: 9/10. Validation set: Average loss: 0.1392
# Train: [0/2931 (0%)]	Loss: 0.127895
# Train: [1098/2931 (100%)]	Loss: 0.158044
# Epoch: 10/10. Train set: Average loss: 0.1580
# Epoch: 10/10. Validation set: Average loss: 0.1321
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249143
# Train: [1098/2931 (100%)]	Loss: 0.183761
# Epoch: 1/10. Train set: Average loss: 0.1839
# Epoch: 1/10. Validation set: Average loss: 0.1419
# Train: [0/2931 (0%)]	Loss: 0.282048
# Train: [1098/2931 (100%)]	Loss: 0.171619
# Epoch: 2/10. Train set: Average loss: 0.1719
# Epoch: 2/10. Validation set: Average loss: 0.1806
# Train: [0/2931 (0%)]	Loss: 0.178359
# Train: [1098/2931 (100%)]	Loss: 0.173775
# Epoch: 3/10. Train set: Average loss: 0.1738
# Epoch: 3/10. Validation set: Average loss: 0.1462
# Train: [0/2931 (0%)]	Loss: 0.104767
# Train: [1098/2931 (100%)]	Loss: 0.174127
# Epoch: 4/10. Train set: Average loss: 0.1739
# Epoch: 4/10. Validation set: Average loss: 0.1895
# Train: [0/2931 (0%)]	Loss: 0.190845
# Train: [1098/2931 (100%)]	Loss: 0.168270
# Epoch: 5/10. Train set: Average loss: 0.1683
# Epoch: 5/10. Validation set: Average loss: 0.1374
# Train: [0/2931 (0%)]	Loss: 0.076063
# Train: [1098/2931 (100%)]	Loss: 0.174195
# Epoch: 6/10. Train set: Average loss: 0.1739
# Epoch: 6/10. Validation set: Average loss: 0.1497
# Train: [0/2931 (0%)]	Loss: 0.256962
# Train: [1098/2931 (100%)]	Loss: 0.175386
# Epoch: 7/10. Train set: Average loss: 0.1756
# Epoch: 7/10. Validation set: Average loss: 0.1360
# Train: [0/2931 (0%)]	Loss: 0.166923
# Train: [1098/2931 (100%)]	Loss: 0.169652
# Epoch: 8/10. Train set: Average loss: 0.1696
# Epoch: 8/10. Validation set: Average loss: 0.1615
# Train: [0/2931 (0%)]	Loss: 0.309211
# Train: [1098/2931 (100%)]	Loss: 0.171717
# Epoch: 9/10. Train set: Average loss: 0.1721
# Epoch: 9/10. Validation set: Average loss: 0.1344
# Train: [0/2931 (0%)]	Loss: 0.159155
# Train: [1098/2931 (100%)]	Loss: 0.166484
# Epoch: 10/10. Train set: Average loss: 0.1665
# Epoch: 10/10. Validation set: Average loss: 0.1384
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.310189
# Train: [1098/2931 (100%)]	Loss: 0.177511
# Epoch: 1/10. Train set: Average loss: 0.1779
# Epoch: 1/10. Validation set: Average loss: 0.1410
# Train: [0/2931 (0%)]	Loss: 0.168140
# Train: [1098/2931 (100%)]	Loss: 0.179118
# Epoch: 2/10. Train set: Average loss: 0.1791
# Epoch: 2/10. Validation set: Average loss: 0.1599
# Train: [0/2931 (0%)]	Loss: 0.197205
# Train: [1098/2931 (100%)]	Loss: 0.170502
# Epoch: 3/10. Train set: Average loss: 0.1706
# Epoch: 3/10. Validation set: Average loss: 0.1552
# Train: [0/2931 (0%)]	Loss: 0.251465
# Train: [1098/2931 (100%)]	Loss: 0.165467
# Epoch: 4/10. Train set: Average loss: 0.1657
# Epoch: 4/10. Validation set: Average loss: 0.1719
# Train: [0/2931 (0%)]	Loss: 0.209766
# Train: [1098/2931 (100%)]	Loss: 0.173535
# Epoch: 5/10. Train set: Average loss: 0.1736
# Epoch: 5/10. Validation set: Average loss: 0.1551
# Train: [0/2931 (0%)]	Loss: 0.195783
# Train: [1098/2931 (100%)]	Loss: 0.164327
# Epoch: 6/10. Train set: Average loss: 0.1644
# Epoch: 6/10. Validation set: Average loss: 0.1485
# Train: [0/2931 (0%)]	Loss: 0.181583
# Train: [1098/2931 (100%)]	Loss: 0.173037
# Epoch: 7/10. Train set: Average loss: 0.1731
# Epoch: 7/10. Validation set: Average loss: 0.1451
# Train: [0/2931 (0%)]	Loss: 0.215682
# Train: [1098/2931 (100%)]	Loss: 0.173746
# Epoch: 8/10. Train set: Average loss: 0.1739
# Epoch: 8/10. Validation set: Average loss: 0.1931
# Train: [0/2931 (0%)]	Loss: 0.335156
# Train: [1098/2931 (100%)]	Loss: 0.171963
# Epoch: 9/10. Train set: Average loss: 0.1724
# Epoch: 9/10. Validation set: Average loss: 0.1377
# Train: [0/2931 (0%)]	Loss: 0.302451
# Train: [1098/2931 (100%)]	Loss: 0.171293
# Epoch: 10/10. Train set: Average loss: 0.1717
# Epoch: 10/10. Validation set: Average loss: 0.1374
# Number features: 21
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.186391
# Train: [1098/2931 (100%)]	Loss: 0.161429
# Epoch: 1/10. Train set: Average loss: 0.1615
# Epoch: 1/10. Validation set: Average loss: 0.1253
# Train: [0/2931 (0%)]	Loss: 0.134086
# Train: [1098/2931 (100%)]	Loss: 0.167520
# Epoch: 2/10. Train set: Average loss: 0.1674
# Epoch: 2/10. Validation set: Average loss: 0.1498
# Train: [0/2931 (0%)]	Loss: 0.147110
# Train: [1098/2931 (100%)]	Loss: 0.152493
# Epoch: 3/10. Train set: Average loss: 0.1525
# Epoch: 3/10. Validation set: Average loss: 0.1215
# Train: [0/2931 (0%)]	Loss: 0.142044
# Train: [1098/2931 (100%)]	Loss: 0.160205
# Epoch: 4/10. Train set: Average loss: 0.1602
# Epoch: 4/10. Validation set: Average loss: 0.1554
# Train: [0/2931 (0%)]	Loss: 0.189100
# Train: [1098/2931 (100%)]	Loss: 0.156310
# Epoch: 5/10. Train set: Average loss: 0.1564
# Epoch: 5/10. Validation set: Average loss: 0.1373
# Train: [0/2931 (0%)]	Loss: 0.087012
# Train: [1098/2931 (100%)]	Loss: 0.150998
# Epoch: 6/10. Train set: Average loss: 0.1508
# Epoch: 6/10. Validation set: Average loss: 0.1449
# Train: [0/2931 (0%)]	Loss: 0.156130
# Train: [1098/2931 (100%)]	Loss: 0.150326
# Epoch: 7/10. Train set: Average loss: 0.1503
# Epoch: 7/10. Validation set: Average loss: 0.1425
# Train: [0/2931 (0%)]	Loss: 0.106515
# Train: [1098/2931 (100%)]	Loss: 0.153445
# Epoch: 8/10. Train set: Average loss: 0.1533
# Epoch: 8/10. Validation set: Average loss: 0.1372
# Train: [0/2931 (0%)]	Loss: 0.111948
# Train: [1098/2931 (100%)]	Loss: 0.148106
# Epoch: 9/10. Train set: Average loss: 0.1480
# Epoch: 9/10. Validation set: Average loss: 0.1354
# Train: [0/2931 (0%)]	Loss: 0.069870
# Train: [1098/2931 (100%)]	Loss: 0.142133
# Epoch: 10/10. Train set: Average loss: 0.1419
# Epoch: 10/10. Validation set: Average loss: 0.1330
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.248569
# Train: [1098/2931 (100%)]	Loss: 0.157723
# Epoch: 1/10. Train set: Average loss: 0.1580
# Epoch: 1/10. Validation set: Average loss: 0.1336
# Train: [0/2931 (0%)]	Loss: 0.164355
# Train: [1098/2931 (100%)]	Loss: 0.163310
# Epoch: 2/10. Train set: Average loss: 0.1633
# Epoch: 2/10. Validation set: Average loss: 0.1352
# Train: [0/2931 (0%)]	Loss: 0.188957
# Train: [1098/2931 (100%)]	Loss: 0.156533
# Epoch: 3/10. Train set: Average loss: 0.1566
# Epoch: 3/10. Validation set: Average loss: 0.1303
# Train: [0/2931 (0%)]	Loss: 0.107335
# Train: [1098/2931 (100%)]	Loss: 0.150836
# Epoch: 4/10. Train set: Average loss: 0.1507
# Epoch: 4/10. Validation set: Average loss: 0.1353
# Train: [0/2931 (0%)]	Loss: 0.143184
# Train: [1098/2931 (100%)]	Loss: 0.148463
# Epoch: 5/10. Train set: Average loss: 0.1484
# Epoch: 5/10. Validation set: Average loss: 0.1423
# Train: [0/2931 (0%)]	Loss: 0.128250
# Train: [1098/2931 (100%)]	Loss: 0.150403
# Epoch: 6/10. Train set: Average loss: 0.1503
# Epoch: 6/10. Validation set: Average loss: 0.1448
# Train: [0/2931 (0%)]	Loss: 0.126847
# Train: [1098/2931 (100%)]	Loss: 0.152373
# Epoch: 7/10. Train set: Average loss: 0.1523
# Epoch: 7/10. Validation set: Average loss: 0.1325
# Train: [0/2931 (0%)]	Loss: 0.111205
# Train: [1098/2931 (100%)]	Loss: 0.145565
# Epoch: 8/10. Train set: Average loss: 0.1455
# Epoch: 8/10. Validation set: Average loss: 0.1372
# Train: [0/2931 (0%)]	Loss: 0.114732
# Train: [1098/2931 (100%)]	Loss: 0.144023
# Epoch: 9/10. Train set: Average loss: 0.1439
# Epoch: 9/10. Validation set: Average loss: 0.1333
# Train: [0/2931 (0%)]	Loss: 0.101482
# Train: [1098/2931 (100%)]	Loss: 0.144635
# Epoch: 10/10. Train set: Average loss: 0.1445
# Epoch: 10/10. Validation set: Average loss: 0.1338
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249302
# Train: [1098/2931 (100%)]	Loss: 0.161843
# Epoch: 1/10. Train set: Average loss: 0.1621
# Epoch: 1/10. Validation set: Average loss: 0.1408
# Train: [0/2931 (0%)]	Loss: 0.261418
# Train: [1098/2931 (100%)]	Loss: 0.158355
# Epoch: 2/10. Train set: Average loss: 0.1586
# Epoch: 2/10. Validation set: Average loss: 0.1188
# Train: [0/2931 (0%)]	Loss: 0.209357
# Train: [1098/2931 (100%)]	Loss: 0.160665
# Epoch: 3/10. Train set: Average loss: 0.1608
# Epoch: 3/10. Validation set: Average loss: 0.1225
# Train: [0/2931 (0%)]	Loss: 0.081424
# Train: [1098/2931 (100%)]	Loss: 0.156078
# Epoch: 4/10. Train set: Average loss: 0.1559
# Epoch: 4/10. Validation set: Average loss: 0.1220
# Train: [0/2931 (0%)]	Loss: 0.202448
# Train: [1098/2931 (100%)]	Loss: 0.153291
# Epoch: 5/10. Train set: Average loss: 0.1534
# Epoch: 5/10. Validation set: Average loss: 0.1152
# Train: [0/2931 (0%)]	Loss: 0.153335
# Train: [1098/2931 (100%)]	Loss: 0.152747
# Epoch: 6/10. Train set: Average loss: 0.1527
# Epoch: 6/10. Validation set: Average loss: 0.1343
# Train: [0/2931 (0%)]	Loss: 0.215915
# Train: [1098/2931 (100%)]	Loss: 0.152215
# Epoch: 7/10. Train set: Average loss: 0.1524
# Epoch: 7/10. Validation set: Average loss: 0.1358
# Train: [0/2931 (0%)]	Loss: 0.094258
# Train: [1098/2931 (100%)]	Loss: 0.150537
# Epoch: 8/10. Train set: Average loss: 0.1504
# Epoch: 8/10. Validation set: Average loss: 0.1294
# Train: [0/2931 (0%)]	Loss: 0.299599
# Train: [1098/2931 (100%)]	Loss: 0.148866
# Epoch: 9/10. Train set: Average loss: 0.1493
# Epoch: 9/10. Validation set: Average loss: 0.1292
# Train: [0/2931 (0%)]	Loss: 0.192750
# Train: [1098/2931 (100%)]	Loss: 0.146888
# Epoch: 10/10. Train set: Average loss: 0.1470
# Epoch: 10/10. Validation set: Average loss: 0.1282
# Number features: 41
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.436115
# Train: [1098/2931 (100%)]	Loss: 0.167779
# Epoch: 1/10. Train set: Average loss: 0.1685
# Epoch: 1/10. Validation set: Average loss: 0.1749
# Train: [0/2931 (0%)]	Loss: 0.236499
# Train: [1098/2931 (100%)]	Loss: 0.163297
# Epoch: 2/10. Train set: Average loss: 0.1635
# Epoch: 2/10. Validation set: Average loss: 0.1503
# Train: [0/2931 (0%)]	Loss: 0.147617
# Train: [1098/2931 (100%)]	Loss: 0.161997
# Epoch: 3/10. Train set: Average loss: 0.1620
# Epoch: 3/10. Validation set: Average loss: 0.1537
# Train: [0/2931 (0%)]	Loss: 0.272351
# Train: [1098/2931 (100%)]	Loss: 0.164740
# Epoch: 4/10. Train set: Average loss: 0.1650
# Epoch: 4/10. Validation set: Average loss: 0.1404
# Train: [0/2931 (0%)]	Loss: 0.173662
# Train: [1098/2931 (100%)]	Loss: 0.156436
# Epoch: 5/10. Train set: Average loss: 0.1565
# Epoch: 5/10. Validation set: Average loss: 0.1352
# Train: [0/2931 (0%)]	Loss: 0.206793
# Train: [1098/2931 (100%)]	Loss: 0.152224
# Epoch: 6/10. Train set: Average loss: 0.1524
# Epoch: 6/10. Validation set: Average loss: 0.1328
# Train: [0/2931 (0%)]	Loss: 0.159441
# Train: [1098/2931 (100%)]	Loss: 0.149819
# Epoch: 7/10. Train set: Average loss: 0.1498
# Epoch: 7/10. Validation set: Average loss: 0.1296
# Train: [0/2931 (0%)]	Loss: 0.205541
# Train: [1098/2931 (100%)]	Loss: 0.157132
# Epoch: 8/10. Train set: Average loss: 0.1573
# Epoch: 8/10. Validation set: Average loss: 0.1441
# Train: [0/2931 (0%)]	Loss: 0.228668
# Train: [1098/2931 (100%)]	Loss: 0.146136
# Epoch: 9/10. Train set: Average loss: 0.1464
# Epoch: 9/10. Validation set: Average loss: 0.1375
# Train: [0/2931 (0%)]	Loss: 0.218677
# Train: [1098/2931 (100%)]	Loss: 0.143921
# Epoch: 10/10. Train set: Average loss: 0.1441
# Epoch: 10/10. Validation set: Average loss: 0.1329
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.311768
# Train: [1098/2931 (100%)]	Loss: 0.168222
# Epoch: 1/10. Train set: Average loss: 0.1686
# Epoch: 1/10. Validation set: Average loss: 0.1667
# Train: [0/2931 (0%)]	Loss: 0.172543
# Train: [1098/2931 (100%)]	Loss: 0.166970
# Epoch: 2/10. Train set: Average loss: 0.1670
# Epoch: 2/10. Validation set: Average loss: 0.1641
# Train: [0/2931 (0%)]	Loss: 0.196426
# Train: [1098/2931 (100%)]	Loss: 0.163168
# Epoch: 3/10. Train set: Average loss: 0.1633
# Epoch: 3/10. Validation set: Average loss: 0.1484
# Train: [0/2931 (0%)]	Loss: 0.258383
# Train: [1098/2931 (100%)]	Loss: 0.157731
# Epoch: 4/10. Train set: Average loss: 0.1580
# Epoch: 4/10. Validation set: Average loss: 0.1736
# Train: [0/2931 (0%)]	Loss: 0.218984
# Train: [1098/2931 (100%)]	Loss: 0.154676
# Epoch: 5/10. Train set: Average loss: 0.1549
# Epoch: 5/10. Validation set: Average loss: 0.1367
# Train: [0/2931 (0%)]	Loss: 0.188693
# Train: [1098/2931 (100%)]	Loss: 0.149053
# Epoch: 6/10. Train set: Average loss: 0.1492
# Epoch: 6/10. Validation set: Average loss: 0.1442
# Train: [0/2931 (0%)]	Loss: 0.068888
# Train: [1098/2931 (100%)]	Loss: 0.149797
# Epoch: 7/10. Train set: Average loss: 0.1496
# Epoch: 7/10. Validation set: Average loss: 0.1522
# Train: [0/2931 (0%)]	Loss: 0.171647
# Train: [1098/2931 (100%)]	Loss: 0.155132
# Epoch: 8/10. Train set: Average loss: 0.1552
# Epoch: 8/10. Validation set: Average loss: 0.1614
# Train: [0/2931 (0%)]	Loss: 0.186554
# Train: [1098/2931 (100%)]	Loss: 0.154212
# Epoch: 9/10. Train set: Average loss: 0.1543
# Epoch: 9/10. Validation set: Average loss: 0.1356
# Train: [0/2931 (0%)]	Loss: 0.144349
# Train: [1098/2931 (100%)]	Loss: 0.146804
# Epoch: 10/10. Train set: Average loss: 0.1468
# Epoch: 10/10. Validation set: Average loss: 0.1364
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249489
# Train: [1098/2931 (100%)]	Loss: 0.161241
# Epoch: 1/10. Train set: Average loss: 0.1615
# Epoch: 1/10. Validation set: Average loss: 0.1625
# Train: [0/2931 (0%)]	Loss: 0.182733
# Train: [1098/2931 (100%)]	Loss: 0.161067
# Epoch: 2/10. Train set: Average loss: 0.1611
# Epoch: 2/10. Validation set: Average loss: 0.1449
# Train: [0/2931 (0%)]	Loss: 0.101057
# Train: [1098/2931 (100%)]	Loss: 0.157697
# Epoch: 3/10. Train set: Average loss: 0.1575
# Epoch: 3/10. Validation set: Average loss: 0.1419
# Train: [0/2931 (0%)]	Loss: 0.219153
# Train: [1098/2931 (100%)]	Loss: 0.159642
# Epoch: 4/10. Train set: Average loss: 0.1598
# Epoch: 4/10. Validation set: Average loss: 0.1564
# Train: [0/2931 (0%)]	Loss: 0.197586
# Train: [1098/2931 (100%)]	Loss: 0.164741
# Epoch: 5/10. Train set: Average loss: 0.1648
# Epoch: 5/10. Validation set: Average loss: 0.1717
# Train: [0/2931 (0%)]	Loss: 0.210552
# Train: [1098/2931 (100%)]	Loss: 0.171460
# Epoch: 6/10. Train set: Average loss: 0.1716
# Epoch: 6/10. Validation set: Average loss: 0.1722
# Train: [0/2931 (0%)]	Loss: 0.195319
# Train: [1098/2931 (100%)]	Loss: 0.172978
# Epoch: 7/10. Train set: Average loss: 0.1730
# Epoch: 7/10. Validation set: Average loss: 0.1571
# Train: [0/2931 (0%)]	Loss: 0.225241
# Train: [1098/2931 (100%)]	Loss: 0.172855
# Epoch: 8/10. Train set: Average loss: 0.1730
# Epoch: 8/10. Validation set: Average loss: 0.1628
# Train: [0/2931 (0%)]	Loss: 0.170402
# Train: [1098/2931 (100%)]	Loss: 0.162586
# Epoch: 9/10. Train set: Average loss: 0.1626
# Epoch: 9/10. Validation set: Average loss: 0.1589
# Train: [0/2931 (0%)]	Loss: 0.218865
# Train: [1098/2931 (100%)]	Loss: 0.164498
# Epoch: 10/10. Train set: Average loss: 0.1646
# Epoch: 10/10. Validation set: Average loss: 0.1567
# Number features: 61
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187033
# Train: [1098/2931 (100%)]	Loss: 0.155859
# Epoch: 1/10. Train set: Average loss: 0.1559
# Epoch: 1/10. Validation set: Average loss: 0.1538
# Train: [0/2931 (0%)]	Loss: 0.126431
# Train: [1098/2931 (100%)]	Loss: 0.158201
# Epoch: 2/10. Train set: Average loss: 0.1581
# Epoch: 2/10. Validation set: Average loss: 0.1662
# Train: [0/2931 (0%)]	Loss: 0.160069
# Train: [1098/2931 (100%)]	Loss: 0.147551
# Epoch: 3/10. Train set: Average loss: 0.1476
# Epoch: 3/10. Validation set: Average loss: 0.1646
# Train: [0/2931 (0%)]	Loss: 0.148138
# Train: [1098/2931 (100%)]	Loss: 0.147913
# Epoch: 4/10. Train set: Average loss: 0.1479
# Epoch: 4/10. Validation set: Average loss: 0.1539
# Train: [0/2931 (0%)]	Loss: 0.139401
# Train: [1098/2931 (100%)]	Loss: 0.148513
# Epoch: 5/10. Train set: Average loss: 0.1485
# Epoch: 5/10. Validation set: Average loss: 0.1254
# Train: [0/2931 (0%)]	Loss: 0.133036
# Train: [1098/2931 (100%)]	Loss: 0.143398
# Epoch: 6/10. Train set: Average loss: 0.1434
# Epoch: 6/10. Validation set: Average loss: 0.1493
# Train: [0/2931 (0%)]	Loss: 0.113963
# Train: [1098/2931 (100%)]	Loss: 0.146385
# Epoch: 7/10. Train set: Average loss: 0.1463
# Epoch: 7/10. Validation set: Average loss: 0.1266
# Train: [0/2931 (0%)]	Loss: 0.156700
# Train: [1098/2931 (100%)]	Loss: 0.146616
# Epoch: 8/10. Train set: Average loss: 0.1466
# Epoch: 8/10. Validation set: Average loss: 0.1977
# Train: [0/2931 (0%)]	Loss: 0.152660
# Train: [1098/2931 (100%)]	Loss: 0.143001
# Epoch: 9/10. Train set: Average loss: 0.1430
# Epoch: 9/10. Validation set: Average loss: 0.1454
# Train: [0/2931 (0%)]	Loss: 0.134517
# Train: [1098/2931 (100%)]	Loss: 0.140291
# Epoch: 10/10. Train set: Average loss: 0.1403
# Epoch: 10/10. Validation set: Average loss: 0.1397
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.124776
# Train: [1098/2931 (100%)]	Loss: 0.153993
# Epoch: 1/10. Train set: Average loss: 0.1539
# Epoch: 1/10. Validation set: Average loss: 0.1312
# Train: [0/2931 (0%)]	Loss: 0.185050
# Train: [1098/2931 (100%)]	Loss: 0.157418
# Epoch: 2/10. Train set: Average loss: 0.1575
# Epoch: 2/10. Validation set: Average loss: 0.1319
# Train: [0/2931 (0%)]	Loss: 0.098326
# Train: [1098/2931 (100%)]	Loss: 0.154493
# Epoch: 3/10. Train set: Average loss: 0.1543
# Epoch: 3/10. Validation set: Average loss: 0.1439
# Train: [0/2931 (0%)]	Loss: 0.067962
# Train: [1098/2931 (100%)]	Loss: 0.145897
# Epoch: 4/10. Train set: Average loss: 0.1457
# Epoch: 4/10. Validation set: Average loss: 0.1570
# Train: [0/2931 (0%)]	Loss: 0.121964
# Train: [1098/2931 (100%)]	Loss: 0.152660
# Epoch: 5/10. Train set: Average loss: 0.1526
# Epoch: 5/10. Validation set: Average loss: 0.1401
# Train: [0/2931 (0%)]	Loss: 0.159376
# Train: [1098/2931 (100%)]	Loss: 0.157792
# Epoch: 6/10. Train set: Average loss: 0.1578
# Epoch: 6/10. Validation set: Average loss: 0.1581
# Train: [0/2931 (0%)]	Loss: 0.087570
# Train: [1098/2931 (100%)]	Loss: 0.154061
# Epoch: 7/10. Train set: Average loss: 0.1539
# Epoch: 7/10. Validation set: Average loss: 0.1524
# Train: [0/2931 (0%)]	Loss: 0.150657
# Train: [1098/2931 (100%)]	Loss: 0.159478
# Epoch: 8/10. Train set: Average loss: 0.1595
# Epoch: 8/10. Validation set: Average loss: 0.1439
# Train: [0/2931 (0%)]	Loss: 0.125205
# Train: [1098/2931 (100%)]	Loss: 0.148366
# Epoch: 9/10. Train set: Average loss: 0.1483
# Epoch: 9/10. Validation set: Average loss: 0.1393
# Train: [0/2931 (0%)]	Loss: 0.086130
# Train: [1098/2931 (100%)]	Loss: 0.144125
# Epoch: 10/10. Train set: Average loss: 0.1440
# Epoch: 10/10. Validation set: Average loss: 0.1305
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.312125
# Train: [1098/2931 (100%)]	Loss: 0.159727
# Epoch: 1/10. Train set: Average loss: 0.1601
# Epoch: 1/10. Validation set: Average loss: 0.1422
# Train: [0/2931 (0%)]	Loss: 0.119115
# Train: [1098/2931 (100%)]	Loss: 0.160834
# Epoch: 2/10. Train set: Average loss: 0.1607
# Epoch: 2/10. Validation set: Average loss: 0.1382
# Train: [0/2931 (0%)]	Loss: 0.157811
# Train: [1098/2931 (100%)]	Loss: 0.156847
# Epoch: 3/10. Train set: Average loss: 0.1568
# Epoch: 3/10. Validation set: Average loss: 0.1340
# Train: [0/2931 (0%)]	Loss: 0.216801
# Train: [1098/2931 (100%)]	Loss: 0.152058
# Epoch: 4/10. Train set: Average loss: 0.1522
# Epoch: 4/10. Validation set: Average loss: 0.1363
# Train: [0/2931 (0%)]	Loss: 0.120270
# Train: [1098/2931 (100%)]	Loss: 0.146864
# Epoch: 5/10. Train set: Average loss: 0.1468
# Epoch: 5/10. Validation set: Average loss: 0.1506
# Train: [0/2931 (0%)]	Loss: 0.185711
# Train: [1098/2931 (100%)]	Loss: 0.155385
# Epoch: 6/10. Train set: Average loss: 0.1555
# Epoch: 6/10. Validation set: Average loss: 0.1650
# Train: [0/2931 (0%)]	Loss: 0.118592
# Train: [1098/2931 (100%)]	Loss: 0.155446
# Epoch: 7/10. Train set: Average loss: 0.1553
# Epoch: 7/10. Validation set: Average loss: 0.1655
# Train: [0/2931 (0%)]	Loss: 0.154588
# Train: [1098/2931 (100%)]	Loss: 0.153161
# Epoch: 8/10. Train set: Average loss: 0.1532
# Epoch: 8/10. Validation set: Average loss: 0.1508
# Train: [0/2931 (0%)]	Loss: 0.093067
# Train: [1098/2931 (100%)]	Loss: 0.142753
# Epoch: 9/10. Train set: Average loss: 0.1426
# Epoch: 9/10. Validation set: Average loss: 0.1366
# Train: [0/2931 (0%)]	Loss: 0.117966
# Train: [1098/2931 (100%)]	Loss: 0.142376
# Epoch: 10/10. Train set: Average loss: 0.1423
# Epoch: 10/10. Validation set: Average loss: 0.1360
# Number features: 81
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.311918
# Train: [1098/2931 (100%)]	Loss: 0.166743
# Epoch: 1/10. Train set: Average loss: 0.1671
# Epoch: 1/10. Validation set: Average loss: 0.1474
# Train: [0/2931 (0%)]	Loss: 0.227311
# Train: [1098/2931 (100%)]	Loss: 0.153060
# Epoch: 2/10. Train set: Average loss: 0.1533
# Epoch: 2/10. Validation set: Average loss: 0.1075
# Train: [0/2931 (0%)]	Loss: 0.240959
# Train: [1098/2931 (100%)]	Loss: 0.153951
# Epoch: 3/10. Train set: Average loss: 0.1542
# Epoch: 3/10. Validation set: Average loss: 0.1504
# Train: [0/2931 (0%)]	Loss: 0.144056
# Train: [1098/2931 (100%)]	Loss: 0.161805
# Epoch: 4/10. Train set: Average loss: 0.1618
# Epoch: 4/10. Validation set: Average loss: 0.0964
# Train: [0/2931 (0%)]	Loss: 0.134181
# Train: [1098/2931 (100%)]	Loss: 0.145165
# Epoch: 5/10. Train set: Average loss: 0.1451
# Epoch: 5/10. Validation set: Average loss: 0.1351
# Train: [0/2931 (0%)]	Loss: 0.089966
# Train: [1098/2931 (100%)]	Loss: 0.153374
# Epoch: 6/10. Train set: Average loss: 0.1532
# Epoch: 6/10. Validation set: Average loss: 0.1135
# Train: [0/2931 (0%)]	Loss: 0.197740
# Train: [1098/2931 (100%)]	Loss: 0.144402
# Epoch: 7/10. Train set: Average loss: 0.1445
# Epoch: 7/10. Validation set: Average loss: 0.1132
# Train: [0/2931 (0%)]	Loss: 0.091005
# Train: [1098/2931 (100%)]	Loss: 0.145676
# Epoch: 8/10. Train set: Average loss: 0.1455
# Epoch: 8/10. Validation set: Average loss: 0.1232
# Train: [0/2931 (0%)]	Loss: 0.077847
# Train: [1098/2931 (100%)]	Loss: 0.144466
# Epoch: 9/10. Train set: Average loss: 0.1443
# Epoch: 9/10. Validation set: Average loss: 0.1206
# Train: [0/2931 (0%)]	Loss: 0.146463
# Train: [1098/2931 (100%)]	Loss: 0.139293
# Epoch: 10/10. Train set: Average loss: 0.1393
# Epoch: 10/10. Validation set: Average loss: 0.1244
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.186741
# Train: [1098/2931 (100%)]	Loss: 0.164286
# Epoch: 1/10. Train set: Average loss: 0.1643
# Epoch: 1/10. Validation set: Average loss: 0.1355
# Train: [0/2931 (0%)]	Loss: 0.149935
# Train: [1098/2931 (100%)]	Loss: 0.159617
# Epoch: 2/10. Train set: Average loss: 0.1596
# Epoch: 2/10. Validation set: Average loss: 0.1368
# Train: [0/2931 (0%)]	Loss: 0.148414
# Train: [1098/2931 (100%)]	Loss: 0.154326
# Epoch: 3/10. Train set: Average loss: 0.1543
# Epoch: 3/10. Validation set: Average loss: 0.1210
# Train: [0/2931 (0%)]	Loss: 0.132651
# Train: [1098/2931 (100%)]	Loss: 0.159446
# Epoch: 4/10. Train set: Average loss: 0.1594
# Epoch: 4/10. Validation set: Average loss: 0.1865
# Train: [0/2931 (0%)]	Loss: 0.213714
# Train: [1098/2931 (100%)]	Loss: 0.161932
# Epoch: 5/10. Train set: Average loss: 0.1621
# Epoch: 5/10. Validation set: Average loss: 0.1545
# Train: [0/2931 (0%)]	Loss: 0.097503
# Train: [1098/2931 (100%)]	Loss: 0.150544
# Epoch: 6/10. Train set: Average loss: 0.1504
# Epoch: 6/10. Validation set: Average loss: 0.1272
# Train: [0/2931 (0%)]	Loss: 0.169398
# Train: [1098/2931 (100%)]	Loss: 0.148044
# Epoch: 7/10. Train set: Average loss: 0.1481
# Epoch: 7/10. Validation set: Average loss: 0.1190
# Train: [0/2931 (0%)]	Loss: 0.147161
# Train: [1098/2931 (100%)]	Loss: 0.143898
# Epoch: 8/10. Train set: Average loss: 0.1439
# Epoch: 8/10. Validation set: Average loss: 0.1133
# Train: [0/2931 (0%)]	Loss: 0.139633
# Train: [1098/2931 (100%)]	Loss: 0.140044
# Epoch: 9/10. Train set: Average loss: 0.1400
# Epoch: 9/10. Validation set: Average loss: 0.1284
# Train: [0/2931 (0%)]	Loss: 0.144250
# Train: [1098/2931 (100%)]	Loss: 0.142830
# Epoch: 10/10. Train set: Average loss: 0.1428
# Epoch: 10/10. Validation set: Average loss: 0.1293
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.187132
# Train: [1098/2931 (100%)]	Loss: 0.167335
# Epoch: 1/10. Train set: Average loss: 0.1674
# Epoch: 1/10. Validation set: Average loss: 0.1129
# Train: [0/2931 (0%)]	Loss: 0.150376
# Train: [1098/2931 (100%)]	Loss: 0.162059
# Epoch: 2/10. Train set: Average loss: 0.1620
# Epoch: 2/10. Validation set: Average loss: 0.1446
# Train: [0/2931 (0%)]	Loss: 0.359391
# Train: [1098/2931 (100%)]	Loss: 0.165373
# Epoch: 3/10. Train set: Average loss: 0.1659
# Epoch: 3/10. Validation set: Average loss: 0.1519
# Train: [0/2931 (0%)]	Loss: 0.188186
# Train: [1098/2931 (100%)]	Loss: 0.156928
# Epoch: 4/10. Train set: Average loss: 0.1570
# Epoch: 4/10. Validation set: Average loss: 0.1247
# Train: [0/2931 (0%)]	Loss: 0.331852
# Train: [1098/2931 (100%)]	Loss: 0.153246
# Epoch: 5/10. Train set: Average loss: 0.1537
# Epoch: 5/10. Validation set: Average loss: 0.1310
# Train: [0/2931 (0%)]	Loss: 0.157544
# Train: [1098/2931 (100%)]	Loss: 0.156277
# Epoch: 6/10. Train set: Average loss: 0.1563
# Epoch: 6/10. Validation set: Average loss: 0.1374
# Train: [0/2931 (0%)]	Loss: 0.168729
# Train: [1098/2931 (100%)]	Loss: 0.149662
# Epoch: 7/10. Train set: Average loss: 0.1497
# Epoch: 7/10. Validation set: Average loss: 0.1248
# Train: [0/2931 (0%)]	Loss: 0.139777
# Train: [1098/2931 (100%)]	Loss: 0.148751
# Epoch: 8/10. Train set: Average loss: 0.1487
# Epoch: 8/10. Validation set: Average loss: 0.1072
# Train: [0/2931 (0%)]	Loss: 0.132725
# Train: [1098/2931 (100%)]	Loss: 0.139050
# Epoch: 9/10. Train set: Average loss: 0.1390
# Epoch: 9/10. Validation set: Average loss: 0.1248
# Train: [0/2931 (0%)]	Loss: 0.146161
# Train: [1098/2931 (100%)]	Loss: 0.136385
# Epoch: 10/10. Train set: Average loss: 0.1364
# Epoch: 10/10. Validation set: Average loss: 0.1243
# Number features: 101
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187226
# Train: [1098/2931 (100%)]	Loss: 0.163462
# Epoch: 1/10. Train set: Average loss: 0.1635
# Epoch: 1/10. Validation set: Average loss: 0.1284
# Train: [0/2931 (0%)]	Loss: 0.070271
# Train: [1098/2931 (100%)]	Loss: 0.166245
# Epoch: 2/10. Train set: Average loss: 0.1660
# Epoch: 2/10. Validation set: Average loss: 0.1759
# Train: [0/2931 (0%)]	Loss: 0.142037
# Train: [1098/2931 (100%)]	Loss: 0.161824
# Epoch: 3/10. Train set: Average loss: 0.1618
# Epoch: 3/10. Validation set: Average loss: 0.1354
# Train: [0/2931 (0%)]	Loss: 0.153414
# Train: [1098/2931 (100%)]	Loss: 0.158177
# Epoch: 4/10. Train set: Average loss: 0.1582
# Epoch: 4/10. Validation set: Average loss: 0.1449
# Train: [0/2931 (0%)]	Loss: 0.248697
# Train: [1098/2931 (100%)]	Loss: 0.157957
# Epoch: 5/10. Train set: Average loss: 0.1582
# Epoch: 5/10. Validation set: Average loss: 0.1431
# Train: [0/2931 (0%)]	Loss: 0.113532
# Train: [1098/2931 (100%)]	Loss: 0.151155
# Epoch: 6/10. Train set: Average loss: 0.1511
# Epoch: 6/10. Validation set: Average loss: 0.1380
# Train: [0/2931 (0%)]	Loss: 0.139177
# Train: [1098/2931 (100%)]	Loss: 0.147017
# Epoch: 7/10. Train set: Average loss: 0.1470
# Epoch: 7/10. Validation set: Average loss: 0.1357
# Train: [0/2931 (0%)]	Loss: 0.145296
# Train: [1098/2931 (100%)]	Loss: 0.144421
# Epoch: 8/10. Train set: Average loss: 0.1444
# Epoch: 8/10. Validation set: Average loss: 0.1392
# Train: [0/2931 (0%)]	Loss: 0.126617
# Train: [1098/2931 (100%)]	Loss: 0.138791
# Epoch: 9/10. Train set: Average loss: 0.1388
# Epoch: 9/10. Validation set: Average loss: 0.1306
# Train: [0/2931 (0%)]	Loss: 0.116895
# Train: [1098/2931 (100%)]	Loss: 0.134252
# Epoch: 10/10. Train set: Average loss: 0.1342
# Epoch: 10/10. Validation set: Average loss: 0.1324
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.311786
# Train: [1098/2931 (100%)]	Loss: 0.167611
# Epoch: 1/10. Train set: Average loss: 0.1680
# Epoch: 1/10. Validation set: Average loss: 0.1237
# Train: [0/2931 (0%)]	Loss: 0.165655
# Train: [1098/2931 (100%)]	Loss: 0.167779
# Epoch: 2/10. Train set: Average loss: 0.1678
# Epoch: 2/10. Validation set: Average loss: 0.1535
# Train: [0/2931 (0%)]	Loss: 0.180355
# Train: [1098/2931 (100%)]	Loss: 0.162767
# Epoch: 3/10. Train set: Average loss: 0.1628
# Epoch: 3/10. Validation set: Average loss: 0.1374
# Train: [0/2931 (0%)]	Loss: 0.271777
# Train: [1098/2931 (100%)]	Loss: 0.152652
# Epoch: 4/10. Train set: Average loss: 0.1530
# Epoch: 4/10. Validation set: Average loss: 0.1386
# Train: [0/2931 (0%)]	Loss: 0.118790
# Train: [1098/2931 (100%)]	Loss: 0.157545
# Epoch: 5/10. Train set: Average loss: 0.1574
# Epoch: 5/10. Validation set: Average loss: 0.1513
# Train: [0/2931 (0%)]	Loss: 0.169688
# Train: [1098/2931 (100%)]	Loss: 0.153493
# Epoch: 6/10. Train set: Average loss: 0.1535
# Epoch: 6/10. Validation set: Average loss: 0.1382
# Train: [0/2931 (0%)]	Loss: 0.137645
# Train: [1098/2931 (100%)]	Loss: 0.150099
# Epoch: 7/10. Train set: Average loss: 0.1501
# Epoch: 7/10. Validation set: Average loss: 0.1469
# Train: [0/2931 (0%)]	Loss: 0.165284
# Train: [1098/2931 (100%)]	Loss: 0.147302
# Epoch: 8/10. Train set: Average loss: 0.1474
# Epoch: 8/10. Validation set: Average loss: 0.1351
# Train: [0/2931 (0%)]	Loss: 0.188777
# Train: [1098/2931 (100%)]	Loss: 0.140438
# Epoch: 9/10. Train set: Average loss: 0.1406
# Epoch: 9/10. Validation set: Average loss: 0.1314
# Train: [0/2931 (0%)]	Loss: 0.182860
# Train: [1098/2931 (100%)]	Loss: 0.133697
# Epoch: 10/10. Train set: Average loss: 0.1338
# Epoch: 10/10. Validation set: Average loss: 0.1351
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.249072
# Train: [1098/2931 (100%)]	Loss: 0.161184
# Epoch: 1/10. Train set: Average loss: 0.1614
# Epoch: 1/10. Validation set: Average loss: 0.1419
# Train: [0/2931 (0%)]	Loss: 0.157862
# Train: [1098/2931 (100%)]	Loss: 0.162895
# Epoch: 2/10. Train set: Average loss: 0.1629
# Epoch: 2/10. Validation set: Average loss: 0.1410
# Train: [0/2931 (0%)]	Loss: 0.130348
# Train: [1098/2931 (100%)]	Loss: 0.157864
# Epoch: 3/10. Train set: Average loss: 0.1578
# Epoch: 3/10. Validation set: Average loss: 0.1263
# Train: [0/2931 (0%)]	Loss: 0.068644
# Train: [1098/2931 (100%)]	Loss: 0.150891
# Epoch: 4/10. Train set: Average loss: 0.1507
# Epoch: 4/10. Validation set: Average loss: 0.1399
# Train: [0/2931 (0%)]	Loss: 0.175544
# Train: [1098/2931 (100%)]	Loss: 0.156225
# Epoch: 5/10. Train set: Average loss: 0.1563
# Epoch: 5/10. Validation set: Average loss: 0.1238
# Train: [0/2931 (0%)]	Loss: 0.140446
# Train: [1098/2931 (100%)]	Loss: 0.152145
# Epoch: 6/10. Train set: Average loss: 0.1521
# Epoch: 6/10. Validation set: Average loss: 0.1285
# Train: [0/2931 (0%)]	Loss: 0.164614
# Train: [1098/2931 (100%)]	Loss: 0.149338
# Epoch: 7/10. Train set: Average loss: 0.1494
# Epoch: 7/10. Validation set: Average loss: 0.1386
# Train: [0/2931 (0%)]	Loss: 0.125114
# Train: [1098/2931 (100%)]	Loss: 0.150905
# Epoch: 8/10. Train set: Average loss: 0.1508
# Epoch: 8/10. Validation set: Average loss: 0.1318
# Train: [0/2931 (0%)]	Loss: 0.139423
# Train: [1098/2931 (100%)]	Loss: 0.137471
# Epoch: 9/10. Train set: Average loss: 0.1375
# Epoch: 9/10. Validation set: Average loss: 0.1331
# Train: [0/2931 (0%)]	Loss: 0.159512
# Train: [1098/2931 (100%)]	Loss: 0.137654
# Epoch: 10/10. Train set: Average loss: 0.1377
# Epoch: 10/10. Validation set: Average loss: 0.1362
# Number features: 122
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.249637
# Train: [1098/2931 (100%)]	Loss: 0.153297
# Epoch: 1/10. Train set: Average loss: 0.1536
# Epoch: 1/10. Validation set: Average loss: 0.1566
# Train: [0/2931 (0%)]	Loss: 0.178925
# Train: [1098/2931 (100%)]	Loss: 0.151550
# Epoch: 2/10. Train set: Average loss: 0.1516
# Epoch: 2/10. Validation set: Average loss: 0.1711
# Train: [0/2931 (0%)]	Loss: 0.162661
# Train: [1098/2931 (100%)]	Loss: 0.144631
# Epoch: 3/10. Train set: Average loss: 0.1447
# Epoch: 3/10. Validation set: Average loss: 0.1498
# Train: [0/2931 (0%)]	Loss: 0.216236
# Train: [1098/2931 (100%)]	Loss: 0.147699
# Epoch: 4/10. Train set: Average loss: 0.1479
# Epoch: 4/10. Validation set: Average loss: 0.1684
# Train: [0/2931 (0%)]	Loss: 0.160913
# Train: [1098/2931 (100%)]	Loss: 0.140934
# Epoch: 5/10. Train set: Average loss: 0.1410
# Epoch: 5/10. Validation set: Average loss: 0.1676
# Train: [0/2931 (0%)]	Loss: 0.208175
# Train: [1098/2931 (100%)]	Loss: 0.145552
# Epoch: 6/10. Train set: Average loss: 0.1457
# Epoch: 6/10. Validation set: Average loss: 0.1794
# Train: [0/2931 (0%)]	Loss: 0.164400
# Train: [1098/2931 (100%)]	Loss: 0.139225
# Epoch: 7/10. Train set: Average loss: 0.1393
# Epoch: 7/10. Validation set: Average loss: 0.1627
# Train: [0/2931 (0%)]	Loss: 0.237701
# Train: [1098/2931 (100%)]	Loss: 0.140634
# Epoch: 8/10. Train set: Average loss: 0.1409
# Epoch: 8/10. Validation set: Average loss: 0.1712
# Train: [0/2931 (0%)]	Loss: 0.140197
# Train: [1098/2931 (100%)]	Loss: 0.140035
# Epoch: 9/10. Train set: Average loss: 0.1400
# Epoch: 9/10. Validation set: Average loss: 0.1531
# Train: [0/2931 (0%)]	Loss: 0.145698
# Train: [1098/2931 (100%)]	Loss: 0.138083
# Epoch: 10/10. Train set: Average loss: 0.1381
# Epoch: 10/10. Validation set: Average loss: 0.1490
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249572
# Train: [1098/2931 (100%)]	Loss: 0.158480
# Epoch: 1/10. Train set: Average loss: 0.1587
# Epoch: 1/10. Validation set: Average loss: 0.1563
# Train: [0/2931 (0%)]	Loss: 0.231800
# Train: [1098/2931 (100%)]	Loss: 0.158824
# Epoch: 2/10. Train set: Average loss: 0.1590
# Epoch: 2/10. Validation set: Average loss: 0.1853
# Train: [0/2931 (0%)]	Loss: 0.164262
# Train: [1098/2931 (100%)]	Loss: 0.155424
# Epoch: 3/10. Train set: Average loss: 0.1554
# Epoch: 3/10. Validation set: Average loss: 0.1528
# Train: [0/2931 (0%)]	Loss: 0.168151
# Train: [1098/2931 (100%)]	Loss: 0.146719
# Epoch: 4/10. Train set: Average loss: 0.1468
# Epoch: 4/10. Validation set: Average loss: 0.1520
# Train: [0/2931 (0%)]	Loss: 0.159186
# Train: [1098/2931 (100%)]	Loss: 0.152415
# Epoch: 5/10. Train set: Average loss: 0.1524
# Epoch: 5/10. Validation set: Average loss: 0.1473
# Train: [0/2931 (0%)]	Loss: 0.161289
# Train: [1098/2931 (100%)]	Loss: 0.155170
# Epoch: 6/10. Train set: Average loss: 0.1552
# Epoch: 6/10. Validation set: Average loss: 0.1619
# Train: [0/2931 (0%)]	Loss: 0.206284
# Train: [1098/2931 (100%)]	Loss: 0.156597
# Epoch: 7/10. Train set: Average loss: 0.1567
# Epoch: 7/10. Validation set: Average loss: 0.1733
# Train: [0/2931 (0%)]	Loss: 0.192971
# Train: [1098/2931 (100%)]	Loss: 0.143847
# Epoch: 8/10. Train set: Average loss: 0.1440
# Epoch: 8/10. Validation set: Average loss: 0.1765
# Train: [0/2931 (0%)]	Loss: 0.158624
# Train: [1098/2931 (100%)]	Loss: 0.147036
# Epoch: 9/10. Train set: Average loss: 0.1471
# Epoch: 9/10. Validation set: Average loss: 0.1413
# Train: [0/2931 (0%)]	Loss: 0.127910
# Train: [1098/2931 (100%)]	Loss: 0.142851
# Epoch: 10/10. Train set: Average loss: 0.1428
# Epoch: 10/10. Validation set: Average loss: 0.1447
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.186941
# Train: [1098/2931 (100%)]	Loss: 0.168047
# Epoch: 1/10. Train set: Average loss: 0.1681
# Epoch: 1/10. Validation set: Average loss: 0.1630
# Train: [0/2931 (0%)]	Loss: 0.105890
# Train: [1098/2931 (100%)]	Loss: 0.147854
# Epoch: 2/10. Train set: Average loss: 0.1477
# Epoch: 2/10. Validation set: Average loss: 0.1569
# Train: [0/2931 (0%)]	Loss: 0.140152
# Train: [1098/2931 (100%)]	Loss: 0.147577
# Epoch: 3/10. Train set: Average loss: 0.1476
# Epoch: 3/10. Validation set: Average loss: 0.1662
# Train: [0/2931 (0%)]	Loss: 0.256340
# Train: [1098/2931 (100%)]	Loss: 0.151435
# Epoch: 4/10. Train set: Average loss: 0.1517
# Epoch: 4/10. Validation set: Average loss: 0.1619
# Train: [0/2931 (0%)]	Loss: 0.203182
# Train: [1098/2931 (100%)]	Loss: 0.147334
# Epoch: 5/10. Train set: Average loss: 0.1475
# Epoch: 5/10. Validation set: Average loss: 0.1664
# Train: [0/2931 (0%)]	Loss: 0.198223
# Train: [1098/2931 (100%)]	Loss: 0.152559
# Epoch: 6/10. Train set: Average loss: 0.1527
# Epoch: 6/10. Validation set: Average loss: 0.1748
# Train: [0/2931 (0%)]	Loss: 0.163441
# Train: [1098/2931 (100%)]	Loss: 0.146161
# Epoch: 7/10. Train set: Average loss: 0.1462
# Epoch: 7/10. Validation set: Average loss: 0.1725
# Train: [0/2931 (0%)]	Loss: 0.224092
# Train: [1098/2931 (100%)]	Loss: 0.150111
# Epoch: 8/10. Train set: Average loss: 0.1503
# Epoch: 8/10. Validation set: Average loss: 0.1789
# Train: [0/2931 (0%)]	Loss: 0.135792
# Train: [1098/2931 (100%)]	Loss: 0.144244
# Epoch: 9/10. Train set: Average loss: 0.1442
# Epoch: 9/10. Validation set: Average loss: 0.1446
# Train: [0/2931 (0%)]	Loss: 0.175154
# Train: [1098/2931 (100%)]	Loss: 0.134720
# Epoch: 10/10. Train set: Average loss: 0.1348
# Epoch: 10/10. Validation set: Average loss: 0.1398
# Number features: 142
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187168
# Train: [1098/2931 (100%)]	Loss: 0.147691
# Epoch: 1/10. Train set: Average loss: 0.1478
# Epoch: 1/10. Validation set: Average loss: 0.1687
# Train: [0/2931 (0%)]	Loss: 0.244079
# Train: [1098/2931 (100%)]	Loss: 0.144579
# Epoch: 2/10. Train set: Average loss: 0.1448
# Epoch: 2/10. Validation set: Average loss: 0.1545
# Train: [0/2931 (0%)]	Loss: 0.158288
# Train: [1098/2931 (100%)]	Loss: 0.145971
# Epoch: 3/10. Train set: Average loss: 0.1460
# Epoch: 3/10. Validation set: Average loss: 0.1749
# Train: [0/2931 (0%)]	Loss: 0.132604
# Train: [1098/2931 (100%)]	Loss: 0.144292
# Epoch: 4/10. Train set: Average loss: 0.1443
# Epoch: 4/10. Validation set: Average loss: 0.1534
# Train: [0/2931 (0%)]	Loss: 0.125684
# Train: [1098/2931 (100%)]	Loss: 0.145325
# Epoch: 5/10. Train set: Average loss: 0.1453
# Epoch: 5/10. Validation set: Average loss: 0.1622
# Train: [0/2931 (0%)]	Loss: 0.204692
# Train: [1098/2931 (100%)]	Loss: 0.146168
# Epoch: 6/10. Train set: Average loss: 0.1463
# Epoch: 6/10. Validation set: Average loss: 0.1675
# Train: [0/2931 (0%)]	Loss: 0.171903
# Train: [1098/2931 (100%)]	Loss: 0.136245
# Epoch: 7/10. Train set: Average loss: 0.1363
# Epoch: 7/10. Validation set: Average loss: 0.1739
# Train: [0/2931 (0%)]	Loss: 0.139503
# Train: [1098/2931 (100%)]	Loss: 0.143156
# Epoch: 8/10. Train set: Average loss: 0.1431
# Epoch: 8/10. Validation set: Average loss: 0.1546
# Train: [0/2931 (0%)]	Loss: 0.201214
# Train: [1098/2931 (100%)]	Loss: 0.133415
# Epoch: 9/10. Train set: Average loss: 0.1336
# Epoch: 9/10. Validation set: Average loss: 0.1279
# Train: [0/2931 (0%)]	Loss: 0.181365
# Train: [1098/2931 (100%)]	Loss: 0.133608
# Epoch: 10/10. Train set: Average loss: 0.1337
# Epoch: 10/10. Validation set: Average loss: 0.1287
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.124820
# Train: [1098/2931 (100%)]	Loss: 0.143982
# Epoch: 1/10. Train set: Average loss: 0.1439
# Epoch: 1/10. Validation set: Average loss: 0.1650
# Train: [0/2931 (0%)]	Loss: 0.065917
# Train: [1098/2931 (100%)]	Loss: 0.149343
# Epoch: 2/10. Train set: Average loss: 0.1491
# Epoch: 2/10. Validation set: Average loss: 0.1746
# Train: [0/2931 (0%)]	Loss: 0.104978
# Train: [1098/2931 (100%)]	Loss: 0.145374
# Epoch: 3/10. Train set: Average loss: 0.1453
# Epoch: 3/10. Validation set: Average loss: 0.1644
# Train: [0/2931 (0%)]	Loss: 0.103637
# Train: [1098/2931 (100%)]	Loss: 0.143325
# Epoch: 4/10. Train set: Average loss: 0.1432
# Epoch: 4/10. Validation set: Average loss: 0.1551
# Train: [0/2931 (0%)]	Loss: 0.085179
# Train: [1098/2931 (100%)]	Loss: 0.146403
# Epoch: 5/10. Train set: Average loss: 0.1462
# Epoch: 5/10. Validation set: Average loss: 0.1511
# Train: [0/2931 (0%)]	Loss: 0.102338
# Train: [1098/2931 (100%)]	Loss: 0.144938
# Epoch: 6/10. Train set: Average loss: 0.1448
# Epoch: 6/10. Validation set: Average loss: 0.1674
# Train: [0/2931 (0%)]	Loss: 0.116283
# Train: [1098/2931 (100%)]	Loss: 0.134480
# Epoch: 7/10. Train set: Average loss: 0.1344
# Epoch: 7/10. Validation set: Average loss: 0.1702
# Train: [0/2931 (0%)]	Loss: 0.091182
# Train: [1098/2931 (100%)]	Loss: 0.144262
# Epoch: 8/10. Train set: Average loss: 0.1441
# Epoch: 8/10. Validation set: Average loss: 0.1678
# Train: [0/2931 (0%)]	Loss: 0.064124
# Train: [1098/2931 (100%)]	Loss: 0.135435
# Epoch: 9/10. Train set: Average loss: 0.1352
# Epoch: 9/10. Validation set: Average loss: 0.1373
# Train: [0/2931 (0%)]	Loss: 0.099051
# Train: [1098/2931 (100%)]	Loss: 0.134503
# Epoch: 10/10. Train set: Average loss: 0.1344
# Epoch: 10/10. Validation set: Average loss: 0.1360
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.186982
# Train: [1098/2931 (100%)]	Loss: 0.149590
# Epoch: 1/10. Train set: Average loss: 0.1497
# Epoch: 1/10. Validation set: Average loss: 0.1098
# Train: [0/2931 (0%)]	Loss: 0.217757
# Train: [1098/2931 (100%)]	Loss: 0.144099
# Epoch: 2/10. Train set: Average loss: 0.1443
# Epoch: 2/10. Validation set: Average loss: 0.1452
# Train: [0/2931 (0%)]	Loss: 0.155488
# Train: [1098/2931 (100%)]	Loss: 0.142729
# Epoch: 3/10. Train set: Average loss: 0.1428
# Epoch: 3/10. Validation set: Average loss: 0.1311
# Train: [0/2931 (0%)]	Loss: 0.106239
# Train: [1098/2931 (100%)]	Loss: 0.142337
# Epoch: 4/10. Train set: Average loss: 0.1422
# Epoch: 4/10. Validation set: Average loss: 0.1211
# Train: [0/2931 (0%)]	Loss: 0.170997
# Train: [1098/2931 (100%)]	Loss: 0.151953
# Epoch: 5/10. Train set: Average loss: 0.1520
# Epoch: 5/10. Validation set: Average loss: 0.1381
# Train: [0/2931 (0%)]	Loss: 0.169290
# Train: [1098/2931 (100%)]	Loss: 0.150925
# Epoch: 6/10. Train set: Average loss: 0.1510
# Epoch: 6/10. Validation set: Average loss: 0.1393
# Train: [0/2931 (0%)]	Loss: 0.129269
# Train: [1098/2931 (100%)]	Loss: 0.135827
# Epoch: 7/10. Train set: Average loss: 0.1358
# Epoch: 7/10. Validation set: Average loss: 0.1757
# Train: [0/2931 (0%)]	Loss: 0.134924
# Train: [1098/2931 (100%)]	Loss: 0.133177
# Epoch: 8/10. Train set: Average loss: 0.1332
# Epoch: 8/10. Validation set: Average loss: 0.1506
# Train: [0/2931 (0%)]	Loss: 0.127704
# Train: [1098/2931 (100%)]	Loss: 0.129870
# Epoch: 9/10. Train set: Average loss: 0.1299
# Epoch: 9/10. Validation set: Average loss: 0.1347
# Train: [0/2931 (0%)]	Loss: 0.111857
# Train: [1098/2931 (100%)]	Loss: 0.128200
# Epoch: 10/10. Train set: Average loss: 0.1282
# Epoch: 10/10. Validation set: Average loss: 0.1373
# Number features: 162
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187039
# Train: [1098/2931 (100%)]	Loss: 0.155795
# Epoch: 1/10. Train set: Average loss: 0.1559
# Epoch: 1/10. Validation set: Average loss: 0.1488
# Train: [0/2931 (0%)]	Loss: 0.132857
# Train: [1098/2931 (100%)]	Loss: 0.153853
# Epoch: 2/10. Train set: Average loss: 0.1538
# Epoch: 2/10. Validation set: Average loss: 0.1330
# Train: [0/2931 (0%)]	Loss: 0.157341
# Train: [1098/2931 (100%)]	Loss: 0.161363
# Epoch: 3/10. Train set: Average loss: 0.1614
# Epoch: 3/10. Validation set: Average loss: 0.1269
# Train: [0/2931 (0%)]	Loss: 0.060366
# Train: [1098/2931 (100%)]	Loss: 0.155134
# Epoch: 4/10. Train set: Average loss: 0.1549
# Epoch: 4/10. Validation set: Average loss: 0.1311
# Train: [0/2931 (0%)]	Loss: 0.197090
# Train: [1098/2931 (100%)]	Loss: 0.148416
# Epoch: 5/10. Train set: Average loss: 0.1485
# Epoch: 5/10. Validation set: Average loss: 0.1325
# Train: [0/2931 (0%)]	Loss: 0.141721
# Train: [1098/2931 (100%)]	Loss: 0.144971
# Epoch: 6/10. Train set: Average loss: 0.1450
# Epoch: 6/10. Validation set: Average loss: 0.1350
# Train: [0/2931 (0%)]	Loss: 0.156347
# Train: [1098/2931 (100%)]	Loss: 0.143658
# Epoch: 7/10. Train set: Average loss: 0.1437
# Epoch: 7/10. Validation set: Average loss: 0.1469
# Train: [0/2931 (0%)]	Loss: 0.108724
# Train: [1098/2931 (100%)]	Loss: 0.141606
# Epoch: 8/10. Train set: Average loss: 0.1415
# Epoch: 8/10. Validation set: Average loss: 0.1257
# Train: [0/2931 (0%)]	Loss: 0.102747
# Train: [1098/2931 (100%)]	Loss: 0.137290
# Epoch: 9/10. Train set: Average loss: 0.1372
# Epoch: 9/10. Validation set: Average loss: 0.1301
# Train: [0/2931 (0%)]	Loss: 0.150319
# Train: [1098/2931 (100%)]	Loss: 0.133226
# Epoch: 10/10. Train set: Average loss: 0.1333
# Epoch: 10/10. Validation set: Average loss: 0.1306
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.249208
# Train: [1098/2931 (100%)]	Loss: 0.161186
# Epoch: 1/10. Train set: Average loss: 0.1614
# Epoch: 1/10. Validation set: Average loss: 0.1040
# Train: [0/2931 (0%)]	Loss: 0.220045
# Train: [1098/2931 (100%)]	Loss: 0.162725
# Epoch: 2/10. Train set: Average loss: 0.1629
# Epoch: 2/10. Validation set: Average loss: 0.1414
# Train: [0/2931 (0%)]	Loss: 0.154101
# Train: [1098/2931 (100%)]	Loss: 0.158113
# Epoch: 3/10. Train set: Average loss: 0.1581
# Epoch: 3/10. Validation set: Average loss: 0.1398
# Train: [0/2931 (0%)]	Loss: 0.196047
# Train: [1098/2931 (100%)]	Loss: 0.152457
# Epoch: 4/10. Train set: Average loss: 0.1526
# Epoch: 4/10. Validation set: Average loss: 0.1069
# Train: [0/2931 (0%)]	Loss: 0.154792
# Train: [1098/2931 (100%)]	Loss: 0.157831
# Epoch: 5/10. Train set: Average loss: 0.1578
# Epoch: 5/10. Validation set: Average loss: 0.1273
# Train: [0/2931 (0%)]	Loss: 0.073009
# Train: [1098/2931 (100%)]	Loss: 0.147743
# Epoch: 6/10. Train set: Average loss: 0.1475
# Epoch: 6/10. Validation set: Average loss: 0.1591
# Train: [0/2931 (0%)]	Loss: 0.242044
# Train: [1098/2931 (100%)]	Loss: 0.150881
# Epoch: 7/10. Train set: Average loss: 0.1511
# Epoch: 7/10. Validation set: Average loss: 0.1273
# Train: [0/2931 (0%)]	Loss: 0.157186
# Train: [1098/2931 (100%)]	Loss: 0.141199
# Epoch: 8/10. Train set: Average loss: 0.1412
# Epoch: 8/10. Validation set: Average loss: 0.1551
# Train: [0/2931 (0%)]	Loss: 0.138753
# Train: [1098/2931 (100%)]	Loss: 0.140544
# Epoch: 9/10. Train set: Average loss: 0.1405
# Epoch: 9/10. Validation set: Average loss: 0.1263
# Train: [0/2931 (0%)]	Loss: 0.142530
# Train: [1098/2931 (100%)]	Loss: 0.134288
# Epoch: 10/10. Train set: Average loss: 0.1343
# Epoch: 10/10. Validation set: Average loss: 0.1261
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.311869
# Train: [1098/2931 (100%)]	Loss: 0.160354
# Epoch: 1/10. Train set: Average loss: 0.1608
# Epoch: 1/10. Validation set: Average loss: 0.1182
# Train: [0/2931 (0%)]	Loss: 0.195904
# Train: [1098/2931 (100%)]	Loss: 0.152280
# Epoch: 2/10. Train set: Average loss: 0.1524
# Epoch: 2/10. Validation set: Average loss: 0.1632
# Train: [0/2931 (0%)]	Loss: 0.150009
# Train: [1098/2931 (100%)]	Loss: 0.154727
# Epoch: 3/10. Train set: Average loss: 0.1547
# Epoch: 3/10. Validation set: Average loss: 0.1015
# Train: [0/2931 (0%)]	Loss: 0.306624
# Train: [1098/2931 (100%)]	Loss: 0.146063
# Epoch: 4/10. Train set: Average loss: 0.1465
# Epoch: 4/10. Validation set: Average loss: 0.1488
# Train: [0/2931 (0%)]	Loss: 0.064291
# Train: [1098/2931 (100%)]	Loss: 0.152657
# Epoch: 5/10. Train set: Average loss: 0.1524
# Epoch: 5/10. Validation set: Average loss: 0.1115
# Train: [0/2931 (0%)]	Loss: 0.151267
# Train: [1098/2931 (100%)]	Loss: 0.156013
# Epoch: 6/10. Train set: Average loss: 0.1560
# Epoch: 6/10. Validation set: Average loss: 0.2028
# Train: [0/2931 (0%)]	Loss: 0.255787
# Train: [1098/2931 (100%)]	Loss: 0.151941
# Epoch: 7/10. Train set: Average loss: 0.1522
# Epoch: 7/10. Validation set: Average loss: 0.1382
# Train: [0/2931 (0%)]	Loss: 0.180683
# Train: [1098/2931 (100%)]	Loss: 0.158602
# Epoch: 8/10. Train set: Average loss: 0.1587
# Epoch: 8/10. Validation set: Average loss: 0.1342
# Train: [0/2931 (0%)]	Loss: 0.219638
# Train: [1098/2931 (100%)]	Loss: 0.155050
# Epoch: 9/10. Train set: Average loss: 0.1552
# Epoch: 9/10. Validation set: Average loss: 0.1297
# Train: [0/2931 (0%)]	Loss: 0.120451
# Train: [1098/2931 (100%)]	Loss: 0.141440
# Epoch: 10/10. Train set: Average loss: 0.1414
# Epoch: 10/10. Validation set: Average loss: 0.1189
# Number features: 182
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.249111
# Train: [1098/2931 (100%)]	Loss: 0.181954
# Epoch: 1/10. Train set: Average loss: 0.1821
# Epoch: 1/10. Validation set: Average loss: 0.1833
# Train: [0/2931 (0%)]	Loss: 0.256790
# Train: [1098/2931 (100%)]	Loss: 0.159231
# Epoch: 2/10. Train set: Average loss: 0.1595
# Epoch: 2/10. Validation set: Average loss: 0.1379
# Train: [0/2931 (0%)]	Loss: 0.116563
# Train: [1098/2931 (100%)]	Loss: 0.149646
# Epoch: 3/10. Train set: Average loss: 0.1496
# Epoch: 3/10. Validation set: Average loss: 0.1621
# Train: [0/2931 (0%)]	Loss: 0.238632
# Train: [1098/2931 (100%)]	Loss: 0.148010
# Epoch: 4/10. Train set: Average loss: 0.1483
# Epoch: 4/10. Validation set: Average loss: 0.1396
# Train: [0/2931 (0%)]	Loss: 0.204025
# Train: [1098/2931 (100%)]	Loss: 0.146598
# Epoch: 5/10. Train set: Average loss: 0.1468
# Epoch: 5/10. Validation set: Average loss: 0.1512
# Train: [0/2931 (0%)]	Loss: 0.206766
# ...
# Epoch: 10/10. Validation set: Average loss: 0.1501
# Number features: 1071
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.186609
# Train: [1098/2931 (100%)]	Loss: 0.169294
# Epoch: 1/10. Train set: Average loss: 0.1693
# Epoch: 1/10. Validation set: Average loss: 0.1379
# Train: [0/2931 (0%)]	Loss: 0.406607
# Train: [1098/2931 (100%)]	Loss: 0.156101
# Epoch: 2/10. Train set: Average loss: 0.1568
# Epoch: 2/10. Validation set: Average loss: 0.1394
# Train: [0/2931 (0%)]	Loss: 0.137250
# Train: [1098/2931 (100%)]	Loss: 0.158165
# Epoch: 3/10. Train set: Average loss: 0.1581
# Epoch: 3/10. Validation set: Average loss: 0.1241
# Train: [0/2931 (0%)]	Loss: 0.174799
# Train: [1098/2931 (100%)]	Loss: 0.157610
# Epoch: 4/10. Train set: Average loss: 0.1577
# Epoch: 4/10. Validation set: Average loss: 0.1354
# Train: [0/2931 (0%)]	Loss: 0.105157
# Train: [1098/2931 (100%)]	Loss: 0.156478
# Epoch: 5/10. Train set: Average loss: 0.1563
# Epoch: 5/10. Validation set: Average loss: 0.1319
# Train: [0/2931 (0%)]	Loss: 0.102774
# Train: [1098/2931 (100%)]	Loss: 0.144722
# Epoch: 6/10. Train set: Average loss: 0.1446
# Epoch: 6/10. Validation set: Average loss: 0.1251
# Train: [0/2931 (0%)]	Loss: 0.124686
# Train: [1098/2931 (100%)]	Loss: 0.143601
# Epoch: 7/10. Train set: Average loss: 0.1435
# Epoch: 7/10. Validation set: Average loss: 0.1173
# Train: [0/2931 (0%)]	Loss: 0.106406
# Train: [1098/2931 (100%)]	Loss: 0.135764
# Epoch: 8/10. Train set: Average loss: 0.1357
# Epoch: 8/10. Validation set: Average loss: 0.1208
# Train: [0/2931 (0%)]	Loss: 0.121892
# Train: [1098/2931 (100%)]	Loss: 0.129127
# Epoch: 9/10. Train set: Average loss: 0.1291
# Epoch: 9/10. Validation set: Average loss: 0.1233
# Train: [0/2931 (0%)]	Loss: 0.190786
# Train: [1098/2931 (100%)]	Loss: 0.120982
# Epoch: 10/10. Train set: Average loss: 0.1212
# Epoch: 10/10. Validation set: Average loss: 0.1217
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.062463
# Train: [1098/2931 (100%)]	Loss: 0.170218
# Epoch: 1/10. Train set: Average loss: 0.1699
# Epoch: 1/10. Validation set: Average loss: 0.1697
# Train: [0/2931 (0%)]	Loss: 0.045290
# Train: [1098/2931 (100%)]	Loss: 0.169042
# Epoch: 2/10. Train set: Average loss: 0.1687
# Epoch: 2/10. Validation set: Average loss: 0.1418
# Train: [0/2931 (0%)]	Loss: 0.116508
# Train: [1098/2931 (100%)]	Loss: 0.166983
# Epoch: 3/10. Train set: Average loss: 0.1668
# Epoch: 3/10. Validation set: Average loss: 0.0997
# Train: [0/2931 (0%)]	Loss: 0.147258
# Train: [1098/2931 (100%)]	Loss: 0.170688
# Epoch: 4/10. Train set: Average loss: 0.1706
# Epoch: 4/10. Validation set: Average loss: 0.1157
# Train: [0/2931 (0%)]	Loss: 0.163074
# Train: [1098/2931 (100%)]	Loss: 0.160283
# Epoch: 5/10. Train set: Average loss: 0.1603
# Epoch: 5/10. Validation set: Average loss: 0.1331
# Train: [0/2931 (0%)]	Loss: 0.160800
# Train: [1098/2931 (100%)]	Loss: 0.163528
# Epoch: 6/10. Train set: Average loss: 0.1635
# Epoch: 6/10. Validation set: Average loss: 0.1334
# Train: [0/2931 (0%)]	Loss: 0.104842
# Train: [1098/2931 (100%)]	Loss: 0.144076
# Epoch: 7/10. Train set: Average loss: 0.1440
# Epoch: 7/10. Validation set: Average loss: 0.1358
# Train: [0/2931 (0%)]	Loss: 0.075715
# Train: [1098/2931 (100%)]	Loss: 0.142986
# Epoch: 8/10. Train set: Average loss: 0.1428
# Epoch: 8/10. Validation set: Average loss: 0.1295
# Train: [0/2931 (0%)]	Loss: 0.134116
# Train: [1098/2931 (100%)]	Loss: 0.137184
# Epoch: 9/10. Train set: Average loss: 0.1372
# Epoch: 9/10. Validation set: Average loss: 0.1141
# Train: [0/2931 (0%)]	Loss: 0.161334
# Train: [1098/2931 (100%)]	Loss: 0.131985
# Epoch: 10/10. Train set: Average loss: 0.1321
# Epoch: 10/10. Validation set: Average loss: 0.1123
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.311641
# Train: [1098/2931 (100%)]	Loss: 0.167167
# Epoch: 1/10. Train set: Average loss: 0.1676
# Epoch: 1/10. Validation set: Average loss: 0.1232
# Train: [0/2931 (0%)]	Loss: 0.170113
# Train: [1098/2931 (100%)]	Loss: 0.162503
# Epoch: 2/10. Train set: Average loss: 0.1625
# Epoch: 2/10. Validation set: Average loss: 0.1219
# Train: [0/2931 (0%)]	Loss: 0.199227
# Train: [1098/2931 (100%)]	Loss: 0.165903
# Epoch: 3/10. Train set: Average loss: 0.1660
# Epoch: 3/10. Validation set: Average loss: 0.1525
# Train: [0/2931 (0%)]	Loss: 0.131423
# Train: [1098/2931 (100%)]	Loss: 0.160460
# Epoch: 4/10. Train set: Average loss: 0.1604
# Epoch: 4/10. Validation set: Average loss: 0.1301
# Train: [0/2931 (0%)]	Loss: 0.110868
# Train: [1098/2931 (100%)]	Loss: 0.160161
# Epoch: 5/10. Train set: Average loss: 0.1600
# Epoch: 5/10. Validation set: Average loss: 0.1345
# Train: [0/2931 (0%)]	Loss: 0.111761
# Train: [1098/2931 (100%)]	Loss: 0.167060
# Epoch: 6/10. Train set: Average loss: 0.1669
# Epoch: 6/10. Validation set: Average loss: 0.1366
# Train: [0/2931 (0%)]	Loss: 0.226227
# Train: [1098/2931 (100%)]	Loss: 0.165297
# Epoch: 7/10. Train set: Average loss: 0.1655
# Epoch: 7/10. Validation set: Average loss: 0.1443
# Train: [0/2931 (0%)]	Loss: 0.115910
# Train: [1098/2931 (100%)]	Loss: 0.144243
# Epoch: 8/10. Train set: Average loss: 0.1442
# Epoch: 8/10. Validation set: Average loss: 0.1198
# Train: [0/2931 (0%)]	Loss: 0.100418
# Train: [1098/2931 (100%)]	Loss: 0.131505
# Epoch: 9/10. Train set: Average loss: 0.1314
# Epoch: 9/10. Validation set: Average loss: 0.1210
# Train: [0/2931 (0%)]	Loss: 0.139703
# Train: [1098/2931 (100%)]	Loss: 0.126400
# Epoch: 10/10. Train set: Average loss: 0.1264
# Epoch: 10/10. Validation set: Average loss: 0.1207
# Number features: 1091
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.312047
# Train: [1098/2931 (100%)]	Loss: 0.164279
# Epoch: 1/10. Train set: Average loss: 0.1647
# Epoch: 1/10. Validation set: Average loss: 0.1273
# Train: [0/2931 (0%)]	Loss: 0.134126
# Train: [1098/2931 (100%)]	Loss: 0.159745
# Epoch: 2/10. Train set: Average loss: 0.1597
# Epoch: 2/10. Validation set: Average loss: 0.1287
# Train: [0/2931 (0%)]	Loss: 0.131715
# Train: [1098/2931 (100%)]	Loss: 0.157999
# Epoch: 3/10. Train set: Average loss: 0.1579
# Epoch: 3/10. Validation set: Average loss: 0.1794
# Train: [0/2931 (0%)]	Loss: 0.141253
# Train: [1098/2931 (100%)]	Loss: 0.148593
# Epoch: 4/10. Train set: Average loss: 0.1486
# Epoch: 4/10. Validation set: Average loss: 0.1299
# Train: [0/2931 (0%)]	Loss: 0.233070
# Train: [1098/2931 (100%)]	Loss: 0.156789
# Epoch: 5/10. Train set: Average loss: 0.1570
# Epoch: 5/10. Validation set: Average loss: 0.1411
# Train: [0/2931 (0%)]	Loss: 0.216496
# Train: [1098/2931 (100%)]	Loss: 0.152747
# Epoch: 6/10. Train set: Average loss: 0.1529
# Epoch: 6/10. Validation set: Average loss: 0.1274
# Train: [0/2931 (0%)]	Loss: 0.115137
# Train: [1098/2931 (100%)]	Loss: 0.148072
# Epoch: 7/10. Train set: Average loss: 0.1480
# Epoch: 7/10. Validation set: Average loss: 0.1112
# Train: [0/2931 (0%)]	Loss: 0.120071
# Train: [1098/2931 (100%)]	Loss: 0.146857
# Epoch: 8/10. Train set: Average loss: 0.1468
# Epoch: 8/10. Validation set: Average loss: 0.1447
# Train: [0/2931 (0%)]	Loss: 0.263266
# Train: [1098/2931 (100%)]	Loss: 0.138465
# Epoch: 9/10. Train set: Average loss: 0.1388
# Epoch: 9/10. Validation set: Average loss: 0.1360
# Train: [0/2931 (0%)]	Loss: 0.158796
# Train: [1098/2931 (100%)]	Loss: 0.128560
# Epoch: 10/10. Train set: Average loss: 0.1286
# Epoch: 10/10. Validation set: Average loss: 0.1373
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.311186
# Train: [1098/2931 (100%)]	Loss: 0.165383
# Epoch: 1/10. Train set: Average loss: 0.1658
# Epoch: 1/10. Validation set: Average loss: 0.1459
# Train: [0/2931 (0%)]	Loss: 0.199515
# Train: [1098/2931 (100%)]	Loss: 0.169497
# Epoch: 2/10. Train set: Average loss: 0.1696
# Epoch: 2/10. Validation set: Average loss: 0.1515
# Train: [0/2931 (0%)]	Loss: 0.219457
# Train: [1098/2931 (100%)]	Loss: 0.165486
# Epoch: 3/10. Train set: Average loss: 0.1656
# Epoch: 3/10. Validation set: Average loss: 0.1279
# Train: [0/2931 (0%)]	Loss: 0.204538
# Train: [1098/2931 (100%)]	Loss: 0.147891
# Epoch: 4/10. Train set: Average loss: 0.1480
# Epoch: 4/10. Validation set: Average loss: 0.1083
# Train: [0/2931 (0%)]	Loss: 0.172541
# Train: [1098/2931 (100%)]	Loss: 0.150615
# Epoch: 5/10. Train set: Average loss: 0.1507
# Epoch: 5/10. Validation set: Average loss: 0.1265
# Train: [0/2931 (0%)]	Loss: 0.183790
# Train: [1098/2931 (100%)]	Loss: 0.146526
# Epoch: 6/10. Train set: Average loss: 0.1466
# Epoch: 6/10. Validation set: Average loss: 0.1154
# Train: [0/2931 (0%)]	Loss: 0.200996
# Train: [1098/2931 (100%)]	Loss: 0.142152
# Epoch: 7/10. Train set: Average loss: 0.1423
# Epoch: 7/10. Validation set: Average loss: 0.1223
# Train: [0/2931 (0%)]	Loss: 0.187783
# Train: [1098/2931 (100%)]	Loss: 0.139081
# Epoch: 8/10. Train set: Average loss: 0.1392
# Epoch: 8/10. Validation set: Average loss: 0.1294
# Train: [0/2931 (0%)]	Loss: 0.167043
# Train: [1098/2931 (100%)]	Loss: 0.130517
# Epoch: 9/10. Train set: Average loss: 0.1306
# Epoch: 9/10. Validation set: Average loss: 0.1342
# Train: [0/2931 (0%)]	Loss: 0.152213
# Train: [1098/2931 (100%)]	Loss: 0.127523
# Epoch: 10/10. Train set: Average loss: 0.1276
# Epoch: 10/10. Validation set: Average loss: 0.1324
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.311035
# Train: [1098/2931 (100%)]	Loss: 0.170532
# Epoch: 1/10. Train set: Average loss: 0.1709
# Epoch: 1/10. Validation set: Average loss: 0.1149
# Train: [0/2931 (0%)]	Loss: 0.116119
# Train: [1098/2931 (100%)]	Loss: 0.168704
# Epoch: 2/10. Train set: Average loss: 0.1686
# Epoch: 2/10. Validation set: Average loss: 0.1217
# Train: [0/2931 (0%)]	Loss: 0.276957
# Train: [1098/2931 (100%)]	Loss: 0.159717
# Epoch: 3/10. Train set: Average loss: 0.1600
# Epoch: 3/10. Validation set: Average loss: 0.1382
# Train: [0/2931 (0%)]	Loss: 0.179059
# Train: [1098/2931 (100%)]	Loss: 0.163043
# Epoch: 4/10. Train set: Average loss: 0.1631
# Epoch: 4/10. Validation set: Average loss: 0.1251
# Train: [0/2931 (0%)]	Loss: 0.116418
# Train: [1098/2931 (100%)]	Loss: 0.162959
# Epoch: 5/10. Train set: Average loss: 0.1628
# Epoch: 5/10. Validation set: Average loss: 0.1276
# Train: [0/2931 (0%)]	Loss: 0.132564
# Train: [1098/2931 (100%)]	Loss: 0.160184
# Epoch: 6/10. Train set: Average loss: 0.1601
# Epoch: 6/10. Validation set: Average loss: 0.1221
# Train: [0/2931 (0%)]	Loss: 0.156870
# Train: [1098/2931 (100%)]	Loss: 0.145957
# Epoch: 7/10. Train set: Average loss: 0.1460
# Epoch: 7/10. Validation set: Average loss: 0.1320
# Train: [0/2931 (0%)]	Loss: 0.128509
# Train: [1098/2931 (100%)]	Loss: 0.147180
# Epoch: 8/10. Train set: Average loss: 0.1471
# Epoch: 8/10. Validation set: Average loss: 0.1280
# Train: [0/2931 (0%)]	Loss: 0.195547
# Train: [1098/2931 (100%)]	Loss: 0.139099
# Epoch: 9/10. Train set: Average loss: 0.1393
# Epoch: 9/10. Validation set: Average loss: 0.1285
# Train: [0/2931 (0%)]	Loss: 0.151962
# Train: [1098/2931 (100%)]	Loss: 0.132786
# Epoch: 10/10. Train set: Average loss: 0.1328
# Epoch: 10/10. Validation set: Average loss: 0.1311
# Number features: 1111
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.187241
# Train: [1098/2931 (100%)]	Loss: 0.159644
# Epoch: 1/10. Train set: Average loss: 0.1597
# Epoch: 1/10. Validation set: Average loss: 0.1180
# Train: [0/2931 (0%)]	Loss: 0.123479
# Train: [1098/2931 (100%)]	Loss: 0.162348
# Epoch: 2/10. Train set: Average loss: 0.1622
# Epoch: 2/10. Validation set: Average loss: 0.1648
# Train: [0/2931 (0%)]	Loss: 0.087010
# Train: [1098/2931 (100%)]	Loss: 0.161205
# Epoch: 3/10. Train set: Average loss: 0.1610
# Epoch: 3/10. Validation set: Average loss: 0.1395
# Train: [0/2931 (0%)]	Loss: 0.093879
# Train: [1098/2931 (100%)]	Loss: 0.149761
# Epoch: 4/10. Train set: Average loss: 0.1496
# Epoch: 4/10. Validation set: Average loss: 0.1723
# Train: [0/2931 (0%)]	Loss: 0.128352
# Train: [1098/2931 (100%)]	Loss: 0.143351
# Epoch: 5/10. Train set: Average loss: 0.1433
# Epoch: 5/10. Validation set: Average loss: 0.1482
# Train: [0/2931 (0%)]	Loss: 0.149090
# Train: [1098/2931 (100%)]	Loss: 0.142715
# Epoch: 6/10. Train set: Average loss: 0.1427
# Epoch: 6/10. Validation set: Average loss: 0.1744
# Train: [0/2931 (0%)]	Loss: 0.069483
# Train: [1098/2931 (100%)]	Loss: 0.136305
# Epoch: 7/10. Train set: Average loss: 0.1361
# Epoch: 7/10. Validation set: Average loss: 0.1364
# Train: [0/2931 (0%)]	Loss: 0.081422
# Train: [1098/2931 (100%)]	Loss: 0.130976
# Epoch: 8/10. Train set: Average loss: 0.1308
# Epoch: 8/10. Validation set: Average loss: 0.1605
# Train: [0/2931 (0%)]	Loss: 0.102901
# Train: [1098/2931 (100%)]	Loss: 0.121030
# Epoch: 9/10. Train set: Average loss: 0.1210
# Epoch: 9/10. Validation set: Average loss: 0.1367
# Train: [0/2931 (0%)]	Loss: 0.100642
# Train: [1098/2931 (100%)]	Loss: 0.122863
# Epoch: 10/10. Train set: Average loss: 0.1228
# Epoch: 10/10. Validation set: Average loss: 0.1424
# 	model_1
# Train: [0/2931 (0%)]	Loss: 0.436517
# Train: [1098/2931 (100%)]	Loss: 0.163104
# Epoch: 1/10. Train set: Average loss: 0.1638
# Epoch: 1/10. Validation set: Average loss: 0.1405
# Train: [0/2931 (0%)]	Loss: 0.123759
# Train: [1098/2931 (100%)]	Loss: 0.161911
# Epoch: 2/10. Train set: Average loss: 0.1618
# Epoch: 2/10. Validation set: Average loss: 0.1329
# Train: [0/2931 (0%)]	Loss: 0.152272
# Train: [1098/2931 (100%)]	Loss: 0.144535
# Epoch: 3/10. Train set: Average loss: 0.1446
# Epoch: 3/10. Validation set: Average loss: 0.1312
# Train: [0/2931 (0%)]	Loss: 0.210430
# Train: [1098/2931 (100%)]	Loss: 0.153289
# Epoch: 4/10. Train set: Average loss: 0.1534
# Epoch: 4/10. Validation set: Average loss: 0.1538
# Train: [0/2931 (0%)]	Loss: 0.176505
# Train: [1098/2931 (100%)]	Loss: 0.171160
# Epoch: 5/10. Train set: Average loss: 0.1712
# Epoch: 5/10. Validation set: Average loss: 0.1467
# Train: [0/2931 (0%)]	Loss: 0.308932
# Train: [1098/2931 (100%)]	Loss: 0.155195
# Epoch: 6/10. Train set: Average loss: 0.1556
# Epoch: 6/10. Validation set: Average loss: 0.1230
# Train: [0/2931 (0%)]	Loss: 0.172062
# Train: [1098/2931 (100%)]	Loss: 0.144310
# Epoch: 7/10. Train set: Average loss: 0.1444
# Epoch: 7/10. Validation set: Average loss: 0.1430
# Train: [0/2931 (0%)]	Loss: 0.265979
# Train: [1098/2931 (100%)]	Loss: 0.141111
# Epoch: 8/10. Train set: Average loss: 0.1415
# Epoch: 8/10. Validation set: Average loss: 0.1287
# Train: [0/2931 (0%)]	Loss: 0.161041
# Train: [1098/2931 (100%)]	Loss: 0.132753
# Epoch: 9/10. Train set: Average loss: 0.1328
# Epoch: 9/10. Validation set: Average loss: 0.1403
# Train: [0/2931 (0%)]	Loss: 0.209124
# Train: [1098/2931 (100%)]	Loss: 0.128851
# Epoch: 10/10. Train set: Average loss: 0.1291
# Epoch: 10/10. Validation set: Average loss: 0.1416
# 	model_2
# Train: [0/2931 (0%)]	Loss: 0.311682
# Train: [1098/2931 (100%)]	Loss: 0.160829
# Epoch: 1/10. Train set: Average loss: 0.1612
# Epoch: 1/10. Validation set: Average loss: 0.1248
# Train: [0/2931 (0%)]	Loss: 0.255223
# Train: [1098/2931 (100%)]	Loss: 0.155670
# Epoch: 2/10. Train set: Average loss: 0.1559
# Epoch: 2/10. Validation set: Average loss: 0.1293
# Train: [0/2931 (0%)]	Loss: 0.121697
# Train: [1098/2931 (100%)]	Loss: 0.159249
# Epoch: 3/10. Train set: Average loss: 0.1591
# Epoch: 3/10. Validation set: Average loss: 0.1523
# Train: [0/2931 (0%)]	Loss: 0.258121
# Train: [1098/2931 (100%)]	Loss: 0.152555
# Epoch: 4/10. Train set: Average loss: 0.1528
# Epoch: 4/10. Validation set: Average loss: 0.1158
# Train: [0/2931 (0%)]	Loss: 0.156679
# Train: [1098/2931 (100%)]	Loss: 0.143396
# Epoch: 5/10. Train set: Average loss: 0.1434
# Epoch: 5/10. Validation set: Average loss: 0.1237
# Train: [0/2931 (0%)]	Loss: 0.122793
# Train: [1098/2931 (100%)]	Loss: 0.149319
# Epoch: 6/10. Train set: Average loss: 0.1492
# Epoch: 6/10. Validation set: Average loss: 0.1640
# Train: [0/2931 (0%)]	Loss: 0.190084
# Train: [1098/2931 (100%)]	Loss: 0.137142
# Epoch: 7/10. Train set: Average loss: 0.1373
# Epoch: 7/10. Validation set: Average loss: 0.1272
# Train: [0/2931 (0%)]	Loss: 0.168646
# Train: [1098/2931 (100%)]	Loss: 0.134011
# Epoch: 8/10. Train set: Average loss: 0.1341
# Epoch: 8/10. Validation set: Average loss: 0.1346
# Train: [0/2931 (0%)]	Loss: 0.222088
# Train: [1098/2931 (100%)]	Loss: 0.127868
# Epoch: 9/10. Train set: Average loss: 0.1281
# Epoch: 9/10. Validation set: Average loss: 0.1305
# Train: [0/2931 (0%)]	Loss: 0.064649
# Train: [1098/2931 (100%)]	Loss: 0.122582
# Epoch: 10/10. Train set: Average loss: 0.1224
# Epoch: 10/10. Validation set: Average loss: 0.1331
# Number features: 1131
#
# 	model_0
# Train: [0/2931 (0%)]	Loss: 0.249412
# Train: [1098/2931 (100%)]	Loss: 0.157963
# Epoch: 1/10. Train set: Average loss: 0.1582
# Epoch: 1/10. Validation set: Average loss: 0.1138
# Train: [0/2931 (0%)]	Loss: 0.205409
# Train: [1098/2931 (100%)]	Loss: 0.155016
