# %%
import numpy as np
import pandas as pd
np.random.seed(123)

# viz
import matplotlib.pyplot as plt

# notebook settings
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.set_option('display.max_columns', 1000)

# %% [markdown]
# ## Sample Prep

# %%
samples = pd.read_csv('../data/TCGA/rna-seq_pan/meta/gdc_sample_sheet.2019-12-12.tsv', sep="\t")
# get file type
samples['data'] = [val[1] for i,val in samples['File Name'].str.split(".").items()]
samples['project'] = [val[1] for i,val in samples['Project ID'].str.split("-").items()]
samples['project'].value_counts()
# Out:
# BRCA    1206
# LUAD     588
# UCEC     567
# KIRC     554
# LUSC     543
# LGG      524
# PRAD     517
# COAD     506
# THCA     505
# SKCM     469
# BLCA     431
# LIHC     421
# STAD     402
# OV       379
# KIRP     308
# CESC     306
# ESCA     171
# PAAD     171
# GBM      166
# TGCT     150
# PCPG     133
# LAML     123
# KICH      81
# ACC       75
# CHOL      41
# SARC      10
# DLBC       9
# READ       7
# MESO       1
# Name: project, dtype: int64

# %%
foo = pd.read_csv('../data/TCGA/pilot_LUAD/gdc_sample_sheet.2019-12-09.tsv', sep="\t")
foo.head()
# Out:
#                                 File ID  \
# 0  c5b283b8-a6ab-4652-b824-18fe1cebe0e3
# 1  27079945-f3da-42b4-8c17-c82d66b7d321
# 2  da368838-dad0-434d-a2a8-084b362e358e
# 3  be46ee72-8958-483f-bd54-38d21ebf7ff6
# 4  c5f764bd-a9d4-4188-a4dc-a5e6ca1183f8
#
#                                            File Name            Data Category  \
# 0   0bf53fc6-b8fb-4e6d-9297-4129c708f3da.FPKM.txt.gz  Transcriptome Profiling
# 1  f4a1e772-2a5e-4c0a-803a-1bdb2b376a47.FPKM-UQ.t...  Transcriptome Profiling
# 2   12d2b9fa-1921-4033-bdb9-7e114c0d7812.FPKM.txt.gz  Transcriptome Profiling
# 3   4d36e127-5fad-4b97-afff-28f4bdbf5f5d.FPKM.txt.gz  Transcriptome Profiling
# 4  c57c5f57-5426-4662-832d-6f342ebeff04.FPKM-UQ.t...  Transcriptome Profiling
#
#                         Data Type Project ID       Case ID         Sample ID  \
# 0  Gene Expression Quantification  TCGA-LUAD  TCGA-50-5935  TCGA-50-5935-01A
# 1  Gene Expression Quantification  TCGA-LUAD  TCGA-55-6971  TCGA-55-6971-11A
# 2  Gene Expression Quantification  TCGA-LUAD  TCGA-99-8025  TCGA-99-8025-01A
# 3  Gene Expression Quantification  TCGA-LUAD  TCGA-55-8301  TCGA-55-8301-01A
# 4  Gene Expression Quantification  TCGA-LUAD  TCGA-73-4677  TCGA-73-4677-01A
#
#            Sample Type
# 0        Primary Tumor
# 1  Solid Tissue Normal
# 2        Primary Tumor
# 3        Primary Tumor
# 4        Primary Tumor

# %%
foo['Sample Type'].value_counts()
# Out:
# Primary Tumor          1599
# Solid Tissue Normal     177
# Recurrent Tumor           6
# Name: Sample Type, dtype: int64

# %%
samples.shape
cases = samples[samples['Sample Type']=='Primary Tumor'].sample(frac=1).copy()
cases.shape
proj = cases['project'].value_counts().head(10).index
cases = cases[cases['project'].isin(proj)]
cases['project'].value_counts()
cases.shape
# Out:
# (9364, 10)
# (8166, 10)
# BRCA    1087
# UCEC     544
# LUAD     528
# LGG      506
# LUSC     496
# KIRC     483
# PRAD     466
# COAD     465
# THCA     445
# BLCA     412
# Name: project, dtype: int64
# (5432, 10)

# %% [markdown]
# ## Dataset Prep

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

target = 'project'
cases[target] = cases[target].astype('category')

train, test = train_test_split(cases)
train[target].value_counts()
test[target].value_counts()
# Out:
# BRCA    820
# UCEC    407
# LUAD    400
# LUSC    381
# LGG     378
# KIRC    356
# COAD    355
# PRAD    353
# THCA    332
# BLCA    292
# Name: project, dtype: int64
# BRCA    267
# UCEC    137
# LUAD    128
# LGG     128
# KIRC    127
# BLCA    120
# LUSC    115
# THCA    113
# PRAD    113
# COAD    110
# Name: project, dtype: int64

# %%
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable
torch.manual_seed(123)

from trainer import fit
import visualization as vis
import numpy as np
cuda = torch.cuda.is_available()
print("Cuda is available: {}".format(cuda))

classes = {key:val for val,key in enumerate(train[target].cat.categories.values)}
classes
# Out:
# Cuda is available: True
# {'BLCA': 0,
#  'BRCA': 1,
#  'COAD': 2,
#  'KIRC': 3,
#  'LGG': 4,
#  'LUAD': 5,
#  'LUSC': 6,
#  'PRAD': 7,
#  'THCA': 8,
#  'UCEC': 9}

# %%
from tcga_datasets import TCGA, SiameseTCGA
root_dir = "../data/TCGA/rna-seq_pan/"
batch_size = 1

train_dataset = TCGA(root_dir, samples=train, train=True, target=target, norm=False)
test_dataset = TCGA(root_dir, samples=test, train=False, target=target, norm=False)

scaler = StandardScaler()
train_dataset.data = pd.DataFrame(scaler.fit_transform(train_dataset.data),
                                  index=train_dataset.data.index,
                                  columns=train_dataset.data.columns)
test_dataset.data = pd.DataFrame(scaler.transform(test_dataset.data),
                                 index=test_dataset.data.index,
                                 columns=test_dataset.data.columns)

kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {'num_workers': 10}
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, **kwargs)

# %% [markdown]
# ## Siamese Network

# %%
# Step 1 set up dataloader
root_dir = "../data/TCGA"
siamese_train_dataset = SiameseTCGA(train_dataset) # Returns pairs of images and target same/different
siamese_test_dataset = SiameseTCGA(test_dataset)
batch_size = 64
kwargs = {'num_workers': 10, 'pin_memory': True} if cuda else {}
siamese_train_loader = torch.utils.data.DataLoader(siamese_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
siamese_test_loader = torch.utils.data.DataLoader(siamese_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)

# Set up the network and training parameters
from tcga_networks import EmbeddingNet, SiameseNet
from losses import ContrastiveLoss
from metrics import AccumulatedAccuracyMetric

# Step 2
embedding_net = EmbeddingNet()
# Step 3
model = SiameseNet(embedding_net)
if cuda:
    model.cuda()
    
# Step 4
margin = 1.
loss_fn = ContrastiveLoss(margin)
lr = 1e-3
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 20
# print training metrics every log_interval * batch_size
log_interval = 5
# Out:
# SiameseNet(
#   (embedding_net): EmbeddingNet(
#     (fc): Sequential(
#       (linear1): Linear(in_features=60483, out_features=2000, bias=True)
#       (relu1): PReLU(num_parameters=1)
#       (linear2): Linear(in_features=2000, out_features=500, bias=True)
#       (relu2): PReLU(num_parameters=1)
#       (linear3): Linear(in_features=500, out_features=250, bias=True)
#       (relu3): PReLU(num_parameters=1)
#       (linear4): Linear(in_features=250, out_features=100, bias=True)
#       (relu4): PReLU(num_parameters=1)
#       (linear5): Linear(in_features=100, out_features=50, bias=True)
#       (relu5): PReLU(num_parameters=1)
#       (linear6): Linear(in_features=50, out_features=10, bias=True)
#       (relu6): PReLU(num_parameters=1)
#       (linear7): Linear(in_features=10, out_features=2, bias=True)
#     )
#   )
# )

# %%
train_loss, val_loss = fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, 
    n_epochs, cuda, log_interval)
# Out:
# Train: [0/4074 (0%)]	Loss: 0.248647
# Train: [320/4074 (8%)]	Loss: 0.310211
# Train: [640/4074 (16%)]	Loss: 0.124154
# Train: [960/4074 (23%)]	Loss: 0.075968
# Train: [1280/4074 (31%)]	Loss: 1.051746
# Train: [1600/4074 (39%)]	Loss: 0.180839
# Train: [1920/4074 (47%)]	Loss: 0.111274
# Train: [2240/4074 (55%)]	Loss: 0.252777
# Train: [2560/4074 (62%)]	Loss: 0.136673
# Train: [2880/4074 (70%)]	Loss: 0.585527
# Train: [3200/4074 (78%)]	Loss: 1.609950
# Train: [3520/4074 (86%)]	Loss: 9.314102
# Train: [3840/4074 (94%)]	Loss: 0.474410
# Epoch: 1/20. Train set: Average loss: 1.1210
# Epoch: 1/20. Validation set: Average loss: 0.2606
# Train: [0/4074 (0%)]	Loss: 0.132143
# Train: [320/4074 (8%)]	Loss: 0.206611
# Train: [640/4074 (16%)]	Loss: 1.958800
# Train: [960/4074 (23%)]	Loss: 2.033570
# Train: [1280/4074 (31%)]	Loss: 0.376870
# Train: [1600/4074 (39%)]	Loss: 0.935826
# Train: [1920/4074 (47%)]	Loss: 0.256294
# Train: [2240/4074 (55%)]	Loss: 1.929032
# Train: [2560/4074 (62%)]	Loss: 0.913257
# Train: [2880/4074 (70%)]	Loss: 0.221431
# Train: [3200/4074 (78%)]	Loss: 0.197957
# Train: [3520/4074 (86%)]	Loss: 0.338138
# Train: [3840/4074 (94%)]	Loss: 0.334455
# Epoch: 2/20. Train set: Average loss: 0.7635
# Epoch: 2/20. Validation set: Average loss: 0.2939
# Train: [0/4074 (0%)]	Loss: 0.338424
# Train: [320/4074 (8%)]	Loss: 0.075534
# Train: [640/4074 (16%)]	Loss: 0.132925
# Train: [960/4074 (23%)]	Loss: 1.621119
# Train: [1280/4074 (31%)]	Loss: 0.722417
# Train: [1600/4074 (39%)]	Loss: 3.484344
# Train: [1920/4074 (47%)]	Loss: 6.360743
# Train: [2240/4074 (55%)]	Loss: 0.469589
# Train: [2560/4074 (62%)]	Loss: 9.892129
# Train: [2880/4074 (70%)]	Loss: 0.453305
# Train: [3200/4074 (78%)]	Loss: 1.465860
# Train: [3520/4074 (86%)]	Loss: 4.249059
# Train: [3840/4074 (94%)]	Loss: 0.767890
# Epoch: 3/20. Train set: Average loss: 2.3307
# Epoch: 3/20. Validation set: Average loss: 0.4080
# Train: [0/4074 (0%)]	Loss: 0.513316
# Train: [320/4074 (8%)]	Loss: 2.587975
# Train: [640/4074 (16%)]	Loss: 0.604056
# Train: [960/4074 (23%)]	Loss: 0.174021
# Train: [1280/4074 (31%)]	Loss: 0.490666
# Train: [1600/4074 (39%)]	Loss: 0.132776
# Train: [1920/4074 (47%)]	Loss: 0.267161
# Train: [2240/4074 (55%)]	Loss: 0.201783
# Train: [2560/4074 (62%)]	Loss: 0.061162
# Train: [2880/4074 (70%)]	Loss: 0.072228
# Train: [3200/4074 (78%)]	Loss: 0.087727
# Train: [3520/4074 (86%)]	Loss: 0.080220
# Train: [3840/4074 (94%)]	Loss: 0.066697
# Epoch: 4/20. Train set: Average loss: 0.3917
# Epoch: 4/20. Validation set: Average loss: 0.0727
# Train: [0/4074 (0%)]	Loss: 0.056407
# Train: [320/4074 (8%)]	Loss: 0.051977
# Train: [640/4074 (16%)]	Loss: 0.051895
# Train: [960/4074 (23%)]	Loss: 0.064834
# Train: [1280/4074 (31%)]	Loss: 0.052498
# Train: [1600/4074 (39%)]	Loss: 0.069850
# Train: [1920/4074 (47%)]	Loss: 0.053215
# Train: [2240/4074 (55%)]	Loss: 0.064681
# Train: [2560/4074 (62%)]	Loss: 0.050059
# Train: [2880/4074 (70%)]	Loss: 0.046132
# Train: [3200/4074 (78%)]	Loss: 0.056331
# Train: [3520/4074 (86%)]	Loss: 0.076434
# Train: [3840/4074 (94%)]	Loss: 0.046329
# Epoch: 5/20. Train set: Average loss: 0.0562
# Epoch: 5/20. Validation set: Average loss: 0.0526
# Train: [0/4074 (0%)]	Loss: 0.047410
# Train: [320/4074 (8%)]	Loss: 0.044047
# Train: [640/4074 (16%)]	Loss: 0.050290
# Train: [960/4074 (23%)]	Loss: 0.031330
# Train: [1280/4074 (31%)]	Loss: 0.087339
# Train: [1600/4074 (39%)]	Loss: 0.075704
# Train: [1920/4074 (47%)]	Loss: 0.052347
# Train: [2240/4074 (55%)]	Loss: 0.081647
# Train: [2560/4074 (62%)]	Loss: 0.125330
# Train: [2880/4074 (70%)]	Loss: 0.073931
# Train: [3200/4074 (78%)]	Loss: 0.041330
# Train: [3520/4074 (86%)]	Loss: 0.036620
# Train: [3840/4074 (94%)]	Loss: 0.032992
# Epoch: 6/20. Train set: Average loss: 0.0594
# Epoch: 6/20. Validation set: Average loss: 0.0790
# Train: [0/4074 (0%)]	Loss: 0.029935
# Train: [320/4074 (8%)]	Loss: 0.070245
# Train: [640/4074 (16%)]	Loss: 0.033923
# Train: [960/4074 (23%)]	Loss: 0.034612
# Train: [1280/4074 (31%)]	Loss: 0.087806
# Train: [1600/4074 (39%)]	Loss: 0.037056
# Train: [1920/4074 (47%)]	Loss: 0.067233
# Train: [2240/4074 (55%)]	Loss: 0.042784
# Train: [2560/4074 (62%)]	Loss: 0.031046
# Train: [2880/4074 (70%)]	Loss: 0.029192
# Train: [3200/4074 (78%)]	Loss: 0.027878
# Train: [3520/4074 (86%)]	Loss: 0.045601
# Train: [3840/4074 (94%)]	Loss: 0.027402
# Epoch: 7/20. Train set: Average loss: 0.0437
# Epoch: 7/20. Validation set: Average loss: 0.0435
# Train: [0/4074 (0%)]	Loss: 0.027490
# Train: [320/4074 (8%)]	Loss: 0.029816
# Train: [640/4074 (16%)]	Loss: 0.032177
# Train: [960/4074 (23%)]	Loss: 0.651093
# Train: [1280/4074 (31%)]	Loss: 1.095724
# Train: [1600/4074 (39%)]	Loss: 0.251314
# Train: [1920/4074 (47%)]	Loss: 0.180882
# Train: [2240/4074 (55%)]	Loss: 0.086134
# Train: [2560/4074 (62%)]	Loss: 0.122355
# Train: [2880/4074 (70%)]	Loss: 0.060997
# Train: [3200/4074 (78%)]	Loss: 0.063726
# Train: [3520/4074 (86%)]	Loss: 0.042630
# Train: [3840/4074 (94%)]	Loss: 0.040551
# Epoch: 8/20. Train set: Average loss: 0.2102
# Epoch: 8/20. Validation set: Average loss: 0.0543
# Train: [0/4074 (0%)]	Loss: 0.043593
# Train: [320/4074 (8%)]	Loss: 0.031982
# Train: [640/4074 (16%)]	Loss: 0.090147
# Train: [960/4074 (23%)]	Loss: 0.040313
# Train: [1280/4074 (31%)]	Loss: 0.057116
# Train: [1600/4074 (39%)]	Loss: 0.195266
# Train: [1920/4074 (47%)]	Loss: 0.049324
# Train: [2240/4074 (55%)]	Loss: 0.034154
# Train: [2560/4074 (62%)]	Loss: 0.049469
# Train: [2880/4074 (70%)]	Loss: 0.041415
# Train: [3200/4074 (78%)]	Loss: 0.035377
# Train: [3520/4074 (86%)]	Loss: 0.040383
# Train: [3840/4074 (94%)]	Loss: 0.030215
# Epoch: 9/20. Train set: Average loss: 0.0570
# Epoch: 9/20. Validation set: Average loss: 0.0506
# Train: [0/4074 (0%)]	Loss: 3.968802
# Train: [320/4074 (8%)]	Loss: 0.047244
# Train: [640/4074 (16%)]	Loss: 0.044559
# Train: [960/4074 (23%)]	Loss: 0.225614
# Train: [1280/4074 (31%)]	Loss: 0.037341
# Train: [1600/4074 (39%)]	Loss: 0.051451
# Train: [1920/4074 (47%)]	Loss: 0.069221
# Train: [2240/4074 (55%)]	Loss: 0.041409
# Train: [2560/4074 (62%)]	Loss: 0.088500
# Train: [2880/4074 (70%)]	Loss: 0.038163
# Train: [3200/4074 (78%)]	Loss: 0.035864
# Train: [3520/4074 (86%)]	Loss: 0.039287
# Train: [3840/4074 (94%)]	Loss: 0.084068
# Epoch: 10/20. Train set: Average loss: 0.1264
# Epoch: 10/20. Validation set: Average loss: 0.0581
# Train: [0/4074 (0%)]	Loss: 0.026409
# Train: [320/4074 (8%)]	Loss: 0.034674
# Train: [640/4074 (16%)]	Loss: 0.042840
# Train: [960/4074 (23%)]	Loss: 0.051953
# Train: [1280/4074 (31%)]	Loss: 0.059469
# Train: [1600/4074 (39%)]	Loss: 0.059887
# Train: [1920/4074 (47%)]	Loss: 0.077070
# Train: [2240/4074 (55%)]	Loss: 0.028718
# Train: [2560/4074 (62%)]	Loss: 0.050177
# Train: [2880/4074 (70%)]	Loss: 0.034172
# Train: [3200/4074 (78%)]	Loss: 0.041482
# Train: [3520/4074 (86%)]	Loss: 0.050258
# Train: [3840/4074 (94%)]	Loss: 0.035284
# Epoch: 11/20. Train set: Average loss: 0.0467
# Epoch: 11/20. Validation set: Average loss: 0.0518
# Train: [0/4074 (0%)]	Loss: 0.024247
# Train: [320/4074 (8%)]	Loss: 0.035573
# Train: [640/4074 (16%)]	Loss: 0.081193
# Train: [960/4074 (23%)]	Loss: 0.034253
# Train: [1280/4074 (31%)]	Loss: 0.027287
# Train: [1600/4074 (39%)]	Loss: 0.040977
# Train: [1920/4074 (47%)]	Loss: 0.045138
# Train: [2240/4074 (55%)]	Loss: 0.036398
# Train: [2560/4074 (62%)]	Loss: 0.041070
# Train: [2880/4074 (70%)]	Loss: 0.028484
# Train: [3200/4074 (78%)]	Loss: 0.039740
# Train: [3520/4074 (86%)]	Loss: 0.043031
# Train: [3840/4074 (94%)]	Loss: 0.046752
# Epoch: 12/20. Train set: Average loss: 0.0411
# Epoch: 12/20. Validation set: Average loss: 0.0504
# Train: [0/4074 (0%)]	Loss: 0.030558
# Train: [320/4074 (8%)]	Loss: 0.046994
# Train: [640/4074 (16%)]	Loss: 0.035406
# Train: [960/4074 (23%)]	Loss: 0.037451
# Train: [1280/4074 (31%)]	Loss: 0.029586
# Train: [1600/4074 (39%)]	Loss: 0.033325
# Train: [1920/4074 (47%)]	Loss: 0.033236
# Train: [2240/4074 (55%)]	Loss: 0.032939
# Train: [2560/4074 (62%)]	Loss: 0.036166
# Train: [2880/4074 (70%)]	Loss: 0.031856
# Train: [3200/4074 (78%)]	Loss: 0.030457
# Train: [3520/4074 (86%)]	Loss: 0.026861
# Train: [3840/4074 (94%)]	Loss: 0.027242
# Epoch: 13/20. Train set: Average loss: 0.0340
# Epoch: 13/20. Validation set: Average loss: 0.0476
# Train: [0/4074 (0%)]	Loss: 0.029487
# Train: [320/4074 (8%)]	Loss: 0.035831
# Train: [640/4074 (16%)]	Loss: 0.025437
# Train: [960/4074 (23%)]	Loss: 0.028128
# Train: [1280/4074 (31%)]	Loss: 0.027023
# Train: [1600/4074 (39%)]	Loss: 0.037092
# Train: [1920/4074 (47%)]	Loss: 0.028668
# Train: [2240/4074 (55%)]	Loss: 0.034899
# Train: [2560/4074 (62%)]	Loss: 0.028020
# Train: [2880/4074 (70%)]	Loss: 0.023350
# Train: [3200/4074 (78%)]	Loss: 0.026304
# Train: [3520/4074 (86%)]	Loss: 0.028922
# Train: [3840/4074 (94%)]	Loss: 0.023255
# Epoch: 14/20. Train set: Average loss: 0.0289
# Epoch: 14/20. Validation set: Average loss: 0.0448
# Train: [0/4074 (0%)]	Loss: 0.022115
# Train: [320/4074 (8%)]	Loss: 0.027281
# Train: [640/4074 (16%)]	Loss: 0.026656
# Train: [960/4074 (23%)]	Loss: 0.023649
# Train: [1280/4074 (31%)]	Loss: 0.025181
# Train: [1600/4074 (39%)]	Loss: 0.025658
# Train: [1920/4074 (47%)]	Loss: 3.242507
# Train: [2240/4074 (55%)]	Loss: 0.042852
# Train: [2560/4074 (62%)]	Loss: 0.032935
# Train: [2880/4074 (70%)]	Loss: 0.041284
# Train: [3200/4074 (78%)]	Loss: 0.037768
# Train: [3520/4074 (86%)]	Loss: 0.059564
# Train: [3840/4074 (94%)]	Loss: 0.082283
# Epoch: 15/20. Train set: Average loss: 0.2911
# Epoch: 15/20. Validation set: Average loss: 0.0615
# Train: [0/4074 (0%)]	Loss: 0.063943
# Train: [320/4074 (8%)]	Loss: 0.038945
# Train: [640/4074 (16%)]	Loss: 0.050912
# Train: [960/4074 (23%)]	Loss: 0.054942
# Train: [1280/4074 (31%)]	Loss: 0.056940
# Train: [1600/4074 (39%)]	Loss: 0.034356
# Train: [1920/4074 (47%)]	Loss: 0.034263
# Train: [2240/4074 (55%)]	Loss: 0.038402
# Train: [2560/4074 (62%)]	Loss: 0.038364
# Train: [2880/4074 (70%)]	Loss: 0.039852
# Train: [3200/4074 (78%)]	Loss: 1.260272
# Train: [3520/4074 (86%)]	Loss: 0.042762
# Train: [3840/4074 (94%)]	Loss: 0.032863
# Epoch: 16/20. Train set: Average loss: 0.1375
# Epoch: 16/20. Validation set: Average loss: 0.0505
# Train: [0/4074 (0%)]	Loss: 0.020874
# Train: [320/4074 (8%)]	Loss: 0.033468
# Train: [640/4074 (16%)]	Loss: 0.071555
# Train: [960/4074 (23%)]	Loss: 0.044687
# Train: [1280/4074 (31%)]	Loss: 0.046886
# Train: [1600/4074 (39%)]	Loss: 0.061962
# Train: [1920/4074 (47%)]	Loss: 0.040465
# Train: [2240/4074 (55%)]	Loss: 0.031519
# Train: [2560/4074 (62%)]	Loss: 0.030325
# Train: [2880/4074 (70%)]	Loss: 0.041145
# Train: [3200/4074 (78%)]	Loss: 0.028130
# Train: [3520/4074 (86%)]	Loss: 0.048986
# Train: [3840/4074 (94%)]	Loss: 0.037457
# Epoch: 17/20. Train set: Average loss: 0.0439
# Epoch: 17/20. Validation set: Average loss: 0.0500
# Train: [0/4074 (0%)]	Loss: 0.077768
# Train: [320/4074 (8%)]	Loss: 0.030126
# Train: [640/4074 (16%)]	Loss: 0.061477
# Train: [960/4074 (23%)]	Loss: 0.029446
# Train: [1280/4074 (31%)]	Loss: 0.037813
# Train: [1600/4074 (39%)]	Loss: 0.041984
# Train: [1920/4074 (47%)]	Loss: 0.037926
# Train: [2240/4074 (55%)]	Loss: 0.031122
# Train: [2560/4074 (62%)]	Loss: 0.031407
# Train: [2880/4074 (70%)]	Loss: 0.036507
# Train: [3200/4074 (78%)]	Loss: 0.029131
# Train: [3520/4074 (86%)]	Loss: 0.024877
# Train: [3840/4074 (94%)]	Loss: 0.039251
# Epoch: 18/20. Train set: Average loss: 0.0367
# Epoch: 18/20. Validation set: Average loss: 0.0493
# Train: [0/4074 (0%)]	Loss: 0.033099
# Train: [320/4074 (8%)]	Loss: 0.041569
# Train: [640/4074 (16%)]	Loss: 0.038424
# Train: [960/4074 (23%)]	Loss: 0.039032
# Train: [1280/4074 (31%)]	Loss: 0.041601
# Train: [1600/4074 (39%)]	Loss: 0.046721
# Train: [1920/4074 (47%)]	Loss: 0.046391
# Train: [2240/4074 (55%)]	Loss: 0.029173
# Train: [2560/4074 (62%)]	Loss: 0.027389
# Train: [2880/4074 (70%)]	Loss: 0.029258
# Train: [3200/4074 (78%)]	Loss: 0.024684
# Train: [3520/4074 (86%)]	Loss: 0.027206
# Train: [3840/4074 (94%)]	Loss: 0.032669
# Epoch: 19/20. Train set: Average loss: 0.0372
# Epoch: 19/20. Validation set: Average loss: 0.0485
# Train: [0/4074 (0%)]	Loss: 0.030516
# Train: [320/4074 (8%)]	Loss: 0.032040
# Train: [640/4074 (16%)]	Loss: 0.044311
# Train: [960/4074 (23%)]	Loss: 0.032546
# Train: [1280/4074 (31%)]	Loss: 0.040237
# Train: [1600/4074 (39%)]	Loss: 0.050956
# Train: [1920/4074 (47%)]	Loss: 0.031656
# Train: [2240/4074 (55%)]	Loss: 0.030013
# Train: [2560/4074 (62%)]	Loss: 0.029416
# Train: [2880/4074 (70%)]	Loss: 0.023773
# Train: [3200/4074 (78%)]	Loss: 0.029959
# Train: [3520/4074 (86%)]	Loss: 0.029301
# Train: [3840/4074 (94%)]	Loss: 0.036904
# Epoch: 20/20. Train set: Average loss: 0.0342
# Epoch: 20/20. Validation set: Average loss: 0.0477

# %%
plt.plot(range(0, n_epochs), train_loss, 'rx-')
plt.plot(range(0, n_epochs), val_loss, 'bx-')

# %%
train_embeddings_cl, train_labels_cl = vis.extract_embeddings(train_loader, model)
vis.plot_embeddings(train_embeddings_cl, train_labels_cl, siamese_train_dataset.labels_dict)

# %%
val_embeddings_baseline, val_labels_baseline = vis.extract_embeddings(test_loader, model)
vis.plot_embeddings(val_embeddings_baseline, val_labels_baseline, siamese_test_dataset.labels_dict)
